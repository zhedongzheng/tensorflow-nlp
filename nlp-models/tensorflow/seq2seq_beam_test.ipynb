# %%
from seq2seq_beam import Seq2Seq
import sys
if int(sys.version[0]) == 2:
    from io import open


def read_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()
# end function read_data


def build_map(data):
    specials = ['<GO>',  '<EOS>', '<PAD>', '<UNK>']
    chars = list(set([char for line in data.split('\n') for char in line]))
    idx2char = {idx: char for idx, char in enumerate(specials + chars)}
    char2idx = {char: idx for idx, char in idx2char.items()}
    return idx2char, char2idx
# end function build_map


def preprocess_data():
    X_data = read_data('temp/letters_source.txt')
    Y_data = read_data('temp/letters_target.txt')

    X_idx2char, X_char2idx = build_map(X_data)
    Y_idx2char, Y_char2idx = build_map(Y_data)

    x_unk = X_char2idx['<UNK>']
    y_unk = Y_char2idx['<UNK>']
    y_eos = Y_char2idx['<EOS>']

    X_indices = [[X_char2idx.get(char, x_unk) for char in line] for line in X_data.split('\n')]
    Y_indices = [[Y_char2idx.get(char, y_unk) for char in line] + [y_eos] for line in Y_data.split('\n')]

    return X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char
# end function preprocess_data


def main():
    BATCH_SIZE = 128
    X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char = preprocess_data()
    X_train = X_indices[BATCH_SIZE:]
    Y_train = Y_indices[BATCH_SIZE:]
    X_test = X_indices[:BATCH_SIZE]
    Y_test = Y_indices[:BATCH_SIZE]

    model = Seq2Seq(
        rnn_size = 50,
        n_layers = 2,
        X_word2idx = X_char2idx,
        encoder_embedding_dim = 15,
        Y_word2idx = Y_char2idx,
        decoder_embedding_dim = 15,
    )
    model.fit(X_train, Y_train, val_data=(X_test, Y_test), batch_size=BATCH_SIZE)
    model.infer('common', X_idx2char, Y_idx2char)
    model.infer('apple', X_idx2char, Y_idx2char)
    model.infer('zhedong', X_idx2char, Y_idx2char)
# end function main


if __name__ == '__main__':
    main()
# Out:
# /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/60 | Batch 0/77 | train_loss: 3.401 | test_loss: 3.397
# Epoch 1/60 | Batch 50/77 | train_loss: 2.740 | test_loss: 2.704
# Epoch 2/60 | Batch 0/77 | train_loss: 2.369 | test_loss: 2.359
# Epoch 2/60 | Batch 50/77 | train_loss: 1.987 | test_loss: 1.975
# Epoch 3/60 | Batch 0/77 | train_loss: 1.772 | test_loss: 1.776
# Epoch 3/60 | Batch 50/77 | train_loss: 1.527 | test_loss: 1.501
# Epoch 4/60 | Batch 0/77 | train_loss: 1.385 | test_loss: 1.379
# Epoch 4/60 | Batch 50/77 | train_loss: 1.236 | test_loss: 1.198
# Epoch 5/60 | Batch 0/77 | train_loss: 1.113 | test_loss: 1.105
# Epoch 5/60 | Batch 50/77 | train_loss: 1.022 | test_loss: 0.963
# Epoch 6/60 | Batch 0/77 | train_loss: 0.896 | test_loss: 0.903
# Epoch 6/60 | Batch 50/77 | train_loss: 0.852 | test_loss: 0.786
# Epoch 7/60 | Batch 0/77 | train_loss: 0.730 | test_loss: 0.747
# Epoch 7/60 | Batch 50/77 | train_loss: 0.716 | test_loss: 0.644
# Epoch 8/60 | Batch 0/77 | train_loss: 0.611 | test_loss: 0.611
# Epoch 8/60 | Batch 50/77 | train_loss: 0.617 | test_loss: 0.538
# Epoch 9/60 | Batch 0/77 | train_loss: 0.518 | test_loss: 0.524
# Epoch 9/60 | Batch 50/77 | train_loss: 0.534 | test_loss: 0.454
# Epoch 10/60 | Batch 0/77 | train_loss: 0.452 | test_loss: 0.439
# Epoch 10/60 | Batch 50/77 | train_loss: 0.467 | test_loss: 0.391
# Epoch 11/60 | Batch 0/77 | train_loss: 0.389 | test_loss: 0.377
# Epoch 11/60 | Batch 50/77 | train_loss: 0.406 | test_loss: 0.338
# Epoch 32/60 | Batch 50/77 | train_loss: 0.027 | test_loss: 0.035
# Epoch 33/60 | Batch 0/77 | train_loss: 0.021 | test_loss: 0.035
# Epoch 33/60 | Batch 50/77 | train_loss: 0.026 | test_loss: 0.034
# Epoch 34/60 | Batch 0/77 | train_loss: 0.019 | test_loss: 0.033
# Epoch 34/60 | Batch 50/77 | train_loss: 0.022 | test_loss: 0.036
# Epoch 35/60 | Batch 0/77 | train_loss: 0.018 | test_loss: 0.029
# Epoch 35/60 | Batch 50/77 | train_loss: 0.018 | test_loss: 0.032
# Epoch 36/60 | Batch 0/77 | train_loss: 0.017 | test_loss: 0.029
# Epoch 36/60 | Batch 50/77 | train_loss: 0.017 | test_loss: 0.032
# Epoch 37/60 | Batch 0/77 | train_loss: 0.016 | test_loss: 0.028
# Epoch 37/60 | Batch 50/77 | train_loss: 0.016 | test_loss: 0.028
# Epoch 38/60 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.025
# Epoch 38/60 | Batch 50/77 | train_loss: 0.015 | test_loss: 0.025
# Epoch 39/60 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.028
# Epoch 39/60 | Batch 50/77 | train_loss: 0.015 | test_loss: 0.027
# Epoch 40/60 | Batch 0/77 | train_loss: 0.013 | test_loss: 0.024
# Epoch 40/60 | Batch 50/77 | train_loss: 0.013 | test_loss: 0.027
# Epoch 41/60 | Batch 0/77 | train_loss: 0.012 | test_loss: 0.024
# Epoch 41/60 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.023
# Epoch 42/60 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.023
# Epoch 42/60 | Batch 50/77 | train_loss: 0.013 | test_loss: 0.025
# Epoch 43/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.024
# Epoch 43/60 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.036
# Epoch 44/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.021
# Epoch 44/60 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.022
# Epoch 45/60 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.021
# Epoch 45/60 | Batch 50/77 | train_loss: 0.014 | test_loss: 0.022
# Epoch 46/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.027
# Epoch 46/60 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.017
# Epoch 47/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.020
# Epoch 47/60 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.021
# Epoch 48/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.020
# Epoch 48/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.022
# Epoch 49/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.019
# Epoch 49/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.022
# Epoch 50/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.019
# Epoch 50/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.020
# Epoch 51/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.017
# Epoch 51/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.022
# Epoch 52/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.017
# Epoch 52/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.017
# Epoch 53/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.018
# Epoch 53/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.020
# Epoch 54/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.016
# Epoch 54/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.024
# Epoch 55/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.021
# Epoch 55/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.019
# Epoch 56/60 | Batch 0/77 | train_loss: 0.061 | test_loss: 0.018
# Epoch 56/60 | Batch 50/77 | train_loss: 0.038 | test_loss: 0.019
# Epoch 57/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.027
# Epoch 57/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.016
# Epoch 58/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.015
# Epoch 58/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.013
# Epoch 59/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.013
# Epoch 59/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.013
# Epoch 60/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.014
# Epoch 60/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.013
#
# Source
# Word: [9, 27, 26, 26, 27, 6]
# IN: c o m m o n
#
# Target
# Word: [9, 26, 26, 6, 27, 27, 1]
# OUT: c m m n o o <EOS>
#
# Source
# Word: [14, 17, 17, 11, 13]
# IN: a p p l e
#
# Target
# Word: [14, 13, 11, 17, 17, 1]
# OUT: a e l p p <EOS>
#
# Source
# Word: [23, 24, 13, 25, 27, 6, 10]
# IN: z h e d o n g
#
# Target
# Word: [25, 13, 10, 24, 6, 27, 23, 1]
# OUT: d e g h n o z <EOS>
