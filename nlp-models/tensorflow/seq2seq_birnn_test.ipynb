# %%
from seq2seq_birnn import Seq2Seq
import sys
if int(sys.version[0]) == 2:
    from io import open


def read_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()
# end function read_data


def build_map(data):
    specials = ['<GO>',  '<EOS>', '<PAD>', '<UNK>']
    chars = list(set([char for line in data.split('\n') for char in line]))
    idx2char = {idx: char for idx, char in enumerate(specials + chars)}
    char2idx = {char: idx for idx, char in idx2char.items()}
    return idx2char, char2idx
# end function build_map


def preprocess_data():
    X_data = read_data('temp/letters_source.txt')
    Y_data = read_data('temp/letters_target.txt')

    X_idx2char, X_char2idx = build_map(X_data)
    Y_idx2char, Y_char2idx = build_map(Y_data)

    x_unk = X_char2idx['<UNK>']
    y_unk = Y_char2idx['<UNK>']
    y_eos = Y_char2idx['<EOS>']

    X_indices = [[X_char2idx.get(char, x_unk) for char in line] for line in X_data.split('\n')]
    Y_indices = [[Y_char2idx.get(char, y_unk) for char in line] + [y_eos] for line in Y_data.split('\n')]

    return X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char
# end function preprocess_data


def main():
    BATCH_SIZE = 128
    X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char = preprocess_data()
    X_train = X_indices[BATCH_SIZE:]
    Y_train = Y_indices[BATCH_SIZE:]
    X_test = X_indices[:BATCH_SIZE]
    Y_test = Y_indices[:BATCH_SIZE]

    model = Seq2Seq(
        rnn_size = 50,
        n_layers = 2,
        X_word2idx = X_char2idx,
        encoder_embedding_dim = 15,
        Y_word2idx = Y_char2idx,
        decoder_embedding_dim = 15,
    )
    model.fit(X_train, Y_train, val_data=(X_test, Y_test), batch_size=BATCH_SIZE)
    model.infer('common', X_idx2char, Y_idx2char)
    model.infer('apple', X_idx2char, Y_idx2char)
    model.infer('zhedong', X_idx2char, Y_idx2char)
# end function main


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/60 | Batch 0/77 | train_loss: 3.399 | test_loss: 3.396
# Epoch 1/60 | Batch 50/77 | train_loss: 2.818 | test_loss: 2.804
# Epoch 2/60 | Batch 0/77 | train_loss: 2.346 | test_loss: 2.373
# Epoch 2/60 | Batch 50/77 | train_loss: 1.831 | test_loss: 1.813
# Epoch 3/60 | Batch 0/77 | train_loss: 1.592 | test_loss: 1.620
# Epoch 3/60 | Batch 50/77 | train_loss: 1.415 | test_loss: 1.367
# Epoch 4/60 | Batch 0/77 | train_loss: 1.237 | test_loss: 1.265
# Epoch 4/60 | Batch 50/77 | train_loss: 1.139 | test_loss: 1.102
# Epoch 5/60 | Batch 0/77 | train_loss: 0.992 | test_loss: 1.033
# Epoch 5/60 | Batch 50/77 | train_loss: 0.934 | test_loss: 0.915
# Epoch 6/60 | Batch 0/77 | train_loss: 0.807 | test_loss: 0.862
# Epoch 6/60 | Batch 50/77 | train_loss: 0.775 | test_loss: 0.766
# Epoch 7/60 | Batch 0/77 | train_loss: 0.662 | test_loss: 0.717
# Epoch 7/60 | Batch 50/77 | train_loss: 0.646 | test_loss: 0.640
# Epoch 8/60 | Batch 0/77 | train_loss: 0.550 | test_loss: 0.601
# Epoch 8/60 | Batch 50/77 | train_loss: 0.539 | test_loss: 0.533
# Epoch 9/60 | Batch 0/77 | train_loss: 0.461 | test_loss: 0.505
# Epoch 9/60 | Batch 50/77 | train_loss: 0.449 | test_loss: 0.444
# Epoch 10/60 | Batch 0/77 | train_loss: 0.385 | test_loss: 0.422
# Epoch 10/60 | Batch 50/77 | train_loss: 0.372 | test_loss: 0.369
# Epoch 31/60 | Batch 50/77 | train_loss: 0.025 | test_loss: 0.034
# Epoch 32/60 | Batch 0/77 | train_loss: 0.021 | test_loss: 0.036
# Epoch 32/60 | Batch 50/77 | train_loss: 0.023 | test_loss: 0.032
# Epoch 33/60 | Batch 0/77 | train_loss: 0.019 | test_loss: 0.034
# Epoch 33/60 | Batch 50/77 | train_loss: 0.021 | test_loss: 0.029
# Epoch 34/60 | Batch 0/77 | train_loss: 0.017 | test_loss: 0.032
# Epoch 34/60 | Batch 50/77 | train_loss: 0.019 | test_loss: 0.027
# Epoch 35/60 | Batch 0/77 | train_loss: 0.016 | test_loss: 0.030
# Epoch 35/60 | Batch 50/77 | train_loss: 0.017 | test_loss: 0.025
# Epoch 36/60 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.027
# Epoch 36/60 | Batch 50/77 | train_loss: 0.016 | test_loss: 0.024
# Epoch 37/60 | Batch 0/77 | train_loss: 0.014 | test_loss: 0.025
# Epoch 37/60 | Batch 50/77 | train_loss: 0.015 | test_loss: 0.023
# Epoch 38/60 | Batch 0/77 | train_loss: 0.013 | test_loss: 0.023
# Epoch 38/60 | Batch 50/77 | train_loss: 0.014 | test_loss: 0.021
# Epoch 39/60 | Batch 0/77 | train_loss: 0.012 | test_loss: 0.022
# Epoch 39/60 | Batch 50/77 | train_loss: 0.013 | test_loss: 0.020
# Epoch 40/60 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.020
# Epoch 40/60 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.019
# Epoch 41/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.019
# Epoch 41/60 | Batch 50/77 | train_loss: 0.011 | test_loss: 0.018
# Epoch 42/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.018
# Epoch 42/60 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.017
# Epoch 43/60 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.017
# Epoch 43/60 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.016
# Epoch 44/60 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.016
# Epoch 44/60 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.016
# Epoch 45/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.016
# Epoch 45/60 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.015
# Epoch 46/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.015
# Epoch 46/60 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.014
# Epoch 47/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.014
# Epoch 47/60 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.014
# Epoch 48/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.014
# Epoch 48/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.013
# Epoch 49/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.013
# Epoch 49/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.013
# Epoch 50/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.013
# Epoch 50/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.012
# Epoch 51/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.012
# Epoch 51/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.012
# Epoch 52/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.012
# Epoch 52/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.011
# Epoch 53/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.012
# Epoch 53/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.011
# Epoch 54/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.011
# Epoch 54/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.010
# Epoch 55/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.011
# Epoch 55/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.010
# Epoch 56/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.011
# Epoch 56/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.009
# Epoch 57/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.010
# Epoch 57/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 58/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.010
# Epoch 58/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 59/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.009
# Epoch 59/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 60/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.009
# Epoch 60/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.007
#
# Source
# Word: [13, 25, 6, 6, 25, 18]
# IN: c o m m o n
#
# Target
# Word: [13, 6, 6, 18, 25, 25, 1]
# OUT: c m m n o o <EOS>
#
# Source
# Word: [4, 21, 21, 23, 17]
# IN: a p p l e
#
# Target
# Word: [4, 17, 23, 21, 21, 1]
# OUT: a e l p p <EOS>
#
# Source
# Word: [11, 15, 17, 5, 25, 18, 20]
# IN: z h e d o n g
#
# Target
# Word: [5, 17, 20, 15, 18, 25, 11, 1]
# OUT: d e g h n o z <EOS>
