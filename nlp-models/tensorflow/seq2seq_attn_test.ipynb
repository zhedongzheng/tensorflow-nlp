# %%
from seq2seq_attn import Seq2Seq
import sys
if int(sys.version[0]) == 2:
    from io import open


def read_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()
# end function read_data


def build_map(data):
    specials = ['<GO>',  '<EOS>', '<PAD>', '<UNK>']
    chars = list(set([char for line in data.split('\n') for char in line]))
    idx2char = {idx: char for idx, char in enumerate(specials + chars)}
    char2idx = {char: idx for idx, char in idx2char.items()}
    return idx2char, char2idx
# end function build_map


def preprocess_data():
    X_data = read_data('temp/letters_source.txt')
    Y_data = read_data('temp/letters_target.txt')

    X_idx2char, X_char2idx = build_map(X_data)
    Y_idx2char, Y_char2idx = build_map(Y_data)

    x_unk = X_char2idx['<UNK>']
    y_unk = Y_char2idx['<UNK>']
    y_eos = Y_char2idx['<EOS>']

    X_indices = [[X_char2idx.get(char, x_unk) for char in line] for line in X_data.split('\n')]
    Y_indices = [[Y_char2idx.get(char, y_unk) for char in line] + [y_eos] for line in Y_data.split('\n')]

    return X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char
# end function preprocess_data


def main():
    BATCH_SIZE = 128
    X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char = preprocess_data()
    X_train = X_indices[BATCH_SIZE:]
    Y_train = Y_indices[BATCH_SIZE:]
    X_test = X_indices[:BATCH_SIZE]
    Y_test = Y_indices[:BATCH_SIZE]

    model = Seq2Seq(
        rnn_size = 50,
        n_layers = 2,
        X_word2idx = X_char2idx,
        encoder_embedding_dim = 15,
        Y_word2idx = Y_char2idx,
        decoder_embedding_dim = 15,
    )
    model.fit(X_train, Y_train, val_data=(X_test, Y_test), batch_size=BATCH_SIZE)
    model.infer('common', X_idx2char, Y_idx2char)
    model.infer('apple', X_idx2char, Y_idx2char)
    model.infer('zhedong', X_idx2char, Y_idx2char)
# end function main


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/60 | Batch 0/77 | train_loss: 3.401 | test_loss: 3.396
# Epoch 1/60 | Batch 50/77 | train_loss: 2.796 | test_loss: 2.784
# Epoch 2/60 | Batch 0/77 | train_loss: 2.255 | test_loss: 2.274
# Epoch 2/60 | Batch 50/77 | train_loss: 1.732 | test_loss: 1.668
# Epoch 3/60 | Batch 0/77 | train_loss: 1.543 | test_loss: 1.479
# Epoch 3/60 | Batch 50/77 | train_loss: 1.305 | test_loss: 1.231
# Epoch 4/60 | Batch 0/77 | train_loss: 1.147 | test_loss: 1.106
# Epoch 4/60 | Batch 50/77 | train_loss: 0.994 | test_loss: 0.926
# Epoch 5/60 | Batch 0/77 | train_loss: 0.877 | test_loss: 0.863
# Epoch 5/60 | Batch 50/77 | train_loss: 0.776 | test_loss: 0.725
# Epoch 6/60 | Batch 0/77 | train_loss: 0.677 | test_loss: 0.668
# Epoch 6/60 | Batch 50/77 | train_loss: 0.581 | test_loss: 0.550
# Epoch 7/60 | Batch 0/77 | train_loss: 0.495 | test_loss: 0.514
# Epoch 7/60 | Batch 50/77 | train_loss: 0.440 | test_loss: 0.425
# Epoch 8/60 | Batch 0/77 | train_loss: 0.359 | test_loss: 0.376
# Epoch 8/60 | Batch 50/77 | train_loss: 0.332 | test_loss: 0.308
# Epoch 9/60 | Batch 0/77 | train_loss: 0.274 | test_loss: 0.279
# Epoch 9/60 | Batch 50/77 | train_loss: 0.244 | test_loss: 0.240
# Epoch 10/60 | Batch 0/77 | train_loss: 0.204 | test_loss: 0.215
# Epoch 10/60 | Batch 50/77 | train_loss: 0.174 | test_loss: 0.181
# Epoch 11/60 | Batch 0/77 | train_loss: 0.149 | test_loss: 0.166
# Epoch 11/60 | Batch 50/77 | train_loss: 0.136 | test_loss: 0.145
# Epoch 12/60 | Batch 0/77 | train_loss: 0.105 | test_loss: 0.134
# Epoch 12/60 | Batch 50/77 | train_loss: 0.096 | test_loss: 0.116
# Epoch 13/60 | Batch 0/77 | train_loss: 0.075 | test_loss: 0.111
# Epoch 13/60 | Batch 50/77 | train_loss: 0.068 | test_loss: 0.094
# Epoch 14/60 | Batch 0/77 | train_loss: 0.067 | test_loss: 0.099
# Epoch 14/60 | Batch 50/77 | train_loss: 0.048 | test_loss: 0.080
# Epoch 15/60 | Batch 0/77 | train_loss: 0.042 | test_loss: 0.083
# Epoch 15/60 | Batch 50/77 | train_loss: 0.040 | test_loss: 0.078
# Epoch 16/60 | Batch 0/77 | train_loss: 0.033 | test_loss: 0.068
# Epoch 16/60 | Batch 50/77 | train_loss: 0.025 | test_loss: 0.065
# Epoch 17/60 | Batch 0/77 | train_loss: 0.027 | test_loss: 0.055
# Epoch 17/60 | Batch 50/77 | train_loss: 0.019 | test_loss: 0.056
# Epoch 18/60 | Batch 0/77 | train_loss: 0.022 | test_loss: 0.053
# Epoch 18/60 | Batch 50/77 | train_loss: 0.017 | test_loss: 0.053
# Epoch 19/60 | Batch 0/77 | train_loss: 0.017 | test_loss: 0.053
# Epoch 19/60 | Batch 50/77 | train_loss: 0.018 | test_loss: 0.045
# Epoch 20/60 | Batch 0/77 | train_loss: 0.016 | test_loss: 0.050
# Epoch 20/60 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.054
# Epoch 21/60 | Batch 0/77 | train_loss: 0.013 | test_loss: 0.047
# Epoch 21/60 | Batch 50/77 | train_loss: 0.011 | test_loss: 0.043
# Epoch 22/60 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.044
# Epoch 22/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.038
# Epoch 23/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.045
# Epoch 23/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.039
# Epoch 24/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.037
# Epoch 24/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.044
# Epoch 25/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.036
# Epoch 25/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.032
# Epoch 26/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.043
# Epoch 26/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.028
# Epoch 27/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.045
# Epoch 27/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.029
# Epoch 28/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.045
# Epoch 28/60 | Batch 50/77 | train_loss: 0.002 | test_loss: 0.032
# Epoch 29/60 | Batch 0/77 | train_loss: 0.002 | test_loss: 0.044
# Epoch 29/60 | Batch 50/77 | train_loss: 0.002 | test_loss: 0.034
# Epoch 30/60 | Batch 0/77 | train_loss: 0.002 | test_loss: 0.043
# Epoch 30/60 | Batch 50/77 | train_loss: 0.002 | test_loss: 0.032
# Epoch 31/60 | Batch 0/77 | train_loss: 0.002 | test_loss: 0.044
# Epoch 31/60 | Batch 50/77 | train_loss: 0.002 | test_loss: 0.033
# Epoch 32/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.047
# Epoch 32/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.035
# Epoch 33/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.048
# Epoch 33/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 34/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.042
# Epoch 34/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 35/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.041
# Epoch 35/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 36/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.041
# Epoch 36/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 37/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 37/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 38/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 38/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 39/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 39/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.036
# Epoch 40/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 40/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.035
# Epoch 41/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 41/60 | Batch 50/77 | train_loss: 0.001 | test_loss: 0.035
# Epoch 42/60 | Batch 0/77 | train_loss: 0.001 | test_loss: 0.039
# Epoch 42/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 43/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.039
# Epoch 43/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 44/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.039
# Epoch 44/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 45/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.039
# Epoch 45/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 46/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.039
# Epoch 46/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 47/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.038
# Epoch 47/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 48/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.038
# Epoch 48/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 49/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.037
# Epoch 49/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 50/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.037
# Epoch 50/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 51/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.037
# Epoch 51/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 52/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 52/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 53/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 53/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 54/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 54/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 55/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 55/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.034
# Epoch 56/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 56/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.033
# Epoch 57/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.036
# Epoch 57/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.033
# Epoch 58/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 58/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.033
# Epoch 59/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 59/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.033
# Epoch 60/60 | Batch 0/77 | train_loss: 0.000 | test_loss: 0.035
# Epoch 60/60 | Batch 50/77 | train_loss: 0.000 | test_loss: 0.033
#
# Source
# Word: [12, 29, 8, 8, 29, 26]
# IN: c o m m o n
#
# Target
# Word: [12, 8, 8, 26, 29, 29, 1]
# OUT: c m m n o o <EOS>
#
# Source
# Word: [9, 18, 18, 7, 24]
# IN: a p p l e
#
# Target
# Word: [9, 24, 7, 18, 18, 1]
# OUT: a e l p p <EOS>
#
# Source
# Word: [11, 20, 24, 6, 29, 26, 14]
# IN: z h e d o n g
#
# Target
# Word: [6, 24, 14, 20, 26, 29, 11, 1]
# OUT: d e g h n o z <EOS>
