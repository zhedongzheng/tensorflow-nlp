# %%
from seq2seq import Seq2Seq
import sys
if int(sys.version[0]) == 2:
    from io import open


def read_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()
# end function read_data


def build_map(data):
    specials = ['<GO>',  '<EOS>', '<PAD>', '<UNK>']
    chars = list(set([char for line in data.split('\n') for char in line]))
    idx2char = {idx: char for idx, char in enumerate(specials + chars)}
    char2idx = {char: idx for idx, char in idx2char.items()}
    return idx2char, char2idx
# end function build_map


def preprocess_data():
    X_data = read_data('temp/letters_source.txt')
    Y_data = read_data('temp/letters_target.txt')

    X_idx2char, X_char2idx = build_map(X_data)
    Y_idx2char, Y_char2idx = build_map(Y_data)

    x_unk = X_char2idx['<UNK>']
    y_unk = Y_char2idx['<UNK>']
    y_eos = Y_char2idx['<EOS>']

    X_indices = [[X_char2idx.get(char, x_unk) for char in line] for line in X_data.split('\n')]
    Y_indices = [[Y_char2idx.get(char, y_unk) for char in line] + [y_eos] for line in Y_data.split('\n')]

    return X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char
# end function preprocess_data


def main():
    BATCH_SIZE = 128
    X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char = preprocess_data()
    X_train = X_indices[BATCH_SIZE:]
    Y_train = Y_indices[BATCH_SIZE:]
    X_test = X_indices[:BATCH_SIZE]
    Y_test = Y_indices[:BATCH_SIZE]

    model = Seq2Seq(
        rnn_size = 50,
        n_layers = 2,
        X_word2idx = X_char2idx,
        encoder_embedding_dim = 15,
        Y_word2idx = Y_char2idx,
        decoder_embedding_dim = 15,
    )
    model.fit(X_train, Y_train, val_data=(X_test, Y_test), batch_size=BATCH_SIZE, n_epoch=50)
    model.infer('common', X_idx2char, Y_idx2char)
    model.infer('apple', X_idx2char, Y_idx2char)
    model.infer('zhedong', X_idx2char, Y_idx2char)
# end function main


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/50 | Batch 0/77 | train_loss: 3.402 | test_loss: 3.397
# Epoch 1/50 | Batch 50/77 | train_loss: 2.689 | test_loss: 2.676
# Epoch 2/50 | Batch 0/77 | train_loss: 2.277 | test_loss: 2.282
# Epoch 2/50 | Batch 50/77 | train_loss: 1.930 | test_loss: 1.923
# Epoch 3/50 | Batch 0/77 | train_loss: 1.740 | test_loss: 1.767
# Epoch 3/50 | Batch 50/77 | train_loss: 1.528 | test_loss: 1.501
# Epoch 4/50 | Batch 0/77 | train_loss: 1.379 | test_loss: 1.385
# Epoch 4/50 | Batch 50/77 | train_loss: 1.236 | test_loss: 1.217
# Epoch 5/50 | Batch 0/77 | train_loss: 1.146 | test_loss: 1.141
# Epoch 5/50 | Batch 50/77 | train_loss: 1.042 | test_loss: 1.019
# Epoch 6/50 | Batch 0/77 | train_loss: 0.964 | test_loss: 0.953
# Epoch 6/50 | Batch 50/77 | train_loss: 0.877 | test_loss: 0.848
# Epoch 7/50 | Batch 0/77 | train_loss: 0.804 | test_loss: 0.789
# Epoch 7/50 | Batch 50/77 | train_loss: 0.730 | test_loss: 0.704
# Epoch 8/50 | Batch 0/77 | train_loss: 0.671 | test_loss: 0.657
# Epoch 8/50 | Batch 50/77 | train_loss: 0.604 | test_loss: 0.585
# Epoch 9/50 | Batch 0/77 | train_loss: 0.563 | test_loss: 0.550
# Epoch 9/50 | Batch 50/77 | train_loss: 0.503 | test_loss: 0.487
# Epoch 10/50 | Batch 0/77 | train_loss: 0.468 | test_loss: 0.457
# Epoch 10/50 | Batch 50/77 | train_loss: 0.417 | test_loss: 0.408
# Epoch 31/50 | Batch 0/77 | train_loss: 0.027 | test_loss: 0.043
# Epoch 31/50 | Batch 50/77 | train_loss: 0.027 | test_loss: 0.047
# Epoch 32/50 | Batch 0/77 | train_loss: 0.025 | test_loss: 0.041
# Epoch 32/50 | Batch 50/77 | train_loss: 0.026 | test_loss: 0.045
# Epoch 33/50 | Batch 0/77 | train_loss: 0.023 | test_loss: 0.039
# Epoch 33/50 | Batch 50/77 | train_loss: 0.023 | test_loss: 0.043
# Epoch 34/50 | Batch 0/77 | train_loss: 0.021 | test_loss: 0.038
# Epoch 34/50 | Batch 50/77 | train_loss: 0.020 | test_loss: 0.039
# Epoch 35/50 | Batch 0/77 | train_loss: 0.019 | test_loss: 0.037
# Epoch 35/50 | Batch 50/77 | train_loss: 0.019 | test_loss: 0.036
# Epoch 36/50 | Batch 0/77 | train_loss: 0.018 | test_loss: 0.035
# Epoch 36/50 | Batch 50/77 | train_loss: 0.017 | test_loss: 0.034
# Epoch 37/50 | Batch 0/77 | train_loss: 0.017 | test_loss: 0.033
# Epoch 37/50 | Batch 50/77 | train_loss: 0.016 | test_loss: 0.032
# Epoch 38/50 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.031
# Epoch 38/50 | Batch 50/77 | train_loss: 0.015 | test_loss: 0.031
# Epoch 39/50 | Batch 0/77 | train_loss: 0.014 | test_loss: 0.030
# Epoch 39/50 | Batch 50/77 | train_loss: 0.014 | test_loss: 0.029
# Epoch 40/50 | Batch 0/77 | train_loss: 0.013 | test_loss: 0.029
# Epoch 40/50 | Batch 50/77 | train_loss: 0.014 | test_loss: 0.029
# Epoch 41/50 | Batch 0/77 | train_loss: 0.012 | test_loss: 0.028
# Epoch 41/50 | Batch 50/77 | train_loss: 0.013 | test_loss: 0.030
# Epoch 42/50 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.028
# Epoch 42/50 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.031
# Epoch 43/50 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.028
# Epoch 43/50 | Batch 50/77 | train_loss: 0.011 | test_loss: 0.032
# Epoch 44/50 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.030
# Epoch 44/50 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.031
# Epoch 45/50 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.029
# Epoch 45/50 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.032
# Epoch 46/50 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.027
# Epoch 46/50 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.031
# Epoch 47/50 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.025
# Epoch 47/50 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.029
# Epoch 48/50 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.024
# Epoch 48/50 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.028
# Epoch 49/50 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.023
# Epoch 49/50 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.027
# Epoch 50/50 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.023
# Epoch 50/50 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.026
#
# Source
# Word: [9, 28, 10, 10, 28, 29]
# IN: c o m m o n
#
# Target
# Word: [9, 10, 10, 29, 28, 28, 1]
# OUT: c m m n o o <EOS>
#
# Source
# Word: [27, 21, 21, 5, 14]
# IN: a p p l e
#
# Target
# Word: [27, 14, 5, 21, 21, 1]
# OUT: a e l p p <EOS>
#
# Source
# Word: [12, 13, 14, 22, 28, 29, 24]
# IN: z h e d o n g
#
# Target
# Word: [22, 14, 24, 13, 29, 28, 12, 1]
# OUT: d e g h n o z <EOS>
