# %%
import pos
import numpy as np
import tensorflow as tf

from birnn_crf_clf import BiRNN_CRF
from sklearn.metrics import classification_report


SEQ_LEN = 20
BATCH_SIZE = 128
sample = ['I', 'love', 'you']


def to_train_seq(*args):
    data = []
    for x in args:
        data.append(iter_seq(x))
    return data


def to_test_seq(*args):
    data = []
    for x in args:
        x = x[: (len(x) - len(x) % SEQ_LEN)]
        data.append(np.reshape(x, [-1, SEQ_LEN]))
    return data


def iter_seq(x, text_iter_step=1):
    return np.array([x[i : i+SEQ_LEN] for i in range(0, len(x)-SEQ_LEN, text_iter_step)])


if __name__ == '__main__':
    x_train, y_train, x_test, y_test, vocab_size, n_class, word2idx, tag2idx = pos.load_data()
    X_train, Y_train = to_train_seq(x_train, y_train)
    X_test, Y_test = to_test_seq(x_test, y_test)
    print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)

    clf = BiRNN_CRF(vocab_size, n_class)
    clf.fit(X_train, Y_train, keep_prob=0.8, n_epoch=1, batch_size=BATCH_SIZE)
    
    y_pred = clf.predict(X_test, batch_size=BATCH_SIZE)
    print(classification_report(Y_test.ravel(), y_pred.ravel(), target_names=tag2idx.keys()))
    
    idx2tag = {idx : tag for tag, idx in tag2idx.items()}
    labels = clf.infer([word2idx[w] for w in sample])
    print(' '.join(sample))
    print(' '.join([idx2tag[idx] for idx in labels]))
# Out:
# Vocab Size: 19124 | x_train: 211727 | x_test: 47377
# (211707, 20) (211707, 20) (2368, 20) (2368, 20)
# /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Data Shuffled
# Epoch 1/1 | Step 0/1653 | train_loss: 76.5489 | train_acc: 0.0250 | lr: 0.0050
# Epoch 1/1 | Step 50/1653 | train_loss: 12.1942 | train_acc: 0.8242 | lr: 0.0047
# Epoch 1/1 | Step 100/1653 | train_loss: 7.5490 | train_acc: 0.8910 | lr: 0.0044
# Epoch 1/1 | Step 150/1653 | train_loss: 4.5577 | train_acc: 0.9391 | lr: 0.0041
# Epoch 1/1 | Step 200/1653 | train_loss: 3.1285 | train_acc: 0.9484 | lr: 0.0038
# Epoch 1/1 | Step 250/1653 | train_loss: 2.4561 | train_acc: 0.9629 | lr: 0.0035
# Epoch 1/1 | Step 300/1653 | train_loss: 2.0300 | train_acc: 0.9699 | lr: 0.0033
# Epoch 1/1 | Step 350/1653 | train_loss: 1.4030 | train_acc: 0.9801 | lr: 0.0031
# Epoch 1/1 | Step 400/1653 | train_loss: 1.3985 | train_acc: 0.9789 | lr: 0.0029
# Epoch 1/1 | Step 450/1653 | train_loss: 0.9159 | train_acc: 0.9879 | lr: 0.0027
# Epoch 1/1 | Step 500/1653 | train_loss: 1.1320 | train_acc: 0.9832 | lr: 0.0025
# Epoch 1/1 | Step 550/1653 | train_loss: 0.8177 | train_acc: 0.9863 | lr: 0.0023
# Epoch 1/1 | Step 600/1653 | train_loss: 0.5722 | train_acc: 0.9934 | lr: 0.0022
# Epoch 1/1 | Step 650/1653 | train_loss: 0.4868 | train_acc: 0.9934 | lr: 0.0020
# Epoch 1/1 | Step 700/1653 | train_loss: 0.7290 | train_acc: 0.9891 | lr: 0.0019
# Epoch 1/1 | Step 750/1653 | train_loss: 0.4820 | train_acc: 0.9930 | lr: 0.0018
# Epoch 1/1 | Step 800/1653 | train_loss: 0.4038 | train_acc: 0.9930 | lr: 0.0016
# Epoch 1/1 | Step 850/1653 | train_loss: 0.4201 | train_acc: 0.9934 | lr: 0.0015
# Epoch 1/1 | Step 900/1653 | train_loss: 0.4726 | train_acc: 0.9934 | lr: 0.0014
# Epoch 1/1 | Step 950/1653 | train_loss: 0.3903 | train_acc: 0.9937 | lr: 0.0013
# Epoch 1/1 | Step 1000/1653 | train_loss: 0.3163 | train_acc: 0.9949 | lr: 0.0012
# Epoch 1/1 | Step 1050/1653 | train_loss: 0.3323 | train_acc: 0.9949 | lr: 0.0012
# Epoch 1/1 | Step 1100/1653 | train_loss: 0.4939 | train_acc: 0.9934 | lr: 0.0011
# Epoch 1/1 | Step 1150/1653 | train_loss: 0.1937 | train_acc: 0.9969 | lr: 0.0010
# Epoch 1/1 | Step 1200/1653 | train_loss: 0.3903 | train_acc: 0.9930 | lr: 0.0009
# Epoch 1/1 | Step 1250/1653 | train_loss: 0.2885 | train_acc: 0.9957 | lr: 0.0009
# Epoch 1/1 | Step 1300/1653 | train_loss: 0.2965 | train_acc: 0.9969 | lr: 0.0008
# Epoch 1/1 | Step 1350/1653 | train_loss: 0.3733 | train_acc: 0.9957 | lr: 0.0008
# Epoch 1/1 | Step 1400/1653 | train_loss: 0.2815 | train_acc: 0.9957 | lr: 0.0007
# Epoch 1/1 | Step 1450/1653 | train_loss: 0.2485 | train_acc: 0.9969 | lr: 0.0007
# Epoch 1/1 | Step 1500/1653 | train_loss: 0.2781 | train_acc: 0.9969 | lr: 0.0006
# Epoch 1/1 | Step 1550/1653 | train_loss: 0.2499 | train_acc: 0.9957 | lr: 0.0006
# Epoch 1/1 | Step 1600/1653 | train_loss: 0.2381 | train_acc: 0.9965 | lr: 0.0005
# Epoch 1/1 | Step 1650/1653 | train_loss: 0.1773 | train_acc: 0.9977 | lr: 0.0005
# Epoch 1/1 | train_loss: 0.1808 | train_acc: 0.9976 | lr: 0.0005
#              precision    recall  f1-score   support
#
#       <pad>       0.96      0.91      0.94      6639
#          NN       0.99      1.00      1.00      5070
#          IN       1.00      1.00      1.00      4020
#          DT       0.98      0.93      0.95       912
#         VBZ       0.98      0.94      0.96      1354
#          RB       0.94      0.85      0.89      1103
#         VBN       1.00      1.00      1.00      1177
#          TO       0.95      0.92      0.94      1269
#          VB       0.95      0.86      0.90      2962
#          JJ       0.99      0.88      0.93      3034
#         NNS       0.97      0.89      0.93      4803
#         NNP       1.00      1.00      1.00      2389
#           ,       1.00      1.00      1.00      1214
#          CC       0.99      1.00      1.00       433
#         POS       1.00      1.00      1.00      1974
#           .       0.92      0.92      0.92       539
#         VBP       0.94      0.85      0.89       727
#         VBG       1.00      1.00      1.00       421
#        PRP$       0.52      1.00      0.68      1918
#          CD       1.00      1.00      1.00       323
#          ``       1.00      0.99      1.00       316
#          ''       0.97      0.94      0.95      1679
#         VBD       1.00      1.00      1.00        48
#          EX       1.00      0.99      0.99       470
#          MD       1.00      1.00      1.00        11
#           #       1.00      1.00      1.00        77
#           (       1.00      1.00      1.00       384
#           $       1.00      1.00      1.00        77
#           )       0.90      0.63      0.74       130
#        NNPS       1.00      1.00      1.00       814
#         PRP       1.00      0.94      0.97        77
#         JJS       1.00      1.00      1.00       110
#          WP       0.91      0.89      0.90        70
#         RBR       0.95      0.94      0.95       202
#         JJR       0.97      0.96      0.97       202
#         WDT       1.00      0.99      0.99        93
#         WRB       1.00      0.98      0.99        49
#         RBS       1.00      1.00      1.00        10
#         PDT       0.73      0.67      0.70        12
#          RP       1.00      1.00      1.00       238
#           :       1.00      0.75      0.86         4
#          FW       1.00      1.00      1.00         4
#         WP$       1.00      0.50      0.67         2
#
# avg / total       0.96      0.94      0.95     47360
#
# I love you
# PRP VBP PRP
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 43, does not match size of target_names, 45
#   .format(len(labels), len(target_names))
