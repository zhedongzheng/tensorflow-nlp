# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_lccc/main')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

import numpy as np
import pprint
import logging

from pathlib import Path
from modified_beam_search_decoder import BeamSearchDecoder

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  char2idx = params['char2idx']
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      source, target = line.split('<SEP>')
      source = [char2idx.get(c, len(char2idx)) for c in list(source)]
      target = [char2idx.get(c, len(char2idx)) for c in list(target)]
      if len(source) > params['max_len']:
        source = source[:params['max_len']]
      if len(target) > params['max_len']:
        target = target[:params['max_len']]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    def cell_fn():
        cell = tf.nn.rnn_cell.LSTMCell(params['rnn_units'],
                                       initializer=tf.orthogonal_initializer())
        return cell
    if params['dec_layers'] > 1:
      cells = []
      for i in range(params['dec_layers']):
        if i == params['dec_layers'] - 1:
          cells.append(cell_fn())
        else:
          cells.append(tf.nn.rnn_cell.ResidualWrapper(cell_fn(), residual_fn=lambda i,o: tf.concat((i,o), -1)))
      return tf.nn.rnn_cell.MultiRNNCell(cells)
    else:
      return cell_fn()

  
def dec_cell(enc_out, enc_seq_len):
    attn = tf.contrib.seq2seq.BahdanauAttention(
        num_units = params['rnn_units'],
        memory = enc_out,
        memory_sequence_length = enc_seq_len)
    
    return tf.contrib.seq2seq.AttentionWrapper(
        cell = rnn_cell(),
        attention_mechanism = attn,
        attention_layer_size = params['rnn_units'])

# %%
class TiedDense(tf.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return tf.nn.softmax(x)
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
class Pointer(tf.layers.Layer):
  def __init__(self, vocab_size, encoder_ids, encoder_out, is_beam_search):
    super().__init__()
    self.encoder_ids = encoder_ids
    self.encoder_out = encoder_out
    self.vocab_size = vocab_size
    self.is_beam_search = is_beam_search

  def call(self, inputs):
    _max_len = tf.shape(self.encoder_ids)[1]
    _batch_size_ori = tf.shape(inputs)[0]
    if self.is_beam_search:
      _batch_size= _batch_size_ori * params['beam_width']
    else:
      _batch_size = _batch_size_ori
    inputs = tf.reshape(inputs, (_batch_size, params['rnn_units']))

    attn_weights = tf.matmul(self.encoder_out, tf.expand_dims(inputs, -1))
    attn_weights = tf.squeeze(attn_weights, -1)
    updates = tf.nn.softmax(attn_weights)
    
    batch_nums = tf.range(0, _batch_size)
    batch_nums = tf.expand_dims(batch_nums, axis=1)
    batch_nums = tf.tile(batch_nums, [1, _max_len])

    indices = tf.stack([batch_nums, self.encoder_ids], axis=2)
    if self.is_beam_search:
      x = tf.scatter_nd(indices, updates, (_batch_size, self.vocab_size))
      return tf.reshape(x, (_batch_size_ori, params['beam_width'], self.vocab_size))
    else:
      x = tf.scatter_nd(indices, updates, (_batch_size, self.vocab_size))
      return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.vocab_size)

# %%
class OutputProj(tf.layers.Layer):
  def __init__(self, tied_embed, vocab_size, encoder_ids, encoder_out, is_beam_search):
    super().__init__()
    self.generator = TiedDense(tied_embed, vocab_size)
    self.pointer = Pointer(vocab_size, encoder_ids, encoder_out, is_beam_search)
    self.vocab_size = vocab_size

  def build(self, input_shape):
    self.gate_fc = tf.keras.layers.Dense(1, tf.sigmoid, use_bias=False)
    super().build(input_shape)
  
  def call(self, inputs):
    gen_dist = self.generator(inputs)
    copy_dist = self.pointer(inputs)
    gate = self.gate_fc(inputs)
    return gate * gen_dist + (1 - gate) * copy_dist
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.vocab_size)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    mask = tf.sign(words)
    
    
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        x = tf.nn.embedding_lookup(embedding, words)
        x = tf.layers.dropout(x, params['dropout_rate'], training=is_training)
    
    
    with tf.variable_scope('Encoder'):
        encoder = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
          params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
        enc_out, state_fw_h, state_fw_c, state_bw_h, state_bw_c = encoder(x, mask=mask)

        enc_state = tf.concat((tf.reduce_max(enc_out, 1), state_fw_h, state_bw_h), axis=-1)
        enc_state = tf.layers.dense(enc_state, params['rnn_units'], params['activation'], name='state_fc')
        enc_out = tf.layers.dense(enc_out, params['rnn_units'], params['activation'], name='out_fc')
        enc_state = tf.nn.rnn_cell.LSTMStateTuple(c=enc_state, h=enc_state)
        if params['dec_layers'] > 1:
          enc_state = tuple(params['dec_layers'] * [enc_state])
    
    
    with tf.variable_scope('Decoder'):
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = tf.layers.dropout(dec_inputs, params['dropout_rate'], training=is_training)

            cell = dec_cell(enc_out, words_len)
            output_proj = OutputProj(embedding, len(params['char2idx'])+1, words, enc_out, is_beam_search=False)
            
            init_state = cell.zero_state(batch_sz, tf.float32).clone(
                cell_state=enc_state)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = dec_inputs,
                sequence_length = dec_seq_len,)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = cell,
                helper = helper,
                initial_state = init_state,
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            
            return decoder_output.rnn_output
        else:
            enc_id_t = tf.contrib.seq2seq.tile_batch(words, params['beam_width'])
            enc_out_t = tf.contrib.seq2seq.tile_batch(enc_out, params['beam_width'])
            enc_state_t = tf.contrib.seq2seq.tile_batch(enc_state, params['beam_width'])
            enc_seq_len_t = tf.contrib.seq2seq.tile_batch(words_len, params['beam_width'])
            
            cell = dec_cell(enc_out_t, enc_seq_len_t)
            output_proj = OutputProj(embedding, len(params['char2idx'])+1, enc_id_t, enc_out_t, is_beam_search=True)
            
            init_state = cell.zero_state(batch_sz*params['beam_width'], tf.float32).clone(
                cell_state=enc_state_t)
            
            decoder = BeamSearchDecoder(
                cell = cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
                end_token = 2,
                initial_state = init_state,
                beam_width = params['beam_width'],
                output_layer = output_proj,
                length_penalty_weight = params['length_penalty'],
                coverage_penalty_weight = params['coverage_penalty'],)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = params['max_len'],)
            
            return decoder_output.predicted_ids[:, :, :params['top_k']]

# %%
def clr(step,
        initial_learning_rate,
        maximal_learning_rate,
        step_size,
        scale_fn,
        scale_mode,):
  step = tf.cast(step, tf.float32)
  
  initial_learning_rate = tf.convert_to_tensor(
    initial_learning_rate, name='initial_learning_rate')
  dtype = initial_learning_rate.dtype
  maximal_learning_rate = tf.cast(maximal_learning_rate, dtype)
  step_size = tf.cast(step_size, dtype)
  cycle = tf.floor(1 + step / (2 * step_size))
  x = tf.abs(step / step_size - 2 * cycle + 1)

  mode_step = cycle if scale_mode == 'cycle' else step

  return initial_learning_rate + (
    maximal_learning_rate - initial_learning_rate) * tf.maximum(
      tf.cast(0, dtype), (1 - x)) * scale_fn(mode_step)

# %%
def cross_entropy_loss(logits, labels, vocab_size, smoothing):
  soft_targets = tf.one_hot(tf.cast(labels, tf.int32), depth=vocab_size)
  soft_targets = ((1-smoothing) * soft_targets) + (smoothing / vocab_size)

  logits = tf.math.minimum(1., logits + 1e-6)
  log_probs = tf.math.log(logits)
  xentropy = - tf.reduce_sum(soft_targets * log_probs, axis=-1)

  weights = tf.cast(tf.math.not_equal(labels, 0), tf.float32)
  xentropy *= weights
  return tf.reduce_sum(xentropy) / tf.reduce_sum(weights)

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    
    if (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = cross_entropy_loss(logits_or_ids, dec_outputs, len(params['char2idx'])+1, .0)
    else:
      loss_op = cross_entropy_loss(logits_or_ids, dec_outputs, len(params['char2idx'])+1, params['label_smoothing'])
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()

        decay_lr = clr(
          step = global_step,
          initial_learning_rate = 1e-4,
          maximal_learning_rate = 8e-4,
          step_size = params['num_samples'] / params['batch_size'] // 2,
          scale_fn=lambda x: 1 / (2.0 ** (x - 1)),
          scale_mode = 'cycle',)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def unit_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '你今天心情好吗',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去唱歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs, dtype=np.int32), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('unit test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx!=0 and idx!=2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
params = {
    'model_dir': '../model/lstm_pointer',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'dropout_rate': .2,
    'rnn_units': 300,
    'activation': tf.nn.swish,
    'dec_layers': 1,
    'beam_width': 10,
    'top_k': 3,
    'length_penalty': .6,
    'coverage_penalty': .0,
    'label_smoothing': .2,
    'clip_norm': .1,
    'num_samples': 5000000,
    'buffer_size': 500000,
    'batch_size': 64,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}
print(len(params['char2idx']), 'Chars')

# Create directory if not exist
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps = params['num_samples'] // params['batch_size'] + 1,
    keep_checkpoint_max = 2),
  params=params)

best_ppl = 10000.
count = 0
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  unit_test(estimator)
  
  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  print("Perplexity: {:.3f}".format(ppl))

  if ppl < best_ppl:
    best_ppl = ppl
    count = 0
  else:
    count += 1
  print("Best Perplexity: {:.3f}".format(best_ppl))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# 3042 Chars
# INFO:tensorflow:Using config: {'_model_dir': '../model/lstm_pointer', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 78126, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 2, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa7c53417f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# WARNING:tensorflow:From <ipython-input-10-e160818cd8e1>:14: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:271: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From <ipython-input-10-e160818cd8e1>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From <ipython-input-6-33c7bca471bf>:12: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:Entity <bound method OutputProj.call of <__main__.OutputProj object at 0x7fa7b703c828>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method OutputProj.call of <__main__.OutputProj object at 0x7fa7b703c828>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fa7b703c898>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fa7b703c898>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pointer.call of <__main__.Pointer object at 0x7fa7b703c9e8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Pointer.call of <__main__.Pointer object at 0x7fa7b703c9e8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3043, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/out_fc/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/out_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/output_proj/tied_dense/bias:0' shape=(3043,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/while/BasicDecoderStep/output_proj/dense/kernel:0' shape=(300, 1) dtype=float32>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_pointer/model.ckpt-468750
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 468750 into ../model/lstm_pointer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 4.8338313, step = 468750
# INFO:tensorflow:lr = 0.00010000168
# INFO:tensorflow:global_step/sec: 4.29535
# INFO:tensorflow:loss = 4.9151487, step = 468850 (23.289 sec)
# INFO:tensorflow:lr = 0.000100029676 (23.289 sec)
# INFO:tensorflow:global_step/sec: 4.56632
# INFO:tensorflow:loss = 4.7346883, step = 468950 (21.896 sec)
# INFO:tensorflow:lr = 0.00010005768 (21.898 sec)
# INFO:tensorflow:global_step/sec: 4.62822
# INFO:tensorflow:loss = 4.9791636, step = 469050 (21.607 sec)
# INFO:tensorflow:lr = 0.00010008568 (21.606 sec)
# INFO:tensorflow:global_step/sec: 4.65782
# INFO:tensorflow:loss = 4.8442717, step = 469150 (21.468 sec)
# INFO:tensorflow:lr = 0.000100113684 (21.470 sec)
# INFO:tensorflow:global_step/sec: 4.53397
# INFO:tensorflow:loss = 4.819277, step = 469250 (22.054 sec)
# INFO:tensorflow:lr = 0.00010014168 (22.053 sec)
# INFO:tensorflow:global_step/sec: 4.50894
# INFO:tensorflow:loss = 4.6225505, step = 469350 (22.180 sec)
# INFO:tensorflow:lr = 0.00010016967 (22.179 sec)
# INFO:tensorflow:global_step/sec: 4.60375
# INFO:tensorflow:loss = 4.8636303, step = 469450 (21.722 sec)
# INFO:tensorflow:lr = 0.000100197685 (21.721 sec)
# INFO:tensorflow:global_step/sec: 4.67648
# INFO:tensorflow:loss = 4.9095054, step = 469550 (21.382 sec)
# INFO:tensorflow:lr = 0.000100225676 (21.384 sec)
# INFO:tensorflow:global_step/sec: 4.71276
# INFO:tensorflow:loss = 4.8736057, step = 469650 (21.220 sec)
# INFO:tensorflow:lr = 0.00010025369 (21.219 sec)
# INFO:tensorflow:global_step/sec: 4.76173
# INFO:tensorflow:loss = 4.8860507, step = 469750 (21.001 sec)
# INFO:tensorflow:lr = 0.00010028168 (21.001 sec)
# INFO:tensorflow:global_step/sec: 4.71093
# INFO:tensorflow:loss = 4.709522, step = 469850 (21.225 sec)
# INFO:tensorflow:lr = 0.00010030968 (21.226 sec)
# INFO:tensorflow:global_step/sec: 4.75515
# INFO:tensorflow:loss = 4.981556, step = 469950 (21.030 sec)
# INFO:tensorflow:lr = 0.00010033768 (21.032 sec)
# INFO:tensorflow:global_step/sec: 4.78187
# INFO:tensorflow:loss = 4.752223, step = 470050 (20.912 sec)
# INFO:tensorflow:lr = 0.00010036568 (20.909 sec)
# INFO:tensorflow:global_step/sec: 4.86801
# INFO:tensorflow:loss = 4.7807965, step = 470150 (20.545 sec)
# INFO:tensorflow:lr = 0.000100393685 (20.545 sec)
# INFO:tensorflow:global_step/sec: 4.89069
# INFO:tensorflow:loss = 4.6636114, step = 470250 (20.447 sec)
# INFO:tensorflow:lr = 0.00010042168 (20.447 sec)
# INFO:tensorflow:global_step/sec: 4.90614
# INFO:tensorflow:loss = 4.781418, step = 470350 (20.384 sec)
# INFO:tensorflow:lr = 0.00010044968 (20.383 sec)
# INFO:tensorflow:global_step/sec: 4.94224
# INFO:tensorflow:loss = 4.761419, step = 470450 (20.233 sec)
# INFO:tensorflow:lr = 0.000100477686 (20.233 sec)
# INFO:tensorflow:global_step/sec: 4.94661
# INFO:tensorflow:loss = 4.8034267, step = 470550 (20.213 sec)
# INFO:tensorflow:lr = 0.000100505684 (20.214 sec)
# INFO:tensorflow:global_step/sec: 4.96831
# INFO:tensorflow:loss = 4.758636, step = 470650 (20.130 sec)
# INFO:tensorflow:lr = 0.00010053368 (20.130 sec)
# INFO:tensorflow:global_step/sec: 4.92685
# INFO:tensorflow:loss = 4.8762784, step = 470750 (20.296 sec)
# INFO:tensorflow:lr = 0.00010056169 (20.295 sec)
# INFO:tensorflow:global_step/sec: 4.99704
# INFO:tensorflow:loss = 4.7422996, step = 470850 (20.013 sec)
# INFO:tensorflow:lr = 0.000100589685 (20.014 sec)
# INFO:tensorflow:global_step/sec: 5.00876
# INFO:tensorflow:loss = 4.9509087, step = 470950 (19.962 sec)
# INFO:tensorflow:lr = 0.00010061769 (19.962 sec)
# INFO:tensorflow:global_step/sec: 4.98257
# INFO:tensorflow:loss = 4.9344764, step = 471050 (20.073 sec)
# INFO:tensorflow:lr = 0.00010064569 (20.073 sec)
# INFO:tensorflow:global_step/sec: 4.99773
# INFO:tensorflow:loss = 4.8978896, step = 471150 (20.006 sec)
# INFO:tensorflow:lr = 0.00010067368 (20.011 sec)
# INFO:tensorflow:global_step/sec: 5.04218
# INFO:tensorflow:loss = 4.7367687, step = 471250 (19.836 sec)
# INFO:tensorflow:lr = 0.00010070169 (19.831 sec)
# INFO:tensorflow:global_step/sec: 4.96171
# INFO:tensorflow:loss = 4.7009826, step = 471350 (20.155 sec)
# INFO:tensorflow:lr = 0.00010072968 (20.154 sec)
# INFO:tensorflow:global_step/sec: 5.0118
# INFO:tensorflow:loss = 4.7168036, step = 471450 (19.951 sec)
# INFO:tensorflow:lr = 0.000100757694 (19.953 sec)
# INFO:tensorflow:global_step/sec: 4.96536
# INFO:tensorflow:loss = 4.890582, step = 471550 (20.140 sec)
# INFO:tensorflow:lr = 0.000100785684 (20.140 sec)
# INFO:tensorflow:global_step/sec: 5.05843
# INFO:tensorflow:loss = 4.8490863, step = 471650 (19.767 sec)
# INFO:tensorflow:lr = 0.00010081368 (19.767 sec)
# INFO:tensorflow:global_step/sec: 5.02783
# INFO:tensorflow:loss = 4.8679633, step = 471750 (19.889 sec)
# INFO:tensorflow:lr = 0.00010084169 (19.887 sec)
# INFO:tensorflow:global_step/sec: 5.07397
# INFO:tensorflow:loss = 4.731988, step = 471850 (19.710 sec)
# INFO:tensorflow:lr = 0.000100869685 (19.712 sec)
# INFO:tensorflow:global_step/sec: 4.99964
# INFO:tensorflow:loss = 4.778894, step = 471950 (20.002 sec)
# INFO:tensorflow:lr = 0.00010089769 (20.001 sec)
# INFO:tensorflow:global_step/sec: 5.03352
# INFO:tensorflow:loss = 4.649537, step = 472050 (19.869 sec)
# INFO:tensorflow:lr = 0.00010092569 (19.868 sec)
# INFO:tensorflow:global_step/sec: 5.05541
# INFO:tensorflow:loss = 4.907662, step = 472150 (19.779 sec)
# INFO:tensorflow:lr = 0.000100953686 (19.780 sec)
# INFO:tensorflow:global_step/sec: 5.08498
# INFO:tensorflow:loss = 4.896853, step = 472250 (19.666 sec)
# INFO:tensorflow:lr = 0.00010098169 (19.665 sec)
# INFO:tensorflow:global_step/sec: 5.02663
# INFO:tensorflow:loss = 4.774584, step = 472350 (19.893 sec)
# INFO:tensorflow:lr = 0.00010100969 (19.894 sec)
# INFO:tensorflow:global_step/sec: 5.07148
# INFO:tensorflow:loss = 4.8778615, step = 472450 (19.719 sec)
# INFO:tensorflow:lr = 0.00010103769 (19.718 sec)
# INFO:tensorflow:global_step/sec: 5.05558
# INFO:tensorflow:loss = 4.679188, step = 472550 (19.780 sec)
# INFO:tensorflow:lr = 0.00010106569 (19.780 sec)
# INFO:tensorflow:global_step/sec: 5.05931
# INFO:tensorflow:loss = 4.8882947, step = 472650 (19.766 sec)
# INFO:tensorflow:lr = 0.00010109369 (19.766 sec)
# INFO:tensorflow:global_step/sec: 5.00396
# INFO:tensorflow:loss = 4.6220007, step = 472750 (19.984 sec)
# INFO:tensorflow:lr = 0.000101121695 (19.985 sec)
# INFO:tensorflow:global_step/sec: 4.96525
# INFO:tensorflow:loss = 4.843534, step = 472850 (20.139 sec)
# INFO:tensorflow:lr = 0.00010114969 (20.139 sec)
# INFO:tensorflow:global_step/sec: 5.01905
# INFO:tensorflow:loss = 4.6142883, step = 472950 (19.922 sec)
# INFO:tensorflow:lr = 0.00010117769 (19.924 sec)
# INFO:tensorflow:global_step/sec: 5.08959
# INFO:tensorflow:loss = 4.810038, step = 473050 (19.650 sec)
# INFO:tensorflow:lr = 0.0001012057 (19.649 sec)
# INFO:tensorflow:global_step/sec: 5.08418
# INFO:tensorflow:loss = 4.8165956, step = 473150 (19.669 sec)
# INFO:tensorflow:lr = 0.000101233694 (19.669 sec)
# INFO:tensorflow:global_step/sec: 5.09861
# INFO:tensorflow:loss = 4.9624023, step = 473250 (19.614 sec)
# INFO:tensorflow:lr = 0.0001012617 (19.613 sec)
# INFO:tensorflow:global_step/sec: 5.04424
# INFO:tensorflow:loss = 4.842603, step = 473350 (19.824 sec)
# INFO:tensorflow:lr = 0.0001012897 (19.825 sec)
# INFO:tensorflow:global_step/sec: 5.02914
# INFO:tensorflow:loss = 4.8569, step = 473450 (19.886 sec)
# INFO:tensorflow:lr = 0.00010131769 (19.884 sec)
# INFO:tensorflow:global_step/sec: 4.98359
# INFO:tensorflow:loss = 4.7590847, step = 473550 (20.065 sec)
# INFO:tensorflow:lr = 0.0001013457 (20.065 sec)
# INFO:tensorflow:global_step/sec: 5.05578
# INFO:tensorflow:loss = 4.724683, step = 473650 (19.779 sec)
# INFO:tensorflow:lr = 0.00010137369 (19.778 sec)
# INFO:tensorflow:global_step/sec: 5.04878
# INFO:tensorflow:loss = 4.877709, step = 473750 (19.808 sec)
# INFO:tensorflow:lr = 0.0001014017 (19.808 sec)
# INFO:tensorflow:global_step/sec: 5.04727
# INFO:tensorflow:loss = 4.84971, step = 473850 (19.813 sec)
# INFO:tensorflow:lr = 0.000101429694 (19.813 sec)
# INFO:tensorflow:global_step/sec: 5.02967
# INFO:tensorflow:loss = 4.7077565, step = 473950 (19.887 sec)
# INFO:tensorflow:lr = 0.00010145769 (19.887 sec)
# INFO:tensorflow:global_step/sec: 5.01122
# INFO:tensorflow:loss = 4.866624, step = 474050 (19.951 sec)
# INFO:tensorflow:lr = 0.0001014857 (19.950 sec)
# INFO:tensorflow:global_step/sec: 5.06281
# INFO:tensorflow:loss = 4.764505, step = 474150 (19.750 sec)
# INFO:tensorflow:lr = 0.000101513695 (19.750 sec)
# INFO:tensorflow:global_step/sec: 4.98196
# INFO:tensorflow:loss = 4.9581017, step = 474250 (20.073 sec)
# INFO:tensorflow:lr = 0.00010154169 (20.075 sec)
# INFO:tensorflow:global_step/sec: 4.9198
# INFO:tensorflow:loss = 4.808321, step = 474350 (20.327 sec)
# INFO:tensorflow:lr = 0.0001015697 (20.327 sec)
# INFO:tensorflow:global_step/sec: 4.77148
# INFO:tensorflow:loss = 4.7849083, step = 474450 (20.958 sec)
# INFO:tensorflow:lr = 0.000101597696 (20.957 sec)
# INFO:tensorflow:global_step/sec: 4.83897
# INFO:tensorflow:loss = 4.8641458, step = 474550 (20.665 sec)
# INFO:tensorflow:lr = 0.0001016257 (20.665 sec)
# INFO:tensorflow:global_step/sec: 4.73018
# INFO:tensorflow:loss = 4.858291, step = 474650 (21.139 sec)
# INFO:tensorflow:lr = 0.0001016537 (21.140 sec)
# INFO:tensorflow:global_step/sec: 4.63758
# INFO:tensorflow:loss = 4.983636, step = 474750 (21.566 sec)
# INFO:tensorflow:lr = 0.0001016817 (21.566 sec)
# INFO:tensorflow:global_step/sec: 4.75141
# INFO:tensorflow:loss = 4.7238374, step = 474850 (21.043 sec)
# INFO:tensorflow:lr = 0.0001017097 (21.043 sec)
# INFO:tensorflow:global_step/sec: 4.73694
# INFO:tensorflow:loss = 4.857829, step = 474950 (21.113 sec)
# INFO:tensorflow:lr = 0.0001017377 (21.113 sec)
# INFO:tensorflow:global_step/sec: 4.69476
# INFO:tensorflow:loss = 4.7574263, step = 475050 (21.301 sec)
# INFO:tensorflow:lr = 0.000101765705 (21.300 sec)
# INFO:tensorflow:global_step/sec: 4.67902
# INFO:tensorflow:loss = 4.843785, step = 475150 (21.372 sec)
# INFO:tensorflow:lr = 0.0001017937 (21.371 sec)
# INFO:tensorflow:global_step/sec: 4.76754
# INFO:tensorflow:loss = 4.7001953, step = 475250 (20.975 sec)
# INFO:tensorflow:lr = 0.0001018217 (20.975 sec)
# INFO:tensorflow:global_step/sec: 4.80513
# INFO:tensorflow:loss = 4.829166, step = 475350 (20.811 sec)
# INFO:tensorflow:lr = 0.000101849706 (20.812 sec)
# INFO:tensorflow:global_step/sec: 4.71152
# INFO:tensorflow:loss = 4.9196525, step = 475450 (21.222 sec)
# INFO:tensorflow:lr = 0.0001018777 (21.222 sec)
# INFO:tensorflow:global_step/sec: 4.63675
# INFO:tensorflow:loss = 4.803467, step = 475550 (21.567 sec)
# INFO:tensorflow:lr = 0.00010190571 (21.567 sec)
# INFO:tensorflow:global_step/sec: 4.58963
# INFO:tensorflow:loss = 4.785481, step = 475650 (21.792 sec)
# INFO:tensorflow:lr = 0.00010193371 (21.791 sec)
# INFO:tensorflow:global_step/sec: 4.67632
# INFO:tensorflow:loss = 4.80142, step = 475750 (21.383 sec)
# INFO:tensorflow:lr = 0.0001019617 (21.383 sec)
# INFO:tensorflow:global_step/sec: 4.7599
# INFO:tensorflow:loss = 4.8614364, step = 475850 (21.010 sec)
# INFO:tensorflow:lr = 0.0001019897 (21.011 sec)
# INFO:tensorflow:global_step/sec: 4.77288
# INFO:tensorflow:loss = 4.7303815, step = 475950 (20.950 sec)
# INFO:tensorflow:lr = 0.0001020177 (20.954 sec)
# INFO:tensorflow:global_step/sec: 4.86666
# INFO:tensorflow:loss = 4.8367834, step = 476050 (20.550 sec)
# INFO:tensorflow:lr = 0.0001020457 (20.545 sec)
# INFO:tensorflow:global_step/sec: 4.86395
# INFO:tensorflow:loss = 4.755257, step = 476150 (20.558 sec)
# INFO:tensorflow:lr = 0.0001020737 (20.559 sec)
# INFO:tensorflow:global_step/sec: 4.81198
# INFO:tensorflow:loss = 4.833772, step = 476250 (20.779 sec)
# INFO:tensorflow:lr = 0.0001021017 (20.779 sec)
# INFO:tensorflow:global_step/sec: 4.82617
# INFO:tensorflow:loss = 4.69455, step = 476350 (20.724 sec)
# INFO:tensorflow:lr = 0.00010212971 (20.723 sec)
# INFO:tensorflow:global_step/sec: 4.96068
# INFO:tensorflow:loss = 4.7399907, step = 476450 (20.155 sec)
# INFO:tensorflow:lr = 0.000102157705 (20.154 sec)
# INFO:tensorflow:global_step/sec: 4.99505
# INFO:tensorflow:loss = 4.7536826, step = 476550 (20.020 sec)
# INFO:tensorflow:lr = 0.0001021857 (20.027 sec)
# INFO:tensorflow:global_step/sec: 4.986
# INFO:tensorflow:loss = 4.8427896, step = 476650 (20.058 sec)
# INFO:tensorflow:lr = 0.00010221371 (20.052 sec)
# INFO:tensorflow:global_step/sec: 4.99131
# INFO:tensorflow:loss = 4.9754953, step = 476750 (20.033 sec)
# INFO:tensorflow:lr = 0.000102241705 (20.038 sec)
# INFO:tensorflow:global_step/sec: 4.98665
# INFO:tensorflow:loss = 4.7605524, step = 476850 (20.055 sec)
# INFO:tensorflow:lr = 0.00010226971 (20.050 sec)
# INFO:tensorflow:global_step/sec: 5.03214
# INFO:tensorflow:loss = 4.893359, step = 476950 (19.873 sec)
# INFO:tensorflow:lr = 0.00010229771 (19.872 sec)
# INFO:tensorflow:global_step/sec: 5.03105
# INFO:tensorflow:loss = 4.670141, step = 477050 (19.876 sec)
# INFO:tensorflow:lr = 0.00010232571 (19.876 sec)
# INFO:tensorflow:global_step/sec: 5.03689
# INFO:tensorflow:loss = 4.668399, step = 477150 (19.855 sec)
# INFO:tensorflow:lr = 0.00010235371 (19.854 sec)
# INFO:tensorflow:global_step/sec: 5.05859
# INFO:tensorflow:loss = 4.9618406, step = 477250 (19.768 sec)
# INFO:tensorflow:lr = 0.00010238171 (19.769 sec)
# INFO:tensorflow:global_step/sec: 5.09384
# INFO:tensorflow:loss = 4.7575173, step = 477350 (19.631 sec)
# INFO:tensorflow:lr = 0.000102409715 (19.631 sec)
# INFO:tensorflow:global_step/sec: 4.98363
# INFO:tensorflow:loss = 4.838988, step = 477450 (20.066 sec)
# INFO:tensorflow:lr = 0.00010243771 (20.068 sec)
# INFO:tensorflow:global_step/sec: 5.07886
# INFO:tensorflow:loss = 4.7795763, step = 477550 (19.687 sec)
# INFO:tensorflow:lr = 0.0001024657 (19.686 sec)
# INFO:tensorflow:global_step/sec: 5.06825
# INFO:tensorflow:loss = 4.862156, step = 477650 (19.733 sec)
# INFO:tensorflow:lr = 0.000102493716 (19.732 sec)
# INFO:tensorflow:global_step/sec: 5.05576
# INFO:tensorflow:loss = 4.8420067, step = 477750 (19.780 sec)
# INFO:tensorflow:lr = 0.000102521706 (19.781 sec)
# INFO:tensorflow:global_step/sec: 5.07929
# INFO:tensorflow:loss = 4.8398004, step = 477850 (19.685 sec)
# INFO:tensorflow:lr = 0.000102549704 (19.684 sec)
# INFO:tensorflow:global_step/sec: 5.08561
# INFO:tensorflow:loss = 4.7570105, step = 477950 (19.664 sec)
# INFO:tensorflow:lr = 0.00010257771 (19.666 sec)
# INFO:tensorflow:global_step/sec: 5.09369
# INFO:tensorflow:loss = 4.8740582, step = 478050 (19.633 sec)
# INFO:tensorflow:lr = 0.00010260571 (19.631 sec)
# INFO:tensorflow:global_step/sec: 5.12173
# INFO:tensorflow:loss = 4.7648005, step = 478150 (19.525 sec)
# INFO:tensorflow:lr = 0.00010263371 (19.525 sec)
# INFO:tensorflow:global_step/sec: 5.06853
# INFO:tensorflow:loss = 4.793591, step = 478250 (19.727 sec)
# INFO:tensorflow:lr = 0.00010266171 (19.728 sec)
# INFO:tensorflow:global_step/sec: 5.08994
# INFO:tensorflow:loss = 4.8006096, step = 478350 (19.651 sec)
# INFO:tensorflow:lr = 0.00010268971 (19.650 sec)
# INFO:tensorflow:global_step/sec: 5.12959
# INFO:tensorflow:loss = 4.7846327, step = 478450 (19.493 sec)
# INFO:tensorflow:lr = 0.00010271771 (19.494 sec)
# INFO:tensorflow:global_step/sec: 5.15034
# INFO:tensorflow:loss = 4.7795515, step = 478550 (19.416 sec)
# INFO:tensorflow:lr = 0.00010274571 (19.417 sec)
# INFO:tensorflow:global_step/sec: 5.12708
# INFO:tensorflow:loss = 4.821649, step = 478650 (19.503 sec)
# INFO:tensorflow:lr = 0.000102773716 (19.504 sec)
# INFO:tensorflow:global_step/sec: 5.07316
# INFO:tensorflow:loss = 4.6419873, step = 478750 (19.712 sec)
# INFO:tensorflow:lr = 0.000102801714 (19.711 sec)
# INFO:tensorflow:global_step/sec: 5.09497
# INFO:tensorflow:loss = 4.91121, step = 478850 (19.625 sec)
# INFO:tensorflow:lr = 0.00010282971 (19.625 sec)
# INFO:tensorflow:global_step/sec: 5.1187
# INFO:tensorflow:loss = 4.8033166, step = 478950 (19.539 sec)
# INFO:tensorflow:lr = 0.00010285772 (19.539 sec)
# INFO:tensorflow:global_step/sec: 5.014
# INFO:tensorflow:loss = 4.749983, step = 479050 (19.942 sec)
# INFO:tensorflow:lr = 0.000102885715 (19.944 sec)
# INFO:tensorflow:global_step/sec: 5.08681
# INFO:tensorflow:loss = 4.7962947, step = 479150 (19.659 sec)
# INFO:tensorflow:lr = 0.00010291372 (19.659 sec)
# INFO:tensorflow:global_step/sec: 5.11539
# INFO:tensorflow:loss = 4.7498813, step = 479250 (19.551 sec)
# INFO:tensorflow:lr = 0.00010294172 (19.549 sec)
# INFO:tensorflow:global_step/sec: 5.07071
# INFO:tensorflow:loss = 4.705895, step = 479350 (19.721 sec)
# INFO:tensorflow:lr = 0.000102969716 (19.720 sec)
# INFO:tensorflow:global_step/sec: 5.1123
# INFO:tensorflow:loss = 4.858578, step = 479450 (19.562 sec)
# INFO:tensorflow:lr = 0.00010299772 (19.562 sec)
# INFO:tensorflow:global_step/sec: 5.088
# INFO:tensorflow:loss = 4.747156, step = 479550 (19.654 sec)
# INFO:tensorflow:lr = 0.00010302571 (19.655 sec)
# INFO:tensorflow:global_step/sec: 5.15245
# INFO:tensorflow:loss = 4.776051, step = 479650 (19.409 sec)
# INFO:tensorflow:lr = 0.00010305371 (19.407 sec)
# INFO:tensorflow:global_step/sec: 5.13807
# INFO:tensorflow:loss = 4.8339887, step = 479750 (19.463 sec)
# INFO:tensorflow:lr = 0.00010308172 (19.463 sec)
# INFO:tensorflow:global_step/sec: 5.1456
# INFO:tensorflow:loss = 4.7888093, step = 479850 (19.432 sec)
# INFO:tensorflow:lr = 0.00010310971 (19.434 sec)
# INFO:tensorflow:global_step/sec: 5.09356
# INFO:tensorflow:loss = 4.730523, step = 479950 (19.632 sec)
# INFO:tensorflow:lr = 0.00010313772 (19.632 sec)
# INFO:tensorflow:global_step/sec: 5.11705
# INFO:tensorflow:loss = 4.839674, step = 480050 (19.541 sec)
# INFO:tensorflow:lr = 0.000103165716 (19.543 sec)
# INFO:tensorflow:global_step/sec: 5.1504
# INFO:tensorflow:loss = 4.848349, step = 480150 (19.421 sec)
# INFO:tensorflow:lr = 0.00010319371 (19.418 sec)
# INFO:tensorflow:global_step/sec: 5.1092
# INFO:tensorflow:loss = 4.7377224, step = 480250 (19.568 sec)
# INFO:tensorflow:lr = 0.00010322172 (19.569 sec)
# INFO:tensorflow:global_step/sec: 5.08959
# INFO:tensorflow:loss = 4.90183, step = 480350 (19.652 sec)
# INFO:tensorflow:lr = 0.00010324972 (19.650 sec)
# INFO:tensorflow:global_step/sec: 5.15437
# INFO:tensorflow:loss = 4.665814, step = 480450 (19.401 sec)
# INFO:tensorflow:lr = 0.00010327772 (19.402 sec)
# INFO:tensorflow:global_step/sec: 5.10013
# INFO:tensorflow:loss = 4.887159, step = 480550 (19.607 sec)
# INFO:tensorflow:lr = 0.00010330572 (19.606 sec)
# INFO:tensorflow:global_step/sec: 5.05997
# INFO:tensorflow:loss = 4.7595196, step = 480650 (19.760 sec)
# INFO:tensorflow:lr = 0.00010333372 (19.761 sec)
# INFO:tensorflow:global_step/sec: 5.09348
# INFO:tensorflow:loss = 4.776102, step = 480750 (19.638 sec)
# INFO:tensorflow:lr = 0.00010336172 (19.640 sec)
# INFO:tensorflow:global_step/sec: 5.11453
# INFO:tensorflow:loss = 4.767755, step = 480850 (19.548 sec)
# INFO:tensorflow:lr = 0.00010338972 (19.547 sec)
# INFO:tensorflow:global_step/sec: 5.07066
# INFO:tensorflow:loss = 4.958934, step = 480950 (19.724 sec)
# INFO:tensorflow:lr = 0.000103417726 (19.724 sec)
# INFO:tensorflow:global_step/sec: 5.09481
# INFO:tensorflow:loss = 4.881713, step = 481050 (19.625 sec)
# INFO:tensorflow:lr = 0.000103445724 (19.628 sec)
# INFO:tensorflow:global_step/sec: 5.06746
# INFO:tensorflow:loss = 4.851632, step = 481150 (19.734 sec)
# INFO:tensorflow:lr = 0.00010347372 (19.730 sec)
# INFO:tensorflow:global_step/sec: 5.08844
# INFO:tensorflow:loss = 4.926623, step = 481250 (19.652 sec)
# INFO:tensorflow:lr = 0.00010350173 (19.654 sec)
# INFO:tensorflow:global_step/sec: 5.08933
# INFO:tensorflow:loss = 4.9162507, step = 481350 (19.651 sec)
# INFO:tensorflow:lr = 0.000103529725 (19.650 sec)
# INFO:tensorflow:global_step/sec: 5.11757
# INFO:tensorflow:loss = 4.687455, step = 481450 (19.541 sec)
# INFO:tensorflow:lr = 0.000103557715 (19.541 sec)
# INFO:tensorflow:global_step/sec: 5.06581
# INFO:tensorflow:loss = 4.910492, step = 481550 (19.741 sec)
# INFO:tensorflow:lr = 0.00010358573 (19.741 sec)
# INFO:tensorflow:global_step/sec: 5.07075
# INFO:tensorflow:loss = 4.8723774, step = 481650 (19.721 sec)
# INFO:tensorflow:lr = 0.00010361372 (19.721 sec)
# INFO:tensorflow:global_step/sec: 5.15075
# INFO:tensorflow:loss = 4.627282, step = 481750 (19.415 sec)
# INFO:tensorflow:lr = 0.00010364173 (19.415 sec)
# INFO:tensorflow:global_step/sec: 5.1319
# INFO:tensorflow:loss = 4.7659955, step = 481850 (19.485 sec)
# INFO:tensorflow:lr = 0.00010366972 (19.486 sec)
# INFO:tensorflow:global_step/sec: 5.06573
# INFO:tensorflow:loss = 4.9163175, step = 481950 (19.740 sec)
# INFO:tensorflow:lr = 0.00010369772 (19.740 sec)
# INFO:tensorflow:global_step/sec: 5.09704
# INFO:tensorflow:loss = 4.738111, step = 482050 (19.620 sec)
# INFO:tensorflow:lr = 0.000103725724 (19.619 sec)
# INFO:tensorflow:global_step/sec: 5.09627
# INFO:tensorflow:loss = 4.7693114, step = 482150 (19.624 sec)
# INFO:tensorflow:lr = 0.00010375372 (19.623 sec)
# INFO:tensorflow:global_step/sec: 5.03832
# INFO:tensorflow:loss = 4.8758965, step = 482250 (19.845 sec)
# INFO:tensorflow:lr = 0.00010378173 (19.846 sec)
# INFO:tensorflow:global_step/sec: 5.1002
# INFO:tensorflow:loss = 4.762947, step = 482350 (19.610 sec)
# INFO:tensorflow:lr = 0.000103809725 (19.610 sec)
# INFO:tensorflow:global_step/sec: 5.04614
# INFO:tensorflow:loss = 4.76892, step = 482450 (19.814 sec)
# INFO:tensorflow:lr = 0.00010383772 (19.814 sec)
# INFO:tensorflow:global_step/sec: 5.11289
# INFO:tensorflow:loss = 4.871385, step = 482550 (19.560 sec)
# INFO:tensorflow:lr = 0.00010386573 (19.560 sec)
# INFO:tensorflow:global_step/sec: 5.08942
# INFO:tensorflow:loss = 4.7484407, step = 482650 (19.647 sec)
# INFO:tensorflow:lr = 0.000103893726 (19.649 sec)
# INFO:tensorflow:global_step/sec: 5.05849
# INFO:tensorflow:loss = 4.917001, step = 482750 (19.768 sec)
# INFO:tensorflow:lr = 0.00010392173 (19.770 sec)
# INFO:tensorflow:global_step/sec: 4.94353
# INFO:tensorflow:loss = 4.6207833, step = 482850 (20.229 sec)
# INFO:tensorflow:lr = 0.00010394973 (20.226 sec)
# INFO:tensorflow:global_step/sec: 4.99251
# INFO:tensorflow:loss = 4.706682, step = 482950 (20.031 sec)
# INFO:tensorflow:lr = 0.00010397773 (20.033 sec)
# INFO:tensorflow:global_step/sec: 5.02492
# INFO:tensorflow:loss = 4.847261, step = 483050 (19.899 sec)
# INFO:tensorflow:lr = 0.00010400573 (19.900 sec)
# INFO:tensorflow:global_step/sec: 5.03568
# INFO:tensorflow:loss = 4.907348, step = 483150 (19.861 sec)
# INFO:tensorflow:lr = 0.00010403373 (19.859 sec)
# INFO:tensorflow:global_step/sec: 4.98738
# INFO:tensorflow:loss = 4.9059615, step = 483250 (20.050 sec)
# INFO:tensorflow:lr = 0.00010406172 (20.051 sec)
# INFO:tensorflow:global_step/sec: 5.04676
# INFO:tensorflow:loss = 4.7898216, step = 483350 (19.815 sec)
# INFO:tensorflow:lr = 0.00010408973 (19.815 sec)
# INFO:tensorflow:global_step/sec: 5.07865
# INFO:tensorflow:loss = 4.9172926, step = 483450 (19.691 sec)
# INFO:tensorflow:lr = 0.00010411773 (19.691 sec)
# INFO:tensorflow:global_step/sec: 5.08082
# INFO:tensorflow:loss = 4.7525887, step = 483550 (19.683 sec)
# INFO:tensorflow:lr = 0.000104145736 (19.683 sec)
# INFO:tensorflow:global_step/sec: 5.04789
# INFO:tensorflow:loss = 4.6663713, step = 483650 (19.809 sec)
# INFO:tensorflow:lr = 0.00010417373 (19.809 sec)
# INFO:tensorflow:global_step/sec: 4.95781
# INFO:tensorflow:loss = 4.9097576, step = 483750 (20.167 sec)
# INFO:tensorflow:lr = 0.000104201725 (20.169 sec)
# INFO:tensorflow:global_step/sec: 4.94131
# INFO:tensorflow:loss = 4.7629724, step = 483850 (20.241 sec)
# INFO:tensorflow:lr = 0.00010422974 (20.239 sec)
# INFO:tensorflow:global_step/sec: 4.87964
# INFO:tensorflow:loss = 4.868005, step = 483950 (20.490 sec)
# INFO:tensorflow:lr = 0.00010425773 (20.491 sec)
# INFO:tensorflow:global_step/sec: 4.88631
# INFO:tensorflow:loss = 4.9228487, step = 484050 (20.470 sec)
# INFO:tensorflow:lr = 0.00010428573 (20.468 sec)
# INFO:tensorflow:global_step/sec: 4.95482
# INFO:tensorflow:loss = 4.870129, step = 484150 (20.181 sec)
# INFO:tensorflow:lr = 0.00010431373 (20.181 sec)
# INFO:tensorflow:global_step/sec: 4.82571
# INFO:tensorflow:loss = 4.8939, step = 484250 (20.723 sec)
# INFO:tensorflow:lr = 0.00010434173 (20.723 sec)
# INFO:tensorflow:global_step/sec: 5.02919
# INFO:tensorflow:loss = 4.7891774, step = 484350 (19.881 sec)
# INFO:tensorflow:lr = 0.000104369734 (19.885 sec)
# INFO:tensorflow:global_step/sec: 5.08201
# INFO:tensorflow:loss = 4.8122234, step = 484450 (19.681 sec)
# INFO:tensorflow:lr = 0.00010439773 (19.677 sec)
# INFO:tensorflow:global_step/sec: 5.05447
# INFO:tensorflow:loss = 4.79432, step = 484550 (19.783 sec)
# INFO:tensorflow:lr = 0.00010442574 (19.784 sec)
# INFO:tensorflow:global_step/sec: 5.06629
# INFO:tensorflow:loss = 4.6522193, step = 484650 (19.740 sec)
# INFO:tensorflow:lr = 0.000104453735 (19.739 sec)
# INFO:tensorflow:global_step/sec: 5.11931
# INFO:tensorflow:loss = 4.7925973, step = 484750 (19.532 sec)
# INFO:tensorflow:lr = 0.00010448173 (19.531 sec)
# INFO:tensorflow:global_step/sec: 5.06376
# INFO:tensorflow:loss = 4.548668, step = 484850 (19.747 sec)
# INFO:tensorflow:lr = 0.00010450974 (19.750 sec)
# INFO:tensorflow:global_step/sec: 5.08498
# INFO:tensorflow:loss = 4.850411, step = 484950 (19.668 sec)
# INFO:tensorflow:lr = 0.000104537736 (19.665 sec)
# INFO:tensorflow:global_step/sec: 5.10707
# INFO:tensorflow:loss = 4.9048033, step = 485050 (19.581 sec)
# INFO:tensorflow:lr = 0.00010456573 (19.581 sec)
# INFO:tensorflow:global_step/sec: 5.07861
# INFO:tensorflow:loss = 4.716598, step = 485150 (19.690 sec)
# INFO:tensorflow:lr = 0.00010459374 (19.692 sec)
# INFO:tensorflow:global_step/sec: 5.01677
# INFO:tensorflow:loss = 4.803493, step = 485250 (19.932 sec)
# INFO:tensorflow:lr = 0.00010462174 (19.929 sec)
# INFO:tensorflow:global_step/sec: 4.76649
# INFO:tensorflow:loss = 4.8007083, step = 485350 (20.982 sec)
# INFO:tensorflow:lr = 0.00010464974 (20.982 sec)
# INFO:tensorflow:global_step/sec: 4.8075
# INFO:tensorflow:loss = 4.852951, step = 485450 (20.797 sec)
# INFO:tensorflow:lr = 0.00010467774 (20.800 sec)
# INFO:tensorflow:global_step/sec: 4.83123
# INFO:tensorflow:loss = 4.8222685, step = 485550 (20.700 sec)
# INFO:tensorflow:lr = 0.00010470573 (20.698 sec)
# INFO:tensorflow:global_step/sec: 4.8197
# INFO:tensorflow:loss = 4.7884474, step = 485650 (20.750 sec)
# INFO:tensorflow:lr = 0.00010473374 (20.750 sec)
# INFO:tensorflow:global_step/sec: 4.83209
# INFO:tensorflow:loss = 4.9026093, step = 485750 (20.695 sec)
# INFO:tensorflow:lr = 0.00010476173 (20.695 sec)
# INFO:tensorflow:global_step/sec: 4.86092
# INFO:tensorflow:loss = 4.9571285, step = 485850 (20.572 sec)
# INFO:tensorflow:lr = 0.000104789746 (20.573 sec)
# INFO:tensorflow:global_step/sec: 4.77437
# INFO:tensorflow:loss = 4.8014984, step = 485950 (20.947 sec)
# INFO:tensorflow:lr = 0.00010481774 (20.946 sec)
# INFO:tensorflow:global_step/sec: 4.74293
# INFO:tensorflow:loss = 4.9170585, step = 486050 (21.080 sec)
# INFO:tensorflow:lr = 0.000104845734 (21.080 sec)
# INFO:tensorflow:global_step/sec: 4.82636
# INFO:tensorflow:loss = 4.842814, step = 486150 (20.723 sec)
# INFO:tensorflow:lr = 0.00010487374 (20.724 sec)
# INFO:tensorflow:global_step/sec: 4.72535
# INFO:tensorflow:loss = 4.784855, step = 486250 (21.158 sec)
# INFO:tensorflow:lr = 0.00010490174 (21.160 sec)
# INFO:tensorflow:global_step/sec: 4.75307
# INFO:tensorflow:loss = 4.852285, step = 486350 (21.040 sec)
# INFO:tensorflow:lr = 0.00010492974 (21.038 sec)
# INFO:tensorflow:global_step/sec: 4.73299
# INFO:tensorflow:loss = 4.79431, step = 486450 (21.133 sec)
# INFO:tensorflow:lr = 0.00010495774 (21.132 sec)
# INFO:tensorflow:global_step/sec: 4.71306
# INFO:tensorflow:loss = 4.71029, step = 486550 (21.216 sec)
# INFO:tensorflow:lr = 0.00010498574 (21.216 sec)
# INFO:tensorflow:global_step/sec: 4.71914
# INFO:tensorflow:loss = 4.8990245, step = 486650 (21.192 sec)
# INFO:tensorflow:lr = 0.00010501374 (21.192 sec)
# INFO:tensorflow:global_step/sec: 4.75344
# INFO:tensorflow:loss = 4.804822, step = 486750 (21.032 sec)
# INFO:tensorflow:lr = 0.00010504174 (21.032 sec)
# INFO:tensorflow:global_step/sec: 4.65759
# INFO:tensorflow:loss = 4.880676, step = 486850 (21.474 sec)
# INFO:tensorflow:lr = 0.00010506974 (21.474 sec)
# INFO:tensorflow:global_step/sec: 4.68099
# INFO:tensorflow:loss = 4.7105846, step = 486950 (21.364 sec)
# INFO:tensorflow:lr = 0.000105097744 (21.364 sec)
# INFO:tensorflow:global_step/sec: 4.71987
# INFO:tensorflow:loss = 4.849503, step = 487050 (21.184 sec)
# INFO:tensorflow:lr = 0.00010512574 (21.186 sec)
# INFO:tensorflow:global_step/sec: 4.87883
# INFO:tensorflow:loss = 4.808903, step = 487150 (20.498 sec)
# INFO:tensorflow:lr = 0.00010515375 (20.496 sec)
# INFO:tensorflow:global_step/sec: 4.89379
# INFO:tensorflow:loss = 4.890233, step = 487250 (20.435 sec)
# INFO:tensorflow:lr = 0.000105181745 (20.434 sec)
# INFO:tensorflow:global_step/sec: 4.94163
# INFO:tensorflow:loss = 4.7190804, step = 487350 (20.236 sec)
# INFO:tensorflow:lr = 0.000105209736 (20.237 sec)
# INFO:tensorflow:global_step/sec: 4.9287
# INFO:tensorflow:loss = 4.6500883, step = 487450 (20.289 sec)
# INFO:tensorflow:lr = 0.00010523775 (20.289 sec)
# INFO:tensorflow:global_step/sec: 4.94991
# INFO:tensorflow:loss = 4.8723154, step = 487550 (20.200 sec)
# INFO:tensorflow:lr = 0.000105265746 (20.200 sec)
# INFO:tensorflow:global_step/sec: 5.04932
# INFO:tensorflow:loss = 4.8854384, step = 487650 (19.806 sec)
# INFO:tensorflow:lr = 0.00010529375 (19.806 sec)
# INFO:tensorflow:global_step/sec: 5.05384
# INFO:tensorflow:loss = 4.814858, step = 487750 (19.789 sec)
# INFO:tensorflow:lr = 0.00010532174 (19.789 sec)
# INFO:tensorflow:global_step/sec: 5.05508
# INFO:tensorflow:loss = 4.886373, step = 487850 (19.779 sec)
# INFO:tensorflow:lr = 0.00010534974 (19.780 sec)
# INFO:tensorflow:global_step/sec: 5.06524
# INFO:tensorflow:loss = 4.842809, step = 487950 (19.743 sec)
# INFO:tensorflow:lr = 0.00010537775 (19.742 sec)
# INFO:tensorflow:global_step/sec: 5.09819
# INFO:tensorflow:loss = 4.8544674, step = 488050 (19.618 sec)
# INFO:tensorflow:lr = 0.00010540574 (19.617 sec)
# INFO:tensorflow:global_step/sec: 5.10464
# INFO:tensorflow:loss = 4.9059753, step = 488150 (19.587 sec)
# INFO:tensorflow:lr = 0.00010543375 (19.587 sec)
# INFO:tensorflow:global_step/sec: 5.10273
# INFO:tensorflow:loss = 4.8316607, step = 488250 (19.596 sec)
# INFO:tensorflow:lr = 0.000105461746 (19.597 sec)
# INFO:tensorflow:global_step/sec: 4.97162
# INFO:tensorflow:loss = 4.8497734, step = 488350 (20.113 sec)
# INFO:tensorflow:lr = 0.000105489744 (20.112 sec)
# INFO:tensorflow:global_step/sec: 5.08317
# INFO:tensorflow:loss = 4.6325817, step = 488450 (19.673 sec)
# INFO:tensorflow:lr = 0.00010551775 (19.673 sec)
# INFO:tensorflow:global_step/sec: 5.09312
# INFO:tensorflow:loss = 4.823402, step = 488550 (19.639 sec)
# INFO:tensorflow:lr = 0.00010554575 (19.639 sec)
# INFO:tensorflow:global_step/sec: 5.11322
# INFO:tensorflow:loss = 4.800382, step = 488650 (19.556 sec)
# INFO:tensorflow:lr = 0.000105573745 (19.556 sec)
# INFO:tensorflow:global_step/sec: 5.02479
# INFO:tensorflow:loss = 4.6652923, step = 488750 (19.901 sec)
# INFO:tensorflow:lr = 0.00010560175 (19.901 sec)
# INFO:tensorflow:global_step/sec: 5.08282
# INFO:tensorflow:loss = 4.8099174, step = 488850 (19.674 sec)
# INFO:tensorflow:lr = 0.00010562975 (19.675 sec)
# INFO:tensorflow:global_step/sec: 5.06941
# INFO:tensorflow:loss = 4.7979198, step = 488950 (19.726 sec)
# INFO:tensorflow:lr = 0.00010565775 (19.726 sec)
# INFO:tensorflow:global_step/sec: 5.07403
# INFO:tensorflow:loss = 4.6625047, step = 489050 (19.707 sec)
# INFO:tensorflow:lr = 0.00010568575 (19.707 sec)
# INFO:tensorflow:global_step/sec: 5.07011
# INFO:tensorflow:loss = 4.8661613, step = 489150 (19.725 sec)
# INFO:tensorflow:lr = 0.00010571375 (19.724 sec)
# INFO:tensorflow:global_step/sec: 5.05778
# INFO:tensorflow:loss = 4.7951465, step = 489250 (19.773 sec)
# INFO:tensorflow:lr = 0.000105741754 (19.773 sec)
# INFO:tensorflow:global_step/sec: 5.06692
# INFO:tensorflow:loss = 4.8516736, step = 489350 (19.735 sec)
# INFO:tensorflow:lr = 0.00010576975 (19.735 sec)
# INFO:tensorflow:global_step/sec: 5.06621
# INFO:tensorflow:loss = 5.078469, step = 489450 (19.738 sec)
# INFO:tensorflow:lr = 0.00010579776 (19.738 sec)
# INFO:tensorflow:global_step/sec: 5.06159
# INFO:tensorflow:loss = 4.7786045, step = 489550 (19.756 sec)
# INFO:tensorflow:lr = 0.000105825755 (19.756 sec)
# INFO:tensorflow:global_step/sec: 5.0189
# INFO:tensorflow:loss = 4.837298, step = 489650 (19.923 sec)
# INFO:tensorflow:lr = 0.000105853745 (19.924 sec)
# INFO:tensorflow:global_step/sec: 5.10137
# INFO:tensorflow:loss = 4.7656255, step = 489750 (19.606 sec)
# INFO:tensorflow:lr = 0.00010588176 (19.607 sec)
# INFO:tensorflow:global_step/sec: 5.06471
# INFO:tensorflow:loss = 4.859196, step = 489850 (19.740 sec)
# INFO:tensorflow:lr = 0.00010590975 (19.741 sec)
# INFO:tensorflow:global_step/sec: 4.9554
# INFO:tensorflow:loss = 4.8086114, step = 489950 (20.185 sec)
# INFO:tensorflow:lr = 0.00010593776 (20.181 sec)
# INFO:tensorflow:global_step/sec: 5.03987
# INFO:tensorflow:loss = 4.894604, step = 490050 (19.839 sec)
# INFO:tensorflow:lr = 0.00010596575 (19.841 sec)
# INFO:tensorflow:global_step/sec: 5.06507
# INFO:tensorflow:loss = 4.8063707, step = 490150 (19.745 sec)
# INFO:tensorflow:lr = 0.00010599375 (19.743 sec)
# INFO:tensorflow:global_step/sec: 5.04648
# INFO:tensorflow:loss = 4.886829, step = 490250 (19.814 sec)
# INFO:tensorflow:lr = 0.000106021755 (19.815 sec)
# INFO:tensorflow:global_step/sec: 5.04488
# INFO:tensorflow:loss = 4.9250727, step = 490350 (19.823 sec)
# INFO:tensorflow:lr = 0.00010604975 (19.823 sec)
# INFO:tensorflow:global_step/sec: 5.08364
# INFO:tensorflow:loss = 5.016846, step = 490450 (19.669 sec)
# INFO:tensorflow:lr = 0.00010607775 (19.670 sec)
# INFO:tensorflow:global_step/sec: 5.10719
# INFO:tensorflow:loss = 4.729321, step = 490550 (19.582 sec)
# INFO:tensorflow:lr = 0.000106105756 (19.581 sec)
# INFO:tensorflow:global_step/sec: 5.1102
# INFO:tensorflow:loss = 4.89482, step = 490650 (19.567 sec)
# INFO:tensorflow:lr = 0.00010613375 (19.569 sec)
# INFO:tensorflow:global_step/sec: 5.06842
# INFO:tensorflow:loss = 4.7609706, step = 490750 (19.729 sec)
# INFO:tensorflow:lr = 0.00010616176 (19.728 sec)
# INFO:tensorflow:global_step/sec: 5.01108
# INFO:tensorflow:loss = 4.796869, step = 490850 (19.958 sec)
# INFO:tensorflow:lr = 0.00010618976 (19.957 sec)
# INFO:tensorflow:global_step/sec: 5.00088
# INFO:tensorflow:loss = 4.7382154, step = 490950 (19.993 sec)
# INFO:tensorflow:lr = 0.000106217754 (19.995 sec)
# INFO:tensorflow:global_step/sec: 5.04275
# INFO:tensorflow:loss = 4.845927, step = 491050 (19.837 sec)
# INFO:tensorflow:lr = 0.00010624576 (19.835 sec)
# INFO:tensorflow:global_step/sec: 4.9758
# INFO:tensorflow:loss = 4.7087693, step = 491150 (20.094 sec)
# INFO:tensorflow:lr = 0.00010627376 (20.094 sec)
# INFO:tensorflow:global_step/sec: 4.94596
# INFO:tensorflow:loss = 4.7962236, step = 491250 (20.218 sec)
# INFO:tensorflow:lr = 0.00010630176 (20.220 sec)
# INFO:tensorflow:global_step/sec: 4.96027
# INFO:tensorflow:loss = 4.759451, step = 491350 (20.160 sec)
# INFO:tensorflow:lr = 0.00010632976 (20.158 sec)
# INFO:tensorflow:global_step/sec: 4.94384
# INFO:tensorflow:loss = 4.66556, step = 491450 (20.228 sec)
# INFO:tensorflow:lr = 0.00010635776 (20.229 sec)
# INFO:tensorflow:global_step/sec: 4.94222
# INFO:tensorflow:loss = 4.7386885, step = 491550 (20.234 sec)
# INFO:tensorflow:lr = 0.00010638576 (20.233 sec)
# INFO:tensorflow:global_step/sec: 5.02966
# INFO:tensorflow:loss = 4.715433, step = 491650 (19.879 sec)
# INFO:tensorflow:lr = 0.00010641376 (19.883 sec)
# INFO:tensorflow:global_step/sec: 5.06297
# INFO:tensorflow:loss = 4.731926, step = 491750 (19.752 sec)
# INFO:tensorflow:lr = 0.00010644177 (19.749 sec)
# INFO:tensorflow:global_step/sec: 5.01016
# INFO:tensorflow:loss = 4.587081, step = 491850 (19.958 sec)
# INFO:tensorflow:lr = 0.000106469764 (19.958 sec)
# INFO:tensorflow:global_step/sec: 5.05698
# INFO:tensorflow:loss = 4.816843, step = 491950 (19.777 sec)
# INFO:tensorflow:lr = 0.000106497755 (19.777 sec)
# INFO:tensorflow:global_step/sec: 5.02794
# INFO:tensorflow:loss = 4.823773, step = 492050 (19.886 sec)
# INFO:tensorflow:lr = 0.00010652577 (19.889 sec)
# INFO:tensorflow:global_step/sec: 5.06373
# INFO:tensorflow:loss = 4.8137994, step = 492150 (19.751 sec)
# INFO:tensorflow:lr = 0.00010655376 (19.749 sec)
# INFO:tensorflow:global_step/sec: 5.09606
# INFO:tensorflow:loss = 4.681805, step = 492250 (19.622 sec)
# INFO:tensorflow:lr = 0.000106581756 (19.624 sec)
# INFO:tensorflow:global_step/sec: 5.06941
# INFO:tensorflow:loss = 4.7336044, step = 492350 (19.727 sec)
# INFO:tensorflow:lr = 0.00010660976 (19.726 sec)
# INFO:tensorflow:global_step/sec: 4.99954
# INFO:tensorflow:loss = 4.6144834, step = 492450 (20.004 sec)
# INFO:tensorflow:lr = 0.00010663776 (20.004 sec)
# INFO:tensorflow:global_step/sec: 5.06238
# INFO:tensorflow:loss = 4.81466, step = 492550 (19.752 sec)
# INFO:tensorflow:lr = 0.000106665764 (19.752 sec)
# INFO:tensorflow:global_step/sec: 5.10874
# INFO:tensorflow:loss = 4.7770114, step = 492650 (19.570 sec)
# INFO:tensorflow:lr = 0.00010669376 (19.573 sec)
# INFO:tensorflow:global_step/sec: 5.11192
# INFO:tensorflow:loss = 4.710775, step = 492750 (19.563 sec)
# INFO:tensorflow:lr = 0.00010672176 (19.562 sec)
# INFO:tensorflow:global_step/sec: 5.04184
# INFO:tensorflow:loss = 4.648829, step = 492850 (19.835 sec)
# INFO:tensorflow:lr = 0.000106749765 (19.834 sec)
# INFO:tensorflow:global_step/sec: 5.09048
# INFO:tensorflow:loss = 4.759885, step = 492950 (19.646 sec)
# INFO:tensorflow:lr = 0.00010677776 (19.645 sec)
# INFO:tensorflow:global_step/sec: 4.9938
# INFO:tensorflow:loss = 4.804322, step = 493050 (20.026 sec)
# INFO:tensorflow:lr = 0.00010680577 (20.027 sec)
# INFO:tensorflow:global_step/sec: 5.0637
# INFO:tensorflow:loss = 4.796227, step = 493150 (19.747 sec)
# INFO:tensorflow:lr = 0.000106833766 (19.746 sec)
# INFO:tensorflow:global_step/sec: 5.05639
# INFO:tensorflow:loss = 4.739547, step = 493250 (19.777 sec)
# INFO:tensorflow:lr = 0.000106861764 (19.778 sec)
# INFO:tensorflow:global_step/sec: 5.10419
# INFO:tensorflow:loss = 4.884618, step = 493350 (19.591 sec)
# INFO:tensorflow:lr = 0.00010688977 (19.591 sec)
# INFO:tensorflow:global_step/sec: 5.10517
# INFO:tensorflow:loss = 4.68442, step = 493450 (19.589 sec)
# INFO:tensorflow:lr = 0.00010691777 (19.589 sec)
# INFO:tensorflow:global_step/sec: 5.13095
# INFO:tensorflow:loss = 4.8839083, step = 493550 (19.490 sec)
# INFO:tensorflow:lr = 0.00010694577 (19.489 sec)
# INFO:tensorflow:global_step/sec: 5.12675
# INFO:tensorflow:loss = 4.8483496, step = 493650 (19.505 sec)
# INFO:tensorflow:lr = 0.00010697377 (19.505 sec)
# INFO:tensorflow:global_step/sec: 5.16682
# INFO:tensorflow:loss = 4.6986485, step = 493750 (19.355 sec)
# INFO:tensorflow:lr = 0.00010700176 (19.354 sec)
# INFO:tensorflow:global_step/sec: 5.17843
# INFO:tensorflow:loss = 4.8302917, step = 493850 (19.309 sec)
# INFO:tensorflow:lr = 0.00010702977 (19.311 sec)
# INFO:tensorflow:global_step/sec: 5.15794
# INFO:tensorflow:loss = 4.666323, step = 493950 (19.387 sec)
# INFO:tensorflow:lr = 0.000107057764 (19.388 sec)
# INFO:tensorflow:global_step/sec: 5.12425
# INFO:tensorflow:loss = 4.7819, step = 494050 (19.513 sec)
# INFO:tensorflow:lr = 0.00010708576 (19.515 sec)
# INFO:tensorflow:global_step/sec: 5.16503
# INFO:tensorflow:loss = 4.7354064, step = 494150 (19.364 sec)
# INFO:tensorflow:lr = 0.00010711377 (19.362 sec)
# INFO:tensorflow:global_step/sec: 5.15126
# INFO:tensorflow:loss = 4.8590894, step = 494250 (19.411 sec)
# INFO:tensorflow:lr = 0.000107141765 (19.413 sec)
# INFO:tensorflow:global_step/sec: 5.16247
# INFO:tensorflow:loss = 4.66393, step = 494350 (19.369 sec)
# INFO:tensorflow:lr = 0.00010716977 (19.370 sec)
# INFO:tensorflow:global_step/sec: 5.14076
# INFO:tensorflow:loss = 4.7950335, step = 494450 (19.457 sec)
# INFO:tensorflow:lr = 0.00010719777 (19.453 sec)
# INFO:tensorflow:global_step/sec: 5.15283
# INFO:tensorflow:loss = 4.8065906, step = 494550 (19.405 sec)
# INFO:tensorflow:lr = 0.000107225766 (19.407 sec)
# ...
# INFO:tensorflow:loss = 4.890936, step = 582075 (19.763 sec)
# INFO:tensorflow:lr = 0.000104929044 (19.764 sec)
# INFO:tensorflow:global_step/sec: 5.10807
# INFO:tensorflow:loss = 4.810946, step = 582175 (19.577 sec)
# INFO:tensorflow:lr = 0.00010494304 (19.577 sec)
# INFO:tensorflow:global_step/sec: 5.13537
# INFO:tensorflow:loss = 4.705932, step = 582275 (19.471 sec)
# INFO:tensorflow:lr = 0.00010495704 (19.474 sec)
# INFO:tensorflow:global_step/sec: 5.0648
# INFO:tensorflow:loss = 4.7532363, step = 582375 (19.746 sec)
# INFO:tensorflow:lr = 0.00010497104 (19.742 sec)
# INFO:tensorflow:global_step/sec: 5.05467
# INFO:tensorflow:loss = 4.61103, step = 582475 (19.782 sec)
# INFO:tensorflow:lr = 0.00010498504 (19.784 sec)
# INFO:tensorflow:global_step/sec: 5.11152
# INFO:tensorflow:loss = 4.60113, step = 582575 (19.563 sec)
# INFO:tensorflow:lr = 0.00010499904 (19.564 sec)
# INFO:tensorflow:global_step/sec: 5.14583
# INFO:tensorflow:loss = 4.7329597, step = 582675 (19.436 sec)
# INFO:tensorflow:lr = 0.00010501304 (19.434 sec)
# INFO:tensorflow:global_step/sec: 5.12062
# INFO:tensorflow:loss = 4.8042283, step = 582775 (19.527 sec)
# INFO:tensorflow:lr = 0.000105027044 (19.528 sec)
# INFO:tensorflow:global_step/sec: 5.09517
# INFO:tensorflow:loss = 4.7455926, step = 582875 (19.627 sec)
# INFO:tensorflow:lr = 0.00010504104 (19.628 sec)
# INFO:tensorflow:global_step/sec: 5.10864
# INFO:tensorflow:loss = 4.7544403, step = 582975 (19.575 sec)
# INFO:tensorflow:lr = 0.00010505504 (19.575 sec)
# INFO:tensorflow:global_step/sec: 5.16839
# INFO:tensorflow:loss = 4.731277, step = 583075 (19.345 sec)
# INFO:tensorflow:lr = 0.00010506904 (19.346 sec)
# INFO:tensorflow:global_step/sec: 5.13826
# INFO:tensorflow:loss = 4.6989074, step = 583175 (19.462 sec)
# INFO:tensorflow:lr = 0.00010508304 (19.463 sec)
# INFO:tensorflow:global_step/sec: 5.11864
# INFO:tensorflow:loss = 4.869751, step = 583275 (19.540 sec)
# INFO:tensorflow:lr = 0.00010509704 (19.538 sec)
# INFO:tensorflow:global_step/sec: 5.12595
# INFO:tensorflow:loss = 4.7935424, step = 583375 (19.509 sec)
# INFO:tensorflow:lr = 0.000105111045 (19.509 sec)
# INFO:tensorflow:global_step/sec: 5.14928
# INFO:tensorflow:loss = 4.9603724, step = 583475 (19.421 sec)
# INFO:tensorflow:lr = 0.000105125044 (19.421 sec)
# INFO:tensorflow:global_step/sec: 5.16104
# INFO:tensorflow:loss = 4.7618837, step = 583575 (19.374 sec)
# INFO:tensorflow:lr = 0.00010513904 (19.374 sec)
# INFO:tensorflow:global_step/sec: 5.14168
# INFO:tensorflow:loss = 4.8817487, step = 583675 (19.448 sec)
# INFO:tensorflow:lr = 0.00010515304 (19.448 sec)
# INFO:tensorflow:global_step/sec: 5.11382
# INFO:tensorflow:loss = 4.935797, step = 583775 (19.554 sec)
# INFO:tensorflow:lr = 0.00010516704 (19.554 sec)
# INFO:tensorflow:global_step/sec: 5.14313
# INFO:tensorflow:loss = 4.9021263, step = 583875 (19.447 sec)
# INFO:tensorflow:lr = 0.00010518105 (19.446 sec)
# INFO:tensorflow:global_step/sec: 5.03811
# INFO:tensorflow:loss = 4.829121, step = 583975 (19.849 sec)
# INFO:tensorflow:lr = 0.000105195046 (19.848 sec)
# INFO:tensorflow:global_step/sec: 5.14498
# INFO:tensorflow:loss = 4.8494153, step = 584075 (19.436 sec)
# INFO:tensorflow:lr = 0.000105209045 (19.436 sec)
# INFO:tensorflow:global_step/sec: 5.11459
# INFO:tensorflow:loss = 4.842268, step = 584175 (19.551 sec)
# INFO:tensorflow:lr = 0.000105223044 (19.552 sec)
# INFO:tensorflow:global_step/sec: 5.12519
# INFO:tensorflow:loss = 4.8204837, step = 584275 (19.511 sec)
# INFO:tensorflow:lr = 0.00010523704 (19.510 sec)
# INFO:tensorflow:global_step/sec: 5.12952
# INFO:tensorflow:loss = 4.842826, step = 584375 (19.493 sec)
# INFO:tensorflow:lr = 0.00010525105 (19.492 sec)
# INFO:tensorflow:global_step/sec: 5.1203
# INFO:tensorflow:loss = 4.771784, step = 584475 (19.530 sec)
# INFO:tensorflow:lr = 0.00010526505 (19.538 sec)
# INFO:tensorflow:global_step/sec: 5.09073
# INFO:tensorflow:loss = 4.7025275, step = 584575 (19.644 sec)
# INFO:tensorflow:lr = 0.00010527905 (19.638 sec)
# INFO:tensorflow:global_step/sec: 5.13303
# INFO:tensorflow:loss = 4.768401, step = 584675 (19.485 sec)
# INFO:tensorflow:lr = 0.000105293046 (19.484 sec)
# INFO:tensorflow:global_step/sec: 5.16205
# INFO:tensorflow:loss = 4.7708445, step = 584775 (19.371 sec)
# INFO:tensorflow:lr = 0.000105307045 (19.373 sec)
# INFO:tensorflow:global_step/sec: 5.09541
# INFO:tensorflow:loss = 4.6793423, step = 584875 (19.627 sec)
# INFO:tensorflow:lr = 0.00010532104 (19.625 sec)
# INFO:tensorflow:global_step/sec: 5.13211
# INFO:tensorflow:loss = 4.875002, step = 584975 (19.485 sec)
# INFO:tensorflow:lr = 0.00010533504 (19.485 sec)
# INFO:tensorflow:global_step/sec: 5.11911
# INFO:tensorflow:loss = 4.6404123, step = 585075 (19.531 sec)
# INFO:tensorflow:lr = 0.00010534904 (19.536 sec)
# INFO:tensorflow:global_step/sec: 5.13377
# INFO:tensorflow:loss = 4.877546, step = 585175 (19.483 sec)
# INFO:tensorflow:lr = 0.00010536305 (19.477 sec)
# INFO:tensorflow:global_step/sec: 5.16051
# INFO:tensorflow:loss = 4.866316, step = 585275 (19.374 sec)
# INFO:tensorflow:lr = 0.00010537705 (19.375 sec)
# INFO:tensorflow:global_step/sec: 5.10691
# INFO:tensorflow:loss = 4.882547, step = 585375 (19.583 sec)
# INFO:tensorflow:lr = 0.000105391046 (19.583 sec)
# INFO:tensorflow:global_step/sec: 5.16216
# INFO:tensorflow:loss = 4.644015, step = 585475 (19.374 sec)
# INFO:tensorflow:lr = 0.000105405044 (19.374 sec)
# INFO:tensorflow:global_step/sec: 5.02026
# INFO:tensorflow:loss = 4.8914256, step = 585575 (19.917 sec)
# INFO:tensorflow:lr = 0.00010541904 (19.917 sec)
# INFO:tensorflow:global_step/sec: 5.13957
# INFO:tensorflow:loss = 4.8619676, step = 585675 (19.458 sec)
# INFO:tensorflow:lr = 0.00010543305 (19.458 sec)
# INFO:tensorflow:global_step/sec: 5.09006
# INFO:tensorflow:loss = 4.7374225, step = 585775 (19.642 sec)
# INFO:tensorflow:lr = 0.00010544705 (19.643 sec)
# INFO:tensorflow:global_step/sec: 5.14299
# INFO:tensorflow:loss = 4.7931204, step = 585875 (19.444 sec)
# INFO:tensorflow:lr = 0.00010546105 (19.445 sec)
# INFO:tensorflow:global_step/sec: 5.13212
# INFO:tensorflow:loss = 4.7714763, step = 585975 (19.487 sec)
# INFO:tensorflow:lr = 0.000105462444 (19.487 sec)
# INFO:tensorflow:global_step/sec: 5.14844
# INFO:tensorflow:loss = 4.943985, step = 586075 (19.424 sec)
# INFO:tensorflow:lr = 0.000105448446 (19.423 sec)
# INFO:tensorflow:global_step/sec: 4.99016
# INFO:tensorflow:loss = 4.795148, step = 586175 (20.041 sec)
# INFO:tensorflow:lr = 0.00010543445 (20.041 sec)
# INFO:tensorflow:global_step/sec: 5.13245
# INFO:tensorflow:loss = 4.906557, step = 586275 (19.480 sec)
# INFO:tensorflow:lr = 0.00010542045 (19.478 sec)
# INFO:tensorflow:global_step/sec: 5.16645
# INFO:tensorflow:loss = 4.740441, step = 586375 (19.356 sec)
# INFO:tensorflow:lr = 0.00010540644 (19.356 sec)
# INFO:tensorflow:global_step/sec: 5.15109
# INFO:tensorflow:loss = 4.8375735, step = 586475 (19.417 sec)
# INFO:tensorflow:lr = 0.00010539244 (19.417 sec)
# INFO:tensorflow:global_step/sec: 5.1196
# INFO:tensorflow:loss = 4.8149047, step = 586575 (19.533 sec)
# INFO:tensorflow:lr = 0.00010537845 (19.533 sec)
# INFO:tensorflow:global_step/sec: 5.13503
# INFO:tensorflow:loss = 4.746445, step = 586675 (19.471 sec)
# INFO:tensorflow:lr = 0.000105364445 (19.472 sec)
# INFO:tensorflow:global_step/sec: 5.15364
# INFO:tensorflow:loss = 4.7964926, step = 586775 (19.403 sec)
# INFO:tensorflow:lr = 0.000105350446 (19.404 sec)
# INFO:tensorflow:global_step/sec: 5.15304
# INFO:tensorflow:loss = 4.797984, step = 586875 (19.407 sec)
# INFO:tensorflow:lr = 0.00010533645 (19.406 sec)
# INFO:tensorflow:global_step/sec: 5.09841
# INFO:tensorflow:loss = 4.756148, step = 586975 (19.615 sec)
# INFO:tensorflow:lr = 0.00010532245 (19.614 sec)
# INFO:tensorflow:global_step/sec: 5.11557
# INFO:tensorflow:loss = 4.8135295, step = 587075 (19.552 sec)
# INFO:tensorflow:lr = 0.00010530845 (19.550 sec)
# INFO:tensorflow:global_step/sec: 5.03442
# INFO:tensorflow:loss = 4.7865157, step = 587175 (19.860 sec)
# INFO:tensorflow:lr = 0.00010529444 (19.860 sec)
# INFO:tensorflow:global_step/sec: 5.1692
# INFO:tensorflow:loss = 4.722356, step = 587275 (19.345 sec)
# INFO:tensorflow:lr = 0.000105280444 (19.348 sec)
# INFO:tensorflow:global_step/sec: 5.12963
# INFO:tensorflow:loss = 4.656241, step = 587375 (19.497 sec)
# INFO:tensorflow:lr = 0.000105266445 (19.494 sec)
# INFO:tensorflow:global_step/sec: 5.12777
# INFO:tensorflow:loss = 4.7795777, step = 587475 (19.502 sec)
# INFO:tensorflow:lr = 0.000105252446 (19.501 sec)
# INFO:tensorflow:global_step/sec: 5.11998
# INFO:tensorflow:loss = 4.955843, step = 587575 (19.532 sec)
# INFO:tensorflow:lr = 0.00010523845 (19.533 sec)
# INFO:tensorflow:global_step/sec: 5.14086
# INFO:tensorflow:loss = 4.8504777, step = 587675 (19.449 sec)
# INFO:tensorflow:lr = 0.00010522444 (19.450 sec)
# INFO:tensorflow:global_step/sec: 5.18564
# INFO:tensorflow:loss = 4.724047, step = 587775 (19.285 sec)
# INFO:tensorflow:lr = 0.00010521044 (19.284 sec)
# INFO:tensorflow:global_step/sec: 5.10395
# INFO:tensorflow:loss = 4.9300528, step = 587875 (19.593 sec)
# INFO:tensorflow:lr = 0.00010519644 (19.593 sec)
# INFO:tensorflow:global_step/sec: 5.12749
# INFO:tensorflow:loss = 4.7038484, step = 587975 (19.503 sec)
# INFO:tensorflow:lr = 0.000105182444 (19.503 sec)
# INFO:tensorflow:global_step/sec: 5.13584
# INFO:tensorflow:loss = 4.7842503, step = 588075 (19.471 sec)
# INFO:tensorflow:lr = 0.000105168445 (19.471 sec)
# INFO:tensorflow:global_step/sec: 5.11921
# INFO:tensorflow:loss = 4.8588276, step = 588175 (19.531 sec)
# INFO:tensorflow:lr = 0.00010515444 (19.535 sec)
# INFO:tensorflow:global_step/sec: 5.10776
# INFO:tensorflow:loss = 4.827792, step = 588275 (19.578 sec)
# INFO:tensorflow:lr = 0.00010514044 (19.579 sec)
# INFO:tensorflow:global_step/sec: 5.14008
# INFO:tensorflow:loss = 4.7935634, step = 588375 (19.457 sec)
# INFO:tensorflow:lr = 0.00010512644 (19.453 sec)
# INFO:tensorflow:global_step/sec: 5.13833
# INFO:tensorflow:loss = 4.6745834, step = 588475 (19.461 sec)
# INFO:tensorflow:lr = 0.00010511244 (19.461 sec)
# INFO:tensorflow:global_step/sec: 5.15095
# INFO:tensorflow:loss = 4.888427, step = 588575 (19.414 sec)
# INFO:tensorflow:lr = 0.00010509844 (19.414 sec)
# INFO:tensorflow:global_step/sec: 5.08264
# INFO:tensorflow:loss = 4.795292, step = 588675 (19.676 sec)
# INFO:tensorflow:lr = 0.000105084444 (19.675 sec)
# INFO:tensorflow:global_step/sec: 5.02569
# INFO:tensorflow:loss = 4.68656, step = 588775 (19.898 sec)
# INFO:tensorflow:lr = 0.000105070445 (19.898 sec)
# INFO:tensorflow:global_step/sec: 5.11881
# INFO:tensorflow:loss = 4.843316, step = 588875 (19.533 sec)
# INFO:tensorflow:lr = 0.000105056446 (19.533 sec)
# INFO:tensorflow:global_step/sec: 5.10652
# INFO:tensorflow:loss = 4.8904333, step = 588975 (19.582 sec)
# INFO:tensorflow:lr = 0.00010504244 (19.583 sec)
# INFO:tensorflow:global_step/sec: 5.07849
# INFO:tensorflow:loss = 4.751595, step = 589075 (19.693 sec)
# INFO:tensorflow:lr = 0.00010502844 (19.694 sec)
# INFO:tensorflow:global_step/sec: 5.11633
# INFO:tensorflow:loss = 4.8200383, step = 589175 (19.546 sec)
# INFO:tensorflow:lr = 0.00010501444 (19.545 sec)
# INFO:tensorflow:global_step/sec: 5.07379
# INFO:tensorflow:loss = 4.8218412, step = 589275 (19.706 sec)
# INFO:tensorflow:lr = 0.00010500044 (19.707 sec)
# INFO:tensorflow:global_step/sec: 5.05547
# INFO:tensorflow:loss = 4.6019344, step = 589375 (19.781 sec)
# INFO:tensorflow:lr = 0.000104986444 (19.780 sec)
# INFO:tensorflow:global_step/sec: 4.96454
# INFO:tensorflow:loss = 4.859253, step = 589475 (20.148 sec)
# INFO:tensorflow:lr = 0.00010497244 (20.148 sec)
# INFO:tensorflow:global_step/sec: 5.06493
# INFO:tensorflow:loss = 4.918741, step = 589575 (19.743 sec)
# INFO:tensorflow:lr = 0.00010495844 (19.745 sec)
# INFO:tensorflow:global_step/sec: 5.11853
# INFO:tensorflow:loss = 4.804659, step = 589675 (19.535 sec)
# INFO:tensorflow:lr = 0.00010494444 (19.534 sec)
# INFO:tensorflow:global_step/sec: 5.13406
# INFO:tensorflow:loss = 4.907523, step = 589775 (19.475 sec)
# INFO:tensorflow:lr = 0.00010493044 (19.475 sec)
# INFO:tensorflow:global_step/sec: 5.12033
# INFO:tensorflow:loss = 4.781812, step = 589875 (19.530 sec)
# INFO:tensorflow:lr = 0.00010491644 (19.528 sec)
# INFO:tensorflow:global_step/sec: 5.16052
# INFO:tensorflow:loss = 4.8277607, step = 589975 (19.378 sec)
# INFO:tensorflow:lr = 0.000104902436 (19.380 sec)
# INFO:tensorflow:global_step/sec: 5.13451
# INFO:tensorflow:loss = 4.719335, step = 590075 (19.478 sec)
# INFO:tensorflow:lr = 0.00010488844 (19.475 sec)
# INFO:tensorflow:global_step/sec: 5.14865
# INFO:tensorflow:loss = 4.711407, step = 590175 (19.421 sec)
# INFO:tensorflow:lr = 0.00010487444 (19.422 sec)
# INFO:tensorflow:global_step/sec: 5.08054
# INFO:tensorflow:loss = 4.7720995, step = 590275 (19.685 sec)
# INFO:tensorflow:lr = 0.00010486044 (19.684 sec)
# INFO:tensorflow:global_step/sec: 5.03086
# INFO:tensorflow:loss = 4.8394756, step = 590375 (19.876 sec)
# INFO:tensorflow:lr = 0.00010484644 (19.877 sec)
# INFO:tensorflow:global_step/sec: 5.14359
# INFO:tensorflow:loss = 4.827785, step = 590475 (19.444 sec)
# INFO:tensorflow:lr = 0.00010483244 (19.444 sec)
# INFO:tensorflow:global_step/sec: 5.14625
# INFO:tensorflow:loss = 4.8487988, step = 590575 (19.432 sec)
# INFO:tensorflow:lr = 0.000104818435 (19.431 sec)
# INFO:tensorflow:global_step/sec: 5.11411
# INFO:tensorflow:loss = 4.794856, step = 590675 (19.553 sec)
# INFO:tensorflow:lr = 0.00010480444 (19.554 sec)
# INFO:tensorflow:global_step/sec: 5.13709
# INFO:tensorflow:loss = 4.7642956, step = 590775 (19.465 sec)
# INFO:tensorflow:lr = 0.00010479044 (19.468 sec)
# INFO:tensorflow:global_step/sec: 5.13807
# INFO:tensorflow:loss = 4.7323895, step = 590875 (19.463 sec)
# INFO:tensorflow:lr = 0.00010477644 (19.459 sec)
# INFO:tensorflow:global_step/sec: 5.16897
# INFO:tensorflow:loss = 4.85469, step = 590975 (19.349 sec)
# INFO:tensorflow:lr = 0.00010476244 (19.348 sec)
# INFO:tensorflow:global_step/sec: 5.14237
# INFO:tensorflow:loss = 4.763725, step = 591075 (19.441 sec)
# INFO:tensorflow:lr = 0.00010474844 (19.443 sec)
# INFO:tensorflow:global_step/sec: 5.10983
# INFO:tensorflow:loss = 4.724722, step = 591175 (19.573 sec)
# INFO:tensorflow:lr = 0.00010473444 (19.571 sec)
# INFO:tensorflow:global_step/sec: 5.12583
# INFO:tensorflow:loss = 4.8285646, step = 591275 (19.511 sec)
# INFO:tensorflow:lr = 0.000104720435 (19.511 sec)
# INFO:tensorflow:global_step/sec: 5.1568
# INFO:tensorflow:loss = 4.745642, step = 591375 (19.388 sec)
# INFO:tensorflow:lr = 0.000104706436 (19.390 sec)
# INFO:tensorflow:global_step/sec: 5.16419
# INFO:tensorflow:loss = 4.751034, step = 591475 (19.366 sec)
# INFO:tensorflow:lr = 0.00010469244 (19.364 sec)
# INFO:tensorflow:global_step/sec: 5.11846
# INFO:tensorflow:loss = 4.6309013, step = 591575 (19.537 sec)
# INFO:tensorflow:lr = 0.00010467844 (19.537 sec)
# INFO:tensorflow:global_step/sec: 5.16242
# INFO:tensorflow:loss = 4.796167, step = 591675 (19.370 sec)
# INFO:tensorflow:lr = 0.00010466444 (19.370 sec)
# INFO:tensorflow:global_step/sec: 5.11388
# INFO:tensorflow:loss = 4.780007, step = 591775 (19.556 sec)
# INFO:tensorflow:lr = 0.00010465043 (19.556 sec)
# INFO:tensorflow:global_step/sec: 5.12811
# INFO:tensorflow:loss = 4.806933, step = 591875 (19.497 sec)
# INFO:tensorflow:lr = 0.000104636434 (19.500 sec)
# INFO:tensorflow:global_step/sec: 5.01938
# INFO:tensorflow:loss = 4.6357675, step = 591975 (19.927 sec)
# INFO:tensorflow:lr = 0.000104622435 (19.924 sec)
# INFO:tensorflow:global_step/sec: 5.081
# INFO:tensorflow:loss = 4.5470433, step = 592075 (19.679 sec)
# INFO:tensorflow:lr = 0.000104608436 (19.680 sec)
# INFO:tensorflow:global_step/sec: 5.05546
# INFO:tensorflow:loss = 4.591142, step = 592175 (19.782 sec)
# INFO:tensorflow:lr = 0.00010459444 (19.782 sec)
# INFO:tensorflow:global_step/sec: 5.06521
# INFO:tensorflow:loss = 4.8358, step = 592275 (19.739 sec)
# INFO:tensorflow:lr = 0.00010458044 (19.741 sec)
# INFO:tensorflow:global_step/sec: 5.00823
# INFO:tensorflow:loss = 4.835816, step = 592375 (19.971 sec)
# INFO:tensorflow:lr = 0.00010456643 (19.969 sec)
# INFO:tensorflow:global_step/sec: 5.13794
# INFO:tensorflow:loss = 4.8464494, step = 592475 (19.465 sec)
# INFO:tensorflow:lr = 0.00010455244 (19.465 sec)
# INFO:tensorflow:global_step/sec: 5.1055
# INFO:tensorflow:loss = 4.9021, step = 592575 (19.584 sec)
# INFO:tensorflow:lr = 0.000104538434 (19.585 sec)
# INFO:tensorflow:global_step/sec: 5.06493
# INFO:tensorflow:loss = 4.868694, step = 592675 (19.745 sec)
# INFO:tensorflow:lr = 0.000104524435 (19.744 sec)
