# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_lccc/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

import numpy as np
import pprint
import logging

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  char2idx = params['char2idx']
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      source, target = line.split('<SEP>')
      source = [char2idx.get(c, len(char2idx)) for c in list(source)]
      target = [char2idx.get(c, len(char2idx)) for c in list(target)]
      if len(source) > params['max_len']:
        source = source[:params['max_len']]
      if len(target) > params['max_len']:
        target = target[:params['max_len']]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    def cell_fn():
        cell = tf.nn.rnn_cell.LSTMCell(params['rnn_units'],
                                       initializer=tf.orthogonal_initializer())
        return cell
    if params['dec_layers'] > 1:
      cells = []
      for i in range(params['dec_layers']):
        if i == params['dec_layers'] - 1:
          cells.append(cell_fn())
        else:
          cells.append(tf.nn.rnn_cell.ResidualWrapper(cell_fn(), residual_fn=lambda i,o: tf.concat((i,o), -1)))
      return tf.nn.rnn_cell.MultiRNNCell(cells)
    else:
      return cell_fn()

  
def dec_cell(enc_out, enc_seq_len):
    attn = tf.contrib.seq2seq.BahdanauAttention(
        num_units = params['rnn_units'],
        memory = enc_out,
        memory_sequence_length = enc_seq_len)
    
    return tf.contrib.seq2seq.AttentionWrapper(
        cell = rnn_cell(),
        attention_mechanism = attn,
        attention_layer_size = params['rnn_units'])

# %%
class TiedDense(tf.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    if params['rnn_units'] != 300:
      self.proj_W = self.add_weight(name='proj_W',
                                    shape=[params['rnn_units'], params['embed_dim']],
                                    trainable=True)
      self.proj_b = self.add_weight(name='proj_b',
                                    shape=[params['embed_dim']],
                                    trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    if params['rnn_units'] != 300:
      inputs = params['activation'](tf.nn.bias_add(tf.matmul(inputs, self.proj_W), self.proj_b))
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    mask = tf.sign(words)
    
    
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        x = tf.nn.embedding_lookup(embedding, words)
        x = tf.layers.dropout(x, params['dropout_rate'], training=is_training)
    
    
    with tf.variable_scope('Encoder'):
        encoder = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
          params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
        enc_out, state_fw_h, state_fw_c, state_bw_h, state_bw_c = encoder(x, mask=mask)

        enc_state = tf.concat((tf.reduce_max(enc_out, 1), state_fw_h, state_bw_h), axis=-1)
        enc_state = tf.layers.dense(enc_state, params['rnn_units'], params['activation'], name='state_fc')
        enc_state = tf.nn.rnn_cell.LSTMStateTuple(c=enc_state, h=enc_state)
        if params['dec_layers'] > 1:
          enc_state = tuple(params['dec_layers'] * [enc_state])
    
    
    with tf.variable_scope('Decoder'):
        output_proj = TiedDense(embedding, len(params['char2idx'])+1)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = tf.layers.dropout(dec_inputs, params['dropout_rate'], training=is_training)
            cell = dec_cell(enc_out, words_len)
            
            init_state = cell.zero_state(batch_sz, tf.float32).clone(
                cell_state=enc_state)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = dec_inputs,
                sequence_length = dec_seq_len,)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = cell,
                helper = helper,
                initial_state = init_state,
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            
            return decoder_output.rnn_output
        else:
            enc_out_t = tf.contrib.seq2seq.tile_batch(enc_out, params['beam_width'])
            enc_state_t = tf.contrib.seq2seq.tile_batch(enc_state, params['beam_width'])
            enc_seq_len_t = tf.contrib.seq2seq.tile_batch(words_len, params['beam_width'])
            
            cell = dec_cell(enc_out_t, enc_seq_len_t)
            
            init_state = cell.zero_state(batch_sz*params['beam_width'], tf.float32).clone(
                cell_state=enc_state_t)
            
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
                end_token = 2,
                initial_state = init_state,
                beam_width = params['beam_width'],
                output_layer = output_proj,
                length_penalty_weight = params['length_penalty'],
                coverage_penalty_weight = params['coverage_penalty'],)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = params['max_len'],)
            
            return decoder_output.predicted_ids[:, :, :params['top_k']]

# %%
def clr(step,
        initial_learning_rate,
        maximal_learning_rate,
        step_size,
        scale_fn,
        scale_mode,):
  step = tf.cast(step, tf.float32)
  
  initial_learning_rate = tf.convert_to_tensor(
    initial_learning_rate, name='initial_learning_rate')
  dtype = initial_learning_rate.dtype
  maximal_learning_rate = tf.cast(maximal_learning_rate, dtype)
  step_size = tf.cast(step_size, dtype)
  cycle = tf.floor(1 + step / (2 * step_size))
  x = tf.abs(step / step_size - 2 * cycle + 1)

  mode_step = cycle if scale_mode == 'cycle' else step

  return initial_learning_rate + (
    maximal_learning_rate - initial_learning_rate) * tf.maximum(
      tf.cast(0, dtype), (1 - x)) * scale_fn(mode_step)

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()

        decay_lr = clr(
          step = global_step,
          initial_learning_rate = 1e-4,
          maximal_learning_rate = 8e-4,
          step_size = params['num_samples'] / params['batch_size'] // 2,
          scale_fn=lambda x: 1 / (2.0 ** (x - 1)),
          scale_mode = 'cycle',)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def unit_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '你今天心情好吗',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去唱歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('unit test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx!=0 and idx!=2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
params = {
    'model_dir': '../model/lstm_seq2seq',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'dropout_rate': .2,
    'rnn_units': 300,
    'activation': tf.nn.swish,
    'dec_layers': 1,
    'beam_width': 10,
    'top_k': 3,
    'length_penalty': .6,
    'coverage_penalty': .0,
    'label_smoothing': .2,
    'clip_norm': .1,
    'num_samples': 5000000,
    'buffer_size': 500000,
    'batch_size': 64,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}
print(len(params['char2idx']), 'Chars')

# Create directory if not exist
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps = params['num_samples'] // params['batch_size'] + 1,
    keep_checkpoint_max = 2),
  params=params)

best_ppl = 10000.
count = 0
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  unit_test(estimator)
  
  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  print("Perplexity: {:.3f}".format(ppl))

  if ppl < best_ppl:
    best_ppl = ppl
    count = 0
  else:
    count += 1
  print("Best Perplexity: {:.3f}".format(best_ppl))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# 3042 Chars
# INFO:tensorflow:Using config: {'_model_dir': '../model/lstm_seq2seq', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 78126, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 2, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3e80050630>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# WARNING:tensorflow:From <ipython-input-8-decc5ee5bcc2>:14: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:271: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From <ipython-input-8-decc5ee5bcc2>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-6-33c7bca471bf>:12: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3e6e2d5cf8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3e6e2d5cf8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From <ipython-input-10-34f5836bdfd0>:15: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3043, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3043,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 8.0280285, step = 0
# INFO:tensorflow:lr = 1e-04
# INFO:tensorflow:global_step/sec: 5.52268
# INFO:tensorflow:loss = 6.5790267, step = 100 (18.112 sec)
# INFO:tensorflow:lr = 0.00010179201 (18.114 sec)
# INFO:tensorflow:global_step/sec: 5.83107
# INFO:tensorflow:loss = 6.325684, step = 200 (17.148 sec)
# INFO:tensorflow:lr = 0.000103584025 (17.149 sec)
# INFO:tensorflow:global_step/sec: 5.78168
# INFO:tensorflow:loss = 6.34679, step = 300 (17.294 sec)
# INFO:tensorflow:lr = 0.00010537608 (17.293 sec)
# INFO:tensorflow:global_step/sec: 5.79017
# INFO:tensorflow:loss = 6.2656126, step = 400 (17.270 sec)
# INFO:tensorflow:lr = 0.000107168096 (17.271 sec)
# INFO:tensorflow:global_step/sec: 5.76918
# INFO:tensorflow:loss = 6.1021075, step = 500 (17.338 sec)
# INFO:tensorflow:lr = 0.00010896011 (17.336 sec)
# INFO:tensorflow:global_step/sec: 5.78043
# INFO:tensorflow:loss = 6.267239, step = 600 (17.298 sec)
# INFO:tensorflow:lr = 0.000110752124 (17.299 sec)
# INFO:tensorflow:global_step/sec: 5.68325
# INFO:tensorflow:loss = 6.1172314, step = 700 (17.593 sec)
# INFO:tensorflow:lr = 0.00011254418 (17.592 sec)
# INFO:tensorflow:global_step/sec: 5.74522
# INFO:tensorflow:loss = 6.1652985, step = 800 (17.407 sec)
# INFO:tensorflow:lr = 0.00011433619 (17.407 sec)
# INFO:tensorflow:global_step/sec: 5.76223
# INFO:tensorflow:loss = 6.004941, step = 900 (17.353 sec)
# INFO:tensorflow:lr = 0.000116128205 (17.353 sec)
# INFO:tensorflow:global_step/sec: 5.78668
# INFO:tensorflow:loss = 6.0284176, step = 1000 (17.283 sec)
# INFO:tensorflow:lr = 0.000117920215 (17.284 sec)
# INFO:tensorflow:global_step/sec: 5.7332
# INFO:tensorflow:loss = 6.0469794, step = 1100 (17.441 sec)
# INFO:tensorflow:lr = 0.00011971223 (17.443 sec)
# INFO:tensorflow:global_step/sec: 5.78732
# INFO:tensorflow:loss = 5.8831725, step = 1200 (17.278 sec)
# INFO:tensorflow:lr = 0.00012150429 (17.276 sec)
# INFO:tensorflow:global_step/sec: 5.66532
# INFO:tensorflow:loss = 6.0766244, step = 1300 (17.651 sec)
# INFO:tensorflow:lr = 0.0001232963 (17.651 sec)
# INFO:tensorflow:global_step/sec: 5.78187
# INFO:tensorflow:loss = 5.95793, step = 1400 (17.296 sec)
# INFO:tensorflow:lr = 0.0001250883 (17.296 sec)
# INFO:tensorflow:global_step/sec: 5.76088
# INFO:tensorflow:loss = 5.8668113, step = 1500 (17.362 sec)
# INFO:tensorflow:lr = 0.00012688033 (17.360 sec)
# INFO:tensorflow:global_step/sec: 5.78549
# INFO:tensorflow:loss = 5.830776, step = 1600 (17.284 sec)
# INFO:tensorflow:lr = 0.00012867239 (17.286 sec)
# INFO:tensorflow:global_step/sec: 5.73793
# INFO:tensorflow:loss = 5.9062214, step = 1700 (17.431 sec)
# INFO:tensorflow:lr = 0.0001304644 (17.428 sec)
# INFO:tensorflow:global_step/sec: 5.77283
# INFO:tensorflow:loss = 5.8912683, step = 1800 (17.321 sec)
# INFO:tensorflow:lr = 0.0001322564 (17.323 sec)
# INFO:tensorflow:global_step/sec: 5.81085
# INFO:tensorflow:loss = 5.874049, step = 1900 (17.211 sec)
# INFO:tensorflow:lr = 0.00013404843 (17.209 sec)
# INFO:tensorflow:global_step/sec: 5.73191
# INFO:tensorflow:loss = 5.8411746, step = 2000 (17.443 sec)
# INFO:tensorflow:lr = 0.00013584044 (17.443 sec)
# INFO:tensorflow:global_step/sec: 5.72867
# INFO:tensorflow:loss = 5.836754, step = 2100 (17.458 sec)
# INFO:tensorflow:lr = 0.0001376325 (17.459 sec)
# INFO:tensorflow:global_step/sec: 5.79543
# INFO:tensorflow:loss = 5.736423, step = 2200 (17.255 sec)
# INFO:tensorflow:lr = 0.0001394245 (17.254 sec)
# INFO:tensorflow:global_step/sec: 5.82969
# INFO:tensorflow:loss = 5.6501374, step = 2300 (17.152 sec)
# INFO:tensorflow:lr = 0.00014121651 (17.153 sec)
# INFO:tensorflow:global_step/sec: 5.73762
# INFO:tensorflow:loss = 5.7536016, step = 2400 (17.429 sec)
# INFO:tensorflow:lr = 0.00014300854 (17.429 sec)
# INFO:tensorflow:global_step/sec: 5.70077
# INFO:tensorflow:loss = 5.7479463, step = 2500 (17.539 sec)
# INFO:tensorflow:lr = 0.00014480058 (17.538 sec)
# INFO:tensorflow:global_step/sec: 5.77437
# INFO:tensorflow:loss = 5.6796002, step = 2600 (17.318 sec)
# INFO:tensorflow:lr = 0.0001465926 (17.317 sec)
# INFO:tensorflow:global_step/sec: 5.81625
# INFO:tensorflow:loss = 5.7595234, step = 2700 (17.198 sec)
# INFO:tensorflow:lr = 0.00014838461 (17.197 sec)
# INFO:tensorflow:global_step/sec: 5.7718
# INFO:tensorflow:loss = 5.570733, step = 2800 (17.324 sec)
# INFO:tensorflow:lr = 0.00015017662 (17.324 sec)
# INFO:tensorflow:global_step/sec: 5.76551
# INFO:tensorflow:loss = 5.862792, step = 2900 (17.344 sec)
# INFO:tensorflow:lr = 0.00015196865 (17.345 sec)
# INFO:tensorflow:global_step/sec: 5.75676
# INFO:tensorflow:loss = 5.6619782, step = 3000 (17.373 sec)
# INFO:tensorflow:lr = 0.0001537607 (17.373 sec)
# INFO:tensorflow:global_step/sec: 5.79619
# INFO:tensorflow:loss = 5.604374, step = 3100 (17.249 sec)
# INFO:tensorflow:lr = 0.00015555271 (17.249 sec)
# INFO:tensorflow:global_step/sec: 5.79644
# INFO:tensorflow:loss = 5.47819, step = 3200 (17.251 sec)
# INFO:tensorflow:lr = 0.00015734472 (17.251 sec)
# INFO:tensorflow:global_step/sec: 5.79886
# INFO:tensorflow:loss = 5.6619987, step = 3300 (17.247 sec)
# INFO:tensorflow:lr = 0.00015913673 (17.246 sec)
# INFO:tensorflow:global_step/sec: 5.71615
# INFO:tensorflow:loss = 5.5829277, step = 3400 (17.498 sec)
# INFO:tensorflow:lr = 0.00016092879 (17.498 sec)
# INFO:tensorflow:global_step/sec: 5.76953
# INFO:tensorflow:loss = 5.5814757, step = 3500 (17.331 sec)
# INFO:tensorflow:lr = 0.0001627208 (17.331 sec)
# INFO:tensorflow:global_step/sec: 5.82101
# INFO:tensorflow:loss = 5.5453362, step = 3600 (17.177 sec)
# INFO:tensorflow:lr = 0.00016451282 (17.178 sec)
# INFO:tensorflow:global_step/sec: 5.80246
# INFO:tensorflow:loss = 5.5677733, step = 3700 (17.234 sec)
# INFO:tensorflow:lr = 0.00016630483 (17.233 sec)
# INFO:tensorflow:global_step/sec: 5.8114
# INFO:tensorflow:loss = 5.6685047, step = 3800 (17.209 sec)
# INFO:tensorflow:lr = 0.00016809686 (17.210 sec)
# INFO:tensorflow:global_step/sec: 5.72507
# INFO:tensorflow:loss = 5.6224637, step = 3900 (17.465 sec)
# INFO:tensorflow:lr = 0.0001698889 (17.465 sec)
# INFO:tensorflow:global_step/sec: 5.79372
# INFO:tensorflow:loss = 5.57092, step = 4000 (17.261 sec)
# INFO:tensorflow:lr = 0.0001716809 (17.261 sec)
# INFO:tensorflow:global_step/sec: 5.73515
# INFO:tensorflow:loss = 5.670625, step = 4100 (17.434 sec)
# INFO:tensorflow:lr = 0.00017347293 (17.437 sec)
# INFO:tensorflow:global_step/sec: 5.79344
# INFO:tensorflow:loss = 5.6389, step = 4200 (17.265 sec)
# INFO:tensorflow:lr = 0.00017526494 (17.260 sec)
# INFO:tensorflow:global_step/sec: 5.70255
# INFO:tensorflow:loss = 5.5183916, step = 4300 (17.532 sec)
# INFO:tensorflow:lr = 0.000177057 (17.533 sec)
# INFO:tensorflow:global_step/sec: 5.81389
# INFO:tensorflow:loss = 5.625504, step = 4400 (17.202 sec)
# INFO:tensorflow:lr = 0.000178849 (17.203 sec)
# INFO:tensorflow:global_step/sec: 5.80937
# INFO:tensorflow:loss = 5.526631, step = 4500 (17.216 sec)
# INFO:tensorflow:lr = 0.00018064103 (17.215 sec)
# INFO:tensorflow:global_step/sec: 5.83733
# INFO:tensorflow:loss = 5.49778, step = 4600 (17.132 sec)
# INFO:tensorflow:lr = 0.00018243304 (17.133 sec)
# INFO:tensorflow:global_step/sec: 5.82261
# INFO:tensorflow:loss = 5.5078425, step = 4700 (17.172 sec)
# INFO:tensorflow:lr = 0.00018422505 (17.171 sec)
# INFO:tensorflow:global_step/sec: 5.74515
# INFO:tensorflow:loss = 5.4743495, step = 4800 (17.405 sec)
# INFO:tensorflow:lr = 0.0001860171 (17.404 sec)
# INFO:tensorflow:global_step/sec: 5.82484
# INFO:tensorflow:loss = 5.556298, step = 4900 (17.170 sec)
# INFO:tensorflow:lr = 0.00018780911 (17.174 sec)
# INFO:tensorflow:global_step/sec: 5.79365
# INFO:tensorflow:loss = 5.473726, step = 5000 (17.261 sec)
# INFO:tensorflow:lr = 0.00018960114 (17.258 sec)
# INFO:tensorflow:global_step/sec: 5.8153
# INFO:tensorflow:loss = 5.494432, step = 5100 (17.194 sec)
# INFO:tensorflow:lr = 0.00019139315 (17.197 sec)
# INFO:tensorflow:global_step/sec: 5.79552
# INFO:tensorflow:loss = 5.4499083, step = 5200 (17.254 sec)
# INFO:tensorflow:lr = 0.0001931852 (17.251 sec)
# INFO:tensorflow:global_step/sec: 5.80425
# INFO:tensorflow:loss = 5.54177, step = 5300 (17.231 sec)
# INFO:tensorflow:lr = 0.00019497721 (17.231 sec)
# INFO:tensorflow:global_step/sec: 5.78065
# INFO:tensorflow:loss = 5.363087, step = 5400 (17.299 sec)
# INFO:tensorflow:lr = 0.00019676922 (17.298 sec)
# INFO:tensorflow:global_step/sec: 5.83298
# INFO:tensorflow:loss = 5.5399203, step = 5500 (17.142 sec)
# INFO:tensorflow:lr = 0.00019856125 (17.141 sec)
# INFO:tensorflow:global_step/sec: 5.79348
# INFO:tensorflow:loss = 5.441289, step = 5600 (17.264 sec)
# INFO:tensorflow:lr = 0.00020035326 (17.264 sec)
# INFO:tensorflow:global_step/sec: 5.72365
# INFO:tensorflow:loss = 5.517609, step = 5700 (17.468 sec)
# INFO:tensorflow:lr = 0.00020214531 (17.469 sec)
# INFO:tensorflow:global_step/sec: 5.79429
# INFO:tensorflow:loss = 5.4037604, step = 5800 (17.262 sec)
# INFO:tensorflow:lr = 0.00020393732 (17.262 sec)
# INFO:tensorflow:global_step/sec: 5.81879
# INFO:tensorflow:loss = 5.477639, step = 5900 (17.185 sec)
# INFO:tensorflow:lr = 0.00020572933 (17.188 sec)
# INFO:tensorflow:global_step/sec: 5.80664
# INFO:tensorflow:loss = 5.5427694, step = 6000 (17.221 sec)
# INFO:tensorflow:lr = 0.00020752136 (17.219 sec)
# INFO:tensorflow:global_step/sec: 5.68089
# INFO:tensorflow:loss = 5.4259734, step = 6100 (17.605 sec)
# INFO:tensorflow:lr = 0.00020931341 (17.605 sec)
# INFO:tensorflow:global_step/sec: 5.75205
# INFO:tensorflow:loss = 5.368666, step = 6200 (17.380 sec)
# INFO:tensorflow:lr = 0.00021110542 (17.379 sec)
# INFO:tensorflow:global_step/sec: 5.75792
# INFO:tensorflow:loss = 5.475007, step = 6300 (17.372 sec)
# INFO:tensorflow:lr = 0.00021289743 (17.371 sec)
# INFO:tensorflow:global_step/sec: 5.82836
# INFO:tensorflow:loss = 5.563068, step = 6400 (17.158 sec)
# INFO:tensorflow:lr = 0.00021468944 (17.158 sec)
# INFO:tensorflow:global_step/sec: 5.78211
# INFO:tensorflow:loss = 5.32184, step = 6500 (17.292 sec)
# INFO:tensorflow:lr = 0.00021648147 (17.294 sec)
# INFO:tensorflow:global_step/sec: 5.76613
# INFO:tensorflow:loss = 5.3682423, step = 6600 (17.341 sec)
# INFO:tensorflow:lr = 0.00021827352 (17.342 sec)
# INFO:tensorflow:global_step/sec: 5.76167
# INFO:tensorflow:loss = 5.3933415, step = 6700 (17.359 sec)
# INFO:tensorflow:lr = 0.00022006553 (17.357 sec)
# INFO:tensorflow:global_step/sec: 5.78988
# INFO:tensorflow:loss = 5.438794, step = 6800 (17.269 sec)
# INFO:tensorflow:lr = 0.00022185754 (17.269 sec)
# INFO:tensorflow:global_step/sec: 5.76073
# INFO:tensorflow:loss = 5.520709, step = 6900 (17.358 sec)
# INFO:tensorflow:lr = 0.00022364955 (17.358 sec)
# INFO:tensorflow:global_step/sec: 5.82571
# INFO:tensorflow:loss = 5.37345, step = 7000 (17.168 sec)
# INFO:tensorflow:lr = 0.00022544162 (17.170 sec)
# INFO:tensorflow:global_step/sec: 5.82143
# INFO:tensorflow:loss = 5.460565, step = 7100 (17.180 sec)
# INFO:tensorflow:lr = 0.00022723363 (17.177 sec)
# INFO:tensorflow:global_step/sec: 5.77841
# INFO:tensorflow:loss = 5.324707, step = 7200 (17.305 sec)
# INFO:tensorflow:lr = 0.00022902564 (17.307 sec)
# INFO:tensorflow:global_step/sec: 5.81631
# INFO:tensorflow:loss = 5.4402275, step = 7300 (17.191 sec)
# INFO:tensorflow:lr = 0.00023081765 (17.190 sec)
# INFO:tensorflow:global_step/sec: 5.77507
# INFO:tensorflow:loss = 5.3919473, step = 7400 (17.314 sec)
# INFO:tensorflow:lr = 0.00023260966 (17.314 sec)
# INFO:tensorflow:global_step/sec: 5.77727
# INFO:tensorflow:loss = 5.4168015, step = 7500 (17.312 sec)
# INFO:tensorflow:lr = 0.00023440173 (17.312 sec)
# INFO:tensorflow:global_step/sec: 5.74178
# INFO:tensorflow:loss = 5.5008545, step = 7600 (17.413 sec)
# INFO:tensorflow:lr = 0.00023619374 (17.413 sec)
# INFO:tensorflow:global_step/sec: 5.83442
# INFO:tensorflow:loss = 5.2594004, step = 7700 (17.146 sec)
# INFO:tensorflow:lr = 0.00023798575 (17.146 sec)
# INFO:tensorflow:global_step/sec: 5.8101
# INFO:tensorflow:loss = 5.4205623, step = 7800 (17.209 sec)
# INFO:tensorflow:lr = 0.00023977782 (17.209 sec)
# INFO:tensorflow:global_step/sec: 5.7029
# INFO:tensorflow:loss = 5.2891026, step = 7900 (17.537 sec)
# INFO:tensorflow:lr = 0.00024156983 (17.539 sec)
# INFO:tensorflow:global_step/sec: 5.77768
# INFO:tensorflow:loss = 5.3854747, step = 8000 (17.302 sec)
# INFO:tensorflow:lr = 0.00024336184 (17.302 sec)
# INFO:tensorflow:global_step/sec: 5.74788
# INFO:tensorflow:loss = 5.4220486, step = 8100 (17.401 sec)
# INFO:tensorflow:lr = 0.00024515385 (17.399 sec)
# INFO:tensorflow:global_step/sec: 5.82145
# INFO:tensorflow:loss = 5.248687, step = 8200 (17.178 sec)
# INFO:tensorflow:lr = 0.00024694586 (17.178 sec)
# INFO:tensorflow:global_step/sec: 5.77628
# INFO:tensorflow:loss = 5.3667846, step = 8300 (17.312 sec)
# INFO:tensorflow:lr = 0.00024873787 (17.314 sec)
# INFO:tensorflow:global_step/sec: 5.80586
# INFO:tensorflow:loss = 5.4052696, step = 8400 (17.226 sec)
# INFO:tensorflow:lr = 0.00025052993 (17.224 sec)
# INFO:tensorflow:global_step/sec: 5.76454
# INFO:tensorflow:loss = 5.3884306, step = 8500 (17.343 sec)
# INFO:tensorflow:lr = 0.00025232194 (17.343 sec)
# INFO:tensorflow:global_step/sec: 5.74023
# INFO:tensorflow:loss = 5.324129, step = 8600 (17.424 sec)
# INFO:tensorflow:lr = 0.00025411395 (17.425 sec)
# INFO:tensorflow:global_step/sec: 5.76673
# INFO:tensorflow:loss = 5.2409334, step = 8700 (17.341 sec)
# INFO:tensorflow:lr = 0.00025590602 (17.340 sec)
# INFO:tensorflow:global_step/sec: 5.78419
# INFO:tensorflow:loss = 5.388473, step = 8800 (17.288 sec)
# INFO:tensorflow:lr = 0.00025769803 (17.288 sec)
# INFO:tensorflow:global_step/sec: 5.76786
# INFO:tensorflow:loss = 5.2062025, step = 8900 (17.335 sec)
# INFO:tensorflow:lr = 0.00025949004 (17.335 sec)
# INFO:tensorflow:global_step/sec: 5.7473
# INFO:tensorflow:loss = 5.249114, step = 9000 (17.403 sec)
# INFO:tensorflow:lr = 0.00026128205 (17.403 sec)
# INFO:tensorflow:global_step/sec: 5.79301
# INFO:tensorflow:loss = 5.2667613, step = 9100 (17.261 sec)
# INFO:tensorflow:lr = 0.00026307406 (17.261 sec)
# INFO:tensorflow:global_step/sec: 5.71511
# INFO:tensorflow:loss = 5.457818, step = 9200 (17.495 sec)
# INFO:tensorflow:lr = 0.00026486607 (17.496 sec)
# INFO:tensorflow:global_step/sec: 5.80651
# INFO:tensorflow:loss = 5.288625, step = 9300 (17.226 sec)
# INFO:tensorflow:lr = 0.00026665814 (17.225 sec)
# INFO:tensorflow:global_step/sec: 5.79747
# INFO:tensorflow:loss = 5.275107, step = 9400 (17.248 sec)
# INFO:tensorflow:lr = 0.00026845015 (17.249 sec)
# INFO:tensorflow:global_step/sec: 5.71264
# INFO:tensorflow:loss = 5.234369, step = 9500 (17.505 sec)
# INFO:tensorflow:lr = 0.00027024216 (17.505 sec)
# INFO:tensorflow:global_step/sec: 5.79399
# INFO:tensorflow:loss = 5.4710975, step = 9600 (17.258 sec)
# INFO:tensorflow:lr = 0.00027203423 (17.259 sec)
# INFO:tensorflow:global_step/sec: 5.7135
# INFO:tensorflow:loss = 5.330329, step = 9700 (17.504 sec)
# INFO:tensorflow:lr = 0.00027382624 (17.502 sec)
# INFO:tensorflow:global_step/sec: 5.7398
# INFO:tensorflow:loss = 5.273193, step = 9800 (17.422 sec)
# INFO:tensorflow:lr = 0.00027561825 (17.423 sec)
# INFO:tensorflow:global_step/sec: 5.63137
# INFO:tensorflow:loss = 5.268228, step = 9900 (17.760 sec)
# INFO:tensorflow:lr = 0.00027741026 (17.759 sec)
# INFO:tensorflow:global_step/sec: 5.66763
# INFO:tensorflow:loss = 5.2752867, step = 10000 (17.641 sec)
# INFO:tensorflow:lr = 0.00027920227 (17.642 sec)
# INFO:tensorflow:global_step/sec: 5.66413
# INFO:tensorflow:loss = 5.178351, step = 10100 (17.653 sec)
# INFO:tensorflow:lr = 0.00028099428 (17.653 sec)
# INFO:tensorflow:global_step/sec: 5.61579
# INFO:tensorflow:loss = 5.1847787, step = 10200 (17.806 sec)
# INFO:tensorflow:lr = 0.0002827863 (17.806 sec)
# INFO:tensorflow:global_step/sec: 5.62331
# INFO:tensorflow:loss = 5.2591543, step = 10300 (17.786 sec)
# INFO:tensorflow:lr = 0.00028457836 (17.788 sec)
# INFO:tensorflow:global_step/sec: 5.60995
# INFO:tensorflow:loss = 5.1431274, step = 10400 (17.825 sec)
# INFO:tensorflow:lr = 0.00028637037 (17.824 sec)
# INFO:tensorflow:global_step/sec: 5.63347
# INFO:tensorflow:loss = 5.2755637, step = 10500 (17.751 sec)
# INFO:tensorflow:lr = 0.00028816244 (17.750 sec)
# INFO:tensorflow:global_step/sec: 5.66648
# INFO:tensorflow:loss = 5.3422728, step = 10600 (17.645 sec)
# INFO:tensorflow:lr = 0.00028995445 (17.646 sec)
# INFO:tensorflow:global_step/sec: 5.63829
# INFO:tensorflow:loss = 5.390077, step = 10700 (17.739 sec)
# INFO:tensorflow:lr = 0.00029174646 (17.739 sec)
# INFO:tensorflow:global_step/sec: 5.6287
# INFO:tensorflow:loss = 5.1430783, step = 10800 (17.764 sec)
# INFO:tensorflow:lr = 0.00029353847 (17.764 sec)
# INFO:tensorflow:global_step/sec: 5.70889
# INFO:tensorflow:loss = 5.278245, step = 10900 (17.518 sec)
# INFO:tensorflow:lr = 0.00029533048 (17.519 sec)
# INFO:tensorflow:global_step/sec: 5.78204
# INFO:tensorflow:loss = 5.284099, step = 11000 (17.295 sec)
# INFO:tensorflow:lr = 0.0002971225 (17.293 sec)
# INFO:tensorflow:global_step/sec: 5.82595
# INFO:tensorflow:loss = 5.2064047, step = 11100 (17.165 sec)
# INFO:tensorflow:lr = 0.0002989145 (17.166 sec)
# INFO:tensorflow:global_step/sec: 5.83526
# INFO:tensorflow:loss = 5.1185665, step = 11200 (17.137 sec)
# INFO:tensorflow:lr = 0.00030070657 (17.138 sec)
# INFO:tensorflow:global_step/sec: 5.75678
# INFO:tensorflow:loss = 5.350652, step = 11300 (17.367 sec)
# INFO:tensorflow:lr = 0.00030249858 (17.368 sec)
# INFO:tensorflow:global_step/sec: 5.81617
# INFO:tensorflow:loss = 5.290036, step = 11400 (17.195 sec)
# INFO:tensorflow:lr = 0.00030429062 (17.194 sec)
# INFO:tensorflow:global_step/sec: 5.6543
# INFO:tensorflow:loss = 5.377284, step = 11500 (17.687 sec)
# INFO:tensorflow:lr = 0.00030608266 (17.687 sec)
# INFO:tensorflow:global_step/sec: 5.77228
# INFO:tensorflow:loss = 5.284012, step = 11600 (17.325 sec)
# INFO:tensorflow:lr = 0.00030787467 (17.324 sec)
# INFO:tensorflow:global_step/sec: 5.79126
# INFO:tensorflow:loss = 5.285326, step = 11700 (17.266 sec)
# INFO:tensorflow:lr = 0.00030966668 (17.268 sec)
# INFO:tensorflow:global_step/sec: 5.75207
# INFO:tensorflow:loss = 5.2392807, step = 11800 (17.389 sec)
# INFO:tensorflow:lr = 0.0003114587 (17.387 sec)
# INFO:tensorflow:global_step/sec: 5.74925
# INFO:tensorflow:loss = 5.246379, step = 11900 (17.389 sec)
# INFO:tensorflow:lr = 0.0003132507 (17.391 sec)
# INFO:tensorflow:global_step/sec: 5.80086
# INFO:tensorflow:loss = 5.302374, step = 12000 (17.240 sec)
# INFO:tensorflow:lr = 0.0003150427 (17.240 sec)
# INFO:tensorflow:global_step/sec: 5.77254
# INFO:tensorflow:loss = 5.150296, step = 12100 (17.323 sec)
# INFO:tensorflow:lr = 0.00031683478 (17.323 sec)
# INFO:tensorflow:global_step/sec: 5.74898
# INFO:tensorflow:loss = 5.1496086, step = 12200 (17.392 sec)
# INFO:tensorflow:lr = 0.0003186268 (17.391 sec)
# INFO:tensorflow:global_step/sec: 5.74783
# INFO:tensorflow:loss = 5.1058846, step = 12300 (17.403 sec)
# INFO:tensorflow:lr = 0.00032041883 (17.404 sec)
# INFO:tensorflow:global_step/sec: 5.81283
# INFO:tensorflow:loss = 5.255664, step = 12400 (17.197 sec)
# INFO:tensorflow:lr = 0.00032221084 (17.199 sec)
# INFO:tensorflow:global_step/sec: 5.81371
# INFO:tensorflow:loss = 5.421416, step = 12500 (17.206 sec)
# INFO:tensorflow:lr = 0.00032400287 (17.203 sec)
# INFO:tensorflow:global_step/sec: 5.79724
# INFO:tensorflow:loss = 5.3426375, step = 12600 (17.249 sec)
# INFO:tensorflow:lr = 0.00032579488 (17.250 sec)
# INFO:tensorflow:global_step/sec: 5.74818
# INFO:tensorflow:loss = 5.198436, step = 12700 (17.396 sec)
# INFO:tensorflow:lr = 0.0003275869 (17.395 sec)
# INFO:tensorflow:global_step/sec: 5.74222
# INFO:tensorflow:loss = 5.2176127, step = 12800 (17.414 sec)
# INFO:tensorflow:lr = 0.0003293789 (17.414 sec)
# INFO:tensorflow:global_step/sec: 5.79428
# INFO:tensorflow:loss = 5.1122665, step = 12900 (17.261 sec)
# INFO:tensorflow:lr = 0.00033117092 (17.260 sec)
# INFO:tensorflow:global_step/sec: 5.7685
# INFO:tensorflow:loss = 5.230555, step = 13000 (17.333 sec)
# INFO:tensorflow:lr = 0.00033296298 (17.332 sec)
# INFO:tensorflow:global_step/sec: 5.77458
# INFO:tensorflow:loss = 5.1677995, step = 13100 (17.318 sec)
# INFO:tensorflow:lr = 0.000334755 (17.319 sec)
# INFO:tensorflow:global_step/sec: 5.74133
# INFO:tensorflow:loss = 5.1414647, step = 13200 (17.417 sec)
# INFO:tensorflow:lr = 0.00033654703 (17.417 sec)
# INFO:tensorflow:global_step/sec: 5.68713
# INFO:tensorflow:loss = 5.3824673, step = 13300 (17.588 sec)
# INFO:tensorflow:lr = 0.00033833904 (17.587 sec)
# INFO:tensorflow:global_step/sec: 5.80808
# INFO:tensorflow:loss = 5.1702623, step = 13400 (17.215 sec)
# INFO:tensorflow:lr = 0.00034013108 (17.215 sec)
# INFO:tensorflow:global_step/sec: 5.77789
# INFO:tensorflow:loss = 5.2821317, step = 13500 (17.306 sec)
# INFO:tensorflow:lr = 0.0003419231 (17.307 sec)
# INFO:tensorflow:global_step/sec: 5.77108
# INFO:tensorflow:loss = 5.184595, step = 13600 (17.326 sec)
# INFO:tensorflow:lr = 0.0003437151 (17.325 sec)
# INFO:tensorflow:global_step/sec: 5.79995
# INFO:tensorflow:loss = 5.29101, step = 13700 (17.243 sec)
# INFO:tensorflow:lr = 0.0003455071 (17.244 sec)
# INFO:tensorflow:global_step/sec: 5.77574
# INFO:tensorflow:loss = 5.205954, step = 13800 (17.314 sec)
# INFO:tensorflow:lr = 0.00034729912 (17.316 sec)
# INFO:tensorflow:global_step/sec: 5.76386
# INFO:tensorflow:loss = 5.293548, step = 13900 (17.346 sec)
# INFO:tensorflow:lr = 0.0003490912 (17.345 sec)
# INFO:tensorflow:global_step/sec: 5.79628
# INFO:tensorflow:loss = 5.1779566, step = 14000 (17.255 sec)
# INFO:tensorflow:lr = 0.0003508832 (17.256 sec)
# INFO:tensorflow:global_step/sec: 5.76611
# INFO:tensorflow:loss = 5.148273, step = 14100 (17.344 sec)
# INFO:tensorflow:lr = 0.00035267524 (17.343 sec)
# INFO:tensorflow:global_step/sec: 5.78659
# INFO:tensorflow:loss = 5.26929, step = 14200 (17.280 sec)
# INFO:tensorflow:lr = 0.00035446728 (17.281 sec)
# INFO:tensorflow:global_step/sec: 5.80907
# INFO:tensorflow:loss = 5.1386, step = 14300 (17.216 sec)
# INFO:tensorflow:lr = 0.0003562593 (17.215 sec)
# INFO:tensorflow:global_step/sec: 5.75338
# INFO:tensorflow:loss = 5.3127985, step = 14400 (17.379 sec)
# INFO:tensorflow:lr = 0.0003580513 (17.379 sec)
# INFO:tensorflow:global_step/sec: 5.70138
# INFO:tensorflow:loss = 5.1795096, step = 14500 (17.542 sec)
# INFO:tensorflow:lr = 0.0003598433 (17.541 sec)
# INFO:tensorflow:global_step/sec: 5.7809
# INFO:tensorflow:loss = 4.9934916, step = 14600 (17.297 sec)
# INFO:tensorflow:lr = 0.00036163532 (17.299 sec)
# INFO:tensorflow:global_step/sec: 5.79672
# INFO:tensorflow:loss = 5.198742, step = 14700 (17.249 sec)
# INFO:tensorflow:lr = 0.00036342733 (17.247 sec)
# INFO:tensorflow:global_step/sec: 5.75737
# INFO:tensorflow:loss = 5.2617154, step = 14800 (17.369 sec)
# INFO:tensorflow:lr = 0.0003652194 (17.370 sec)
# INFO:tensorflow:global_step/sec: 5.79188
# INFO:tensorflow:loss = 5.2739134, step = 14900 (17.268 sec)
# INFO:tensorflow:lr = 0.0003670114 (17.268 sec)
# INFO:tensorflow:global_step/sec: 5.71902
# INFO:tensorflow:loss = 5.3581967, step = 15000 (17.484 sec)
# INFO:tensorflow:lr = 0.00036880345 (17.483 sec)
# INFO:tensorflow:global_step/sec: 5.71423
# INFO:tensorflow:loss = 5.1808405, step = 15100 (17.502 sec)
# INFO:tensorflow:lr = 0.0003705955 (17.503 sec)
# INFO:tensorflow:global_step/sec: 5.76723
# INFO:tensorflow:loss = 5.2987924, step = 15200 (17.340 sec)
# INFO:tensorflow:lr = 0.0003723875 (17.339 sec)
# INFO:tensorflow:global_step/sec: 5.7971
# INFO:tensorflow:loss = 5.149607, step = 15300 (17.248 sec)
# INFO:tensorflow:lr = 0.0003741795 (17.249 sec)
# INFO:tensorflow:global_step/sec: 5.71516
# INFO:tensorflow:loss = 5.0532355, step = 15400 (17.499 sec)
# INFO:tensorflow:lr = 0.00037597152 (17.498 sec)
# INFO:tensorflow:global_step/sec: 5.5228
# INFO:tensorflow:loss = 5.282514, step = 15500 (18.106 sec)
# INFO:tensorflow:lr = 0.00037776353 (18.108 sec)
# INFO:tensorflow:global_step/sec: 5.50495
# INFO:tensorflow:loss = 5.0467196, step = 15600 (18.166 sec)
# INFO:tensorflow:lr = 0.0003795556 (18.164 sec)
# INFO:tensorflow:global_step/sec: 5.37833
# INFO:tensorflow:loss = 5.134897, step = 15700 (18.591 sec)
# INFO:tensorflow:lr = 0.0003813476 (18.594 sec)
# INFO:tensorflow:global_step/sec: 5.45334
# INFO:tensorflow:loss = 5.2119546, step = 15800 (18.340 sec)
# INFO:tensorflow:lr = 0.00038313962 (18.337 sec)
# INFO:tensorflow:global_step/sec: 5.53218
# INFO:tensorflow:loss = 5.152189, step = 15900 (18.077 sec)
# INFO:tensorflow:lr = 0.00038493166 (18.077 sec)
# INFO:tensorflow:global_step/sec: 5.59862
# INFO:tensorflow:loss = 5.066285, step = 16000 (17.861 sec)
# INFO:tensorflow:lr = 0.00038672367 (17.860 sec)
# INFO:tensorflow:global_step/sec: 5.526
# INFO:tensorflow:loss = 5.05232, step = 16100 (18.093 sec)
# INFO:tensorflow:lr = 0.0003885157 (18.096 sec)
# INFO:tensorflow:global_step/sec: 5.54603
# INFO:tensorflow:loss = 5.288285, step = 16200 (18.030 sec)
# INFO:tensorflow:lr = 0.00039030772 (18.029 sec)
# INFO:tensorflow:global_step/sec: 5.58022
# INFO:tensorflow:loss = 5.15377, step = 16300 (17.922 sec)
# INFO:tensorflow:lr = 0.00039209973 (17.921 sec)
# INFO:tensorflow:global_step/sec: 5.56425
# INFO:tensorflow:loss = 5.122006, step = 16400 (17.971 sec)
# INFO:tensorflow:lr = 0.00039389174 (17.972 sec)
# INFO:tensorflow:global_step/sec: 5.62298
# INFO:tensorflow:loss = 5.1444817, step = 16500 (17.787 sec)
# INFO:tensorflow:lr = 0.00039568378 (17.786 sec)
# INFO:tensorflow:global_step/sec: 5.66262
# INFO:tensorflow:loss = 5.2217693, step = 16600 (17.660 sec)
# INFO:tensorflow:lr = 0.00039747581 (17.662 sec)
# INFO:tensorflow:global_step/sec: 5.69212
# INFO:tensorflow:loss = 5.119979, step = 16700 (17.567 sec)
# INFO:tensorflow:lr = 0.00039926782 (17.565 sec)
# INFO:tensorflow:global_step/sec: 5.52628
# INFO:tensorflow:loss = 5.2818193, step = 16800 (18.095 sec)
# INFO:tensorflow:lr = 0.00040105986 (18.097 sec)
# INFO:tensorflow:global_step/sec: 5.65965
# INFO:tensorflow:loss = 5.1875734, step = 16900 (17.671 sec)
# INFO:tensorflow:lr = 0.00040285187 (17.668 sec)
# INFO:tensorflow:global_step/sec: 5.72285
# INFO:tensorflow:loss = 5.206165, step = 17000 (17.472 sec)
# INFO:tensorflow:lr = 0.0004046439 (17.475 sec)
# INFO:tensorflow:global_step/sec: 5.6383
# INFO:tensorflow:loss = 5.128683, step = 17100 (17.737 sec)
# INFO:tensorflow:lr = 0.00040643592 (17.735 sec)
# INFO:tensorflow:global_step/sec: 5.66317
# INFO:tensorflow:loss = 5.1695485, step = 17200 (17.656 sec)
# INFO:tensorflow:lr = 0.00040822793 (17.657 sec)
# INFO:tensorflow:global_step/sec: 5.64222
# INFO:tensorflow:loss = 5.0631948, step = 17300 (17.721 sec)
# INFO:tensorflow:lr = 0.00041001994 (17.721 sec)
# INFO:tensorflow:global_step/sec: 5.68331
# INFO:tensorflow:loss = 5.195368, step = 17400 (17.598 sec)
# INFO:tensorflow:lr = 0.00041181198 (17.599 sec)
# INFO:tensorflow:global_step/sec: 5.68752
# INFO:tensorflow:loss = 5.1441555, step = 17500 (17.582 sec)
# INFO:tensorflow:lr = 0.00041360402 (17.581 sec)
# INFO:tensorflow:global_step/sec: 5.68024
# INFO:tensorflow:loss = 4.9919033, step = 17600 (17.606 sec)
# INFO:tensorflow:lr = 0.00041539603 (17.605 sec)
# INFO:tensorflow:global_step/sec: 5.62205
# INFO:tensorflow:loss = 5.2591033, step = 17700 (17.784 sec)
# INFO:tensorflow:lr = 0.00041718807 (17.786 sec)
# INFO:tensorflow:global_step/sec: 5.7186
# INFO:tensorflow:loss = 5.303919, step = 17800 (17.492 sec)
# INFO:tensorflow:lr = 0.00041898008 (17.489 sec)
# INFO:tensorflow:global_step/sec: 5.62652
# INFO:tensorflow:loss = 5.0888457, step = 17900 (17.771 sec)
# INFO:tensorflow:lr = 0.0004207721 (17.772 sec)
# INFO:tensorflow:global_step/sec: 5.61005
# INFO:tensorflow:loss = 5.0457964, step = 18000 (17.829 sec)
# INFO:tensorflow:lr = 0.00042256413 (17.827 sec)
# INFO:tensorflow:global_step/sec: 5.4981
# INFO:tensorflow:loss = 5.1671777, step = 18100 (18.183 sec)
# INFO:tensorflow:lr = 0.00042435614 (18.184 sec)
# INFO:tensorflow:global_step/sec: 5.49312
# INFO:tensorflow:loss = 5.116601, step = 18200 (18.203 sec)
# INFO:tensorflow:lr = 0.00042614815 (18.202 sec)
# INFO:tensorflow:global_step/sec: 5.67809
# INFO:tensorflow:loss = 5.030267, step = 18300 (17.611 sec)
# INFO:tensorflow:lr = 0.0004279402 (17.612 sec)
# INFO:tensorflow:global_step/sec: 5.55415
# INFO:tensorflow:loss = 5.2628818, step = 18400 (18.008 sec)
# INFO:tensorflow:lr = 0.0004297322 (18.009 sec)
# INFO:tensorflow:global_step/sec: 5.44347
# INFO:tensorflow:loss = 5.2023635, step = 18500 (18.370 sec)
# INFO:tensorflow:lr = 0.00043152424 (18.368 sec)
# INFO:tensorflow:global_step/sec: 5.55052
# INFO:tensorflow:loss = 5.193511, step = 18600 (18.021 sec)
# INFO:tensorflow:lr = 0.00043331628 (18.020 sec)
# INFO:tensorflow:global_step/sec: 5.56469
# INFO:tensorflow:loss = 5.112028, step = 18700 (17.971 sec)
# INFO:tensorflow:lr = 0.0004351083 (17.972 sec)
# INFO:tensorflow:global_step/sec: 5.54531
# INFO:tensorflow:loss = 5.1400914, step = 18800 (18.028 sec)
# INFO:tensorflow:lr = 0.0004369003 (18.030 sec)
# INFO:tensorflow:global_step/sec: 5.44515
# INFO:tensorflow:loss = 5.090801, step = 18900 (18.368 sec)
# INFO:tensorflow:lr = 0.0004386923 (18.367 sec)
# INFO:tensorflow:global_step/sec: 5.51311
# INFO:tensorflow:loss = 5.1201725, step = 19000 (18.133 sec)
# INFO:tensorflow:lr = 0.00044048435 (18.133 sec)
# INFO:tensorflow:global_step/sec: 5.65876
# INFO:tensorflow:loss = 5.0130315, step = 19100 (17.672 sec)
# INFO:tensorflow:lr = 0.00044227636 (17.672 sec)
# INFO:tensorflow:global_step/sec: 5.68661
# INFO:tensorflow:loss = 5.1428823, step = 19200 (17.588 sec)
# INFO:tensorflow:lr = 0.0004440684 (17.588 sec)
# INFO:tensorflow:global_step/sec: 5.57183
# INFO:tensorflow:loss = 5.1275516, step = 19300 (17.949 sec)
# INFO:tensorflow:lr = 0.0004458604 (17.948 sec)
# INFO:tensorflow:global_step/sec: 5.51671
# INFO:tensorflow:loss = 5.2532444, step = 19400 (18.122 sec)
# INFO:tensorflow:lr = 0.00044765242 (18.125 sec)
# INFO:tensorflow:global_step/sec: 5.44818
# INFO:tensorflow:loss = 5.1078568, step = 19500 (18.359 sec)
# INFO:tensorflow:lr = 0.0004494445 (18.357 sec)
# INFO:tensorflow:global_step/sec: 5.42133
# INFO:tensorflow:loss = 5.2181325, step = 19600 (18.441 sec)
# INFO:tensorflow:lr = 0.0004512365 (18.441 sec)
# INFO:tensorflow:global_step/sec: 5.55525
# INFO:tensorflow:loss = 5.173723, step = 19700 (18.002 sec)
# INFO:tensorflow:lr = 0.0004530285 (18.006 sec)
# INFO:tensorflow:global_step/sec: 5.70787
# INFO:tensorflow:loss = 4.957989, step = 19800 (17.519 sec)
# INFO:tensorflow:lr = 0.00045482052 (17.521 sec)
# INFO:tensorflow:global_step/sec: 5.69778
# INFO:tensorflow:loss = 4.8827667, step = 19900 (17.553 sec)
# INFO:tensorflow:lr = 0.00045661256 (17.547 sec)
# INFO:tensorflow:global_step/sec: 5.67273
# INFO:tensorflow:loss = 5.2058606, step = 20000 (17.629 sec)
# INFO:tensorflow:lr = 0.0004584046 (17.630 sec)
# INFO:tensorflow:global_step/sec: 5.71107
# INFO:tensorflow:loss = 5.0523634, step = 20100 (17.510 sec)
# INFO:tensorflow:lr = 0.0004601966 (17.510 sec)
# INFO:tensorflow:global_step/sec: 5.69436
# INFO:tensorflow:loss = 5.2047043, step = 20200 (17.559 sec)
# INFO:tensorflow:lr = 0.00046198862 (17.562 sec)
# INFO:tensorflow:global_step/sec: 5.59051
# INFO:tensorflow:loss = 4.9823465, step = 20300 (17.888 sec)
# INFO:tensorflow:lr = 0.00046378063 (17.886 sec)
# INFO:tensorflow:global_step/sec: 5.68509
# INFO:tensorflow:loss = 5.109373, step = 20400 (17.591 sec)
# INFO:tensorflow:lr = 0.00046557267 (17.591 sec)
# INFO:tensorflow:global_step/sec: 5.64215
# INFO:tensorflow:loss = 5.0853004, step = 20500 (17.723 sec)
# INFO:tensorflow:lr = 0.0004673647 (17.722 sec)
# INFO:tensorflow:global_step/sec: 5.64801
# INFO:tensorflow:loss = 5.1459255, step = 20600 (17.705 sec)
# INFO:tensorflow:lr = 0.00046915672 (17.708 sec)
# INFO:tensorflow:global_step/sec: 5.66528
# INFO:tensorflow:loss = 5.0390425, step = 20700 (17.651 sec)
# INFO:tensorflow:lr = 0.00047094873 (17.651 sec)
# INFO:tensorflow:global_step/sec: 5.67081
# INFO:tensorflow:loss = 5.095134, step = 20800 (17.632 sec)
# INFO:tensorflow:lr = 0.00047274074 (17.629 sec)
# INFO:tensorflow:global_step/sec: 5.6592
# INFO:tensorflow:loss = 5.223586, step = 20900 (17.671 sec)
# INFO:tensorflow:lr = 0.0004745328 (17.673 sec)
# INFO:tensorflow:global_step/sec: 5.67661
# INFO:tensorflow:loss = 5.240507, step = 21000 (17.619 sec)
# INFO:tensorflow:lr = 0.0004763248 (17.618 sec)
# INFO:tensorflow:global_step/sec: 5.68337
# INFO:tensorflow:loss = 5.061335, step = 21100 (17.596 sec)
# INFO:tensorflow:lr = 0.00047811682 (17.597 sec)
# INFO:tensorflow:global_step/sec: 5.61772
# INFO:tensorflow:loss = 5.0669756, step = 21200 (17.802 sec)
# INFO:tensorflow:lr = 0.00047990883 (17.800 sec)
# INFO:tensorflow:global_step/sec: 5.60351
# INFO:tensorflow:loss = 5.1063027, step = 21300 (17.845 sec)
# INFO:tensorflow:lr = 0.00048170084 (17.847 sec)
# INFO:tensorflow:global_step/sec: 5.65803
# INFO:tensorflow:loss = 5.116361, step = 21400 (17.670 sec)
# INFO:tensorflow:lr = 0.0004834929 (17.670 sec)
# INFO:tensorflow:global_step/sec: 5.68869
# INFO:tensorflow:loss = 5.1523676, step = 21500 (17.580 sec)
# INFO:tensorflow:lr = 0.00048528492 (17.580 sec)
# INFO:tensorflow:global_step/sec: 5.66092
# INFO:tensorflow:loss = 5.1027284, step = 21600 (17.666 sec)
# INFO:tensorflow:lr = 0.00048707693 (17.666 sec)
# INFO:tensorflow:global_step/sec: 5.66232
# INFO:tensorflow:loss = 5.0469937, step = 21700 (17.660 sec)
# INFO:tensorflow:lr = 0.0004888689 (17.660 sec)
# INFO:tensorflow:global_step/sec: 5.62154
# INFO:tensorflow:loss = 5.1663, step = 21800 (17.787 sec)
# INFO:tensorflow:lr = 0.000490661 (17.787 sec)
# INFO:tensorflow:global_step/sec: 5.69327
# INFO:tensorflow:loss = 5.1286993, step = 21900 (17.569 sec)
# INFO:tensorflow:lr = 0.000492453 (17.568 sec)
# INFO:tensorflow:global_step/sec: 5.66261
# INFO:tensorflow:loss = 5.100828, step = 22000 (17.659 sec)
# INFO:tensorflow:lr = 0.00049424503 (17.660 sec)
# INFO:tensorflow:global_step/sec: 5.67863
# INFO:tensorflow:loss = 5.043209, step = 22100 (17.610 sec)
# INFO:tensorflow:lr = 0.000496037 (17.609 sec)
# INFO:tensorflow:global_step/sec: 5.65003
# INFO:tensorflow:loss = 5.229734, step = 22200 (17.700 sec)
# INFO:tensorflow:lr = 0.00049782905 (17.699 sec)
# INFO:tensorflow:global_step/sec: 5.6943
# INFO:tensorflow:loss = 5.1767774, step = 22300 (17.557 sec)
# INFO:tensorflow:lr = 0.0004996211 (17.565 sec)
# INFO:tensorflow:global_step/sec: 5.67977
# INFO:tensorflow:loss = 5.202925, step = 22400 (17.607 sec)
# INFO:tensorflow:lr = 0.00050141313 (17.603 sec)
# INFO:tensorflow:global_step/sec: 5.68136
# INFO:tensorflow:loss = 5.097294, step = 22500 (17.603 sec)
# INFO:tensorflow:lr = 0.0005032051 (17.602 sec)
# INFO:tensorflow:global_step/sec: 5.6899
# INFO:tensorflow:loss = 5.1028204, step = 22600 (17.576 sec)
# INFO:tensorflow:lr = 0.00050499715 (17.574 sec)
# INFO:tensorflow:global_step/sec: 5.6629
# INFO:tensorflow:loss = 5.0464087, step = 22700 (17.661 sec)
# INFO:tensorflow:lr = 0.0005067892 (17.660 sec)
# INFO:tensorflow:global_step/sec: 5.6334
# INFO:tensorflow:loss = 5.1108913, step = 22800 (17.749 sec)
# INFO:tensorflow:lr = 0.00050858123 (17.750 sec)
# INFO:tensorflow:global_step/sec: 5.69649
# INFO:tensorflow:loss = 5.1527996, step = 22900 (17.554 sec)
# INFO:tensorflow:lr = 0.0005103732 (17.555 sec)
# INFO:tensorflow:global_step/sec: 5.66201
# INFO:tensorflow:loss = 5.085236, step = 23000 (17.662 sec)
# INFO:tensorflow:lr = 0.00051216525 (17.662 sec)
# INFO:tensorflow:global_step/sec: 5.63013
# INFO:tensorflow:loss = 4.8304343, step = 23100 (17.761 sec)
# INFO:tensorflow:lr = 0.00051395723 (17.759 sec)
# INFO:tensorflow:global_step/sec: 5.68747
# INFO:tensorflow:loss = 5.148002, step = 23200 (17.586 sec)
# INFO:tensorflow:lr = 0.0005157493 (17.585 sec)
# INFO:tensorflow:global_step/sec: 5.68243
# INFO:tensorflow:loss = 5.1188664, step = 23300 (17.593 sec)
# INFO:tensorflow:lr = 0.0005175413 (17.596 sec)
# INFO:tensorflow:global_step/sec: 5.72718
# INFO:tensorflow:loss = 5.0782394, step = 23400 (17.461 sec)
# INFO:tensorflow:lr = 0.00051933335 (17.460 sec)
# INFO:tensorflow:global_step/sec: 5.62781
# INFO:tensorflow:loss = 5.105462, step = 23500 (17.770 sec)
# INFO:tensorflow:lr = 0.00052112533 (17.770 sec)
# INFO:tensorflow:global_step/sec: 5.63689
# INFO:tensorflow:loss = 5.2122817, step = 23600 (17.743 sec)
# INFO:tensorflow:lr = 0.0005229174 (17.742 sec)
# INFO:tensorflow:global_step/sec: 5.64163
# INFO:tensorflow:loss = 5.0668473, step = 23700 (17.721 sec)
# INFO:tensorflow:lr = 0.0005247094 (17.721 sec)
# INFO:tensorflow:global_step/sec: 5.58219
# INFO:tensorflow:loss = 5.088018, step = 23800 (17.923 sec)
# INFO:tensorflow:lr = 0.00052650145 (17.924 sec)
# INFO:tensorflow:global_step/sec: 5.72413
# INFO:tensorflow:loss = 5.2222123, step = 23900 (17.466 sec)
# INFO:tensorflow:lr = 0.0005282934 (17.465 sec)
# INFO:tensorflow:global_step/sec: 5.68847
# INFO:tensorflow:loss = 5.05515, step = 24000 (17.579 sec)
# INFO:tensorflow:lr = 0.00053008547 (17.579 sec)
# INFO:tensorflow:global_step/sec: 5.72711
# INFO:tensorflow:loss = 5.0032654, step = 24100 (17.461 sec)
# INFO:tensorflow:lr = 0.0005318775 (17.461 sec)
# INFO:tensorflow:global_step/sec: 5.74494
# INFO:tensorflow:loss = 5.127228, step = 24200 (17.406 sec)
# INFO:tensorflow:lr = 0.00053366955 (17.407 sec)
# INFO:tensorflow:global_step/sec: 5.69085
# INFO:tensorflow:loss = 5.0010223, step = 24300 (17.572 sec)
# INFO:tensorflow:lr = 0.0005354615 (17.571 sec)
# INFO:tensorflow:global_step/sec: 5.6797
# INFO:tensorflow:loss = 5.11873, step = 24400 (17.604 sec)
# INFO:tensorflow:lr = 0.00053725357 (17.606 sec)
# INFO:tensorflow:global_step/sec: 5.64735
# INFO:tensorflow:loss = 5.1667886, step = 24500 (17.705 sec)
# INFO:tensorflow:lr = 0.0005390456 (17.705 sec)
# INFO:tensorflow:global_step/sec: 5.68179
# INFO:tensorflow:loss = 5.031388, step = 24600 (17.601 sec)
# INFO:tensorflow:lr = 0.00054083765 (17.602 sec)
# INFO:tensorflow:global_step/sec: 5.67027
# INFO:tensorflow:loss = 5.143016, step = 24700 (17.639 sec)
# INFO:tensorflow:lr = 0.0005426296 (17.638 sec)
# INFO:tensorflow:global_step/sec: 5.66014
# INFO:tensorflow:loss = 5.1861973, step = 24800 (17.667 sec)
# INFO:tensorflow:lr = 0.00054442167 (17.667 sec)
# INFO:tensorflow:global_step/sec: 5.65387
# INFO:tensorflow:loss = 5.1622047, step = 24900 (17.688 sec)
# INFO:tensorflow:lr = 0.00054621365 (17.688 sec)
# INFO:tensorflow:global_step/sec: 5.63044
# INFO:tensorflow:loss = 5.103351, step = 25000 (17.758 sec)
# INFO:tensorflow:lr = 0.00054800574 (17.762 sec)
# INFO:tensorflow:global_step/sec: 5.67628
# INFO:tensorflow:loss = 5.2637897, step = 25100 (17.617 sec)
# INFO:tensorflow:lr = 0.0005497977 (17.616 sec)
# INFO:tensorflow:global_step/sec: 5.66641
# INFO:tensorflow:loss = 5.125005, step = 25200 (17.646 sec)
# INFO:tensorflow:lr = 0.00055158976 (17.644 sec)
# INFO:tensorflow:global_step/sec: 5.65318
# INFO:tensorflow:loss = 5.106142, step = 25300 (17.694 sec)
# INFO:tensorflow:lr = 0.00055338175 (17.692 sec)
# INFO:tensorflow:global_step/sec: 5.66411
# INFO:tensorflow:loss = 4.946365, step = 25400 (17.652 sec)
# INFO:tensorflow:lr = 0.00055517384 (17.654 sec)
# INFO:tensorflow:global_step/sec: 5.64393
# INFO:tensorflow:loss = 5.1380897, step = 25500 (17.717 sec)
# INFO:tensorflow:lr = 0.0005569658 (17.717 sec)
# INFO:tensorflow:global_step/sec: 5.65771
# INFO:tensorflow:loss = 5.113091, step = 25600 (17.678 sec)
# INFO:tensorflow:lr = 0.00055875786 (17.678 sec)
# INFO:tensorflow:global_step/sec: 5.67387
# INFO:tensorflow:loss = 5.091294, step = 25700 (17.621 sec)
# INFO:tensorflow:lr = 0.00056054984 (17.621 sec)
# INFO:tensorflow:global_step/sec: 5.65693
# INFO:tensorflow:loss = 5.0216093, step = 25800 (17.679 sec)
# INFO:tensorflow:lr = 0.0005623419 (17.679 sec)
# INFO:tensorflow:global_step/sec: 5.61909
# INFO:tensorflow:loss = 4.9964194, step = 25900 (17.798 sec)
# INFO:tensorflow:lr = 0.0005641339 (17.802 sec)
# INFO:tensorflow:global_step/sec: 5.69715
# INFO:tensorflow:loss = 5.08887, step = 26000 (17.554 sec)
# INFO:tensorflow:lr = 0.00056592596 (17.549 sec)
# INFO:tensorflow:global_step/sec: 5.61861
# INFO:tensorflow:loss = 5.054116, step = 26100 (17.796 sec)
# INFO:tensorflow:lr = 0.00056771794 (17.798 sec)
# INFO:tensorflow:global_step/sec: 5.67455
# INFO:tensorflow:loss = 5.1030607, step = 26200 (17.621 sec)
# INFO:tensorflow:lr = 0.00056951 (17.620 sec)
# INFO:tensorflow:global_step/sec: 5.78375
# INFO:tensorflow:loss = 5.2808595, step = 26300 (17.289 sec)
# INFO:tensorflow:lr = 0.000571302 (17.289 sec)
# INFO:tensorflow:global_step/sec: 5.67886
# INFO:tensorflow:loss = 5.0918384, step = 26400 (17.611 sec)
# INFO:tensorflow:lr = 0.00057309406 (17.610 sec)
# INFO:tensorflow:global_step/sec: 5.69972
# INFO:tensorflow:loss = 5.0430417, step = 26500 (17.547 sec)
# INFO:tensorflow:lr = 0.00057488604 (17.548 sec)
# INFO:tensorflow:global_step/sec: 5.70912
# INFO:tensorflow:loss = 4.895256, step = 26600 (17.514 sec)
# INFO:tensorflow:lr = 0.0005766781 (17.516 sec)
# INFO:tensorflow:global_step/sec: 5.66728
# INFO:tensorflow:loss = 5.126784, step = 26700 (17.642 sec)
# INFO:tensorflow:lr = 0.00057847006 (17.641 sec)
# INFO:tensorflow:global_step/sec: 5.75097
# INFO:tensorflow:loss = 5.1031322, step = 26800 (17.388 sec)
# INFO:tensorflow:lr = 0.00058026216 (17.390 sec)
# INFO:tensorflow:global_step/sec: 5.79297
# INFO:tensorflow:loss = 5.0155306, step = 26900 (17.263 sec)
# INFO:tensorflow:lr = 0.00058205414 (17.261 sec)
# INFO:tensorflow:global_step/sec: 5.78445
# INFO:tensorflow:loss = 5.090794, step = 27000 (17.292 sec)
# INFO:tensorflow:lr = 0.0005838462 (17.291 sec)
# INFO:tensorflow:global_step/sec: 5.79792
# INFO:tensorflow:loss = 4.9089007, step = 27100 (17.247 sec)
# INFO:tensorflow:lr = 0.00058563816 (17.247 sec)
# INFO:tensorflow:global_step/sec: 5.77386
# INFO:tensorflow:loss = 5.0093284, step = 27200 (17.318 sec)
# ...
# INFO:tensorflow:lr = 0.000107598134 (17.582 sec)
# INFO:tensorflow:global_step/sec: 5.65328
# INFO:tensorflow:loss = 4.892098, step = 77800 (17.686 sec)
# INFO:tensorflow:lr = 0.000105806124 (17.685 sec)
# INFO:tensorflow:global_step/sec: 5.65411
# INFO:tensorflow:loss = 4.8988714, step = 77900 (17.689 sec)
# INFO:tensorflow:lr = 0.00010401411 (17.689 sec)
# INFO:tensorflow:global_step/sec: 5.65179
# INFO:tensorflow:loss = 4.8487144, step = 78000 (17.691 sec)
# INFO:tensorflow:lr = 0.0001022221 (17.691 sec)
# INFO:tensorflow:global_step/sec: 5.66983
# INFO:tensorflow:loss = 4.8597016, step = 78100 (17.636 sec)
# INFO:tensorflow:lr = 0.00010043008 (17.636 sec)
# INFO:tensorflow:Saving checkpoints for 78125 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.024053.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3df7de64a8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3df7de64a8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/seq2seq/python/ops/beam_search_decoder.py:971: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/seq2seq/python/ops/beam_search_decoder.py:1252: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-78125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ------------
# unit test
# Q: 你 好
# A1: 你 好
# A2: 你 好 ！
# A3: 我 好
#
# Q: 早 上 好
# A1: 早 上 好
# A2: 早 上 好 ！
# A3: 晚 上 好
#
# Q: 晚 上 好
# A1: 晚 上 好
# A2: 晚 上 好 ！
# A3: 晚 安
#
# Q: 再 见
# A1: 再 见
# A2: 哈 哈
# A3: 再 见 再 见
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 是 啊
# A3: 好 久 不 见 啊
#
# Q: 想 死 你 了
# A1: 我 也 想 你
# A2: 我 也 想
# A3: 我 也 想 死
#
# Q: 谢 谢 你
# A1: 不 客 气
# A2: 不 用 谢
# A3: 客 气
#
# Q: 爱 你
# A1: 我 也 爱 你
# A2: 爱 你
# A3: 我 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 厉 害 了
# A2: 哈 哈
# A3: 不 厉 害
#
# Q: 你 叫 什 么
# A1: 你 猜
# A2: 不 知 道
# A3: 我 叫 什 么
#
# Q: 你 几 岁 了
# A1: 问 女 孩 子 年 龄 可 不 是 绅 士 所 为 哦 ~
# A2: 问 女 孩 子 年 龄 可 不 是 绅 士 所 为 哦 ~ ~
# A3: 问 女 孩 子 年 龄 可 不 是 绅 士 所 为 ~
#
# Q: 现 在 几 点
# A1: 1 0 点
# A2: 1 1 点
# A3: 1 2 点
#
# Q: 今 天 天 气 怎 么 样
# A1: 挺 好 的
# A2: 今 天 天 气 好
# A3: 今 天 天 气 不 错
#
# Q: 你 今 天 心 情 好 吗
# A1: 不 好
# A2: 心 情 好
# A3: 心 情 不 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 你 们 在 哪 里
# A2: 你 在 哪 里
# A3: 你 在 哪 里 ？
#
# Q: 讲 个 笑 话
# A1: 笑 话
# A2: 哈 哈
# A3: 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈
#
# Q: 你 会 几 种 语 言 呀
# A1: 不 会
# A2: 一 种 语 言
# A3: 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈 哈
#
# Q: 你 觉 得 我 帅 吗
# A1: 不 帅
# A2: 我 觉 得 你 帅
# A3: 我 觉 得 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 哈 哈
# A2: 我 也 是
# A3: 我 也 讨 厌
#
# Q: 好 烦 啊
# A1: 哈 哈
# A2: 怎 么 了 ？
# A3: 怎 么 了
#
# Q: 天 气 真 好
# A1: 是 啊
# A2: 是 的
# A3: 天 气 真 好
#
# Q: 今 天 好 冷
# A1: 是 啊
# A2: 我 也 是
# A3: 今 天 好 冷
#
# Q: 今 天 好 热
# A1: 是 啊
# A2: 我 也 是
# A3: 好 热 啊
#
# Q: 下 雨 了
# A1: 是 啊
# A2: 是 的
# A3: 下 雨 了
#
# Q: 风 好 大
# A1: 是 的
# A2: 是 啊
# A3: 哈 哈
#
# Q: 终 于 周 五 了
# A1: 是 的
# A2: 我 也 是
# A3: 我 也 是 周 五
#
# Q: 我 想 去 唱 歌
# A1: 来 吧
# A2: 来 吧 来 吧
# A3: 来 啊 来 啊
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3df80b3f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3df80b3f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-28T04:42:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-78125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-08-28-04:42:55
# INFO:tensorflow:Saving dict for global step 78125: global_step = 78125, loss = 3.7196558
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78125: ../model/lstm_seq2seq/model.ckpt-78125
# Perplexity: 41.250
# Best Perplexity: 41.250
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3e10187fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3e10187fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3043, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3043,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-78125
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 78125 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 4.861157, step = 78125
# INFO:tensorflow:lr = 0.000100008925
# INFO:tensorflow:global_step/sec: 5.24386
# INFO:tensorflow:loss = 4.863012, step = 78225 (19.076 sec)
# INFO:tensorflow:lr = 0.000100904974 (19.077 sec)
# INFO:tensorflow:global_step/sec: 5.60323
# INFO:tensorflow:loss = 4.898035, step = 78325 (17.842 sec)
# INFO:tensorflow:lr = 0.00010180094 (17.842 sec)
# INFO:tensorflow:global_step/sec: 5.52429
# INFO:tensorflow:loss = 5.027878, step = 78425 (18.102 sec)
# INFO:tensorflow:lr = 0.00010269699 (18.103 sec)
# INFO:tensorflow:global_step/sec: 5.50753
# INFO:tensorflow:loss = 4.8898134, step = 78525 (18.163 sec)
# INFO:tensorflow:lr = 0.00010359304 (18.160 sec)
# INFO:tensorflow:global_step/sec: 5.51503
# INFO:tensorflow:loss = 4.967149, step = 78625 (18.132 sec)
# INFO:tensorflow:lr = 0.000104489 (18.132 sec)
# INFO:tensorflow:global_step/sec: 5.53581
# INFO:tensorflow:loss = 4.862857, step = 78725 (18.062 sec)
# INFO:tensorflow:lr = 0.00010538505 (18.064 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8df9e51aaaed> in <module>()
#      20
#      21 while True:
# ---> 22   estimator.train(input_fn=lambda: dataset(is_training=True, params=params))
#      23
#      24   unit_test(estimator)
#
# /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1194                                              hooks, global_step_tensor,
# -> 1195                                              saving_listeners)
#    1196
#    1197   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /tensorflow-1.15.2/python3.6/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1492       any_step_done = False
#    1493       while not mon_sess.should_stop():
# -> 1494         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1495         any_step_done = True
#    1496     if not any_step_done:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1257             feed_dict=feed_dict,
#    1258             options=options,
# -> 1259             run_metadata=run_metadata)
#    1260       except _PREEMPTION_ERRORS as e:
#    1261         logging.info(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
