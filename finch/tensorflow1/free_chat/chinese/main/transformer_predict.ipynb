# %%
"""
We use following lines because we are running on Google Colab
If you are running notebook on a local computer, you don't need this cell
"""
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese/main')

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import time

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.0
# GPU Enabled: False

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

def parse_fn(text):
  parse = lambda text: [[params['char2idx'].get(c, len(params['char2idx'])) for c in list(text)]]
  return {'words': parse(text)}

# %%
params = {'export_dir': '../model/transformer_export'}

params['char2idx'] = get_vocab('../vocab/char.txt')

params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}

subdirs = [x for x in Path(params['export_dir']).iterdir()
           if x.is_dir() and 'temp' not in str(x)]
latest = str(sorted(subdirs)[-1])
print(latest)

predict_fn = tf.contrib.predictor.from_saved_model(latest)
# Out:
# ../model/transformer_export/1576026596
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from ../model/transformer_export/1576026596/variables/variables

# %%
while True:
  text_inp = input('Input:')
  t0 = time.time()
  predictions = predict_fn(parse_fn(text_inp))
  #print('Shape:', predictions['output'].shape)
  max_len = 0
  output = None
  for j in range(3):
    indices = [params['idx2char'].get(idx, len(params['idx2char'])) for idx in predictions['output'][0, :, j] if (idx != 0 and idx != 2)]
    sent = ' '.join(indices)
    if len(indices) > max_len:
      max_len = len(indices)
      output = sent
    #print('Rank_{}:'.format(j+1), sent)
  print('Output:', output)
  print('Cost %.2f sec' % (time.time() - t0))
  print()
# Out:
# Input:你好
# Output: 主 人 你 好 O ( ∩ _ ∩ ) O
# Cost 3.50 sec
#
# Input:早上好
# Output: 早 上 好 ！
# Cost 0.25 sec
#
# Input:晚上好
# Output: 晚 上 好 ， 主 人 。
# Cost 0.26 sec
#
# Input:再见
# Output: 再 见 ！ ！
# Cost 0.21 sec
#
# Input:好久不见
# Output: 好 久 不 见 !
# Cost 0.30 sec
#
# Input:想死你了
# Output: 我 也 想 死 你 了
# Cost 0.24 sec
#
# Input:谢谢你
# Output: 谢 谢 我
# Cost 0.22 sec
#
# Input:爱你
# Output: 我 也 爱 你 ！
# Cost 0.30 sec
#
# Input:你叫什么名字
# Output: 我 的 名 字 叫 小 点 。
# Cost 0.34 sec
#
# Input:你几岁了
# Output: 我 主 人 几 岁 了
# Cost 0.28 sec
#
# Input:现在几点了
# Output: 主 人 几 点 了 ？
# Cost 0.32 sec
#
# Input:今天天气怎么样
# Output: 天 气 怎 么 样 的
# Cost 0.28 sec
#
# Input:我们现在在哪里
# Output: 我 在 你 旁 边
# Cost 0.31 sec
#
# Input:你能给我讲个笑话吗
# Output: 我 给 你 一 个 人 ！
# Cost 0.34 sec
#
# Input:你是男孩还是女孩呀
# Output: 我 是 男 孩 纸
# Cost 0.35 sec
#
# Input:你会几种语言呀
# Output: 全 世 界 语 言 的 我 都 会
# Cost 0.32 sec
#
# Input:你能陪我玩吗
# Output: 我 可 以 陪 你 玩 ~
# Cost 0.28 sec
#
# Input:说话可以大声一点吗
# Output: 可 以 啊
# Cost 0.25 sec
#
# Input:天气真好
# Output: 天 气 好 好 好
# Cost 0.25 sec
#
# Input:天气太糟糕了
# Output: 天 气 预 报 天 气 太 好 了
# Cost 0.34 sec
#
# Input:下雨了
# Output: 下 雨 了 吗 ?
# Cost 0.24 sec
#
# Input:雨好大
# Output: 好 大 雨
# Cost 0.21 sec
#
# Input:我讨厌艳阳天
# Output: 我 也 讨 厌
# Cost 0.26 sec
#
# Input:好晒啊
# Output: 好 好 好 晒
# Cost 0.27 sec
#
# Input:今天好冷
# Output: 我 今 天 也 冷
# Cost 0.27 sec
#
# Input:今天好热
# Output: 今 天 好 热 啊
# Cost 0.27 sec
#
# Input:风好大
# Output: 大 风 是 什 么 ？
# Cost 0.31 sec
#
# Input:雾太大了看不清路
# Output: 看 不 清 ? ?
# Cost 0.42 sec
#
# Input:打雷了好可怕
# Output: 可 怕 的 小 通
# Cost 0.28 sec
#
# Input:下雪了诶
# Output: 下 雪 了 ? ?
# Cost 0.28 sec
#
# Input:好烦啊
# Output: 我 也 好 烦
# Cost 0.28 sec
#
# Input:好开心
# Output: 你 开 心 我 就 开 心
# Cost 0.29 sec
#
# Input:太激动
# Output: 太 激 动 了
# Cost 0.23 sec
#
# Input:我好难过
# Output: 不 要 难 过 我 陪 你
# Cost 0.34 sec
#
# Input:我想哭
# Output: 想 哭 就 哭 吧
# Cost 0.31 sec
#
# Input:太好笑了
# Output: 是 你 太 好 笑 了
# Cost 0.26 sec
#
# Input:我好伤心
# Output: 你 怎 么 伤 心 了 ？
# Cost 0.38 sec
#
# Input:心好痛
# Output: 我 也 心 痛
# Cost 0.33 sec
#
# Input:好累啊
# Output: 好 好 累
# Cost 0.23 sec
#
# Input:我好疲惫
# Output: 疲 惫 就 好
# Cost 0.27 sec
#
# Input:我爱你
# Output: 主 人 我 爱 你
# Cost 0.27 sec
#
# Input:我讨厌你
# Output: 我 也 讨 厌 你
# Cost 0.21 sec
#
# Input:你真是太棒啦
# Output: 我 就 是 真 心 的
# Cost 0.30 sec
#
# Input:你好厉害啊
# Output: 主 人 你 好 O ( ∩ _ ∩ ) O
# Cost 0.35 sec
#
# Input:吓死我了
# Output: 你 吓 死 我 了
# Cost 0.26 sec
#
# Input:我想回家
# Output: 我 也 想 回 家
# Cost 0.24 sec
#
# Input:我想爸妈了
# Output: 我 也 想 妈 妈 了
# Cost 0.25 sec
#
# Input:不知道小孩在家有没有听话
# Output: 没 有 !
# Cost 0.31 sec
#
# Input:想回家撸猫
# Output: 猫 猫 也 爱 你
# Cost 0.29 sec
