# %%
"""
We use following lines because we are running on Google Colab
If you are running notebook on a local computer, you don't need this cell
"""
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese/main')

# %%
# %tensorflow_version 1.x
# !pip install texar

# %%
import tensorflow as tf
import texar.tf as tx

import numpy as np
import pprint
import logging
import copy

from pathlib import Path
from texar.tf.modules import TransformerEncoder, TransformerDecoder

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.0
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_paths, params):
  char2idx = params['char2idx']
  for f_path in f_paths:
    with open(f_path) as f:
      print('Reading', f_path)
      for line in f:
        line = line.rstrip()
        sp = line.split('|')
        if len(sp) == 2:
          source, target = sp
        else:
          continue
        source = [char2idx.get(c, len(char2idx)) for c in list(source)]
        target = [char2idx.get(c, len(char2idx)) for c in list(target)]
        if len(source) > params['max_len']:
          source = source[:params['max_len']]
        if len(target) > params['max_len']:
          target = target[:params['max_len']]
        target_in = [1] + target
        target_out = target + [2]
        if len(source) > 0:
          yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_paths'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_paths'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    #pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    
  
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        embedding = tf.concat([tf.zeros(shape=[1, params['embed_dim']]), embedding[1:, :]], axis=0)
        x = tf.nn.embedding_lookup(embedding, words)
        pos_embedder = tx.modules.SinusoidsPositionEmbedder(
            position_size = params['max_len'] + 1,
            hparams = config_model.position_embedder_hparams)
        x = (x * config_model.hidden_dim ** 0.5) + pos_embedder(sequence_length=words_len)


    with tf.variable_scope('Encoder'):
        encoder = TransformerEncoder(hparams=config_model.encoder)
        enc_out = encoder(inputs=x, sequence_length=words_len)
    
    
    with tf.variable_scope('Decoder'):
        decoder = TransformerDecoder(vocab_size=len(params['char2idx'])+1,
                                     output_layer=tf.transpose(embedding, (1, 0)),
                                     hparams=config_model.decoder)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = (dec_inputs * config_model.hidden_dim ** 0.5) + pos_embedder(sequence_length=dec_seq_len)

            outputs = decoder(
                memory=enc_out,
                memory_sequence_length=words_len,
                inputs=dec_inputs,
                decoding_strategy='train_greedy',
                mode=tf.estimator.ModeKeys.TRAIN
            )
            
            return outputs.logits
        else:
            start_tokens = tf.fill([batch_sz], 1)

            def _embedding_fn(x, y):
                x_w_embed = tf.nn.embedding_lookup(embedding, x)
                y_p_embed = pos_embedder(y)
                return x_w_embed * config_model.hidden_dim ** 0.5 + y_p_embed

            predictions = decoder(
                memory=enc_out,
                memory_sequence_length=words_len,
                beam_width=params['beam_width'],
                length_penalty=params['length_penalty'],
                start_tokens=start_tokens,
                end_token=2,
                embedding=_embedding_fn,
                max_decoding_length=params['max_len'],
                mode=tf.estimator.ModeKeys.PREDICT)
            
            return predictions['sample_id'][:, :, :params['top_k']]

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()
        
        decay_lr = tf.train.exponential_decay(
            params['lr'], global_step, 1000, .99)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def minimal_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去K歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('minimal test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx != 0 and idx != 2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
def is_increasing(history: list) -> bool:
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] >= history[i]:
      return False
  return True

# %%
class config_model:
    hidden_dim = 300
    num_heads = 8
    dropout_rate = .2
    num_blocks = 6

    position_embedder_hparams = {
        'dim': hidden_dim
    }

    encoder = {
        'dim': hidden_dim,
        'embedding_dropout': dropout_rate,
        'residual_dropout': dropout_rate,
        'num_blocks': num_blocks,
        'initializer': {
            'type': 'variance_scaling_initializer',
            'kwargs': {
                'scale': 1.0,
                'mode': 'fan_avg',
                'distribution': 'uniform',
            },
        },
        'multihead_attention': {
            'dropout_rate': dropout_rate,
            'num_heads': num_heads,
            'output_dim': hidden_dim,
            'use_bias': True,
        },
        'poswise_feedforward': {
          'name': 'fnn',
          'layers': [
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv1',
                      'units': hidden_dim * 2,
                      'activation': 'gelu',
                      'use_bias': True,
                  },
              },
              {
                  'type': 'Dropout',
                  'kwargs': {
                      'rate': dropout_rate,
                  }
              },
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv2',
                      'units': hidden_dim,
                      'use_bias': True,
                  }
              }
          ],
        },
    }

    decoder = copy.deepcopy(encoder)
    decoder['output_layer_bias'] = True


params = {
    'model_dir': '../model/transformer',
    'log_path': '../log/transformer.txt',
    'train_paths': ['../data/core.txt'] + ['../data/reduced.txt'],
    'test_paths': ['../data/core.txt'],
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'embed_dim': config_model.hidden_dim,
    'beam_width': 5,
    'top_k': 3,
    'length_penalty': .6,
    'label_smoothing': .3,
    'lr': 7e-4,
    'clip_norm': 5.,
    'buffer_size': 180000,
    'batch_size': 64,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps=params['buffer_size']//params['batch_size'], keep_checkpoint_max=1),
  params=params)

best_ppl = 10000.
history_ppl = []
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  minimal_test(estimator)
  
  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  logger.info("Perplexity: {:.3f}".format(ppl))
  history_ppl.append(ppl)

  if ppl < best_ppl:
    best_ppl = ppl
  logger.info("Best Perplexity: {:.3f}".format(best_ppl))

  if len(history_ppl) > params['num_patience'] and is_increasing(history_ppl):
    logger.info("Perplexity not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
  
  # BLEU
  labels = [label for _, (_, label) in dataset(is_training=False, params=params)]
  labels = [j for i in labels for j in i.numpy()]
  labels = [[params['idx2char'].get(idx, '<unk>') for idx in arr if (idx!=0 and idx!=2)] for arr in labels]

  preds = list(estimator.predict(input_fn=lambda: dataset(is_training=False, params=params)))
  assert len(labels) == len(preds)
  preds = [[params['idx2char'].get(idx, '<unk>') for idx in arr[:, 0] if (idx!=0 and idx!=2)] for arr in preds]

  logger.info("BLEU: {:.1f}".format(tx.evals.corpus_bleu_moses(list_of_references=[[l] for l in labels], hypotheses=preds)))
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../model/transformer', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 2812, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f839a586e10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/texar/tf/module_base.py:83: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/texar/tf/modules/embedders/position_embedders.py:338: The name tf.mod is deprecated. Please use tf.math.mod instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/texar/tf/modules/encoders/transformer_encoders.py:142: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /usr/lib/python3.6/pydoc.py:1595: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/texar/tf/core/layers.py:608: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From /usr/lib/python3.6/pydoc.py:1595: The name tf.layers.Dropout is deprecated. Please use tf.compat.v1.layers.Dropout instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/texar/tf
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 好 久
# A3: 好 久 久 不 见
#
# Q: 想 死 你 了
# A1: 我 也 想 死 你 了
# A2: 我 也 想 死
# A3: 我 也 想 死 了
#
# Q: 谢 谢 你
# A1: 谢 你
# A2: 谢
# A3: 谢 你 妹
#
# Q: 爱 你
# A1: 我 也 爱 你
# A2: 我 爱 你
# A3: 我 爱 你 爱 我
#
# Q: 你 好 厉 害 啊
# A1: 当 然 厉 害 ！
# A2: 好 厉 害
# A3: 当 然 厉 害
#
# Q: 你 叫 什 么
# A1: 你 叫 什 么
# A2: 我 叫 什 么
# A3: 没 什 么
#
# Q: 你 几 岁 了
# A1: 我 几 岁 了
# A2: 你 几 岁 了
# A3: 你 几 岁 ？
#
# Q: 现 在 几 点
# A1: 几 点 ？
# A2: 我 几 点 都 几 点
# A3: 我 几 点 几 点 ？
#
# Q: 今 天 天 气 怎 么 样
# A1: 天 气 好
# A2: 怎 么 了 ?
# A3: 怎 么 了
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 哪 里
# A2: 你 在 哪 里 ？
# A3: 我 们 在 哪 里
#
# Q: 讲 个 笑 话
# A1: 讲 话
# A2: 讲 话 ！
# A3: 讲 话 啊
#
# Q: 你 会 几 种 语 言 呀
# A1: 我 不 会
# A2: 全 世 界 语 言
# A3: 我 不 会 ？
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得 你 很 帅
# A2: 我 觉 得 你 不 帅
# A3: 我 觉 得 我 也 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌
# A2: 我 也 讨 厌
# A3: 讨 厌 啊
#
# Q: 好 烦 啊
# A1: 好 烦
# A2: 好 烦 啊
# A3: 我 也 好 烦
#
# Q: 天 气 真 好
# A1: 天 气 好
# A2: 天 气 很 好
# A3: 天 气 真 好
#
# Q: 今 天 好 冷
# A1: 好 冷 啊
# A2: 今 天 好 冷
# A3: 今 天 好 冷 啊
#
# Q: 今 天 好 热
# A1: 好 热
# A2: 好 热 啊
# A3: 好 热 啊 ， 好 热 啊
#
# Q: 下 雨 了
# A1: 下 雨 了
# A2: 下 雨 了 ?
# A3: 下 雨 了 吗 ?
#
# Q: 风 好 大
# A1: 大 风
# A2: 好 大 风
# A3: 大 风 风 大 风
#
# Q: 终 于 周 五 了
# A1: 周 五 了 ?
# A2: 今 天 周 五
# A3: 周 五 是 什 么
#
# Q: 我 想 去 K 歌
# A1: 我 也 想 去
# A2: 想 去
# A3: 我 想 去 唱 歌
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T03:25:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-24705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:Finished evaluation at 2019-12-10-03:25:28
# INFO:tensorflow:Saving dict for global step 24705: global_step = 24705, loss = 3.5314324
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24705: ../model/transformer/model.ckpt-24705
# INFO:tensorflow:Perplexity: 34.173
# INFO:tensorflow:Best Perplexity: 34.173
# Reading ../data/core.txt
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-24705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:BLEU: 6.5
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-24705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24705 into ../model/transformer/model.ckpt.
# Reading ../data/core.txt
# Reading ../data/reduced.txt
# INFO:tensorflow:loss = 5.2511134, step = 24705
# INFO:tensorflow:lr = 0.0005460917
# INFO:tensorflow:global_step/sec: 5.14927
# INFO:tensorflow:loss = 5.1955094, step = 24805 (19.423 sec)
# INFO:tensorflow:lr = 0.00054554315 (19.423 sec)
# INFO:tensorflow:global_step/sec: 7.33116
# INFO:tensorflow:loss = 5.2025805, step = 24905 (13.640 sec)
# INFO:tensorflow:lr = 0.0005449952 (13.639 sec)
# INFO:tensorflow:global_step/sec: 7.35506
# INFO:tensorflow:loss = 5.312581, step = 25005 (13.600 sec)
# INFO:tensorflow:lr = 0.0005444477 (13.600 sec)
# INFO:tensorflow:global_step/sec: 7.44657
# INFO:tensorflow:loss = 5.324305, step = 25105 (13.426 sec)
# INFO:tensorflow:loss = 5.244933, step = 26805 (13.257 sec)
# INFO:tensorflow:lr = 0.00053468684 (13.256 sec)
# INFO:tensorflow:global_step/sec: 7.47544
# INFO:tensorflow:loss = 5.327634, step = 26905 (13.373 sec)
# INFO:tensorflow:lr = 0.00053414976 (13.373 sec)
# INFO:tensorflow:global_step/sec: 7.49608
# INFO:tensorflow:loss = 5.34893, step = 27005 (13.342 sec)
# INFO:tensorflow:lr = 0.0005336132 (13.342 sec)
# INFO:tensorflow:global_step/sec: 7.49352
# INFO:tensorflow:loss = 5.472206, step = 27105 (13.344 sec)
# INFO:tensorflow:lr = 0.00053307717 (13.343 sec)
# INFO:tensorflow:global_step/sec: 7.36149
# INFO:tensorflow:loss = 5.5022354, step = 27205 (13.586 sec)
# INFO:tensorflow:lr = 0.00053254166 (13.587 sec)
# INFO:tensorflow:global_step/sec: 7.51071
# INFO:tensorflow:loss = 5.393441, step = 27305 (13.319 sec)
# INFO:tensorflow:lr = 0.00053200667 (13.318 sec)
# INFO:tensorflow:global_step/sec: 7.51377
# INFO:tensorflow:loss = 5.284816, step = 27405 (13.306 sec)
# INFO:tensorflow:lr = 0.0005314723 (13.305 sec)
# INFO:tensorflow:Saving checkpoints for 27450 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.2855186.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-27450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 你 好
# A2: 你 好 啊
# A3: 主 人 你 好 O ( ∩ _ ∩ ) O
#
# Q: 早 上 好
# A1: 早 上 好
# A2: 早 上 好 ！
# A3: 早 上 好 !
#
# Q: 晚 上 好
# A1: 晚 安
# A2: 晚 上 好
# A3: 晚 安 ！
#
# Q: 再 见
# A1: 再 见
# A2: 再 见 ！
# A3: 再 见 了
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 不 见
# A3: 好 久
#
# Q: 想 死 你 了
# A1: 我 也 想 死 你 了
# A2: 我 也 想 死
# A3: 我 也 想 死 你
#
# Q: 谢 谢 你
# A1: 谢 谢 谢
# A2: 谢 谢 谢 你 ！
# A3: 谢 谢 谢 你
#
# Q: 爱 你
# A1: 我 也 爱 你
# A2: 爱 你
# A3: 我 也 爱 你 ~
#
# Q: 你 好 厉 害 啊
# A1: 我 厉 害
# A2: 比 你 还 厉 害
# A3: 比 你 更 厉 害
#
# Q: 你 叫 什 么
# A1: 你 叫 什 么
# A2: 没 什 么
# A3: 没 什 么 啊
#
# Q: 你 几 岁 了
# A1: 我 几 岁 了
# A2: 我 岁 了
# A3: 几 岁
#
# Q: 现 在 几 点
# A1: 几 点 ？
# A2: 几 点
# A3: 几 点 ?
#
# Q: 今 天 天 气 怎 么 样
# A1: 怎 么 了
# A2: 天 气 怎 么 样
# A3: 今 天 气 怎 么 了
#
# Q: 我 们 现 在 在 哪 里
# A1: 你 在 哪 里
# A2: 你 在 哪 里 ？
# A3: 在 哪 里
#
# Q: 讲 个 笑 话
# A1: 笑 话
# A2: 我 笑 了
# A3: 我 说 的 话
#
# Q: 你 会 几 种 语 言 呀
# A1: 全 世 界 的 语 言 我 都 会
# A2: 全 世 界 语 言 的 我 都 会
# A3: 全 世 界 都 会
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得
# A2: 我 觉 得 不 帅
# A3: 我 觉 得 你 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 �
#
# Q: 你 几 岁 了
# A1: 主 人 几 岁
# A2: 我 主 人 几 岁 岁
# A3: 你 三 岁 了
#
# Q: 现 在 几 点
# A1: 主 人 几 点
# A2: 主 人 几 点 ！
# A3: 主 人 几 点 啊
#
# Q: 今 天 天 气 怎 么 样
# A1: 我 今 天 气 好
# A2: 天 气 预 报 报
# A3: 我 今 天 气 好 了
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 哪 里 ？
# A2: 你 在 哪 ？
# A3: 你 在 哪 里
#
# Q: 讲 个 笑 话
# A1: 讲 什 么 ？
# A2: 讲 什 么 呢
# A3: 讲 什 么 呢 ？
#
# Q: 你 会 几 种 语 言 呀
# A1: 两 种
# A2: 全 世 界 都 会
# A3: 我 会 的
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得 你 不 爱 我
# A2: 我 觉 得 你 帅
# A3: 我 觉 得 你 也 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌
# A2: 不 讨 厌
# A3: 我 也 讨 厌
#
# Q: 好 烦 啊
# A1: 好 烦 啊
# A2: 好 烦
# A3: 好 烦 烦 啊
#
# Q: 天 气 真 好
# A1: 天 气 好
# A2: 好 天 气
# A3: 好 天 气 好
#
# Q: 今 天 好 冷
# A1: 今 天 好 冷
# A2: 今 天 不 冷
# A3: 今 天 不 热 啊
#
# Q: 今 天 好 热
# A1: 今 天 好 热
# A2: 今 天 好 热 啊
# A3: 今 天 不 是 今 天
#
# Q: 下 雨 了
# A1: 下 雨 了
# A2: 下 雨 了 ?
# A3: 下 雨 了 吗 ?
#
# Q: 风 好 大
# A1: 大 风
# A2: 好 大 风
# A3: 大 风 大
#
# Q: 终 于 周 五 了
# A1: 周 五 好
# A2: 为 什 么 周 五 ?
# A3: 为 什 么 周 五 呢 ?
#
# Q: 我 想 去 K 歌
# A1: 我 想 去
# A2: 我 也 想 去
# A3: 想 去
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T03:50:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-32940
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:Finished evaluation at 2019-12-10-03:50:42
# INFO:tensorflow:Saving dict for global step 32940: global_step = 32940, loss = 3.488638
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32940: ../model/transformer/model.ckpt-32940
# INFO:tensorflow:Perplexity: 32.741
# INFO:tensorflow:Best Perplexity: 32.741
# Reading ../data/core.txt
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-32940
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:BLEU: 7.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-32940
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 32940 into ../model/transformer/model.ckpt.
# Reading ../data/core.txt
# Reading ../data/reduced.txt
# INFO:tensorflow:loss = 5.269416, step = 32940
# INFO:tensorflow:lr = 0.00050271454
# INFO:tensorflow:global_step/sec: 5.1464
# INFO:tensorflow:loss = 5.015906, step = 33040 (19.438 sec)
# INFO:tensorflow:lr = 0.0005022096 (19.433 sec)
# INFO:tensorflow:global_step/sec: 7.50596
# INFO:tensorflow:loss = 5.1979513, step = 33140 (13.324 sec)
# INFO:tensorflow:lr = 0.0005017051 (13.324 sec)
# INFO:tensorflow:global_step/sec: 7.4173
# INFO:tensorflow:loss = 5.2384143, step = 33240 (13.481 sec)
# INFO:tensorflow:lr = 0.00050120114 (13.481 sec)
# INFO:tensorflow:global_step/sec: 7.42997
# INFO:tensorflow:loss = 5.325575, step = 33340 (13.454 sec)
# INFO:tensorflow:lr = 0.00050069764 (13.455 sec)
# INFO:tensorflow:global_step/sec: 7.50079
# INFO:tensorflow:loss = 5.403385, step = 33440 (13.336 sec)
# INFO:tensorflow:lr = 0.0005001946 (13.335 sec)
# INFO:tensorflow:lr = 0.0004917212 (13.482 sec)
# INFO:tensorflow:global_step/sec: 7.39884
# INFO:tensorflow:loss = 5.203701, step = 35240 (13.521 sec)
# INFO:tensorflow:lr = 0.0004912272 (13.521 sec)
# INFO:tensorflow:global_step/sec: 7.39548
# INFO:tensorflow:loss = 5.2460947, step = 35340 (13.522 sec)
# INFO:tensorflow:lr = 0.0004907338 (13.522 sec)
# INFO:tensorflow:global_step/sec: 7.41013
# INFO:tensorflow:loss = 5.493124, step = 35440 (13.497 sec)
# INFO:tensorflow:lr = 0.0004902408 (13.498 sec)
# INFO:tensorflow:global_step/sec: 7.28488
# INFO:tensorflow:loss = 5.334705, step = 35540 (13.726 sec)
# INFO:tensorflow:lr = 0.0004897483 (13.725 sec)
# INFO:tensorflow:global_step/sec: 7.40606
# INFO:tensorflow:loss = 5.1135273, step = 35640 (13.498 sec)
# INFO:tensorflow:lr = 0.00048925634 (13.500 sec)
# INFO:tensorflow:Saving checkpoints for 35685 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.1378007.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-35685
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 你 好
# A2: 主 人 你 好 O ( ∩ _ ∩ ) O
# A3: 你 好 ！
#
# Q: 早 上 好
# A1: 早 上 好
# A2: 早 上 好 ~
# A3: 早 上 好 !
#
# Q: 晚 上 好
# A1: 晚 上 好
# A2: 晚 上 好 ~
# A3: 晚 安
#
# Q: 再 见
# A1: 再 见
# A2: 你 再 见
# A3: 再 见 你
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 好 久 不 见 。
# A3: 好 久 不 见 ~
#
# Q: 想 死 你 了
# A1: 我 也 想 死 你 了
# A2: 我 也 想 死
# A3: 死 你 了
#
# Q: 谢 谢 你
# A1: 谢
# A2: 谢 谢 你
# A3: 谢 谢
#
# Q: 爱 你
# A1: 我 爱 你
# A2: 我 也 爱 你
# A3: 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 没 你 厉 害
# A2: 没 有 你 厉 害
# A3: 好 吧
#
# Q: 你 叫 什 么
# A1: 没 什 么
# A2: 没 什 么 啊
# A3: 没 什 么 啦
#
# Q: 你 几 岁 了
# A1: 你 几 岁 了
# A2: 你 几 岁 了 ？
# A3: 你 几 岁 了 ！
#
# Q: 现 在 几 点
# A1: 现 在 几 点 ？
# A2: 现 在 几 点
# A3: 我 现 在 几 点
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 我 也 是
# A2: 今 天 是 个 好 事
# A3: 今 天 是 个 好 天 气
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 哪 里
# A2: 你 在 哪 里 ？
# A3: 你 在 哪
#
# Q: 讲 个 笑 话
# A1: 笑 话
# A2: 笑 话 你 妹 ！
# A3: 笑 话 ， 笑 尿
#
# Q: 你 会 几 种 语 言 呀
# A1: 全 世 界 的 我 都 会
# A2: 全 世 界 都 会
# A3: 全 世 界 都 会 的
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得 帅
# A2: 我 觉 得 你 很 可 爱
# A3: 我 觉 得 你 也 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌
# A2: 不 要 讨 厌
# A3: 我 也 讨 厌
#
# Q: 好 烦 啊
# A1: 好 烦
# A2: 好 烦 啊
# A3: 我 也 好 烦
#
# Q: 天 气 真 好
# A1: 天 气 好
# A2: 天 气 不 好
# A3: 天 气 好 了
#
# Q: 今 天 好 冷
# A1: 今 天 冷
# A2: 今 天 冷 ?
# A3: 今 天 是 谁 ?
#
# Q: 今 天 好 热
# A1: 好 热
# A2: 好 热 好
# A3: 今 天 好 热
#
# Q: 下 雨 了
# A1: 下 雨 了
# A2:
#
# Q: 你 几 岁 了
# A1: 我 主 人 几 岁
# A2: 我 主 人 几 岁 我 就 几 岁
# A3: 我 主 人 几 岁 我 就 几 岁 了
#
# Q: 现 在 几 点
# A1: 我 爸 几 点 了
# A2: 主 人 几 点
# A3: 我 爸 几 点 点
#
# Q: 今 天 天 气 怎 么 样
# A1: 你 怎 么 了
# A2: 我 今 天 怎 么 了
# A3: 我 今 天 怎 么 样
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 哪 里
# A2: 现 在 哪 里
# A3: 现 在 哪 里 都 在 哪 里
#
# Q: 讲 个 笑 话
# A1: 爷 ， 给 妞 亲 一 个
# A2: 爷 ， 给 妞 亲 亲 一 个
# A3: 爷 ， 给 妞 亲 亲 一 个 ~
#
# Q: 你 会 几 种 语 言 呀
# A1: 全 世 界 的 语 言 我 都 会
# A2: 全 世 界 语 言 的 我 都 会
# A3: 全 世 界 的 语 语 言 我 都 会
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得 你 也 很 帅
# A2: 我 觉 得
# A3: 我 觉 得 你 不 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌
# A2: 我 也 讨 厌
# A3: 我 也 很 讨 厌
#
# Q: 好 烦 啊
# A1: 什 么 烦
# A2: 我 也 好 烦
# A3: 什 么 好 烦 啊
#
# Q: 天 气 真 好
# A1: 天 气 好
# A2: 好 天 气
# A3: 天 气 很 好
#
# Q: 今 天 好 冷
# A1: 今 天 好 冷
# A2: 今 天 好 热
# A3: 今 天 好 热 啊
#
# Q: 今 天 好 热
# A1: 好 热
# A2: 热 死 我 了
# A3: 好 热 好 啊
#
# Q: 下 雨 了
# A1: 下 雨 了
# A2: 下 雨 了 ?
# A3: 我 也 下 雨 了
#
# Q: 风 好 大
# A1: 好 大 风
# A2: 好 大 风 好
# A3: 大 风 好 大 风
#
# Q: 终 于 周 五 了
# A1: 终 于 了
# A2: 为 什 么 周 五 ?
# A3: 终 于 周 了
#
# Q: 我 想 去 K 歌
# A1: 想 去
# A2: 想 去 哪 ？
# A3: 想 去 K 歌
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T09:43:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-145485
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:Finished evaluation at 2019-12-10-09:43:17
# INFO:tensorflow:Saving dict for global step 145485: global_step = 145485, loss = 3.0035126
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 145485: ../model/transformer/model.ckpt-145485
# INFO:tensorflow:Perplexity: 20.156
# INFO:tensorflow:Best Perplexity: 20.156
# Reading ../data/core.txt
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-145485
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:BLEU: 8.6
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-145485
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 145485 into ../model/transformer/model.ckpt.
# Reading ../data/core.txt
# Reading ../data/reduced.txt
# INFO:tensorflow:loss = 4.937867, step = 145485
# INFO:tensorflow:lr = 0.00016221273
# INFO:tensorflow:global_step/sec: 4.71825
# INFO:tensorflow:loss = 5.0025754, step = 145585 (21.198 sec)
# INFO:tensorflow:lr = 0.00016204976 (21.197 sec)
# INFO:tensorflow:global_step/sec: 7.25155
# INFO:tensorflow:loss = 4.846064, step = 145685 (13.792 sec)
# INFO:tensorflow:lr = 0.00016188697 (13.790 sec)
# INFO:tensorflow:global_step/sec: 7.20715
# INFO:tensorflow:loss = 4.8967485, step = 145785 (13.876 sec)
# INFO:tensorflow:lr = 0.00016172437 (13.876 sec)
# INFO:tensorflow:global_step/sec: 7.21017
# INFO:tensorflow:loss = 5.036453, step = 145885 (13.869 sec)
# INFO:tensorflow:loss = 5.1099052, step = 147585 (13.881 sec)
# INFO:tensorflow:lr = 0.00015882497 (13.881 sec)
# INFO:tensorflow:global_step/sec: 7.1677
# INFO:tensorflow:loss = 4.928549, step = 147685 (13.947 sec)
# INFO:tensorflow:lr = 0.00015866543 (13.949 sec)
# INFO:tensorflow:global_step/sec: 7.18242
# INFO:tensorflow:loss = 4.91754, step = 147785 (13.925 sec)
# INFO:tensorflow:lr = 0.00015850607 (13.924 sec)
# INFO:tensorflow:global_step/sec: 7.17558
# INFO:tensorflow:loss = 4.9705687, step = 147885 (13.934 sec)
# INFO:tensorflow:lr = 0.00015834681 (13.935 sec)
# INFO:tensorflow:global_step/sec: 7.19358
# INFO:tensorflow:loss = 5.0971074, step = 147985 (13.901 sec)
# INFO:tensorflow:lr = 0.00015818777 (13.900 sec)
# INFO:tensorflow:global_step/sec: 7.21426
# INFO:tensorflow:loss = 4.974211, step = 148085 (13.866 sec)
# INFO:tensorflow:lr = 0.00015802885 (13.867 sec)
# INFO:tensorflow:global_step/sec: 6.97392
# INFO:tensorflow:loss = 4.9099426, step = 148185 (14.339 sec)
# INFO:tensorflow:lr = 0.0001578701 (14.337 sec)
# INFO:tensorflow:Saving checkpoints for 148230 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.011449.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-148230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 你 好
# A2: 你 好 啊
# A3: 你 好 ， 大 家 好
#
# Q: 早 上 好
# A1: 早 上 好
# A2: 早 上 好 V
# A3: 早 上 好 ！
#
# Q: 晚 上 好
# A1: 晚 上 好
# A2: 早 上 好
# A3: 晚 上 好 主 人
#
# Q: 再 见
# A1: 再 见
# A2: 再 见 ！
# A3: 再 再 见
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 你 好 久 不 见
# A3: 好 久 不 见 ~
#
# Q: 想 死 你 了
# A1: 那 你 死 了
# A2: 我 也 想 死 了
# A3: 我 也 想 你
#
# Q: 谢 谢 你
# A1: 谢 谢 你
# A2: 谢 谢
# A3: 不 谢 谢
#
# Q: 爱 你
# A1: 我 也 爱 你
# A2: 我 爱 你
# A3: 主 人 我 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 主 人 ， 你 好 O ( ∩ _ ∩ ) O
# A2: 没 有 主 人 厉 害
# A3: 没 有 主 人 厉 害 ！
#
# Q: 你 叫 什 么
# A1: 你 叫 什 么
# A2: 你 叫 什 么 呀
# A3: 你 叫 什 么 啊
#
# Q: 你 几 岁 了
# A1: 你 几 岁 了
# A2: 我 今 年 十 岁 了 ！
# A3: 我 今 年 十 岁 了
#
# Q: 现 在 几 点
# A1: 几 点
# A2: 我 爸 几 点 了
# A3: 我 爸 几 点 打 算
#
# Q: 今 天 天 气 怎 么 样
# A1: 你 今 天 怎 么 了
# A2: 不 怎 么 样
# A3: 今 天 气 怎 么 样
#
# Q: 我 们 现 在 在 哪 里
# A1: 我 在 你 眼 里
# A2: 我 在 你 心 里
# A3: 我 在 你 眼 睛 里
#
# Q: 讲 个 笑 话
# A1: 爷 ， 给 你 笑 一 个 。
# A2: 爷 ， 给 妞 笑 一 个
# A3: 爷 ， 给 妞 笑 一 个 。
#
# Q: 你 会 几 种 语 言 呀
# A1: 世 界 上 我 不 会
# A2: 世 界 上 我 会 生 的
# A3: 世 界 上 并 没 有 不 会 的 啦
#
# Q: 你 觉 得 我 帅 吗
# A1: 我 觉 得 你 不 帅
# A2: 我 觉 得 你 帅
# A3: 我 觉 得 我 也 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌
# A2: 不 讨 厌
# A3: 我 也 很 讨 厌
#
# Q: 好 烦 啊
# A1: 好 烦
# A2: 好 烦 啊
# A3: 我 也 好 烦 啊
#
# Q: 天 气 真 好
# A1: 天 气 好 好
# A2: 天 气 真 好
# A3: 天 气 好 好 天 气
#
# Q: 今 天 好 冷
# A1: 今 天 好 冷
# A2: 今 天 是 谁 ?
# A3: 今 天 好 冷 啊
#
# Q: 今 天 好 热
# A1: 好 热
# A2: 我 也 好 热
# A3: 好 热 啊
#
# Q: 下 雨 了
# A1: 下 雨 了
# A2: 我 这 里 也 下 雨 了
# A3: 下 雨 了 ?
#
# Q: 风 好 大
# A1: 好 大 风
# A2: 好 大 风 大
# A3: 好 大 风 好
#
# Q: 终 于 周 五 了
# A1: 终 于 是 周 五 了
# A2: 周 末 是 什 么 ?
# A3: 周 末 是 谁 ?
#
# Q: 我 想 去 K 歌
# A1: 我 想 去 K K K
# A2: 我 想 去 ！
# A3: 我 也 想 去 ！
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T09:52:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-148230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:Finished evaluation at 2019-12-10-09:52:07
# INFO:tensorflow:Saving dict for global step 148230: global_step = 148230, loss = 2.9911587
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 148230: ../model/transformer/model.ckpt-148230
# INFO:tensorflow:Perplexity: 19.909
# INFO:tensorflow:Best Perplexity: 19.909
# Reading ../data/core.txt
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-148230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/core.txt
# INFO:tensorflow:BLEU: 9.7
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-148230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 148230 into ../model/transformer/model.ckpt.
# Reading ../data/core.txt
# Reading ../data/reduced.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e9f457591d02> in <module>()
#      21
#      22 while True:
# ---> 23   estimator.train(input_fn=lambda: dataset(is_training=True, params=params))
#      24
#      25   minimal_test(estimator)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1194                                              hooks, global_step_tensor,
# -> 1195                                              saving_listeners)
#    1196
#    1197   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1492       any_step_done = False
#    1493       while not mon_sess.should_stop():
# -> 1494         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1495         any_step_done = True
#    1496     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1257             feed_dict=feed_dict,
#    1258             options=options,
# -> 1259             run_metadata=run_metadata)
#    1260       except _PREEMPTION_ERRORS as e:
#    1261         logging.info(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
