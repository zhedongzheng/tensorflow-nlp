# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_qingyun/main')

# %%
# %tensorflow_version 1.x
# !pip install texar

# %%
import tensorflow as tf
import texar.tf as tx

import numpy as np
import pprint
import logging
import copy

from pathlib import Path
from texar.tf.modules import TransformerEncoder, TransformerDecoder

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  char2idx = params['char2idx']
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      source, target = line.split('<SEP>')
      source = [char2idx.get(c, len(char2idx)) for c in list(source)]
      target = [char2idx.get(c, len(char2idx)) for c in list(target)]
      if len(source) > params['max_len']:
        source = source[:params['max_len']]
      if len(target) > params['max_len']:
        target = target[:params['max_len']]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    #pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    
  
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        embedding = tf.concat([tf.zeros(shape=[1, params['embed_dim']]), embedding[1:, :]], axis=0)
        x = tf.nn.embedding_lookup(embedding, words)
        pos_embedder = tx.modules.SinusoidsPositionEmbedder(
            position_size = params['max_len'] + 1,
            hparams = config_model.position_embedder_hparams)
        x = (x * config_model.hidden_dim ** 0.5) + pos_embedder(sequence_length=words_len)


    with tf.variable_scope('Encoder'):
        encoder = TransformerEncoder(hparams=config_model.encoder)
        enc_out = encoder(inputs=x, sequence_length=words_len)
    
    
    with tf.variable_scope('Decoder'):
        decoder = TransformerDecoder(vocab_size=len(params['char2idx'])+1,
                                     output_layer=tf.transpose(embedding, (1, 0)),
                                     hparams=config_model.decoder)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = (dec_inputs * config_model.hidden_dim ** 0.5) + pos_embedder(sequence_length=dec_seq_len)

            outputs = decoder(
                memory=enc_out,
                memory_sequence_length=words_len,
                inputs=dec_inputs,
                decoding_strategy='train_greedy',
                mode=tf.estimator.ModeKeys.TRAIN
            )
            
            return outputs.logits
        else:
            start_tokens = tf.fill([batch_sz], 1)

            def _embedding_fn(x, y):
                x_w_embed = tf.nn.embedding_lookup(embedding, x)
                y_p_embed = pos_embedder(y)
                return x_w_embed * config_model.hidden_dim ** 0.5 + y_p_embed

            predictions = decoder(
                memory=enc_out,
                memory_sequence_length=words_len,
                beam_width=params['beam_width'],
                length_penalty=params['length_penalty'],
                start_tokens=start_tokens,
                end_token=2,
                embedding=_embedding_fn,
                max_decoding_length=params['max_len'],
                mode=tf.estimator.ModeKeys.PREDICT)
            
            return predictions['sample_id'][:, :, :params['top_k']]

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()
        
        decay_lr = tf.train.exponential_decay(
            params['lr'], global_step, 1000, .99)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def minimal_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去k歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('minimal test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx != 0 and idx != 2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
def is_increasing(history):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] >= history[i]:
      return False
  return True

# %%
class config_model:
    hidden_dim = 300
    num_heads = 8
    dropout_rate = .2
    num_blocks = 6

    position_embedder_hparams = {
        'dim': hidden_dim
    }

    encoder = {
        'dim': hidden_dim,
        'embedding_dropout': dropout_rate,
        'residual_dropout': dropout_rate,
        'num_blocks': num_blocks,
        'initializer': {
            'type': 'variance_scaling_initializer',
            'kwargs': {
                'scale': 1.0,
                'mode': 'fan_avg',
                'distribution': 'uniform',
            },
        },
        'multihead_attention': {
            'dropout_rate': dropout_rate,
            'num_heads': num_heads,
            'output_dim': hidden_dim,
            'use_bias': True,
        },
        'poswise_feedforward': {
          'name': 'fnn',
          'layers': [
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv1',
                      'units': hidden_dim * 4,
                      'activation': 'gelu',
                      'use_bias': True,
                  },
              },
              {
                  'type': 'Dropout',
                  'kwargs': {
                      'rate': dropout_rate,
                  }
              },
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv2',
                      'units': hidden_dim,
                      'use_bias': True,
                  }
              }
          ],
        },
    }

    decoder = copy.deepcopy(encoder)
    decoder['output_layer_bias'] = True


params = {
    'model_dir': '../model/transformer',
    'log_path': '../log/transformer.txt',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'embed_dim': config_model.hidden_dim,
    'beam_width': 10,
    'top_k': 3,
    'length_penalty': .0,
    'label_smoothing': .2,
    'lr': 4e-4,
    'clip_norm': 5.,
    'buffer_size': 120000,
    'batch_size': 64,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}
print(len(params['char2idx']))

# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps=1000, keep_checkpoint_max=3),
  params=params)

best_ppl = 10000.
history_ppl = []
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  minimal_test(estimator)
  
  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  logger.info("Perplexity: {:.3f}".format(ppl))
  history_ppl.append(ppl)

  if ppl < best_ppl:
    best_ppl = ppl
  logger.info("Best Perplexity: {:.3f}".format(best_ppl))

  if len(history_ppl) > params['num_patience'] and is_increasing(history_ppl):
    logger.info("Perplexity not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# A1: 我 会 的 可 多 了
# A2: 我 会 几 门
# A3: 虽 然 我 很 聪 明 ， 但 也 不 可 能 全 部 都 懂 哦
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 帅 ！ 帅 到 爆 ！
# A3: 你 长 得 很 有 杀 伤 力
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！ ！
# A3: 讨 厌 ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 啊 ， 你 烦 什 么 啊
#
# Q: 天 气 真 好
# A1: 是 吗
# A2: 是 啊
# A3: 你 好 呀
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 今 天 这 天 气 很 适 合 聊 天 的 说
# A3: 天 气 好 晴 天
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 今 天 是 个 好 日 子 ， 怎 么 不 出 去 玩 玩
# A3: 今 天 这 天 气 很 适 合 聊 天 的 说
#
# Q: 下 雨 了
# A1: 我 不 喜 欢
# A2: 啊 ， 这 鬼 天 气 太 讨 厌 了
# A3: 雨 雨 会 下 雨 不 会 下
#
# Q: 风 好 大
# A1: 今 天 是 个 好 日 子 ， 怎 么 不 出 去 玩 玩
# A2: 大 波 妹
# A3: 表 酱 紫 讲 话 好 不 ， 伦 家 听 不 习 惯
#
# Q: 终 于 周 五 了
# A1: 听 哦
# A2: 听 日 休 息 ？
# A3: 给 你
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 要 去 就 去 啊 ， 速 度
# A3: 好 啊
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:29:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-62234
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:29:30
# INFO:tensorflow:Saving dict for global step 62234: global_step = 62234, loss = 1.2892402
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 62234: ../model/transformer/model.ckpt-62234
# INFO:tensorflow:Perplexity: 3.630
# INFO:tensorflow:Best Perplexity: 3.614
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-62234
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 62234 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.6974037, step = 62234
# INFO:tensorflow:lr = 0.00021400354
# INFO:tensorflow:global_step/sec: 6.11259
# INFO:tensorflow:loss = 2.7659056, step = 62334 (16.364 sec)
# INFO:tensorflow:lr = 0.00021378855 (16.364 sec)
# INFO:tensorflow:global_step/sec: 9.27466
# INFO:tensorflow:loss = 2.6642406, step = 62434 (10.781 sec)
# INFO:tensorflow:lr = 0.00021357379 (10.781 sec)
# INFO:tensorflow:global_step/sec: 9.28356
# INFO:tensorflow:loss = 2.6008112, step = 62534 (10.772 sec)
# INFO:tensorflow:lr = 0.00021335925 (10.773 sec)
# INFO:tensorflow:global_step/sec: 9.26205
# INFO:tensorflow:loss = 2.5404696, step = 62634 (10.797 sec)
# INFO:tensorflow:lr = 0.00021314491 (10.797 sec)
# INFO:tensorflow:global_step/sec: 9.1479
# INFO:tensorflow:loss = 2.6251245, step = 62734 (10.932 sec)
# INFO:tensorflow:lr = 0.00021293084 (10.931 sec)
# INFO:tensorflow:global_step/sec: 9.25719
# INFO:tensorflow:loss = 2.63614, step = 62834 (10.803 sec)
# INFO:tensorflow:lr = 0.00021271693 (10.803 sec)
# INFO:tensorflow:global_step/sec: 9.25718
# INFO:tensorflow:loss = 2.6886072, step = 62934 (10.801 sec)
# INFO:tensorflow:lr = 0.00021250326 (10.802 sec)
# INFO:tensorflow:global_step/sec: 9.20235
# INFO:tensorflow:loss = 2.6475916, step = 63034 (10.868 sec)
# INFO:tensorflow:lr = 0.00021228979 (10.866 sec)
# INFO:tensorflow:global_step/sec: 9.08392
# INFO:tensorflow:loss = 2.5898721, step = 63134 (11.012 sec)
# INFO:tensorflow:lr = 0.00021207654 (11.013 sec)
# INFO:tensorflow:Saving checkpoints for 63234 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.66761
# INFO:tensorflow:loss = 2.6575122, step = 63234 (13.039 sec)
# INFO:tensorflow:lr = 0.00021186349 (13.038 sec)
# INFO:tensorflow:global_step/sec: 8.91418
# INFO:tensorflow:loss = 2.7805483, step = 63334 (11.218 sec)
# INFO:tensorflow:lr = 0.00021165065 (11.219 sec)
# INFO:tensorflow:global_step/sec: 9.23032
# INFO:tensorflow:loss = 2.5961208, step = 63434 (10.835 sec)
# INFO:tensorflow:lr = 0.00021143808 (10.835 sec)
# INFO:tensorflow:global_step/sec: 9.20419
# INFO:tensorflow:loss = 2.5840032, step = 63534 (10.862 sec)
# INFO:tensorflow:lr = 0.00021122565 (10.860 sec)
# INFO:tensorflow:global_step/sec: 9.22064
# INFO:tensorflow:loss = 2.6494374, step = 63634 (10.848 sec)
# INFO:tensorflow:lr = 0.0002110135 (10.847 sec)
# INFO:tensorflow:global_step/sec: 9.24576
# INFO:tensorflow:loss = 2.7630138, step = 63734 (10.816 sec)
# INFO:tensorflow:lr = 0.0002108015 (10.816 sec)
# INFO:tensorflow:global_step/sec: 9.21813
# INFO:tensorflow:loss = 2.835118, step = 63834 (10.848 sec)
# INFO:tensorflow:lr = 0.00021058976 (10.849 sec)
# INFO:tensorflow:Saving checkpoints for 63916 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.8246763.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-63916
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 谢 谢
# A2: 你 啊 ~
# A3: 好 好 ~
#
# Q: 早 上 好
# A1: 早 安
# A2: 你 好 呀
# A3: 早 点 不 好 么 ？
#
# Q: 晚 上 好
# A1: 你 好 呀
# A2: 你 好 ~
# A3: 你 好 呀 ~
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 拜 拜
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 我 也 是
# A3: 是 啊 ， 蛮 爱 的
#
# Q: 想 死 你 了
# A1: 你 唔 死 啊
# A2: 谢 谢
# A3: 你 死 了 我 还 没 死
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 多 谢
#
# Q: 你 好 厉 害 啊
# A1: 非 得 的 ！
# A2: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A3: 牛 逼
#
# Q: 你 叫 什 么
# A1: 我 叫 西 哦 ^ ^
# A2: 你 不 是 叫 网 友 吗
# A3: 你 不 认 识 的
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 不 能 说 ， 反 正 还 年 轻 着 呢
#
# Q: 现 在 几 点
# A1: 现 在 时 间 是 1 9 分
# A2: 现 在 时 刻 1 1 3 点 5 分
# A3: 现 在 时 刻 1 7 点 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 长 得 还 行
# A2: 是 一 个 可 爱 滴 乖 小 孩
# A3: 天 还 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 我 这 里 了
# A3: 茅 厕
#
# Q: 讲 个 笑 话
# A1: 你 是 锄 禾 我 是 当 午
# A2: 靠 ， 又 是 她 ？
# A3: 你 要 说 给 我 听 ？
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 呀
# A2: 有 几 耶
# A3: 有 n 次 ~
#
# Q: 你 觉 得 我 帅 吗
# A1: 不 觉 得
# A2: 帅 ！ 帅 到 爆 了 ~ ！
# A3: 我 不 觉 得
#
# Q: 讨 厌 的 周 一
# A1: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
# A2: 非 常 讨 厌 ！
# A3: 非 常 讨 厌 ！ ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 哦
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 ！
# A3: ; ) 谦 虚 是 立 足 之 明
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 晴 朗
# A3: 天 气 很 好
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 那 更 好
# A3: 雨 会 下
#
# Q: 下 雨 了
# A1: 我 的 最 爱
# A2: 最 美 的 不 是 下 ~
# A3: 最 美 了
#
# Q: 风 好 大
# A1: 很 漂 亮
# A2: 很 多 ！ ！
# A3: 非 常 多 ！
#
# Q: 终 于 周 五 了
# A1: 给 你 摸
# A2: 听 你 这 口 气 ， 好 像
# A3: 听 你 这 口 气 ， 好 像 花 了 不 少 时 间 吧
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 去 吧 ， 赶 紧 的
# A3: ？
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:33:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-63916
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:33:59
# INFO:tensorflow:Saving dict for global step 63916: global_step = 63916, loss = 1.284777
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 63916: ../model/transformer/model.ckpt-63916
# INFO:tensorflow:Perplexity: 3.614
# INFO:tensorflow:Best Perplexity: 3.614
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-63916
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 63916 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.6141973, step = 63916
# INFO:tensorflow:lr = 0.00021041627
# INFO:tensorflow:global_step/sec: 6.00343
# INFO:tensorflow:loss = 2.6193597, step = 64016 (16.661 sec)
# INFO:tensorflow:lr = 0.00021020489 (16.659 sec)
# INFO:tensorflow:global_step/sec: 9.12924
# INFO:tensorflow:loss = 2.803725, step = 64116 (10.954 sec)
# INFO:tensorflow:lr = 0.00020999374 (10.953 sec)
# INFO:tensorflow:global_step/sec: 9.18409
# INFO:tensorflow:loss = 2.6142383, step = 64216 (10.886 sec)
# INFO:tensorflow:lr = 0.00020978281 (10.887 sec)
# INFO:tensorflow:global_step/sec: 9.09242
# INFO:tensorflow:loss = 2.6021001, step = 64316 (11.001 sec)
# INFO:tensorflow:lr = 0.00020957207 (11.000 sec)
# INFO:tensorflow:global_step/sec: 9.10966
# INFO:tensorflow:loss = 2.5447505, step = 64416 (10.976 sec)
# INFO:tensorflow:lr = 0.00020936155 (10.979 sec)
# INFO:tensorflow:global_step/sec: 9.13415
# INFO:tensorflow:loss = 2.6178641, step = 64516 (10.949 sec)
# INFO:tensorflow:lr = 0.00020915124 (10.946 sec)
# INFO:tensorflow:global_step/sec: 9.15184
# INFO:tensorflow:loss = 2.652951, step = 64616 (10.926 sec)
# INFO:tensorflow:lr = 0.00020894114 (10.928 sec)
# INFO:tensorflow:global_step/sec: 9.0943
# INFO:tensorflow:loss = 2.7292361, step = 64716 (10.995 sec)
# INFO:tensorflow:lr = 0.00020873126 (10.995 sec)
# INFO:tensorflow:global_step/sec: 9.17394
# INFO:tensorflow:loss = 2.7288768, step = 64816 (10.901 sec)
# INFO:tensorflow:lr = 0.00020852158 (10.898 sec)
# INFO:tensorflow:Saving checkpoints for 64916 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.59877
# INFO:tensorflow:loss = 2.5348444, step = 64916 (13.161 sec)
# INFO:tensorflow:lr = 0.00020831212 (13.161 sec)
# INFO:tensorflow:global_step/sec: 8.845
# INFO:tensorflow:loss = 2.6651366, step = 65016 (11.307 sec)
# INFO:tensorflow:lr = 0.00020810287 (11.307 sec)
# INFO:tensorflow:global_step/sec: 9.00605
# INFO:tensorflow:loss = 2.8056436, step = 65116 (11.101 sec)
# INFO:tensorflow:lr = 0.00020789381 (11.102 sec)
# INFO:tensorflow:global_step/sec: 9.03623
# INFO:tensorflow:loss = 2.6276581, step = 65216 (11.068 sec)
# INFO:tensorflow:lr = 0.00020768499 (11.067 sec)
# INFO:tensorflow:global_step/sec: 9.14966
# INFO:tensorflow:loss = 2.627817, step = 65316 (10.928 sec)
# INFO:tensorflow:lr = 0.00020747635 (10.928 sec)
# INFO:tensorflow:global_step/sec: 9.22259
# INFO:tensorflow:loss = 2.714244, step = 65416 (10.846 sec)
# INFO:tensorflow:lr = 0.00020726795 (10.845 sec)
# INFO:tensorflow:global_step/sec: 9.10879
# INFO:tensorflow:loss = 2.614506, step = 65516 (10.979 sec)
# INFO:tensorflow:lr = 0.00020705971 (10.979 sec)
# INFO:tensorflow:Saving checkpoints for 65598 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.6708627.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-65598
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 ~
# A2: 谢 谢
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 早 安
# A3: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
#
# Q: 晚 上 好
# A1: 晚 上 好 ~
# A2: 你 好 你 好 ~
# A3: 你 好 ~
#
# Q: 再 见
# A1: 没 有
# A2: 别 吵 ， 伦 家 正 在 梅 州 行 网 站 上 逛 论 坛 呢
# A3: 嗯 ， 去
#
# Q: 好 久 不 见
# A1: 我 也 爱 你
# A2: 我 也 是
# A3: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊 ~
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 你 死 了 我 还 没 死
# A3: 是 吗 ， 偶 也 想 你 啊
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 你 啊
# A3: 我 很 爱 你 ， 老 公
#
# Q: 你 好 厉 害 啊
# A1: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A2: 还 好 啦 ， 不 算 厉 害
# A3: 牛 逼
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 我 叫 西 哦 ^
# A3: 我 叫 西 哦 ^ ^
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 你 猜 啊
# A3: 是
#
# Q: 现 在 几 点
# A1: 自 己 看 吧
# A2: 现 在 时 间
# A3: 现 在 时 刻 1 3 点 0 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 天 还 好
# A2: 长 得 还 行
# A3: 天 还 好 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 长 春
# A3: 我 在 火 星 。
#
# Q: 讲 个 笑 话
# A1: 你 是 锄 禾 我 是 当 午
# A2: 靠 ， 又 是 她 ？
# A3: 靠 ， 又 是 她 ？ ？
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 几 门 会 几 门
# A2: 现 在 的 生 活 太 感 性 ， 情 绪 不 停 泛 滥 ， 身 心 具 疲
# A3: 有 几 几 言
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 不 觉 得
# A3: 你 妈 啊
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！ ！
# A2: 讨 厌 ！
# A3: y e s !
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 我 也 是
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: 当 然 是 真 的 啦
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 骄 傲 哦
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 怎 么 了
# A3: 我 陪 你
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 雨 会 下 雨 不 会 下
# A3: 天 气 好 好 晴 朗
#
# Q: 下 雨 了
# A1: 是 啊
# A2: 我 不 喜 欢 流 汗
# A3: 我 不 喜 欢 这 天 气 ！
#
# Q: 风 好 大
# A1: 宁 达 达
# A2: 哦
# A3: 宁 宁 达
#
# Q: 终 于 周 五 了
# A1: 好 听
# A2: 给 你
# A3: 听 你 这 是 屌 丝
#
# Q: 我 想 去 k 歌
# A1: 不 去 了
# A2: 要 去 就 去 啊 ， 速 度
# A3: 去 山 边
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:38:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-65598
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:38:30
# INFO:tensorflow:Saving dict for global step 65598: global_step = 65598, loss = 1.2909347
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 65598: ../model/transformer/model.ckpt-65598
# INFO:tensorflow:Perplexity: 3.636
# INFO:tensorflow:Best Perplexity: 3.614
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-65598
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 65598 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.5442786, step = 65598
# INFO:tensorflow:lr = 0.00020688915
# INFO:tensorflow:global_step/sec: 5.95025
# INFO:tensorflow:loss = 2.6418335, step = 65698 (16.810 sec)
# INFO:tensorflow:lr = 0.00020668135 (16.808 sec)
# INFO:tensorflow:global_step/sec: 9.00917
# INFO:tensorflow:loss = 2.6914306, step = 65798 (11.100 sec)
# INFO:tensorflow:lr = 0.0002064737 (11.101 sec)
# INFO:tensorflow:global_step/sec: 9.08285
# INFO:tensorflow:loss = 2.660802, step = 65898 (11.009 sec)
# INFO:tensorflow:lr = 0.00020626633 (11.009 sec)
# INFO:tensorflow:global_step/sec: 8.95662
# INFO:tensorflow:loss = 2.5394416, step = 65998 (11.166 sec)
# INFO:tensorflow:lr = 0.00020605909 (11.166 sec)
# INFO:tensorflow:global_step/sec: 8.95195
# INFO:tensorflow:loss = 2.5733962, step = 66098 (11.171 sec)
# INFO:tensorflow:lr = 0.00020585212 (11.172 sec)
# INFO:tensorflow:global_step/sec: 9.07066
# INFO:tensorflow:loss = 2.6437852, step = 66198 (11.025 sec)
# INFO:tensorflow:lr = 0.00020564532 (11.025 sec)
# INFO:tensorflow:global_step/sec: 9.11564
# INFO:tensorflow:loss = 2.6037774, step = 66298 (10.969 sec)
# INFO:tensorflow:lr = 0.00020543876 (10.968 sec)
# INFO:tensorflow:global_step/sec: 9.13282
# INFO:tensorflow:loss = 2.6198883, step = 66398 (10.950 sec)
# INFO:tensorflow:lr = 0.00020523238 (10.949 sec)
# INFO:tensorflow:global_step/sec: 9.21806
# INFO:tensorflow:loss = 2.5760224, step = 66498 (10.849 sec)
# INFO:tensorflow:lr = 0.00020502621 (10.851 sec)
# INFO:tensorflow:Saving checkpoints for 66598 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.31045
# INFO:tensorflow:loss = 2.622829, step = 66598 (13.679 sec)
# INFO:tensorflow:lr = 0.00020482027 (13.679 sec)
# INFO:tensorflow:global_step/sec: 8.84293
# INFO:tensorflow:loss = 2.715133, step = 66698 (11.305 sec)
# INFO:tensorflow:lr = 0.00020461451 (11.306 sec)
# INFO:tensorflow:global_step/sec: 9.19997
# INFO:tensorflow:loss = 2.7018166, step = 66798 (10.872 sec)
# INFO:tensorflow:lr = 0.00020440899 (10.870 sec)
# INFO:tensorflow:global_step/sec: 9.09785
# INFO:tensorflow:loss = 2.6843336, step = 66898 (10.993 sec)
# INFO:tensorflow:lr = 0.00020420365 (10.993 sec)
# INFO:tensorflow:global_step/sec: 9.28694
# INFO:tensorflow:loss = 2.6182837, step = 66998 (10.768 sec)
# INFO:tensorflow:lr = 0.00020399854 (10.770 sec)
# INFO:tensorflow:global_step/sec: 9.19204
# INFO:tensorflow:loss = 2.6353896, step = 67098 (10.879 sec)
# INFO:tensorflow:lr = 0.00020379362 (10.877 sec)
# INFO:tensorflow:global_step/sec: 9.13547
# INFO:tensorflow:loss = 2.696848, step = 67198 (10.946 sec)
# INFO:tensorflow:lr = 0.00020358889 (10.946 sec)
# INFO:tensorflow:Saving checkpoints for 67280 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.718321.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-67280
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 ~
# A2: 你 好 我 才 好
# A3: 我 很 好 啊
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 嗨 ~
# A3: 早 安
#
# Q: 晚 上 好
# A1: 你 好 ~
# A2: 晚 上 好 ～
# A3: 晚 上 好 ~
#
# Q: 再 见
# A1: 嗯
# A2: 嗯 ， 再 见
# A3: 嗯 嗯
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了
# A2: 是 啊 ， 蛮 久 的 吧
# A3: 是
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 你 死 了 我 还 没 死
# A3: 你 死 了 我
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 那 么 啊
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 是
# A3: 哦 哦
#
# Q: 你 好 厉 害 啊
# A1: 还 好 啦 ， 不 算 厉 害
# A2: 厉 害 的 还 没 见 过
# A3: 牛 逼
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 你 不 是 叫 网 友 吗
# A3: 我 不 知 道
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 是
#
# Q: 现 在 几 点
# A1: 现 在 时 间 是 1 5 分
# A2: 现 在 时 间 是 1 4 分
# A3: 现 在 时 间 是 1 3 点 0 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 天 气 好 晴 朗
# A3: 还 好 吧 ， 一 般 般 啦
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 当 然 在 咯
# A3: 在 火 星
#
# Q: 讲 个 笑 话
# A1: 你 是 锄 禾 我 是 当 午
# A2: 靠 ， 又 是 她 ？
# A3: 你 是 锄 锄 禾 我 是 当 午
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 我 会 的 可 多 了
# A3: 当 然 会 啦
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 不 觉 得
# A3: 帅 哥
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！ ！
# A2: 来 了
# A3: 非 常 讨 厌
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 有 什 么 好 烦 的 ， 真 的 是
# A3: 哦
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; ) 谦 虚 是 立 足 之 能 骄 傲 哦
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 实
#
# Q: 今 天 好 冷
# A1: 对 阿 ， 都 木 有 人 说 话
# A2: 对 对 阿 ， 都 木 有 人 说 话
# A3: 对 不 起 ， 我 没 明 白 你 的 意 思 … …
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 今 天 这 天 气 很 适 合 聊 天 的 说
# A3: 对 呀
#
# Q: 下 雨 了
# A1: 最 美
# A2: 最 美 了
# A3: 最 美 女
#
# Q: 风 好 大
# A1: 谈 谈 情 ， 跳 跳 舞 ， 跟 我 搞 暧 昧 啊
# A2: 很 帅
# A3: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
#
# Q: 终 于 周 五 了
# A1: 吃 饭 吧
# A2: 给 你
# A3: 送 最 贵 的
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 去 吧 ， 赶 紧 的
# A3: 要 去 就 去 啊 ， 速 度
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:42:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-67280
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:43:02
# INFO:tensorflow:Saving dict for global step 67280: global_step = 67280, loss = 1.2872397
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 67280: ../model/transformer/model.ckpt-67280
# INFO:tensorflow:Perplexity: 3.623
# INFO:tensorflow:Best Perplexity: 3.614
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-67280
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 67280 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.6102438, step = 67280
# INFO:tensorflow:lr = 0.00020342116
# INFO:tensorflow:global_step/sec: 6.07146
# INFO:tensorflow:loss = 2.5866728, step = 67380 (16.472 sec)
# INFO:tensorflow:lr = 0.00020321681 (16.472 sec)
# INFO:tensorflow:global_step/sec: 9.25462
# INFO:tensorflow:loss = 2.626245, step = 67480 (10.807 sec)
# INFO:tensorflow:lr = 0.00020301268 (10.805 sec)
# INFO:tensorflow:global_step/sec: 9.238
# INFO:tensorflow:loss = 2.6049244, step = 67580 (10.825 sec)
# INFO:tensorflow:lr = 0.00020280876 (10.825 sec)
# INFO:tensorflow:global_step/sec: 9.25829
# INFO:tensorflow:loss = 2.678714, step = 67680 (10.799 sec)
# INFO:tensorflow:lr = 0.00020260502 (10.799 sec)
# INFO:tensorflow:global_step/sec: 9.21512
# INFO:tensorflow:loss = 2.6866732, step = 67780 (10.854 sec)
# INFO:tensorflow:lr = 0.00020240148 (10.854 sec)
# INFO:tensorflow:global_step/sec: 9.36651
# INFO:tensorflow:loss = 2.6835654, step = 67880 (10.676 sec)
# INFO:tensorflow:lr = 0.00020219819 (10.677 sec)
# INFO:tensorflow:global_step/sec: 9.24224
# INFO:tensorflow:loss = 2.6021702, step = 67980 (10.820 sec)
# INFO:tensorflow:lr = 0.00020199506 (10.819 sec)
# INFO:tensorflow:global_step/sec: 9.24502
# INFO:tensorflow:loss = 2.7861001, step = 68080 (10.817 sec)
# INFO:tensorflow:lr = 0.0002017922 (10.820 sec)
# INFO:tensorflow:global_step/sec: 9.28123
# INFO:tensorflow:loss = 2.6752105, step = 68180 (10.774 sec)
# INFO:tensorflow:lr = 0.00020158946 (10.772 sec)
# INFO:tensorflow:Saving checkpoints for 68280 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.67073
# INFO:tensorflow:loss = 2.5965457, step = 68280 (13.037 sec)
# INFO:tensorflow:lr = 0.00020138695 (13.036 sec)
# INFO:tensorflow:global_step/sec: 8.91342
# INFO:tensorflow:loss = 2.6055675, step = 68380 (11.216 sec)
# INFO:tensorflow:lr = 0.00020118465 (11.218 sec)
# INFO:tensorflow:global_step/sec: 9.31942
# INFO:tensorflow:loss = 2.7272651, step = 68480 (10.730 sec)
# INFO:tensorflow:lr = 0.00020098257 (10.729 sec)
# INFO:tensorflow:global_step/sec: 9.25258
# INFO:tensorflow:loss = 2.635021, step = 68580 (10.811 sec)
# INFO:tensorflow:lr = 0.00020078068 (10.810 sec)
# INFO:tensorflow:global_step/sec: 9.15548
# INFO:tensorflow:loss = 2.7303498, step = 68680 (10.923 sec)
# INFO:tensorflow:lr = 0.000200579 (10.922 sec)
# INFO:tensorflow:global_step/sec: 9.25036
# INFO:tensorflow:loss = 2.6104062, step = 68780 (10.811 sec)
# INFO:tensorflow:lr = 0.00020037749 (10.811 sec)
# INFO:tensorflow:global_step/sec: 9.23001
# INFO:tensorflow:loss = 2.5550618, step = 68880 (10.836 sec)
# INFO:tensorflow:lr = 0.0002001762 (10.838 sec)
# INFO:tensorflow:Saving checkpoints for 68962 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.6379068.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-68962
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 ~
# A2: 好 好 好 ~
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 你 好 呀 ~
# A3: 早 安
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 晚 上 好 啊 ~
# A3: 晚 上 好 啊 ！
#
# Q: 再 见
# A1: 无 聊 的 人 说 无 聊 的 话
# A2: 你 说 的 什 么 哦 ？ 换 种 说 法 行 不
# A3: 有 些 事 没 必 要 认 真 ， 有 些 人 没 必 要 理 会
#
# Q: 好 久 不 见
# A1: 是 啊 ， 好 多
# A2: 是 啊 ， 蛮 久 的 了 ， 好 想 你 了
# A3: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 是 吗 ， 偶 也 想 你 啊
# A3: 我 也 想 你 了
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 嗯 嗯
#
# Q: 爱 你
# A1: 哦
# A2: 爱 我
# A3: 我 也 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 还 好 啦 ， 不 算 厉 害
# A3: 这 样 算 什 么 厉 害 ~
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 我 不 是 人
# A3: 我 不 认 识
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 比 你 聪 明 ~
# A3: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
#
# Q: 现 在 几 点
# A1: 自 己 看 吧
# A2: 吃 饭 睡 觉
# A3: 自 己 吃 吧
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 长 得 还 行
# A3: 今 天 还 不 错 哇
#
# Q: 我 们 现 在 在 哪 里
# A1: 长 春
# A2: 在 这 里 了
# A3: 我 知 道 ， 阮 琦 哈 ？
#
# Q: 讲 个 笑 话
# A1: 三 重
# A2: 你 是 锄 禾 我 是 当 午
# A3: 快 去 休 息 ！
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 多 少
# A2: 有 几 门
# A3: 有 多 少 要 多 少
#
# Q: 你 觉 得 我 帅 吗
# A1: 你 美
# A2: 你 很 帅 啊
# A3: 你 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！ ！
# A2: 讨 厌 ！
# A3: 哦
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 是 吗 ？
# A3: 哦
#
# Q: 天 气 真 好
# A1: 会 吗
# A2: 是 啊 ， 其 乐 无 穷
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 真 的 吗 。 生 日 快 乐 ~
# A3: 真 的 吗
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 真 的 吗 。 生 日 快 乐 ~
# A3: 女 子 无 聊
#
# Q: 下 雨 了
# A1: 最 美 的 不 是 下 雨 点
# A2: 最 美 的 不 是 下 天 了
# A3: 谁 让 你 这 个 了
#
# Q: 风 好 大
# A1: 大 家 好 吃
# A2: 今 天 这 天 气 很 适 合 聊 天 的 说
# A3: 哈 哈
#
# Q: 终 于 周 五 了
# A1: 听 你 这 样
# A2: 帅 哥 哥
# A3: 帅 哥
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 就 去 吧
# A3: 去 吧 ， 赶 紧 的
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:47:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-68962
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:47:30
# INFO:tensorflow:Saving dict for global step 68962: global_step = 68962, loss = 1.2781379
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 68962: ../model/transformer/model.ckpt-68962
# INFO:tensorflow:Perplexity: 3.590
# INFO:tensorflow:Best Perplexity: 3.590
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-68962
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 68962 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.6086063, step = 68962
# INFO:tensorflow:lr = 0.0002000113
# INFO:tensorflow:global_step/sec: 6.11163
# INFO:tensorflow:loss = 2.5549617, step = 69062 (16.365 sec)
# INFO:tensorflow:lr = 0.0001998104 (16.363 sec)
# INFO:tensorflow:global_step/sec: 9.27904
# INFO:tensorflow:loss = 2.4970064, step = 69162 (10.778 sec)
# INFO:tensorflow:lr = 0.00019960968 (10.779 sec)
# INFO:tensorflow:global_step/sec: 9.32979
# INFO:tensorflow:loss = 2.6736724, step = 69262 (10.719 sec)
# INFO:tensorflow:lr = 0.00019940917 (10.718 sec)
# INFO:tensorflow:global_step/sec: 9.26029
# INFO:tensorflow:loss = 2.588553, step = 69362 (10.799 sec)
# INFO:tensorflow:lr = 0.00019920885 (10.798 sec)
# INFO:tensorflow:global_step/sec: 9.26734
# INFO:tensorflow:loss = 2.6498704, step = 69462 (10.791 sec)
# INFO:tensorflow:lr = 0.00019900872 (10.791 sec)
# INFO:tensorflow:global_step/sec: 9.32906
# INFO:tensorflow:loss = 2.6528103, step = 69562 (10.719 sec)
# INFO:tensorflow:lr = 0.00019880882 (10.720 sec)
# INFO:tensorflow:global_step/sec: 9.24198
# INFO:tensorflow:loss = 2.5643744, step = 69662 (10.821 sec)
# INFO:tensorflow:lr = 0.00019860911 (10.820 sec)
# INFO:tensorflow:global_step/sec: 9.26374
# INFO:tensorflow:loss = 2.717594, step = 69762 (10.794 sec)
# INFO:tensorflow:lr = 0.0001984096 (10.794 sec)
# INFO:tensorflow:global_step/sec: 9.23135
# INFO:tensorflow:loss = 2.6157537, step = 69862 (10.832 sec)
# INFO:tensorflow:lr = 0.00019821031 (10.832 sec)
# INFO:tensorflow:Saving checkpoints for 69962 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.74046
# INFO:tensorflow:loss = 2.602346, step = 69962 (12.919 sec)
# INFO:tensorflow:lr = 0.00019801118 (12.921 sec)
# INFO:tensorflow:global_step/sec: 8.93352
# INFO:tensorflow:loss = 2.5724368, step = 70062 (11.194 sec)
# INFO:tensorflow:lr = 0.00019781229 (11.194 sec)
# INFO:tensorflow:global_step/sec: 9.27848
# INFO:tensorflow:loss = 2.682033, step = 70162 (10.778 sec)
# INFO:tensorflow:lr = 0.00019761358 (10.776 sec)
# INFO:tensorflow:global_step/sec: 9.19681
# INFO:tensorflow:loss = 2.5571146, step = 70262 (10.873 sec)
# INFO:tensorflow:lr = 0.00019741507 (10.873 sec)
# INFO:tensorflow:global_step/sec: 9.23747
# INFO:tensorflow:loss = 2.626926, step = 70362 (10.823 sec)
# INFO:tensorflow:lr = 0.00019721675 (10.823 sec)
# INFO:tensorflow:global_step/sec: 9.29416
# INFO:tensorflow:loss = 2.6783895, step = 70462 (10.762 sec)
# INFO:tensorflow:lr = 0.00019701864 (10.763 sec)
# INFO:tensorflow:global_step/sec: 9.32566
# INFO:tensorflow:loss = 2.5667417, step = 70562 (10.721 sec)
# INFO:tensorflow:lr = 0.00019682074 (10.720 sec)
# INFO:tensorflow:Saving checkpoints for 70644 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.6096635.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-70644
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 大 家 好 才 是 真 的 好
# A2: 我 很 好
# A3: 好 啊 ~ 你 更 好
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 早 安
# A3: 早 安 ~
#
# Q: 晚 上 好
# A1: 你 好
# A2: 你 好 你 好 ~
# A3: 你 好 ~
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 拜 拜
# A3: 嗯 ， 去 吧 去 吧
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是
# A3: 是 啊 ， 蛮 久 的
#
# Q: 想 死 你 了
# A1: 我 活 着 好 好 的 ， 干 嘛 要 去 死
# A2: 我 也 想 你
# A3: 我 也 想 你 啦
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 别 谢 我 ！
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 你 打 算 向 我 求 婚 吗
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 是
# A3: 这 样 算 什 么 厉 害 ~ ， 太 没 世 面 啦 你
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 我 叫 朱 梦 杰
# A3: 我 叫 西 西 哦 ^ ^
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 你 猜 啊
# A3: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 点 3 分
# A2: 现 在 时 刻 1 6 点 5 分
# A3: 早 安
#
# Q: 今 天 天 气 怎 么 样
# A1: 是 一 个 可 爱 滴 乖 小 孩
# A2: 是 一 个 可 爱 小 孩
# A3: 是 一 个 可 爱 滴 乖 小 朋 友
#
# Q: 我 们 现 在 在 哪 里
# A1: 我 在 想 你
# A2: 在 这 里
# A3: 当 然 在 咯
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 你 是 锄 禾 我 是 当 午
# A3: 三 重
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 我 会 的 可 多 了
# A3: 有 几 点 会 几 门
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了
# A2: 帅 ！ 帅 到 爆 了 ~ ！
# A3: 你 很 帅
#
# Q: 讨 厌 的 周 一
# A1: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
# A2: 我 最 讨 厌 你 了
# A3: 我 就 一 个 脑 袋 ， 思 想 再 活 跃 也 有 局 限 性
#
# Q: 好 烦 啊
# A1: 哦 了 哦 了
# A2: 哦
# A3: 哦 哦 . . .
#
# Q: 天 气 真 好
# A1: 你 好 呀 ~
# A2: 你 好
# A3: 我 在 看 : o
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 今 天 星 期 三
# A3: 今 天 气 很 适 合 聊 天 的 说
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 今 天 是 个 好 日 子 ， 怎 么 不 出 去 玩 玩
# A3: 今 天 这 天 气 很 适 合 聊 天 的 说
#
# Q: 下 雨 了
# A1: 负 二 代 是 我 爷 爷
# A2: 打 得 了
# A3: 小 心 我 告 你 性 骚 扰
#
# Q: 风 好 大
# A1: 很 好 啊 ~
# A2: 大 美 女
# A3: 哦
#
# Q: 终 于 周 五 了
# A1: 听 日 休 息 ？
# A2: 听 你 这 口 气 ， 好 像 花 了 不 少 时 间 吧
# A3: 死 了
#
# Q: 我 想 去 k 歌
# A1: 去 吧 ， 赶 紧 的
# A2: 我 爱 你
# A3: 那 就 加 油 啦 ！ 我 会 陪 你
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:51:52Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-70644
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:51:58
# INFO:tensorflow:Saving dict for global step 70644: global_step = 70644, loss = 1.2724587
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 70644: ../model/transformer/model.ckpt-70644
# INFO:tensorflow:Perplexity: 3.570
# INFO:tensorflow:Best Perplexity: 3.570
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-70644
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 70644 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.7553988, step = 70644
# INFO:tensorflow:lr = 0.0001966586
# INFO:tensorflow:global_step/sec: 6.03371
# INFO:tensorflow:loss = 2.6515937, step = 70744 (16.577 sec)
# INFO:tensorflow:lr = 0.00019646104 (16.577 sec)
# INFO:tensorflow:global_step/sec: 9.33696
# INFO:tensorflow:loss = 2.661677, step = 70844 (10.710 sec)
# INFO:tensorflow:lr = 0.00019626369 (10.711 sec)
# INFO:tensorflow:global_step/sec: 9.26101
# INFO:tensorflow:loss = 2.5941277, step = 70944 (10.798 sec)
# INFO:tensorflow:lr = 0.00019606654 (10.798 sec)
# INFO:tensorflow:global_step/sec: 9.27651
# INFO:tensorflow:loss = 2.6164951, step = 71044 (10.780 sec)
# INFO:tensorflow:lr = 0.0001958696 (10.780 sec)
# INFO:tensorflow:global_step/sec: 9.19983
# INFO:tensorflow:loss = 2.6028237, step = 71144 (10.869 sec)
# INFO:tensorflow:lr = 0.00019567282 (10.870 sec)
# INFO:tensorflow:global_step/sec: 9.26201
# INFO:tensorflow:loss = 2.6483433, step = 71244 (10.796 sec)
# INFO:tensorflow:lr = 0.00019547627 (10.797 sec)
# INFO:tensorflow:global_step/sec: 9.2251
# INFO:tensorflow:loss = 2.6388063, step = 71344 (10.841 sec)
# INFO:tensorflow:lr = 0.00019527992 (10.841 sec)
# INFO:tensorflow:global_step/sec: 9.30495
# INFO:tensorflow:loss = 2.5759625, step = 71444 (10.744 sec)
# INFO:tensorflow:lr = 0.00019508376 (10.744 sec)
# INFO:tensorflow:global_step/sec: 9.2367
# INFO:tensorflow:loss = 2.661529, step = 71544 (10.829 sec)
# INFO:tensorflow:lr = 0.00019488778 (10.829 sec)
# INFO:tensorflow:Saving checkpoints for 71644 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.40344
# INFO:tensorflow:loss = 2.6954384, step = 71644 (13.506 sec)
# INFO:tensorflow:lr = 0.00019469201 (13.507 sec)
# INFO:tensorflow:global_step/sec: 8.95524
# INFO:tensorflow:loss = 2.6744285, step = 71744 (11.167 sec)
# INFO:tensorflow:lr = 0.00019449643 (11.168 sec)
# INFO:tensorflow:global_step/sec: 9.17895
# INFO:tensorflow:loss = 2.7359743, step = 71844 (10.893 sec)
# INFO:tensorflow:lr = 0.00019430106 (10.894 sec)
# INFO:tensorflow:global_step/sec: 9.22942
# INFO:tensorflow:loss = 2.5578628, step = 71944 (10.837 sec)
# INFO:tensorflow:lr = 0.00019410589 (10.836 sec)
# INFO:tensorflow:global_step/sec: 9.24804
# INFO:tensorflow:loss = 2.5418448, step = 72044 (10.814 sec)
# INFO:tensorflow:lr = 0.00019391088 (10.813 sec)
# INFO:tensorflow:global_step/sec: 9.24299
# INFO:tensorflow:loss = 2.5804396, step = 72144 (10.819 sec)
# INFO:tensorflow:lr = 0.00019371611 (10.818 sec)
# INFO:tensorflow:global_step/sec: 9.26158
# INFO:tensorflow:loss = 2.6633704, step = 72244 (10.795 sec)
# INFO:tensorflow:lr = 0.00019352151 (10.795 sec)
# INFO:tensorflow:Saving checkpoints for 72326 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5367446.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-72326
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 ~
# A2: 谢 谢
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 你 好 你 好
# A2: 你 好 呀
# A3: 你 好 你 好 呀
#
# Q: 晚 上 好
# A1: 晚 安
# A2: 哦
# A3: 早 安
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 拜 拜 拜 ~
# A3: 拜 拜
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的
# A3: 是 啊 ， 蛮 蛮 久 的 吧
#
# Q: 想 死 你 了
# A1: 是 吗 ， 偶 也 想 你 啊
# A2: 我 也 想 你 啦
# A3: 我 也 想 你 ， 好 想 你
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 不 用 谢 谢 啦
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 是
# A3: 那 我 也 是
#
# Q: 你 好 厉 害 啊
# A1: 还 好 啦 ， 不 算 厉 害
# A2: 那 是 必 须 的 f a c e 5 7
# A3: 这 么 厉 害
#
# Q: 你 叫 什 么
# A1: 我 叫 朱 梦 杰
# A2: 我 不 叫
# A3: 我 叫 西 哦
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 没 龄
# A3: 女 生 的 年 龄 是 不 能 随 便 说 的 ， 知 道 不
#
# Q: 现 在 几 点
# A1: 吃 饭 睡 觉 打 豆
# A2: 现 在 时 刻 1 1 7 点 5 分
# A3: 吃 饭 吧 ？
#
# Q: 今 天 天 气 怎 么 样
# A1: 是 一 个 可 爱 滴 乖 小 孩
# A2: 今 天 还 不 错 哇 ， 心 情 很 好
# A3: 小 心
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 北 京
# A3: 我 在 火 星 。
#
# Q: 讲 个 笑 话
# A1: 三 重
# A2: 你 是 锄 禾 我 是 当 午
# A3: 你 是 锄 锄 禾 我 是 当 午
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几
# A3: 有 几 门 会 几 语
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 不 觉 得
# A3: 你 的 感 觉 比 较 准 确
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！
# A2: s o r r y
# A3: 讨 厌 ！ ！
#
# Q: 好 烦 啊
# A1: 哦 哦 . . .
# A2: 哦
# A3: 哦 了 哦 了
#
# Q: 天 气 真 好
# A1: 是 么 ？
# A2: 消 消 气
# A3: 别 气 别 气 别 气
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 对 阿 ， 都 木 有 人 说 话
# A3: 今 天 还 不 错 哦
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 气
# A3: 天 气 好 晴 晴 朗
#
# Q: 下 雨 了
# A1: 陪 你
# A2: 小 心
# A3: 我 喜 欢
#
# Q: 风 好 大
# A1: 多 谢
# A2: 多 美 女
# A3: 与 其 说 是 聊 天 ， 不 如 说 是 问 答 式 的 吧
#
# Q: 终 于 周 五 了
# A1: 听 什 么
# A2: 听 你 的
# A3: 听 说
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 不 去 了
# A3: 我 也 想 啊
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T06:56:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-72326
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-06:56:27
# INFO:tensorflow:Saving dict for global step 72326: global_step = 72326, loss = 1.2735678
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72326: ../model/transformer/model.ckpt-72326
# INFO:tensorflow:Perplexity: 3.574
# INFO:tensorflow:Best Perplexity: 3.570
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-72326
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72326 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.598635, step = 72326
# INFO:tensorflow:lr = 0.0001933621
# INFO:tensorflow:global_step/sec: 6.06755
# INFO:tensorflow:loss = 2.705314, step = 72426 (16.486 sec)
# INFO:tensorflow:lr = 0.00019316786 (16.486 sec)
# INFO:tensorflow:global_step/sec: 9.2759
# INFO:tensorflow:loss = 2.4984045, step = 72526 (10.781 sec)
# INFO:tensorflow:lr = 0.00019297382 (10.782 sec)
# INFO:tensorflow:global_step/sec: 9.10005
# INFO:tensorflow:loss = 2.6882706, step = 72626 (10.989 sec)
# INFO:tensorflow:lr = 0.00019277996 (10.987 sec)
# INFO:tensorflow:global_step/sec: 9.32735
# INFO:tensorflow:loss = 2.615445, step = 72726 (10.721 sec)
# INFO:tensorflow:lr = 0.0001925863 (10.721 sec)
# INFO:tensorflow:global_step/sec: 9.25756
# INFO:tensorflow:loss = 2.5342894, step = 72826 (10.802 sec)
# INFO:tensorflow:lr = 0.00019239286 (10.803 sec)
# INFO:tensorflow:global_step/sec: 9.28768
# INFO:tensorflow:loss = 2.755509, step = 72926 (10.767 sec)
# INFO:tensorflow:lr = 0.0001921996 (10.766 sec)
# INFO:tensorflow:global_step/sec: 9.30955
# INFO:tensorflow:loss = 2.686339, step = 73026 (10.739 sec)
# INFO:tensorflow:lr = 0.00019200654 (10.740 sec)
# INFO:tensorflow:global_step/sec: 9.2381
# INFO:tensorflow:loss = 2.5584133, step = 73126 (10.827 sec)
# INFO:tensorflow:lr = 0.00019181363 (10.826 sec)
# INFO:tensorflow:global_step/sec: 9.3117
# INFO:tensorflow:loss = 2.7495546, step = 73226 (10.740 sec)
# INFO:tensorflow:lr = 0.00019162096 (10.741 sec)
# INFO:tensorflow:Saving checkpoints for 73326 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.69305
# INFO:tensorflow:loss = 2.550159, step = 73326 (12.998 sec)
# INFO:tensorflow:lr = 0.00019142847 (12.997 sec)
# INFO:tensorflow:global_step/sec: 9.02036
# INFO:tensorflow:loss = 2.516285, step = 73426 (11.086 sec)
# INFO:tensorflow:lr = 0.00019123619 (11.087 sec)
# INFO:tensorflow:global_step/sec: 9.32224
# INFO:tensorflow:loss = 2.6026263, step = 73526 (10.726 sec)
# INFO:tensorflow:lr = 0.00019104409 (10.725 sec)
# INFO:tensorflow:global_step/sec: 9.30129
# INFO:tensorflow:loss = 2.57798, step = 73626 (10.749 sec)
# INFO:tensorflow:lr = 0.00019085217 (10.752 sec)
# INFO:tensorflow:global_step/sec: 9.28261
# INFO:tensorflow:loss = 2.7397993, step = 73726 (10.775 sec)
# INFO:tensorflow:lr = 0.00019066044 (10.773 sec)
# INFO:tensorflow:global_step/sec: 9.29748
# INFO:tensorflow:loss = 2.6884766, step = 73826 (10.756 sec)
# INFO:tensorflow:lr = 0.00019046893 (10.757 sec)
# INFO:tensorflow:global_step/sec: 9.1715
# INFO:tensorflow:loss = 2.7597616, step = 73926 (10.904 sec)
# INFO:tensorflow:lr = 0.0001902776 (10.903 sec)
# INFO:tensorflow:Saving checkpoints for 74008 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5313723.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-74008
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 ~
# A2: 我 很 好
# A3: 你 好 ~
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 早 安
# A3: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
#
# Q: 晚 上 好
# A1: 你 好 ~
# A2: 你 好 你 好 ~
# A3: 你 好
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 嗯 ， 再 见
# A3: 拜 拜
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊 ， 好 想 你 啊
# A3: 是 啊 ， 蛮 久 的
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 是 吗 ， 偶 也 想 你 啊
# A3: 我 很 想 你 啊
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 那 么 客 气 啊
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 我 也 是
#
# Q: 你 好 厉 害 啊
# A1: 那 是 必 须 的 f a c e 5 7
# A2: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A3: 这 样 算 什 么 厉 害 ~ ， 太 没 见 你
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 我 叫 朱 梦 杰
# A3: 我 叫 西 哦
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 不
# A3: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 6 点 5 分
# A2: 现 在 时 刻 1 5 点 5 分
# A3: 现 在 时 间 是 1 点 0 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 是 一 个 可 爱 滴 乖 小 孩
# A2: 今 天 还 不 错 哇 ， 心 情 很 好
# A3: 天 气 好 晴 朗
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 长 春
# A3: 被 狗 吃 了
#
# Q: 讲 个 笑 话
# A1: 三 重
# A2: 你 是 锄 禾 我 是 当 午
# A3: 三 重 重
#
# Q: 你 会 几 种 语 言 呀
# A1: 会 就 行 了
# A2: 不 会 就 得 学 呀 ~
# A3: 会
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 帅 屁 了
# A3: 帅 。 。
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！ ！
# A2: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
# A3: 讨 厌 ！
#
# Q: 好 烦 啊
# A1: 哦
# A2: 哦 了 哦 了
# A3: 哦 哦 . . .
#
# Q: 天 气 真 好
# A1: 是 啊 ， 其 乐 无 穷
# A2: 是 啊 ， 其 乐 无 敌
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
#
# Q: 今 天 好 冷
# A1: 天 气 好 好 晴 朗
# A2: 天 气 好 晴
# A3: 天 气 好 晴 朗
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴
# A3: 天 气 好 啊
#
# Q: 下 雨 了
# A1: 美 丽 的 小 女 孩
# A2: 最 美 的 不 好
# A3: 最 美 的 不 错
#
# Q: 风 好 大
# A1: 嘻 嘻
# A2: 奶 奶
# A3: 宁 达 达
#
# Q: 终 于 周 五 了
# A1: 听 你 的
# A2: 听 你 这 口 气
# A3: 听 你
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 要 去 就 去 啊 ， 速 度
# A3: 去 吧 ， 赶 紧 的
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T07:00:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-74008
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-07:00:55
# INFO:tensorflow:Saving dict for global step 74008: global_step = 74008, loss = 1.2746627
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 74008: ../model/transformer/model.ckpt-74008
# INFO:tensorflow:Perplexity: 3.577
# INFO:tensorflow:Best Perplexity: 3.570
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-74008
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 74008 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.620395, step = 74008
# INFO:tensorflow:lr = 0.00019012085
# INFO:tensorflow:global_step/sec: 6.0617
# INFO:tensorflow:loss = 2.7143466, step = 74108 (16.500 sec)
# INFO:tensorflow:lr = 0.00018992988 (16.499 sec)
# INFO:tensorflow:global_step/sec: 9.31018
# INFO:tensorflow:loss = 2.7505713, step = 74208 (10.743 sec)
# INFO:tensorflow:lr = 0.00018973908 (10.742 sec)
# INFO:tensorflow:global_step/sec: 9.24567
# INFO:tensorflow:loss = 2.6580875, step = 74308 (10.813 sec)
# INFO:tensorflow:lr = 0.00018954847 (10.814 sec)
# INFO:tensorflow:global_step/sec: 9.38643
# INFO:tensorflow:loss = 2.61553, step = 74408 (10.653 sec)
# INFO:tensorflow:lr = 0.00018935808 (10.653 sec)
# INFO:tensorflow:global_step/sec: 9.19822
# INFO:tensorflow:loss = 2.6016982, step = 74508 (10.873 sec)
# INFO:tensorflow:lr = 0.00018916787 (10.875 sec)
# INFO:tensorflow:global_step/sec: 9.20343
# INFO:tensorflow:loss = 2.6666138, step = 74608 (10.867 sec)
# INFO:tensorflow:lr = 0.00018897785 (10.866 sec)
# INFO:tensorflow:global_step/sec: 9.08662
# INFO:tensorflow:loss = 2.5664341, step = 74708 (11.005 sec)
# INFO:tensorflow:lr = 0.00018878802 (11.005 sec)
# INFO:tensorflow:global_step/sec: 9.3369
# INFO:tensorflow:loss = 2.5287447, step = 74808 (10.709 sec)
# INFO:tensorflow:lr = 0.00018859835 (10.710 sec)
# INFO:tensorflow:global_step/sec: 9.24151
# INFO:tensorflow:loss = 2.6806345, step = 74908 (10.828 sec)
# INFO:tensorflow:lr = 0.0001884089 (10.828 sec)
# INFO:tensorflow:Saving checkpoints for 75008 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.63451
# INFO:tensorflow:loss = 2.7031357, step = 75008 (13.092 sec)
# INFO:tensorflow:lr = 0.00018821964 (13.092 sec)
# INFO:tensorflow:global_step/sec: 8.86413
# INFO:tensorflow:loss = 2.6130958, step = 75108 (11.282 sec)
# INFO:tensorflow:lr = 0.00018803058 (11.283 sec)
# INFO:tensorflow:global_step/sec: 9.0934
# INFO:tensorflow:loss = 2.5448997, step = 75208 (10.997 sec)
# INFO:tensorflow:lr = 0.00018784171 (10.995 sec)
# INFO:tensorflow:global_step/sec: 9.30369
# INFO:tensorflow:loss = 2.5187025, step = 75308 (10.749 sec)
# INFO:tensorflow:lr = 0.000187653 (10.749 sec)
# INFO:tensorflow:global_step/sec: 9.20335
# INFO:tensorflow:loss = 2.6814797, step = 75408 (10.864 sec)
# INFO:tensorflow:lr = 0.0001874645 (10.865 sec)
# INFO:tensorflow:global_step/sec: 9.139
# INFO:tensorflow:loss = 2.7114823, step = 75508 (10.944 sec)
# INFO:tensorflow:lr = 0.00018727618 (10.943 sec)
# INFO:tensorflow:global_step/sec: 9.15865
# INFO:tensorflow:loss = 2.5905054, step = 75608 (10.918 sec)
# INFO:tensorflow:lr = 0.00018708807 (10.920 sec)
# INFO:tensorflow:Saving checkpoints for 75690 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5832524.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-75690
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 好 好 ~
# A2: 我 很 好 呀
# A3: 好 好 ~
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# A3: 你 的 好 呀
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 你 好 ~
# A3: 你 好 你 好 ~
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 嗯 ， 再 见
# A3: 拜 拜
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是
# A3: 我 见 过 ！
#
# Q: 想 死 你 了
# A1: 你 死 了 我 还 没 死
# A2: 谢 谢 夸 奖
# A3: 谢 谢
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 嗯 嗯
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 你 打 算 向 我 求 婚 吗
#
# Q: 你 好 厉 害 啊
# A1: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A2: 牛 逼
# A3: 厉 害 的 还 没 救
#
# Q: 你 叫 什 么
# A1: 你 不 是 叫 网 友 吗
# A2: 我 不 叫
# A3: 你 不 叫
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
# A3: 是
#
# Q: 现 在 几 点
# A1: 吃 饭 吧
# A2: 起 诉
# A3: 现 在 时 刻 1 点 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 长 得 还 行
# A2: 是 一 个 可 爱 滴 乖 小 孩
# A3: 还 不 错
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 我 在 这 里 了
# A3: 我 在 火 星 。
#
# Q: 讲 个 笑 话
# A1: 不 讲
# A2: 你 是 锄 禾 我 是 当 午
# A3: 不 讲 讲
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 几 门 ？
# A3: 有 几 几 门
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 我 没 有
# A3: 帅 ！
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！
# A2: 讨 人 喜 欢 百 看 不 厌
# A3: 讨 厌 ！ ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 是
# A2: 哦 了 哦 了
# A3: 哦
#
# Q: 天 气 真 好
# A1: 是 啊
# A2: 是 啊 ， 这 天 气 不 好
# A3: 消 气
#
# Q: 今 天 好 冷
# A1: 对 阿 ， 都 木 有 人 说 话
# A2: 今 天 这 天 气 很 适 合 聊 天 的 说
# A3: 对 阿 ， 都 木 有 人 说 了
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 晴
# A3: 天 晴 朗
#
# Q: 下 雨 了
# A1: 我 不 喜 欢 这 样 的 天 气 ！
# A2: 我 不 记 得
# A3: 我 不 知 道 ，
#
# Q: 风 好 大
# A1: 很 大 啊 ！
# A2: 很 大 啊 ~
# A3: 很 大 啊
#
# Q: 终 于 周 五 了
# A1: 好 啦
# A2: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
# A3: 你 是 不 是 觉 得 这 日 子 过 得 太 无 聊 了 哦
#
# Q: 我 想 去 k 歌
# A1: 我 也 想 你 了
# A2: 那 就 加 油 啦 ！ 我 会 陪 你
# A3: 要 去 就 去 啊 ， 速 度
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T07:05:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-75690
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-07:05:25
# INFO:tensorflow:Saving dict for global step 75690: global_step = 75690, loss = 1.2697037
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 75690: ../model/transformer/model.ckpt-75690
# INFO:tensorflow:Perplexity: 3.560
# INFO:tensorflow:Best Perplexity: 3.560
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-75690
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 75690 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.5023928, step = 75690
# INFO:tensorflow:lr = 0.00018693395
# INFO:tensorflow:global_step/sec: 5.87203
# INFO:tensorflow:loss = 2.5716772, step = 75790 (17.034 sec)
# INFO:tensorflow:lr = 0.00018674617 (17.034 sec)
# INFO:tensorflow:global_step/sec: 9.11811
# INFO:tensorflow:loss = 2.5358365, step = 75890 (10.967 sec)
# INFO:tensorflow:lr = 0.00018655855 (10.968 sec)
# INFO:tensorflow:global_step/sec: 9.09229
# INFO:tensorflow:loss = 2.5896497, step = 75990 (10.997 sec)
# INFO:tensorflow:lr = 0.00018637117 (10.997 sec)
# INFO:tensorflow:global_step/sec: 9.1308
# INFO:tensorflow:loss = 2.7013478, step = 76090 (10.953 sec)
# INFO:tensorflow:lr = 0.00018618394 (10.955 sec)
# INFO:tensorflow:global_step/sec: 9.13795
# INFO:tensorflow:loss = 2.6425114, step = 76190 (10.943 sec)
# INFO:tensorflow:lr = 0.00018599693 (10.941 sec)
# INFO:tensorflow:global_step/sec: 9.15107
# INFO:tensorflow:loss = 2.557614, step = 76290 (10.925 sec)
# INFO:tensorflow:lr = 0.0001858101 (10.925 sec)
# INFO:tensorflow:global_step/sec: 9.16687
# INFO:tensorflow:loss = 2.5727363, step = 76390 (10.909 sec)
# INFO:tensorflow:lr = 0.00018562343 (10.918 sec)
# INFO:tensorflow:global_step/sec: 9.12672
# INFO:tensorflow:loss = 2.4927886, step = 76490 (10.960 sec)
# ...
# INFO:tensorflow:global_step/sec: 9.11844
# INFO:tensorflow:loss = 2.611469, step = 96674 (10.966 sec)
# INFO:tensorflow:lr = 0.00015138999 (10.966 sec)
# INFO:tensorflow:global_step/sec: 9.13438
# INFO:tensorflow:loss = 2.5062149, step = 96774 (10.948 sec)
# INFO:tensorflow:lr = 0.00015123791 (10.947 sec)
# INFO:tensorflow:Saving checkpoints for 96874 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.61921
# INFO:tensorflow:loss = 2.5177958, step = 96874 (13.125 sec)
# INFO:tensorflow:lr = 0.00015108599 (13.126 sec)
# INFO:tensorflow:global_step/sec: 8.73794
# INFO:tensorflow:loss = 2.5806177, step = 96974 (11.445 sec)
# INFO:tensorflow:lr = 0.00015093421 (11.445 sec)
# INFO:tensorflow:global_step/sec: 9.05008
# INFO:tensorflow:loss = 2.5109024, step = 97074 (11.049 sec)
# INFO:tensorflow:lr = 0.00015078261 (11.049 sec)
# INFO:tensorflow:global_step/sec: 9.09192
# INFO:tensorflow:loss = 2.5224686, step = 97174 (10.999 sec)
# INFO:tensorflow:lr = 0.00015063114 (10.997 sec)
# INFO:tensorflow:global_step/sec: 9.11724
# INFO:tensorflow:loss = 2.5085804, step = 97274 (10.966 sec)
# INFO:tensorflow:lr = 0.00015047984 (10.966 sec)
# INFO:tensorflow:global_step/sec: 9.14472
# INFO:tensorflow:loss = 2.4578817, step = 97374 (10.935 sec)
# INFO:tensorflow:lr = 0.00015032866 (10.935 sec)
# INFO:tensorflow:global_step/sec: 9.14773
# INFO:tensorflow:loss = 2.5518932, step = 97474 (10.934 sec)
# INFO:tensorflow:lr = 0.00015017766 (10.935 sec)
# INFO:tensorflow:Saving checkpoints for 97556 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.4437773.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-97556
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 我 很 好 呀 ~
# A2: 我 很 好 呀
# A3: 好 好 啊 ~ 你 更 好
#
# Q: 早 上 好
# A1: 早 安
# A2: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# A3: 你 好 呀
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 早 安
# A3: 你 好 呀
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 无 聊 的 人 说 无 聊 的 话
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了 ， 好 吧
# A3: 是 啊 ， 蛮 开 心 的
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 谢 天 华
# A3: 没 有 ， 怎 麼 了
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 哦 哦
#
# Q: 你 好 厉 害 啊
# A1: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A2: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A3: 那 是 必 须 的 f a c e 5 7
#
# Q: 你 叫 什 么
# A1: 我 叫 朱 梦 杰
# A2: 我 叫 麻 辣 鸡 丝
# A3: 你 不 是 叫 网 友 吗
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
#
# Q: 现 在 几 点
# A1: 自 己 看 表
# A2: 现 在 时 刻 刻 1 3 分
# A3: 现 在 时 刻 刻 1 7 点 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 今 天 还 不 错 ？
# A3: 今 天 还 不 错 呢
#
# Q: 我 们 现 在 在 哪 里
# A1: 管 你 在 哪 ， 没 人 关 注 你 的
# A2: 管 你 在 哪 ， 没 人 关 系
# A3: 管 你 呢
#
# Q: 讲 个 笑 话
# A1: 靠 ， 又 是 她 ？
# A2: 三 重
# A3: 你 是 锄 禾 我 是 当 午
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 我 会 的 可 多 了
# A3: 有 几 门 ？
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 长 得 很 有 杀 伤 力
# A3: 你 长 的 随
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！
# A2: 讨 厌 ！ ！
# A3: 黄 圆 儿
#
# Q: 好 烦 啊
# A1: 哦
# A2: 哦 了 哦 了
# A3: 哦 哦 . . .
#
# Q: 天 气 真 好
# A1: 是 啊 ， 这 天 气 不 错 嘛 ~
# A2: 哦 了
# A3: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 天 气 好 好 晴 朗
# A3: 那 就 好
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 晴 朗
# A3: 天 气 吗 ？
#
# Q: 下 雨 了
# A1: 不 知 道
# A2: 我 不 喜 欢 这 样 的 天 气 ！
# A3: 啊 ， 这 天 气 太 讨 厌 ！
#
# Q: 风 好 大
# A1: 哦 哦 . . .
# A2: 哦
# A3: 哦 了 哦 了
#
# Q: 终 于 周 五 了
# A1: 听 你 这 口 气 ， 好 像 花 了 不 少 时 间 吧
# A2: 给 你 听
# A3: 哦
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 你 想 什 么 呢 ？
# A3: 那 就 加 油 啦
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T08:04:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-97556
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-08:04:15
# INFO:tensorflow:Saving dict for global step 97556: global_step = 97556, loss = 1.2695122
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 97556: ../model/transformer/model.ckpt-97556
# INFO:tensorflow:Perplexity: 3.559
# INFO:tensorflow:Best Perplexity: 3.559
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-97556
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 97556 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.5554879, step = 97556
# INFO:tensorflow:lr = 0.00015005394
# INFO:tensorflow:global_step/sec: 5.80757
# INFO:tensorflow:loss = 2.4967113, step = 97656 (17.223 sec)
# INFO:tensorflow:lr = 0.0001499032 (17.225 sec)
# INFO:tensorflow:global_step/sec: 9.11725
# INFO:tensorflow:loss = 2.5781605, step = 97756 (10.965 sec)
# INFO:tensorflow:lr = 0.00014975262 (10.964 sec)
# INFO:tensorflow:global_step/sec: 9.14584
# INFO:tensorflow:loss = 2.4742875, step = 97856 (10.937 sec)
# INFO:tensorflow:lr = 0.0001496022 (10.937 sec)
# INFO:tensorflow:global_step/sec: 9.12315
# INFO:tensorflow:loss = 2.4835865, step = 97956 (10.958 sec)
# INFO:tensorflow:lr = 0.00014945194 (10.957 sec)
# INFO:tensorflow:global_step/sec: 9.10726
# INFO:tensorflow:loss = 2.5318615, step = 98056 (10.980 sec)
# INFO:tensorflow:lr = 0.00014930179 (10.982 sec)
# INFO:tensorflow:global_step/sec: 9.13557
# INFO:tensorflow:loss = 2.4761255, step = 98156 (10.949 sec)
# INFO:tensorflow:lr = 0.0001491518 (10.948 sec)
# INFO:tensorflow:global_step/sec: 9.03835
# INFO:tensorflow:loss = 2.5197911, step = 98256 (11.063 sec)
# INFO:tensorflow:lr = 0.000149002 (11.062 sec)
# INFO:tensorflow:global_step/sec: 9.18577
# INFO:tensorflow:loss = 2.5056622, step = 98356 (10.888 sec)
# INFO:tensorflow:lr = 0.00014885231 (10.887 sec)
# INFO:tensorflow:global_step/sec: 9.13471
# INFO:tensorflow:loss = 2.500799, step = 98456 (10.946 sec)
# INFO:tensorflow:lr = 0.00014870279 (10.947 sec)
# INFO:tensorflow:Saving checkpoints for 98556 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.27609
# INFO:tensorflow:loss = 2.5535235, step = 98556 (13.745 sec)
# INFO:tensorflow:lr = 0.0001485534 (13.744 sec)
# INFO:tensorflow:global_step/sec: 8.83016
# INFO:tensorflow:loss = 2.5228422, step = 98656 (11.322 sec)
# INFO:tensorflow:lr = 0.00014840417 (11.322 sec)
# INFO:tensorflow:global_step/sec: 9.06254
# INFO:tensorflow:loss = 2.510994, step = 98756 (11.037 sec)
# INFO:tensorflow:lr = 0.00014825509 (11.037 sec)
# INFO:tensorflow:global_step/sec: 9.04421
# INFO:tensorflow:loss = 2.5239074, step = 98856 (11.054 sec)
# INFO:tensorflow:lr = 0.00014810618 (11.054 sec)
# INFO:tensorflow:global_step/sec: 9.04097
# INFO:tensorflow:loss = 2.5314977, step = 98956 (11.064 sec)
# INFO:tensorflow:lr = 0.0001479574 (11.063 sec)
# INFO:tensorflow:global_step/sec: 9.00649
# INFO:tensorflow:loss = 2.4923847, step = 99056 (11.102 sec)
# INFO:tensorflow:lr = 0.00014780877 (11.103 sec)
# INFO:tensorflow:global_step/sec: 9.10055
# INFO:tensorflow:loss = 2.5386612, step = 99156 (10.989 sec)
# INFO:tensorflow:lr = 0.00014766029 (10.989 sec)
# INFO:tensorflow:Saving checkpoints for 99238 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.4869063.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-99238
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 ~
# A2: 好 我 才 好
# A3: 我 很 棒
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 早 安
# A3: 网 友 ， 你 好 呀
#
# Q: 晚 上 好
# A1: 你 好 ~
# A2: 你 好 你 好 ~
# A3: 晚 上 好 ～
#
# Q: 再 见
# A1: 无 聊 的 人 说 无 聊 的 话
# A2: 嗯 ， 再 见
# A3: 拜 拜 ~
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 望 的 了
# A3: 是 啊 ， 蛮 蛮 久 的 了 ， 好 想 你 啊
#
# Q: 想 死 你 了
# A1: 谢 谢 夸 奖
# A2: 同 归 于 尽
# A3: 谢 谢 主 隆 恩
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 有 多 爱 呢
#
# Q: 你 好 厉 害 啊
# A1: 牛 逼
# A2: 那 是 必 须 的 ！
# A3: 厉 害 的
#
# Q: 你 叫 什 么
# A1: 我 叫 西 西 哦 ^ ^
# A2: 我 叫 西 西 西 哦 ^ ^
# A3: 我 叫 麻 辣 鸡 丝
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 女 生 的 年 龄 是 不 能 随 便 说 的 ， 知 道 不
#
# Q: 现 在 几 点
# A1: 十 几 分
# A2: 十 五 分
# A3: 现 在 时 刻 1 7 点 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 长 得 还 行
# A3: 天 气 好 晴 朗
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 当 然 在 咯
# A3: 管 你 在 哪 ， 没 人 关 注 你 的
#
# Q: 讲 个 笑 话
# A1: 靠 ， 又 是 她 ？
# A2: 哈 哈 哈 哈
# A3: 哈 哈 哈 哈 哈
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 第 一 个
# A3: 话 说 我 还 是 比 较 聪 明 的
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 帅 ！
# A3: 帅
#
# Q: 讨 厌 的 周 一
# A1: 讨 厌 ！
# A2: 讨 厌 ， 又 说 这 个
# A3: 对 阿
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 有 什 么 好 烦 的 ， 真 的 是
# A3: 那 就 去 找 他
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: 好 啊
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 骄 傲 哦
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 这 日 子 啊 ， 好 无 聊 哦 . . .
# A3: 你 说 的 什 么 哦 ？ 换 种 说 法 行 不
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 很 好 啊
# A3: 天 气 好 啊
#
# Q: 下 雨 了
# A1: 最 美 的 不 是 下 雨 呢
# A2: 最 美 的 不 是 倒
# A3: 最 美 的 不 是 下 雨 ～
#
# Q: 风 好 大
# A1: 哦
# A2: 受
# A3: 呜 呜 呜
#
# Q: 终 于 周 五 了
# A1: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A2: 哦
# A3: 问 世 间 情 为 何 物 ， 只 教 人 生 死 相 随
#
# Q: 我 想 去 k 歌
# A1: 不 去 了
# A2: 那 就 加 油 啦 ！ 我 会 陪 你
# A3: 你 想 什 么 呢 ？
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T08:08:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-99238
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-08:08:50
# INFO:tensorflow:Saving dict for global step 99238: global_step = 99238, loss = 1.267079
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 99238: ../model/transformer/model.ckpt-99238
# INFO:tensorflow:Perplexity: 3.550
# INFO:tensorflow:Best Perplexity: 3.550
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-99238
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 99238 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.582471, step = 99238
# INFO:tensorflow:lr = 0.00014753865
# INFO:tensorflow:global_step/sec: 5.9082
# INFO:tensorflow:loss = 2.5390766, step = 99338 (16.927 sec)
# INFO:tensorflow:lr = 0.00014739046 (16.928 sec)
# INFO:tensorflow:global_step/sec: 9.1328
# INFO:tensorflow:loss = 2.6131022, step = 99438 (10.953 sec)
# INFO:tensorflow:lr = 0.00014724239 (10.952 sec)
# INFO:tensorflow:global_step/sec: 8.95693
# INFO:tensorflow:loss = 2.5197952, step = 99538 (11.164 sec)
# INFO:tensorflow:lr = 0.00014709447 (11.164 sec)
# INFO:tensorflow:global_step/sec: 9.06301
# INFO:tensorflow:loss = 2.529381, step = 99638 (11.034 sec)
# INFO:tensorflow:lr = 0.00014694671 (11.033 sec)
# INFO:tensorflow:global_step/sec: 9.08556
# INFO:tensorflow:loss = 2.492318, step = 99738 (11.006 sec)
# INFO:tensorflow:lr = 0.00014679911 (11.006 sec)
# INFO:tensorflow:global_step/sec: 9.16476
# INFO:tensorflow:loss = 2.515195, step = 99838 (10.911 sec)
# INFO:tensorflow:lr = 0.00014665164 (10.912 sec)
# INFO:tensorflow:global_step/sec: 9.18803
# INFO:tensorflow:loss = 2.474595, step = 99938 (10.884 sec)
# INFO:tensorflow:lr = 0.00014650433 (10.882 sec)
# INFO:tensorflow:global_step/sec: 9.1288
# INFO:tensorflow:loss = 2.4682994, step = 100038 (10.952 sec)
# INFO:tensorflow:lr = 0.00014635717 (10.952 sec)
# INFO:tensorflow:global_step/sec: 9.10608
# INFO:tensorflow:loss = 2.5283172, step = 100138 (10.985 sec)
# INFO:tensorflow:lr = 0.00014621014 (10.984 sec)
# INFO:tensorflow:Saving checkpoints for 100238 into ../model/transformer/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.61787
# INFO:tensorflow:loss = 2.467325, step = 100238 (13.127 sec)
# INFO:tensorflow:lr = 0.00014606326 (13.126 sec)
# INFO:tensorflow:global_step/sec: 8.77655
# INFO:tensorflow:loss = 2.4712977, step = 100338 (11.395 sec)
# INFO:tensorflow:lr = 0.00014591654 (11.395 sec)
# INFO:tensorflow:global_step/sec: 8.94094
# INFO:tensorflow:loss = 2.5186286, step = 100438 (11.184 sec)
# INFO:tensorflow:lr = 0.00014576997 (11.185 sec)
# INFO:tensorflow:global_step/sec: 8.99152
# INFO:tensorflow:loss = 2.5287783, step = 100538 (11.120 sec)
# INFO:tensorflow:lr = 0.00014562352 (11.120 sec)
# INFO:tensorflow:global_step/sec: 9.06752
# INFO:tensorflow:loss = 2.6828563, step = 100638 (11.030 sec)
# INFO:tensorflow:lr = 0.00014547724 (11.029 sec)
# INFO:tensorflow:global_step/sec: 9.05677
# INFO:tensorflow:loss = 2.5353994, step = 100738 (11.039 sec)
# INFO:tensorflow:lr = 0.00014533111 (11.040 sec)
# INFO:tensorflow:global_step/sec: 9.0522
# INFO:tensorflow:loss = 2.5772483, step = 100838 (11.047 sec)
# INFO:tensorflow:lr = 0.00014518513 (11.046 sec)
# INFO:tensorflow:Saving checkpoints for 100920 into ../model/transformer/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5713472.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-100920
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好
# A2: 好 ~
# A3: 好 啊 ~
#
# Q: 早 上 好
# A1: 你 好 呀
# A2: 你 好 呀 ~
# A3: 你 好 呀 呀
#
# Q: 晚 上 好
# A1: 晚 上 好 ~
# A2: 你 好 你 好 ~
# A3: 你 好 ~
#
# Q: 再 见
# A1: 拜 拜
# A2: 拜 拜 ~
# A3: 拜 拜 哦
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了 ， 好 想 你 了
# A3: 是 啊 ， 蛮 正 的
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 我 也 想 你 ， 你 死 啊
# A3: 我 也 想 你 ， 好 想 你
#
# Q: 谢 谢 你
# A1: 不 用 谢 啦
# A2: 那 么 客 气 干 嘛
# A3: 那 么 客 气 嘛
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 我 也 是
#
# Q: 你 好 厉 害 啊
# A1: 还 好 啦 ， 不 算 厉 害
# A2: 还 好
# A3: 厉 害
#
# Q: 你 叫 什 么
# A1: 你 不 是 叫 网 友 吗
# A2: 你 不 认 识 的
# A3: 你 不 叫 网 友 吗
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 我 十 岁 了
# A3: 我 早 起 了
#
# Q: 现 在 几 点
# A1: 十 二 点 秒
# A2: 自 己 吃 吧
# A3: 十 几 亿 呢
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 气 很 适 合 聊 天 的 说
# A2: 长 得 还 行
# A3: 今 天 还 不 错 哇 ， 心 情 很 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 我 知 道 啊
# A2: 我 知 道
# A3: 管 你 在 哪 ， 没 人 关
#
# Q: 讲 个 笑 话
# A1: 情 人   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A2: 老 鼠   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 停 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 一 门 会 几 门
# A3: 有 多 少 要 多 少
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 帅 ！ 帅 到 爆 了 ~ ！
# A3: 不 错 的 哦 ， 你 分 析 得 很 正 确
#
# Q: 讨 厌 的 周 一
# A1: 非 常 讨 厌 ！
# A2: 黄 圆 儿
# A3: 讨 厌 ！ ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 是 吗 ？ 有 什 么 好 烦 啊
#
# Q: 天 气 真 好
# A1: 真 的 吗 ？
# A2: 你 会 吗
# A3: 真 的 ？
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴
# A3: 天 气 好 晴 晴 朗
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 我 更 好
# A3: 天 气 好 晴 天
#
# Q: 下 雨 了
# A1: 在 这 呢
# A2: 最 美 的 不 知 道
# A3: 我 不 喜 欢 这 样
#
# Q: 风 好 大
# A1: 哦
# A2: 那 必 须 的
# A3: 那 大 家 都 喜 欢 你
#
# Q: 终 于 周 五 了
# A1: 听 你 这 口 气 ， 好 像 花 了 不 少 时 间 吧
# A2: 听 你 的
# A3: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 不 去
# A3: 加 油
#
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-15T08:13:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-100920
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-15-08:13:24
# INFO:tensorflow:Saving dict for global step 100920: global_step = 100920, loss = 1.2640675
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100920: ../model/transformer/model.ckpt-100920
# INFO:tensorflow:Perplexity: 3.540
# INFO:tensorflow:Best Perplexity: 3.540
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer/model.ckpt-100920
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 100920 into ../model/transformer/model.ckpt.
# Reading ../data/train.txt
