# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_qingyun/main')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
import time

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: False

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx


def parse_fn(text):
  parse = lambda text: [[params['char2idx'].get(c, len(params['char2idx'])) for c in list(text)]]
  return {'words': parse(text)}

# %%
params = {'export_dir': '../model/lstm_seq2seq_export'}

params['char2idx'] = get_vocab('../vocab/char.txt')

params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}

subdirs = [x for x in Path(params['export_dir']).iterdir()
           if x.is_dir() and 'temp' not in str(x)]
latest = str(sorted(subdirs)[-1])

predict_fn = tf.contrib.predictor.from_saved_model(latest)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq_export/1587451865/variables/variables

# %%
while True:
  text_inp = input('Input:')
  t0 = time.time()
  predictions = predict_fn(parse_fn(text_inp))
  for j in range(3):
    indices = [params['idx2char'].get(idx, len(params['idx2char'])) for idx in predictions['output'][0, :, j] if (idx != 0 and idx != 2)]
    print('Rank_{}:'.format(j+1), ' '.join(indices))
  print('%.2f sec' % (time.time() - t0))
  print()
# Out:
# Input:你好
# Rank_1: 你 好
# Rank_2: 大 美 女
# Rank_3: 我 很 好 ， 你 呢 ， 你 怎 么 样
# 0.57 sec
#
# Input:早上好
# Rank_1: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# Rank_2: 早 安
# Rank_3: 你 好 呀
# 0.10 sec
#
# Input:晚上好
# Rank_1: 你 好 你 好 ~
# Rank_2: 你 好 你 好
# Rank_3: 你 好
# 0.09 sec
#
# Input:再见
# Rank_1: 嗯 ， 再 见
# Rank_2: 拜 拜 ~
# Rank_3: 8 8 ， 要 想 我 哦
# 0.07 sec
#
# Input:好久不见
# Rank_1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# Rank_2: 是 啊 ， 蛮 久 的 了 ， 好 想 你
# Rank_3: 是 啊 ， 蛮 久 的 了
# 0.09 sec
#
# Input:想死你了
# Rank_1: 我 也 想 你 ， 你 知 道 的 ， 我 永 远 不 会 忘 了 你
# Rank_2: 我 也 想 你 啦
# Rank_3: 我 也 是
# 0.09 sec
#
# Input:谢谢你
# Rank_1: 不 用 谢 啦
# Rank_2: 那 么 客 气 干 嘛
# Rank_3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
# 0.12 sec
#
# Input:爱你
# Rank_1: 哦
# Rank_2: 有 多 爱 呢
# Rank_3: 你 打 算 向 我 求 婚 吗
# 0.12 sec
#
# Input:你叫什么名字
# Rank_1: 我 不 叫
# Rank_2: 我 好
# Rank_3: 不 知 道
# 0.06 sec
#
# Input:你几岁了
# Rank_1: 没 年 龄
# Rank_2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# Rank_3: 你 是 不 是 觉 得 这 日 子 过 得 太 无 聊 了 哦
# 0.08 sec
#
# Input:现在几点了
# Rank_1: 现 在 时 刻 1 6 点 5 3 分
# Rank_2: 现 在 时 刻 1 7 点 5 7 分
# Rank_3: 现 在 时 刻 1 6 点 5 7 分
# 0.06 sec
#
# Input:今天天气怎么样
# Rank_1: 好 好
# Rank_2: 长 得 还 行
# Rank_3: 好 好 味
# 0.13 sec
#
# Input:我们现在在哪里
# Rank_1: 管 你 在 哪 ， 没 人 关 注 你 的
# Rank_2: 梅 州 是 我 家 ， 你 不 知 道 么
# Rank_3: 长 春
# 0.07 sec
#
# Input:你能给我讲个笑话吗
# Rank_1: 好 的 女 人   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# Rank_2: 新 的 女 人   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# Rank_3: i n t   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# 0.13 sec
#
# Input:你是男孩还是女孩呀
# Rank_1: 女 的
# Rank_2: 女 生 啦
# Rank_3: 要 检 查 下 么 ？ 走 ， 进 房 间
# 0.12 sec
#
# Input:你会几种语言呀
# Rank_1: 有 几 门 会 几 门
# Rank_2: 有 几 门 会 几 脚
# Rank_3: 有 些 事 没 必 要 认 真 ， 有 些 人 没 必 要 理 会
# 0.09 sec
#
# Input:你能陪我玩吗
# Rank_1: 陪 聊 ， 陪 睡 ， 陪 什 么 都 行
# Rank_2: 嗯 啊 ， 我 陪 你
# Rank_3: 嗯 ， 我 陪 你
# 0.07 sec
#
# Input:说话可以大声一点吗
# Rank_1: 话 说 我 还 是 比 较 聪 明 的
# Rank_2: 这 日 子 啊 ， 好 无 聊 哦 . . .
# Rank_3: 问 世 间 情 为 何 物 ， 只 教 人 生 死 相 随
# 0.13 sec
#
# Input:天气真好
# Rank_1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# Rank_2: 当 然
# Rank_3: 是 啊 ， 其 乐 无 穷
# 0.13 sec
#
# Input:天气太糟糕了
# Rank_1: 糟 了 个 糕
# Rank_2: 糟 了 么 ？
# Rank_3: 不 管 你 信 不 信 ， 反 正 我 不 想 回 答 你
# 0.08 sec
#
# Input:下雨了
# Rank_1: 啊 ， 这 鬼 天 气 太 讨 厌 了
# Rank_2: 最 讨 厌
# Rank_3: 最 讨 厌 了
# 0.10 sec
#
# Input:雨好大
# Rank_1: 大 美 女
# Rank_2: 大 美 女 ！
# Rank_3: 大 美 女 大
# 0.16 sec
#
# Input:我讨厌艳阳天
# Rank_1: 谢 谢 我 在 你 脑 海 里
# Rank_2: 才 不 讨 厌 呢 ， 你 瞎 说
# Rank_3: 谢 谢
# 0.06 sec
#
# Input:好晒啊
# Rank_1: 好 的
# Rank_2: 知 道
# Rank_3: 好 无 聊 哦 , 我 都 快 睡 着 了 ， 聊 的 什 么 呀
# 0.13 sec
#
# Input:今天好冷
# Rank_1: 天 气 好 晴 朗
# Rank_2: 有 多
# Rank_3: 天 气 好 晴 天
# 0.10 sec
#
# Input:今天好热
# Rank_1: 天 气 好 晴 朗
# Rank_2: 天 气 好 了
# Rank_3: 真 的 吗
# 0.09 sec
#
# Input:风好大
# Rank_1: 嘿 嘿
# Rank_2: 对 不 起 ， 我 没 明 白 你 的 意 思 … …
# Rank_3: 太 深 奥 了 吧 , 我 真 心 没 弄 明 白 您 的 话
# 0.09 sec
#
# Input:雾太大了看不清路
# Rank_1: 与 其 说 是 聊 天 ， 不 如 说 是 问 答 式 的 吧
# Rank_2: 今 天 是 个 好 日 子 ， 怎 么 不 出 去 玩 玩
# Rank_3: 明 知 道 你 是 错 的 人 ， 明 知 道 这 不 是 缘 分 ， 但 我 还 奋 不 顾 身
# 0.13 sec
#
# Input:打雷了好可怕
# Rank_1: 有 文 化 更 可 怕
# Rank_2: 对 不 起 ， 我 没 明 白 你 的 意 思 … …
# Rank_3: 与 其 说 是 聊 天 ， 不 如 说 是 问 答 式 的 吧
# 0.13 sec
#
# Input:下雪了诶
# Rank_1: 白 痴
# Rank_2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# Rank_3: 好 无 聊 哦 , 我 都 快 睡 着 了 ， 聊 的 什 么 呀
# 0.11 sec
#
# Input:好烦啊
# Rank_1: 是 吗 ？ 烦 什 么 啊
# Rank_2: 有 什 么 好 烦 的 ， 真 的 是
# Rank_3: 是 啊 是 啊
# 0.06 sec
#
# Input:好开心
# Rank_1: 瞧 把 你 开 心 得
# Rank_2: 嘿 嘿 ， 心 花 怒 放 了 吧
# Rank_3: 很 开 心 是 不 ， 我 都 听 到 你 在 乐 呵 呵 地 笑 了
# 0.09 sec
#
# Input:太激动了
# Rank_1: 蛋 定 ~
# Rank_2: 蛋 定
# Rank_3: 蛋 定 的
# 0.08 sec
#
# Input:我好难过
# Rank_1: 别 怕 ， 我 陪 着 你
# Rank_2: 别 怕 ， 我 会 陪 在 你 身 边 ， 永 远 爱 你 保 护 你
# Rank_3: 别 怕 ， 我 陪 陪 你
# 0.11 sec
#
# Input:我想哭
# Rank_1: 怎 么 了 嘛 ， 遇 到 不 开 心 的 事 就 说 出 来 啊
# Rank_2: 怎 么 了 嘛
# Rank_3: 你 想 什 么 呢 ？
# 0.08 sec
#
# Input:太好笑了
# Rank_1: 哈 哈 哈 哈 ~ 每 天 笑 一 笑 ， 身 体 更 健 康
# Rank_2: 哈 哈 哈 ~ 每 天 笑 一 笑 ， 身 体 更 健 康
# Rank_3: 哈 哈 哈 哈 哈 ~ 每 天 笑 一 笑 ， 身 体 更 健 康
# 0.10 sec
#
# Input:我好伤心
# Rank_1: 唉 ， 心 病 还 需 心 药 医 ， 别 人 是 没 法 帮 你 的
# Rank_2: 唉 ， 心 病 还 需 心 药 医 ， 别 人 是 没 法 帮 你
# Rank_3: 嘿 嘿 ， 心 花 怒 放 了 吧
# 0.10 sec
#
# Input:心好痛
# Rank_1: 那 就 去 看 他
# Rank_2: 那 就 去 吧
# Rank_3: 心 疼 的 感 觉
# 0.13 sec
#
# Input:好累啊
# Rank_1: 累 就 去 冲 个 热 水 澡 ， 然 后 休 息 一 下 吧
# Rank_2: 累 就 去 冲 个 热 水 澡
# Rank_3: 累 就 去 冲 个
# 0.12 sec
#
# Input:我好疲惫
# Rank_1: 区 生 ， 肥 宝
# Rank_2: 好 好 好 ~
# Rank_3: 宝 贝 ， 你 说 的 话 好 深 奥 啊 ， 有 点 像 哥 德 巴 赫 猜 想 ， 暂 时 无 解 ！
# 0.14 sec
#
# Input:我爱你
# Rank_1: 你 打 算 向 我 求 婚 吗
# Rank_2: 说 爱 我 ， 要 先 学 会 和 我 做 朋 友
# Rank_3: 画 个 圈 圈 诅 咒 你 , 一 辈 子 做 我 的 灰 太 郎
# 0.12 sec
#
# Input:我讨厌你
# Rank_1: 啊 ， 为 什 么 讨 厌 我 ， 我 又 没 做 错 什 么
# Rank_2: 谢 谢 我 在 你 脑 海 里
# Rank_3: 才 不 讨 厌 呢 ， 你 瞎 说
# 0.08 sec
#
# Input:你真是太棒啦
# Rank_1: 值 得 夸 一 下 ！
# Rank_2: 呵 呵 ~ 是 夸 我 吗 ？
# Rank_3: y e s
# 0.11 sec
#
# Input:你好厉害啊
# Rank_1: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# Rank_2: 牛 逼
# Rank_3: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# 0.09 sec
#
# Input:吓死我了
# Rank_1: 擦 了 个 我
# Rank_2: 没 你 吓 人 ！
# Rank_3: 胆 小 鬼 ， 这 样 就 给 吓 着 了
# 0.06 sec
#
# Input:我想回家
# Rank_1: 票 涨 价 了 吧 ？
# Rank_2: 票 涨 价 了 吧
# Rank_3: 你 想 什 么 呢 ？
# 0.10 sec
#
# Input:我想爸妈了
# Rank_1: 你 想 什 么 呢 ？
# Rank_2: 爸 爸
# Rank_3: 我 也 是
# 0.11 sec
#
# Input:不知道小孩在家有没有听话
# Rank_1: 真 蠢 ， 连 这 都 不 懂 = ， = | | |
# Rank_2: 听 不 懂 就 算 啦 ， 只 能 说 你 笨
# Rank_3: 真 蠢 ， 连 这 都 不 懂 = ， = | | | |
# 0.08 sec
#
# Input:想回家撸猫
# Rank_1: 嗯 ， 再 见
# Rank_2: 票 涨 价 了 吧 ？
# Rank_3: 侯 老 师
# 0.09 sec
