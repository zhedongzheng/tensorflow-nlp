# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_qingyun/main')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

import numpy as np
import pprint
import logging

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  char2idx = params['char2idx']
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      source, target = line.split('<SEP>')
      source = [char2idx.get(c, len(char2idx)) for c in list(source)]
      target = [char2idx.get(c, len(char2idx)) for c in list(target)]
      if len(source) > params['max_len']:
        source = source[:params['max_len']]
      if len(target) > params['max_len']:
        target = target[:params['max_len']]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    def cell_fn():
        cell = tf.nn.rnn_cell.LSTMCell(params['rnn_units'],
                                       initializer=tf.orthogonal_initializer())
        return cell
    if params['dec_layers'] > 1:
      cells = []
      for i in range(params['dec_layers']):
        if i == params['dec_layers'] - 1:
          cells.append(cell_fn())
        else:
          cells.append(tf.nn.rnn_cell.ResidualWrapper(cell_fn(), residual_fn=lambda i,o: tf.concat((i,o), -1)))
      return tf.nn.rnn_cell.MultiRNNCell(cells)
    else:
      return cell_fn()

  
def dec_cell(enc_out, enc_seq_len):
    attn = tf.contrib.seq2seq.BahdanauAttention(
        num_units = params['rnn_units'],
        memory = enc_out,
        memory_sequence_length = enc_seq_len)
    
    return tf.contrib.seq2seq.AttentionWrapper(
        cell = rnn_cell(),
        attention_mechanism = attn,
        attention_layer_size = params['rnn_units'])

# %%
class TiedDense(tf.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    if params['rnn_units'] != 300:
      self.proj_W = self.add_weight(name='proj_W',
                                    shape=[params['rnn_units'], params['embed_dim']],
                                    trainable=True)
      self.proj_b = self.add_weight(name='proj_b',
                                    shape=[params['embed_dim']],
                                    trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    if params['rnn_units'] != 300:
      inputs = params['activation'](tf.nn.bias_add(tf.matmul(inputs, self.proj_W), self.proj_b))
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    mask = tf.sign(words)
    
    
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        x = tf.nn.embedding_lookup(embedding, words)
        x = tf.layers.dropout(x, params['dropout_rate'], training=is_training)
    
    
    with tf.variable_scope('Encoder'):
        encoder = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
          params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
        enc_out, state_fw_h, state_fw_c, state_bw_h, state_bw_c = encoder(x, mask=mask)

        enc_state = tf.concat((tf.reduce_max(enc_out, 1), state_fw_h, state_bw_h), axis=-1)
        enc_state = tf.layers.dense(enc_state, params['rnn_units'], params['activation'], name='state_fc')
        enc_state = tf.nn.rnn_cell.LSTMStateTuple(c=enc_state, h=enc_state)
        if params['dec_layers'] > 1:
          enc_state = tuple(params['dec_layers'] * [enc_state])
    
    
    with tf.variable_scope('Decoder'):
        output_proj = TiedDense(embedding, len(params['char2idx'])+1)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = tf.layers.dropout(dec_inputs, params['dropout_rate'], training=is_training)
            cell = dec_cell(enc_out, words_len)
            
            init_state = cell.zero_state(batch_sz, tf.float32).clone(
                cell_state=enc_state)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = dec_inputs,
                sequence_length = dec_seq_len,)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = cell,
                helper = helper,
                initial_state = init_state,
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            
            return decoder_output.rnn_output
        else:
            enc_out_t = tf.contrib.seq2seq.tile_batch(enc_out, params['beam_width'])
            enc_state_t = tf.contrib.seq2seq.tile_batch(enc_state, params['beam_width'])
            enc_seq_len_t = tf.contrib.seq2seq.tile_batch(words_len, params['beam_width'])
            
            cell = dec_cell(enc_out_t, enc_seq_len_t)
            
            init_state = cell.zero_state(batch_sz*params['beam_width'], tf.float32).clone(
                cell_state=enc_state_t)
            
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
                end_token = 2,
                initial_state = init_state,
                beam_width = params['beam_width'],
                output_layer = output_proj,
                length_penalty_weight = params['length_penalty'],
                coverage_penalty_weight = params['coverage_penalty'],)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = params['max_len'],)
            
            return decoder_output.predicted_ids[:, :, :params['top_k']]

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()
        
        decay_lr = tf.train.exponential_decay(
            params['lr'], global_step, 1000, .99)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def minimal_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去k歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('minimal test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx!=0 and idx!=2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
params = {
    'model_dir': '../model/lstm_seq2seq',
    'log_path': '../log/lstm_seq2seq.txt',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'dropout_rate': .2,
    'rnn_units': 300,
    'activation': tf.nn.relu,
    'dec_layers': 1,
    'beam_width': 10,
    'top_k': 3,
    'length_penalty': .0,
    'coverage_penalty': .0,
    'label_smoothing': .2,
    'lr': 4e-4,
    'clip_norm': .1,
    'buffer_size': 120000,
    'batch_size': 64,
    'num_patience': 10,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}
print(len(params['char2idx']))

# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps
# INFO:tensorflow:lr = 0.00031129125 (11.584 sec)
# INFO:tensorflow:global_step/sec: 8.4896
# INFO:tensorflow:loss = 2.7157395, step = 25048 (11.780 sec)
# INFO:tensorflow:lr = 0.00031097856 (11.782 sec)
# INFO:tensorflow:global_step/sec: 8.43838
# INFO:tensorflow:loss = 2.814147, step = 25148 (11.848 sec)
# INFO:tensorflow:lr = 0.00031066616 (11.848 sec)
# INFO:tensorflow:Saving checkpoints for 25230 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.002672.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5959f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5959f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-25230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 我 很 好
# A2: 我 很 好 了
# A3: 我 很 好 ， 你 呢 ， 你 怎 么 样
#
# Q: 早 上 好
# A1: 早 安
# A2: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# A3: 早 点 好 ， 太 晚 了 不 好
#
# Q: 晚 上 好
# A1: 晚 安
# A2: 8 8 ， 要 想 我 哦
# A3: 嗯 ， 再 见
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了
# A3: 是 啊 ， 蛮 久 点 了
#
# Q: 想 死 你 了
# A1: 为 什 么 要 想 死
# A2: 为 什 么 ， 我 死 了 你 很 开 心 吗
# A3: 为 什 么 要 想 不 开 呢 ， 这 世 界 这 么 美 好
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 你 打 算 向 我 求 婚 吗
# A3: 我 也 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 还 好 啦 ， 不 算 厉 害
# A2: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A3: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
#
# Q: 你 叫 什 么
# A1: 网 友 ， 你 不 知 道 你 叫 啥 ？
# A2: 我 不 叫
# A3: 你 叫 你 叫 ， 我 才 不 叫
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 女 生
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 5 点 5 9 分
# A2: 现 在 时 刻 1 7 点 5 9 分
# A3: 现 在 的 生 活 太 感 性 ， 情 绪 不 停 泛 滥 ， 身 心 具 疲
#
# Q: 今 天 天 气 怎 么 样
# A1: 还 好
# A2: 长 得 还 行
# A3: 今 天 还 不 错 哇 ， 心 情 很 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 我 在 美 丽 的 客 都 ， 客 家 小 镇
# A3: 在 一 个 叫 梅 州 的 小 城 市
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 打 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 打 电 话 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几 门 。
# A3: 有 几 门 会 几 头
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 很 帅
# A3: 你 很 帅 啊
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: y e s
# A3: 讨 厌 ！ ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 有 什 么 好 烦 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; )
# A3: 当 然
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 这 日 子 啊 ， 好 无 聊 哦 . . .
# A3: 有 什 么 好 笑 的
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气
# A3: 天 气 好 晴 ~
#
# Q: 下 雨 了
# A1: 这 日 子 啊 ， 好 无 聊 哦 . . .
# A2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A3: 我 就 一 个 脑 袋 ， 思 想 再 活 跃 也 有 局 限 性
#
# Q: 风 好 大
# A1: 多 谢
# A2: 全 是 奴
# A3: 大 帅 哥
#
# Q: 终 于 周 五 了
# A1: 哦
# A2: 对 不 起 ， 我 没 明 白 你 的 意 思 … …
# A3: * * * * * *
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 就 去 吧
# A3: 那 就 加 吧
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f70ce390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f70ce390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T05:53:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-25230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-05:53:48
# INFO:tensorflow:Saving dict for global step 25230: global_step = 25230, loss = 1.3365324
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25230: ../model/lstm_seq2seq/model.ckpt-25230
# INFO:tensorflow:Perplexity: 3.806
# INFO:tensorflow:Best Perplexity: 3.806
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5d5cf98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5d5cf98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3476,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-25230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 25230 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 3.0846071, step = 25230
# INFO:tensorflow:lr = 0.00031041022
# INFO:tensorflow:global_step/sec: 7.96978
# INFO:tensorflow:loss = 2.7513235, step = 25330 (12.552 sec)
# INFO:tensorflow:lr = 0.00031009843 (12.556 sec)
# INFO:tensorflow:global_step/sec: 8.76158
# INFO:tensorflow:loss = 2.8777993, step = 25430 (11.414 sec)
# INFO:tensorflow:lr = 0.00030978693 (11.409 sec)
# INFO:tensorflow:global_step/sec: 8.72919
# INFO:tensorflow:loss = 2.7939022, step = 25530 (11.455 sec)
# INFO:tensorflow:lr = 0.00030947573 (11.455 sec)
# INFO:tensorflow:global_step/sec: 8.53265
# INFO:tensorflow:loss = 2.8608909, step = 25630 (11.718 sec)
# INFO:tensorflow:lr = 0.00030916484 (11.719 sec)
# INFO:tensorflow:global_step/sec: 8.69539
# INFO:tensorflow:loss = 2.8450625, step = 25730 (11.502 sec)
# INFO:tensorflow:lr = 0.00030885427 (11.502 sec)
# INFO:tensorflow:global_step/sec: 8.62733
# INFO:tensorflow:loss = 2.7077065, step = 25830 (11.590 sec)
# INFO:tensorflow:lr = 0.00030854403 (11.590 sec)
# INFO:tensorflow:global_step/sec: 8.65929
# INFO:tensorflow:loss = 2.9738717, step = 25930 (11.550 sec)
# INFO:tensorflow:lr = 0.0003082341 (11.549 sec)
# INFO:tensorflow:global_step/sec: 8.71614
# INFO:tensorflow:loss = 2.6630492, step = 26030 (11.473 sec)
# INFO:tensorflow:lr = 0.00030792446 (11.474 sec)
# INFO:tensorflow:global_step/sec: 8.70874
# INFO:tensorflow:loss = 2.822799, step = 26130 (11.481 sec)
# INFO:tensorflow:lr = 0.00030761515 (11.479 sec)
# INFO:tensorflow:Saving checkpoints for 26230 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.32719
# INFO:tensorflow:loss = 3.0576816, step = 26230 (12.010 sec)
# INFO:tensorflow:lr = 0.00030730615 (12.011 sec)
# INFO:tensorflow:global_step/sec: 8.3902
# INFO:tensorflow:loss = 3.039461, step = 26330 (11.918 sec)
# INFO:tensorflow:lr = 0.00030699745 (11.918 sec)
# INFO:tensorflow:global_step/sec: 8.72533
# INFO:tensorflow:loss = 2.963905, step = 26430 (11.462 sec)
# INFO:tensorflow:lr = 0.00030668906 (11.461 sec)
# INFO:tensorflow:global_step/sec: 8.62943
# INFO:tensorflow:loss = 2.9716744, step = 26530 (11.587 sec)
# INFO:tensorflow:lr = 0.00030638097 (11.588 sec)
# INFO:tensorflow:global_step/sec: 8.65316
# INFO:tensorflow:loss = 2.8096437, step = 26630 (11.558 sec)
# INFO:tensorflow:lr = 0.0003060732 (11.557 sec)
# INFO:tensorflow:global_step/sec: 8.65226
# INFO:tensorflow:loss = 2.7344823, step = 26730 (11.558 sec)
# INFO:tensorflow:lr = 0.00030576574 (11.557 sec)
# INFO:tensorflow:global_step/sec: 8.56435
# INFO:tensorflow:loss = 3.0493023, step = 26830 (11.676 sec)
# INFO:tensorflow:lr = 0.00030545858 (11.676 sec)
# INFO:tensorflow:Saving checkpoints for 26912 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.1764803.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f726ff98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f726ff98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-26912
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 好 ~
# A2: 你 啊
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 早 安
# A2: 你 好 呀
# A3: 早 上 好 啊 ， 老 板
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 8 8 ， 要 想 我 哦
# A3: 晚 安
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 好 久
# A3: 是 啊 ， 蛮 久 的 了 ， 好 想 啊
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 没 有 ， 怎 麼 了
# A3: 我 也 想 你 ！
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 我 也 是
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A3: 还 好 啦 ， 不 算 厉 害
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 网 友 ， 你 不 知 道 你 叫 啥 ？
# A3: 不 叫
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 7 点 1 9 分
# A2: 现 在 时 刻 1 1 点 1 9 分
# A3: 现 在 时 刻 1 1 点 1 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 长 得 还 行
# A3: 还 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 在 一 个 叫 梅 州 的 小 城 市
# A3: 我 在 美 丽 的 客 都 ， 客 家 小 镇
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 你 是 锄 禾 我 是 当 午
# A3: 你 要 说 给 我 听 ？
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: * * * * * *
# A3: 不 会 啊 ， 你 教 我 嘛
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 帅 到 爆
# A3: 你 很 帅 啊
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！
# A3: 讨 厌 ！
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 有 什 么 好 烦 的 ， 真 的 是
# A3: 有 什 么 好 烦 的 ， 真 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; )
# A3: 当 然
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 这 日 子 啊 ， 好 无 聊 哦 . . .
# A3: 一 点 都 不 冷 阿
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 ~
# A3: 一 点 都 不 好
#
# Q: 下 雨 了
# A1: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
# A2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A3: 我 就 一 个 脑 袋 ， 思 想 再 活 跃 也 有 局 限 性
#
# Q: 风 好 大
# A1: 多 谢
# A2: 大 帅 哥
# A3: 你 是 不 是 觉 得 这 日 子 过 得 太 无 聊 了 哦
#
# Q: 终 于 周 五 了
# A1: 哦
# A2: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
# A3: * * * * * *
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 加 油
# A3: 要 去 就 去 啊 ， 速 度
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f54a1ba8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f54a1ba8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T05:57:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-26912
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-05:57:31
# INFO:tensorflow:Saving dict for global step 26912: global_step = 26912, loss = 1.3140831
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 26912: ../model/lstm_seq2seq/model.ckpt-26912
# INFO:tensorflow:Perplexity: 3.721
# INFO:tensorflow:Best Perplexity: 3.721
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe966260cf8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe966260cf8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3476,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-26912
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 26912 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 3.0286064, step = 26912
# INFO:tensorflow:lr = 0.00030520698
# INFO:tensorflow:global_step/sec: 8.01523
# INFO:tensorflow:loss = 2.8907232, step = 27012 (12.481 sec)
# INFO:tensorflow:lr = 0.00030490037 (12.481 sec)
# INFO:tensorflow:global_step/sec: 8.53982
# INFO:tensorflow:loss = 3.0039625, step = 27112 (11.709 sec)
# INFO:tensorflow:lr = 0.00030459408 (11.711 sec)
# INFO:tensorflow:global_step/sec: 8.57303
# INFO:tensorflow:loss = 2.8618355, step = 27212 (11.665 sec)
# INFO:tensorflow:lr = 0.0003042881 (11.664 sec)
# INFO:tensorflow:global_step/sec: 8.72943
# INFO:tensorflow:loss = 2.8580682, step = 27312 (11.454 sec)
# INFO:tensorflow:lr = 0.00030398244 (11.454 sec)
# INFO:tensorflow:global_step/sec: 8.59707
# INFO:tensorflow:loss = 2.9243977, step = 27412 (11.630 sec)
# INFO:tensorflow:lr = 0.0003036771 (11.632 sec)
# INFO:tensorflow:global_step/sec: 8.5799
# INFO:tensorflow:loss = 2.9563518, step = 27512 (11.658 sec)
# INFO:tensorflow:lr = 0.00030337204 (11.655 sec)
# INFO:tensorflow:global_step/sec: 8.60345
# INFO:tensorflow:loss = 2.798316, step = 27612 (11.623 sec)
# INFO:tensorflow:lr = 0.0003030673 (11.623 sec)
# INFO:tensorflow:global_step/sec: 8.73325
# INFO:tensorflow:loss = 2.843111, step = 27712 (11.451 sec)
# INFO:tensorflow:lr = 0.00030276287 (11.452 sec)
# INFO:tensorflow:global_step/sec: 8.65564
# INFO:tensorflow:loss = 2.905971, step = 27812 (11.553 sec)
# INFO:tensorflow:lr = 0.0003024587 (11.552 sec)
# INFO:tensorflow:Saving checkpoints for 27912 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.30261
# INFO:tensorflow:loss = 2.745334, step = 27912 (12.044 sec)
# INFO:tensorflow:lr = 0.0003021549 (12.045 sec)
# INFO:tensorflow:global_step/sec: 8.43382
# INFO:tensorflow:loss = 2.7646246, step = 28012 (11.858 sec)
# INFO:tensorflow:lr = 0.0003018514 (11.858 sec)
# INFO:tensorflow:global_step/sec: 8.40677
# INFO:tensorflow:loss = 2.9493952, step = 28112 (11.893 sec)
# INFO:tensorflow:lr = 0.00030154816 (11.893 sec)
# INFO:tensorflow:global_step/sec: 8.65386
# INFO:tensorflow:loss = 2.9098482, step = 28212 (11.557 sec)
# INFO:tensorflow:lr = 0.00030124525 (11.556 sec)
# INFO:tensorflow:global_step/sec: 8.61937
# INFO:tensorflow:loss = 2.793236, step = 28312 (11.601 sec)
# INFO:tensorflow:lr = 0.00030094263 (11.602 sec)
# INFO:tensorflow:global_step/sec: 8.61827
# INFO:tensorflow:loss = 2.81295, step = 28412 (11.603 sec)
# INFO:tensorflow:lr = 0.00030064033 (11.604 sec)
# INFO:tensorflow:global_step/sec: 8.53112
# INFO:tensorflow:loss = 3.2035472, step = 28512 (11.722 sec)
# INFO:tensorflow:lr = 0.00030033835 (11.721 sec)
# INFO:tensorflow:Saving checkpoints for 28594 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.8255248.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f6015fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f6015fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-28594
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 好 ~
# A2: 我 很 好 ， 你 呢 ， 你 怎 么 样
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 早 安
# A2: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# A3: 你 好 呀
#
# Q: 晚 上 好
# A1: 晚 安
# A2: 8 8 ， 要 想 我 哦
# A3: 你 好 呀 ~
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了 ， 好 想 你
# A3: 是 啊 ， 蛮 久 的 了 ， 好 想 你 哦
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 没 有 ， 怎 麼 了
# A3: 我 也 想 你 ！
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 别 谢 我 ！ 谢 完 我 还 怎 么 好 意 思 向 你 收 聊 天 费 啊 ？
#
# Q: 爱 你
# A1: 哦
# A2: 当 时 做 的 决 定
# A3: 你 打 算 向 我 求 婚 吗
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 还 好 啦 ， 不 算 厉 害
# A3: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
#
# Q: 你 叫 什 么
# A1: 网 友 ， 你 不 知 道 你 叫 啥 ？
# A2: 我 不 叫
# A3: 你 叫 你 叫 ， 我 才 不 叫
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 1 点 5 5 分
# A2: 现 在 时 刻 1 5 点 5 5 分
# A3: 现 在 时 刻 1 7 点 1 9 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 长 得 还 行
# A3: 还 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 管 你 在 哪 ， 没 人 关 注 你 的
# A3: 我 在 美 丽 的 客 都 ， 客 家 小 镇
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 打 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 小 心   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几 门 头
# A3: 有 几 门 会 几 头
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 很 帅
# A3: 帅 到 爆
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！
# A3: 谢 谢 我 在 你 脑 海 里
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 有 什 么 好 烦 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; )
# A3: 当 然
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 有 什 么 好 笑 的
# A3: 这 日 子 啊 ， 好 无 聊 哦 . . .
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 ~
# A3: 天 气
#
# Q: 下 雨 了
# A1: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
# A2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A3: 你 一 开 口 ， 我 就 知 道 结 果 ， 你 就 不 能 搞 点 新 创 意 出 来 嘛
#
# Q: 风 好 大
# A1: 多 谢
# A2: 全 是 奴
# A3: 等 等 哈 ， 正 吃 着 切 糕 呢
#
# Q: 终 于 周 五 了
# A1: * * * * * *
# A2: 对 不 起 ， 我 没 明 白 你 的 意 思 … …
# A3: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 就 去 吧
# A3: 那 加 油
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f7033390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f7033390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T06:01:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-28594
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-06:01:15
# INFO:tensorflow:Saving dict for global step 28594: global_step = 28594, loss = 1.3125664
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 28594: ../model/lstm_seq2seq/model.ckpt-28594
# INFO:tensorflow:Perplexity: 3.716
# INFO:tensorflow:Best Perplexity: 3.716
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5b1af98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5b1af98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3476,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-28594
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 28594 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss =
b8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-30276
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 我 很 好
# A2: 好 好 好 ~
# A3: 我 很 好 ， 你 呢 ， 你 怎 么 样
#
# Q: 早 上 好
# A1: 你 好 呀 ~
# A2: 早 安
# A3: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 你 好 呀 ~
# A3: 晚 安
#
# Q: 再 见
# A1: 拜 拜 ~
# A2: 嗯 ， 再 见
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊
# A3: 是 啊 ， 蛮 久 的 了 ， 好 想 啊
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 我 也 是
# A3: 那 就 咬 他
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 有 多 爱 呢
# A3: 你 打 算 向 我 求 婚 吗
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 还 好 啦 ， 不 算 厉 害
# A3: 当 然 啦 ！
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 网 友 ， 你 不 知 道 你 叫 啥 ？
# A3: 你 叫 你 叫 ， 我 才 不 叫
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
# A3: 女 生
#
# Q: 现 在 几 点
# A1: 十 三
# A2: 现 在 时 间 是 1 2 点 1 3 分
# A3: 现 在 时 刻 1 7 点 5 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 还 好
# A3: 今 天 还 不 错 哇 ， 心 气 很 好
#
# Q: 我 们 现 在 在 哪 里
# A1: 我 在 美 丽 的 客 都 ， 客 家 小 镇
# A2: 在 这 里 了
# A3: 梅 州 是 我 家 ， 你 不 知 道 么
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 打 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 你 是 锄 禾 我 是 当 午
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几 门 吧
# A3: 有 几 门 会 几 门 。
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 帅 ！ 帅 到 爆 了 ~
# A3: 你 妈
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！
# A3: 谢 谢
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 有 什 么 好 烦 的 ， 真 的 是
# A3: 有 什 么 好 烦 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; )
# A3: 当 然
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 一 点 都 不 冷 阿
# A3: 这 日 子 啊 ， 好 无 聊 哦 . . .
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气
# A3: 一 点 都 不 好
#
# Q: 下 雨 了
# A1: 哪 有
# A2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A3: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
# INFO:tensorflow:global_step/sec: 8.77335
# INFO:tensorflow:loss = 2.8173103, step = 31676 (11.398 sec)
# INFO:tensorflow:lr = 0.00029093807 (11.400 sec)
# INFO:tensorflow:global_step/sec: 8.61845
# INFO:tensorflow:loss = 2.9105403, step = 31776 (11.603 sec)
# INFO:tensorflow:lr = 0.0002906458 (11.602 sec)
# INFO:tensorflow:global_step/sec: 8.71143
# INFO:tensorflow:loss = 2.7046645, step = 31876 (11.480 sec)
# INFO:tensorflow:lr = 0.00029035384 (11.480 sec)
# INFO:tensorflow:Saving checkpoints for 31958 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.2057157.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f60242e8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f60242e8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-31958
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 好 好 好 ~
# A2: 你 啊
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 早 上 好 啊 ， 苦 逼 的 一 天 开 始 了
# A2: 早 安
# A3: 你 好 呀
#
# Q: 晚 上 好
# A1: 晚 上 好 ～
# A2: 晚 安
# A3: 晚 上
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 嗯 啊 ， 再 见 ， 我 会 想 你 的
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了
# A3: 是 啊 ， 好 久
#
# Q: 想 死 你 了
# A1: 我 也 想 你 啦
# A2: 为 什 么 ， 我 死 了 你 很 开 心 吗
# A3: 为 什 么 要 想 啊
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 你 打 算 向 我 求 婚 吗
# A3: 我 也 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A3: 当 然 厉 害 啦
#
# Q: 你 叫 什 么
# A1: 我 不 叫
# A2: 网 友 ， 你 不 知 道 你 叫 啥 ？
# A3: 叫 什 么 叫 ， 不 叫 ！
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 女 生 的 年 龄 是 不 能 随 便 说 的 ， 知 道 不
# A3: 女 生 的 年 龄 是 可 以 随 便 问 的 吗
#
# Q: 现 在 几 点
# A1: 十 三
# A2: 现 在 时 刻 1 7 点 2 5 分
# A3: 现 在 时 刻 1 1 点 5 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 今 天 还 不 错 哇 ， 心 情 很 好
# A2: 今 天 还 不 错 哇 ， 心 气 很 好
# A3: 长 得 还 行
#
# Q: 我 们 现 在 在 哪 里
# A1: 在 这 里 了
# A2: 我 在 美 丽 的 客 都 ， 客 家 小 镇
# A3: 梅 州 是 我 家 ， 你 不 知 道 么
#
# Q: 讲 个 笑 话
# A1: 1
# A2: 打 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 动 男 人   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几 头
# A3: 有 几 门 会 几 门 呢
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 妈
# A3: 你 呀
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！
# A3: 讨 人 喜 欢 百 看 不 厌
#
# Q: 好 烦 啊
# A1: 是 吗 ？ 烦 什 么 啊
# A2: 有 什 么 好 烦 的 ， 真 的 是
# A3: 有 什 么 好 烦 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: ; )
# A3: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 一 点 都 不 冷 阿
# A3: 这 日 子 啊 ， 好 无 聊 哦 . . .
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气 好 晴 ~
# A3: 天 气
#
# Q: 下 雨 了
# A1: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
# A2: 问 天 问 地 ， 说 说 你 ， 说 说 我
# A3: 我 就 一 个 脑 袋 ， 思 想 再 活 跃 也 有 局 限 性
#
# Q: 风 好 大
# A1: 多 谢
# A2: 等 等 哈 ， 正 吃 着 切 糕 呢
# A3: 大 帅 哥
#
# Q: 终 于 周 五 了
# A1: 哦
# A2: * * * * * *
# A3: 你 不 觉 得 这 个 话 题 没 什 么 意 思 么
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 就 加 油 啦
# A3: 那 就 加 油 啦 ！ 我 还 陪 你
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f73c52b0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f73c52b0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T06:08:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-31958
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-06:08:40
# INFO:tensorflow:Saving dict for global step 31958: global_step = 31958, loss = 1.3033023
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 31958: ../model/lstm_seq2seq/model.ckpt-31958
# INFO:tensorflow:Perplexity: 3.681
# INFO:tensorflow:Best Perplexity: 3.673
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5149f60>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5149f60>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
# ...
# A2: 帅 ！ 帅 到 爆 了 ~
# A3: 帅 ！ 帅 到 爆 了
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: 讨 厌 ！ ！
# A3: 谢 谢 我 在 你 脑 海 里
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 是 你 烦
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: 是 啊
# A3: 是 啊 是 啊
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 一 点 都 不 冷 阿
# A3: 天 气
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气
# A3: 天 气 好 晴 ~
#
# Q: 下 雨 了
# A1: 最 讨 厌 了
# A2: 最 有 我
# A3: 最 美 的 不 是 下 雨 天 ， 是 曾 与 你 躲 过 雨 的 屋 檐
#
# Q: 风 好 大
# A1: 等 等 哈 ， 正 吃 着 切 糕 呢
# A2: 今 天 是 个 好 日 子 ， 怎 么 不 出 去 玩 玩
# A3: 多 谢
#
# Q: 终 于 周 五 了
# A1: 听
# A2: 哦 了 哦 了 哦 了 , 咱 聊 点 别 的 吧
# A3: 我 也 这 么 觉 得
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 加 油
# A3: 我 也 想 你 啦
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5537358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5537358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T07:04:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-57188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-07:04:36
# INFO:tensorflow:Saving dict for global step 57188: global_step = 57188, loss = 1.2681292
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 57188: ../model/lstm_seq2seq/model.ckpt-57188
# INFO:tensorflow:Perplexity: 3.554
# INFO:tensorflow:Best Perplexity: 3.540
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5ddaf98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5ddaf98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3476,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-57188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 57188 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss =
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 你 好
# A1: 我 很 好 ， 你 呢 ， 你 怎 么 样
# A2: 好 好 好 ~
# A3: 我 很 好
#
# Q: 早 上 好
# A1: 你 好 呀 ~
# A2: 你 好 呀
# A3: 你 好 呀 ？
#
# Q: 晚 上 好
# A1: 你 好 呀
# A2: 你 好 呀 ~
# A3: 晚 上 好 ～
#
# Q: 再 见
# A1: 嗯 ， 再 见
# A2: 拜 拜 ~
# A3: 8 8 ， 要 想 我 哦
#
# Q: 好 久 不 见
# A1: 是 啊 ， 蛮 久 的 了 ， 好 想 你 啊
# A2: 是 啊 ， 蛮 久 的 了 ， 好 想 你 呢
# A3: 是 啊 ， 蛮 久 的 了
#
# Q: 想 死 你 了
# A1: 我 也 想 你 ， 你 知 道 的 ， 我 永 远 不 会 忘 了 你
# A2: 没 有 ， 怎 麼 了
# A3: 我 也 是
#
# Q: 谢 谢 你
# A1: 那 么 客 气 干 嘛
# A2: 不 用 谢 啦
# A3: 人 又 不 斯 文 ， 装 得 这 么 客 气 干 嘛 呢
#
# Q: 爱 你
# A1: 哦
# A2: 我 也 爱 你
# A3: 爱 我 优 惠 ， 包 年 免 费 ！
#
# Q: 你 好 厉 害 啊
# A1: 这 样 算 什 么 厉 害 ~ ， 太 没 见 过 世 面 啦 你
# A2: 厉 害 的 还 没 使 出 来 ， 好 戏 在 后 头
# A3: 当 然 啦
#
# Q: 你 叫 什 么
# A1: 屎
# A2: 我 不 叫
# A3: 我 叫 朱 梦 杰
#
# Q: 你 几 岁 了
# A1: 没 年 龄
# A2: 讨 厌 ， 不 要 随 便 问 女 生 年 龄 知 道 不
# A3: 女 生 的 年 龄 是 不 能 随 便 说 的 ， 知 道 不
#
# Q: 现 在 几 点
# A1: 现 在 时 刻 1 5 点 5 5 分
# A2: 现 在 时 刻 1 5 点 5 7 分
# A3: 现 在 时 刻 1 5 点 2 5 分
#
# Q: 今 天 天 气 怎 么 样
# A1: 长 得 还 行
# A2: 今 天 还 不 错 哇 ， 心 情 很 好
# A3: 还 好 吧 ！ 可 他 们 老 骂 我 ！
#
# Q: 我 们 现 在 在 哪 里
# A1: 管 你 在 哪 ， 没 人 关 注 你 的
# A2: 梅 州 是 我 家 ， 你 不 知 道 么
# A3: 我 在 美 丽 的 客 都 ， 客 家 小 镇
#
# Q: 讲 个 笑 话
# A1: 打 电 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A2: 听 话   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
# A3: 听 话 的   提 示 ： 按 分 类 看 笑 话 请 发 送 “ 笑 话 分 类 ”
#
# Q: 你 会 几 种 语 言 呀
# A1: 有 几 门 会 几 门
# A2: 有 几 门 会 几 门 。
# A3: 有 几 门 吧
#
# Q: 你 觉 得 我 帅 吗
# A1: 帅 ！ 帅 到 爆 了 ~ ！
# A2: 你 妈 生 你 的 时 候 一 定 是 满 怀 焦 虑 ， 心 不 在 焉 的 ， 如 此 潦 草 . . .
# A3: 帅 ！ 帅 到 爆 了 ~
#
# Q: 讨 厌 的 周 一
# A1: y e s !
# A2: b 啊
# A3: 讨 厌 ！
#
# Q: 好 烦 啊
# A1: 有 什 么 好 烦 的 ， 真 的 是
# A2: 是 吗 ？ 烦 什 么 啊
# A3: 有 什 么 好 烦 的 ， 真 的
#
# Q: 天 气 真 好
# A1: ; ) 谦 虚 是 立 足 之 本 ， 再 好 也 要 谦 虚 ， 不 能 骄 傲 哦
# A2: 当 然
# A3: 当 然 好 啊
#
# Q: 今 天 好 冷
# A1: 天 气 好 晴 朗
# A2: 一 点 都 不 冷 阿
# A3: 无 聊 的 人 说 无 聊 的 话
#
# Q: 今 天 好 热
# A1: 天 气 好 晴 朗
# A2: 天 气
# A3: 天 气 好 晴 休
#
# Q: 下 雨 了
# A1: 最 讨 厌 了
# A2: 最 美 的 不 是 下 雨 天 ， 是 曾 与 你 躲 过 雨 的 屋 檐
# A3: 最 美 的 不 是
#
# Q: 风 好 大
# A1: 多 谢
# A2: 等 等 哈 ， 正 吃 着 切 糕 呢
# A3: 大 帅 哥 也
#
# Q: 终 于 周 五 了
# A1: 听
# A2: 我
# A3: 听 你 妹
#
# Q: 我 想 去 k 歌
# A1: 那 就 加 油 啦 ！ 我 会 陪 你
# A2: 那 加 油
# A3: 那 就 加 油 啦 ！
#
# ------------
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5a96358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe8f5a96358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T07:08:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-58870
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-27-07:08:19
# INFO:tensorflow:Saving dict for global step 58870: global_step = 58870, loss = 1.2732397
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 58870: ../model/lstm_seq2seq/model.ckpt-58870
# INFO:tensorflow:Perplexity: 3.572
# INFO:tensorflow:Best Perplexity: 3.540
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe9663dd588>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7fe9663dd588>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3476, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/forward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/recurrent_kernel:0' shape=(300, 1200) dtype=float32>,
#  <tf.Variable 'Encoder/bidirectional/backward_lstm/bias:0' shape=(1200,) dtype=float32>,
#  <tf.Variable 'Encoder/state_fc/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/state_fc/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3476,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/lstm_seq2seq/model.ckpt-58870
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 58870 into ../model/lstm_seq2seq/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 2.6369092, step = 58870
# INFO:tensorflow:lr = 0.00022136254
# INFO:tensorflow:global_step/sec: 7.93415
# INFO:tensorflow:loss = 2.608085, step = 58970 (12.608 sec)
# INFO:tensorflow:lr = 0.00022114016 (12.607 sec)
# INFO:tensorflow:global_step/sec: 8.69861
# INFO:tensorflow:loss = 2.6535451, step = 59070 (11.495 sec)
# INFO:tensorflow:lr = 0.00022091801 (11.497 sec)
# INFO:tensorflow:global_step/sec: 8.54853
# INFO:tensorflow:loss = 2.678941, step = 59170 (11.699 sec)
# INFO:tensorflow:lr = 0.0002206961 (11.698 sec)
# INFO:tensorflow:global_step/sec: 8.6785
# INFO:tensorflow:loss = 2.6543508, step = 59270 (11.522 sec)
# INFO:tensorflow:lr = 0.00022047441 (11.522 sec)
# INFO:tensorflow:global_step/sec: 8.66844
# INFO:tensorflow:loss = 2.6246312, step = 59370 (11.536 sec)
# INFO:tensorflow:lr = 0.00022025294 (11.537 sec)
# INFO:tensorflow:global_step/sec: 8.46793
# INFO:tensorflow:loss = 2.720649, step = 59470 (11.809 sec)
# INFO:tensorflow:lr = 0.00022003168 (11.809 sec)
# INFO:tensorflow:global_step/sec: 8.47124
# INFO:tensorflow:loss = 2.538383, step = 59570 (11.804 sec)
# INFO:tensorflow:lr = 0.00021981065 (11.802 sec)
# INFO:tensorflow:global_step/sec: 8.66377
# INFO:tensorflow:loss = 2.6352785, step = 59670 (11.544 sec)
# INFO:tensorflow:lr = 0.00021958984 (11.544 sec)
# INFO:tensorflow:global_step/sec: 8.55646
# INFO:tensorflow:loss = 2.6536202, step = 59770 (11.687 sec)
# INFO:tensorflow:lr = 0.00021936926 (11.687 sec)
# INFO:tensorflow:Saving checkpoints for 59870 into ../model/lstm_seq2seq/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.23833
# INFO:tensorflow:loss = 2.67561, step = 59870 (12.136 sec)
# INFO:tensorflow:lr = 0.00021914892 (12.137 sec)
