# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/recommender/movielens/main')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
import pprint
import logging

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def gen_fn(f_path):
  movietype2idx = {}
  with open('../vocab/movie_types.txt') as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      movietype2idx[line] = i
  
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      (user_id, user_gender, user_age, user_job, movie_id, movie_types, movie_title, score) = line.split('\t')
      
      movie_types_ = [0] * len(movietype2idx)
      for movie_type in movie_types.split():
        movie_types_[movietype2idx[movie_type]] = 1
        
      movie_title = movie_title.split()
      yield (user_id, user_age, user_job, user_gender, movie_id, movie_types_, movie_title), score


def dataset(is_training, params):
  _shapes = (([], [], [], [], [], [18], [None]), [])
  _types = ((tf.string, tf.string, tf.string, tf.string, tf.string, tf.int32, tf.string), tf.float32)
  _pads = (('-1', '-1', '-1', '-1', '-1', -1, '<pad>'), 0.)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['train_path']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['test_path']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clr(step,
        initial_learning_rate,
        maximal_learning_rate,
        step_size,
        scale_fn,
        scale_mode,):
  step = tf.cast(step, tf.float32)
  
  initial_learning_rate = tf.convert_to_tensor(
    initial_learning_rate, name='initial_learning_rate')
  dtype = initial_learning_rate.dtype
  maximal_learning_rate = tf.cast(maximal_learning_rate, dtype)
  step_size = tf.cast(step_size, dtype)
  cycle = tf.floor(1 + step / (2 * step_size))
  x = tf.abs(step / step_size - 2 * cycle + 1)

  mode_step = cycle if scale_mode == 'cycle' else step

  return initial_learning_rate + (
    maximal_learning_rate - initial_learning_rate) * tf.maximum(
      tf.cast(0, dtype), (1 - x)) * scale_fn(mode_step)

# %%
def model_fn(features, labels, mode, params):
  # Receive inputs
  user_id, user_age, user_job, user_gender, movie_id, movie_types, movie_title = features
  
  
  # Flag for Dropout / Batch Norm
  is_training = (mode == tf.estimator.ModeKeys.TRAIN)
  
  
  # Word Indexing
  lookup_user_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_id.txt', num_oov_buckets=1)
  
  lookup_user_age = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_age.txt', num_oov_buckets=1)
  
  lookup_user_job = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_job.txt', num_oov_buckets=1)
  
  lookup_user_gender = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_gender.txt', num_oov_buckets=1)
  
  lookup_movie_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_id.txt', num_oov_buckets=1)
  
  lookup_movie_title = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_title.txt', num_oov_buckets=1)
  
  user_id = lookup_user_id.lookup(user_id)
  
  user_age = lookup_user_age.lookup(user_age)
  
  user_job = lookup_user_job.lookup(user_job)
  
  user_gender = lookup_user_gender.lookup(user_gender)
  
  movie_id = lookup_movie_id.lookup(movie_id)
  
  movie_title = lookup_movie_title.lookup(movie_title)
  
  
  # Embedding
  user_id = tf.contrib.layers.embed_sequence(
    ids = user_id,
    vocab_size = params['user_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='user_id')
  
  user_age = tf.contrib.layers.embed_sequence(
    ids = user_age,
    vocab_size = params['user_age_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_age')
  
  user_job = tf.contrib.layers.embed_sequence(
    ids = user_job,
    vocab_size = params['user_job_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_job')
  
  user_gender = tf.contrib.layers.embed_sequence(
    ids = user_gender,
    vocab_size = params['user_gender_size'],
    embed_dim = params['small_embed_dim'],
    scope='user_gender')
  
  movie_id = tf.contrib.layers.embed_sequence(
    ids = movie_id,
    vocab_size = params['movie_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_id')
  
  movie_types = tf.to_float(movie_types)
  
  movie_title = tf.contrib.layers.embed_sequence(
    ids = movie_title,
    vocab_size = params['movie_title_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_title')
  
  
  # User Network
  user_feature = tf.concat((user_id, user_age, user_job, user_gender), -1)
  
  user_feature = tf.layers.dropout(user_feature, params['dropout_rate'], training=is_training)
  
  user_feature = tf.layers.dense(user_feature,
                                 params['hidden_dim'],
                                 params['activation'],
                                 name='user_feature/fc')
  
  
  # Movie Network
  movie_title = tf.layers.dropout(movie_title, params['dropout_rate'], training=is_training)
  
  movie_title = tf.reduce_max(tf.layers.conv1d(movie_title,
                                               filters=params['large_embed_dim'],
                                               kernel_size=params['kernel_size'],
                                               activation=params['activation'],
                                               name='movie_feature/conv1d'), axis=1)
  
  movie_feature = tf.concat((movie_id, movie_types, movie_title), -1)
  
  movie_feature = tf.layers.dropout(movie_feature, params['dropout_rate'], training=is_training)
  
  movie_feature = tf.layers.dense(movie_feature,
                                  params['hidden_dim'],
                                  params['activation'],
                                  name='movie_feature/fc')
  
  
  # Aggregation
  scores = tf.concat([tf.abs(user_feature - movie_feature),
                      user_feature * movie_feature,
                      user_feature,
                      movie_feature], -1)
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  scores = tf.layers.dense(scores, 1)
  scores = tf.squeeze(scores, -1)
  predictions = 5. * tf.sigmoid(scores)
  
  
  if labels is not None:
    loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
      labels=labels/5., logits=scores))
  
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    tf.logging.info('\n'+pprint.pformat(tf.trainable_variables()))
    
    global_step=tf.train.get_or_create_global_step()
    decay_lr = clr(
      step = global_step,
      initial_learning_rate = 1e-4,
      maximal_learning_rate = 8e-4,
      step_size = 2 * 900228 // params['batch_size'],
      scale_fn = lambda x: 1 / (2.0 ** (x - 1)),
      scale_mode = 'cycle',)
    
    optim = tf.train.AdamOptimizer(decay_lr)
    train_op = optim.minimize(
      loss_op, global_step=tf.train.get_or_create_global_step())
    
    hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
    
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      train_op=train_op,
                                      training_hooks=[hook],)
  
  
  if mode == tf.estimator.ModeKeys.EVAL:
    mae_op = tf.metrics.mean_absolute_error(labels=labels,
                                            predictions=predictions)
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      eval_metric_ops={'mae': mae_op})

# %%
params = {
    'log_path': '../log/dnn_sigmoid_clr.txt',
    'model_dir': '../model/dnn_sigmoid_clr',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'user_id_size': 6040,
    'user_age_size': 7,
    'user_job_size': 21,
    'user_gender_size': 2,
    'movie_id_size': 3691,
    'movie_title_size': 3702,
    'small_embed_dim': 30,
    'large_embed_dim': 200,
    'hidden_dim': 200,
    'activation': tf.nn.elu,
    'kernel_size': 3,
    'dropout_rate': 0.2,
    'num_patience': 7,
    'buffer_size': 200000,
    'batch_size': 256,
}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
config = tf.estimator.RunConfig(
  save_checkpoints_steps=900228//params['batch_size']+1,
  keep_checkpoint_max=3)

estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=config,
  params=params)

best_mae = 10000.
count = 0
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  mae = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['mae']
  logger.info("MAE: {:.3f}".format(mae))

  if mae < best_mae:
    best_mae = mae
    count = 0
  else:
    count += 1
  logger.info("Best MAE: {:.3f}".format(best_mae))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../model/dnn_sigmoid_clr', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 3517, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fca17070710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-6-e03747f81c5b>:73: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From <ipython-input-6-e03747f81c5b>:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:271: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-6-e03747f81c5b>:90: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From <ipython-input-6-e03747f81c5b>:100: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.7185493, step = 0
# INFO:tensorflow:lr = 1e-04
# INFO:tensorflow:global_step/sec: 16.1537
# INFO:tensorflow:loss = 0.5954652, step = 100 (6.193 sec)
# INFO:tensorflow:lr = 0.00010995308 (6.194 sec)
# INFO:tensorflow:global_step/sec: 17.0679
# INFO:tensorflow:loss = 0.6092737, step = 200 (5.861 sec)
# INFO:tensorflow:lr = 0.00011990616 (5.861 sec)
# INFO:tensorflow:global_step/sec: 16.4585
# INFO:tensorflow:loss = 0.59625065, step = 300 (6.074 sec)
# INFO:tensorflow:lr = 0.00012985924 (6.072 sec)
# INFO:tensorflow:global_step/sec: 16.497
# INFO:tensorflow:loss = 0.57075155, step = 400 (6.064 sec)
# INFO:tensorflow:lr = 0.00013981233 (6.066 sec)
# INFO:tensorflow:global_step/sec: 17.0236
# INFO:tensorflow:loss = 0.5762479, step = 500 (5.874 sec)
# INFO:tensorflow:lr = 0.0001497654 (5.875 sec)
# INFO:tensorflow:global_step/sec: 17.2449
# INFO:tensorflow:loss = 0.5727715, step = 600 (5.799 sec)
# INFO:tensorflow:lr = 0.00015971849 (5.799 sec)
# INFO:tensorflow:global_step/sec: 16.7759
# INFO:tensorflow:loss = 0.5661325, step = 700 (5.962 sec)
# INFO:tensorflow:lr = 0.00016967156 (5.960 sec)
# INFO:tensorflow:global_step/sec: 16.7669
# INFO:tensorflow:loss = 0.54761225, step = 800 (5.964 sec)
# INFO:tensorflow:lr = 0.0001796246 (5.964 sec)
# INFO:tensorflow:global_step/sec: 16.4673
# INFO:tensorflow:loss = 0.5418254, step = 900 (6.069 sec)
# INFO:tensorflow:lr = 0.0001895777 (6.069 sec)
# INFO:tensorflow:global_step/sec: 16.5765
# INFO:tensorflow:loss = 0.55792505, step = 1000 (6.036 sec)
# INFO:tensorflow:lr = 0.00019953077 (6.039 sec)
# INFO:tensorflow:global_step/sec: 16.5489
# INFO:tensorflow:loss = 0.5592674, step = 1100 (6.043 sec)
# INFO:tensorflow:lr = 0.00020948384 (6.040 sec)
# INFO:tensorflow:global_step/sec: 16.1808
# INFO:tensorflow:loss = 0.573969, step = 1200 (6.179 sec)
# INFO:tensorflow:lr = 0.00021943693 (6.180 sec)
# INFO:tensorflow:global_step/sec: 16.8493
# INFO:tensorflow:loss = 0.55412674, step = 1300 (5.937 sec)
# INFO:tensorflow:lr = 0.00022939002 (5.935 sec)
# INFO:tensorflow:global_step/sec: 17.1943
# INFO:tensorflow:loss = 0.5668464, step = 1400 (5.816 sec)
# INFO:tensorflow:lr = 0.00023934309 (5.816 sec)
# INFO:tensorflow:global_step/sec: 16.6145
# INFO:tensorflow:loss = 0.5705122, step = 1500 (6.017 sec)
# INFO:tensorflow:lr = 0.00024929616 (6.017 sec)
# INFO:tensorflow:global_step/sec: 16.9169
# INFO:tensorflow:loss = 0.53846186, step = 1600 (5.913 sec)
# INFO:tensorflow:lr = 0.00025924927 (5.912 sec)
# INFO:tensorflow:global_step/sec: 16.8608
# INFO:tensorflow:loss = 0.5607855, step = 1700 (5.930 sec)
# INFO:tensorflow:lr = 0.00026920234 (5.932 sec)
# INFO:tensorflow:global_step/sec: 16.9448
# INFO:tensorflow:loss = 0.5659287, step = 1800 (5.900 sec)
# INFO:tensorflow:lr = 0.00027915539 (5.899 sec)
# INFO:tensorflow:global_step/sec: 17.1739
# INFO:tensorflow:loss = 0.5349198, step = 1900 (5.826 sec)
# INFO:tensorflow:lr = 0.00028910846 (5.828 sec)
# INFO:tensorflow:global_step/sec: 16.6684
# INFO:tensorflow:loss = 0.5648556, step = 2000 (5.998 sec)
# INFO:tensorflow:lr = 0.00029906153 (5.995 sec)
# INFO:tensorflow:global_step/sec: 16.675
# INFO:tensorflow:loss = 0.5830975, step = 2100 (5.998 sec)
# INFO:tensorflow:lr = 0.00030901463 (5.999 sec)
# INFO:tensorflow:global_step/sec: 16.7805
# INFO:tensorflow:loss = 0.5648977, step = 2200 (5.959 sec)
# INFO:tensorflow:lr = 0.0003189677 (5.960 sec)
# INFO:tensorflow:global_step/sec: 16.5345
# INFO:tensorflow:loss = 0.5847953, step = 2300 (6.048 sec)
# INFO:tensorflow:lr = 0.00032892078 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.6926
# INFO:tensorflow:loss = 0.5443028, step = 2400 (5.991 sec)
# INFO:tensorflow:lr = 0.00033887386 (5.992 sec)
# INFO:tensorflow:global_step/sec: 16.6372
# INFO:tensorflow:loss = 0.5623102, step = 2500 (6.011 sec)
# INFO:tensorflow:lr = 0.00034882696 (6.009 sec)
# INFO:tensorflow:global_step/sec: 16.5782
# INFO:tensorflow:loss = 0.56683624, step = 2600 (6.034 sec)
# INFO:tensorflow:lr = 0.00035878003 (6.034 sec)
# INFO:tensorflow:global_step/sec: 16.804
# INFO:tensorflow:loss = 0.5496422, step = 2700 (5.948 sec)
# INFO:tensorflow:lr = 0.0003687331 (5.949 sec)
# INFO:tensorflow:global_step/sec: 38.417
# INFO:tensorflow:loss = 0.5407954, step = 2800 (2.602 sec)
# INFO:tensorflow:lr = 0.0003786862 (2.601 sec)
# INFO:tensorflow:global_step/sec: 120.029
# INFO:tensorflow:loss = 0.5490092, step = 2900 (0.834 sec)
# INFO:tensorflow:lr = 0.00038863928 (0.834 sec)
# INFO:tensorflow:global_step/sec: 111.485
# INFO:tensorflow:loss = 0.56056964, step = 3000 (0.897 sec)
# INFO:tensorflow:lr = 0.00039859235 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.277
# INFO:tensorflow:loss = 0.55620015, step = 3100 (0.898 sec)
# INFO:tensorflow:lr = 0.00040854543 (0.897 sec)
# INFO:tensorflow:global_step/sec: 119.07
# INFO:tensorflow:loss = 0.5521501, step = 3200 (0.842 sec)
# INFO:tensorflow:lr = 0.00041849853 (0.843 sec)
# INFO:tensorflow:global_step/sec: 120.864
# INFO:tensorflow:loss = 0.5681906, step = 3300 (0.825 sec)
# INFO:tensorflow:lr = 0.0004284516 (0.825 sec)
# INFO:tensorflow:global_step/sec: 122.413
# INFO:tensorflow:loss = 0.54102266, step = 3400 (0.815 sec)
# INFO:tensorflow:lr = 0.00043840468 (0.814 sec)
# INFO:tensorflow:global_step/sec: 118.78
# INFO:tensorflow:loss = 0.5551108, step = 3500 (0.842 sec)
# INFO:tensorflow:lr = 0.00044835778 (0.842 sec)
# INFO:tensorflow:Saving checkpoints for 3517 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5389204.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T01:15:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-3517
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-01:15:53
# INFO:tensorflow:Saving dict for global step 3517: global_step = 3517, loss = 0.5547, mae = 0.7247329
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3517: ../model/dnn_sigmoid_clr/model.ckpt-3517
# INFO:tensorflow:MAE: 0.725
# INFO:tensorflow:Best MAE: 0.725
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-3517
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3517 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.5294446, step = 3517
# INFO:tensorflow:lr = 0.00045004976
# INFO:tensorflow:global_step/sec: 15.1658
# INFO:tensorflow:loss = 0.5445924, step = 3617 (6.599 sec)
# INFO:tensorflow:lr = 0.00046000286 (6.597 sec)
# INFO:tensorflow:global_step/sec: 16.3731
# INFO:tensorflow:loss = 0.5386847, step = 3717 (6.108 sec)
# INFO:tensorflow:lr = 0.00046995594 (6.108 sec)
# INFO:tensorflow:global_step/sec: 16.9299
# INFO:tensorflow:loss = 0.5708776, step = 3817 (5.906 sec)
# INFO:tensorflow:lr = 0.000479909 (5.909 sec)
# INFO:tensorflow:global_step/sec: 16.5422
# INFO:tensorflow:loss = 0.5614549, step = 3917 (6.041 sec)
# INFO:tensorflow:lr = 0.00048986205 (6.044 sec)
# INFO:tensorflow:global_step/sec: 16.5691
# INFO:tensorflow:loss = 0.543277, step = 4017 (6.038 sec)
# INFO:tensorflow:lr = 0.00049981516 (6.033 sec)
# INFO:tensorflow:global_step/sec: 16.9333
# INFO:tensorflow:loss = 0.56554353, step = 4117 (5.908 sec)
# INFO:tensorflow:lr = 0.0005097682 (5.908 sec)
# INFO:tensorflow:global_step/sec: 15.1459
# INFO:tensorflow:loss = 0.5595219, step = 4217 (6.597 sec)
# INFO:tensorflow:lr = 0.0005197213 (6.597 sec)
# INFO:tensorflow:global_step/sec: 15.9373
# INFO:tensorflow:loss = 0.5417254, step = 4317 (6.278 sec)
# INFO:tensorflow:lr = 0.00052967435 (6.278 sec)
# INFO:tensorflow:global_step/sec: 16.4706
# INFO:tensorflow:loss = 0.54439634, step = 4417 (6.069 sec)
# INFO:tensorflow:lr = 0.00053962745 (6.069 sec)
# INFO:tensorflow:global_step/sec: 16.9678
# INFO:tensorflow:loss = 0.5618342, step = 4517 (5.896 sec)
# INFO:tensorflow:lr = 0.00054958055 (5.894 sec)
# INFO:tensorflow:global_step/sec: 16.9118
# INFO:tensorflow:loss = 0.56902593, step = 4617 (5.912 sec)
# INFO:tensorflow:lr = 0.0005595336 (5.914 sec)
# INFO:tensorflow:global_step/sec: 16.3794
# INFO:tensorflow:loss = 0.5697473, step = 4717 (6.107 sec)
# INFO:tensorflow:lr = 0.0005694867 (6.106 sec)
# INFO:tensorflow:global_step/sec: 16.4836
# INFO:tensorflow:loss = 0.54283255, step = 4817 (6.068 sec)
# INFO:tensorflow:lr = 0.00057943974 (6.070 sec)
# INFO:tensorflow:global_step/sec: 16.6683
# INFO:tensorflow:loss = 0.5535169, step = 4917 (5.997 sec)
# INFO:tensorflow:lr = 0.00058939285 (5.995 sec)
# INFO:tensorflow:global_step/sec: 16.3159
# INFO:tensorflow:loss = 0.5786092, step = 5017 (6.130 sec)
# INFO:tensorflow:lr = 0.00059934595 (6.132 sec)
# INFO:tensorflow:global_step/sec: 16.5141
# INFO:tensorflow:loss = 0.5452154, step = 5117 (6.052 sec)
# INFO:tensorflow:lr = 0.00060929905 (6.051 sec)
# INFO:tensorflow:global_step/sec: 16.7782
# INFO:tensorflow:loss = 0.55772305, step = 5217 (5.960 sec)
# INFO:tensorflow:lr = 0.0006192521 (5.965 sec)
# INFO:tensorflow:global_step/sec: 16.8957
# INFO:tensorflow:loss = 0.5529925, step = 5317 (5.921 sec)
# INFO:tensorflow:lr = 0.0006292052 (5.915 sec)
# INFO:tensorflow:global_step/sec: 16.9379
# INFO:tensorflow:loss = 0.5685157, step = 5417 (5.902 sec)
# INFO:tensorflow:lr = 0.00063915824 (5.905 sec)
# INFO:tensorflow:global_step/sec: 16.5983
# INFO:tensorflow:loss = 0.545894, step = 5517 (6.028 sec)
# INFO:tensorflow:lr = 0.0006491113 (6.027 sec)
# INFO:tensorflow:global_step/sec: 16.9
# INFO:tensorflow:loss = 0.54382944, step = 5617 (5.914 sec)
# INFO:tensorflow:lr = 0.0006590644 (5.914 sec)
# INFO:tensorflow:global_step/sec: 16.9332
# INFO:tensorflow:loss = 0.5511628, step = 5717 (5.910 sec)
# INFO:tensorflow:lr = 0.0006690175 (5.909 sec)
# INFO:tensorflow:global_step/sec: 16.2543
# INFO:tensorflow:loss = 0.54613185, step = 5817 (6.150 sec)
# INFO:tensorflow:lr = 0.00067897054 (6.153 sec)
# INFO:tensorflow:global_step/sec: 16.8871
# INFO:tensorflow:loss = 0.56567526, step = 5917 (5.932 sec)
# INFO:tensorflow:lr = 0.00068892364 (5.929 sec)
# INFO:tensorflow:global_step/sec: 16.4132
# INFO:tensorflow:loss = 0.56421983, step = 6017 (6.083 sec)
# INFO:tensorflow:lr = 0.00069887674 (6.085 sec)
# INFO:tensorflow:global_step/sec: 16.3694
# INFO:tensorflow:loss = 0.5579443, step = 6117 (6.110 sec)
# INFO:tensorflow:lr = 0.0007088298 (6.109 sec)
# INFO:tensorflow:global_step/sec: 16.3163
# INFO:tensorflow:loss = 0.551836, step = 6217 (6.135 sec)
# INFO:tensorflow:lr = 0.0007187829 (6.138 sec)
# INFO:tensorflow:global_step/sec: 34.6617
# INFO:tensorflow:loss = 0.55731964, step = 6317 (2.874 sec)
# INFO:tensorflow:lr = 0.00072873593 (2.870 sec)
# INFO:tensorflow:global_step/sec: 118.456
# INFO:tensorflow:loss = 0.54016286, step = 6417 (0.846 sec)
# INFO:tensorflow:lr = 0.00073868904 (0.846 sec)
# INFO:tensorflow:global_step/sec: 121.372
# INFO:tensorflow:loss = 0.539403, step = 6517 (0.824 sec)
# INFO:tensorflow:lr = 0.00074864214 (0.824 sec)
# INFO:tensorflow:global_step/sec: 116.143
# INFO:tensorflow:loss = 0.5668109, step = 6617 (0.861 sec)
# INFO:tensorflow:lr = 0.0007585952 (0.862 sec)
# INFO:tensorflow:global_step/sec: 119.057
# INFO:tensorflow:loss = 0.5601365, step = 6717 (0.840 sec)
# INFO:tensorflow:lr = 0.0007685483 (0.839 sec)
# INFO:tensorflow:global_step/sec: 122.479
# INFO:tensorflow:loss = 0.5444168, step = 6817 (0.817 sec)
# INFO:tensorflow:lr = 0.0007785014 (0.817 sec)
# INFO:tensorflow:global_step/sec: 121.277
# INFO:tensorflow:loss = 0.561746, step = 6917 (0.825 sec)
# INFO:tensorflow:lr = 0.00078845443 (0.826 sec)
# INFO:tensorflow:global_step/sec: 118.49
# INFO:tensorflow:loss = 0.559061, step = 7017 (0.843 sec)
# INFO:tensorflow:lr = 0.0007984075 (0.843 sec)
# INFO:tensorflow:Saving checkpoints for 7034 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.53574276.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T01:19:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-7034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-01:19:53
# INFO:tensorflow:Saving dict for global step 7034: global_step = 7034, loss = 0.54815924, mae = 0.6955126
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7034: ../model/dnn_sigmoid_clr/model.ckpt-7034
# INFO:tensorflow:MAE: 0.696
# INFO:tensorflow:Best MAE: 0.696
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-7034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7034 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.53673035, step = 7034
# INFO:tensorflow:lr = 0.00079990044
# INFO:tensorflow:global_step/sec: 16.1756
# INFO:tensorflow:loss = 0.5410929, step = 7134 (6.187 sec)
# INFO:tensorflow:lr = 0.00078994734 (6.181 sec)
# INFO:tensorflow:global_step/sec: 16.7482
# INFO:tensorflow:loss = 0.560086, step = 7234 (5.968 sec)
# INFO:tensorflow:lr = 0.00077999424 (5.967 sec)
# INFO:tensorflow:global_step/sec: 16.6756
# INFO:tensorflow:loss = 0.5656381, step = 7334 (5.999 sec)
# INFO:tensorflow:lr = 0.0007700412 (5.999 sec)
# INFO:tensorflow:global_step/sec: 16.0072
# INFO:tensorflow:loss = 0.5383322, step = 7434 (6.251 sec)
# INFO:tensorflow:lr = 0.0007600881 (6.252 sec)
# INFO:tensorflow:global_step/sec: 16.4232
# INFO:tensorflow:loss = 0.5244777, step = 7534 (6.086 sec)
# INFO:tensorflow:lr = 0.00075013505 (6.085 sec)
# INFO:tensorflow:global_step/sec: 16.6263
# INFO:tensorflow:loss = 0.5657899, step = 7634 (6.015 sec)
# INFO:tensorflow:lr = 0.00074018195 (6.024 sec)
# INFO:tensorflow:global_step/sec: 15.7207
# INFO:tensorflow:loss = 0.56825465, step = 7734 (6.361 sec)
# INFO:tensorflow:lr = 0.00073022884 (6.354 sec)
# INFO:tensorflow:global_step/sec: 16.3254
# INFO:tensorflow:loss = 0.55367553, step = 7834 (6.128 sec)
# INFO:tensorflow:lr = 0.0007202758 (6.126 sec)
# INFO:tensorflow:global_step/sec: 16.5273
# INFO:tensorflow:loss = 0.5499411, step = 7934 (6.048 sec)
# INFO:tensorflow:lr = 0.0007103227 (6.049 sec)
# INFO:tensorflow:global_step/sec: 16.1196
# INFO:tensorflow:loss = 0.54293764, step = 8034 (6.204 sec)
# INFO:tensorflow:lr = 0.0007003696 (6.205 sec)
# INFO:tensorflow:global_step/sec: 15.9615
# INFO:tensorflow:loss = 0.55834347, step = 8134 (6.265 sec)
# INFO:tensorflow:lr = 0.00069041655 (6.264 sec)
# INFO:tensorflow:global_step/sec: 15.7463
# INFO:tensorflow:loss = 0.55704445, step = 8234 (6.351 sec)
# INFO:tensorflow:lr = 0.00068046356 (6.353 sec)
# INFO:tensorflow:global_step/sec: 16.2806
# INFO:tensorflow:loss = 0.55793476, step = 8334 (6.137 sec)
# INFO:tensorflow:lr = 0.00067051046 (6.135 sec)
# INFO:tensorflow:global_step/sec: 16.6267
# INFO:tensorflow:loss = 0.5535653, step = 8434 (6.019 sec)
# INFO:tensorflow:lr = 0.00066055736 (6.022 sec)
# INFO:tensorflow:global_step/sec: 16.8286
# INFO:tensorflow:loss = 0.5271543, step = 8534 (5.941 sec)
# INFO:tensorflow:lr = 0.0006506043 (5.940 sec)
# INFO:tensorflow:global_step/sec: 16.8352
# INFO:tensorflow:loss = 0.5416899, step = 8634 (5.941 sec)
# INFO:tensorflow:lr = 0.0006406512 (5.940 sec)
# INFO:tensorflow:global_step/sec: 16.4149
# INFO:tensorflow:loss = 0.52313185, step = 8734 (6.092 sec)
# INFO:tensorflow:lr = 0.0006306981 (6.093 sec)
# INFO:tensorflow:global_step/sec: 15.7969
# INFO:tensorflow:loss = 0.5323271, step = 8834 (6.327 sec)
# INFO:tensorflow:lr = 0.00062074506 (6.329 sec)
# INFO:tensorflow:global_step/sec: 15.0672
# INFO:tensorflow:loss = 0.5369042, step = 8934 (6.640 sec)
# INFO:tensorflow:lr = 0.00061079196 (6.637 sec)
# INFO:tensorflow:global_step/sec: 16.6915
# INFO:tensorflow:loss = 0.5396895, step = 9034 (5.991 sec)
# INFO:tensorflow:lr = 0.00060083886 (5.993 sec)
# INFO:tensorflow:global_step/sec: 16.4242
# INFO:tensorflow:loss = 0.5420335, step = 9134 (6.087 sec)
# INFO:tensorflow:lr = 0.0005908858 (6.087 sec)
# INFO:tensorflow:global_step/sec: 17.0049
# INFO:tensorflow:loss = 0.5464524, step = 9234 (5.881 sec)
# INFO:tensorflow:lr = 0.0005809327 (5.879 sec)
# INFO:tensorflow:global_step/sec: 16.6721
# INFO:tensorflow:loss = 0.55484736, step = 9334 (6.001 sec)
# INFO:tensorflow:lr = 0.0005709796 (6.003 sec)
# INFO:tensorflow:global_step/sec: 16.3505
# INFO:tensorflow:loss = 0.5582314, step = 9434 (6.111 sec)
# INFO:tensorflow:lr = 0.00056102657 (6.109 sec)
# INFO:tensorflow:global_step/sec: 16.2321
# INFO:tensorflow:loss = 0.52786225, step = 9534 (6.162 sec)
# INFO:tensorflow:lr = 0.00055107346 (6.164 sec)
# INFO:tensorflow:global_step/sec: 16.3882
# INFO:tensorflow:loss = 0.5240706, step = 9634 (6.103 sec)
# INFO:tensorflow:lr = 0.00054112036 (6.102 sec)
# INFO:tensorflow:global_step/sec: 16.719
# INFO:tensorflow:loss = 0.547315, step = 9734 (5.985 sec)
# INFO:tensorflow:lr = 0.0005311673 (5.984 sec)
# INFO:tensorflow:global_step/sec: 38.2602
# INFO:tensorflow:loss = 0.5466632, step = 9834 (2.609 sec)
# INFO:tensorflow:lr = 0.0005212142 (2.611 sec)
# INFO:tensorflow:global_step/sec: 115.886
# INFO:tensorflow:loss = 0.55034417, step = 9934 (0.862 sec)
# INFO:tensorflow:lr = 0.00051126117 (0.860 sec)
# INFO:tensorflow:global_step/sec: 119.039
# INFO:tensorflow:loss = 0.528998, step = 10034 (0.839 sec)
# INFO:tensorflow:lr = 0.00050130807 (0.839 sec)
# INFO:tensorflow:global_step/sec: 109.968
# INFO:tensorflow:loss = 0.54875064, step = 10134 (0.909 sec)
# INFO:tensorflow:lr = 0.00049135496 (0.910 sec)
# INFO:tensorflow:global_step/sec: 115.212
# INFO:tensorflow:loss = 0.5303555, step = 10234 (0.869 sec)
# INFO:tensorflow:lr = 0.00048140192 (0.869 sec)
# INFO:tensorflow:global_step/sec: 114.94
# INFO:tensorflow:loss = 0.5391926, step = 10334 (0.870 sec)
# INFO:tensorflow:lr = 0.00047144882 (0.869 sec)
# INFO:tensorflow:global_step/sec: 108.906
# INFO:tensorflow:loss = 0.5554991, step = 10434 (0.922 sec)
# INFO:tensorflow:lr = 0.00046149574 (0.924 sec)
# INFO:tensorflow:global_step/sec: 103.195
# INFO:tensorflow:loss = 0.53775436, step = 10534 (0.963 sec)
# INFO:tensorflow:lr = 0.00045154267 (0.962 sec)
# INFO:tensorflow:Saving checkpoints for 10551 into ../model/dnn_sigmoid_clr/model.ckpt.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 0.49892795.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T01:23:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-10551
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-01:23:55
# INFO:tensorflow:Saving dict for global step 10551: global_step = 10551, loss = 0.5443739, mae = 0.6775816
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10551: ../model/dnn_sigmoid_clr/model.ckpt-10551
# INFO:tensorflow:MAE: 0.678
# INFO:tensorflow:Best MAE: 0.678
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-10551
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10551 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.5343193, step = 10551
# INFO:tensorflow:lr = 0.00044985072
# INFO:tensorflow:global_step/sec: 16.5064
# INFO:tensorflow:loss = 0.5391348, step = 10651 (6.063 sec)
# INFO:tensorflow:lr = 0.00043989762 (6.060 sec)
# INFO:tensorflow:global_step/sec: 16.915
# INFO:tensorflow:loss = 0.5332215, step = 10751 (5.913 sec)
# INFO:tensorflow:lr = 0.00042994454 (5.915 sec)
# INFO:tensorflow:global_step/sec: 16.9996
# INFO:tensorflow:loss = 0.5407411, step = 10851 (5.883 sec)
# INFO:tensorflow:lr = 0.00041999147 (5.881 sec)
# INFO:tensorflow:global_step/sec: 16.381
# INFO:tensorflow:loss = 0.5632687, step = 10951 (6.103 sec)
# INFO:tensorflow:lr = 0.0004100384 (6.104 sec)
# INFO:tensorflow:global_step/sec: 16.8432
# INFO:tensorflow:loss = 0.54429704, step = 11051 (5.937 sec)
# INFO:tensorflow:lr = 0.0004000853 (5.936 sec)
# INFO:tensorflow:global_step/sec: 16.593
# INFO:tensorflow:loss = 0.52776325, step = 11151 (6.026 sec)
# INFO:tensorflow:lr = 0.00039013222 (6.027 sec)
# INFO:tensorflow:global_step/sec: 16.4127
# INFO:tensorflow:loss = 0.5082953, step = 11251 (6.093 sec)
# INFO:tensorflow:lr = 0.00038017915 (6.093 sec)
# INFO:tensorflow:global_step/sec: 16.851
# INFO:tensorflow:loss = 0.56362945, step = 11351 (5.935 sec)
# INFO:tensorflow:lr = 0.00037022604 (5.934 sec)
# INFO:tensorflow:global_step/sec: 16.3832
# INFO:tensorflow:loss = 0.51575637, step = 11451 (6.103 sec)
# INFO:tensorflow:lr = 0.00036027297 (6.103 sec)
# INFO:tensorflow:global_step/sec: 16.5608
# INFO:tensorflow:loss = 0.52920413, step = 11551 (6.041 sec)
# INFO:tensorflow:lr = 0.0003503199 (6.044 sec)
# INFO:tensorflow:global_step/sec: 16.5019
# INFO:tensorflow:loss = 0.51762855, step = 11651 (6.057 sec)
# INFO:tensorflow:lr = 0.0003403668 (6.055 sec)
# INFO:tensorflow:global_step/sec: 16.0914
# INFO:tensorflow:loss = 0.52766246, step = 11751 (6.215 sec)
# INFO:tensorflow:lr = 0.00033041372 (6.215 sec)
# INFO:tensorflow:global_step/sec: 16.2801
# INFO:tensorflow:loss = 0.547406, step = 11851 (6.144 sec)
# INFO:tensorflow:lr = 0.00032046065 (6.144 sec)
# INFO:tensorflow:global_step/sec: 16.6517
# INFO:tensorflow:loss = 0.51567876, step = 11951 (6.003 sec)
# INFO:tensorflow:lr = 0.00031050757 (6.005 sec)
# INFO:tensorflow:global_step/sec: 16.4654
# INFO:tensorflow:loss = 0.54525113, step = 12051 (6.075 sec)
# INFO:tensorflow:lr = 0.00030055447 (6.074 sec)
# INFO:tensorflow:global_step/sec: 16.7254
# INFO:tensorflow:loss = 0.5340507, step = 12151 (5.980 sec)
# INFO:tensorflow:lr = 0.0002906014 (5.978 sec)
# INFO:tensorflow:global_step/sec: 16.0513
# INFO:tensorflow:loss = 0.5566987, step = 12251 (6.231 sec)
# INFO:tensorflow:lr = 0.00028064832 (6.233 sec)
# INFO:tensorflow:global_step/sec: 16.5251
# INFO:tensorflow:loss = 0.54676604, step = 12351 (6.050 sec)
# INFO:tensorflow:lr = 0.00027069525 (6.048 sec)
# INFO:tensorflow:global_step/sec: 16.829
# INFO:tensorflow:loss = 0.5385121, step = 12451 (5.942 sec)
# INFO:tensorflow:lr = 0.00026074215 (5.941 sec)
# INFO:tensorflow:global_step/sec: 16.5677
# INFO:tensorflow:loss = 0.5610228, step = 12551 (6.035 sec)
# INFO:tensorflow:lr = 0.00025078907 (6.036 sec)
# INFO:tensorflow:global_step/sec: 16.6474
# INFO:tensorflow:loss = 0.53209686, step = 12651 (6.005 sec)
# INFO:tensorflow:lr = 0.000240836 (6.009 sec)
# INFO:tensorflow:global_step/sec: 15.933
# INFO:tensorflow:loss = 0.5755462, step = 12751 (6.278 sec)
# INFO:tensorflow:lr = 0.0002308829 (6.275 sec)
# INFO:tensorflow:global_step/sec: 16.4284
# INFO:tensorflow:loss = 0.5239121, step = 12851 (6.087 sec)
# INFO:tensorflow:lr = 0.00022092983 (6.086 sec)
# INFO:tensorflow:global_step/sec: 16.1415
# INFO:tensorflow:loss = 0.5654569, step = 12951 (6.197 sec)
# INFO:tensorflow:lr = 0.00021097675 (6.197 sec)
# INFO:tensorflow:global_step/sec: 16.4262
# INFO:tensorflow:loss = 0.50766015, step = 13051 (6.086 sec)
# INFO:tensorflow:lr = 0.00020102375 (6.085 sec)
# INFO:tensorflow:global_step/sec: 16.1672
# INFO:tensorflow:loss = 0.53162766, step = 13151 (6.186 sec)
# INFO:tensorflow:lr = 0.00019107066 (6.186 sec)
# INFO:tensorflow:global_step/sec: 16.788
# INFO:tensorflow:loss = 0.54201514, step = 13251 (5.959 sec)
# INFO:tensorflow:lr = 0.00018111759 (5.958 sec)
# INFO:tensorflow:global_step/sec: 35.9474
# INFO:tensorflow:loss = 0.5358592, step = 13351 (2.778 sec)
# INFO:tensorflow:lr = 0.00017116452 (2.778 sec)
# INFO:tensorflow:global_step/sec: 100.435
# INFO:tensorflow:loss = 0.5340892, step = 13451 (0.996 sec)
# INFO:tensorflow:lr = 0.00016121143 (0.996 sec)
# INFO:tensorflow:global_step/sec: 115.718
# INFO:tensorflow:loss = 0.5128611, step = 13551 (0.864 sec)
# INFO:tensorflow:lr = 0.00015125834 (0.863 sec)
# INFO:tensorflow:global_step/sec: 112.256
# INFO:tensorflow:loss = 0.5214543, step = 13651 (0.897 sec)
# INFO:tensorflow:lr = 0.00014130527 (0.897 sec)
# INFO:tensorflow:global_step/sec: 110.944
# INFO:tensorflow:loss = 0.5400014, step = 13751 (0.895 sec)
# INFO:tensorflow:lr = 0.00013135218 (0.896 sec)
# INFO:tensorflow:global_step/sec: 112.329
# INFO:tensorflow:loss = 0.533806, step = 13851 (0.889 sec)
# INFO:tensorflow:lr = 0.000121399105 (0.888 sec)
# INFO:tensorflow:global_step/sec: 118.052
# INFO:tensorflow:loss = 0.52088445, step = 13951 (0.849 sec)
# INFO:tensorflow:lr = 0.00011144602 (0.848 sec)
# INFO:tensorflow:global_step/sec: 117
# INFO:tensorflow:loss = 0.53222144, step = 14051 (0.854 sec)
# INFO:tensorflow:lr = 0.00010149294 (0.855 sec)
# INFO:tensorflow:Saving checkpoints for 14068 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.55004215.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T01:27:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-14068
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-01:27:56
# INFO:tensorflow:Saving dict for global step 14068: global_step = 14068, loss = 0.54304045, mae = 0.6652836
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14068: ../model/dnn_sigmoid_clr/model.ckpt-14068
# INFO:tensorflow:MAE: 0.665
# INFO:tensorflow:Best MAE: 0.665
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-14068
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 14068 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.52310157, step = 14068
# INFO:tensorflow:lr = 0.00010009955
# INFO:tensorflow:global_step/sec: 16.2661
# INFO:tensorflow:loss = 0.5191321, step = 14168 (6.159 sec)
# INFO:tensorflow:lr = 0.00010507605 (6.159 sec)
# INFO:tensorflow:global_step/sec: 16.9037
# INFO:tensorflow:loss = 0.52630424, step = 14268 (5.908 sec)
# INFO:tensorflow:lr = 0.00011005263 (5.907 sec)
# INFO:tensorflow:global_step/sec: 16.9702
# INFO:tensorflow:loss = 0.5286815, step = 14368 (5.894 sec)
# INFO:tensorflow:lr = 0.00011502913 (5.893 sec)
# INFO:tensorflow:global_step/sec: 16.8061
# INFO:tensorflow:loss = 0.5379689, step = 14468 (5.953 sec)
# INFO:tensorflow:lr = 0.000120005716 (5.956 sec)
# INFO:tensorflow:global_step/sec: 16.7719
# INFO:tensorflow:loss = 0.5493339, step = 14568 (5.964 sec)
# INFO:tensorflow:lr = 0.00012498221 (5.961 sec)
# INFO:tensorflow:global_step/sec: 16.823
# INFO:tensorflow:loss = 0.5568525, step = 14668 (5.940 sec)
# INFO:tensorflow:lr = 0.00012995879 (5.943 sec)
# INFO:tensorflow:global_step/sec: 16.5506
# INFO:tensorflow:loss = 0.532601, step = 14768 (6.044 sec)
# INFO:tensorflow:lr = 0.0001349353 (6.042 sec)
# INFO:tensorflow:global_step/sec: 16.4366
# INFO:tensorflow:loss = 0.54994595, step = 14868 (6.083 sec)
# INFO:tensorflow:lr = 0.00013991188 (6.083 sec)
# INFO:tensorflow:global_step/sec: 16.7152
# INFO:tensorflow:loss = 0.53870666, step = 14968 (5.982 sec)
# INFO:tensorflow:lr = 0.00014488837 (5.981 sec)
# INFO:tensorflow:global_step/sec: 16.4935
# INFO:tensorflow:loss = 0.5297343, step = 15068 (6.062 sec)
# INFO:tensorflow:lr = 0.00014986495 (6.064 sec)
# INFO:tensorflow:global_step/sec: 16.3263
# INFO:tensorflow:loss = 0.52152187, step = 15168 (6.134 sec)
# INFO:tensorflow:lr = 0.00015484146 (6.134 sec)
# INFO:tensorflow:global_step/sec: 16.3622
# INFO:tensorflow:loss = 0.5107721, step = 15268 (6.104 sec)
# INFO:tensorflow:lr = 0.00015981804 (6.103 sec)
# INFO:tensorflow:global_step/sec: 16.1198
# INFO:tensorflow:loss = 0.5419756, step = 15368 (6.203 sec)
# INFO:tensorflow:lr = 0.00016479453 (6.201 sec)
# INFO:tensorflow:global_step/sec: 16.699
# INFO:tensorflow:loss = 0.4962947, step = 15468 (5.990 sec)
# INFO:tensorflow:lr = 0.00016977111 (5.991 sec)
# INFO:tensorflow:global_step/sec: 16.6424
# INFO:tensorflow:loss = 0.53823936, step = 15568 (6.005 sec)
# INFO:tensorflow:lr = 0.00017474762 (6.004 sec)
# INFO:tensorflow:global_step/sec: 16.5267
# INFO:tensorflow:loss = 0.51601845, step = 15668 (6.053 sec)
# INFO:tensorflow:lr = 0.0001797242 (6.055 sec)
# INFO:tensorflow:global_step/sec: 16.602
# INFO:tensorflow:loss = 0.5414072, step = 15768 (6.024 sec)
# INFO:tensorflow:lr = 0.00018470071 (6.023 sec)
# INFO:tensorflow:global_step/sec: 16.8333
# INFO:tensorflow:loss = 0.51217717, step = 15868 (5.942 sec)
# INFO:tensorflow:lr = 0.00018967729 (5.942 sec)
# INFO:tensorflow:global_step/sec: 16.703
# INFO:tensorflow:loss = 0.5581124, step = 15968 (5.988 sec)
# INFO:tensorflow:lr = 0.00019465378 (5.988 sec)
# INFO:tensorflow:global_step/sec: 16.3618
# INFO:tensorflow:loss = 0.53556424, step = 16068 (6.108 sec)
# INFO:tensorflow:lr = 0.00019963036 (6.108 sec)
# INFO:tensorflow:global_step/sec: 16.8247
# INFO:tensorflow:loss = 0.5132988, step = 16168 (5.948 sec)
# INFO:tensorflow:lr = 0.00020460685 (5.949 sec)
# INFO:tensorflow:global_step/sec: 16.3365
# INFO:tensorflow:loss = 0.51860595, step = 16268 (6.119 sec)
# INFO:tensorflow:lr = 0.00020958344 (6.119 sec)
# INFO:tensorflow:global_step/sec: 16.001
# INFO:tensorflow:loss = 0.54594904, step = 16368 (6.250 sec)
# INFO:tensorflow:lr = 0.00021455994 (6.250 sec)
# INFO:tensorflow:global_step/sec: 16.4353
# INFO:tensorflow:loss = 0.520053, step = 16468 (6.083 sec)
# INFO:tensorflow:lr = 0.00021953645 (6.084 sec)
# INFO:tensorflow:global_step/sec: 16.3547
# INFO:tensorflow:loss = 0.52351, step = 16568 (6.113 sec)
# INFO:tensorflow:lr = 0.00022451303 (6.113 sec)
# INFO:tensorflow:global_step/sec: 16.1802
# INFO:tensorflow:loss = 0.5446695, step = 16668 (6.182 sec)
# INFO:tensorflow:lr = 0.00022948952 (6.180 sec)
# INFO:tensorflow:global_step/sec: 16.8779
# INFO:tensorflow:loss = 0.5491404, step = 16768 (5.923 sec)
# INFO:tensorflow:lr = 0.0002344661 (5.925 sec)
# INFO:tensorflow:global_step/sec: 37.9448
# INFO:tensorflow:loss = 0.5455608, step = 16868 (2.635 sec)
# INFO:tensorflow:lr = 0.0002394426 (2.633 sec)
# INFO:tensorflow:global_step/sec: 116.31
# INFO:tensorflow:loss = 0.52063674, step = 16968 (0.859 sec)
# INFO:tensorflow:lr = 0.00024441918 (0.858 sec)
# INFO:tensorflow:global_step/sec: 118.437
# INFO:tensorflow:loss = 0.5369624, step = 17068 (0.845 sec)
# INFO:tensorflow:lr = 0.00024939567 (0.845 sec)
# INFO:tensorflow:global_step/sec: 116.226
# INFO:tensorflow:loss = 0.54365873, step = 17168 (0.863 sec)
# INFO:tensorflow:lr = 0.00025437228 (0.863 sec)
# INFO:tensorflow:global_step/sec: 116.352
# INFO:tensorflow:loss = 0.549605, step = 17268 (0.859 sec)
# INFO:tensorflow:lr = 0.00025934877 (0.858 sec)
# INFO:tensorflow:global_step/sec: 117.145
# INFO:tensorflow:loss = 0.5378676, step = 17368 (0.851 sec)
# INFO:tensorflow:lr = 0.00026432535 (0.851 sec)
# INFO:tensorflow:global_step/sec: 114.422
# INFO:tensorflow:loss = 0.5218735, step = 17468 (0.873 sec)
# INFO:tensorflow:lr = 0.00026930185 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.838
# INFO:tensorflow:loss = 0.52203274, step = 17568 (0.871 sec)
# INFO:tensorflow:lr = 0.00027427843 (0.871 sec)
# INFO:tensorflow:Saving checkpoints for 17585 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5428117.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T01:31:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-17585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-01:31:56
# INFO:tensorflow:Saving dict for global step 17585: global_step = 17585, loss = 0.54285276, mae = 0.6642431
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17585: ../model/dnn_sigmoid_clr/model.ckpt-17585
# INFO:tensorflow:MAE: 0.664
# INFO:tensorflow:Best MAE: 0.664
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-17585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17585 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.54704374, step = 17585
# INFO:tensorflow:lr = 0.00027512442
# INFO:tensorflow:global_step/sec: 16.2152
# INFO:tensorflow:loss = 0.5522042, step = 17685 (6.174 sec)
# INFO:tensorflow:lr = 0.000280101 (6.169 sec)
# INFO:tensorflow:global_step/sec: 15.4125
# INFO:tensorflow:loss = 0.5446172, step = 17785 (6.488 sec)
# INFO:tensorflow:lr = 0.0002850775 (6.486 sec)
# INFO:tensorflow:global_step/sec: 15.6426
# INFO:tensorflow:loss = 0.55596864, step = 17885 (6.394 sec)
# INFO:tensorflow:lr = 0.00029005407 (6.394 sec)
# INFO:tensorflow:global_step/sec: 16.7956
# INFO:tensorflow:loss = 0.54186964, step = 17985 (5.952 sec)
# INFO:tensorflow:lr = 0.00029503056 (5.953 sec)
# INFO:tensorflow:global_step/sec: 16.9026
# INFO:tensorflow:loss = 0.5234683, step = 18085 (5.919 sec)
# INFO:tensorflow:lr = 0.00030000714 (5.917 sec)
# INFO:tensorflow:global_step/sec: 16.658
# INFO:tensorflow:loss = 0.5307031, step = 18185 (6.000 sec)
# INFO:tensorflow:lr = 0.00030498367 (6.001 sec)
# INFO:tensorflow:global_step/sec: 16.5476
# INFO:tensorflow:loss = 0.560374, step = 18285 (6.042 sec)
# INFO:tensorflow:lr = 0.00030996025 (6.043 sec)
# INFO:tensorflow:global_step/sec: 16.7819
# INFO:tensorflow:loss = 0.53076017, step = 18385 (5.962 sec)
# INFO:tensorflow:lr = 0.00031493674 (5.964 sec)
# INFO:tensorflow:global_step/sec: 16.527
# INFO:tensorflow:loss = 0.5319794, step = 18485 (6.046 sec)
# INFO:tensorflow:lr = 0.00031991323 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.2686
# INFO:tensorflow:loss = 0.5489552, step = 18585 (6.148 sec)
# INFO:tensorflow:lr = 0.0003248898 (6.144 sec)
# INFO:tensorflow:global_step/sec: 16.7593
# INFO:tensorflow:loss = 0.54307723, step = 18685 (5.966 sec)
# INFO:tensorflow:lr = 0.0003298663 (5.969 sec)
# INFO:tensorflow:global_step/sec: 15.9268
# INFO:tensorflow:loss = 0.5429295, step = 18785 (6.280 sec)
# INFO:tensorflow:lr = 0.0003348429 (6.277 sec)
# INFO:tensorflow:global_step/sec: 15.7235
# INFO:tensorflow:loss = 0.5157474, step = 18885 (6.359 sec)
# INFO:tensorflow:lr = 0.0003398194 (6.362 sec)
# INFO:tensorflow:global_step/sec: 16.6866
# INFO:tensorflow:loss = 0.5220818, step = 18985 (5.993 sec)
# INFO:tensorflow:lr = 0.000344796 (5.992 sec)
# INFO:tensorflow:global_step/sec: 16.4717
# INFO:tensorflow:loss = 0.5312065, step = 19085 (6.070 sec)
# INFO:tensorflow:lr = 0.00034977248 (6.071 sec)
# INFO:tensorflow:global_step/sec: 16.2286
# INFO:tensorflow:loss = 0.5438818, step = 19185 (6.162 sec)
# INFO:tensorflow:lr = 0.00035474906 (6.160 sec)
# INFO:tensorflow:global_step/sec: 16.5378
# INFO:tensorflow:loss = 0.53097564, step = 19285 (6.047 sec)
# INFO:tensorflow:lr = 0.00035972556 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.747
# INFO:tensorflow:loss = 0.5394515, step = 19385 (5.972 sec)
# INFO:tensorflow:lr = 0.00036470214 (5.972 sec)
# INFO:tensorflow:global_step/sec: 16.6161
# INFO:tensorflow:loss = 0.5275426, step = 19485 (6.018 sec)
# INFO:tensorflow:lr = 0.00036967866 (6.020 sec)
# INFO:tensorflow:global_step/sec: 16.6689
# INFO:tensorflow:loss = 0.53413886, step = 19585 (5.998 sec)
# INFO:tensorflow:lr = 0.00037465524 (5.995 sec)
# INFO:tensorflow:global_step/sec: 16.7797
# INFO:tensorflow:loss = 0.54011136, step = 19685 (5.961 sec)
# INFO:tensorflow:lr = 0.00037963173 (5.961 sec)
# INFO:tensorflow:global_step/sec: 16.2709
# INFO:tensorflow:loss = 0.52497935, step = 19785 (6.148 sec)
# INFO:tensorflow:lr = 0.0003846083 (6.154 sec)
# INFO:tensorflow:global_step/sec: 15.8271
# INFO:tensorflow:loss = 0.56148165, step = 19885 (6.313 sec)
# INFO:tensorflow:lr = 0.0003895848 (6.312 sec)
# INFO:tensorflow:global_step/sec: 16.1216
# INFO:tensorflow:loss = 0.51877433, step = 19985 (6.207 sec)
# INFO:tensorflow:lr = 0.0003945614 (6.203 sec)
# INFO:tensorflow:global_step/sec: 15.9684
# INFO:tensorflow:loss = 0.5603901, step = 20085 (6.263 sec)
# INFO:tensorflow:lr = 0.00039953788 (6.263 sec)
# INFO:tensorflow:global_step/sec: 15.7668
# INFO:tensorflow:loss = 0.5329518, step = 20185 (6.339 sec)
# INFO:tensorflow:lr = 0.00040451446 (6.339 sec)
# INFO:tensorflow:global_step/sec: 16.4053
# INFO:tensorflow:loss = 0.5291275, step = 20285 (6.098 sec)
# ...
# INFO:tensorflow:Saving dict for global step 56272: global_step = 56272, loss = 0.5467681, mae = 0.6662916
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56272: ../model/dnn_sigmoid_clr/model.ckpt-56272
# INFO:tensorflow:MAE: 0.666
# INFO:tensorflow:Best MAE: 0.661
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-56272
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 56272 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.5065561, step = 56272
# INFO:tensorflow:lr = 0.00010004977
# INFO:tensorflow:global_step/sec: 15.9643
# INFO:tensorflow:loss = 0.49052495, step = 56372 (6.268 sec)
# INFO:tensorflow:lr = 0.00010067182 (6.265 sec)
# INFO:tensorflow:global_step/sec: 16.6413
# INFO:tensorflow:loss = 0.48337618, step = 56472 (6.011 sec)
# INFO:tensorflow:lr = 0.00010129392 (6.010 sec)
# INFO:tensorflow:global_step/sec: 16.501
# INFO:tensorflow:loss = 0.5313788, step = 56572 (6.059 sec)
# INFO:tensorflow:lr = 0.00010191597 (6.060 sec)
# INFO:tensorflow:global_step/sec: 16.6646
# INFO:tensorflow:loss = 0.5490665, step = 56672 (5.999 sec)
# INFO:tensorflow:lr = 0.000102538026 (5.997 sec)
# INFO:tensorflow:global_step/sec: 16.1901
# INFO:tensorflow:loss = 0.5227849, step = 56772 (6.180 sec)
# INFO:tensorflow:lr = 0.00010316011 (6.180 sec)
# INFO:tensorflow:global_step/sec: 16.1802
# INFO:tensorflow:loss = 0.5258746, step = 56872 (6.176 sec)
# INFO:tensorflow:lr = 0.00010378217 (6.176 sec)
# INFO:tensorflow:global_step/sec: 16.7705
# INFO:tensorflow:loss = 0.5317968, step = 56972 (5.971 sec)
# INFO:tensorflow:lr = 0.00010440426 (5.974 sec)
# INFO:tensorflow:global_step/sec: 16.4759
# INFO:tensorflow:loss = 0.53719735, step = 57072 (6.066 sec)
# INFO:tensorflow:lr = 0.000105026316 (6.064 sec)
# INFO:tensorflow:global_step/sec: 16.7519
# INFO:tensorflow:loss = 0.5468924, step = 57172 (5.968 sec)
# INFO:tensorflow:lr = 0.00010564837 (5.968 sec)
# INFO:tensorflow:global_step/sec: 15.9469
# INFO:tensorflow:loss = 0.53607243, step = 57272 (6.269 sec)
# INFO:tensorflow:lr = 0.00010627046 (6.269 sec)
# INFO:tensorflow:global_step/sec: 16.4841
# INFO:tensorflow:loss = 0.5101167, step = 57372 (6.067 sec)
# INFO:tensorflow:lr = 0.00010689251 (6.067 sec)
# INFO:tensorflow:global_step/sec: 16.5017
# INFO:tensorflow:loss = 0.5377605, step = 57472 (6.061 sec)
# INFO:tensorflow:lr = 0.00010751456 (6.065 sec)
# INFO:tensorflow:global_step/sec: 16.7095
# INFO:tensorflow:loss = 0.5276326, step = 57572 (5.987 sec)
# INFO:tensorflow:lr = 0.00010813666 (5.986 sec)
# INFO:tensorflow:global_step/sec: 16.7288
# INFO:tensorflow:loss = 0.5301861, step = 57672 (5.976 sec)
# INFO:tensorflow:lr = 0.00010875871 (5.972 sec)
# INFO:tensorflow:global_step/sec: 16.6653
# INFO:tensorflow:loss = 0.55424774, step = 57772 (6.000 sec)
# INFO:tensorflow:lr = 0.00010938076 (6.001 sec)
# INFO:tensorflow:global_step/sec: 16.673
# INFO:tensorflow:loss = 0.5448215, step = 57872 (6.000 sec)
# INFO:tensorflow:lr = 0.00011000285 (5.999 sec)
# INFO:tensorflow:global_step/sec: 16.9597
# INFO:tensorflow:loss = 0.5001653, step = 57972 (5.894 sec)
# INFO:tensorflow:lr = 0.000110624904 (5.896 sec)
# INFO:tensorflow:global_step/sec: 16.9594
# INFO:tensorflow:loss = 0.5388142, step = 58072 (5.897 sec)
# INFO:tensorflow:lr = 0.000111247 (5.896 sec)
# INFO:tensorflow:global_step/sec: 16.6285
# INFO:tensorflow:loss = 0.538677, step = 58172 (6.014 sec)
# INFO:tensorflow:lr = 0.000111869056 (6.013 sec)
# INFO:tensorflow:global_step/sec: 16.8341
# INFO:tensorflow:loss = 0.53197354, step = 58272 (5.940 sec)
# INFO:tensorflow:lr = 0.00011249111 (5.940 sec)
# INFO:tensorflow:global_step/sec: 16.9101
# INFO:tensorflow:loss = 0.5216841, step = 58372 (5.914 sec)
# INFO:tensorflow:lr = 0.0001131132 (5.912 sec)
# INFO:tensorflow:global_step/sec: 16.6451
# INFO:tensorflow:loss = 0.50082016, step = 58472 (6.005 sec)
# INFO:tensorflow:lr = 0.00011373525 (6.006 sec)
# INFO:tensorflow:global_step/sec: 16.6909
# INFO:tensorflow:loss = 0.51739854, step = 58572 (5.996 sec)
# INFO:tensorflow:lr = 0.0001143573 (5.996 sec)
# INFO:tensorflow:global_step/sec: 16.8694
# INFO:tensorflow:loss = 0.5263038, step = 58672 (5.928 sec)
# INFO:tensorflow:lr = 0.0001149794 (5.928 sec)
# INFO:tensorflow:global_step/sec: 16.678
# INFO:tensorflow:loss = 0.4859982, step = 58772 (5.995 sec)
# INFO:tensorflow:lr = 0.00011560145 (5.997 sec)
# INFO:tensorflow:global_step/sec: 15.9922
# INFO:tensorflow:loss = 0.5075299, step = 58872 (6.253 sec)
# INFO:tensorflow:lr = 0.00011622354 (6.253 sec)
# INFO:tensorflow:global_step/sec: 15.1905
# INFO:tensorflow:loss = 0.52980614, step = 58972 (6.585 sec)
# INFO:tensorflow:lr = 0.00011684559 (6.586 sec)
# INFO:tensorflow:global_step/sec: 34.6577
# INFO:tensorflow:loss = 0.524845, step = 59072 (2.879 sec)
# INFO:tensorflow:lr = 0.00011746764 (2.877 sec)
# INFO:tensorflow:global_step/sec: 109.753
# INFO:tensorflow:loss = 0.5039492, step = 59172 (0.913 sec)
# INFO:tensorflow:lr = 0.00011808974 (0.912 sec)
# INFO:tensorflow:global_step/sec: 112.318
# INFO:tensorflow:loss = 0.5069759, step = 59272 (0.890 sec)
# INFO:tensorflow:lr = 0.00011871179 (0.891 sec)
# INFO:tensorflow:global_step/sec: 117.197
# INFO:tensorflow:loss = 0.5461158, step = 59372 (0.852 sec)
# INFO:tensorflow:lr = 0.00011933384 (0.851 sec)
# INFO:tensorflow:global_step/sec: 116.849
# INFO:tensorflow:loss = 0.48419037, step = 59472 (0.856 sec)
# INFO:tensorflow:lr = 0.000119955934 (0.858 sec)
# INFO:tensorflow:global_step/sec: 116.997
# INFO:tensorflow:loss = 0.49527913, step = 59572 (0.855 sec)
# INFO:tensorflow:lr = 0.000120577984 (0.854 sec)
# INFO:tensorflow:global_step/sec: 115.264
# INFO:tensorflow:loss = 0.51086694, step = 59672 (0.868 sec)
# INFO:tensorflow:lr = 0.00012120008 (0.869 sec)
# INFO:tensorflow:global_step/sec: 118.303
# INFO:tensorflow:loss = 0.5196922, step = 59772 (0.846 sec)
# INFO:tensorflow:lr = 0.00012182213 (0.845 sec)
# INFO:tensorflow:Saving checkpoints for 59789 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5203447.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T02:19:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-59789
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-02:19:59
# INFO:tensorflow:Saving dict for global step 59789: global_step = 59789, loss = 0.54753715, mae = 0.66487384
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 59789: ../model/dnn_sigmoid_clr/model.ckpt-59789
# INFO:tensorflow:MAE: 0.665
# INFO:tensorflow:Best MAE: 0.661
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-59789
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 59789 into ../model/dnn_sigmoid_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.50479573, step = 59789
# INFO:tensorflow:lr = 0.000121927864
# INFO:tensorflow:global_step/sec: 16.4075
# INFO:tensorflow:loss = 0.5348384, step = 59889 (6.099 sec)
# INFO:tensorflow:lr = 0.00012254996 (6.093 sec)
# INFO:tensorflow:global_step/sec: 16.8508
# INFO:tensorflow:loss = 0.52689123, step = 59989 (5.933 sec)
# INFO:tensorflow:lr = 0.00012317201 (5.934 sec)
# INFO:tensorflow:global_step/sec: 16.5587
# INFO:tensorflow:loss = 0.5139936, step = 60089 (6.041 sec)
# INFO:tensorflow:lr = 0.0001237941 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.9441
# INFO:tensorflow:loss = 0.5364243, step = 60189 (5.902 sec)
# INFO:tensorflow:lr = 0.00012441615 (5.895 sec)
# INFO:tensorflow:global_step/sec: 17.2547
# INFO:tensorflow:loss = 0.5296945, step = 60289 (5.799 sec)
# INFO:tensorflow:lr = 0.0001250382 (5.796 sec)
# INFO:tensorflow:global_step/sec: 16.8291
# INFO:tensorflow:loss = 0.5213792, step = 60389 (5.939 sec)
# INFO:tensorflow:lr = 0.0001256603 (5.940 sec)
# INFO:tensorflow:global_step/sec: 17.2901
# INFO:tensorflow:loss = 0.52639216, step = 60489 (5.785 sec)
# INFO:tensorflow:lr = 0.00012628235 (5.785 sec)
# INFO:tensorflow:global_step/sec: 17.1757
# INFO:tensorflow:loss = 0.523489, step = 60589 (5.820 sec)
# INFO:tensorflow:lr = 0.0001269044 (5.820 sec)
# INFO:tensorflow:global_step/sec: 17.2116
# INFO:tensorflow:loss = 0.513758, step = 60689 (5.811 sec)
# INFO:tensorflow:lr = 0.0001275265 (5.812 sec)
# INFO:tensorflow:global_step/sec: 16.6742
# INFO:tensorflow:loss = 0.5281209, step = 60789 (5.999 sec)
# INFO:tensorflow:lr = 0.00012814855 (6.002 sec)
# INFO:tensorflow:global_step/sec: 16.6397
# INFO:tensorflow:loss = 0.53641427, step = 60889 (6.011 sec)
# INFO:tensorflow:lr = 0.00012877064 (6.008 sec)
# INFO:tensorflow:global_step/sec: 17.1398
# INFO:tensorflow:loss = 0.51352435, step = 60989 (5.832 sec)
# INFO:tensorflow:lr = 0.00012939269 (5.833 sec)
# INFO:tensorflow:global_step/sec: 16.8013
# INFO:tensorflow:loss = 0.50022006, step = 61089 (5.951 sec)
# INFO:tensorflow:lr = 0.00013001474 (5.951 sec)
# INFO:tensorflow:global_step/sec: 16.6602
# INFO:tensorflow:loss = 0.51044184, step = 61189 (6.007 sec)
# INFO:tensorflow:lr = 0.00013063684 (6.004 sec)
# INFO:tensorflow:global_step/sec: 16.2719
# INFO:tensorflow:loss = 0.5201562, step = 61289 (6.142 sec)
# INFO:tensorflow:lr = 0.00013125889 (6.142 sec)
# INFO:tensorflow:global_step/sec: 16.5501
# INFO:tensorflow:loss = 0.5280844, step = 61389 (6.042 sec)
# INFO:tensorflow:lr = 0.00013188094 (6.042 sec)
# INFO:tensorflow:global_step/sec: 16.5396
# INFO:tensorflow:loss = 0.5075908, step = 61489 (6.046 sec)
# INFO:tensorflow:lr = 0.00013250303 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.8515
# INFO:tensorflow:loss = 0.512856, step = 61589 (5.934 sec)
# INFO:tensorflow:lr = 0.00013312508 (5.933 sec)
# INFO:tensorflow:global_step/sec: 16.8466
# INFO:tensorflow:loss = 0.5100674, step = 61689 (5.945 sec)
# INFO:tensorflow:lr = 0.00013374718 (5.944 sec)
# INFO:tensorflow:global_step/sec: 16.7476
# INFO:tensorflow:loss = 0.5232307, step = 61789 (5.963 sec)
# INFO:tensorflow:lr = 0.00013436923 (5.963 sec)
# INFO:tensorflow:global_step/sec: 16.585
# INFO:tensorflow:loss = 0.5440829, step = 61889 (6.028 sec)
# INFO:tensorflow:lr = 0.00013499128 (6.029 sec)
# INFO:tensorflow:global_step/sec: 16.0073
# INFO:tensorflow:loss = 0.50596356, step = 61989 (6.247 sec)
# INFO:tensorflow:lr = 0.00013561337 (6.249 sec)
# INFO:tensorflow:global_step/sec: 16.8814
# INFO:tensorflow:loss = 0.5238067, step = 62089 (5.924 sec)
# INFO:tensorflow:lr = 0.00013623544 (5.924 sec)
# INFO:tensorflow:global_step/sec: 16.9283
# INFO:tensorflow:loss = 0.5041717, step = 62189 (5.905 sec)
# INFO:tensorflow:lr = 0.00013685747 (5.906 sec)
# INFO:tensorflow:global_step/sec: 16.9877
# INFO:tensorflow:loss = 0.52574366, step = 62289 (5.889 sec)
# INFO:tensorflow:lr = 0.00013747957 (5.887 sec)
# INFO:tensorflow:global_step/sec: 16.376
# INFO:tensorflow:loss = 0.52654636, step = 62389 (6.106 sec)
# INFO:tensorflow:lr = 0.00013810163 (6.108 sec)
# INFO:tensorflow:global_step/sec: 16.817
# INFO:tensorflow:loss = 0.5178692, step = 62489 (5.947 sec)
# INFO:tensorflow:lr = 0.00013872368 (5.945 sec)
# INFO:tensorflow:global_step/sec: 37.7812
# INFO:tensorflow:loss = 0.51616484, step = 62589 (2.644 sec)
# INFO:tensorflow:lr = 0.00013934576 (2.643 sec)
# INFO:tensorflow:global_step/sec: 105.048
# INFO:tensorflow:loss = 0.49728236, step = 62689 (0.953 sec)
# INFO:tensorflow:lr = 0.00013996783 (0.952 sec)
# INFO:tensorflow:global_step/sec: 113.45
# INFO:tensorflow:loss = 0.52302504, step = 62789 (0.882 sec)
# INFO:tensorflow:lr = 0.00014058992 (0.882 sec)
# INFO:tensorflow:global_step/sec: 116.449
# INFO:tensorflow:loss = 0.51807404, step = 62889 (0.858 sec)
# INFO:tensorflow:lr = 0.00014121197 (0.858 sec)
# INFO:tensorflow:global_step/sec: 117.892
# INFO:tensorflow:loss = 0.5307873, step = 62989 (0.846 sec)
# INFO:tensorflow:lr = 0.00014183403 (0.847 sec)
# INFO:tensorflow:global_step/sec: 114.615
# INFO:tensorflow:loss = 0.50007075, step = 63089 (0.874 sec)
# INFO:tensorflow:lr = 0.00014245612 (0.873 sec)
# INFO:tensorflow:global_step/sec: 115.479
# INFO:tensorflow:loss = 0.5341691, step = 63189 (0.867 sec)
# INFO:tensorflow:lr = 0.00014307817 (0.867 sec)
# INFO:tensorflow:global_step/sec: 113.805
# INFO:tensorflow:loss = 0.4911115, step = 63289 (0.879 sec)
# INFO:tensorflow:lr = 0.00014370022 (0.879 sec)
# INFO:tensorflow:Saving checkpoints for 63306 into ../model/dnn_sigmoid_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.49862787.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-02T02:23:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_sigmoid_clr/model.ckpt-63306
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-06-02-02:23:55
# INFO:tensorflow:Saving dict for global step 63306: global_step = 63306, loss = 0.54741657, mae = 0.6665753
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 63306: ../model/dnn_sigmoid_clr/model.ckpt-63306
# INFO:tensorflow:MAE: 0.667
# INFO:tensorflow:Best MAE: 0.661
# 7 times not improve the best result, therefore stop training
