# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/recommender/movielens/main')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
import pprint
import logging

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def gen_fn(f_path):
  movietype2idx = {}
  with open('../vocab/movie_types.txt') as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      movietype2idx[line] = i
  
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      (user_id, user_gender, user_age, user_job, movie_id, movie_types, movie_title, score) = line.split('\t')
      
      movie_types_ = [0] * len(movietype2idx)
      for movie_type in movie_types.split():
        movie_types_[movietype2idx[movie_type]] = 1
        
      movie_title = movie_title.split()
      yield (user_id, user_age, user_job, user_gender, movie_id, movie_types_, movie_title), score


def dataset(is_training, params):
  _shapes = (([], [], [], [], [], [18], [None]), [])
  _types = ((tf.string, tf.string, tf.string, tf.string, tf.string, tf.int32, tf.string), tf.float32)
  _pads = (('-1', '-1', '-1', '-1', '-1', -1, '<pad>'), 0.)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['train_path']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['test_path']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clr(step,
        initial_learning_rate,
        maximal_learning_rate,
        step_size,
        gamma=1.,):
  scale_mode = "iterations"
  scale_fn = lambda x: gamma**x
  step = tf.cast(step, tf.float32)
  
  initial_learning_rate = tf.convert_to_tensor(
    initial_learning_rate, name="initial_learning_rate")
  dtype = initial_learning_rate.dtype
  maximal_learning_rate = tf.cast(maximal_learning_rate, dtype)
  step_size = tf.cast(step_size, dtype)
  cycle = tf.floor(1 + step / (2 * step_size))
  x = tf.abs(step / step_size - 2 * cycle + 1)

  mode_step = cycle if scale_mode == "cycle" else step

  return initial_learning_rate + (
    maximal_learning_rate - initial_learning_rate) * tf.maximum(
      tf.cast(0, dtype), (1 - x)) * scale_fn(mode_step)

# %%
def model_fn(features, labels, mode, params):
  # Receive inputs
  user_id, user_age, user_job, user_gender, movie_id, movie_types, movie_title = features
  
  
  # Flag for Dropout / Batch Norm
  is_training = (mode == tf.estimator.ModeKeys.TRAIN)
  
  
  # Word Indexing
  lookup_user_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_id.txt', num_oov_buckets=1)
  
  lookup_user_age = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_age.txt', num_oov_buckets=1)
  
  lookup_user_job = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_job.txt', num_oov_buckets=1)
  
  lookup_user_gender = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_gender.txt', num_oov_buckets=1)
  
  lookup_movie_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_id.txt', num_oov_buckets=1)
  
  lookup_movie_title = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_title.txt', num_oov_buckets=1)
  
  user_id = lookup_user_id.lookup(user_id)
  
  user_age = lookup_user_age.lookup(user_age)
  
  user_job = lookup_user_job.lookup(user_job)
  
  user_gender = lookup_user_gender.lookup(user_gender)
  
  movie_id = lookup_movie_id.lookup(movie_id)
  
  movie_title = lookup_movie_title.lookup(movie_title)
  
  
  # Embedding
  user_id = tf.contrib.layers.embed_sequence(
    ids = user_id,
    vocab_size = params['user_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='user_id')
  
  user_age = tf.contrib.layers.embed_sequence(
    ids = user_age,
    vocab_size = params['user_age_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_age')
  
  user_job = tf.contrib.layers.embed_sequence(
    ids = user_job,
    vocab_size = params['user_job_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_job')
  
  user_gender = tf.contrib.layers.embed_sequence(
    ids = user_gender,
    vocab_size = params['user_gender_size'],
    embed_dim = params['small_embed_dim'],
    scope='user_gender')
  
  movie_id = tf.contrib.layers.embed_sequence(
    ids = movie_id,
    vocab_size = params['movie_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_id')
  
  movie_types = tf.to_float(movie_types)
  
  movie_title = tf.contrib.layers.embed_sequence(
    ids = movie_title,
    vocab_size = params['movie_title_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_title')
  
  
  # User Network
  user_feature = tf.concat((user_id, user_age, user_job, user_gender), -1)
  
  user_feature = tf.layers.dropout(user_feature, params['dropout_rate'], training=is_training)
  
  user_feature = tf.layers.dense(user_feature,
                                 params['hidden_dim'],
                                 params['activation'],
                                 name='user_feature/fc')
  
  
  # Movie Network
  movie_title = tf.layers.dropout(movie_title, params['dropout_rate'], training=is_training)
  
  movie_title = tf.reduce_max(tf.layers.conv1d(movie_title,
                                               filters=params['large_embed_dim'],
                                               kernel_size=params['kernel_size'],
                                               activation=params['activation'],
                                               name='movie_feature/conv1d'), axis=1)
  
  movie_feature = tf.concat((movie_id, movie_types, movie_title), -1)
  
  movie_feature = tf.layers.dropout(movie_feature, params['dropout_rate'], training=is_training)
  
  movie_feature = tf.layers.dense(movie_feature,
                                  params['hidden_dim'],
                                  params['activation'],
                                  name='movie_feature/fc')
  
  
  # Aggregation
  scores = tf.concat([tf.abs(user_feature - movie_feature),
                      user_feature * movie_feature,
                      user_feature,
                      movie_feature], -1)
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  logits = tf.layers.dense(scores, 5)
  predictions = tf.to_float(tf.argmax(logits, -1) + 1)
  
  
  if labels is not None:
    loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
      labels=tf.to_int32(labels-1), logits=logits))
  
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    tf.logging.info('\n'+pprint.pformat(tf.trainable_variables()))
    
    global_step=tf.train.get_or_create_global_step()
    decay_lr = clr(
      step = global_step,
      initial_learning_rate = 1e-4,
      maximal_learning_rate = 8e-4,
      step_size = 2*900228//params['batch_size'],)
    
    optim = tf.train.AdamOptimizer(decay_lr)
    train_op = optim.minimize(
      loss_op, global_step=tf.train.get_or_create_global_step())
    
    hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
    
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      train_op=train_op,
                                      training_hooks=[hook],)
  
  
  if mode == tf.estimator.ModeKeys.EVAL:
    mae_op = tf.metrics.mean_absolute_error(labels=labels,
                                            predictions=predictions)
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      eval_metric_ops={'mae': mae_op})

# %%
params = {
    'log_path': '../log/dnn_softmax_clr.txt',
    'model_dir': '../model/dnn_softmax_clr',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'user_id_size': 6040,
    'user_age_size': 7,
    'user_job_size': 21,
    'user_gender_size': 2,
    'movie_id_size': 3691,
    'movie_title_size': 3702,
    'small_embed_dim': 30,
    'large_embed_dim': 200,
    'hidden_dim': 200,
    'activation': tf.nn.elu,
    'kernel_size': 3,
    'dropout_rate': 0.2,
    'lr': 3e-4,
    'num_patience': 7,
    'buffer_size': 200000,
    'batch_size': 256,
}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
config = tf.estimator.RunConfig(
  save_checkpoints_steps=900228//params['batch_size']+1,
  keep_checkpoint_max=3)

estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=config,
  params=params)

best_mae = 10000.
count = 0
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  mae = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['mae']
  logger.info("MAE: {:.3f}".format(mae))

  if mae < best_mae:
    best_mae = mae
    count = 0
  else:
    count += 1
  logger.info("Best MAE: {:.3f}".format(best_mae))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../model/dnn_softmax_clr', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 3517, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff7e1970cf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-6-c59d8b077104>:73: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From <ipython-input-6-c59d8b077104>:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:271: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-6-c59d8b077104>:90: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From <ipython-input-6-c59d8b077104>:100: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From <ipython-input-6-c59d8b077104>:127: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.6565199, step = 0
# INFO:tensorflow:lr = 1e-04
# INFO:tensorflow:global_step/sec: 15.3157
# INFO:tensorflow:loss = 1.451543, step = 100 (6.534 sec)
# INFO:tensorflow:lr = 0.00010995308 (6.535 sec)
# INFO:tensorflow:global_step/sec: 15.7943
# INFO:tensorflow:loss = 1.4737172, step = 200 (6.331 sec)
# INFO:tensorflow:lr = 0.00011990616 (6.331 sec)
# INFO:tensorflow:global_step/sec: 15.9464
# INFO:tensorflow:loss = 1.4462236, step = 300 (6.273 sec)
# INFO:tensorflow:lr = 0.00012985924 (6.271 sec)
# INFO:tensorflow:global_step/sec: 15.7115
# INFO:tensorflow:loss = 1.3942164, step = 400 (6.365 sec)
# INFO:tensorflow:lr = 0.00013981233 (6.364 sec)
# INFO:tensorflow:global_step/sec: 15.9141
# INFO:tensorflow:loss = 1.2873437, step = 500 (6.284 sec)
# INFO:tensorflow:lr = 0.0001497654 (6.289 sec)
# INFO:tensorflow:global_step/sec: 16.0846
# INFO:tensorflow:loss = 1.2879729, step = 600 (6.215 sec)
# INFO:tensorflow:lr = 0.00015971849 (6.211 sec)
# INFO:tensorflow:global_step/sec: 16.1584
# INFO:tensorflow:loss = 1.353726, step = 700 (6.191 sec)
# INFO:tensorflow:lr = 0.00016967156 (6.190 sec)
# INFO:tensorflow:global_step/sec: 15.5728
# INFO:tensorflow:loss = 1.2740396, step = 800 (6.421 sec)
# INFO:tensorflow:lr = 0.0001796246 (6.421 sec)
# INFO:tensorflow:global_step/sec: 15.4645
# INFO:tensorflow:loss = 1.3048044, step = 900 (6.467 sec)
# INFO:tensorflow:lr = 0.0001895777 (6.466 sec)
# INFO:tensorflow:global_step/sec: 15.8667
# INFO:tensorflow:loss = 1.3035432, step = 1000 (6.302 sec)
# INFO:tensorflow:lr = 0.00019953077 (6.303 sec)
# INFO:tensorflow:global_step/sec: 16.1091
# INFO:tensorflow:loss = 1.2529107, step = 1100 (6.210 sec)
# INFO:tensorflow:lr = 0.00020948384 (6.212 sec)
# INFO:tensorflow:global_step/sec: 16.0358
# INFO:tensorflow:loss = 1.2211047, step = 1200 (6.235 sec)
# INFO:tensorflow:lr = 0.00021943693 (6.232 sec)
# INFO:tensorflow:global_step/sec: 15.9369
# INFO:tensorflow:loss = 1.2079461, step = 1300 (6.274 sec)
# INFO:tensorflow:lr = 0.00022939002 (6.275 sec)
# INFO:tensorflow:global_step/sec: 15.8955
# INFO:tensorflow:loss = 1.2401764, step = 1400 (6.291 sec)
# INFO:tensorflow:lr = 0.00023934309 (6.293 sec)
# INFO:tensorflow:global_step/sec: 15.946
# INFO:tensorflow:loss = 1.3438983, step = 1500 (6.271 sec)
# INFO:tensorflow:lr = 0.00024929616 (6.272 sec)
# INFO:tensorflow:global_step/sec: 16.0443
# INFO:tensorflow:loss = 1.2214627, step = 1600 (6.233 sec)
# INFO:tensorflow:lr = 0.00025924927 (6.231 sec)
# INFO:tensorflow:global_step/sec: 16.0413
# INFO:tensorflow:loss = 1.2242131, step = 1700 (6.236 sec)
# INFO:tensorflow:lr = 0.00026920234 (6.238 sec)
# INFO:tensorflow:global_step/sec: 15.8428
# INFO:tensorflow:loss = 1.2131566, step = 1800 (6.311 sec)
# INFO:tensorflow:lr = 0.00027915539 (6.306 sec)
# INFO:tensorflow:global_step/sec: 15.7288
# INFO:tensorflow:loss = 1.2848383, step = 1900 (6.357 sec)
# INFO:tensorflow:lr = 0.00028910846 (6.357 sec)
# INFO:tensorflow:global_step/sec: 15.9802
# INFO:tensorflow:loss = 1.237076, step = 2000 (6.257 sec)
# INFO:tensorflow:lr = 0.00029906153 (6.257 sec)
# INFO:tensorflow:global_step/sec: 15.8059
# INFO:tensorflow:loss = 1.2464056, step = 2100 (6.327 sec)
# INFO:tensorflow:lr = 0.00030901463 (6.328 sec)
# INFO:tensorflow:global_step/sec: 15.5037
# INFO:tensorflow:loss = 1.2324874, step = 2200 (6.448 sec)
# INFO:tensorflow:lr = 0.0003189677 (6.447 sec)
# INFO:tensorflow:global_step/sec: 15.9883
# INFO:tensorflow:loss = 1.2340199, step = 2300 (6.258 sec)
# INFO:tensorflow:lr = 0.00032892078 (6.260 sec)
# INFO:tensorflow:global_step/sec: 15.9051
# INFO:tensorflow:loss = 1.2716018, step = 2400 (6.288 sec)
# INFO:tensorflow:lr = 0.00033887386 (6.291 sec)
# INFO:tensorflow:global_step/sec: 15.9225
# INFO:tensorflow:loss = 1.2105863, step = 2500 (6.278 sec)
# INFO:tensorflow:lr = 0.00034882696 (6.276 sec)
# INFO:tensorflow:global_step/sec: 16.1401
# INFO:tensorflow:loss = 1.2371205, step = 2600 (6.196 sec)
# INFO:tensorflow:lr = 0.00035878003 (6.194 sec)
# INFO:tensorflow:global_step/sec: 15.8267
# INFO:tensorflow:loss = 1.2449975, step = 2700 (6.318 sec)
# INFO:tensorflow:lr = 0.0003687331 (6.321 sec)
# INFO:tensorflow:global_step/sec: 36.5009
# INFO:tensorflow:loss = 1.2618676, step = 2800 (2.738 sec)
# INFO:tensorflow:lr = 0.0003786862 (2.735 sec)
# INFO:tensorflow:global_step/sec: 112.639
# INFO:tensorflow:loss = 1.2339553, step = 2900 (0.888 sec)
# INFO:tensorflow:lr = 0.00038863928 (0.888 sec)
# INFO:tensorflow:global_step/sec: 116.753
# INFO:tensorflow:loss = 1.2133431, step = 3000 (0.856 sec)
# INFO:tensorflow:lr = 0.00039859235 (0.855 sec)
# INFO:tensorflow:global_step/sec: 114.251
# INFO:tensorflow:loss = 1.1781137, step = 3100 (0.878 sec)
# INFO:tensorflow:lr = 0.00040854543 (0.879 sec)
# INFO:tensorflow:global_step/sec: 115.05
# INFO:tensorflow:loss = 1.246277, step = 3200 (0.867 sec)
# INFO:tensorflow:lr = 0.00041849853 (0.866 sec)
# INFO:tensorflow:global_step/sec: 115.259
# INFO:tensorflow:loss = 1.2288948, step = 3300 (0.865 sec)
# INFO:tensorflow:lr = 0.0004284516 (0.866 sec)
# INFO:tensorflow:global_step/sec: 112.905
# INFO:tensorflow:loss = 1.2046522, step = 3400 (0.888 sec)
# INFO:tensorflow:lr = 0.00043840468 (0.888 sec)
# INFO:tensorflow:global_step/sec: 113.945
# INFO:tensorflow:loss = 1.2478576, step = 3500 (0.877 sec)
# INFO:tensorflow:lr = 0.00044835778 (0.878 sec)
# INFO:tensorflow:Saving checkpoints for 3517 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.397657.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T02:47:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-3517
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-02:48:22
# INFO:tensorflow:Saving dict for global step 3517: global_step = 3517, loss = 1.220053, mae = 0.7114652
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3517: ../model/dnn_softmax_clr/model.ckpt-3517
# INFO:tensorflow:MAE: 0.711
# INFO:tensorflow:Best MAE: 0.711
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-3517
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3517 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.209908, step = 3517
# INFO:tensorflow:lr = 0.00045004976
# INFO:tensorflow:global_step/sec: 15.7133
# INFO:tensorflow:loss = 1.1909747, step = 3617 (6.370 sec)
# INFO:tensorflow:lr = 0.00046000286 (6.369 sec)
# INFO:tensorflow:global_step/sec: 16.299
# INFO:tensorflow:loss = 1.2418578, step = 3717 (6.135 sec)
# INFO:tensorflow:lr = 0.00046995594 (6.135 sec)
# INFO:tensorflow:global_step/sec: 16.0697
# INFO:tensorflow:loss = 1.1515782, step = 3817 (6.221 sec)
# INFO:tensorflow:lr = 0.000479909 (6.221 sec)
# INFO:tensorflow:global_step/sec: 16.0549
# INFO:tensorflow:loss = 1.1776723, step = 3917 (6.229 sec)
# INFO:tensorflow:lr = 0.00048986205 (6.229 sec)
# INFO:tensorflow:global_step/sec: 16.0915
# INFO:tensorflow:loss = 1.1993331, step = 4017 (6.215 sec)
# INFO:tensorflow:lr = 0.00049981516 (6.215 sec)
# INFO:tensorflow:global_step/sec: 15.9137
# INFO:tensorflow:loss = 1.2238498, step = 4117 (6.285 sec)
# INFO:tensorflow:lr = 0.0005097682 (6.284 sec)
# INFO:tensorflow:global_step/sec: 15.7868
# INFO:tensorflow:loss = 1.2078204, step = 4217 (6.333 sec)
# INFO:tensorflow:lr = 0.0005197213 (6.334 sec)
# INFO:tensorflow:global_step/sec: 15.6728
# INFO:tensorflow:loss = 1.2217664, step = 4317 (6.380 sec)
# INFO:tensorflow:lr = 0.00052967435 (6.382 sec)
# INFO:tensorflow:global_step/sec: 15.8727
# INFO:tensorflow:loss = 1.197035, step = 4417 (6.302 sec)
# INFO:tensorflow:lr = 0.00053962745 (6.303 sec)
# INFO:tensorflow:global_step/sec: 15.8104
# INFO:tensorflow:loss = 1.2702578, step = 4517 (6.325 sec)
# INFO:tensorflow:lr = 0.00054958055 (6.325 sec)
# INFO:tensorflow:global_step/sec: 15.9313
# INFO:tensorflow:loss = 1.2418152, step = 4617 (6.274 sec)
# INFO:tensorflow:lr = 0.0005595336 (6.271 sec)
# INFO:tensorflow:global_step/sec: 16.1343
# INFO:tensorflow:loss = 1.2699522, step = 4717 (6.200 sec)
# INFO:tensorflow:lr = 0.0005694867 (6.200 sec)
# INFO:tensorflow:global_step/sec: 16.1773
# INFO:tensorflow:loss = 1.1443623, step = 4817 (6.183 sec)
# INFO:tensorflow:lr = 0.00057943974 (6.184 sec)
# INFO:tensorflow:global_step/sec: 16.1458
# INFO:tensorflow:loss = 1.1907216, step = 4917 (6.192 sec)
# INFO:tensorflow:lr = 0.00058939285 (6.194 sec)
# INFO:tensorflow:global_step/sec: 16.1455
# INFO:tensorflow:loss = 1.2196422, step = 5017 (6.193 sec)
# INFO:tensorflow:lr = 0.00059934595 (6.190 sec)
# INFO:tensorflow:global_step/sec: 16.178
# INFO:tensorflow:loss = 1.1908408, step = 5117 (6.183 sec)
# INFO:tensorflow:lr = 0.00060929905 (6.184 sec)
# INFO:tensorflow:global_step/sec: 16.1774
# INFO:tensorflow:loss = 1.3037195, step = 5217 (6.178 sec)
# INFO:tensorflow:lr = 0.0006192521 (6.180 sec)
# INFO:tensorflow:global_step/sec: 16.1618
# INFO:tensorflow:loss = 1.2224964, step = 5317 (6.191 sec)
# INFO:tensorflow:lr = 0.0006292052 (6.190 sec)
# INFO:tensorflow:global_step/sec: 16.5769
# INFO:tensorflow:loss = 1.1871779, step = 5417 (6.032 sec)
# INFO:tensorflow:lr = 0.00063915824 (6.034 sec)
# INFO:tensorflow:global_step/sec: 16.3031
# INFO:tensorflow:loss = 1.1847621, step = 5517 (6.133 sec)
# INFO:tensorflow:lr = 0.0006491113 (6.131 sec)
# INFO:tensorflow:global_step/sec: 16.3585
# INFO:tensorflow:loss = 1.2421546, step = 5617 (6.114 sec)
# INFO:tensorflow:lr = 0.0006590644 (6.114 sec)
# INFO:tensorflow:global_step/sec: 16.7664
# INFO:tensorflow:loss = 1.1518705, step = 5717 (5.964 sec)
# INFO:tensorflow:lr = 0.0006690175 (5.966 sec)
# INFO:tensorflow:global_step/sec: 16.6873
# INFO:tensorflow:loss = 1.227827, step = 5817 (5.991 sec)
# INFO:tensorflow:lr = 0.00067897054 (5.989 sec)
# INFO:tensorflow:global_step/sec: 16.6654
# INFO:tensorflow:loss = 1.2548192, step = 5917 (6.001 sec)
# INFO:tensorflow:lr = 0.00068892364 (6.000 sec)
# INFO:tensorflow:global_step/sec: 16.7595
# INFO:tensorflow:loss = 1.1902227, step = 6017 (5.968 sec)
# INFO:tensorflow:lr = 0.00069887674 (5.969 sec)
# INFO:tensorflow:global_step/sec: 16.7409
# INFO:tensorflow:loss = 1.2127402, step = 6117 (5.974 sec)
# INFO:tensorflow:lr = 0.0007088298 (5.976 sec)
# INFO:tensorflow:global_step/sec: 16.8016
# INFO:tensorflow:loss = 1.1048461, step = 6217 (5.951 sec)
# INFO:tensorflow:lr = 0.0007187829 (5.949 sec)
# INFO:tensorflow:global_step/sec: 38.0346
# INFO:tensorflow:loss = 1.1855109, step = 6317 (2.628 sec)
# INFO:tensorflow:lr = 0.00072873593 (2.628 sec)
# INFO:tensorflow:global_step/sec: 119.398
# INFO:tensorflow:loss = 1.2356597, step = 6417 (0.836 sec)
# INFO:tensorflow:lr = 0.00073868904 (0.836 sec)
# INFO:tensorflow:global_step/sec: 123.096
# INFO:tensorflow:loss = 1.2522328, step = 6517 (0.813 sec)
# INFO:tensorflow:lr = 0.00074864214 (0.812 sec)
# INFO:tensorflow:global_step/sec: 122.406
# INFO:tensorflow:loss = 1.2254118, step = 6617 (0.817 sec)
# INFO:tensorflow:lr = 0.0007585952 (0.818 sec)
# INFO:tensorflow:global_step/sec: 117.909
# INFO:tensorflow:loss = 1.2344044, step = 6717 (0.848 sec)
# INFO:tensorflow:lr = 0.0007685483 (0.847 sec)
# INFO:tensorflow:global_step/sec: 118.333
# INFO:tensorflow:loss = 1.1489767, step = 6817 (0.844 sec)
# INFO:tensorflow:lr = 0.0007785014 (0.844 sec)
# INFO:tensorflow:global_step/sec: 119.946
# INFO:tensorflow:loss = 1.1688302, step = 6917 (0.833 sec)
# INFO:tensorflow:lr = 0.00078845443 (0.834 sec)
# INFO:tensorflow:global_step/sec: 120.84
# INFO:tensorflow:loss = 1.2088609, step = 7017 (0.828 sec)
# INFO:tensorflow:lr = 0.0007984075 (0.827 sec)
# INFO:tensorflow:Saving checkpoints for 7034 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1919218.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T02:52:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-7034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-02:52:28
# INFO:tensorflow:Saving dict for global step 7034: global_step = 7034, loss = 1.1828176, mae = 0.68013924
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7034: ../model/dnn_softmax_clr/model.ckpt-7034
# INFO:tensorflow:MAE: 0.680
# INFO:tensorflow:Best MAE: 0.680
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-7034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7034 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.1263044, step = 7034
# INFO:tensorflow:lr = 0.00079990044
# INFO:tensorflow:global_step/sec: 15.4503
# INFO:tensorflow:loss = 1.1907849, step = 7134 (6.480 sec)
# INFO:tensorflow:lr = 0.00078994734 (6.477 sec)
# INFO:tensorflow:global_step/sec: 16.263
# INFO:tensorflow:loss = 1.1838336, step = 7234 (6.147 sec)
# INFO:tensorflow:lr = 0.00077999424 (6.147 sec)
# INFO:tensorflow:global_step/sec: 16.1944
# INFO:tensorflow:loss = 1.1671214, step = 7334 (6.174 sec)
# INFO:tensorflow:lr = 0.0007700412 (6.177 sec)
# INFO:tensorflow:global_step/sec: 16.0856
# INFO:tensorflow:loss = 1.1894524, step = 7434 (6.217 sec)
# INFO:tensorflow:lr = 0.0007600881 (6.216 sec)
# INFO:tensorflow:global_step/sec: 16.1333
# INFO:tensorflow:loss = 1.2351276, step = 7534 (6.199 sec)
# INFO:tensorflow:lr = 0.00075013505 (6.200 sec)
# INFO:tensorflow:global_step/sec: 15.8492
# INFO:tensorflow:loss = 1.1855757, step = 7634 (6.310 sec)
# INFO:tensorflow:lr = 0.00074018195 (6.311 sec)
# INFO:tensorflow:global_step/sec: 15.374
# INFO:tensorflow:loss = 1.1601101, step = 7734 (6.503 sec)
# INFO:tensorflow:lr = 0.00073022884 (6.501 sec)
# INFO:tensorflow:global_step/sec: 14.2242
# INFO:tensorflow:loss = 1.1563671, step = 7834 (7.031 sec)
# INFO:tensorflow:lr = 0.0007202758 (7.030 sec)
# INFO:tensorflow:global_step/sec: 15.1945
# INFO:tensorflow:loss = 1.1775467, step = 7934 (6.584 sec)
# INFO:tensorflow:lr = 0.0007103227 (6.586 sec)
# INFO:tensorflow:global_step/sec: 15.8697
# INFO:tensorflow:loss = 1.1980264, step = 8034 (6.296 sec)
# INFO:tensorflow:lr = 0.0007003696 (6.293 sec)
# INFO:tensorflow:global_step/sec: 15.7564
# INFO:tensorflow:loss = 1.1174866, step = 8134 (6.350 sec)
# INFO:tensorflow:lr = 0.00069041655 (6.353 sec)
# INFO:tensorflow:global_step/sec: 15.8687
# INFO:tensorflow:loss = 1.1714509, step = 8234 (6.300 sec)
# INFO:tensorflow:lr = 0.00068046356 (6.298 sec)
# INFO:tensorflow:global_step/sec: 15.8049
# INFO:tensorflow:loss = 1.2272593, step = 8334 (6.327 sec)
# INFO:tensorflow:lr = 0.00067051046 (6.327 sec)
# INFO:tensorflow:global_step/sec: 15.9121
# INFO:tensorflow:loss = 1.2373205, step = 8434 (6.286 sec)
# INFO:tensorflow:lr = 0.00066055736 (6.287 sec)
# INFO:tensorflow:global_step/sec: 15.8107
# INFO:tensorflow:loss = 1.1626667, step = 8534 (6.329 sec)
# INFO:tensorflow:lr = 0.0006506043 (6.329 sec)
# INFO:tensorflow:global_step/sec: 15.5082
# INFO:tensorflow:loss = 1.1530749, step = 8634 (6.442 sec)
# INFO:tensorflow:lr = 0.0006406512 (6.442 sec)
# INFO:tensorflow:global_step/sec: 15.7939
# INFO:tensorflow:loss = 1.1594775, step = 8734 (6.335 sec)
# INFO:tensorflow:lr = 0.0006306981 (6.337 sec)
# INFO:tensorflow:global_step/sec: 15.6739
# INFO:tensorflow:loss = 1.1259141, step = 8834 (6.377 sec)
# INFO:tensorflow:lr = 0.00062074506 (6.374 sec)
# INFO:tensorflow:global_step/sec: 15.6997
# INFO:tensorflow:loss = 1.1868529, step = 8934 (6.371 sec)
# INFO:tensorflow:lr = 0.00061079196 (6.372 sec)
# INFO:tensorflow:global_step/sec: 15.2085
# INFO:tensorflow:loss = 1.1466955, step = 9034 (6.574 sec)
# INFO:tensorflow:lr = 0.00060083886 (6.575 sec)
# INFO:tensorflow:global_step/sec: 15.7602
# INFO:tensorflow:loss = 1.1876425, step = 9134 (6.345 sec)
# INFO:tensorflow:lr = 0.0005908858 (6.344 sec)
# INFO:tensorflow:global_step/sec: 16.151
# INFO:tensorflow:loss = 1.169549, step = 9234 (6.192 sec)
# INFO:tensorflow:lr = 0.0005809327 (6.195 sec)
# INFO:tensorflow:global_step/sec: 16.0387
# INFO:tensorflow:loss = 1.1290791, step = 9334 (6.235 sec)
# INFO:tensorflow:lr = 0.0005709796 (6.232 sec)
# INFO:tensorflow:global_step/sec: 16.1067
# INFO:tensorflow:loss = 1.123405, step = 9434 (6.208 sec)
# INFO:tensorflow:lr = 0.00056102657 (6.209 sec)
# INFO:tensorflow:global_step/sec: 15.846
# INFO:tensorflow:loss = 1.131978, step = 9534 (6.317 sec)
# INFO:tensorflow:lr = 0.00055107346 (6.316 sec)
# INFO:tensorflow:global_step/sec: 15.927
# INFO:tensorflow:loss = 1.2486008, step = 9634 (6.273 sec)
# INFO:tensorflow:lr = 0.00054112036 (6.273 sec)
# INFO:tensorflow:global_step/sec: 15.9929
# INFO:tensorflow:loss = 1.1781888, step = 9734 (6.254 sec)
# INFO:tensorflow:lr = 0.0005311673 (6.254 sec)
# INFO:tensorflow:global_step/sec: 36.8977
# INFO:tensorflow:loss = 1.1320149, step = 9834 (2.708 sec)
# INFO:tensorflow:lr = 0.0005212142 (2.708 sec)
# INFO:tensorflow:global_step/sec: 115.884
# INFO:tensorflow:loss = 1.1644022, step = 9934 (0.862 sec)
# INFO:tensorflow:lr = 0.00051126117 (0.862 sec)
# INFO:tensorflow:global_step/sec: 117.8
# INFO:tensorflow:loss = 1.1601653, step = 10034 (0.849 sec)
# INFO:tensorflow:lr = 0.00050130807 (0.849 sec)
# INFO:tensorflow:global_step/sec: 116.539
# INFO:tensorflow:loss = 1.2071532, step = 10134 (0.858 sec)
# INFO:tensorflow:lr = 0.00049135496 (0.859 sec)
# INFO:tensorflow:global_step/sec: 118.531
# INFO:tensorflow:loss = 1.1918544, step = 10234 (0.844 sec)
# INFO:tensorflow:lr = 0.00048140192 (0.844 sec)
# INFO:tensorflow:global_step/sec: 113.046
# INFO:tensorflow:loss = 1.1327696, step = 10334 (0.882 sec)
# INFO:tensorflow:lr = 0.00047144882 (0.882 sec)
# INFO:tensorflow:global_step/sec: 118.166
# INFO:tensorflow:loss = 1.0633729, step = 10434 (0.848 sec)
# INFO:tensorflow:lr = 0.00046149574 (0.850 sec)
# INFO:tensorflow:global_step/sec: 115.717
# INFO:tensorflow:loss = 1.1714326, step = 10534 (0.865 sec)
# INFO:tensorflow:lr = 0.00045154267 (0.865 sec)
# INFO:tensorflow:Saving checkpoints for 10551 into ../model/dnn_softmax_clr/model.ckpt.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 1.1735085.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T02:56:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-10551
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-02:56:37
# INFO:tensorflow:Saving dict for global step 10551: global_step = 10551, loss = 1.1525156, mae = 0.6494034
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10551: ../model/dnn_softmax_clr/model.ckpt-10551
# INFO:tensorflow:MAE: 0.649
# INFO:tensorflow:Best MAE: 0.649
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-10551
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10551 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.1598414, step = 10551
# INFO:tensorflow:lr = 0.00044985072
# INFO:tensorflow:global_step/sec: 15.4486
# INFO:tensorflow:loss = 1.1181126, step = 10651 (6.485 sec)
# INFO:tensorflow:lr = 0.00043989762 (6.484 sec)
# INFO:tensorflow:global_step/sec: 16.2524
# INFO:tensorflow:loss = 1.1655163, step = 10751 (6.148 sec)
# INFO:tensorflow:lr = 0.00042994454 (6.150 sec)
# INFO:tensorflow:global_step/sec: 16.2035
# INFO:tensorflow:loss = 1.0747917, step = 10851 (6.170 sec)
# INFO:tensorflow:lr = 0.00041999147 (6.168 sec)
# INFO:tensorflow:global_step/sec: 15.9681
# INFO:tensorflow:loss = 1.1308645, step = 10951 (6.265 sec)
# INFO:tensorflow:lr = 0.0004100384 (6.264 sec)
# INFO:tensorflow:global_step/sec: 15.3319
# INFO:tensorflow:loss = 1.137799, step = 11051 (6.521 sec)
# INFO:tensorflow:lr = 0.0004000853 (6.521 sec)
# INFO:tensorflow:global_step/sec: 15.6063
# INFO:tensorflow:loss = 1.1398925, step = 11151 (6.407 sec)
# INFO:tensorflow:lr = 0.00039013222 (6.410 sec)
# INFO:tensorflow:global_step/sec: 15.3728
# INFO:tensorflow:loss = 1.0606174, step = 11251 (6.507 sec)
# INFO:tensorflow:lr = 0.00038017915 (6.504 sec)
# INFO:tensorflow:global_step/sec: 15.4095
# INFO:tensorflow:loss = 1.1295415, step = 11351 (6.489 sec)
# INFO:tensorflow:lr = 0.00037022604 (6.491 sec)
# INFO:tensorflow:global_step/sec: 15.6447
# INFO:tensorflow:loss = 1.1049556, step = 11451 (6.390 sec)
# INFO:tensorflow:lr = 0.00036027297 (6.388 sec)
# INFO:tensorflow:global_step/sec: 15.2845
# INFO:tensorflow:loss = 1.0950963, step = 11551 (6.546 sec)
# INFO:tensorflow:lr = 0.0003503199 (6.551 sec)
# INFO:tensorflow:global_step/sec: 15.1405
# INFO:tensorflow:loss = 1.11607, step = 11651 (6.605 sec)
# INFO:tensorflow:lr = 0.0003403668 (6.599 sec)
# INFO:tensorflow:global_step/sec: 15.5591
# INFO:tensorflow:loss = 1.0990576, step = 11751 (6.430 sec)
# INFO:tensorflow:lr = 0.00033041372 (6.436 sec)
# INFO:tensorflow:global_step/sec: 15.2362
# INFO:tensorflow:loss = 1.0734537, step = 11851 (6.559 sec)
# INFO:tensorflow:lr = 0.00032046065 (6.553 sec)
# INFO:tensorflow:global_step/sec: 15.3264
# INFO:tensorflow:loss = 1.1384948, step = 11951 (6.522 sec)
# INFO:tensorflow:lr = 0.00031050757 (6.527 sec)
# INFO:tensorflow:global_step/sec: 15.565
# INFO:tensorflow:loss = 1.0227987, step = 12051 (6.426 sec)
# INFO:tensorflow:lr = 0.00030055447 (6.423 sec)
# INFO:tensorflow:global_step/sec: 15.2133
# INFO:tensorflow:loss = 1.1786231, step = 12151 (6.576 sec)
# INFO:tensorflow:lr = 0.0002906014 (6.578 sec)
# INFO:tensorflow:global_step/sec: 13.9432
# INFO:tensorflow:loss = 1.130663, step = 12251 (7.172 sec)
# INFO:tensorflow:lr = 0.00028064832 (7.169 sec)
# INFO:tensorflow:global_step/sec: 14.3062
# INFO:tensorflow:loss = 1.0714781, step = 12351 (6.988 sec)
# INFO:tensorflow:lr = 0.00027069525 (6.989 sec)
# INFO:tensorflow:global_step/sec: 15.3918
# INFO:tensorflow:loss = 1.1409591, step = 12451 (6.495 sec)
# INFO:tensorflow:lr = 0.00026074215 (6.495 sec)
# INFO:tensorflow:global_step/sec: 15.5903
# INFO:tensorflow:loss = 1.0685232, step = 12551 (6.417 sec)
# INFO:tensorflow:lr = 0.00025078907 (6.416 sec)
# INFO:tensorflow:global_step/sec: 15.3018
# INFO:tensorflow:loss = 1.100852, step = 12651 (6.537 sec)
# INFO:tensorflow:lr = 0.000240836 (6.537 sec)
# INFO:tensorflow:global_step/sec: 15.6915
# INFO:tensorflow:loss = 1.1175637, step = 12751 (6.373 sec)
# INFO:tensorflow:lr = 0.0002308829 (6.371 sec)
# INFO:tensorflow:global_step/sec: 15.5676
# INFO:tensorflow:loss = 1.0773243, step = 12851 (6.439 sec)
# INFO:tensorflow:lr = 0.00022092983 (6.438 sec)
# INFO:tensorflow:global_step/sec: 15.5968
# INFO:tensorflow:loss = 1.1102033, step = 12951 (6.395 sec)
# INFO:tensorflow:lr = 0.00021097675 (6.396 sec)
# INFO:tensorflow:global_step/sec: 15.4219
# INFO:tensorflow:loss = 1.1420697, step = 13051 (6.485 sec)
# INFO:tensorflow:lr = 0.00020102375 (6.484 sec)
# INFO:tensorflow:global_step/sec: 15.3782
# INFO:tensorflow:loss = 1.1385595, step = 13151 (6.499 sec)
# INFO:tensorflow:lr = 0.00019107066 (6.504 sec)
# INFO:tensorflow:global_step/sec: 15.5325
# INFO:tensorflow:loss = 1.1633699, step = 13251 (6.441 sec)
# INFO:tensorflow:lr = 0.00018111759 (6.436 sec)
# INFO:tensorflow:global_step/sec: 36.3855
# INFO:tensorflow:loss = 1.1907351, step = 13351 (2.745 sec)
# INFO:tensorflow:lr = 0.00017116452 (2.745 sec)
# INFO:tensorflow:global_step/sec: 112.048
# INFO:tensorflow:loss = 1.1552234, step = 13451 (0.892 sec)
# INFO:tensorflow:lr = 0.00016121143 (0.893 sec)
# INFO:tensorflow:global_step/sec: 114.619
# INFO:tensorflow:loss = 1.142666, step = 13551 (0.874 sec)
# INFO:tensorflow:lr = 0.00015125834 (0.873 sec)
# INFO:tensorflow:global_step/sec: 117.046
# INFO:tensorflow:loss = 1.1066272, step = 13651 (0.854 sec)
# INFO:tensorflow:lr = 0.00014130527 (0.855 sec)
# INFO:tensorflow:global_step/sec: 117.954
# INFO:tensorflow:loss = 1.0954127, step = 13751 (0.848 sec)
# INFO:tensorflow:lr = 0.00013135218 (0.847 sec)
# INFO:tensorflow:global_step/sec: 110.363
# INFO:tensorflow:loss = 1.1730179, step = 13851 (0.907 sec)
# INFO:tensorflow:lr = 0.000121399105 (0.908 sec)
# INFO:tensorflow:global_step/sec: 106.031
# INFO:tensorflow:loss = 1.1590263, step = 13951 (0.942 sec)
# INFO:tensorflow:lr = 0.00011144602 (0.942 sec)
# INFO:tensorflow:global_step/sec: 106.286
# INFO:tensorflow:loss = 1.0552065, step = 14051 (0.942 sec)
# INFO:tensorflow:lr = 0.00010149294 (0.942 sec)
# INFO:tensorflow:Saving checkpoints for 14068 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0032803.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T03:00:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-14068
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-03:00:52
# INFO:tensorflow:Saving dict for global step 14068: global_step = 14068, loss = 1.1421142, mae = 0.6358508
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14068: ../model/dnn_softmax_clr/model.ckpt-14068
# INFO:tensorflow:MAE: 0.636
# INFO:tensorflow:Best MAE: 0.636
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-14068
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 14068 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.0430522, step = 14068
# INFO:tensorflow:lr = 0.000100199104
# INFO:tensorflow:global_step/sec: 15.2814
# INFO:tensorflow:loss = 1.1725546, step = 14168 (6.549 sec)
# INFO:tensorflow:lr = 0.0001101521 (6.548 sec)
# INFO:tensorflow:global_step/sec: 15.787
# INFO:tensorflow:loss = 1.1528658, step = 14268 (6.343 sec)
# INFO:tensorflow:lr = 0.000120105266 (6.344 sec)
# INFO:tensorflow:global_step/sec: 15.5499
# INFO:tensorflow:loss = 1.0497981, step = 14368 (6.422 sec)
# INFO:tensorflow:lr = 0.00013005827 (6.420 sec)
# INFO:tensorflow:global_step/sec: 15.5866
# INFO:tensorflow:loss = 1.054546, step = 14468 (6.417 sec)
# INFO:tensorflow:lr = 0.00014001143 (6.416 sec)
# INFO:tensorflow:global_step/sec: 15.7049
# INFO:tensorflow:loss = 1.0821885, step = 14568 (6.366 sec)
# INFO:tensorflow:lr = 0.00014996443 (6.367 sec)
# INFO:tensorflow:global_step/sec: 15.6075
# INFO:tensorflow:loss = 1.0694643, step = 14668 (6.409 sec)
# INFO:tensorflow:lr = 0.00015991759 (6.407 sec)
# INFO:tensorflow:global_step/sec: 15.6353
# INFO:tensorflow:loss = 1.1087406, step = 14768 (6.393 sec)
# INFO:tensorflow:lr = 0.00016987059 (6.393 sec)
# INFO:tensorflow:global_step/sec: 15.6865
# INFO:tensorflow:loss = 1.0289742, step = 14868 (6.376 sec)
# INFO:tensorflow:lr = 0.00017982375 (6.378 sec)
# INFO:tensorflow:global_step/sec: 15.6969
# INFO:tensorflow:loss = 1.0381387, step = 14968 (6.370 sec)
# INFO:tensorflow:lr = 0.00018977675 (6.370 sec)
# INFO:tensorflow:global_step/sec: 15.6349
# INFO:tensorflow:loss = 1.121661, step = 15068 (6.396 sec)
# INFO:tensorflow:lr = 0.00019972991 (6.394 sec)
# INFO:tensorflow:global_step/sec: 15.5915
# INFO:tensorflow:loss = 1.0560182, step = 15168 (6.416 sec)
# INFO:tensorflow:lr = 0.00020968291 (6.417 sec)
# INFO:tensorflow:global_step/sec: 15.6737
# INFO:tensorflow:loss = 1.0776227, step = 15268 (6.380 sec)
# INFO:tensorflow:lr = 0.00021963607 (6.379 sec)
# INFO:tensorflow:global_step/sec: 15.6238
# INFO:tensorflow:loss = 1.0722224, step = 15368 (6.402 sec)
# INFO:tensorflow:lr = 0.00022958909 (6.404 sec)
# INFO:tensorflow:global_step/sec: 15.5939
# INFO:tensorflow:loss = 1.0605712, step = 15468 (6.409 sec)
# INFO:tensorflow:lr = 0.00023954225 (6.408 sec)
# INFO:tensorflow:global_step/sec: 15.4581
# INFO:tensorflow:loss = 1.1209623, step = 15568 (6.471 sec)
# INFO:tensorflow:lr = 0.00024949524 (6.472 sec)
# INFO:tensorflow:global_step/sec: 15.16
# INFO:tensorflow:loss = 1.1189789, step = 15668 (6.594 sec)
# INFO:tensorflow:lr = 0.0002594484 (6.592 sec)
# INFO:tensorflow:global_step/sec: 15.5457
# INFO:tensorflow:loss = 1.0873302, step = 15768 (6.434 sec)
# INFO:tensorflow:lr = 0.0002694014 (6.434 sec)
# INFO:tensorflow:global_step/sec: 15.8297
# INFO:tensorflow:loss = 1.07945, step = 15868 (6.317 sec)
# INFO:tensorflow:lr = 0.00027935457 (6.316 sec)
# INFO:tensorflow:global_step/sec: 15.8986
# INFO:tensorflow:loss = 1.1117667, step = 15968 (6.289 sec)
# INFO:tensorflow:lr = 0.00028930756 (6.291 sec)
# INFO:tensorflow:global_step/sec: 15.8185
# INFO:tensorflow:loss = 1.1452914, step = 16068 (6.323 sec)
# INFO:tensorflow:lr = 0.00029926072 (6.323 sec)
# INFO:tensorflow:global_step/sec: 15.7882
# INFO:tensorflow:loss = 1.091313, step = 16168 (6.335 sec)
# INFO:tensorflow:lr = 0.00030921373 (6.332 sec)
# INFO:tensorflow:global_step/sec: 15.7823
# INFO:tensorflow:loss = 1.044218, step = 16268 (6.334 sec)
# INFO:tensorflow:lr = 0.0003191669 (6.335 sec)
# INFO:tensorflow:global_step/sec: 15.8939
# INFO:tensorflow:loss = 1.1308454, step = 16368 (6.293 sec)
# INFO:tensorflow:lr = 0.00032911988 (6.294 sec)
# INFO:tensorflow:global_step/sec: 15.7918
# INFO:tensorflow:loss = 1.0516032, step = 16468 (6.329 sec)
# INFO:tensorflow:lr = 0.0003390729 (6.334 sec)
# INFO:tensorflow:global_step/sec: 14.9458
# INFO:tensorflow:loss = 1.0654347, step = 16568 (6.693 sec)
# INFO:tensorflow:lr = 0.00034902606 (6.689 sec)
# INFO:tensorflow:global_step/sec: 14.5683
# INFO:tensorflow:loss = 1.0119327, step = 16668 (6.864 sec)
# INFO:tensorflow:lr = 0.00035897904 (6.864 sec)
# INFO:tensorflow:global_step/sec: 15.2875
# INFO:tensorflow:loss = 1.1463823, step = 16768 (6.540 sec)
# INFO:tensorflow:lr = 0.00036893223 (6.539 sec)
# INFO:tensorflow:global_step/sec: 36.952
# INFO:tensorflow:loss = 1.1369894, step = 16868 (2.705 sec)
# INFO:tensorflow:lr = 0.00037888522 (2.706 sec)
# INFO:tensorflow:global_step/sec: 118.71
# INFO:tensorflow:loss = 1.1228578, step = 16968 (0.842 sec)
# INFO:tensorflow:lr = 0.00038883838 (0.842 sec)
# INFO:tensorflow:global_step/sec: 115.928
# INFO:tensorflow:loss = 1.0923339, step = 17068 (0.864 sec)
# INFO:tensorflow:lr = 0.00039879137 (0.864 sec)
# INFO:tensorflow:global_step/sec: 116.775
# INFO:tensorflow:loss = 1.0548806, step = 17168 (0.855 sec)
# INFO:tensorflow:lr = 0.00040874456 (0.855 sec)
# INFO:tensorflow:global_step/sec: 112.835
# INFO:tensorflow:loss = 1.126117, step = 17268 (0.887 sec)
# INFO:tensorflow:lr = 0.00041869754 (0.887 sec)
# INFO:tensorflow:global_step/sec: 117.388
# INFO:tensorflow:loss = 1.1823964, step = 17368 (0.851 sec)
# INFO:tensorflow:lr = 0.0004286507 (0.850 sec)
# INFO:tensorflow:global_step/sec: 117.479
# INFO:tensorflow:loss = 1.0808951, step = 17468 (0.852 sec)
# INFO:tensorflow:lr = 0.00043860372 (0.852 sec)
# INFO:tensorflow:global_step/sec: 114.32
# INFO:tensorflow:loss = 1.0517536, step = 17568 (0.875 sec)
# INFO:tensorflow:lr = 0.00044855688 (0.875 sec)
# INFO:tensorflow:Saving checkpoints for 17585 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1076463.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T03:04:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-17585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-03:05:04
# INFO:tensorflow:Saving dict for global step 17585: global_step = 17585, loss = 1.1480293, mae = 0.6427621
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17585: ../model/dnn_softmax_clr/model.ckpt-17585
# INFO:tensorflow:MAE: 0.643
# INFO:tensorflow:Best MAE: 0.636
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-17585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17585 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.0349282, step = 17585
# INFO:tensorflow:lr = 0.00045024883
# INFO:tensorflow:global_step/sec: 15.4588
# INFO:tensorflow:loss = 1.1248546, step = 17685 (6.474 sec)
# INFO:tensorflow:lr = 0.000460202 (6.478 sec)
# INFO:tensorflow:global_step/sec: 15.8443
# INFO:tensorflow:loss = 1.069789, step = 17785 (6.312 sec)
# INFO:tensorflow:lr = 0.000470155 (6.310 sec)
# INFO:tensorflow:global_step/sec: 16.0329
# INFO:tensorflow:loss = 1.1072797, step = 17885 (6.238 sec)
# INFO:tensorflow:lr = 0.00048010817 (6.241 sec)
# INFO:tensorflow:global_step/sec: 16.1432
# INFO:tensorflow:loss = 1.0597242, step = 17985 (6.193 sec)
# INFO:tensorflow:lr = 0.0004900611 (6.190 sec)
# INFO:tensorflow:global_step/sec: 16.2218
# INFO:tensorflow:loss = 1.1112552, step = 18085 (6.166 sec)
# INFO:tensorflow:lr = 0.0005000143 (6.164 sec)
# INFO:tensorflow:global_step/sec: 16.0517
# INFO:tensorflow:loss = 1.142361, step = 18185 (6.228 sec)
# INFO:tensorflow:lr = 0.0005099673 (6.228 sec)
# INFO:tensorflow:global_step/sec: 16.2816
# INFO:tensorflow:loss = 1.0751953, step = 18285 (6.142 sec)
# INFO:tensorflow:lr = 0.0005199205 (6.144 sec)
# INFO:tensorflow:global_step/sec: 16.1998
# INFO:tensorflow:loss = 1.1139237, step = 18385 (6.174 sec)
# INFO:tensorflow:lr = 0.0005298735 (6.174 sec)
# INFO:tensorflow:global_step/sec: 16.2367
# INFO:tensorflow:loss = 1.1203978, step = 18485 (6.159 sec)
# INFO:tensorflow:lr = 0.00053982646 (6.158 sec)
# INFO:tensorflow:global_step/sec: 16.2366
# INFO:tensorflow:loss = 1.028404, step = 18585 (6.161 sec)
# INFO:tensorflow:lr = 0.0005497796 (6.161 sec)
# INFO:tensorflow:global_step/sec: 16.1547
# INFO:tensorflow:loss = 1.1171292, step = 18685 (6.187 sec)
# INFO:tensorflow:lr = 0.0005597326 (6.186 sec)
# INFO:tensorflow:global_step/sec: 16.229
# INFO:tensorflow:loss = 1.0653623, step = 18785 (6.162 sec)
# INFO:tensorflow:lr = 0.00056968577 (6.161 sec)
# INFO:tensorflow:global_step/sec: 16.4405
# INFO:tensorflow:loss = 0.9992028, step = 18885 (6.086 sec)
# INFO:tensorflow:lr = 0.0005796388 (6.088 sec)
# INFO:tensorflow:global_step/sec: 16.2947
# INFO:tensorflow:loss = 1.1745139, step = 18985 (6.134 sec)
# INFO:tensorflow:lr = 0.000589592 (6.134 sec)
# INFO:tensorflow:global_step/sec: 15.9004
# INFO:tensorflow:loss = 1.1056571, step = 19085 (6.291 sec)
# INFO:tensorflow:lr = 0.00059954496 (6.289 sec)
# INFO:tensorflow:global_step/sec: 15.9373
# INFO:tensorflow:loss = 1.0260382, step = 19185 (6.273 sec)
# INFO:tensorflow:lr = 0.0006094981 (6.272 sec)
# INFO:tensorflow:global_step/sec: 16.4337
# INFO:tensorflow:loss = 1.0910764, step = 19285 (6.084 sec)
# INFO:tensorflow:lr = 0.0006194511 (6.084 sec)
# INFO:tensorflow:global_step/sec: 16.3712
# INFO:tensorflow:loss = 1.1812325, step = 19385 (6.110 sec)
# INFO:tensorflow:lr = 0.00062940427 (6.113 sec)
# INFO:tensorflow:global_step/sec: 16.2444
# INFO:tensorflow:loss = 1.1550114, step = 19485 (6.156 sec)
# INFO:tensorflow:lr = 0.0006393573 (6.157 sec)
# INFO:tensorflow:global_step/sec: 16.4093
# INFO:tensorflow:loss = 1.1022671, step = 19585 (6.090 sec)
# INFO:tensorflow:lr = 0.0006493105 (6.086 sec)
# INFO:tensorflow:global_step/sec: 16.2885
# INFO:tensorflow:loss = 1.0732185, step = 19685 (6.142 sec)
# INFO:tensorflow:lr = 0.00065926346 (6.142 sec)
# INFO:tensorflow:global_step/sec: 16.4476
# INFO:tensorflow:loss = 1.1576968, step = 19785 (6.081 sec)
# INFO:tensorflow:lr = 0.0006692166 (6.085 sec)
# INFO:tensorflow:global_step/sec: 16.3749
# INFO:tensorflow:loss = 1.0909879, step = 19885 (6.105 sec)
# INFO:tensorflow:lr = 0.0006791696 (6.102 sec)
# INFO:tensorflow:global_step/sec: 16.3966
# ...
# INFO:tensorflow:Saving dict for global step 56272: global_step = 56272, loss = 1.2207843, mae = 0.65013355
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56272: ../model/dnn_softmax_clr/model.ckpt-56272
# INFO:tensorflow:MAE: 0.650
# INFO:tensorflow:Best MAE: 0.628
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-56272
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 56272 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.91757745, step = 56272
# INFO:tensorflow:lr = 0.00010079641
# INFO:tensorflow:global_step/sec: 15.2611
# INFO:tensorflow:loss = 0.9130471, step = 56372 (6.558 sec)
# INFO:tensorflow:lr = 0.00011074924 (6.557 sec)
# INFO:tensorflow:global_step/sec: 16.1395
# INFO:tensorflow:loss = 0.9537958, step = 56472 (6.197 sec)
# INFO:tensorflow:lr = 0.00012070274 (6.199 sec)
# INFO:tensorflow:global_step/sec: 15.8955
# INFO:tensorflow:loss = 0.9180924, step = 56572 (6.292 sec)
# INFO:tensorflow:lr = 0.00013065556 (6.291 sec)
# INFO:tensorflow:global_step/sec: 16.0792
# INFO:tensorflow:loss = 0.92273843, step = 56672 (6.218 sec)
# INFO:tensorflow:lr = 0.0001406084 (6.219 sec)
# INFO:tensorflow:global_step/sec: 15.9926
# INFO:tensorflow:loss = 0.8498336, step = 56772 (6.254 sec)
# INFO:tensorflow:lr = 0.0001505619 (6.253 sec)
# INFO:tensorflow:global_step/sec: 14.9765
# INFO:tensorflow:loss = 0.89407957, step = 56872 (6.677 sec)
# INFO:tensorflow:lr = 0.00016051473 (6.678 sec)
# INFO:tensorflow:global_step/sec: 14.6212
# INFO:tensorflow:loss = 0.92873585, step = 56972 (6.838 sec)
# INFO:tensorflow:lr = 0.00017046824 (6.840 sec)
# INFO:tensorflow:global_step/sec: 15.9507
# INFO:tensorflow:loss = 0.9031164, step = 57072 (6.271 sec)
# INFO:tensorflow:lr = 0.00018042106 (6.275 sec)
# INFO:tensorflow:global_step/sec: 16.0095
# INFO:tensorflow:loss = 0.8986295, step = 57172 (6.246 sec)
# INFO:tensorflow:lr = 0.00019037389 (6.241 sec)
# INFO:tensorflow:global_step/sec: 15.9528
# INFO:tensorflow:loss = 0.8428797, step = 57272 (6.265 sec)
# INFO:tensorflow:lr = 0.0002003274 (6.263 sec)
# INFO:tensorflow:global_step/sec: 15.9238
# INFO:tensorflow:loss = 0.9063416, step = 57372 (6.283 sec)
# INFO:tensorflow:lr = 0.00021028022 (6.284 sec)
# INFO:tensorflow:global_step/sec: 15.9156
# INFO:tensorflow:loss = 0.87453145, step = 57472 (6.285 sec)
# INFO:tensorflow:lr = 0.00022023305 (6.283 sec)
# INFO:tensorflow:global_step/sec: 15.5227
# INFO:tensorflow:loss = 0.91114336, step = 57572 (6.441 sec)
# INFO:tensorflow:lr = 0.00023018656 (6.442 sec)
# INFO:tensorflow:global_step/sec: 15.7299
# INFO:tensorflow:loss = 0.91843677, step = 57672 (6.359 sec)
# INFO:tensorflow:lr = 0.00024013937 (6.361 sec)
# INFO:tensorflow:global_step/sec: 15.8463
# INFO:tensorflow:loss = 0.95649385, step = 57772 (6.306 sec)
# INFO:tensorflow:lr = 0.0002500922 (6.307 sec)
# INFO:tensorflow:global_step/sec: 16.1579
# INFO:tensorflow:loss = 0.87808, step = 57872 (6.191 sec)
# INFO:tensorflow:lr = 0.00026004572 (6.189 sec)
# INFO:tensorflow:global_step/sec: 16.091
# INFO:tensorflow:loss = 0.91827977, step = 57972 (6.215 sec)
# INFO:tensorflow:lr = 0.00026999853 (6.215 sec)
# INFO:tensorflow:global_step/sec: 16.2438
# INFO:tensorflow:loss = 0.90110654, step = 58072 (6.156 sec)
# INFO:tensorflow:lr = 0.00027995204 (6.156 sec)
# INFO:tensorflow:global_step/sec: 16.3019
# INFO:tensorflow:loss = 0.9405346, step = 58172 (6.134 sec)
# INFO:tensorflow:lr = 0.00028990488 (6.134 sec)
# INFO:tensorflow:global_step/sec: 16.299
# INFO:tensorflow:loss = 0.90951097, step = 58272 (6.138 sec)
# INFO:tensorflow:lr = 0.0002998577 (6.139 sec)
# INFO:tensorflow:global_step/sec: 16.3239
# INFO:tensorflow:loss = 0.9183568, step = 58372 (6.125 sec)
# INFO:tensorflow:lr = 0.0003098112 (6.124 sec)
# INFO:tensorflow:global_step/sec: 16.3955
# INFO:tensorflow:loss = 1.0360355, step = 58472 (6.096 sec)
# INFO:tensorflow:lr = 0.00031976402 (6.095 sec)
# INFO:tensorflow:global_step/sec: 16.4167
# INFO:tensorflow:loss = 0.9969532, step = 58572 (6.093 sec)
# INFO:tensorflow:lr = 0.00032971686 (6.095 sec)
# INFO:tensorflow:global_step/sec: 16.4704
# INFO:tensorflow:loss = 0.9627489, step = 58672 (6.074 sec)
# INFO:tensorflow:lr = 0.00033967037 (6.072 sec)
# INFO:tensorflow:global_step/sec: 16.3186
# INFO:tensorflow:loss = 0.87196755, step = 58772 (6.128 sec)
# INFO:tensorflow:lr = 0.0003496232 (6.132 sec)
# INFO:tensorflow:global_step/sec: 15.9737
# INFO:tensorflow:loss = 0.90372413, step = 58872 (6.258 sec)
# INFO:tensorflow:lr = 0.0003595767 (6.255 sec)
# INFO:tensorflow:global_step/sec: 16.2202
# INFO:tensorflow:loss = 0.89159936, step = 58972 (6.164 sec)
# INFO:tensorflow:lr = 0.00036952953 (6.166 sec)
# INFO:tensorflow:global_step/sec: 37.4061
# INFO:tensorflow:loss = 0.92147696, step = 59072 (2.673 sec)
# INFO:tensorflow:lr = 0.00037948237 (2.671 sec)
# INFO:tensorflow:global_step/sec: 117.276
# INFO:tensorflow:loss = 0.9045905, step = 59172 (0.853 sec)
# INFO:tensorflow:lr = 0.00038943585 (0.853 sec)
# INFO:tensorflow:global_step/sec: 119.155
# INFO:tensorflow:loss = 0.9334596, step = 59272 (0.838 sec)
# INFO:tensorflow:lr = 0.0003993887 (0.839 sec)
# INFO:tensorflow:global_step/sec: 118.185
# INFO:tensorflow:loss = 0.934989, step = 59372 (0.848 sec)
# INFO:tensorflow:lr = 0.00040934153 (0.846 sec)
# INFO:tensorflow:global_step/sec: 117.981
# INFO:tensorflow:loss = 0.8571701, step = 59472 (0.848 sec)
# INFO:tensorflow:lr = 0.00041929501 (0.849 sec)
# INFO:tensorflow:global_step/sec: 117.189
# INFO:tensorflow:loss = 0.9649935, step = 59572 (0.852 sec)
# INFO:tensorflow:lr = 0.00042924786 (0.852 sec)
# INFO:tensorflow:global_step/sec: 118.994
# INFO:tensorflow:loss = 0.9861109, step = 59672 (0.841 sec)
# INFO:tensorflow:lr = 0.00043920134 (0.842 sec)
# INFO:tensorflow:global_step/sec: 115.22
# INFO:tensorflow:loss = 0.9874089, step = 59772 (0.864 sec)
# INFO:tensorflow:lr = 0.00044915418 (0.866 sec)
# INFO:tensorflow:Saving checkpoints for 59789 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.89136285.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T03:53:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-59789
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-03:53:41
# INFO:tensorflow:Saving dict for global step 59789: global_step = 59789, loss = 1.2138488, mae = 0.65709484
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 59789: ../model/dnn_softmax_clr/model.ckpt-59789
# INFO:tensorflow:MAE: 0.657
# INFO:tensorflow:Best MAE: 0.628
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'user_id/embeddings:0' shape=(6041, 200) dtype=float32_ref>,
#  <tf.Variable 'user_age/embeddings:0' shape=(8, 30) dtype=float32_ref>,
#  <tf.Variable 'user_job/embeddings:0' shape=(22, 30) dtype=float32_ref>,
#  <tf.Variable 'user_gender/embeddings:0' shape=(2, 30) dtype=float32_ref>,
#  <tf.Variable 'movie_id/embeddings:0' shape=(3692, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_title/embeddings:0' shape=(3703, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/kernel:0' shape=(290, 200) dtype=float32_ref>,
#  <tf.Variable 'user_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/kernel:0' shape=(3, 200, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/conv1d/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/kernel:0' shape=(418, 200) dtype=float32_ref>,
#  <tf.Variable 'movie_feature/fc/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(800, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(200, 200) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(200,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(200, 5) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(5,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-59789
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 59789 into ../model/dnn_softmax_clr/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 0.85627246, step = 59789
# INFO:tensorflow:lr = 0.0004508458
# INFO:tensorflow:global_step/sec: 15.6257
# INFO:tensorflow:loss = 0.93820876, step = 59889 (6.407 sec)
# INFO:tensorflow:lr = 0.00046079932 (6.407 sec)
# INFO:tensorflow:global_step/sec: 16.1301
# INFO:tensorflow:loss = 0.89449716, step = 59989 (6.201 sec)
# INFO:tensorflow:lr = 0.00047075213 (6.200 sec)
# INFO:tensorflow:global_step/sec: 16.4012
# INFO:tensorflow:loss = 0.895369, step = 60089 (6.098 sec)
# INFO:tensorflow:lr = 0.00048070564 (6.104 sec)
# INFO:tensorflow:global_step/sec: 15.8903
# INFO:tensorflow:loss = 1.005223, step = 60189 (6.290 sec)
# INFO:tensorflow:lr = 0.00049065845 (6.286 sec)
# INFO:tensorflow:global_step/sec: 16.1486
# INFO:tensorflow:loss = 0.98811597, step = 60289 (6.193 sec)
# INFO:tensorflow:lr = 0.00050061126 (6.192 sec)
# INFO:tensorflow:global_step/sec: 16.1233
# INFO:tensorflow:loss = 0.8668517, step = 60389 (6.202 sec)
# INFO:tensorflow:lr = 0.0005105648 (6.202 sec)
# INFO:tensorflow:global_step/sec: 15.2066
# INFO:tensorflow:loss = 0.93163335, step = 60489 (6.572 sec)
# INFO:tensorflow:lr = 0.0005205176 (6.571 sec)
# INFO:tensorflow:global_step/sec: 16.0155
# INFO:tensorflow:loss = 0.88913476, step = 60589 (6.245 sec)
# INFO:tensorflow:lr = 0.00053047045 (6.245 sec)
# INFO:tensorflow:global_step/sec: 15.8716
# INFO:tensorflow:loss = 0.8783969, step = 60689 (6.307 sec)
# INFO:tensorflow:lr = 0.00054042396 (6.307 sec)
# INFO:tensorflow:global_step/sec: 16.0091
# INFO:tensorflow:loss = 0.9269674, step = 60789 (6.245 sec)
# INFO:tensorflow:lr = 0.0005503768 (6.244 sec)
# INFO:tensorflow:global_step/sec: 16.0188
# INFO:tensorflow:loss = 0.819852, step = 60889 (6.242 sec)
# INFO:tensorflow:lr = 0.0005603303 (6.242 sec)
# INFO:tensorflow:global_step/sec: 15.7615
# INFO:tensorflow:loss = 0.884837, step = 60989 (6.344 sec)
# INFO:tensorflow:lr = 0.0005702831 (6.345 sec)
# INFO:tensorflow:global_step/sec: 15.6509
# INFO:tensorflow:loss = 0.91218174, step = 61089 (6.390 sec)
# INFO:tensorflow:lr = 0.0005802359 (6.388 sec)
# INFO:tensorflow:global_step/sec: 15.8376
# INFO:tensorflow:loss = 0.9388083, step = 61189 (6.313 sec)
# INFO:tensorflow:lr = 0.0005901894 (6.315 sec)
# INFO:tensorflow:global_step/sec: 16.0282
# INFO:tensorflow:loss = 0.83919257, step = 61289 (6.239 sec)
# INFO:tensorflow:lr = 0.0006001423 (6.238 sec)
# INFO:tensorflow:global_step/sec: 15.1514
# INFO:tensorflow:loss = 0.9112018, step = 61389 (6.604 sec)
# INFO:tensorflow:lr = 0.0006100951 (6.604 sec)
# INFO:tensorflow:global_step/sec: 14.4812
# INFO:tensorflow:loss = 0.9680771, step = 61489 (6.905 sec)
# INFO:tensorflow:lr = 0.0006200486 (6.906 sec)
# INFO:tensorflow:global_step/sec: 15.7382
# INFO:tensorflow:loss = 0.9051462, step = 61589 (6.352 sec)
# INFO:tensorflow:lr = 0.0006300014 (6.353 sec)
# INFO:tensorflow:global_step/sec: 15.6589
# INFO:tensorflow:loss = 0.91995716, step = 61689 (6.385 sec)
# INFO:tensorflow:lr = 0.00063995493 (6.383 sec)
# INFO:tensorflow:global_step/sec: 15.7783
# INFO:tensorflow:loss = 0.88818, step = 61789 (6.342 sec)
# INFO:tensorflow:lr = 0.00064990774 (6.346 sec)
# INFO:tensorflow:global_step/sec: 15.8213
# INFO:tensorflow:loss = 0.94030344, step = 61889 (6.316 sec)
# INFO:tensorflow:lr = 0.0006598606 (6.313 sec)
# INFO:tensorflow:global_step/sec: 15.8598
# INFO:tensorflow:loss = 0.89987636, step = 61989 (6.307 sec)
# INFO:tensorflow:lr = 0.0006698141 (6.311 sec)
# INFO:tensorflow:global_step/sec: 15.8266
# INFO:tensorflow:loss = 0.97284156, step = 62089 (6.322 sec)
# INFO:tensorflow:lr = 0.00067976693 (6.317 sec)
# INFO:tensorflow:global_step/sec: 15.7987
# INFO:tensorflow:loss = 0.9959573, step = 62189 (6.324 sec)
# INFO:tensorflow:lr = 0.00068971975 (6.323 sec)
# INFO:tensorflow:global_step/sec: 15.4983
# INFO:tensorflow:loss = 1.0188758, step = 62289 (6.452 sec)
# INFO:tensorflow:lr = 0.00069967326 (6.454 sec)
# INFO:tensorflow:global_step/sec: 15.6345
# INFO:tensorflow:loss = 0.87850124, step = 62389 (6.400 sec)
# INFO:tensorflow:lr = 0.00070962607 (6.398 sec)
# INFO:tensorflow:global_step/sec: 15.9193
# INFO:tensorflow:loss = 0.9908719, step = 62489 (6.276 sec)
# INFO:tensorflow:lr = 0.00071957894 (6.275 sec)
# INFO:tensorflow:global_step/sec: 36.0182
# INFO:tensorflow:loss = 1.0504687, step = 62589 (2.780 sec)
# INFO:tensorflow:lr = 0.0007295324 (2.780 sec)
# INFO:tensorflow:global_step/sec: 113.069
# INFO:tensorflow:loss = 0.9879747, step = 62689 (0.884 sec)
# INFO:tensorflow:lr = 0.00073948526 (0.884 sec)
# INFO:tensorflow:global_step/sec: 113.92
# INFO:tensorflow:loss = 0.97365165, step = 62789 (0.877 sec)
# INFO:tensorflow:lr = 0.00074943877 (0.877 sec)
# INFO:tensorflow:global_step/sec: 111.675
# INFO:tensorflow:loss = 1.0013039, step = 62889 (0.897 sec)
# INFO:tensorflow:lr = 0.0007593916 (0.897 sec)
# INFO:tensorflow:global_step/sec: 110.869
# INFO:tensorflow:loss = 1.0231102, step = 62989 (0.901 sec)
# INFO:tensorflow:lr = 0.0007693444 (0.900 sec)
# INFO:tensorflow:global_step/sec: 111.831
# INFO:tensorflow:loss = 0.93426263, step = 63089 (0.892 sec)
# INFO:tensorflow:lr = 0.0007792979 (0.894 sec)
# INFO:tensorflow:global_step/sec: 109.995
# INFO:tensorflow:loss = 0.9879998, step = 63189 (0.908 sec)
# INFO:tensorflow:lr = 0.0007892507 (0.909 sec)
# INFO:tensorflow:global_step/sec: 110.174
# INFO:tensorflow:loss = 0.9089722, step = 63289 (0.911 sec)
# INFO:tensorflow:lr = 0.0007992036 (0.909 sec)
# INFO:tensorflow:Saving checkpoints for 63306 into ../model/dnn_softmax_clr/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0001694.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-29T03:57:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/dnn_softmax_clr/model.ckpt-63306
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2020-04-29-03:57:50
# INFO:tensorflow:Saving dict for global step 63306: global_step = 63306, loss = 1.1960713, mae = 0.65733486
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 63306: ../model/dnn_softmax_clr/model.ckpt-63306
# INFO:tensorflow:MAE: 0.657
# INFO:tensorflow:Best MAE: 0.628
# 7 times not improve the best result, therefore stop training
