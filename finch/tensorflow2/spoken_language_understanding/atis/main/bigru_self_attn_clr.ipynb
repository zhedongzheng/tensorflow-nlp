# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/spoken_language_understanding/atis/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score
from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate

import tensorflow as tf
import pprint
import logging
import time
import numpy as np

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-442ec6a690cd>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(vocab_path):
  word2idx = {}
  with open(vocab_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
def data_generator(f_path, params):
  print('Reading', f_path)
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      text, slot_intent = line.split('\t')
      words = text.split()[1:-1]
      slot_intent = slot_intent.split()
      slots, intent = slot_intent[1:-1], slot_intent[-1]
      assert len(words) == len(slots)
      
      words = [params['word2idx'].get(w, len(params['word2idx'])) for w in words]
      intent = params['intent2idx'].get(intent, len(params['intent2idx']))
      slots = [params['slot2idx'].get(s, len(params['slot2idx'])) for s in slots]
      
      yield (words, (intent, slots))

# %%
def dataset(is_training, params):
  _shapes = ([None], ((), [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (-1, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class LayerNorm(tf.keras.layers.Layer):
  def __init__(self, params):
    super().__init__()
    self._epsilon = 1e-6
    self._units = 2 * params['rnn_units']
  
  def build(self, input_shape):
    self.scale = self.add_weight(name='scale',
                                 shape=[self._units],
                                 initializer=tf.ones_initializer(),
                                 trainable=True)
    self.bias = self.add_weight(name='bias',
                                shape=[self._units],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    mean, variance = tf.nn.moments(inputs, [-1], keepdims=True)
    norm_x = (inputs - mean) * tf.math.rsqrt(variance + self._epsilon)
    return norm_x * self.scale + self.bias
  
  def compute_output_shape(self, input_shape):
    return input_shape


class EncoderBlock(tf.keras.Model):
  def __init__(self, SubModel, params, name):
    super().__init__(name = name)
    self.layer_norm = LayerNorm(params)
    self.sub_model = SubModel(params)
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
  
  def call(self, inputs, training=False):
    inputs, masks = inputs
    x = self.layer_norm(inputs)
    x = self.sub_model((x, masks), training=training)
    x = self.dropout(x, training=training)
    x += inputs
    return x


class MultiheadSelfAttention(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.qkv_linear = tf.keras.layers.Dense(3 * 2 * params['rnn_units'], name='qkv_linear')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(2 * params['rnn_units'], name='out_linear')
    self._num_heads = params['num_heads']
  
  def call(self, inputs, training=False):
    x, masks = inputs
    timesteps = tf.shape(x)[1]
    
    q_k_v = self.qkv_linear(x)
    q, k, v = tf.split(q_k_v, 3, axis=-1)
    
    if self._num_heads > 1:
      q = tf.concat(tf.split(q, self._num_heads, axis=2), axis=0)                        
      k = tf.concat(tf.split(k, self._num_heads, axis=2), axis=0)                        
      v = tf.concat(tf.split(v, self._num_heads, axis=2), axis=0)
    
    align = tf.matmul(q, k, transpose_b=True)
    align *= tf.math.rsqrt(tf.cast(k.shape[-1], tf.float32))
    
    if (masks is not None) or (not self._is_bidirectional):
      paddings = tf.fill(tf.shape(align), float('-inf'))
    
    if masks is not None:
      c_masks = tf.tile(masks, [params['num_heads'], 1])
      c_masks = tf.tile(tf.expand_dims(c_masks, 1), [1, timesteps, 1])
      align = tf.where(tf.equal(c_masks, 0), paddings, align)
    
    align = tf.nn.softmax(align)
    align = self.dropout(align, training=training)
    
    if masks is not None:
      q_masks = tf.tile(masks, [params['num_heads'], 1])
      q_masks = tf.tile(tf.expand_dims(q_masks, 2), [1, 1, timesteps])
      align *= tf.cast(q_masks, tf.float32)
    
    x = tf.matmul(align, v)
    if self._num_heads > 1:
      x = tf.concat(tf.split(x, self._num_heads, axis=0), axis=2)
    x = self.out_linear(x)
    
    return x
  

class PointwiseFFN(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dense_1 = tf.keras.layers.Dense(2 * params['multiplier'] * params['rnn_units'], tf.nn.relu, name='fc_relu')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.dense_2 = tf.keras.layers.Dense(2 * params['rnn_units'], name='linear')
  
  def call(self, inputs, training=False):
    x, masks = inputs
    return self.dense_2(self.dropout(self.dense_1(x), training=training))

# %%
class Model(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['vocab_path']),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
    self.input_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
        params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    self.transformer = [
        EncoderBlock(MultiheadSelfAttention, params, name='self_attention'),
        EncoderBlock(PointwiseFFN, params, name='pointwise_ffn'),
    ]
    
    self.intent_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.fc_intent = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='fc_intent')
    self.out_linear_intent = tf.keras.layers.Dense(params['intent_size'], name='output_intent')
    self.out_linear_slot = tf.keras.layers.Dense(params['slot_size'], name='output_slot')
  
  
  def call(self, inputs, training=False):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    mask = tf.sign(inputs)
    rnn_mask = tf.cast(mask, tf.bool)
    
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    x = self.input_dropout(x, training=training)
    x, s_fw, s_bw = self.bidir_gru(x, mask=rnn_mask)
    for block in self.transformer:
      x = block((x, mask), training=training)
    
    x_intent = tf.concat([tf.reduce_max(x, 1), s_fw, s_bw], -1)
    x_intent = self.intent_dropout(x_intent, training=training)
    x_intent = self.out_linear_intent(self.fc_intent(x_intent))
    x_slot = self.out_linear_slot(x)
    return (x_intent, x_slot)

# %%
params = {
  'train_path': '../data/atis.train.w-intent.iob',
  'test_path': '../data/atis.test.w-intent.iob',
  'word_path': '../vocab/word.txt',
  'vocab_path': '../vocab/word.npy',
  'intent_path': '../vocab/intent.txt',
  'slot_path': '../vocab/slot.txt',
  'batch_size': 16,
  'num_samples': 4978,
  'rnn_units': 300,
  'num_heads': 6,
  'multiplier': 2,
  'dropout_rate': .2,
  'clip_norm': .1,
}

# %%
params['word2idx'] = get_vocab(params['word_path'])
params['intent2idx'] = get_vocab(params['intent_path'])
params['slot2idx'] = get_vocab(params['slot_path'])

params['word_size'] = len(params['word2idx']) + 1
params['intent_size'] = len(params['intent2idx']) + 1
params['slot_size'] = len(params['slot2idx']) + 1

# %%
model = Model(params)
model.build(input_shape=(None, None))
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = 1e-4,
  maximal_learning_rate = 8e-4,
  step_size = 8 * params['num_samples'] // params['batch_size'],
)
optim = tf.optimizers.Adam(1e-4)
global_step = 0

slot_best_f1 = .0
intent_acc_with_that = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

for n_epoch in range(1, 64+1):
  # TRAINING
  for (words, (intent, slots)) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      y_intent, y_slots = model(words, training=True)
      loss_intent = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(intent, len(params['intent2idx'])+1),
        logits = y_intent,
        label_smoothing = .2)
      # weight of 'O' is set to be small
      weights = tf.cast(tf.sign(slots), tf.float32)
      padding = tf.constant(1e-2, tf.float32, weights.shape)
      weights = tf.where(tf.equal(weights, 0.), padding, weights)

      loss_slots = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(slots, len(params['slot2idx'])+1),
        logits = y_slots,
        weights = tf.cast(weights, tf.float32),
        label_smoothing = .2)
      # joint loss
      loss = loss_intent + loss_slots
    
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))

    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Loss_intent: {:.4f} | Loss_slots: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), loss_intent.numpy().item(), loss_slots.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
    
  # EVALUATION
  intent_true = []
  intent_pred = []
  slot_true = []
  slot_pred = []

  for (words, (intent, slots)) in dataset(is_training=False, params=params):
    y_intent, y_slots = model(words, training=False)
    y_intent = tf.argmax(y_intent, -1)
    y_slots = tf.argmax(y_slots, -1)
    
    intent_true += intent.numpy().flatten().tolist()
    intent_pred += y_intent.numpy().flatten().tolist()
    slot_true += slots.numpy().flatten().tolist()
    slot_pred += y_slots.numpy().flatten().tolist()
    
  f1_slots = f1_score(y_true = slot_true,
                      y_pred = slot_pred,
                      labels = list(params['slot2idx'].values()),
                      sample_weight = np.sign(slot_true),
                      average='micro',)
  
  acc_intent = accuracy_score(intent_true, intent_pred)

  logger.info("Slot F1: {:.3f}, Intent Acc: {:.3f}".format(f1_slots, acc_intent))

  if n_epoch != 1 and n_epoch % 8 == 0:
    logger.info('\n'+classification_report(y_true = intent_true,
                                          y_pred = intent_pred,
                                          labels = list(params['intent2idx'].values()),
                                          target_names = list(params['intent2idx'].keys()),
                                          digits=3))
    logger.info('\n'+classification_report(y_true = slot_true,
                                          y_pred = slot_pred,
                                          labels = list(params['slot2idx'].values()),
                                          target_names = list(params['slot2idx'].keys()),
                                          sample_weight = np.sign(slot_true),
                                          digits=3))
  
  if f1_slots > slot_best_f1:
    slot_best_f1 = f1_slots
    intent_acc_with_that = acc_intent
    # you can save model here
  logger.info("Best Slot F1: {:.3f}, Intent Acc: {:.3f}".format(slot_best_f1, intent_acc_with_that))
# Out:
# [('bidirectional/forward_gru/gru_cell_1/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/bias:0', TensorShape([2, 900])),
#  ('self_attention/layer_norm/scale:0', TensorShape([600])),
#  ('self_attention/layer_norm/bias:0', TensorShape([600])),
#  ('self_attention/multihead_self_attention/qkv_linear/kernel:0',
#   TensorShape([600, 1800])),
#  ('self_attention/multihead_self_attention/qkv_linear/bias:0',
#   TensorShape([1800])),
#  ('self_attention/multihead_self_attention/out_linear/kernel:0',
#   TensorShape([600, 600])),
#  ('self_attention/multihead_self_attention/out_linear/bias:0',
#   TensorShape([600])),
#  ('pointwise_ffn/layer_norm_1/scale:0', TensorShape([600])),
#  ('pointwise_ffn/layer_norm_1/bias:0', TensorShape([600])),
#  ('pointwise_ffn/pointwise_ffn/fc_relu/kernel:0', TensorShape([600, 1200])),
#  ('pointwise_ffn/pointwise_ffn/fc_relu/bias:0', TensorShape([1200])),
#  ('pointwise_ffn/pointwise_ffn/linear/kernel:0', TensorShape([1200, 600])),
#  ('pointwise_ffn/pointwise_ffn/linear/bias:0', TensorShape([600])),
#  ('fc_intent/kernel:0', TensorShape([1200, 300])),
#  ('fc_intent/bias:0', TensorShape([300])),
#  ('output_intent/kernel:0', TensorShape([300, 23])),
#  ('output_intent/bias:0', TensorShape([23])),
#  ('output_slot/kernel:0', TensorShape([600, 122])),
#  ('output_slot/bias:0', TensorShape([122])),
#  ('pretrained_embedding:0', TensorShape([750, 300]))]
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 0 | Loss: 5.5263 | Loss_intent: 4.5244 | Loss_slots: 1.0020 | Spent: 2.2 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 2.4542 | Loss_intent: 1.6822 | Loss_slots: 0.7720 | Spent: 2.6 secs | LR: 0.000114
# INFO:tensorflow:Step 100 | Loss: 2.2175 | Loss_intent: 1.3024 | Loss_slots: 0.9151 | Spent: 2.6 secs | LR: 0.000128
# INFO:tensorflow:Step 150 | Loss: 2.0622 | Loss_intent: 1.5697 | Loss_slots: 0.4924 | Spent: 2.6 secs | LR: 0.000142
# INFO:tensorflow:Step 200 | Loss: 2.1562 | Loss_intent: 1.5115 | Loss_slots: 0.6447 | Spent: 2.6 secs | LR: 0.000156
# INFO:tensorflow:Step 250 | Loss: 2.1736 | Loss_intent: 1.7907 | Loss_slots: 0.3829 | Spent: 2.6 secs | LR: 0.000170
# INFO:tensorflow:Step 300 | Loss: 1.6916 | Loss_intent: 1.1685 | Loss_slots: 0.5231 | Spent: 2.6 secs | LR: 0.000184
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.775, Intent Acc: 0.909
# INFO:tensorflow:Best Slot F1: 0.775, Intent Acc: 0.909
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 350 | Loss: 1.8814 | Loss_intent: 1.3360 | Loss_slots: 0.5454 | Spent: 4.8 secs | LR: 0.000198
# INFO:tensorflow:Step 400 | Loss: 1.6109 | Loss_intent: 1.2909 | Loss_slots: 0.3201 | Spent: 2.6 secs | LR: 0.000212
# INFO:tensorflow:Step 450 | Loss: 1.7515 | Loss_intent: 1.2577 | Loss_slots: 0.4937 | Spent: 2.6 secs | LR: 0.000227
# INFO:tensorflow:Step 500 | Loss: 1.6554 | Loss_intent: 1.2416 | Loss_slots: 0.4138 | Spent: 2.6 secs | LR: 0.000241
# INFO:tensorflow:Step 550 | Loss: 1.6913 | Loss_intent: 1.1690 | Loss_slots: 0.5223 | Spent: 2.6 secs | LR: 0.000255
# INFO:tensorflow:Step 600 | Loss: 1.5661 | Loss_intent: 1.1437 | Loss_slots: 0.4224 | Spent: 2.6 secs | LR: 0.000269
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.878, Intent Acc: 0.942
# INFO:tensorflow:Best Slot F1: 0.878, Intent Acc: 0.942
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 650 | Loss: 1.8522 | Loss_intent: 1.3335 | Loss_slots: 0.5186 | Spent: 4.8 secs | LR: 0.000283
# INFO:tensorflow:Step 700 | Loss: 1.6570 | Loss_intent: 1.2106 | Loss_slots: 0.4464 | Spent: 2.6 secs | LR: 0.000297
# INFO:tensorflow:Step 750 | Loss: 1.5062 | Loss_intent: 1.1068 | Loss_slots: 0.3994 | Spent: 2.6 secs | LR: 0.000311
# INFO:tensorflow:Step 800 | Loss: 1.6787 | Loss_intent: 1.2308 | Loss_slots: 0.4479 | Spent: 2.6 secs | LR: 0.000325
# INFO:tensorflow:Step 850 | Loss: 1.5075 | Loss_intent: 1.1059 | Loss_slots: 0.4016 | Spent: 2.6 secs | LR: 0.000339
# INFO:tensorflow:Step 900 | Loss: 1.5715 | Loss_intent: 1.1043 | Loss_slots: 0.4672 | Spent: 2.6 secs | LR: 0.000353
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.914, Intent Acc: 0.960
# INFO:tensorflow:Best Slot F1: 0.914, Intent Acc: 0.960
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 950 | Loss: 1.4598 | Loss_intent: 1.0946 | Loss_slots: 0.3652 | Spent: 4.9 secs | LR: 0.000367
# INFO:tensorflow:Step 1000 | Loss: 1.5256 | Loss_intent: 1.0999 | Loss_slots: 0.4257 | Spent: 2.7 secs | LR: 0.000381
# INFO:tensorflow:Step 1050 | Loss: 1.4435 | Loss_intent: 1.1731 | Loss_slots: 0.2703 | Spent: 2.6 secs | LR: 0.000395
# INFO:tensorflow:Step 1100 | Loss: 1.4625 | Loss_intent: 1.1087 | Loss_slots: 0.3538 | Spent: 2.6 secs | LR: 0.000409
# INFO:tensorflow:Step 1150 | Loss: 1.3231 | Loss_intent: 1.0953 | Loss_slots: 0.2278 | Spent: 2.6 secs | LR: 0.000423
# INFO:tensorflow:Step 1200 | Loss: 1.4395 | Loss_intent: 1.0941 | Loss_slots: 0.3454 | Spent: 2.6 secs | LR: 0.000437
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.927, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.927, Intent Acc: 0.964
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1250 | Loss: 1.4405 | Loss_intent: 1.1106 | Loss_slots: 0.3300 | Spent: 4.8 secs | LR: 0.000452
# INFO:tensorflow:Step 1300 | Loss: 1.5073 | Loss_intent: 1.0949 | Loss_slots: 0.4124 | Spent: 2.6 secs | LR: 0.000466
# INFO:tensorflow:Step 1350 | Loss: 1.4344 | Loss_intent: 1.0916 | Loss_slots: 0.3428 | Spent: 2.6 secs | LR: 0.000480
# INFO:tensorflow:Step 1400 | Loss: 1.4813 | Loss_intent: 1.1643 | Loss_slots: 0.3170 | Spent: 2.6 secs | LR: 0.000494
# INFO:tensorflow:Step 1450 | Loss: 1.4262 | Loss_intent: 1.0951 | Loss_slots: 0.3311 | Spent: 2.6 secs | LR: 0.000508
# INFO:tensorflow:Step 1500 | Loss: 1.5154 | Loss_intent: 1.1086 | Loss_slots: 0.4068 | Spent: 2.6 secs | LR: 0.000522
# INFO:tensorflow:Step 1550 | Loss: 1.4395 | Loss_intent: 1.1086 | Loss_slots: 0.3309 | Spent: 2.6 secs | LR: 0.000536
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.934, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.934, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1600 | Loss: 1.4391 | Loss_intent: 1.1156 | Loss_slots: 0.3235 | Spent: 4.9 secs | LR: 0.000550
# INFO:tensorflow:Step 1650 | Loss: 1.4851 | Loss_intent: 1.1086 | Loss_slots: 0.3765 | Spent: 2.6 secs | LR: 0.000564
# INFO:tensorflow:Step 1700 | Loss: 1.4862 | Loss_intent: 1.0996 | Loss_slots: 0.3866 | Spent: 2.6 secs | LR: 0.000578
# INFO:tensorflow:Step 1750 | Loss: 1.4405 | Loss_intent: 1.0906 | Loss_slots: 0.3498 | Spent: 2.6 secs | LR: 0.000592
# INFO:tensorflow:Step 1800 | Loss: 1.5258 | Loss_intent: 1.1386 | Loss_slots: 0.3872 | Spent: 2.6 secs | LR: 0.000606
# INFO:tensorflow:Step 1850 | Loss: 1.4302 | Loss_intent: 1.1274 | Loss_slots: 0.3027 | Spent: 2.6 secs | LR: 0.000620
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.935, Intent Acc: 0.972
# INFO:tensorflow:Best Slot F1: 0.935, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1900 | Loss: 1.5925 | Loss_intent: 1.1727 | Loss_slots: 0.4198 | Spent: 4.8 secs | LR: 0.000634
# INFO:tensorflow:Step 1950 | Loss: 1.5372 | Loss_intent: 1.0911 | Loss_slots: 0.4462 | Spent: 2.6 secs | LR: 0.000648
# INFO:tensorflow:Step 2000 | Loss: 1.6110 | Loss_intent: 1.0928 | Loss_slots: 0.5182 | Spent: 2.6 secs | LR: 0.000662
# INFO:tensorflow:Step 2050 | Loss: 1.5089 | Loss_intent: 1.1294 | Loss_slots: 0.3795 | Spent: 2.6 secs | LR: 0.000677
# INFO:tensorflow:Step 2100 | Loss: 1.4053 | Loss_intent: 1.0862 | Loss_slots: 0.3191 | Spent: 2.6 secs | LR: 0.000691
# INFO:tensorflow:Step 2150 | Loss: 1.4634 | Loss_intent: 1.1824 | Loss_slots: 0.2810 | Spent: 2.6 secs | LR: 0.000705
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.937, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.937, Intent Acc: 0.964
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2200 | Loss: 1.4844 | Loss_intent: 1.0948 | Loss_slots: 0.3896 | Spent: 4.9 secs | LR: 0.000719
# INFO:tensorflow:Step 2250 | Loss: 1.5000 | Loss_intent: 1.2225 | Loss_slots: 0.2775 | Spent: 2.6 secs | LR: 0.000733
# INFO:tensorflow:Step 2300 | Loss: 1.3616 | Loss_intent: 1.0948 | Loss_slots: 0.2668 | Spent: 2.7 secs | LR: 0.000747
# INFO:tensorflow:Step 2350 | Loss: 1.3820 | Loss_intent: 1.1380 | Loss_slots: 0.2441 | Spent: 2.6 secs | LR: 0.000761
# INFO:tensorflow:Step 2400 | Loss: 1.6261 | Loss_intent: 1.2727 | Loss_slots: 0.3535 | Spent: 2.6 secs | LR: 0.000775
# INFO:tensorflow:Step 2450 | Loss: 1.4432 | Loss_intent: 1.0907 | Loss_slots: 0.3525 | Spent: 2.6 secs | LR: 0.000789
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.943, Intent Acc: 0.950
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.954     0.992     0.973       632
#                             atis_airfare      0.922     0.979     0.949        48
#                      atis_ground_service      0.973     1.000     0.986        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.941     0.970     0.955        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      0.500     1.000     0.667         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.667     0.167     0.267        12
#                             atis_airport      1.000     0.778     0.875        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.000     0.000     0.000         6
#                         atis_ground_fare      1.000     0.571     0.727         7
#                            atis_capacity      1.000     0.905     0.950        21
#                           atis_flight_no      1.000     0.750     0.857         8
#                                atis_meal      0.000     0.000     0.000         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.950     0.955     0.952       888
#                                macro avg      0.562     0.551     0.536       888
#                             weighted avg      0.938     0.955     0.943       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.970     0.993     0.981     716.0
#          B-fromloc.city_name      0.974     1.000     0.987     704.0
#            I-toloc.city_name      0.956     0.985     0.970     265.0
#       B-depart_date.day_name      0.990     0.972     0.981     212.0
#               B-airline_name      1.000     0.990     0.995     101.0
#          I-fromloc.city_name      0.946     0.994     0.970     177.0
#  B-depart_time.period_of_day      0.959     0.900     0.929     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.838     1.000     0.912      57.0
#                 B-round_trip      1.000     0.973     0.986      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.800     1.000     0.889      24.0
#  B-depart_time.time_relative      0.955     0.969     0.962      65.0
#           I-depart_time.time      0.929     1.000     0.963      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.837     0.632     0.720      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.906     0.935     0.921      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      0.955     1.000     0.977      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     1.000     1.000      15.0
#       I-fromloc.airport_name      0.469     1.000     0.638      15.0
#       B-fromloc.airport_name      0.409     0.750     0.529      12.0
#       B-arrive_date.day_name      0.611     1.000     0.759      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.423     1.000     0.595      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.781     0.893     0.833      28.0
#            B-fare_basis_code      0.909     0.588     0.714      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.667     1.000     0.800       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.900     0.310     0.462      29.0
#                B-fare_amount      0.500     1.000     0.667       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.333     0.500      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     0.900     0.947      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     0.600     0.750       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     0.333     0.500       3.0
#         B-fromloc.state_name      0.895     1.000     0.944      17.0
#               B-airport_name      0.714     0.238     0.357      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.818     0.900      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.333     0.400       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.500     0.667       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      0.333     1.000     0.500       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      0.000     0.000     0.000       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.333     0.333     0.333       3.0
#         I-fromloc.state_name      0.000     0.000     0.000       1.0
#                 B-state_code      0.000     0.000     0.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      0.000     0.000     0.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      0.000     0.000     0.000       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      0.500     1.000     0.667       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.000     0.000     0.000       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.943     0.944     0.943    3657.0
#                    macro avg      0.601     0.592     0.581    3657.0
#                 weighted avg      0.942     0.944     0.937    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.950
# Reading ../data/atis.train.w-intent.iob
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:tensorflow:Step 2500 | Loss: 1.4694 | Loss_intent: 1.0972 | Loss_slots: 0.3721 | Spent: 4.9 secs | LR: 0.000797
# INFO:tensorflow:Step 2550 | Loss: 1.5717 | Loss_intent: 1.1036 | Loss_slots: 0.4681 | Spent: 2.6 secs | LR: 0.000783
# INFO:tensorflow:Step 2600 | Loss: 1.3631 | Loss_intent: 1.0909 | Loss_slots: 0.2722 | Spent: 2.6 secs | LR: 0.000769
# INFO:tensorflow:Step 2650 | Loss: 1.4330 | Loss_intent: 1.0861 | Loss_slots: 0.3469 | Spent: 2.6 secs | LR: 0.000755
# INFO:tensorflow:Step 2700 | Loss: 1.4206 | Loss_intent: 1.1033 | Loss_slots: 0.3172 | Spent: 2.6 secs | LR: 0.000741
# INFO:tensorflow:Step 2750 | Loss: 1.6004 | Loss_intent: 1.2087 | Loss_slots: 0.3917 | Spent: 2.7 secs | LR: 0.000727
# INFO:tensorflow:Step 2800 | Loss: 1.4213 | Loss_intent: 1.0941 | Loss_slots: 0.3272 | Spent: 2.6 secs | LR: 0.000713
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2850 | Loss: 1.4565 | Loss_intent: 1.0862 | Loss_slots: 0.3703 | Spent: 4.8 secs | LR: 0.000698
# INFO:tensorflow:Step 2900 | Loss: 1.5466 | Loss_intent: 1.1033 | Loss_slots: 0.4433 | Spent: 2.6 secs | LR: 0.000684
# INFO:tensorflow:Step 2950 | Loss: 1.3990 | Loss_intent: 1.1126 | Loss_slots: 0.2863 | Spent: 2.6 secs | LR: 0.000670
# INFO:tensorflow:Step 3000 | Loss: 1.3866 | Loss_intent: 1.1000 | Loss_slots: 0.2866 | Spent: 2.7 secs | LR: 0.000656
# INFO:tensorflow:Step 3050 | Loss: 1.4021 | Loss_intent: 1.0832 | Loss_slots: 0.3189 | Spent: 2.6 secs | LR: 0.000642
# INFO:tensorflow:Step 3100 | Loss: 1.4710 | Loss_intent: 1.0895 | Loss_slots: 0.3815 | Spent: 2.6 secs | LR: 0.000628
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.965
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3150 | Loss: 1.4061 | Loss_intent: 1.0904 | Loss_slots: 0.3157 | Spent: 4.8 secs | LR: 0.000614
# INFO:tensorflow:Step 3200 | Loss: 1.3360 | Loss_intent: 1.0860 | Loss_slots: 0.2500 | Spent: 2.6 secs | LR: 0.000600
# INFO:tensorflow:Step 3250 | Loss: 1.4439 | Loss_intent: 1.1233 | Loss_slots: 0.3206 | Spent: 2.6 secs | LR: 0.000586
# INFO:tensorflow:Step 3300 | Loss: 1.5117 | Loss_intent: 1.0860 | Loss_slots: 0.4258 | Spent: 2.6 secs | LR: 0.000572
# INFO:tensorflow:Step 3350 | Loss: 1.4938 | Loss_intent: 1.0882 | Loss_slots: 0.4056 | Spent: 2.6 secs | LR: 0.000558
# INFO:tensorflow:Step 3400 | Loss: 1.4769 | Loss_intent: 1.0969 | Loss_slots: 0.3799 | Spent: 2.6 secs | LR: 0.000544
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3450 | Loss: 1.3934 | Loss_intent: 1.0862 | Loss_slots: 0.3072 | Spent: 4.8 secs | LR: 0.000530
# INFO:tensorflow:Step 3500 | Loss: 1.4242 | Loss_intent: 1.0890 | Loss_slots: 0.3352 | Spent: 2.7 secs | LR: 0.000516
# INFO:tensorflow:Step 3550 | Loss: 1.4009 | Loss_intent: 1.0873 | Loss_slots: 0.3136 | Spent: 2.6 secs | LR: 0.000502
# INFO:tensorflow:Step 3600 | Loss: 1.4609 | Loss_intent: 1.0829 | Loss_slots: 0.3780 | Spent: 2.6 secs | LR: 0.000488
# INFO:tensorflow:Step 3650 | Loss: 1.4721 | Loss_intent: 1.0953 | Loss_slots: 0.3768 | Spent: 2.7 secs | LR: 0.000473
# INFO:tensorflow:Step 3700 | Loss: 1.5683 | Loss_intent: 1.1337 | Loss_slots: 0.4346 | Spent: 2.6 secs | LR: 0.000459
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3750 | Loss: 1.2624 | Loss_intent: 1.0810 | Loss_slots: 0.1814 | Spent: 4.9 secs | LR: 0.000445
# INFO:tensorflow:Step 3800 | Loss: 1.3738 | Loss_intent: 1.0871 | Loss_slots: 0.2866 | Spent: 2.6 secs | LR: 0.000431
# INFO:tensorflow:Step 3850 | Loss: 1.4562 | Loss_intent: 1.0836 | Loss_slots: 0.3725 | Spent: 2.6 secs | LR: 0.000417
# INFO:tensorflow:Step 3900 | Loss: 1.5238 | Loss_intent: 1.0828 | Loss_slots: 0.4410 | Spent: 2.7 secs | LR: 0.000403
# INFO:tensorflow:Step 3950 | Loss: 1.3993 | Loss_intent: 1.0819 | Loss_slots: 0.3174 | Spent: 2.8 secs | LR: 0.000389
# INFO:tensorflow:Step 4000 | Loss: 1.3653 | Loss_intent: 1.0867 | Loss_slots: 0.2786 | Spent: 2.7 secs | LR: 0.000375
# INFO:tensorflow:Step 4050 | Loss: 1.4360 | Loss_intent: 1.0828 | Loss_slots: 0.3532 | Spent: 2.6 secs | LR: 0.000361
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4100 | Loss: 1.4560 | Loss_intent: 1.0817 | Loss_slots: 0.3743 | Spent: 4.8 secs | LR: 0.000347
# INFO:tensorflow:Step 4150 | Loss: 1.3916 | Loss_intent: 1.0851 | Loss_slots: 0.3065 | Spent: 2.6 secs | LR: 0.000333
# INFO:tensorflow:Step 4200 | Loss: 1.4968 | Loss_intent: 1.0863 | Loss_slots: 0.4106 | Spent: 2.6 secs | LR: 0.000319
# INFO:tensorflow:Step 4250 | Loss: 1.4750 | Loss_intent: 1.0822 | Loss_slots: 0.3928 | Spent: 2.6 secs | LR: 0.000305
# INFO:tensorflow:Step 4300 | Loss: 1.3425 | Loss_intent: 1.0831 | Loss_slots: 0.2594 | Spent: 2.6 secs | LR: 0.000291
# INFO:tensorflow:Step 4350 | Loss: 1.4126 | Loss_intent: 1.0816 | Loss_slots: 0.3310 | Spent: 2.6 secs | LR: 0.000277
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4400 | Loss: 1.3276 | Loss_intent: 1.0808 | Loss_slots: 0.2467 | Spent: 4.9 secs | LR: 0.000263
# INFO:tensorflow:Step 4450 | Loss: 1.4610 | Loss_intent: 1.0845 | Loss_slots: 0.3765 | Spent: 2.7 secs | LR: 0.000248
# INFO:tensorflow:Step 4500 | Loss: 1.4952 | Loss_intent: 1.0806 | Loss_slots: 0.4146 | Spent: 2.6 secs | LR: 0.000234
# INFO:tensorflow:Step 4550 | Loss: 1.4598 | Loss_intent: 1.0807 | Loss_slots: 0.3791 | Spent: 2.5 secs | LR: 0.000220
# INFO:tensorflow:Step 4600 | Loss: 1.4064 | Loss_intent: 1.0822 | Loss_slots: 0.3242 | Spent: 2.6 secs | LR: 0.000206
# INFO:tensorflow:Step 4650 | Loss: 1.4352 | Loss_intent: 1.0812 | Loss_slots: 0.3540 | Spent: 2.6 secs | LR: 0.000192
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4700 | Loss: 1.4396 | Loss_intent: 1.0865 | Loss_slots: 0.3530 | Spent: 4.9 secs | LR: 0.000178
# INFO:tensorflow:Step 4750 | Loss: 1.3849 | Loss_intent: 1.0801 | Loss_slots: 0.3047 | Spent: 2.8 secs | LR: 0.000164
# INFO:tensorflow:Step 4800 | Loss: 1.4338 | Loss_intent: 1.0839 | Loss_slots: 0.3499 | Spent: 2.8 secs | LR: 0.000150
# INFO:tensorflow:Step 4850 | Loss: 1.3646 | Loss_intent: 1.0812 | Loss_slots: 0.2835 | Spent: 2.8 secs | LR: 0.000136
# INFO:tensorflow:Step 4900 | Loss: 1.4380 | Loss_intent: 1.1352 | Loss_slots: 0.3028 | Spent: 2.8 secs | LR: 0.000122
# INFO:tensorflow:Step 4950 | Loss: 1.4321 | Loss_intent: 1.0808 | Loss_slots: 0.3512 | Spent: 2.7 secs | LR: 0.000108
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.975
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.983     0.991     0.987       632
#                             atis_airfare      0.980     1.000     0.990        48
#                      atis_ground_service      0.973     1.000     0.986        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      0.947     1.000     0.973        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     0.857     0.923         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.975     0.981     0.978       888
#                                macro avg      0.681     0.671     0.665       888
#                             weighted avg      0.977     0.981     0.977       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.974     0.992     0.983     716.0
#          B-fromloc.city_name      0.983     1.000     0.992     704.0
#            I-toloc.city_name      0.956     0.981     0.968     265.0
#       B-depart_date.day_name      0.986     0.986     0.986     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.957     0.994     0.975     177.0
#  B-depart_time.period_of_day      1.000     0.923     0.960     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.826     1.000     0.905      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.828     1.000     0.906      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.943     0.579     0.717      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.971     0.971     0.971      34.0
#  B-arrive_time.time_relative      0.829     0.935     0.879      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.417     1.000     0.588      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.440     1.000     0.611      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.781     0.893     0.833      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.667     1.000     0.800       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.909     0.345     0.500      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.367     0.537      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      0.944     1.000     0.971      17.0
#               B-airport_name      0.800     0.381     0.516      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.833     0.909     0.870      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      0.500     1.000     0.667       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.667     0.667     0.667       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.951     0.952     0.952    3657.0
#                    macro avg      0.666     0.649     0.643    3657.0
#                 weighted avg      0.954     0.952     0.947    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.975
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5000 | Loss: 1.3964 | Loss_intent: 1.0831 | Loss_slots: 0.3132 | Spent: 5.0 secs | LR: 0.000103
# INFO:tensorflow:Step 5050 | Loss: 1.3612 | Loss_intent: 1.0818 | Loss_slots: 0.2794 | Spent: 2.7 secs | LR: 0.000110
# INFO:tensorflow:Step 5100 | Loss: 1.4277 | Loss_intent: 1.0810 | Loss_slots: 0.3467 | Spent: 2.6 secs | LR: 0.000117
# INFO:tensorflow:Step 5150 | Loss: 1.3252 | Loss_intent: 1.0819 | Loss_slots: 0.2433 | Spent: 2.6 secs | LR: 0.000124
# INFO:tensorflow:Step 5200 | Loss: 1.4050 | Loss_intent: 1.0815 | Loss_slots: 0.3236 | Spent: 2.6 secs | LR: 0.000131
# INFO:tensorflow:Step 5250 | Loss: 1.4656 | Loss_intent: 1.0801 | Loss_slots: 0.3855 | Spent: 2.6 secs | LR: 0.000138
# INFO:tensorflow:Step 5300 | Loss: 1.4818 | Loss_intent: 1.0811 | Loss_slots: 0.4007 | Spent: 2.6 secs | LR: 0.000145
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5350 | Loss: 1.4151 | Loss_intent: 1.0803 | Loss_slots: 0.3347 | Spent: 4.8 secs | LR: 0.000152
# INFO:tensorflow:Step 5400 | Loss: 1.3815 | Loss_intent: 1.0804 | Loss_slots: 0.3010 | Spent: 2.7 secs | LR: 0.000159
# INFO:tensorflow:Step 5450 | Loss: 1.4772 | Loss_intent: 1.0811 | Loss_slots: 0.3961 | Spent: 2.6 secs | LR: 0.000166
# INFO:tensorflow:Step 5500 | Loss: 1.4029 | Loss_intent: 1.0841 | Loss_slots: 0.3189 | Spent: 2.6 secs | LR: 0.000173
# INFO:tensorflow:Step 5550 | Loss: 1.3535 | Loss_intent: 1.0806 | Loss_slots: 0.2729 | Spent: 2.7 secs | LR: 0.000180
# INFO:tensorflow:Step 5600 | Loss: 1.3675 | Loss_intent: 1.0804 | Loss_slots: 0.2871 | Spent: 2.6 secs | LR: 0.000187
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5650 | Loss: 1.3780 | Loss_intent: 1.1004 | Loss_slots: 0.2776 | Spent: 4.8 secs | LR: 0.000194
# INFO:tensorflow:Step 5700 | Loss: 1.4475 | Loss_intent: 1.0808 | Loss_slots: 0.3667 | Spent: 2.6 secs | LR: 0.000202
# INFO:tensorflow:Step 5750 | Loss: 1.3723 | Loss_intent: 1.0830 | Loss_slots: 0.2893 | Spent: 2.6 secs | LR: 0.000209
# INFO:tensorflow:Step 5800 | Loss: 1.4000 | Loss_intent: 1.0809 | Loss_slots: 0.3191 | Spent: 2.6 secs | LR: 0.000216
# INFO:tensorflow:Step 5850 | Loss: 1.3401 | Loss_intent: 1.0812 | Loss_slots: 0.2589 | Spent: 2.6 secs | LR: 0.000223
# INFO:tensorflow:Step 5900 | Loss: 1.3170 | Loss_intent: 1.0812 | Loss_slots: 0.2358 | Spent: 2.6 secs | LR: 0.000230
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5950 | Loss: 1.4340 | Loss_intent: 1.0814 | Loss_slots: 0.3526 | Spent: 4.8 secs | LR: 0.000237
# INFO:tensorflow:Step 6000 | Loss: 1.4086 | Loss_intent: 1.0815 | Loss_slots: 0.3272 | Spent: 2.6 secs | LR: 0.000244
# INFO:tensorflow:Step 6050 | Loss: 1.4797 | Loss_intent: 1.0818 | Loss_slots: 0.3979 | Spent: 2.6 secs | LR: 0.000251
# INFO:tensorflow:Step 6100 | Loss: 1.3447 | Loss_intent: 1.0811 | Loss_slots: 0.2636 | Spent: 2.6 secs | LR: 0.000258
# INFO:tensorflow:Step 6150 | Loss: 1.4205 | Loss_intent: 1.0855 | Loss_slots: 0.3350 | Spent: 2.6 secs | LR: 0.000265
# INFO:tensorflow:Step 6200 | Loss: 1.3595 | Loss_intent: 1.0803 | Loss_slots: 0.2792 | Spent: 2.6 secs | LR: 0.000272
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.978
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6250 | Loss: 1.3721 | Loss_intent: 1.0808 | Loss_slots: 0.2912 | Spent: 4.8 secs | LR: 0.000279
# INFO:tensorflow:Step 6300 | Loss: 1.4512 | Loss_intent: 1.0827 | Loss_slots: 0.3685 | Spent: 2.6 secs | LR: 0.000286
# INFO:tensorflow:Step 6350 | Loss: 1.4047 | Loss_intent: 1.0872 | Loss_slots: 0.3175 | Spent: 2.6 secs | LR: 0.000293
# INFO:tensorflow:Step 6400 | Loss: 1.4978 | Loss_intent: 1.0816 | Loss_slots: 0.4163 | Spent: 2.6 secs | LR: 0.000300
# INFO:tensorflow:Step 6450 | Loss: 1.4519 | Loss_intent: 1.0914 | Loss_slots: 0.3605 | Spent: 2.6 secs | LR: 0.000307
# INFO:tensorflow:Step 6500 | Loss: 1.4754 | Loss_intent: 1.0805 | Loss_slots: 0.3949 | Spent: 2.6 secs | LR: 0.000314
# INFO:tensorflow:Step 6550 | Loss: 1.3293 | Loss_intent: 1.0829 | Loss_slots: 0.2463 | Spent: 2.7 secs | LR: 0.000321
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.975
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6600 | Loss: 1.3690 | Loss_intent: 1.0844 | Loss_slots: 0.2846 | Spent: 4.9 secs | LR: 0.000328
# INFO:tensorflow:Step 6650 | Loss: 1.3691 | Loss_intent: 1.0812 | Loss_slots: 0.2879 | Spent: 2.6 secs | LR: 0.000335
# INFO:tensorflow:Step 6700 | Loss: 1.4378 | Loss_intent: 1.0817 | Loss_slots: 0.3562 | Spent: 2.6 secs | LR: 0.000342
# INFO:tensorflow:Step 6750 | Loss: 1.3965 | Loss_intent: 1.0959 | Loss_slots: 0.3005 | Spent: 2.6 secs | LR: 0.000349
# INFO:tensorflow:Step 6800 | Loss: 1.4432 | Loss_intent: 1.0815 | Loss_slots: 0.3616 | Spent: 2.6 secs | LR: 0.000356
# INFO:tensorflow:Step 6850 | Loss: 1.3914 | Loss_intent: 1.0849 | Loss_slots: 0.3065 | Spent: 2.6 secs | LR: 0.000363
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.975
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6900 | Loss: 1.4155 | Loss_intent: 1.0996 | Loss_slots: 0.3160 | Spent: 4.8 secs | LR: 0.000370
# INFO:tensorflow:Step 6950 | Loss: 1.4571 | Loss_intent: 1.0807 | Loss_slots: 0.3764 | Spent: 2.7 secs | LR: 0.000377
# INFO:tensorflow:Step 7000 | Loss: 1.3451 | Loss_intent: 1.0853 | Loss_slots: 0.2598 | Spent: 2.6 secs | LR: 0.000384
# INFO:tensorflow:Step 7050 | Loss: 1.4778 | Loss_intent: 1.0901 | Loss_slots: 0.3877 | Spent: 2.6 secs | LR: 0.000391
# INFO:tensorflow:Step 7100 | Loss: 1.3732 | Loss_intent: 1.0830 | Loss_slots: 0.2902 | Spent: 2.6 secs | LR: 0.000398
# INFO:tensorflow:Step 7150 | Loss: 1.4608 | Loss_intent: 1.1097 | Loss_slots: 0.3511 | Spent: 2.6 secs | LR: 0.000405
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.975
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 7200 | Loss: 1.3589 | Loss_intent: 1.0825 | Loss_slots: 0.2764 | Spent: 4.8 secs | LR: 0.000412
# INFO:tensorflow:Step 7250 | Loss: 1.4719 | Loss_intent: 1.0809 | Loss_slots: 0.3909 | Spent: 2.6 secs | LR: 0.000419
# INFO:tensorflow:Step 7300 | Loss: 1.4574 | Loss_intent: 1.0848 | Loss_slots: 0.3726 | Spent: 2.6 secs | LR: 0.000427
# INFO:tensorflow:Step 7350 | Loss: 1.3777 | Loss_intent: 1.0848 | Loss_slots: 0.2928 | Spent: 2.6 secs | LR: 0.000434
# INFO:tensorflow:Step 7400 | Loss: 1.3595 | Loss_intent: 1.0829 | Loss_slots: 0.2766 | Spent: 2.6 secs | LR: 0.000441
# INFO:tensorflow:Step 7450 | Loss: 1.4189 | Loss_intent: 1.0870 | Loss_slots: 0.3319 | Spent: 2.6 secs | LR: 0.000448
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.975
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.984     0.987     0.986       632
#                             atis_airfare      0.980     1.000     0.990        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      0.500     1.000     0.667         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.857     0.500     0.632        12
#                             atis_airport      0.947     1.000     0.973        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      0.833     0.833     0.833         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
# ...
# INFO:tensorflow:Step 18300 | Loss: 1.3662 | Loss_intent: 1.0817 | Loss_slots: 0.2845 | Spent: 2.6 secs | LR: 0.000157
# INFO:tensorflow:Step 18350 | Loss: 1.4211 | Loss_intent: 1.0806 | Loss_slots: 0.3405 | Spent: 2.6 secs | LR: 0.000155
# INFO:tensorflow:Step 18400 | Loss: 1.4245 | Loss_intent: 1.0818 | Loss_slots: 0.3427 | Spent: 2.6 secs | LR: 0.000153
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18450 | Loss: 1.4092 | Loss_intent: 1.0805 | Loss_slots: 0.3288 | Spent: 4.8 secs | LR: 0.000151
# INFO:tensorflow:Step 18500 | Loss: 1.2913 | Loss_intent: 1.0800 | Loss_slots: 0.2113 | Spent: 2.7 secs | LR: 0.000150
# INFO:tensorflow:Step 18550 | Loss: 1.3792 | Loss_intent: 1.0804 | Loss_slots: 0.2988 | Spent: 2.6 secs | LR: 0.000148
# INFO:tensorflow:Step 18600 | Loss: 1.4541 | Loss_intent: 1.0797 | Loss_slots: 0.3744 | Spent: 2.6 secs | LR: 0.000146
# INFO:tensorflow:Step 18650 | Loss: 1.4833 | Loss_intent: 1.0800 | Loss_slots: 0.4033 | Spent: 2.6 secs | LR: 0.000144
# INFO:tensorflow:Step 18700 | Loss: 1.3307 | Loss_intent: 1.0817 | Loss_slots: 0.2490 | Spent: 2.5 secs | LR: 0.000143
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.978
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18750 | Loss: 1.3606 | Loss_intent: 1.0797 | Loss_slots: 0.2809 | Spent: 4.8 secs | LR: 0.000141
# INFO:tensorflow:Step 18800 | Loss: 1.3471 | Loss_intent: 1.0811 | Loss_slots: 0.2660 | Spent: 2.6 secs | LR: 0.000139
# INFO:tensorflow:Step 18850 | Loss: 1.4495 | Loss_intent: 1.0832 | Loss_slots: 0.3663 | Spent: 2.6 secs | LR: 0.000137
# INFO:tensorflow:Step 18900 | Loss: 1.3801 | Loss_intent: 1.0804 | Loss_slots: 0.2997 | Spent: 2.6 secs | LR: 0.000136
# INFO:tensorflow:Step 18950 | Loss: 1.4762 | Loss_intent: 1.0810 | Loss_slots: 0.3953 | Spent: 2.6 secs | LR: 0.000134
# INFO:tensorflow:Step 19000 | Loss: 1.3693 | Loss_intent: 1.0803 | Loss_slots: 0.2890 | Spent: 2.5 secs | LR: 0.000132
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.978
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19050 | Loss: 1.3267 | Loss_intent: 1.0797 | Loss_slots: 0.2470 | Spent: 4.7 secs | LR: 0.000130
# INFO:tensorflow:Step 19100 | Loss: 1.3760 | Loss_intent: 1.0822 | Loss_slots: 0.2939 | Spent: 2.6 secs | LR: 0.000129
# INFO:tensorflow:Step 19150 | Loss: 1.4018 | Loss_intent: 1.0801 | Loss_slots: 0.3216 | Spent: 2.6 secs | LR: 0.000127
# INFO:tensorflow:Step 19200 | Loss: 1.3425 | Loss_intent: 1.0798 | Loss_slots: 0.2628 | Spent: 2.6 secs | LR: 0.000125
# INFO:tensorflow:Step 19250 | Loss: 1.4003 | Loss_intent: 1.0800 | Loss_slots: 0.3203 | Spent: 2.6 secs | LR: 0.000123
# INFO:tensorflow:Step 19300 | Loss: 1.4072 | Loss_intent: 1.0797 | Loss_slots: 0.3275 | Spent: 2.7 secs | LR: 0.000122
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.978
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19350 | Loss: 1.3689 | Loss_intent: 1.0799 | Loss_slots: 0.2890 | Spent: 4.9 secs | LR: 0.000120
# INFO:tensorflow:Step 19400 | Loss: 1.4437 | Loss_intent: 1.0800 | Loss_slots: 0.3637 | Spent: 2.6 secs | LR: 0.000118
# INFO:tensorflow:Step 19450 | Loss: 1.4491 | Loss_intent: 1.0797 | Loss_slots: 0.3694 | Spent: 2.6 secs | LR: 0.000116
# INFO:tensorflow:Step 19500 | Loss: 1.3604 | Loss_intent: 1.0800 | Loss_slots: 0.2804 | Spent: 2.6 secs | LR: 0.000114
# INFO:tensorflow:Step 19550 | Loss: 1.4238 | Loss_intent: 1.0804 | Loss_slots: 0.3433 | Spent: 2.6 secs | LR: 0.000113
# INFO:tensorflow:Step 19600 | Loss: 1.2602 | Loss_intent: 1.0796 | Loss_slots: 0.1806 | Spent: 2.6 secs | LR: 0.000111
# INFO:tensorflow:Step 19650 | Loss: 1.4740 | Loss_intent: 1.0802 | Loss_slots: 0.3939 | Spent: 2.5 secs | LR: 0.000109
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.978
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19700 | Loss: 1.3000 | Loss_intent: 1.0796 | Loss_slots: 0.2204 | Spent: 4.9 secs | LR: 0.000107
# INFO:tensorflow:Step 19750 | Loss: 1.4497 | Loss_intent: 1.0796 | Loss_slots: 0.3701 | Spent: 2.6 secs | LR: 0.000106
# INFO:tensorflow:Step 19800 | Loss: 1.4138 | Loss_intent: 1.0798 | Loss_slots: 0.3340 | Spent: 2.6 secs | LR: 0.000104
# INFO:tensorflow:Step 19850 | Loss: 1.4520 | Loss_intent: 1.0806 | Loss_slots: 0.3714 | Spent: 2.6 secs | LR: 0.000102
# INFO:tensorflow:Step 19900 | Loss: 1.3576 | Loss_intent: 1.0810 | Loss_slots: 0.2766 | Spent: 2.6 secs | LR: 0.000100
# INFO:tensorflow:Step 19950 | Loss: 1.3087 | Loss_intent: 1.0871 | Loss_slots: 0.2217 | Spent: 2.7 secs | LR: 0.000101
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.976
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.984     0.991     0.987       632
#                             atis_airfare      0.980     1.000     0.990        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      0.941     0.970     0.955        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.857     0.500     0.632        12
#                             atis_airport      0.947     1.000     0.973        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.976     0.982     0.979       888
#                                macro avg      0.683     0.680     0.672       888
#                             weighted avg      0.980     0.982     0.979       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.973     0.992     0.982     716.0
#          B-fromloc.city_name      0.987     0.999     0.993     704.0
#            I-toloc.city_name      0.959     0.977     0.968     265.0
#       B-depart_date.day_name      0.986     0.991     0.988     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.957     1.000     0.978     177.0
#  B-depart_time.period_of_day      1.000     0.923     0.960     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.838     1.000     0.912      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.828     1.000     0.906      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      0.952     1.000     0.976      20.0
#                  B-city_name      0.872     0.596     0.708      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.441     1.000     0.612      15.0
#       B-fromloc.airport_name      0.480     1.000     0.649      12.0
#       B-arrive_date.day_name      0.846     1.000     0.917      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.440     1.000     0.611      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.962     0.893     0.926      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.433     0.605      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      0.909     1.000     0.952      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.714     1.000     0.833       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.643     0.429     0.514      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.833     0.909     0.870      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.500     0.667       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      0.500     1.000     0.667       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     1.000     1.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.500     0.111     0.182       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.953     0.955     0.954    3657.0
#                    macro avg      0.678     0.658     0.653    3657.0
#                 weighted avg      0.958     0.955     0.951    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.976
