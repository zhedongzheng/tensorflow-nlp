# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/spoken_language_understanding/atis/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score
from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate

import tensorflow as tf
import pprint
import logging
import time
import numpy as np

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-442ec6a690cd>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(vocab_path):
  word2idx = {}
  with open(vocab_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
def data_generator(f_path, params):
  print('Reading', f_path)
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      text, slot_intent = line.split('\t')
      words = text.split()[1:-1]
      slot_intent = slot_intent.split()
      slots, intent = slot_intent[1:-1], slot_intent[-1]
      assert len(words) == len(slots)
      
      words = [params['word2idx'].get(w, len(params['word2idx'])) for w in words]
      intent = params['intent2idx'].get(intent, len(params['intent2idx']))
      slots = [params['slot2idx'].get(s, len(params['slot2idx'])) for s in slots]
      
      yield (words, (intent, slots))

# %%
def dataset(is_training, params):
  _shapes = ([None], ((), [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (-1, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class Model(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['vocab_path']),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
    self.input_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
        params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    
    self.intent_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.fc_intent = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='fc_intent')
    self.out_linear_intent = tf.keras.layers.Dense(params['intent_size'], name='output_intent')
    self.out_linear_slot = tf.keras.layers.Dense(params['slot_size'], name='output_slot')
  
  
  def call(self, inputs, training=False):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    mask = tf.sign(inputs)
    rnn_mask = tf.cast(mask, tf.bool)
    
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    x = self.input_dropout(x, training=training)
    x, s_fw, s_bw = self.bidir_gru(x, mask=rnn_mask)
    
    x_intent = tf.concat([tf.reduce_max(x, 1), s_fw, s_bw], -1)
    x_intent = self.intent_dropout(x_intent, training=training)
    x_intent = self.out_linear_intent(self.fc_intent(x_intent))
    x_slot = self.out_linear_slot(x)
    return (x_intent, x_slot)

# %%
params = {
  'train_path': '../data/atis.train.w-intent.iob',
  'test_path': '../data/atis.test.w-intent.iob',
  'word_path': '../vocab/word.txt',
  'vocab_path': '../vocab/word.npy',
  'intent_path': '../vocab/intent.txt',
  'slot_path': '../vocab/slot.txt',
  'batch_size': 16,
  'num_samples': 4978,
  'rnn_units': 300,
  'dropout_rate': .2,
  'clip_norm': .1,
}

# %%
params['word2idx'] = get_vocab(params['word_path'])
params['intent2idx'] = get_vocab(params['intent_path'])
params['slot2idx'] = get_vocab(params['slot_path'])

params['word_size'] = len(params['word2idx']) + 1
params['intent_size'] = len(params['intent2idx']) + 1
params['slot_size'] = len(params['slot2idx']) + 1

# %%
model = Model(params)
model.build(input_shape=(None, None))
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = 1e-4,
  maximal_learning_rate = 8e-4,
  step_size = 8 * params['num_samples'] // params['batch_size'],
)
optim = tf.optimizers.Adam(1e-4)
global_step = 0

slot_best_f1 = .0
intent_acc_with_that = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

for n_epoch in range(1, 64+1):
  # TRAINING
  for (words, (intent, slots)) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      y_intent, y_slots = model(words, training=True)
      loss_intent = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(intent, len(params['intent2idx'])+1),
        logits = y_intent,
        label_smoothing = .2)
      # weight of 'O' is set to be small
      weights = tf.cast(tf.sign(slots), tf.float32)
      padding = tf.constant(1e-2, tf.float32, weights.shape)
      weights = tf.where(tf.equal(weights, 0.), padding, weights)

      loss_slots = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(slots, len(params['slot2idx'])+1),
        logits = y_slots,
        weights = tf.cast(weights, tf.float32),
        label_smoothing = .2)
      # joint loss
      loss = loss_intent + loss_slots
    
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))

    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Loss_intent: {:.4f} | Loss_slots: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), loss_intent.numpy().item(), loss_slots.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
    
  # EVALUATION
  intent_true = []
  intent_pred = []
  slot_true = []
  slot_pred = []

  for (words, (intent, slots)) in dataset(is_training=False, params=params):
    y_intent, y_slots = model(words, training=False)
    y_intent = tf.argmax(y_intent, -1)
    y_slots = tf.argmax(y_slots, -1)
    
    intent_true += intent.numpy().flatten().tolist()
    intent_pred += y_intent.numpy().flatten().tolist()
    slot_true += slots.numpy().flatten().tolist()
    slot_pred += y_slots.numpy().flatten().tolist()
    
  f1_slots = f1_score(y_true = slot_true,
                      y_pred = slot_pred,
                      labels = list(params['slot2idx'].values()),
                      sample_weight = np.sign(slot_true),
                      average='micro',)
  
  acc_intent = accuracy_score(intent_true, intent_pred)

  logger.info("Slot F1: {:.3f}, Intent Acc: {:.3f}".format(f1_slots, acc_intent))

  if n_epoch != 1 and n_epoch % 8 == 0:
    logger.info('\n'+classification_report(y_true = intent_true,
                                          y_pred = intent_pred,
                                          labels = list(params['intent2idx'].values()),
                                          target_names = list(params['intent2idx'].keys()),
                                          digits=3))
    logger.info('\n'+classification_report(y_true = slot_true,
                                          y_pred = slot_pred,
                                          labels = list(params['slot2idx'].values()),
                                          target_names = list(params['slot2idx'].keys()),
                                          sample_weight = np.sign(slot_true),
                                          digits=3))
  
  if f1_slots > slot_best_f1:
    slot_best_f1 = f1_slots
    intent_acc_with_that = acc_intent
    # you can save model here
  logger.info("Best Slot F1: {:.3f}, Intent Acc: {:.3f}".format(slot_best_f1, intent_acc_with_that))
# Out:
# [('bidirectional/forward_gru/gru_cell_1/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/bias:0', TensorShape([2, 900])),
#  ('fc_intent/kernel:0', TensorShape([1200, 300])),
#  ('fc_intent/bias:0', TensorShape([300])),
#  ('output_intent/kernel:0', TensorShape([300, 23])),
#  ('output_intent/bias:0', TensorShape([23])),
#  ('output_slot/kernel:0', TensorShape([600, 122])),
#  ('output_slot/bias:0', TensorShape([122])),
#  ('pretrained_embedding:0', TensorShape([750, 300]))]
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 0 | Loss: 4.3893 | Loss_intent: 3.2410 | Loss_slots: 1.1482 | Spent: 2.5 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 3.0150 | Loss_intent: 1.7607 | Loss_slots: 1.2543 | Spent: 2.2 secs | LR: 0.000114
# INFO:tensorflow:Step 100 | Loss: 2.4566 | Loss_intent: 1.6998 | Loss_slots: 0.7568 | Spent: 2.2 secs | LR: 0.000128
# INFO:tensorflow:Step 150 | Loss: 2.1020 | Loss_intent: 1.3305 | Loss_slots: 0.7715 | Spent: 2.3 secs | LR: 0.000142
# INFO:tensorflow:Step 200 | Loss: 2.3151 | Loss_intent: 1.5661 | Loss_slots: 0.7490 | Spent: 2.3 secs | LR: 0.000156
# INFO:tensorflow:Step 250 | Loss: 1.9906 | Loss_intent: 1.2328 | Loss_slots: 0.7578 | Spent: 2.3 secs | LR: 0.000170
# INFO:tensorflow:Step 300 | Loss: 1.9396 | Loss_intent: 1.3083 | Loss_slots: 0.6313 | Spent: 2.2 secs | LR: 0.000184
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.663, Intent Acc: 0.887
# INFO:tensorflow:Best Slot F1: 0.663, Intent Acc: 0.887
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 350 | Loss: 1.5943 | Loss_intent: 1.1324 | Loss_slots: 0.4619 | Spent: 4.5 secs | LR: 0.000198
# INFO:tensorflow:Step 400 | Loss: 1.9180 | Loss_intent: 1.2735 | Loss_slots: 0.6444 | Spent: 2.3 secs | LR: 0.000212
# INFO:tensorflow:Step 450 | Loss: 1.8439 | Loss_intent: 1.3550 | Loss_slots: 0.4889 | Spent: 2.3 secs | LR: 0.000227
# INFO:tensorflow:Step 500 | Loss: 1.9573 | Loss_intent: 1.3901 | Loss_slots: 0.5671 | Spent: 2.3 secs | LR: 0.000241
# INFO:tensorflow:Step 550 | Loss: 1.8512 | Loss_intent: 1.3255 | Loss_slots: 0.5257 | Spent: 2.2 secs | LR: 0.000255
# INFO:tensorflow:Step 600 | Loss: 1.9522 | Loss_intent: 1.4425 | Loss_slots: 0.5098 | Spent: 2.4 secs | LR: 0.000269
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.829, Intent Acc: 0.931
# INFO:tensorflow:Best Slot F1: 0.829, Intent Acc: 0.931
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 650 | Loss: 1.7384 | Loss_intent: 1.2650 | Loss_slots: 0.4734 | Spent: 4.7 secs | LR: 0.000283
# INFO:tensorflow:Step 700 | Loss: 1.4836 | Loss_intent: 1.1310 | Loss_slots: 0.3525 | Spent: 2.2 secs | LR: 0.000297
# INFO:tensorflow:Step 750 | Loss: 1.4482 | Loss_intent: 1.2116 | Loss_slots: 0.2365 | Spent: 2.2 secs | LR: 0.000311
# INFO:tensorflow:Step 800 | Loss: 1.5566 | Loss_intent: 1.1270 | Loss_slots: 0.4296 | Spent: 2.3 secs | LR: 0.000325
# INFO:tensorflow:Step 850 | Loss: 1.4891 | Loss_intent: 1.1221 | Loss_slots: 0.3669 | Spent: 2.2 secs | LR: 0.000339
# INFO:tensorflow:Step 900 | Loss: 1.5088 | Loss_intent: 1.1167 | Loss_slots: 0.3921 | Spent: 2.2 secs | LR: 0.000353
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.886, Intent Acc: 0.940
# INFO:tensorflow:Best Slot F1: 0.886, Intent Acc: 0.940
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 950 | Loss: 1.5132 | Loss_intent: 1.1273 | Loss_slots: 0.3859 | Spent: 4.6 secs | LR: 0.000367
# INFO:tensorflow:Step 1000 | Loss: 1.4526 | Loss_intent: 1.1252 | Loss_slots: 0.3275 | Spent: 2.3 secs | LR: 0.000381
# INFO:tensorflow:Step 1050 | Loss: 1.4322 | Loss_intent: 1.1129 | Loss_slots: 0.3193 | Spent: 2.2 secs | LR: 0.000395
# INFO:tensorflow:Step 1100 | Loss: 1.4864 | Loss_intent: 1.1041 | Loss_slots: 0.3823 | Spent: 2.4 secs | LR: 0.000409
# INFO:tensorflow:Step 1150 | Loss: 1.4071 | Loss_intent: 1.1310 | Loss_slots: 0.2761 | Spent: 2.5 secs | LR: 0.000423
# INFO:tensorflow:Step 1200 | Loss: 1.6179 | Loss_intent: 1.2484 | Loss_slots: 0.3695 | Spent: 2.4 secs | LR: 0.000437
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.928, Intent Acc: 0.963
# INFO:tensorflow:Best Slot F1: 0.928, Intent Acc: 0.963
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1250 | Loss: 1.4816 | Loss_intent: 1.1038 | Loss_slots: 0.3778 | Spent: 4.7 secs | LR: 0.000452
# INFO:tensorflow:Step 1300 | Loss: 1.5140 | Loss_intent: 1.1237 | Loss_slots: 0.3903 | Spent: 2.3 secs | LR: 0.000466
# INFO:tensorflow:Step 1350 | Loss: 1.4256 | Loss_intent: 1.1043 | Loss_slots: 0.3212 | Spent: 2.2 secs | LR: 0.000480
# INFO:tensorflow:Step 1400 | Loss: 1.5831 | Loss_intent: 1.1355 | Loss_slots: 0.4475 | Spent: 2.3 secs | LR: 0.000494
# INFO:tensorflow:Step 1450 | Loss: 1.5292 | Loss_intent: 1.0883 | Loss_slots: 0.4409 | Spent: 2.4 secs | LR: 0.000508
# INFO:tensorflow:Step 1500 | Loss: 1.6183 | Loss_intent: 1.1397 | Loss_slots: 0.4786 | Spent: 2.2 secs | LR: 0.000522
# INFO:tensorflow:Step 1550 | Loss: 1.4852 | Loss_intent: 1.1337 | Loss_slots: 0.3515 | Spent: 2.4 secs | LR: 0.000536
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.946, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.946, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1600 | Loss: 1.5189 | Loss_intent: 1.1696 | Loss_slots: 0.3493 | Spent: 4.6 secs | LR: 0.000550
# INFO:tensorflow:Step 1650 | Loss: 1.4322 | Loss_intent: 1.0874 | Loss_slots: 0.3448 | Spent: 2.3 secs | LR: 0.000564
# INFO:tensorflow:Step 1700 | Loss: 1.5406 | Loss_intent: 1.1062 | Loss_slots: 0.4344 | Spent: 2.3 secs | LR: 0.000578
# INFO:tensorflow:Step 1750 | Loss: 1.4858 | Loss_intent: 1.0897 | Loss_slots: 0.3961 | Spent: 2.2 secs | LR: 0.000592
# INFO:tensorflow:Step 1800 | Loss: 1.5056 | Loss_intent: 1.1250 | Loss_slots: 0.3806 | Spent: 2.3 secs | LR: 0.000606
# INFO:tensorflow:Step 1850 | Loss: 1.4225 | Loss_intent: 1.1153 | Loss_slots: 0.3072 | Spent: 2.2 secs | LR: 0.000620
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.947, Intent Acc: 0.962
# INFO:tensorflow:Best Slot F1: 0.947, Intent Acc: 0.962
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1900 | Loss: 1.4587 | Loss_intent: 1.1058 | Loss_slots: 0.3529 | Spent: 4.6 secs | LR: 0.000634
# INFO:tensorflow:Step 1950 | Loss: 1.5238 | Loss_intent: 1.1028 | Loss_slots: 0.4210 | Spent: 2.3 secs | LR: 0.000648
# INFO:tensorflow:Step 2000 | Loss: 1.5254 | Loss_intent: 1.1239 | Loss_slots: 0.4016 | Spent: 2.3 secs | LR: 0.000662
# INFO:tensorflow:Step 2050 | Loss: 1.4739 | Loss_intent: 1.1125 | Loss_slots: 0.3614 | Spent: 2.3 secs | LR: 0.000677
# INFO:tensorflow:Step 2100 | Loss: 1.4778 | Loss_intent: 1.0882 | Loss_slots: 0.3896 | Spent: 2.2 secs | LR: 0.000691
# INFO:tensorflow:Step 2150 | Loss: 1.3935 | Loss_intent: 1.1013 | Loss_slots: 0.2922 | Spent: 2.2 secs | LR: 0.000705
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.944, Intent Acc: 0.963
# INFO:tensorflow:Best Slot F1: 0.947, Intent Acc: 0.962
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2200 | Loss: 1.4449 | Loss_intent: 1.1143 | Loss_slots: 0.3306 | Spent: 4.6 secs | LR: 0.000719
# INFO:tensorflow:Step 2250 | Loss: 1.4965 | Loss_intent: 1.1160 | Loss_slots: 0.3805 | Spent: 2.4 secs | LR: 0.000733
# INFO:tensorflow:Step 2300 | Loss: 1.3605 | Loss_intent: 1.0849 | Loss_slots: 0.2756 | Spent: 2.3 secs | LR: 0.000747
# INFO:tensorflow:Step 2350 | Loss: 1.4170 | Loss_intent: 1.1624 | Loss_slots: 0.2546 | Spent: 2.4 secs | LR: 0.000761
# INFO:tensorflow:Step 2400 | Loss: 1.4851 | Loss_intent: 1.0913 | Loss_slots: 0.3938 | Spent: 2.3 secs | LR: 0.000775
# INFO:tensorflow:Step 2450 | Loss: 1.4261 | Loss_intent: 1.0998 | Loss_slots: 0.3263 | Spent: 2.3 secs | LR: 0.000789
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.969
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.974     0.992     0.983       632
#                             atis_airfare      0.959     0.979     0.969        48
#                      atis_ground_service      0.973     1.000     0.986        36
#                             atis_airline      1.000     0.974     0.987        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.500     0.083     0.143        12
#                             atis_airport      1.000     1.000     1.000        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     0.714     0.833         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.969     0.974     0.971       888
#                                macro avg      0.667     0.647     0.642       888
#                             weighted avg      0.966     0.974     0.967       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.967     0.993     0.980     716.0
#          B-fromloc.city_name      0.982     0.999     0.990     704.0
#            I-toloc.city_name      0.967     0.981     0.974     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.972     0.994     0.983     177.0
#  B-depart_time.period_of_day      0.991     0.892     0.939     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.770     1.000     0.870      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.800     1.000     0.889      24.0
#  B-depart_time.time_relative      0.955     0.985     0.970      65.0
#           I-depart_time.time      0.897     1.000     0.945      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.912     0.544     0.681      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      1.000     0.971     0.985      34.0
#  B-arrive_time.time_relative      0.879     0.935     0.906      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     1.000     1.000      15.0
#       I-fromloc.airport_name      0.429     1.000     0.600      15.0
#       B-fromloc.airport_name      0.444     1.000     0.615      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.379     1.000     0.550      11.0
#  B-depart_date.date_relative      0.895     1.000     0.944      17.0
#           B-toloc.state_name      0.833     0.893     0.862      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.909     0.345     0.500      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.696     0.533     0.604      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     0.900     0.947      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     0.333     0.500       3.0
#         B-fromloc.state_name      0.944     1.000     0.971      17.0
#               B-airport_name      0.750     0.286     0.414      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.909     0.952      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.667     0.667     0.667       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.500     0.667       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     0.500     0.667       2.0
#                 I-flight_mod      0.000     0.000     0.000       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.333     0.333     0.333       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      0.000     0.000     0.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.500     0.667       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.000     0.000     0.000       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.948     0.950     0.949    3657.0
#                    macro avg      0.642     0.620     0.619    3657.0
#                 weighted avg      0.948     0.950     0.944    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.949, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:tensorflow:Step 2500 | Loss: 1.4691 | Loss_intent: 1.0955 | Loss_slots: 0.3736 | Spent: 4.5 secs | LR: 0.000797
# INFO:tensorflow:Step 2550 | Loss: 1.3247 | Loss_intent: 1.1170 | Loss_slots: 0.2077 | Spent: 2.4 secs | LR: 0.000783
# INFO:tensorflow:Step 2600 | Loss: 1.3363 | Loss_intent: 1.1016 | Loss_slots: 0.2347 | Spent: 2.3 secs | LR: 0.000769
# INFO:tensorflow:Step 2650 | Loss: 1.4571 | Loss_intent: 1.0846 | Loss_slots: 0.3725 | Spent: 2.5 secs | LR: 0.000755
# INFO:tensorflow:Step 2700 | Loss: 1.4036 | Loss_intent: 1.1983 | Loss_slots: 0.2053 | Spent: 2.4 secs | LR: 0.000741
# INFO:tensorflow:Step 2750 | Loss: 1.4242 | Loss_intent: 1.1000 | Loss_slots: 0.3242 | Spent: 2.2 secs | LR: 0.000727
# INFO:tensorflow:Step 2800 | Loss: 1.4561 | Loss_intent: 1.0909 | Loss_slots: 0.3652 | Spent: 2.3 secs | LR: 0.000713
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.971
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2850 | Loss: 1.4663 | Loss_intent: 1.0929 | Loss_slots: 0.3734 | Spent: 4.4 secs | LR: 0.000698
# INFO:tensorflow:Step 2900 | Loss: 1.4286 | Loss_intent: 1.0961 | Loss_slots: 0.3325 | Spent: 2.3 secs | LR: 0.000684
# INFO:tensorflow:Step 2950 | Loss: 1.4292 | Loss_intent: 1.0987 | Loss_slots: 0.3305 | Spent: 2.3 secs | LR: 0.000670
# INFO:tensorflow:Step 3000 | Loss: 1.3621 | Loss_intent: 1.0874 | Loss_slots: 0.2747 | Spent: 2.3 secs | LR: 0.000656
# INFO:tensorflow:Step 3050 | Loss: 1.3833 | Loss_intent: 1.0900 | Loss_slots: 0.2932 | Spent: 2.3 secs | LR: 0.000642
# INFO:tensorflow:Step 3100 | Loss: 1.4649 | Loss_intent: 1.0840 | Loss_slots: 0.3808 | Spent: 2.3 secs | LR: 0.000628
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.971
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3150 | Loss: 1.3550 | Loss_intent: 1.0873 | Loss_slots: 0.2677 | Spent: 4.7 secs | LR: 0.000614
# INFO:tensorflow:Step 3200 | Loss: 1.3396 | Loss_intent: 1.0922 | Loss_slots: 0.2474 | Spent: 2.3 secs | LR: 0.000600
# INFO:tensorflow:Step 3250 | Loss: 1.3813 | Loss_intent: 1.0866 | Loss_slots: 0.2947 | Spent: 2.5 secs | LR: 0.000586
# INFO:tensorflow:Step 3300 | Loss: 1.4451 | Loss_intent: 1.0887 | Loss_slots: 0.3563 | Spent: 2.7 secs | LR: 0.000572
# INFO:tensorflow:Step 3350 | Loss: 1.3400 | Loss_intent: 1.0862 | Loss_slots: 0.2537 | Spent: 2.5 secs | LR: 0.000558
# INFO:tensorflow:Step 3400 | Loss: 1.4679 | Loss_intent: 1.0925 | Loss_slots: 0.3753 | Spent: 2.4 secs | LR: 0.000544
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3450 | Loss: 1.4487 | Loss_intent: 1.0879 | Loss_slots: 0.3608 | Spent: 4.7 secs | LR: 0.000530
# INFO:tensorflow:Step 3500 | Loss: 1.4469 | Loss_intent: 1.0887 | Loss_slots: 0.3581 | Spent: 2.2 secs | LR: 0.000516
# INFO:tensorflow:Step 3550 | Loss: 1.4066 | Loss_intent: 1.0961 | Loss_slots: 0.3105 | Spent: 2.4 secs | LR: 0.000502
# INFO:tensorflow:Step 3600 | Loss: 1.5372 | Loss_intent: 1.0834 | Loss_slots: 0.4538 | Spent: 2.3 secs | LR: 0.000488
# INFO:tensorflow:Step 3650 | Loss: 1.3657 | Loss_intent: 1.0841 | Loss_slots: 0.2816 | Spent: 2.3 secs | LR: 0.000473
# INFO:tensorflow:Step 3700 | Loss: 1.4145 | Loss_intent: 1.0899 | Loss_slots: 0.3245 | Spent: 2.3 secs | LR: 0.000459
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3750 | Loss: 1.3652 | Loss_intent: 1.0820 | Loss_slots: 0.2832 | Spent: 4.6 secs | LR: 0.000445
# INFO:tensorflow:Step 3800 | Loss: 1.3274 | Loss_intent: 1.0830 | Loss_slots: 0.2444 | Spent: 2.4 secs | LR: 0.000431
# INFO:tensorflow:Step 3850 | Loss: 1.3630 | Loss_intent: 1.0815 | Loss_slots: 0.2815 | Spent: 2.2 secs | LR: 0.000417
# INFO:tensorflow:Step 3900 | Loss: 1.4307 | Loss_intent: 1.0822 | Loss_slots: 0.3485 | Spent: 2.3 secs | LR: 0.000403
# INFO:tensorflow:Step 3950 | Loss: 1.4593 | Loss_intent: 1.0864 | Loss_slots: 0.3729 | Spent: 2.2 secs | LR: 0.000389
# INFO:tensorflow:Step 4000 | Loss: 1.4034 | Loss_intent: 1.0908 | Loss_slots: 0.3126 | Spent: 2.2 secs | LR: 0.000375
# INFO:tensorflow:Step 4050 | Loss: 1.4227 | Loss_intent: 1.0810 | Loss_slots: 0.3417 | Spent: 2.4 secs | LR: 0.000361
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4100 | Loss: 1.3947 | Loss_intent: 1.0820 | Loss_slots: 0.3127 | Spent: 4.6 secs | LR: 0.000347
# INFO:tensorflow:Step 4150 | Loss: 1.3446 | Loss_intent: 1.0863 | Loss_slots: 0.2583 | Spent: 2.2 secs | LR: 0.000333
# INFO:tensorflow:Step 4200 | Loss: 1.4484 | Loss_intent: 1.0851 | Loss_slots: 0.3632 | Spent: 2.2 secs | LR: 0.000319
# INFO:tensorflow:Step 4250 | Loss: 1.4173 | Loss_intent: 1.0839 | Loss_slots: 0.3334 | Spent: 2.2 secs | LR: 0.000305
# INFO:tensorflow:Step 4300 | Loss: 1.3777 | Loss_intent: 1.0806 | Loss_slots: 0.2971 | Spent: 2.2 secs | LR: 0.000291
# INFO:tensorflow:Step 4350 | Loss: 1.3523 | Loss_intent: 1.0823 | Loss_slots: 0.2700 | Spent: 2.4 secs | LR: 0.000277
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4400 | Loss: 1.4130 | Loss_intent: 1.0820 | Loss_slots: 0.3309 | Spent: 4.7 secs | LR: 0.000263
# INFO:tensorflow:Step 4450 | Loss: 1.4325 | Loss_intent: 1.0812 | Loss_slots: 0.3513 | Spent: 2.3 secs | LR: 0.000248
# INFO:tensorflow:Step 4500 | Loss: 1.4444 | Loss_intent: 1.0802 | Loss_slots: 0.3642 | Spent: 2.3 secs | LR: 0.000234
# INFO:tensorflow:Step 4550 | Loss: 1.3148 | Loss_intent: 1.0853 | Loss_slots: 0.2295 | Spent: 2.2 secs | LR: 0.000220
# INFO:tensorflow:Step 4600 | Loss: 1.4514 | Loss_intent: 1.0815 | Loss_slots: 0.3699 | Spent: 2.3 secs | LR: 0.000206
# INFO:tensorflow:Step 4650 | Loss: 1.4795 | Loss_intent: 1.0852 | Loss_slots: 0.3943 | Spent: 2.5 secs | LR: 0.000192
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4700 | Loss: 1.4873 | Loss_intent: 1.0808 | Loss_slots: 0.4064 | Spent: 4.8 secs | LR: 0.000178
# INFO:tensorflow:Step 4750 | Loss: 1.4064 | Loss_intent: 1.0833 | Loss_slots: 0.3230 | Spent: 2.3 secs | LR: 0.000164
# INFO:tensorflow:Step 4800 | Loss: 1.4339 | Loss_intent: 1.0881 | Loss_slots: 0.3458 | Spent: 2.2 secs | LR: 0.000150
# INFO:tensorflow:Step 4850 | Loss: 1.4139 | Loss_intent: 1.0801 | Loss_slots: 0.3338 | Spent: 2.2 secs | LR: 0.000136
# INFO:tensorflow:Step 4900 | Loss: 1.3841 | Loss_intent: 1.0808 | Loss_slots: 0.3034 | Spent: 2.4 secs | LR: 0.000122
# INFO:tensorflow:Step 4950 | Loss: 1.4568 | Loss_intent: 1.0810 | Loss_slots: 0.3758 | Spent: 2.2 secs | LR: 0.000108
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.974
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.975     0.992     0.984       632
#                             atis_airfare      0.979     0.979     0.979        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.944     0.971        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.974     0.980     0.977       888
#                                macro avg      0.687     0.672     0.669       888
#                             weighted avg      0.976     0.980     0.976       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.970     0.993     0.981     716.0
#          B-fromloc.city_name      0.986     1.000     0.993     704.0
#            I-toloc.city_name      0.959     0.981     0.970     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.962     1.000     0.981     177.0
#  B-depart_time.period_of_day      1.000     0.923     0.960     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.838     1.000     0.912      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.828     1.000     0.906      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.963     1.000     0.981      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.865     0.561     0.681      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.971     0.971     0.971      34.0
#  B-arrive_time.time_relative      0.879     0.935     0.906      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.429     1.000     0.600      15.0
#       B-fromloc.airport_name      0.480     1.000     0.649      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.344     1.000     0.512      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.806     0.893     0.847      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.933     0.467     0.622      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      0.909     1.000     0.952      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.778     0.333     0.467      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.909     0.952      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.500     0.667       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.667     0.800       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      1.000     0.667     0.800       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.952     0.954     0.953    3657.0
#                    macro avg      0.682     0.653     0.654    3657.0
#                 weighted avg      0.956     0.954     0.950    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5000 | Loss: 1.3169 | Loss_intent: 1.0821 | Loss_slots: 0.2348 | Spent: 4.6 secs | LR: 0.000103
# INFO:tensorflow:Step 5050 | Loss: 1.3974 | Loss_intent: 1.0816 | Loss_slots: 0.3158 | Spent: 2.3 secs | LR: 0.000110
# INFO:tensorflow:Step 5100 | Loss: 1.3896 | Loss_intent: 1.0818 | Loss_slots: 0.3077 | Spent: 2.3 secs | LR: 0.000117
# INFO:tensorflow:Step 5150 | Loss: 1.3989 | Loss_intent: 1.0811 | Loss_slots: 0.3178 | Spent: 2.4 secs | LR: 0.000124
# INFO:tensorflow:Step 5200 | Loss: 1.4060 | Loss_intent: 1.0827 | Loss_slots: 0.3233 | Spent: 2.3 secs | LR: 0.000131
# INFO:tensorflow:Step 5250 | Loss: 1.2539 | Loss_intent: 1.0802 | Loss_slots: 0.1737 | Spent: 2.4 secs | LR: 0.000138
# INFO:tensorflow:Step 5300 | Loss: 1.3509 | Loss_intent: 1.0806 | Loss_slots: 0.2703 | Spent: 2.3 secs | LR: 0.000145
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5350 | Loss: 1.3536 | Loss_intent: 1.0806 | Loss_slots: 0.2730 | Spent: 5.1 secs | LR: 0.000152
# INFO:tensorflow:Step 5400 | Loss: 1.4581 | Loss_intent: 1.0815 | Loss_slots: 0.3766 | Spent: 2.4 secs | LR: 0.000159
# INFO:tensorflow:Step 5450 | Loss: 1.3845 | Loss_intent: 1.0813 | Loss_slots: 0.3033 | Spent: 2.4 secs | LR: 0.000166
# INFO:tensorflow:Step 5500 | Loss: 1.4189 | Loss_intent: 1.0851 | Loss_slots: 0.3337 | Spent: 2.3 secs | LR: 0.000173
# INFO:tensorflow:Step 5550 | Loss: 1.4380 | Loss_intent: 1.0821 | Loss_slots: 0.3559 | Spent: 2.3 secs | LR: 0.000180
# INFO:tensorflow:Step 5600 | Loss: 1.3741 | Loss_intent: 1.0819 | Loss_slots: 0.2922 | Spent: 2.2 secs | LR: 0.000187
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5650 | Loss: 1.3520 | Loss_intent: 1.0803 | Loss_slots: 0.2717 | Spent: 4.6 secs | LR: 0.000194
# INFO:tensorflow:Step 5700 | Loss: 1.4575 | Loss_intent: 1.0828 | Loss_slots: 0.3748 | Spent: 2.5 secs | LR: 0.000202
# INFO:tensorflow:Step 5750 | Loss: 1.4058 | Loss_intent: 1.0817 | Loss_slots: 0.3241 | Spent: 2.3 secs | LR: 0.000209
# INFO:tensorflow:Step 5800 | Loss: 1.3972 | Loss_intent: 1.0805 | Loss_slots: 0.3167 | Spent: 2.2 secs | LR: 0.000216
# INFO:tensorflow:Step 5850 | Loss: 1.4016 | Loss_intent: 1.0817 | Loss_slots: 0.3199 | Spent: 2.3 secs | LR: 0.000223
# INFO:tensorflow:Step 5900 | Loss: 1.3479 | Loss_intent: 1.0832 | Loss_slots: 0.2647 | Spent: 2.2 secs | LR: 0.000230
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5950 | Loss: 1.3024 | Loss_intent: 1.0836 | Loss_slots: 0.2188 | Spent: 4.6 secs | LR: 0.000237
# INFO:tensorflow:Step 6000 | Loss: 1.4234 | Loss_intent: 1.0822 | Loss_slots: 0.3413 | Spent: 2.3 secs | LR: 0.000244
# INFO:tensorflow:Step 6050 | Loss: 1.3898 | Loss_intent: 1.0808 | Loss_slots: 0.3090 | Spent: 2.3 secs | LR: 0.000251
# INFO:tensorflow:Step 6100 | Loss: 1.4658 | Loss_intent: 1.0845 | Loss_slots: 0.3813 | Spent: 2.3 secs | LR: 0.000258
# INFO:tensorflow:Step 6150 | Loss: 1.3662 | Loss_intent: 1.0877 | Loss_slots: 0.2784 | Spent: 2.3 secs | LR: 0.000265
# INFO:tensorflow:Step 6200 | Loss: 1.3320 | Loss_intent: 1.0814 | Loss_slots: 0.2507 | Spent: 2.2 secs | LR: 0.000272
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.972
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6250 | Loss: 1.4378 | Loss_intent: 1.0812 | Loss_slots: 0.3567 | Spent: 4.4 secs | LR: 0.000279
# INFO:tensorflow:Step 6300 | Loss: 1.3689 | Loss_intent: 1.0826 | Loss_slots: 0.2864 | Spent: 2.2 secs | LR: 0.000286
# INFO:tensorflow:Step 6350 | Loss: 1.3776 | Loss_intent: 1.0850 | Loss_slots: 0.2926 | Spent: 2.3 secs | LR: 0.000293
# INFO:tensorflow:Step 6400 | Loss: 1.4209 | Loss_intent: 1.0898 | Loss_slots: 0.3311 | Spent: 2.4 secs | LR: 0.000300
# INFO:tensorflow:Step 6450 | Loss: 1.3806 | Loss_intent: 1.0812 | Loss_slots: 0.2994 | Spent: 2.3 secs | LR: 0.000307
# INFO:tensorflow:Step 6500 | Loss: 1.3922 | Loss_intent: 1.0807 | Loss_slots: 0.3114 | Spent: 2.3 secs | LR: 0.000314
# INFO:tensorflow:Step 6550 | Loss: 1.3871 | Loss_intent: 1.0804 | Loss_slots: 0.3066 | Spent: 2.3 secs | LR: 0.000321
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6600 | Loss: 1.4015 | Loss_intent: 1.0815 | Loss_slots: 0.3199 | Spent: 4.7 secs | LR: 0.000328
# INFO:tensorflow:Step 6650 | Loss: 1.4172 | Loss_intent: 1.0815 | Loss_slots: 0.3356 | Spent: 2.3 secs | LR: 0.000335
# INFO:tensorflow:Step 6700 | Loss: 1.4048 | Loss_intent: 1.0806 | Loss_slots: 0.3241 | Spent: 2.4 secs | LR: 0.000342
# INFO:tensorflow:Step 6750 | Loss: 1.3364 | Loss_intent: 1.0804 | Loss_slots: 0.2560 | Spent: 2.3 secs | LR: 0.000349
# INFO:tensorflow:Step 6800 | Loss: 1.3140 | Loss_intent: 1.0803 | Loss_slots: 0.2337 | Spent: 2.2 secs | LR: 0.000356
# INFO:tensorflow:Step 6850 | Loss: 1.2659 | Loss_intent: 1.0810 | Loss_slots: 0.1849 | Spent: 2.3 secs | LR: 0.000363
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6900 | Loss: 1.4086 | Loss_intent: 1.0831 | Loss_slots: 0.3255 | Spent: 4.8 secs | LR: 0.000370
# INFO:tensorflow:Step 6950 | Loss: 1.3728 | Loss_intent: 1.0810 | Loss_slots: 0.2919 | Spent: 2.4 secs | LR: 0.000377
# INFO:tensorflow:Step 7000 | Loss: 1.3924 | Loss_intent: 1.0825 | Loss_slots: 0.3099 | Spent: 2.2 secs | LR: 0.000384
# INFO:tensorflow:Step 7050 | Loss: 1.4533 | Loss_intent: 1.0822 | Loss_slots: 0.3711 | Spent: 2.2 secs | LR: 0.000391
# INFO:tensorflow:Step 7100 | Loss: 1.5029 | Loss_intent: 1.0915 | Loss_slots: 0.4115 | Spent: 2.5 secs | LR: 0.000398
# INFO:tensorflow:Step 7150 | Loss: 1.4204 | Loss_intent: 1.0829 | Loss_slots: 0.3375 | Spent: 2.3 secs | LR: 0.000405
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 7200 | Loss: 1.4691 | Loss_intent: 1.0827 | Loss_slots: 0.3863 | Spent: 4.5 secs | LR: 0.000412
# INFO:tensorflow:Step 7250 | Loss: 1.3499 | Loss_intent: 1.0804 | Loss_slots: 0.2695 | Spent: 2.3 secs | LR: 0.000419
# INFO:tensorflow:Step 7300 | Loss: 1.4232 | Loss_intent: 1.0838 | Loss_slots: 0.3394 | Spent: 2.3 secs | LR: 0.000427
# INFO:tensorflow:Step 7350 | Loss: 1.3952 | Loss_intent: 1.0858 | Loss_slots: 0.3094 | Spent: 2.2 secs | LR: 0.000434
# INFO:tensorflow:Step 7400 | Loss: 1.4157 | Loss_intent: 1.0816 | Loss_slots: 0.3340 | Spent: 2.3 secs | LR: 0.000441
# INFO:tensorflow:Step 7450 | Loss: 1.3281 | Loss_intent: 1.0810 | Loss_slots: 0.2471 | Spent: 2.4 secs | LR: 0.000448
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.975
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.978     0.992     0.985       632
#                             atis_airfare      0.959     0.979     0.969        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.375     1.000     0.545         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.944     0.971        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      1.000     1.000     1.000         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.975     0.981     0.978       888
#                                macro avg      0.688     0.674     0.670       888
#                             weighted avg      0.978     0.981     0.978       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.970     0.993     0.981     716.0
#          B-fromloc.city_name      0.985     0.999     0.992     704.0
#            I-toloc.city_name      0.956     0.981     0.968     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.962     1.000     0.981     177.0
#  B-depart_time.period_of_day      1.000     0.931     0.964     130.0
# ...
# INFO:tensorflow:Step 18300 | Loss: 1.3211 | Loss_intent: 1.0810 | Loss_slots: 0.2401 | Spent: 2.7 secs | LR: 0.000157
# INFO:tensorflow:Step 18350 | Loss: 1.3687 | Loss_intent: 1.0798 | Loss_slots: 0.2889 | Spent: 2.4 secs | LR: 0.000155
# INFO:tensorflow:Step 18400 | Loss: 1.3144 | Loss_intent: 1.0805 | Loss_slots: 0.2339 | Spent: 2.3 secs | LR: 0.000153
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18450 | Loss: 1.3529 | Loss_intent: 1.0816 | Loss_slots: 0.2713 | Spent: 4.6 secs | LR: 0.000151
# INFO:tensorflow:Step 18500 | Loss: 1.3762 | Loss_intent: 1.0799 | Loss_slots: 0.2963 | Spent: 2.3 secs | LR: 0.000150
# INFO:tensorflow:Step 18550 | Loss: 1.4320 | Loss_intent: 1.0800 | Loss_slots: 0.3520 | Spent: 2.3 secs | LR: 0.000148
# INFO:tensorflow:Step 18600 | Loss: 1.4221 | Loss_intent: 1.0803 | Loss_slots: 0.3418 | Spent: 2.3 secs | LR: 0.000146
# INFO:tensorflow:Step 18650 | Loss: 1.4109 | Loss_intent: 1.0809 | Loss_slots: 0.3300 | Spent: 2.4 secs | LR: 0.000144
# INFO:tensorflow:Step 18700 | Loss: 1.3604 | Loss_intent: 1.0800 | Loss_slots: 0.2804 | Spent: 2.3 secs | LR: 0.000143
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18750 | Loss: 1.3280 | Loss_intent: 1.0799 | Loss_slots: 0.2481 | Spent: 4.4 secs | LR: 0.000141
# INFO:tensorflow:Step 18800 | Loss: 1.3840 | Loss_intent: 1.0807 | Loss_slots: 0.3033 | Spent: 2.3 secs | LR: 0.000139
# INFO:tensorflow:Step 18850 | Loss: 1.3972 | Loss_intent: 1.0797 | Loss_slots: 0.3175 | Spent: 2.3 secs | LR: 0.000137
# INFO:tensorflow:Step 18900 | Loss: 1.2458 | Loss_intent: 1.0804 | Loss_slots: 0.1654 | Spent: 2.3 secs | LR: 0.000136
# INFO:tensorflow:Step 18950 | Loss: 1.3725 | Loss_intent: 1.0804 | Loss_slots: 0.2922 | Spent: 2.2 secs | LR: 0.000134
# INFO:tensorflow:Step 19000 | Loss: 1.2822 | Loss_intent: 1.0811 | Loss_slots: 0.2011 | Spent: 2.2 secs | LR: 0.000132
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19050 | Loss: 1.2943 | Loss_intent: 1.0810 | Loss_slots: 0.2133 | Spent: 4.8 secs | LR: 0.000130
# INFO:tensorflow:Step 19100 | Loss: 1.4137 | Loss_intent: 1.0802 | Loss_slots: 0.3335 | Spent: 2.3 secs | LR: 0.000129
# INFO:tensorflow:Step 19150 | Loss: 1.3502 | Loss_intent: 1.0799 | Loss_slots: 0.2703 | Spent: 2.4 secs | LR: 0.000127
# INFO:tensorflow:Step 19200 | Loss: 1.4168 | Loss_intent: 1.0801 | Loss_slots: 0.3367 | Spent: 2.4 secs | LR: 0.000125
# INFO:tensorflow:Step 19250 | Loss: 1.4388 | Loss_intent: 1.0799 | Loss_slots: 0.3588 | Spent: 2.2 secs | LR: 0.000123
# INFO:tensorflow:Step 19300 | Loss: 1.3850 | Loss_intent: 1.0809 | Loss_slots: 0.3040 | Spent: 2.3 secs | LR: 0.000122
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19350 | Loss: 1.2560 | Loss_intent: 1.0802 | Loss_slots: 0.1757 | Spent: 4.6 secs | LR: 0.000120
# INFO:tensorflow:Step 19400 | Loss: 1.4447 | Loss_intent: 1.0800 | Loss_slots: 0.3647 | Spent: 2.4 secs | LR: 0.000118
# INFO:tensorflow:Step 19450 | Loss: 1.4071 | Loss_intent: 1.0797 | Loss_slots: 0.3274 | Spent: 2.2 secs | LR: 0.000116
# INFO:tensorflow:Step 19500 | Loss: 1.2685 | Loss_intent: 1.0810 | Loss_slots: 0.1875 | Spent: 2.4 secs | LR: 0.000114
# INFO:tensorflow:Step 19550 | Loss: 1.3886 | Loss_intent: 1.0813 | Loss_slots: 0.3073 | Spent: 2.3 secs | LR: 0.000113
# INFO:tensorflow:Step 19600 | Loss: 1.4181 | Loss_intent: 1.0799 | Loss_slots: 0.3382 | Spent: 2.1 secs | LR: 0.000111
# INFO:tensorflow:Step 19650 | Loss: 1.3914 | Loss_intent: 1.0798 | Loss_slots: 0.3116 | Spent: 2.2 secs | LR: 0.000109
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19700 | Loss: 1.3991 | Loss_intent: 1.0817 | Loss_slots: 0.3174 | Spent: 4.6 secs | LR: 0.000107
# INFO:tensorflow:Step 19750 | Loss: 1.3336 | Loss_intent: 1.0798 | Loss_slots: 0.2538 | Spent: 2.3 secs | LR: 0.000106
# INFO:tensorflow:Step 19800 | Loss: 1.2687 | Loss_intent: 1.0799 | Loss_slots: 0.1888 | Spent: 2.2 secs | LR: 0.000104
# INFO:tensorflow:Step 19850 | Loss: 1.4346 | Loss_intent: 1.0799 | Loss_slots: 0.3547 | Spent: 2.3 secs | LR: 0.000102
# INFO:tensorflow:Step 19900 | Loss: 1.2896 | Loss_intent: 1.0799 | Loss_slots: 0.2097 | Spent: 2.4 secs | LR: 0.000100
# INFO:tensorflow:Step 19950 | Loss: 1.3572 | Loss_intent: 1.0801 | Loss_slots: 0.2770 | Spent: 2.3 secs | LR: 0.000101
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.974
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.975     0.992     0.984       632
#                             atis_airfare      0.979     0.979     0.979        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.944     0.971        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.974     0.980     0.977       888
#                                macro avg      0.687     0.672     0.669       888
#                             weighted avg      0.976     0.980     0.976       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.971     0.992     0.981     716.0
#          B-fromloc.city_name      0.983     0.999     0.991     704.0
#            I-toloc.city_name      0.959     0.981     0.970     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.962     1.000     0.981     177.0
#  B-depart_time.period_of_day      1.000     0.923     0.960     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.792     1.000     0.884      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.828     1.000     0.906      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.821     0.561     0.667      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.441     1.000     0.612      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.393     1.000     0.564      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.862     0.893     0.877      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.933     0.467     0.622      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      0.909     1.000     0.952      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.833     1.000     0.909       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.778     0.333     0.467      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.909     0.952      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.500     0.667       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     1.000     1.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.952     0.954     0.953    3657.0
#                    macro avg      0.679     0.657     0.655    3657.0
#                 weighted avg      0.956     0.954     0.950    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.974
