# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/spoken_language_understanding/atis/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score

import tensorflow as tf
import tensorflow_addons as tfa
import pprint
import logging
import time
import numpy as np

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-dd37b7ada4e1>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(vocab_path):
  word2idx = {}
  with open(vocab_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
def data_generator(f_path, params):
  print('Reading', f_path)
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      text, slot_intent = line.split('\t')
      words = text.split()[1:-1]
      slot_intent = slot_intent.split()
      slots, intent = slot_intent[1:-1], slot_intent[-1]
      assert len(words) == len(slots)
      
      words = [params['word2idx'].get(w, len(params['word2idx'])) for w in words]
      intent = params['intent2idx'].get(intent, len(params['intent2idx']))
      slots = [params['slot2idx'].get(s, len(params['slot2idx'])) for s in slots]
      
      yield (words, (intent, slots))

# %%
def dataset(is_training, params):
  _shapes = ([None], ((), [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (-1, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class Model(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['vocab_path']),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
    self.input_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
        params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    
    self.intent_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.fc_intent = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='fc_intent')
    self.out_linear_intent = tf.keras.layers.Dense(params['intent_size'], name='output_intent')
    self.out_linear_slot = tf.keras.layers.Dense(params['slot_size'], name='output_slot')

    self.trans_params = self.add_weight('transitions', (params['slot_size'], params['slot_size']))
  
  
  def call(self, inputs, training=False):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    mask = tf.sign(inputs)
    rnn_mask = tf.cast(mask, tf.bool)
    
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    x = self.input_dropout(x, training=training)
    x, s_fw, s_bw = self.bidir_gru(x, mask=rnn_mask)
    
    x_intent = tf.concat([tf.reduce_max(x, 1), s_fw, s_bw], -1)
    x_intent = self.intent_dropout(x_intent, training=training)
    x_intent = self.out_linear_intent(self.fc_intent(x_intent))
    x_slot = self.out_linear_slot(x)
    return (x_intent, x_slot)

# %%
params = {
  'train_path': '../data/atis.train.w-intent.iob',
  'test_path': '../data/atis.test.w-intent.iob',
  'word_path': '../vocab/word.txt',
  'vocab_path': '../vocab/word.npy',
  'intent_path': '../vocab/intent.txt',
  'slot_path': '../vocab/slot.txt',
  'batch_size': 16,
  'num_samples': 4978,
  'rnn_units': 300,
  'num_heads': 6,
  'multiplier': 2,
  'dropout_rate': .2,
  'clip_norm': .1,
}

# %%
params['word2idx'] = get_vocab(params['word_path'])
params['intent2idx'] = get_vocab(params['intent_path'])
params['slot2idx'] = get_vocab(params['slot_path'])

params['word_size'] = len(params['word2idx']) + 1
params['intent_size'] = len(params['intent2idx']) + 1
params['slot_size'] = len(params['slot2idx']) + 1

# %%
model = Model(params)
model.build(input_shape=(None, None))
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = tfa.optimizers.Triangular2CyclicalLearningRate(
  initial_learning_rate = 1e-4,
  maximal_learning_rate = 8e-4,
  step_size = 8 * params['num_samples'] // params['batch_size'],
)
optim = tf.optimizers.Adam(1e-4)
global_step = 0

slot_best_f1 = .0
intent_acc_with_that = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

for n_epoch in range(1, 64+1):
  # TRAINING
  for (words, (intent, slots)) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      y_intent, y_slots = model(words, training=True)

      loss_intent = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(intent, len(params['intent2idx'])+1),
        logits = y_intent,
        label_smoothing = .2)
      
      log_likelihood, _ = tfa.text.crf_log_likelihood(
          inputs = y_slots,
          tag_indices = slots,
          sequence_lengths = tf.math.count_nonzero(words, axis=1, dtype=tf.int32),
          transition_params = model.trans_params,)
      loss_slots = - tf.reduce_mean(log_likelihood)

      loss = 4. * loss_intent + loss_slots
    
    train_vars = model.trainable_variables
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, train_vars)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, train_vars))

    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Loss_intent: {:.4f} | Loss_slots: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), loss_intent.numpy().item(), loss_slots.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
    
  # EVALUATION
  intent_true = []
  intent_pred = []
  slot_true = []
  slot_pred = []

  for (words, (intent, slots)) in dataset(is_training=False, params=params):
    y_intent, y_slots = model(words, training=False)
    y_intent = tf.argmax(y_intent, -1)
    y_slots, _ = tfa.text.crf_decode(
      potentials = y_slots,
      transition_params = model.trans_params,
      sequence_length = tf.math.count_nonzero(words, axis=1, dtype=tf.int32),)
    
    intent_true += intent.numpy().flatten().tolist()
    intent_pred += y_intent.numpy().flatten().tolist()
    slot_true += slots.numpy().flatten().tolist()
    slot_pred += y_slots.numpy().flatten().tolist()
    
  f1_slots = f1_score(y_true = slot_true,
                      y_pred = slot_pred,
                      labels = list(params['slot2idx'].values()),
                      sample_weight = np.sign(slot_true),
                      average='micro',)
  
  acc_intent = accuracy_score(intent_true, intent_pred)

  logger.info("Slot F1: {:.3f}, Intent Acc: {:.3f}".format(f1_slots, acc_intent))

  if n_epoch != 1 and n_epoch % 8 == 0:
    logger.info('\n'+classification_report(y_true = intent_true,
                                          y_pred = intent_pred,
                                          labels = list(params['intent2idx'].values()),
                                          target_names = list(params['intent2idx'].keys()),
                                          digits=3))
    logger.info('\n'+classification_report(y_true = slot_true,
                                          y_pred = slot_pred,
                                          labels = list(params['slot2idx'].values()),
                                          target_names = list(params['slot2idx'].keys()),
                                          sample_weight = np.sign(slot_true),
                                          digits=3))
  
  if f1_slots > slot_best_f1:
    slot_best_f1 = f1_slots
    intent_acc_with_that = acc_intent
    # you can save model here
  logger.info("Best Slot F1: {:.3f}, Intent Acc: {:.3f}".format(slot_best_f1, intent_acc_with_that))
# Out:
# [('bidirectional/forward_gru/gru_cell_1/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/bias:0', TensorShape([2, 900])),
#  ('fc_intent/kernel:0', TensorShape([1200, 300])),
#  ('fc_intent/bias:0', TensorShape([300])),
#  ('output_intent/kernel:0', TensorShape([300, 23])),
#  ('output_intent/bias:0', TensorShape([23])),
#  ('output_slot/kernel:0', TensorShape([600, 122])),
#  ('output_slot/bias:0', TensorShape([122])),
#  ('pretrained_embedding:0', TensorShape([750, 300])),
#  ('transitions:0', TensorShape([122, 122]))]
# Reading ../data/atis.train.w-intent.iob
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:644: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# INFO:tensorflow:Step 0 | Loss: 73.1080 | Loss_intent: 3.2780 | Loss_slots: 59.9961 | Spent: 2.7 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 24.1529 | Loss_intent: 1.4655 | Loss_slots: 18.2909 | Spent: 5.8 secs | LR: 0.000114
# INFO:tensorflow:Step 100 | Loss: 21.6899 | Loss_intent: 1.9602 | Loss_slots: 13.8491 | Spent: 5.9 secs | LR: 0.000128
# INFO:tensorflow:Step 150 | Loss: 13.2405 | Loss_intent: 1.3232 | Loss_slots: 7.9479 | Spent: 5.6 secs | LR: 0.000142
# INFO:tensorflow:Step 200 | Loss: 10.1275 | Loss_intent: 1.2394 | Loss_slots: 5.1700 | Spent: 5.5 secs | LR: 0.000156
# INFO:tensorflow:Step 250 | Loss: 12.2418 | Loss_intent: 1.5050 | Loss_slots: 6.2218 | Spent: 5.6 secs | LR: 0.000170
# INFO:tensorflow:Step 300 | Loss: 10.8262 | Loss_intent: 1.6381 | Loss_slots: 4.2736 | Spent: 5.8 secs | LR: 0.000184
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.770, Intent Acc: 0.868
# INFO:tensorflow:Best Slot F1: 0.770, Intent Acc: 0.868
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 350 | Loss: 12.7001 | Loss_intent: 1.4251 | Loss_slots: 6.9996 | Spent: 11.5 secs | LR: 0.000198
# INFO:tensorflow:Step 400 | Loss: 6.1034 | Loss_intent: 1.1585 | Loss_slots: 1.4692 | Spent: 5.6 secs | LR: 0.000212
# INFO:tensorflow:Step 450 | Loss: 7.7278 | Loss_intent: 1.1885 | Loss_slots: 2.9737 | Spent: 5.5 secs | LR: 0.000227
# INFO:tensorflow:Step 500 | Loss: 6.3725 | Loss_intent: 1.2881 | Loss_slots: 1.2203 | Spent: 5.3 secs | LR: 0.000241
# INFO:tensorflow:Step 550 | Loss: 8.1140 | Loss_intent: 1.3082 | Loss_slots: 2.8812 | Spent: 5.9 secs | LR: 0.000255
# INFO:tensorflow:Step 600 | Loss: 7.1830 | Loss_intent: 1.2287 | Loss_slots: 2.2680 | Spent: 5.5 secs | LR: 0.000269
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.893, Intent Acc: 0.894
# INFO:tensorflow:Best Slot F1: 0.893, Intent Acc: 0.894
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 650 | Loss: 6.8950 | Loss_intent: 1.5199 | Loss_slots: 0.8155 | Spent: 11.5 secs | LR: 0.000283
# INFO:tensorflow:Step 700 | Loss: 6.4873 | Loss_intent: 1.2097 | Loss_slots: 1.6485 | Spent: 5.6 secs | LR: 0.000297
# INFO:tensorflow:Step 750 | Loss: 5.4467 | Loss_intent: 1.2651 | Loss_slots: 0.3865 | Spent: 5.9 secs | LR: 0.000311
# INFO:tensorflow:Step 800 | Loss: 5.7526 | Loss_intent: 1.1900 | Loss_slots: 0.9924 | Spent: 5.8 secs | LR: 0.000325
# INFO:tensorflow:Step 850 | Loss: 5.6837 | Loss_intent: 1.3150 | Loss_slots: 0.4236 | Spent: 5.6 secs | LR: 0.000339
# INFO:tensorflow:Step 900 | Loss: 4.8850 | Loss_intent: 1.1208 | Loss_slots: 0.4019 | Spent: 5.5 secs | LR: 0.000353
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.946, Intent Acc: 0.922
# INFO:tensorflow:Best Slot F1: 0.946, Intent Acc: 0.922
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 950 | Loss: 5.0718 | Loss_intent: 1.2073 | Loss_slots: 0.2426 | Spent: 11.7 secs | LR: 0.000367
# INFO:tensorflow:Step 1000 | Loss: 5.2767 | Loss_intent: 1.2848 | Loss_slots: 0.1375 | Spent: 5.6 secs | LR: 0.000381
# INFO:tensorflow:Step 1050 | Loss: 5.3447 | Loss_intent: 1.1498 | Loss_slots: 0.7454 | Spent: 5.7 secs | LR: 0.000395
# INFO:tensorflow:Step 1100 | Loss: 5.1734 | Loss_intent: 1.1148 | Loss_slots: 0.7141 | Spent: 5.6 secs | LR: 0.000409
# INFO:tensorflow:Step 1150 | Loss: 7.0858 | Loss_intent: 1.1586 | Loss_slots: 2.4514 | Spent: 5.4 secs | LR: 0.000423
# INFO:tensorflow:Step 1200 | Loss: 7.0699 | Loss_intent: 1.1061 | Loss_slots: 2.6457 | Spent: 5.6 secs | LR: 0.000437
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.931
# INFO:tensorflow:Best Slot F1: 0.949, Intent Acc: 0.931
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1250 | Loss: 5.0097 | Loss_intent: 1.1330 | Loss_slots: 0.4777 | Spent: 11.3 secs | LR: 0.000452
# INFO:tensorflow:Step 1300 | Loss: 5.6987 | Loss_intent: 1.1863 | Loss_slots: 0.9537 | Spent: 5.4 secs | LR: 0.000466
# INFO:tensorflow:Step 1350 | Loss: 4.9097 | Loss_intent: 1.1088 | Loss_slots: 0.4747 | Spent: 5.8 secs | LR: 0.000480
# INFO:tensorflow:Step 1400 | Loss: 5.1731 | Loss_intent: 1.1616 | Loss_slots: 0.5266 | Spent: 5.4 secs | LR: 0.000494
# INFO:tensorflow:Step 1450 | Loss: 4.6164 | Loss_intent: 1.1202 | Loss_slots: 0.1356 | Spent: 5.6 secs | LR: 0.000508
# INFO:tensorflow:Step 1500 | Loss: 5.2760 | Loss_intent: 1.2822 | Loss_slots: 0.1471 | Spent: 5.5 secs | LR: 0.000522
# INFO:tensorflow:Step 1550 | Loss: 4.7915 | Loss_intent: 1.1709 | Loss_slots: 0.1077 | Spent: 5.5 secs | LR: 0.000536
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.938
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.938
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1600 | Loss: 4.4709 | Loss_intent: 1.0940 | Loss_slots: 0.0949 | Spent: 11.8 secs | LR: 0.000550
# INFO:tensorflow:Step 1650 | Loss: 4.4788 | Loss_intent: 1.0918 | Loss_slots: 0.1116 | Spent: 5.9 secs | LR: 0.000564
# INFO:tensorflow:Step 1700 | Loss: 4.9490 | Loss_intent: 1.0992 | Loss_slots: 0.5520 | Spent: 5.6 secs | LR: 0.000578
# INFO:tensorflow:Step 1750 | Loss: 4.7938 | Loss_intent: 1.1012 | Loss_slots: 0.3891 | Spent: 5.7 secs | LR: 0.000592
# INFO:tensorflow:Step 1800 | Loss: 4.5266 | Loss_intent: 1.1023 | Loss_slots: 0.1175 | Spent: 5.7 secs | LR: 0.000606
# INFO:tensorflow:Step 1850 | Loss: 4.6011 | Loss_intent: 1.1190 | Loss_slots: 0.1253 | Spent: 5.5 secs | LR: 0.000620
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.956
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.956
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1900 | Loss: 4.4039 | Loss_intent: 1.0910 | Loss_slots: 0.0401 | Spent: 11.3 secs | LR: 0.000634
# INFO:tensorflow:Step 1950 | Loss: 4.5829 | Loss_intent: 1.1326 | Loss_slots: 0.0525 | Spent: 5.9 secs | LR: 0.000648
# INFO:tensorflow:Step 2000 | Loss: 4.6014 | Loss_intent: 1.1208 | Loss_slots: 0.1180 | Spent: 5.4 secs | LR: 0.000662
# INFO:tensorflow:Step 2050 | Loss: 5.8254 | Loss_intent: 1.1834 | Loss_slots: 1.0916 | Spent: 5.7 secs | LR: 0.000677
# INFO:tensorflow:Step 2100 | Loss: 5.8401 | Loss_intent: 1.4514 | Loss_slots: 0.0344 | Spent: 5.4 secs | LR: 0.000691
# INFO:tensorflow:Step 2150 | Loss: 4.3867 | Loss_intent: 1.0908 | Loss_slots: 0.0235 | Spent: 5.3 secs | LR: 0.000705
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.968
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.956
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2200 | Loss: 4.5077 | Loss_intent: 1.0958 | Loss_slots: 0.1246 | Spent: 11.2 secs | LR: 0.000719
# INFO:tensorflow:Step 2250 | Loss: 5.0339 | Loss_intent: 1.2255 | Loss_slots: 0.1318 | Spent: 5.4 secs | LR: 0.000733
# INFO:tensorflow:Step 2300 | Loss: 4.4366 | Loss_intent: 1.0937 | Loss_slots: 0.0619 | Spent: 5.8 secs | LR: 0.000747
# INFO:tensorflow:Step 2350 | Loss: 4.4251 | Loss_intent: 1.0996 | Loss_slots: 0.0268 | Spent: 5.7 secs | LR: 0.000761
# INFO:tensorflow:Step 2400 | Loss: 4.6504 | Loss_intent: 1.1241 | Loss_slots: 0.1542 | Spent: 5.5 secs | LR: 0.000775
# INFO:tensorflow:Step 2450 | Loss: 4.4374 | Loss_intent: 1.1005 | Loss_slots: 0.0355 | Spent: 5.9 secs | LR: 0.000789
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.953
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.965     0.994     0.979       632
#                             atis_airfare      0.855     0.979     0.913        48
#                      atis_ground_service      0.947     1.000     0.973        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      0.900     1.000     0.947         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.273     1.000     0.429         3
#                 atis_flight#atis_airfare      0.000     0.000     0.000        12
#                             atis_airport      1.000     0.722     0.839        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.167     0.286         6
#                         atis_ground_fare      1.000     0.714     0.833         7
#                            atis_capacity      1.000     0.905     0.950        21
#                           atis_flight_no      1.000     1.000     1.000         8
#                                atis_meal      0.000     0.000     0.000         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.953     0.958     0.956       888
#                                macro avg      0.588     0.567     0.552       888
#                             weighted avg      0.941     0.958     0.946       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.978     0.993     0.985     716.0
#          B-fromloc.city_name      0.986     0.999     0.992     704.0
#            I-toloc.city_name      0.974     0.981     0.977     265.0
#       B-depart_date.day_name      0.986     0.991     0.988     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.972     0.994     0.983     177.0
#  B-depart_time.period_of_day      1.000     0.931     0.964     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.980     0.909     0.943      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.851     1.000     0.919      57.0
#                 B-round_trip      1.000     0.973     0.986      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      1.000     1.000     1.000      24.0
#  B-depart_time.time_relative      0.968     0.938     0.953      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.917     0.579     0.710      57.0
#                 B-class_type      0.857     1.000     0.923      24.0
#           B-arrive_time.time      0.971     0.971     0.971      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.424     0.933     0.583      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.769     0.909     0.833      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.688     1.000     0.815      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.800     1.000     0.889      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.923     0.414     0.571      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.895     0.567     0.694      30.0
#         I-toloc.airport_name      1.000     0.667     0.800       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.833     1.000     0.909       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.818     0.429     0.562      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.789     0.909     0.845      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      0.600     1.000     0.750       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.800     1.000     0.889       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.667     0.667     0.667       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      1.000     0.333     0.500       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.954     0.956     0.955    3657.0
#                    macro avg      0.677     0.653     0.653    3657.0
#                 weighted avg      0.960     0.956     0.954    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.953
# Reading ../data/atis.train.w-intent.iob
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:tensorflow:Step 2500 | Loss: 4.4316 | Loss_intent: 1.1019 | Loss_slots: 0.0239 | Spent: 11.6 secs | LR: 0.000797
# INFO:tensorflow:Step 2550 | Loss: 4.4803 | Loss_intent: 1.0990 | Loss_slots: 0.0844 | Spent: 5.6 secs | LR: 0.000783
# INFO:tensorflow:Step 2600 | Loss: 4.3988 | Loss_intent: 1.0924 | Loss_slots: 0.0293 | Spent: 5.7 secs | LR: 0.000769
# INFO:tensorflow:Step 2650 | Loss: 4.4693 | Loss_intent: 1.1046 | Loss_slots: 0.0507 | Spent: 5.8 secs | LR: 0.000755
# INFO:tensorflow:Step 2700 | Loss: 4.4692 | Loss_intent: 1.1108 | Loss_slots: 0.0260 | Spent: 5.3 secs | LR: 0.000741
# INFO:tensorflow:Step 2750 | Loss: 4.4421 | Loss_intent: 1.1092 | Loss_slots: 0.0055 | Spent: 5.9 secs | LR: 0.000727
# INFO:tensorflow:Step 2800 | Loss: 4.6282 | Loss_intent: 1.1163 | Loss_slots: 0.1628 | Spent: 5.5 secs | LR: 0.000713
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.953
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2850 | Loss: 4.7500 | Loss_intent: 1.0852 | Loss_slots: 0.4092 | Spent: 11.2 secs | LR: 0.000698
# INFO:tensorflow:Step 2900 | Loss: 4.5622 | Loss_intent: 1.0864 | Loss_slots: 0.2167 | Spent: 5.8 secs | LR: 0.000684
# INFO:tensorflow:Step 2950 | Loss: 4.5726 | Loss_intent: 1.0867 | Loss_slots: 0.2259 | Spent: 5.7 secs | LR: 0.000670
# INFO:tensorflow:Step 3000 | Loss: 4.3921 | Loss_intent: 1.0919 | Loss_slots: 0.0247 | Spent: 5.5 secs | LR: 0.000656
# INFO:tensorflow:Step 3050 | Loss: 4.5177 | Loss_intent: 1.1244 | Loss_slots: 0.0200 | Spent: 5.9 secs | LR: 0.000642
# INFO:tensorflow:Step 3100 | Loss: 4.4123 | Loss_intent: 1.0934 | Loss_slots: 0.0387 | Spent: 5.3 secs | LR: 0.000628
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.950, Intent Acc: 0.962
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.953
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3150 | Loss: 4.3692 | Loss_intent: 1.0903 | Loss_slots: 0.0082 | Spent: 11.0 secs | LR: 0.000614
# INFO:tensorflow:Step 3200 | Loss: 4.3492 | Loss_intent: 1.0861 | Loss_slots: 0.0047 | Spent: 5.6 secs | LR: 0.000600
# INFO:tensorflow:Step 3250 | Loss: 4.3499 | Loss_intent: 1.0855 | Loss_slots: 0.0077 | Spent: 5.5 secs | LR: 0.000586
# INFO:tensorflow:Step 3300 | Loss: 4.4063 | Loss_intent: 1.1008 | Loss_slots: 0.0031 | Spent: 5.8 secs | LR: 0.000572
# INFO:tensorflow:Step 3350 | Loss: 4.3331 | Loss_intent: 1.0828 | Loss_slots: 0.0018 | Spent: 5.6 secs | LR: 0.000558
# INFO:tensorflow:Step 3400 | Loss: 4.4209 | Loss_intent: 1.0873 | Loss_slots: 0.0716 | Spent: 6.0 secs | LR: 0.000544
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.963
# INFO:tensorflow:Best Slot F1: 0.955, Intent Acc: 0.953
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3450 | Loss: 4.3342 | Loss_intent: 1.0827 | Loss_slots: 0.0036 | Spent: 11.4 secs | LR: 0.000530
# INFO:tensorflow:Step 3500 | Loss: 4.6629 | Loss_intent: 1.1635 | Loss_slots: 0.0089 | Spent: 5.7 secs | LR: 0.000516
# INFO:tensorflow:Step 3550 | Loss: 4.3520 | Loss_intent: 1.0871 | Loss_slots: 0.0036 | Spent: 5.7 secs | LR: 0.000502
# INFO:tensorflow:Step 3600 | Loss: 4.3688 | Loss_intent: 1.0905 | Loss_slots: 0.0069 | Spent: 5.5 secs | LR: 0.000488
# INFO:tensorflow:Step 3650 | Loss: 4.6294 | Loss_intent: 1.1476 | Loss_slots: 0.0388 | Spent: 5.6 secs | LR: 0.000473
# INFO:tensorflow:Step 3700 | Loss: 4.3386 | Loss_intent: 1.0827 | Loss_slots: 0.0079 | Spent: 5.7 secs | LR: 0.000459
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3750 | Loss: 4.3371 | Loss_intent: 1.0831 | Loss_slots: 0.0049 | Spent: 11.3 secs | LR: 0.000445
# INFO:tensorflow:Step 3800 | Loss: 4.3385 | Loss_intent: 1.0829 | Loss_slots: 0.0070 | Spent: 5.8 secs | LR: 0.000431
# INFO:tensorflow:Step 3850 | Loss: 4.3539 | Loss_intent: 1.0828 | Loss_slots: 0.0227 | Spent: 5.4 secs | LR: 0.000417
# INFO:tensorflow:Step 3900 | Loss: 4.3506 | Loss_intent: 1.0875 | Loss_slots: 0.0005 | Spent: 5.6 secs | LR: 0.000403
# INFO:tensorflow:Step 3950 | Loss: 4.4289 | Loss_intent: 1.1048 | Loss_slots: 0.0095 | Spent: 6.0 secs | LR: 0.000389
# INFO:tensorflow:Step 4000 | Loss: 4.3647 | Loss_intent: 1.0884 | Loss_slots: 0.0113 | Spent: 5.4 secs | LR: 0.000375
# INFO:tensorflow:Step 4050 | Loss: 4.3496 | Loss_intent: 1.0835 | Loss_slots: 0.0157 | Spent: 5.4 secs | LR: 0.000361
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4100 | Loss: 4.3304 | Loss_intent: 1.0822 | Loss_slots: 0.0016 | Spent: 10.9 secs | LR: 0.000347
# INFO:tensorflow:Step 4150 | Loss: 4.3474 | Loss_intent: 1.0864 | Loss_slots: 0.0019 | Spent: 5.6 secs | LR: 0.000333
# INFO:tensorflow:Step 4200 | Loss: 4.3335 | Loss_intent: 1.0823 | Loss_slots: 0.0042 | Spent: 6.1 secs | LR: 0.000319
# INFO:tensorflow:Step 4250 | Loss: 4.3371 | Loss_intent: 1.0815 | Loss_slots: 0.0112 | Spent: 5.7 secs | LR: 0.000305
# INFO:tensorflow:Step 4300 | Loss: 4.3320 | Loss_intent: 1.0816 | Loss_slots: 0.0054 | Spent: 5.6 secs | LR: 0.000291
# INFO:tensorflow:Step 4350 | Loss: 4.3303 | Loss_intent: 1.0821 | Loss_slots: 0.0019 | Spent: 5.5 secs | LR: 0.000277
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.968
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4400 | Loss: 4.3294 | Loss_intent: 1.0817 | Loss_slots: 0.0027 | Spent: 11.4 secs | LR: 0.000263
# INFO:tensorflow:Step 4450 | Loss: 4.3334 | Loss_intent: 1.0832 | Loss_slots: 0.0006 | Spent: 5.6 secs | LR: 0.000248
# INFO:tensorflow:Step 4500 | Loss: 4.3299 | Loss_intent: 1.0822 | Loss_slots: 0.0013 | Spent: 5.6 secs | LR: 0.000234
# INFO:tensorflow:Step 4550 | Loss: 4.3241 | Loss_intent: 1.0800 | Loss_slots: 0.0041 | Spent: 5.4 secs | LR: 0.000220
# INFO:tensorflow:Step 4600 | Loss: 4.3241 | Loss_intent: 1.0808 | Loss_slots: 0.0008 | Spent: 5.3 secs | LR: 0.000206
# INFO:tensorflow:Step 4650 | Loss: 4.3299 | Loss_intent: 1.0814 | Loss_slots: 0.0042 | Spent: 5.9 secs | LR: 0.000192
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4700 | Loss: 4.3261 | Loss_intent: 1.0803 | Loss_slots: 0.0047 | Spent: 11.5 secs | LR: 0.000178
# INFO:tensorflow:Step 4750 | Loss: 4.3340 | Loss_intent: 1.0834 | Loss_slots: 0.0004 | Spent: 5.6 secs | LR: 0.000164
# INFO:tensorflow:Step 4800 | Loss: 4.3286 | Loss_intent: 1.0814 | Loss_slots: 0.0028 | Spent: 6.3 secs | LR: 0.000150
# INFO:tensorflow:Step 4850 | Loss: 4.3367 | Loss_intent: 1.0835 | Loss_slots: 0.0028 | Spent: 6.2 secs | LR: 0.000136
# INFO:tensorflow:Step 4900 | Loss: 4.3302 | Loss_intent: 1.0817 | Loss_slots: 0.0033 | Spent: 5.7 secs | LR: 0.000122
# INFO:tensorflow:Step 4950 | Loss: 4.8649 | Loss_intent: 1.2159 | Loss_slots: 0.0014 | Spent: 5.7 secs | LR: 0.000108
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.968
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.975     0.992     0.984       632
#                             atis_airfare      0.922     0.979     0.949        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.800     0.333     0.471        12
#                             atis_airport      1.000     0.889     0.941        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.750     0.500     0.600         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.333     0.500         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.968     0.973     0.970       888
#                                macro avg      0.669     0.635     0.633       888
#                             weighted avg      0.969     0.973     0.968       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.974     0.990     0.982     716.0
#          B-fromloc.city_name      0.983     1.000     0.992     704.0
#            I-toloc.city_name      0.977     0.977     0.977     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.967     1.000     0.983     177.0
#  B-depart_time.period_of_day      1.000     0.931     0.964     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.864     1.000     0.927      57.0
#                 B-round_trip      1.000     0.973     0.986      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      1.000     1.000     1.000      24.0
#  B-depart_time.time_relative      0.968     0.938     0.953      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.919     0.596     0.723      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.441     1.000     0.612      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.611     1.000     0.759      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.806     0.893     0.847      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      0.667     1.000     0.800       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.909     0.667     0.769      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.833     1.000     0.909       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.800     0.381     0.516      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.714     0.909     0.800      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.667     0.667     0.667       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.667     1.000     0.800       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.953     0.955     0.954    3657.0
#                    macro avg      0.677     0.655     0.654    3657.0
#                 weighted avg      0.959     0.955     0.952    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5000 | Loss: 4.3282 | Loss_intent: 1.0816 | Loss_slots: 0.0018 | Spent: 11.5 secs | LR: 0.000103
# INFO:tensorflow:Step 5050 | Loss: 4.3348 | Loss_intent: 1.0829 | Loss_slots: 0.0033 | Spent: 5.4 secs | LR: 0.000110
# INFO:tensorflow:Step 5100 | Loss: 4.3272 | Loss_intent: 1.0817 | Loss_slots: 0.0006 | Spent: 5.4 secs | LR: 0.000117
# INFO:tensorflow:Step 5150 | Loss: 4.3325 | Loss_intent: 1.0831 | Loss_slots: 0.0002 | Spent: 5.5 secs | LR: 0.000124
# INFO:tensorflow:Step 5200 | Loss: 4.3275 | Loss_intent: 1.0816 | Loss_slots: 0.0009 | Spent: 5.6 secs | LR: 0.000131
# INFO:tensorflow:Step 5250 | Loss: 4.3324 | Loss_intent: 1.0830 | Loss_slots: 0.0004 | Spent: 5.5 secs | LR: 0.000138
# INFO:tensorflow:Step 5300 | Loss: 4.3329 | Loss_intent: 1.0831 | Loss_slots: 0.0005 | Spent: 5.6 secs | LR: 0.000145
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.968
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5350 | Loss: 4.3289 | Loss_intent: 1.0819 | Loss_slots: 0.0013 | Spent: 11.4 secs | LR: 0.000152
# INFO:tensorflow:Step 5400 | Loss: 4.3276 | Loss_intent: 1.0815 | Loss_slots: 0.0015 | Spent: 5.6 secs | LR: 0.000159
# INFO:tensorflow:Step 5450 | Loss: 4.4010 | Loss_intent: 1.0999 | Loss_slots: 0.0015 | Spent: 5.8 secs | LR: 0.000166
# INFO:tensorflow:Step 5500 | Loss: 4.3312 | Loss_intent: 1.0825 | Loss_slots: 0.0011 | Spent: 5.6 secs | LR: 0.000173
# INFO:tensorflow:Step 5550 | Loss: 4.3239 | Loss_intent: 1.0805 | Loss_slots: 0.0017 | Spent: 5.9 secs | LR: 0.000180
# INFO:tensorflow:Step 5600 | Loss: 4.3467 | Loss_intent: 1.0864 | Loss_slots: 0.0011 | Spent: 5.6 secs | LR: 0.000187
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5650 | Loss: 4.3252 | Loss_intent: 1.0811 | Loss_slots: 0.0008 | Spent: 11.6 secs | LR: 0.000194
# INFO:tensorflow:Step 5700 | Loss: 4.3842 | Loss_intent: 1.0959 | Loss_slots: 0.0007 | Spent: 5.8 secs | LR: 0.000202
# INFO:tensorflow:Step 5750 | Loss: 4.3227 | Loss_intent: 1.0806 | Loss_slots: 0.0002 | Spent: 5.5 secs | LR: 0.000209
# INFO:tensorflow:Step 5800 | Loss: 4.3348 | Loss_intent: 1.0835 | Loss_slots: 0.0008 | Spent: 5.6 secs | LR: 0.000216
# INFO:tensorflow:Step 5850 | Loss: 4.3865 | Loss_intent: 1.0964 | Loss_slots: 0.0010 | Spent: 5.4 secs | LR: 0.000223
# INFO:tensorflow:Step 5900 | Loss: 4.4475 | Loss_intent: 1.1101 | Loss_slots: 0.0071 | Spent: 5.7 secs | LR: 0.000230
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.956, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5950 | Loss: 4.4197 | Loss_intent: 1.0816 | Loss_slots: 0.0932 | Spent: 11.3 secs | LR: 0.000237
# INFO:tensorflow:Step 6000 | Loss: 4.3378 | Loss_intent: 1.0840 | Loss_slots: 0.0018 | Spent: 5.6 secs | LR: 0.000244
# INFO:tensorflow:Step 6050 | Loss: 4.3458 | Loss_intent: 1.0817 | Loss_slots: 0.0190 | Spent: 5.7 secs | LR: 0.000251
# INFO:tensorflow:Step 6100 | Loss: 4.3385 | Loss_intent: 1.0834 | Loss_slots: 0.0047 | Spent: 5.5 secs | LR: 0.000258
# INFO:tensorflow:Step 6150 | Loss: 4.3227 | Loss_intent: 1.0806 | Loss_slots: 0.0002 | Spent: 5.7 secs | LR: 0.000265
# INFO:tensorflow:Step 6200 | Loss: 4.4014 | Loss_intent: 1.0998 | Loss_slots: 0.0023 | Spent: 5.5 secs | LR: 0.000272
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6250 | Loss: 4.3340 | Loss_intent: 1.0833 | Loss_slots: 0.0010 | Spent: 11.0 secs | LR: 0.000279
# INFO:tensorflow:Step 6300 | Loss: 4.4107 | Loss_intent: 1.1025 | Loss_slots: 0.0008 | Spent: 5.3 secs | LR: 0.000286
# INFO:tensorflow:Step 6350 | Loss: 4.3309 | Loss_intent: 1.0823 | Loss_slots: 0.0017 | Spent: 5.5 secs | LR: 0.000293
# INFO:tensorflow:Step 6400 | Loss: 4.3398 | Loss_intent: 1.0846 | Loss_slots: 0.0012 | Spent: 5.7 secs | LR: 0.000300
# INFO:tensorflow:Step 6450 | Loss: 4.3244 | Loss_intent: 1.0808 | Loss_slots: 0.0014 | Spent: 5.3 secs | LR: 0.000307
# INFO:tensorflow:Step 6500 | Loss: 4.3586 | Loss_intent: 1.0892 | Loss_slots: 0.0016 | Spent: 5.3 secs | LR: 0.000314
# INFO:tensorflow:Step 6550 | Loss: 4.3252 | Loss_intent: 1.0811 | Loss_slots: 0.0008 | Spent: 5.5 secs | LR: 0.000321
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.968
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6600 | Loss: 4.3314 | Loss_intent: 1.0821 | Loss_slots: 0.0030 | Spent: 11.4 secs | LR: 0.000328
# INFO:tensorflow:Step 6650 | Loss: 4.3388 | Loss_intent: 1.0842 | Loss_slots: 0.0021 | Spent: 5.8 secs | LR: 0.000335
# INFO:tensorflow:Step 6700 | Loss: 4.3634 | Loss_intent: 1.0904 | Loss_slots: 0.0018 | Spent: 5.7 secs | LR: 0.000342
# INFO:tensorflow:Step 6750 | Loss: 4.3495 | Loss_intent: 1.0871 | Loss_slots: 0.0011 | Spent: 5.2 secs | LR: 0.000349
# INFO:tensorflow:Step 6800 | Loss: 4.3628 | Loss_intent: 1.0826 | Loss_slots: 0.0323 | Spent: 5.6 secs | LR: 0.000356
# INFO:tensorflow:Step 6850 | Loss: 4.3374 | Loss_intent: 1.0840 | Loss_slots: 0.0016 | Spent: 5.4 secs | LR: 0.000363
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6900 | Loss: 4.4256 | Loss_intent: 1.1045 | Loss_slots: 0.0076 | Spent: 11.2 secs | LR: 0.000370
# INFO:tensorflow:Step 6950 | Loss: 4.3630 | Loss_intent: 1.0892 | Loss_slots: 0.0061 | Spent: 5.5 secs | LR: 0.000377
# INFO:tensorflow:Step 7000 | Loss: 4.4697 | Loss_intent: 1.0885 | Loss_slots: 0.1157 | Spent: 5.3 secs | LR: 0.000384
# INFO:tensorflow:Step 7050 | Loss: 4.3356 | Loss_intent: 1.0837 | Loss_slots: 0.0010 | Spent: 5.5 secs | LR: 0.000391
# INFO:tensorflow:Step 7100 | Loss: 4.3264 | Loss_intent: 1.0813 | Loss_slots: 0.0013 | Spent: 5.3 secs | LR: 0.000398
# INFO:tensorflow:Step 7150 | Loss: 4.3394 | Loss_intent: 1.0848 | Loss_slots: 0.0003 | Spent: 5.4 secs | LR: 0.000405
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 7200 | Loss: 4.3416 | Loss_intent: 1.0847 | Loss_slots: 0.0030 | Spent: 11.9 secs | LR: 0.000412
# INFO:tensorflow:Step 7250 | Loss: 4.3258 | Loss_intent: 1.0808 | Loss_slots: 0.0026 | Spent: 5.4 secs | LR: 0.000419
# INFO:tensorflow:Step 7300 | Loss: 4.3232 | Loss_intent: 1.0807 | Loss_slots: 0.0005 | Spent: 5.5 secs | LR: 0.000427
# INFO:tensorflow:Step 7350 | Loss: 4.3228 | Loss_intent: 1.0806 | Loss_slots: 0.0005 | Spent: 5.6 secs | LR: 0.000434
# INFO:tensorflow:Step 7400 | Loss: 4.3262 | Loss_intent: 1.0813 | Loss_slots: 0.0008 | Spent: 5.4 secs | LR: 0.000441
# INFO:tensorflow:Step 7450 | Loss: 4.3329 | Loss_intent: 1.0830 | Loss_slots: 0.0011 | Spent: 5.3 secs | LR: 0.000448
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.969
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.972     0.992     0.982       632
#                             atis_airfare      0.940     0.979     0.959        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.944     0.971        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.500     0.667         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.167     0.286         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.969     0.974     0.971       888
#                                macro avg      0.684     0.634     0.633       888
#                             weighted avg      0.971     0.974     0.968       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.973     0.992     0.982     716.0
#          B-fromloc.city_name      0.986     1.000     0.993     704.0
# ...
# INFO:tensorflow:Step 18350 | Loss: 4.3214 | Loss_intent: 1.0803 | Loss_slots: 0.0004 | Spent: 5.7 secs | LR: 0.000155
# INFO:tensorflow:Step 18400 | Loss: 4.3206 | Loss_intent: 1.0801 | Loss_slots: 0.0000 | Spent: 5.8 secs | LR: 0.000153
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.972
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18450 | Loss: 4.3193 | Loss_intent: 1.0798 | Loss_slots: 0.0000 | Spent: 11.3 secs | LR: 0.000151
# INFO:tensorflow:Step 18500 | Loss: 4.3218 | Loss_intent: 1.0805 | Loss_slots: 0.0000 | Spent: 6.0 secs | LR: 0.000150
# INFO:tensorflow:Step 18550 | Loss: 4.3242 | Loss_intent: 1.0810 | Loss_slots: 0.0001 | Spent: 5.9 secs | LR: 0.000148
# INFO:tensorflow:Step 18600 | Loss: 4.3226 | Loss_intent: 1.0806 | Loss_slots: 0.0001 | Spent: 5.8 secs | LR: 0.000146
# INFO:tensorflow:Step 18650 | Loss: 4.3210 | Loss_intent: 1.0802 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000144
# INFO:tensorflow:Step 18700 | Loss: 4.3212 | Loss_intent: 1.0803 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000143
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18750 | Loss: 4.3358 | Loss_intent: 1.0839 | Loss_slots: 0.0001 | Spent: 11.3 secs | LR: 0.000141
# INFO:tensorflow:Step 18800 | Loss: 4.3212 | Loss_intent: 1.0803 | Loss_slots: 0.0000 | Spent: 5.6 secs | LR: 0.000139
# INFO:tensorflow:Step 18850 | Loss: 4.3190 | Loss_intent: 1.0797 | Loss_slots: 0.0001 | Spent: 5.4 secs | LR: 0.000137
# INFO:tensorflow:Step 18900 | Loss: 4.3191 | Loss_intent: 1.0797 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000136
# INFO:tensorflow:Step 18950 | Loss: 4.3212 | Loss_intent: 1.0803 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000134
# INFO:tensorflow:Step 19000 | Loss: 4.3198 | Loss_intent: 1.0799 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000132
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.972
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19050 | Loss: 4.3292 | Loss_intent: 1.0823 | Loss_slots: 0.0000 | Spent: 11.8 secs | LR: 0.000130
# INFO:tensorflow:Step 19100 | Loss: 4.3206 | Loss_intent: 1.0801 | Loss_slots: 0.0001 | Spent: 5.4 secs | LR: 0.000129
# INFO:tensorflow:Step 19150 | Loss: 4.3243 | Loss_intent: 1.0811 | Loss_slots: 0.0000 | Spent: 5.6 secs | LR: 0.000127
# INFO:tensorflow:Step 19200 | Loss: 4.3244 | Loss_intent: 1.0811 | Loss_slots: 0.0000 | Spent: 5.9 secs | LR: 0.000125
# INFO:tensorflow:Step 19250 | Loss: 4.3223 | Loss_intent: 1.0806 | Loss_slots: -0.0000 | Spent: 5.8 secs | LR: 0.000123
# INFO:tensorflow:Step 19300 | Loss: 4.3206 | Loss_intent: 1.0801 | Loss_slots: 0.0001 | Spent: 5.4 secs | LR: 0.000122
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19350 | Loss: 4.3273 | Loss_intent: 1.0818 | Loss_slots: 0.0001 | Spent: 11.3 secs | LR: 0.000120
# INFO:tensorflow:Step 19400 | Loss: 4.3193 | Loss_intent: 1.0798 | Loss_slots: 0.0001 | Spent: 5.7 secs | LR: 0.000118
# INFO:tensorflow:Step 19450 | Loss: 4.3237 | Loss_intent: 1.0809 | Loss_slots: 0.0001 | Spent: 5.6 secs | LR: 0.000116
# INFO:tensorflow:Step 19500 | Loss: 4.3209 | Loss_intent: 1.0802 | Loss_slots: 0.0001 | Spent: 5.4 secs | LR: 0.000114
# INFO:tensorflow:Step 19550 | Loss: 4.3252 | Loss_intent: 1.0802 | Loss_slots: 0.0046 | Spent: 6.0 secs | LR: 0.000113
# INFO:tensorflow:Step 19600 | Loss: 4.3212 | Loss_intent: 1.0803 | Loss_slots: 0.0001 | Spent: 6.3 secs | LR: 0.000111
# INFO:tensorflow:Step 19650 | Loss: 4.3219 | Loss_intent: 1.0805 | Loss_slots: -0.0000 | Spent: 5.8 secs | LR: 0.000109
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19700 | Loss: 4.3187 | Loss_intent: 1.0797 | Loss_slots: 0.0001 | Spent: 11.6 secs | LR: 0.000107
# INFO:tensorflow:Step 19750 | Loss: 4.3203 | Loss_intent: 1.0801 | Loss_slots: 0.0000 | Spent: 5.4 secs | LR: 0.000106
# INFO:tensorflow:Step 19800 | Loss: 4.3241 | Loss_intent: 1.0810 | Loss_slots: 0.0001 | Spent: 5.5 secs | LR: 0.000104
# INFO:tensorflow:Step 19850 | Loss: 4.3263 | Loss_intent: 1.0815 | Loss_slots: 0.0004 | Spent: 5.7 secs | LR: 0.000102
# INFO:tensorflow:Step 19900 | Loss: 4.3195 | Loss_intent: 1.0798 | Loss_slots: 0.0002 | Spent: 5.5 secs | LR: 0.000100
# INFO:tensorflow:Step 19950 | Loss: 4.3186 | Loss_intent: 1.0797 | Loss_slots: 0.0000 | Spent: 5.8 secs | LR: 0.000101
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.957, Intent Acc: 0.972
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.980     0.992     0.986       632
#                             atis_airfare      0.959     0.979     0.969        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.375     1.000     0.545         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.944     0.971        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.500     0.667         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.667     0.800         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.972     0.977     0.975       888
#                                macro avg      0.680     0.657     0.653       888
#                             weighted avg      0.975     0.977     0.974       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.975     0.992     0.983     716.0
#          B-fromloc.city_name      0.985     1.000     0.992     704.0
#            I-toloc.city_name      0.977     0.977     0.977     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.967     1.000     0.983     177.0
#  B-depart_time.period_of_day      1.000     0.923     0.960     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.864     1.000     0.927      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      1.000     1.000     1.000      24.0
#  B-depart_time.time_relative      0.969     0.954     0.961      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.897     0.614     0.729      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.441     1.000     0.612      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.688     1.000     0.815      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.806     0.893     0.847      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.909     0.667     0.769      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.833     1.000     0.909       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.800     0.381     0.516      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.811     0.909     0.857      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.667     0.667     0.667       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      0.750     1.000     0.857       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.667     1.000     0.800       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.956     0.957     0.957    3657.0
#                    macro avg      0.680     0.658     0.657    3657.0
#                 weighted avg      0.960     0.957     0.955    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.958, Intent Acc: 0.972
