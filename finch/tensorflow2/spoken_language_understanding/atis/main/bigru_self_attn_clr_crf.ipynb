# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/spoken_language_understanding/atis/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score

import tensorflow as tf
import tensorflow_addons as tfa
import pprint
import logging
import time
import numpy as np

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-dd37b7ada4e1>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(vocab_path):
  word2idx = {}
  with open(vocab_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
def data_generator(f_path, params):
  print('Reading', f_path)
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      text, slot_intent = line.split('\t')
      words = text.split()[1:-1]
      slot_intent = slot_intent.split()
      slots, intent = slot_intent[1:-1], slot_intent[-1]
      assert len(words) == len(slots)
      
      words = [params['word2idx'].get(w, len(params['word2idx'])) for w in words]
      intent = params['intent2idx'].get(intent, len(params['intent2idx']))
      slots = [params['slot2idx'].get(s, len(params['slot2idx'])) for s in slots]
      
      yield (words, (intent, slots))

# %%
def dataset(is_training, params):
  _shapes = ([None], ((), [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (-1, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class LayerNorm(tf.keras.layers.Layer):
  def __init__(self, params):
    super().__init__()
    self._epsilon = 1e-6
    self._units = 2 * params['rnn_units']
  
  def build(self, input_shape):
    self.scale = self.add_weight(name='scale',
                                 shape=[self._units],
                                 initializer=tf.ones_initializer(),
                                 trainable=True)
    self.bias = self.add_weight(name='bias',
                                shape=[self._units],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    mean, variance = tf.nn.moments(inputs, [-1], keepdims=True)
    norm_x = (inputs - mean) * tf.math.rsqrt(variance + self._epsilon)
    return norm_x * self.scale + self.bias
  
  def compute_output_shape(self, input_shape):
    return input_shape


class EncoderBlock(tf.keras.Model):
  def __init__(self, SubModel, params, name):
    super().__init__(name = name)
    self.layer_norm = LayerNorm(params)
    self.sub_model = SubModel(params)
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
  
  def call(self, inputs, training=False):
    inputs, masks = inputs
    x = self.layer_norm(inputs)
    x = self.sub_model((x, masks), training=training)
    x = self.dropout(x, training=training)
    x += inputs
    return x


class MultiheadSelfAttention(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.qkv_linear = tf.keras.layers.Dense(3 * 2 * params['rnn_units'], name='qkv_linear')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(2 * params['rnn_units'], name='out_linear')
    self._num_heads = params['num_heads']
  
  def call(self, inputs, training=False):
    x, masks = inputs
    timesteps = tf.shape(x)[1]
    
    q_k_v = self.qkv_linear(x)
    q, k, v = tf.split(q_k_v, 3, axis=-1)
    
    if self._num_heads > 1:
      q = tf.concat(tf.split(q, self._num_heads, axis=2), axis=0)                        
      k = tf.concat(tf.split(k, self._num_heads, axis=2), axis=0)                        
      v = tf.concat(tf.split(v, self._num_heads, axis=2), axis=0)
    
    align = tf.matmul(q, k, transpose_b=True)
    align *= tf.math.rsqrt(tf.cast(k.shape[-1], tf.float32))
    
    if masks is not None:
      paddings = tf.fill(tf.shape(align), float('-inf'))
    
    if masks is not None:
      c_masks = tf.tile(masks, [params['num_heads'], 1])
      c_masks = tf.tile(tf.expand_dims(c_masks, 1), [1, timesteps, 1])
      align = tf.where(tf.equal(c_masks, 0), paddings, align)
    
    align = tf.nn.softmax(align)
    align = self.dropout(align, training=training)
    
    if masks is not None:
      q_masks = tf.tile(masks, [params['num_heads'], 1])
      q_masks = tf.tile(tf.expand_dims(q_masks, 2), [1, 1, timesteps])
      align *= tf.cast(q_masks, tf.float32)
    
    x = tf.matmul(align, v)
    if self._num_heads > 1:
      x = tf.concat(tf.split(x, self._num_heads, axis=0), axis=2)
    x = self.out_linear(x)
    
    return x
  

class PointwiseFFN(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dense_1 = tf.keras.layers.Dense(2 * params['multiplier'] * params['rnn_units'], tf.nn.relu, name='fc_relu')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.dense_2 = tf.keras.layers.Dense(2 * params['rnn_units'], name='linear')
  
  def call(self, inputs, training=False):
    x, masks = inputs
    return self.dense_2(self.dropout(self.dense_1(x), training=training))

# %%
class Model(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['vocab_path']),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
    self.input_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
        params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    self.transformer = [
        EncoderBlock(MultiheadSelfAttention, params, name='self_attention'),
        EncoderBlock(PointwiseFFN, params, name='pointwise_ffn'),
    ]
    
    self.intent_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.fc_intent = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='fc_intent')
    self.out_linear_intent = tf.keras.layers.Dense(params['intent_size'], name='output_intent')
    self.out_linear_slot = tf.keras.layers.Dense(params['slot_size'], name='output_slot')
    self.trans_params = self.add_weight('transitions', (params['slot_size'], params['slot_size']))
  
  
  def call(self, inputs, training=False):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    mask = tf.sign(inputs)
    rnn_mask = tf.cast(mask, tf.bool)
    
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    x = self.input_dropout(x, training=training)
    x, s_fw, s_bw = self.bidir_gru(x, mask=rnn_mask)
    for block in self.transformer:
      x = block((x, mask), training=training)
    
    x_intent = tf.concat([tf.reduce_max(x, 1), s_fw, s_bw], -1)
    x_intent = self.intent_dropout(x_intent, training=training)
    x_intent = self.out_linear_intent(self.fc_intent(x_intent))
    x_slot = self.out_linear_slot(x)
    return (x_intent, x_slot)

# %%
params = {
  'train_path': '../data/atis.train.w-intent.iob',
  'test_path': '../data/atis.test.w-intent.iob',
  'word_path': '../vocab/word.txt',
  'vocab_path': '../vocab/word.npy',
  'intent_path': '../vocab/intent.txt',
  'slot_path': '../vocab/slot.txt',
  'batch_size': 16,
  'num_samples': 4978,
  'rnn_units': 300,
  'num_heads': 6,
  'multiplier': 2,
  'dropout_rate': .2,
  'clip_norm': 5.,
}

# %%
params['word2idx'] = get_vocab(params['word_path'])
params['intent2idx'] = get_vocab(params['intent_path'])
params['slot2idx'] = get_vocab(params['slot_path'])

params['word_size'] = len(params['word2idx']) + 1
params['intent_size'] = len(params['intent2idx']) + 1
params['slot_size'] = len(params['slot2idx']) + 1

# %%
model = Model(params)
model.build(input_shape=(None, None))
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = tfa.optimizers.Triangular2CyclicalLearningRate(
  initial_learning_rate = 1e-4,
  maximal_learning_rate = 8e-4,
  step_size = 8 * params['num_samples'] // params['batch_size'],
)
optim = tf.optimizers.Adam(1e-4)
global_step = 0

slot_best_f1 = .0
intent_acc_with_that = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

for n_epoch in range(1, 64+1):
  # TRAINING
  for (words, (intent, slots)) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      y_intent, y_slots = model(words, training=True)

      loss_intent = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(intent, len(params['intent2idx'])+1),
        logits = y_intent,
        label_smoothing = .2)
      
      log_likelihood, _ = tfa.text.crf_log_likelihood(
          inputs = y_slots,
          tag_indices = slots,
          sequence_lengths = tf.math.count_nonzero(words, axis=1, dtype=tf.int32),
          transition_params = model.trans_params,)
      loss_slots = - tf.reduce_mean(log_likelihood)

      loss = 4. * loss_intent + loss_slots
    
    train_vars = model.trainable_variables
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, train_vars)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, train_vars))

    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Loss_intent: {:.4f} | Loss_slots: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), loss_intent.numpy().item(), loss_slots.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
    
  # EVALUATION
  intent_true = []
  intent_pred = []
  slot_true = []
  slot_pred = []

  for (words, (intent, slots)) in dataset(is_training=False, params=params):
    y_intent, y_slots = model(words, training=False)
    y_intent = tf.argmax(y_intent, -1)
    y_slots, _ = tfa.text.crf_decode(
      potentials = y_slots,
      transition_params = model.trans_params,
      sequence_length = tf.math.count_nonzero(words, axis=1, dtype=tf.int32),)
    
    intent_true += intent.numpy().flatten().tolist()
    intent_pred += y_intent.numpy().flatten().tolist()
    slot_true += slots.numpy().flatten().tolist()
    slot_pred += y_slots.numpy().flatten().tolist()
    
  f1_slots = f1_score(y_true = slot_true,
                      y_pred = slot_pred,
                      labels = list(params['slot2idx'].values()),
                      sample_weight = np.sign(slot_true),
                      average='micro',)
  
  acc_intent = accuracy_score(intent_true, intent_pred)

  logger.info("Slot F1: {:.3f}, Intent Acc: {:.3f}".format(f1_slots, acc_intent))

  if n_epoch != 1 and n_epoch % 8 == 0:
    logger.info('\n'+classification_report(y_true = intent_true,
                                          y_pred = intent_pred,
                                          labels = list(params['intent2idx'].values()),
                                          target_names = list(params['intent2idx'].keys()),
                                          digits=3))
    logger.info('\n'+classification_report(y_true = slot_true,
                                          y_pred = slot_pred,
                                          labels = list(params['slot2idx'].values()),
                                          target_names = list(params['slot2idx'].keys()),
                                          sample_weight = np.sign(slot_true),
                                          digits=3))
  
  if f1_slots > slot_best_f1:
    slot_best_f1 = f1_slots
    intent_acc_with_that = acc_intent
    # you can save model here
  logger.info("Best Slot F1: {:.3f}, Intent Acc: {:.3f}".format(slot_best_f1, intent_acc_with_that))
# Out:
# [('bidirectional/forward_gru/gru_cell_1/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/kernel:0', TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('bidirectional/backward_gru/gru_cell_2/bias:0', TensorShape([2, 900])),
#  ('self_attention/layer_norm/scale:0', TensorShape([600])),
#  ('self_attention/layer_norm/bias:0', TensorShape([600])),
#  ('self_attention/multihead_self_attention/qkv_linear/kernel:0',
#   TensorShape([600, 1800])),
#  ('self_attention/multihead_self_attention/qkv_linear/bias:0',
#   TensorShape([1800])),
#  ('self_attention/multihead_self_attention/out_linear/kernel:0',
#   TensorShape([600, 600])),
#  ('self_attention/multihead_self_attention/out_linear/bias:0',
#   TensorShape([600])),
#  ('pointwise_ffn/layer_norm_1/scale:0', TensorShape([600])),
#  ('pointwise_ffn/layer_norm_1/bias:0', TensorShape([600])),
#  ('pointwise_ffn/pointwise_ffn/fc_relu/kernel:0', TensorShape([600, 1200])),
#  ('pointwise_ffn/pointwise_ffn/fc_relu/bias:0', TensorShape([1200])),
#  ('pointwise_ffn/pointwise_ffn/linear/kernel:0', TensorShape([1200, 600])),
#  ('pointwise_ffn/pointwise_ffn/linear/bias:0', TensorShape([600])),
#  ('fc_intent/kernel:0', TensorShape([1200, 300])),
#  ('fc_intent/bias:0', TensorShape([300])),
#  ('output_intent/kernel:0', TensorShape([300, 23])),
#  ('output_intent/bias:0', TensorShape([23])),
#  ('output_slot/kernel:0', TensorShape([600, 122])),
#  ('output_slot/bias:0', TensorShape([122])),
#  ('pretrained_embedding:0', TensorShape([750, 300])),
#  ('transitions:0', TensorShape([122, 122]))]
# Reading ../data/atis.train.w-intent.iob
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:644: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# INFO:tensorflow:Step 0 | Loss: 80.4034 | Loss_intent: 3.1263 | Loss_slots: 67.8983 | Spent: 2.7 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 17.7296 | Loss_intent: 1.6005 | Loss_slots: 11.3275 | Spent: 7.5 secs | LR: 0.000114
# INFO:tensorflow:Step 100 | Loss: 15.0300 | Loss_intent: 2.0052 | Loss_slots: 7.0093 | Spent: 7.5 secs | LR: 0.000128
# INFO:tensorflow:Step 150 | Loss: 14.6054 | Loss_intent: 1.5205 | Loss_slots: 8.5233 | Spent: 7.2 secs | LR: 0.000142
# INFO:tensorflow:Step 200 | Loss: 10.5804 | Loss_intent: 1.2418 | Loss_slots: 5.6132 | Spent: 7.0 secs | LR: 0.000156
# INFO:tensorflow:Step 250 | Loss: 10.4124 | Loss_intent: 1.5955 | Loss_slots: 4.0304 | Spent: 7.2 secs | LR: 0.000170
# INFO:tensorflow:Step 300 | Loss: 14.7554 | Loss_intent: 1.8168 | Loss_slots: 7.4881 | Spent: 7.0 secs | LR: 0.000184
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.881, Intent Acc: 0.876
# INFO:tensorflow:Best Slot F1: 0.881, Intent Acc: 0.876
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 350 | Loss: 8.1106 | Loss_intent: 1.4175 | Loss_slots: 2.4404 | Spent: 13.8 secs | LR: 0.000198
# INFO:tensorflow:Step 400 | Loss: 8.1108 | Loss_intent: 1.3656 | Loss_slots: 2.6483 | Spent: 6.9 secs | LR: 0.000212
# INFO:tensorflow:Step 450 | Loss: 8.9245 | Loss_intent: 1.4955 | Loss_slots: 2.9425 | Spent: 7.3 secs | LR: 0.000227
# INFO:tensorflow:Step 500 | Loss: 5.7285 | Loss_intent: 1.2116 | Loss_slots: 0.8820 | Spent: 7.3 secs | LR: 0.000241
# INFO:tensorflow:Step 550 | Loss: 7.0413 | Loss_intent: 1.3664 | Loss_slots: 1.5757 | Spent: 7.0 secs | LR: 0.000255
# INFO:tensorflow:Step 600 | Loss: 6.5516 | Loss_intent: 1.1860 | Loss_slots: 1.8077 | Spent: 7.1 secs | LR: 0.000269
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.927, Intent Acc: 0.923
# INFO:tensorflow:Best Slot F1: 0.927, Intent Acc: 0.923
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 650 | Loss: 7.3619 | Loss_intent: 1.7173 | Loss_slots: 0.4926 | Spent: 14.4 secs | LR: 0.000283
# INFO:tensorflow:Step 700 | Loss: 6.1185 | Loss_intent: 1.3759 | Loss_slots: 0.6150 | Spent: 7.3 secs | LR: 0.000297
# INFO:tensorflow:Step 750 | Loss: 6.1762 | Loss_intent: 1.1865 | Loss_slots: 1.4303 | Spent: 7.0 secs | LR: 0.000311
# INFO:tensorflow:Step 800 | Loss: 4.7322 | Loss_intent: 1.1322 | Loss_slots: 0.2034 | Spent: 7.2 secs | LR: 0.000325
# INFO:tensorflow:Step 850 | Loss: 4.7790 | Loss_intent: 1.1337 | Loss_slots: 0.2441 | Spent: 7.1 secs | LR: 0.000339
# INFO:tensorflow:Step 900 | Loss: 7.3099 | Loss_intent: 1.3729 | Loss_slots: 1.8183 | Spent: 7.1 secs | LR: 0.000353
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.939, Intent Acc: 0.946
# INFO:tensorflow:Best Slot F1: 0.939, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 950 | Loss: 5.0434 | Loss_intent: 1.1567 | Loss_slots: 0.4165 | Spent: 13.7 secs | LR: 0.000367
# INFO:tensorflow:Step 1000 | Loss: 5.2576 | Loss_intent: 1.1501 | Loss_slots: 0.6571 | Spent: 7.1 secs | LR: 0.000381
# INFO:tensorflow:Step 1050 | Loss: 6.1540 | Loss_intent: 1.2273 | Loss_slots: 1.2446 | Spent: 7.2 secs | LR: 0.000395
# INFO:tensorflow:Step 1100 | Loss: 6.5762 | Loss_intent: 1.3228 | Loss_slots: 1.2852 | Spent: 7.1 secs | LR: 0.000409
# INFO:tensorflow:Step 1150 | Loss: 5.9763 | Loss_intent: 1.1422 | Loss_slots: 1.4074 | Spent: 7.2 secs | LR: 0.000423
# INFO:tensorflow:Step 1200 | Loss: 5.1668 | Loss_intent: 1.1223 | Loss_slots: 0.6775 | Spent: 7.0 secs | LR: 0.000437
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.926, Intent Acc: 0.946
# INFO:tensorflow:Best Slot F1: 0.939, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1250 | Loss: 6.1215 | Loss_intent: 1.2031 | Loss_slots: 1.3092 | Spent: 13.9 secs | LR: 0.000452
# INFO:tensorflow:Step 1300 | Loss: 6.0863 | Loss_intent: 1.1597 | Loss_slots: 1.4474 | Spent: 7.5 secs | LR: 0.000466
# INFO:tensorflow:Step 1350 | Loss: 4.6832 | Loss_intent: 1.1353 | Loss_slots: 0.1419 | Spent: 7.1 secs | LR: 0.000480
# INFO:tensorflow:Step 1400 | Loss: 6.8374 | Loss_intent: 1.3715 | Loss_slots: 1.3515 | Spent: 7.4 secs | LR: 0.000494
# INFO:tensorflow:Step 1450 | Loss: 5.0810 | Loss_intent: 1.2065 | Loss_slots: 0.2551 | Spent: 6.9 secs | LR: 0.000508
# INFO:tensorflow:Step 1500 | Loss: 4.5431 | Loss_intent: 1.1200 | Loss_slots: 0.0633 | Spent: 7.0 secs | LR: 0.000522
# INFO:tensorflow:Step 1550 | Loss: 4.6797 | Loss_intent: 1.1192 | Loss_slots: 0.2030 | Spent: 7.5 secs | LR: 0.000536
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.943, Intent Acc: 0.946
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1600 | Loss: 4.5950 | Loss_intent: 1.1025 | Loss_slots: 0.1849 | Spent: 13.5 secs | LR: 0.000550
# INFO:tensorflow:Step 1650 | Loss: 5.1557 | Loss_intent: 1.0968 | Loss_slots: 0.7686 | Spent: 7.2 secs | LR: 0.000564
# INFO:tensorflow:Step 1700 | Loss: 5.5610 | Loss_intent: 1.2428 | Loss_slots: 0.5898 | Spent: 7.3 secs | LR: 0.000578
# INFO:tensorflow:Step 1750 | Loss: 6.5034 | Loss_intent: 1.1955 | Loss_slots: 1.7213 | Spent: 7.3 secs | LR: 0.000592
# INFO:tensorflow:Step 1800 | Loss: 4.7743 | Loss_intent: 1.1027 | Loss_slots: 0.3634 | Spent: 7.2 secs | LR: 0.000606
# INFO:tensorflow:Step 1850 | Loss: 6.1943 | Loss_intent: 1.2986 | Loss_slots: 1.0000 | Spent: 7.3 secs | LR: 0.000620
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.941, Intent Acc: 0.955
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1900 | Loss: 4.5759 | Loss_intent: 1.0998 | Loss_slots: 0.1768 | Spent: 13.8 secs | LR: 0.000634
# INFO:tensorflow:Step 1950 | Loss: 5.3726 | Loss_intent: 1.2309 | Loss_slots: 0.4490 | Spent: 7.5 secs | LR: 0.000648
# INFO:tensorflow:Step 2000 | Loss: 5.7527 | Loss_intent: 1.1400 | Loss_slots: 1.1926 | Spent: 6.9 secs | LR: 0.000662
# INFO:tensorflow:Step 2050 | Loss: 5.7891 | Loss_intent: 1.2356 | Loss_slots: 0.8468 | Spent: 7.3 secs | LR: 0.000677
# INFO:tensorflow:Step 2100 | Loss: 5.2313 | Loss_intent: 1.1267 | Loss_slots: 0.7245 | Spent: 7.2 secs | LR: 0.000691
# INFO:tensorflow:Step 2150 | Loss: 5.8913 | Loss_intent: 1.0987 | Loss_slots: 1.4965 | Spent: 6.9 secs | LR: 0.000705
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.940, Intent Acc: 0.952
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2200 | Loss: 4.8898 | Loss_intent: 1.1935 | Loss_slots: 0.1157 | Spent: 13.9 secs | LR: 0.000719
# INFO:tensorflow:Step 2250 | Loss: 5.6947 | Loss_intent: 1.1862 | Loss_slots: 0.9499 | Spent: 7.1 secs | LR: 0.000733
# INFO:tensorflow:Step 2300 | Loss: 4.5729 | Loss_intent: 1.1228 | Loss_slots: 0.0817 | Spent: 7.1 secs | LR: 0.000747
# INFO:tensorflow:Step 2350 | Loss: 5.8869 | Loss_intent: 1.1041 | Loss_slots: 1.4705 | Spent: 7.1 secs | LR: 0.000761
# INFO:tensorflow:Step 2400 | Loss: 4.5124 | Loss_intent: 1.1014 | Loss_slots: 0.1069 | Spent: 7.2 secs | LR: 0.000775
# INFO:tensorflow:Step 2450 | Loss: 4.7794 | Loss_intent: 1.1526 | Loss_slots: 0.1690 | Spent: 7.2 secs | LR: 0.000789
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.936, Intent Acc: 0.961
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.966     0.992     0.979       632
#                             atis_airfare      0.941     1.000     0.970        48
#                      atis_ground_service      0.923     1.000     0.960        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     0.889     0.941         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.667     0.167     0.267        12
#                             atis_airport      1.000     0.889     0.941        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.500     0.667         6
#                         atis_ground_fare      1.000     0.571     0.727         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      0.000     0.000     0.000         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.961     0.966     0.964       888
#                                macro avg      0.627     0.591     0.590       888
#                             weighted avg      0.954     0.966     0.956       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.971     0.992     0.981     716.0
#          B-fromloc.city_name      0.985     0.997     0.991     704.0
#            I-toloc.city_name      0.974     0.985     0.979     265.0
#       B-depart_date.day_name      0.977     0.991     0.984     212.0
#               B-airline_name      0.953     1.000     0.976     101.0
#          I-fromloc.city_name      0.978     0.989     0.983     177.0
#  B-depart_time.period_of_day      0.983     0.892     0.935     130.0
#               I-airline_name      1.000     0.923     0.960      65.0
#     B-depart_date.day_number      0.964     0.964     0.964      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.889     0.982     0.933      57.0
#                 B-round_trip      1.000     0.959     0.979      73.0
#              B-cost_relative      0.973     0.973     0.973      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.727     1.000     0.842      24.0
#  B-depart_time.time_relative      1.000     0.877     0.934      65.0
#           I-depart_time.time      1.000     0.962     0.980      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.857     0.526     0.652      57.0
#                 B-class_type      0.885     0.958     0.920      24.0
#           B-arrive_time.time      0.895     1.000     0.944      34.0
#  B-arrive_time.time_relative      0.838     1.000     0.912      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      0.955     1.000     0.977      21.0
#           I-arrive_time.time      0.946     1.000     0.972      35.0
#               B-airline_code      0.892     0.971     0.930      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.385     1.000     0.556      15.0
#       B-fromloc.airport_name      0.500     1.000     0.667      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.667     0.800       9.0
#              B-flight_number      0.714     0.909     0.800      11.0
#  B-depart_date.date_relative      1.000     0.353     0.522      17.0
#           B-toloc.state_name      0.821     0.821     0.821      28.0
#            B-fare_basis_code      0.895     1.000     0.944      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.600     1.000     0.750       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.889     0.276     0.421      29.0
#                B-fare_amount      1.000     0.500     0.667       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.533     0.696      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.667     0.667     0.667       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.714     1.000     0.833       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      0.750     1.000     0.857       3.0
#         B-fromloc.state_name      0.882     0.882     0.882      17.0
#               B-airport_name      0.692     0.429     0.529      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.606     0.755      33.0
#                        B-mod      0.000     0.000     0.000       2.0
#               B-airport_code      0.500     0.111     0.182       9.0
#     B-depart_time.start_time      0.600     1.000     0.750       3.0
#       B-depart_time.end_time      0.600     1.000     0.750       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.333     1.000     0.500       4.0
#     B-arrive_time.start_time      1.000     0.125     0.222       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      1.000     0.875     0.933       8.0
#       I-arrive_time.end_time      0.857     0.750     0.800       8.0
#       I-depart_time.end_time      0.400     0.667     0.500       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.500     1.000     0.667       5.0
#           I-restriction_code      0.750     1.000     0.857       3.0
#     I-depart_time.start_time      0.000     0.000     0.000       1.0
#           I-toloc.state_name      0.000     0.000     0.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      0.000     0.000     0.000       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.667     0.667     0.667       3.0
#         I-fromloc.state_name      0.143     1.000     0.250       1.0
#                 B-state_code      0.000     0.000     0.000       1.0
#     I-arrive_time.start_time      0.500     1.000     0.667       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      0.000     0.000     0.000       1.0
#                   B-day_name      0.000     0.000     0.000       2.0
#              B-period_of_day      1.000     0.250     0.400       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.000     0.000     0.000       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.935     0.937     0.936    3657.0
#                    macro avg      0.574     0.579     0.555    3657.0
#                 weighted avg      0.946     0.937     0.934    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:tensorflow:Step 2500 | Loss: 4.9500 | Loss_intent: 1.1226 | Loss_slots: 0.4596 | Spent: 14.3 secs | LR: 0.000797
# INFO:tensorflow:Step 2550 | Loss: 4.8938 | Loss_intent: 1.1996 | Loss_slots: 0.0954 | Spent: 7.4 secs | LR: 0.000783
# INFO:tensorflow:Step 2600 | Loss: 6.1198 | Loss_intent: 1.1230 | Loss_slots: 1.6277 | Spent: 7.0 secs | LR: 0.000769
# INFO:tensorflow:Step 2650 | Loss: 7.3990 | Loss_intent: 1.3838 | Loss_slots: 1.8637 | Spent: 7.2 secs | LR: 0.000755
# INFO:tensorflow:Step 2700 | Loss: 4.6220 | Loss_intent: 1.1375 | Loss_slots: 0.0722 | Spent: 7.0 secs | LR: 0.000741
# INFO:tensorflow:Step 2750 | Loss: 7.2735 | Loss_intent: 1.2078 | Loss_slots: 2.4423 | Spent: 7.0 secs | LR: 0.000727
# INFO:tensorflow:Step 2800 | Loss: 4.6978 | Loss_intent: 1.1063 | Loss_slots: 0.2726 | Spent: 7.3 secs | LR: 0.000713
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.939, Intent Acc: 0.954
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.946
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2850 | Loss: 5.2975 | Loss_intent: 1.1118 | Loss_slots: 0.8501 | Spent: 13.6 secs | LR: 0.000698
# INFO:tensorflow:Step 2900 | Loss: 4.9839 | Loss_intent: 1.1325 | Loss_slots: 0.4541 | Spent: 7.0 secs | LR: 0.000684
# INFO:tensorflow:Step 2950 | Loss: 5.5425 | Loss_intent: 1.1033 | Loss_slots: 1.1293 | Spent: 7.0 secs | LR: 0.000670
# INFO:tensorflow:Step 3000 | Loss: 5.5278 | Loss_intent: 1.1125 | Loss_slots: 1.0780 | Spent: 7.3 secs | LR: 0.000656
# INFO:tensorflow:Step 3050 | Loss: 5.9235 | Loss_intent: 1.2925 | Loss_slots: 0.7536 | Spent: 7.0 secs | LR: 0.000642
# INFO:tensorflow:Step 3100 | Loss: 5.2784 | Loss_intent: 1.1006 | Loss_slots: 0.8760 | Spent: 7.1 secs | LR: 0.000628
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.944, Intent Acc: 0.956
# INFO:tensorflow:Best Slot F1: 0.944, Intent Acc: 0.956
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3150 | Loss: 5.3982 | Loss_intent: 1.2326 | Loss_slots: 0.4678 | Spent: 13.6 secs | LR: 0.000614
# INFO:tensorflow:Step 3200 | Loss: 4.4023 | Loss_intent: 1.0999 | Loss_slots: 0.0026 | Spent: 7.2 secs | LR: 0.000600
# INFO:tensorflow:Step 3250 | Loss: 4.4307 | Loss_intent: 1.1074 | Loss_slots: 0.0013 | Spent: 7.3 secs | LR: 0.000586
# INFO:tensorflow:Step 3300 | Loss: 6.5322 | Loss_intent: 1.3660 | Loss_slots: 1.0682 | Spent: 7.0 secs | LR: 0.000572
# INFO:tensorflow:Step 3350 | Loss: 5.9273 | Loss_intent: 1.1575 | Loss_slots: 1.2973 | Spent: 7.1 secs | LR: 0.000558
# INFO:tensorflow:Step 3400 | Loss: 4.7919 | Loss_intent: 1.1973 | Loss_slots: 0.0027 | Spent: 7.1 secs | LR: 0.000544
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.949, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3450 | Loss: 4.7511 | Loss_intent: 1.1282 | Loss_slots: 0.2383 | Spent: 13.5 secs | LR: 0.000530
# INFO:tensorflow:Step 3500 | Loss: 5.5124 | Loss_intent: 1.2774 | Loss_slots: 0.4029 | Spent: 6.7 secs | LR: 0.000516
# INFO:tensorflow:Step 3550 | Loss: 4.7833 | Loss_intent: 1.1806 | Loss_slots: 0.0610 | Spent: 7.4 secs | LR: 0.000502
# INFO:tensorflow:Step 3600 | Loss: 4.9098 | Loss_intent: 1.0917 | Loss_slots: 0.5429 | Spent: 7.5 secs | LR: 0.000488
# INFO:tensorflow:Step 3650 | Loss: 4.6657 | Loss_intent: 1.0921 | Loss_slots: 0.2971 | Spent: 6.8 secs | LR: 0.000473
# INFO:tensorflow:Step 3700 | Loss: 4.6885 | Loss_intent: 1.1093 | Loss_slots: 0.2514 | Spent: 7.1 secs | LR: 0.000459
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.946, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.949, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3750 | Loss: 4.5474 | Loss_intent: 1.1345 | Loss_slots: 0.0093 | Spent: 13.3 secs | LR: 0.000445
# INFO:tensorflow:Step 3800 | Loss: 4.5324 | Loss_intent: 1.1206 | Loss_slots: 0.0499 | Spent: 7.2 secs | LR: 0.000431
# INFO:tensorflow:Step 3850 | Loss: 5.2864 | Loss_intent: 1.2272 | Loss_slots: 0.3776 | Spent: 7.0 secs | LR: 0.000417
# INFO:tensorflow:Step 3900 | Loss: 5.1522 | Loss_intent: 1.1017 | Loss_slots: 0.7454 | Spent: 7.2 secs | LR: 0.000403
# INFO:tensorflow:Step 3950 | Loss: 4.3698 | Loss_intent: 1.0919 | Loss_slots: 0.0024 | Spent: 7.0 secs | LR: 0.000389
# INFO:tensorflow:Step 4000 | Loss: 4.6441 | Loss_intent: 1.0940 | Loss_slots: 0.2681 | Spent: 7.3 secs | LR: 0.000375
# INFO:tensorflow:Step 4050 | Loss: 4.3577 | Loss_intent: 1.0890 | Loss_slots: 0.0016 | Spent: 6.8 secs | LR: 0.000361
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.961
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.961
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4100 | Loss: 4.6984 | Loss_intent: 1.0932 | Loss_slots: 0.3258 | Spent: 13.3 secs | LR: 0.000347
# INFO:tensorflow:Step 4150 | Loss: 5.2790 | Loss_intent: 1.0948 | Loss_slots: 0.8998 | Spent: 7.2 secs | LR: 0.000333
# INFO:tensorflow:Step 4200 | Loss: 4.8192 | Loss_intent: 1.1397 | Loss_slots: 0.2606 | Spent: 7.2 secs | LR: 0.000319
# INFO:tensorflow:Step 4250 | Loss: 4.3569 | Loss_intent: 1.0859 | Loss_slots: 0.0134 | Spent: 7.2 secs | LR: 0.000305
# INFO:tensorflow:Step 4300 | Loss: 4.7621 | Loss_intent: 1.0916 | Loss_slots: 0.3955 | Spent: 7.6 secs | LR: 0.000291
# INFO:tensorflow:Step 4350 | Loss: 4.3387 | Loss_intent: 1.0838 | Loss_slots: 0.0037 | Spent: 7.2 secs | LR: 0.000277
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.950, Intent Acc: 0.965
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.961
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4400 | Loss: 4.4093 | Loss_intent: 1.0846 | Loss_slots: 0.0710 | Spent: 13.9 secs | LR: 0.000263
# INFO:tensorflow:Step 4450 | Loss: 5.2956 | Loss_intent: 1.1177 | Loss_slots: 0.8248 | Spent: 7.1 secs | LR: 0.000248
# INFO:tensorflow:Step 4500 | Loss: 4.3944 | Loss_intent: 1.0973 | Loss_slots: 0.0051 | Spent: 6.9 secs | LR: 0.000234
# INFO:tensorflow:Step 4550 | Loss: 4.4185 | Loss_intent: 1.0935 | Loss_slots: 0.0445 | Spent: 7.1 secs | LR: 0.000220
# INFO:tensorflow:Step 4600 | Loss: 4.6645 | Loss_intent: 1.0835 | Loss_slots: 0.3307 | Spent: 7.2 secs | LR: 0.000206
# INFO:tensorflow:Step 4650 | Loss: 4.3858 | Loss_intent: 1.0946 | Loss_slots: 0.0074 | Spent: 6.9 secs | LR: 0.000192
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.952, Intent Acc: 0.961
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4700 | Loss: 4.3355 | Loss_intent: 1.0838 | Loss_slots: 0.0004 | Spent: 13.6 secs | LR: 0.000178
# INFO:tensorflow:Step 4750 | Loss: 4.3365 | Loss_intent: 1.0839 | Loss_slots: 0.0009 | Spent: 7.1 secs | LR: 0.000164
# INFO:tensorflow:Step 4800 | Loss: 4.3727 | Loss_intent: 1.0846 | Loss_slots: 0.0341 | Spent: 6.8 secs | LR: 0.000150
# INFO:tensorflow:Step 4850 | Loss: 4.3593 | Loss_intent: 1.0895 | Loss_slots: 0.0011 | Spent: 7.0 secs | LR: 0.000136
# INFO:tensorflow:Step 4900 | Loss: 4.5321 | Loss_intent: 1.0871 | Loss_slots: 0.1836 | Spent: 7.4 secs | LR: 0.000122
# INFO:tensorflow:Step 4950 | Loss: 4.3330 | Loss_intent: 1.0811 | Loss_slots: 0.0088 | Spent: 7.2 secs | LR: 0.000108
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.969
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.971     0.992     0.981       632
#                             atis_airfare      0.940     0.979     0.959        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     0.889     0.941         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.667     0.167     0.267        12
#                             atis_airport      1.000     0.889     0.941        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.750     0.500     0.600         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      1.000     1.000     1.000         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.969     0.974     0.971       888
#                                macro avg      0.671     0.648     0.645       888
#                             weighted avg      0.968     0.974     0.968       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.969     0.990     0.979     716.0
#          B-fromloc.city_name      0.978     1.000     0.989     704.0
#            I-toloc.city_name      0.956     0.985     0.970     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.967     1.000     0.983     177.0
#  B-depart_time.period_of_day      1.000     0.931     0.964     130.0
#               I-airline_name      0.985     1.000     0.992      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.864     1.000     0.927      57.0
#                 B-round_trip      1.000     0.973     0.986      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.960     1.000     0.980      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     0.950     0.974      20.0
#                  B-city_name      0.909     0.526     0.667      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.917     0.971     0.943      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     1.000     1.000      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.469     1.000     0.638      15.0
#       B-fromloc.airport_name      0.500     0.917     0.647      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.611     1.000     0.759      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.806     0.893     0.847      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.923     0.414     0.571      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.433     0.605      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.818     0.429     0.562      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.909     0.909     0.909      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.444     1.000     0.615       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.500     0.667       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.000     0.000     0.000       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.250     0.400       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      0.000     0.000     0.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.667     0.667     0.667       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.952     0.954     0.953    3657.0
#                    macro avg      0.663     0.636     0.636    3657.0
#                 weighted avg      0.956     0.954     0.950    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5000 | Loss: 4.3425 | Loss_intent: 1.0841 | Loss_slots: 0.0062 | Spent: 13.8 secs | LR: 0.000103
# INFO:tensorflow:Step 5050 | Loss: 4.3434 | Loss_intent: 1.0858 | Loss_slots: 0.0003 | Spent: 6.9 secs | LR: 0.000110
# INFO:tensorflow:Step 5100 | Loss: 4.3543 | Loss_intent: 1.0804 | Loss_slots: 0.0329 | Spent: 7.2 secs | LR: 0.000117
# INFO:tensorflow:Step 5150 | Loss: 4.3380 | Loss_intent: 1.0837 | Loss_slots: 0.0033 | Spent: 7.2 secs | LR: 0.000124
# INFO:tensorflow:Step 5200 | Loss: 4.3320 | Loss_intent: 1.0829 | Loss_slots: 0.0004 | Spent: 7.3 secs | LR: 0.000131
# INFO:tensorflow:Step 5250 | Loss: 4.3643 | Loss_intent: 1.0902 | Loss_slots: 0.0035 | Spent: 7.0 secs | LR: 0.000138
# INFO:tensorflow:Step 5300 | Loss: 4.4398 | Loss_intent: 1.1098 | Loss_slots: 0.0006 | Spent: 7.5 secs | LR: 0.000145
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.953, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5350 | Loss: 4.6801 | Loss_intent: 1.0830 | Loss_slots: 0.3481 | Spent: 13.9 secs | LR: 0.000152
# INFO:tensorflow:Step 5400 | Loss: 4.4577 | Loss_intent: 1.1143 | Loss_slots: 0.0005 | Spent: 7.1 secs | LR: 0.000159
# INFO:tensorflow:Step 5450 | Loss: 4.3655 | Loss_intent: 1.0912 | Loss_slots: 0.0008 | Spent: 7.4 secs | LR: 0.000166
# INFO:tensorflow:Step 5500 | Loss: 4.3451 | Loss_intent: 1.0858 | Loss_slots: 0.0020 | Spent: 7.0 secs | LR: 0.000173
# INFO:tensorflow:Step 5550 | Loss: 4.3520 | Loss_intent: 1.0876 | Loss_slots: 0.0014 | Spent: 7.0 secs | LR: 0.000180
# INFO:tensorflow:Step 5600 | Loss: 4.3571 | Loss_intent: 1.0875 | Loss_slots: 0.0072 | Spent: 7.3 secs | LR: 0.000187
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.966
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5650 | Loss: 4.3465 | Loss_intent: 1.0832 | Loss_slots: 0.0137 | Spent: 13.7 secs | LR: 0.000194
# INFO:tensorflow:Step 5700 | Loss: 4.3274 | Loss_intent: 1.0814 | Loss_slots: 0.0018 | Spent: 6.9 secs | LR: 0.000202
# INFO:tensorflow:Step 5750 | Loss: 4.3564 | Loss_intent: 1.0888 | Loss_slots: 0.0013 | Spent: 7.2 secs | LR: 0.000209
# INFO:tensorflow:Step 5800 | Loss: 4.3512 | Loss_intent: 1.0867 | Loss_slots: 0.0046 | Spent: 7.3 secs | LR: 0.000216
# INFO:tensorflow:Step 5850 | Loss: 4.7521 | Loss_intent: 1.0888 | Loss_slots: 0.3969 | Spent: 7.1 secs | LR: 0.000223
# INFO:tensorflow:Step 5900 | Loss: 4.5562 | Loss_intent: 1.1052 | Loss_slots: 0.1355 | Spent: 7.2 secs | LR: 0.000230
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5950 | Loss: 5.3412 | Loss_intent: 1.0864 | Loss_slots: 0.9957 | Spent: 13.8 secs | LR: 0.000237
# INFO:tensorflow:Step 6000 | Loss: 4.3583 | Loss_intent: 1.0883 | Loss_slots: 0.0049 | Spent: 6.9 secs | LR: 0.000244
# INFO:tensorflow:Step 6050 | Loss: 4.3868 | Loss_intent: 1.0949 | Loss_slots: 0.0074 | Spent: 7.0 secs | LR: 0.000251
# INFO:tensorflow:Step 6100 | Loss: 4.3609 | Loss_intent: 1.0902 | Loss_slots: 0.0001 | Spent: 7.3 secs | LR: 0.000258
# INFO:tensorflow:Step 6150 | Loss: 4.5159 | Loss_intent: 1.0982 | Loss_slots: 0.1233 | Spent: 7.2 secs | LR: 0.000265
# INFO:tensorflow:Step 6200 | Loss: 4.4035 | Loss_intent: 1.1000 | Loss_slots: 0.0036 | Spent: 7.2 secs | LR: 0.000272
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6250 | Loss: 4.3614 | Loss_intent: 1.0868 | Loss_slots: 0.0143 | Spent: 13.5 secs | LR: 0.000279
# INFO:tensorflow:Step 6300 | Loss: 4.3661 | Loss_intent: 1.0882 | Loss_slots: 0.0133 | Spent: 7.6 secs | LR: 0.000286
# INFO:tensorflow:Step 6350 | Loss: 4.5777 | Loss_intent: 1.0835 | Loss_slots: 0.2438 | Spent: 6.9 secs | LR: 0.000293
# INFO:tensorflow:Step 6400 | Loss: 4.6775 | Loss_intent: 1.0853 | Loss_slots: 0.3362 | Spent: 7.2 secs | LR: 0.000300
# INFO:tensorflow:Step 6450 | Loss: 4.6465 | Loss_intent: 1.1114 | Loss_slots: 0.2010 | Spent: 7.1 secs | LR: 0.000307
# INFO:tensorflow:Step 6500 | Loss: 4.4206 | Loss_intent: 1.1046 | Loss_slots: 0.0024 | Spent: 7.4 secs | LR: 0.000314
# INFO:tensorflow:Step 6550 | Loss: 4.3844 | Loss_intent: 1.0953 | Loss_slots: 0.0031 | Spent: 7.3 secs | LR: 0.000321
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.945, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6600 | Loss: 4.5708 | Loss_intent: 1.0902 | Loss_slots: 0.2100 | Spent: 13.8 secs | LR: 0.000328
# INFO:tensorflow:Step 6650 | Loss: 4.8838 | Loss_intent: 1.2120 | Loss_slots: 0.0356 | Spent: 7.1 secs | LR: 0.000335
# INFO:tensorflow:Step 6700 | Loss: 4.3829 | Loss_intent: 1.0947 | Loss_slots: 0.0043 | Spent: 7.0 secs | LR: 0.000342
# INFO:tensorflow:Step 6750 | Loss: 4.4458 | Loss_intent: 1.0866 | Loss_slots: 0.0993 | Spent: 7.1 secs | LR: 0.000349
# INFO:tensorflow:Step 6800 | Loss: 4.3502 | Loss_intent: 1.0870 | Loss_slots: 0.0022 | Spent: 7.3 secs | LR: 0.000356
# INFO:tensorflow:Step 6850 | Loss: 4.3328 | Loss_intent: 1.0826 | Loss_slots: 0.0024 | Spent: 7.0 secs | LR: 0.000363
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6900 | Loss: 4.3978 | Loss_intent: 1.0950 | Loss_slots: 0.0179 | Spent: 13.6 secs | LR: 0.000370
# INFO:tensorflow:Step 6950 | Loss: 4.3601 | Loss_intent: 1.0882 | Loss_slots: 0.0075 | Spent: 7.3 secs | LR: 0.000377
# INFO:tensorflow:Step 7000 | Loss: 4.3819 | Loss_intent: 1.0939 | Loss_slots: 0.0064 | Spent: 7.0 secs | LR: 0.000384
# INFO:tensorflow:Step 7050 | Loss: 4.4118 | Loss_intent: 1.0993 | Loss_slots: 0.0146 | Spent: 7.0 secs | LR: 0.000391
# INFO:tensorflow:Step 7100 | Loss: 4.3878 | Loss_intent: 1.0858 | Loss_slots: 0.0445 | Spent: 7.3 secs | LR: 0.000398
# INFO:tensorflow:Step 7150 | Loss: 4.4008 | Loss_intent: 1.0906 | Loss_slots: 0.0386 | Spent: 6.9 secs | LR: 0.000405
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.963
# INFO:tensorflow:Best Slot F1: 0.954, Intent Acc: 0.966
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 7200 | Loss: 4.4298 | Loss_intent: 1.1073 | Loss_slots: 0.0005 | Spent: 13.7 secs | LR: 0.000412
# INFO:tensorflow:Step 7250 | Loss: 4.4030 | Loss_intent: 1.0886 | Loss_slots: 0.0486 | Spent: 6.9 secs | LR: 0.000419
# INFO:tensorflow:Step 7300 | Loss: 4.3882 | Loss_intent: 1.0859 | Loss_slots: 0.0445 | Spent: 7.4 secs | LR: 0.000427
# INFO:tensorflow:Step 7350 | Loss: 4.6545 | Loss_intent: 1.0946 | Loss_slots: 0.2760 | Spent: 7.1 secs | LR: 0.000434
# INFO:tensorflow:Step 7400 | Loss: 4.4185 | Loss_intent: 1.1029 | Loss_slots: 0.0069 | Spent: 7.0 secs | LR: 0.000441
# INFO:tensorflow:Step 7450 | Loss: 5.1814 | Loss_intent: 1.2580 | Loss_slots: 0.1494 | Spent: 7.2 secs | LR: 0.000448
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.963
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.972     0.992     0.982       632
#                             atis_airfare      0.979     0.979     0.979        48
#                      atis_ground_service      0.900     1.000     0.947        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.941     0.970     0.955        33
#                            atis_aircraft      1.000     0.889     0.941         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      1.000     0.833     0.909        18
#                            atis_distance      1.000     0.600     0.750        10
#                                atis_city      1.000     0.500     0.667         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     0.952     0.976        21
#                           atis_flight_no      0.875     0.875     0.875         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
# ...
# INFO:tensorflow:Step 18350 | Loss: 4.3563 | Loss_intent: 1.0890 | Loss_slots: 0.0003 | Spent: 7.0 secs | LR: 0.000155
# INFO:tensorflow:Step 18400 | Loss: 4.3297 | Loss_intent: 1.0824 | Loss_slots: 0.0000 | Spent: 7.0 secs | LR: 0.000153
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18450 | Loss: 4.3349 | Loss_intent: 1.0837 | Loss_slots: 0.0001 | Spent: 12.9 secs | LR: 0.000151
# INFO:tensorflow:Step 18500 | Loss: 4.3246 | Loss_intent: 1.0811 | Loss_slots: 0.0001 | Spent: 7.2 secs | LR: 0.000150
# INFO:tensorflow:Step 18550 | Loss: 4.3471 | Loss_intent: 1.0814 | Loss_slots: 0.0214 | Spent: 6.9 secs | LR: 0.000148
# INFO:tensorflow:Step 18600 | Loss: 4.3384 | Loss_intent: 1.0846 | Loss_slots: 0.0001 | Spent: 7.0 secs | LR: 0.000146
# INFO:tensorflow:Step 18650 | Loss: 4.3332 | Loss_intent: 1.0832 | Loss_slots: 0.0003 | Spent: 6.9 secs | LR: 0.000144
# INFO:tensorflow:Step 18700 | Loss: 4.3340 | Loss_intent: 1.0829 | Loss_slots: 0.0026 | Spent: 7.1 secs | LR: 0.000143
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18750 | Loss: 4.3590 | Loss_intent: 1.0816 | Loss_slots: 0.0327 | Spent: 13.0 secs | LR: 0.000141
# INFO:tensorflow:Step 18800 | Loss: 4.3230 | Loss_intent: 1.0807 | Loss_slots: 0.0000 | Spent: 7.0 secs | LR: 0.000139
# INFO:tensorflow:Step 18850 | Loss: 4.3243 | Loss_intent: 1.0809 | Loss_slots: 0.0007 | Spent: 7.0 secs | LR: 0.000137
# INFO:tensorflow:Step 18900 | Loss: 4.3251 | Loss_intent: 1.0811 | Loss_slots: 0.0008 | Spent: 6.9 secs | LR: 0.000136
# INFO:tensorflow:Step 18950 | Loss: 4.3355 | Loss_intent: 1.0831 | Loss_slots: 0.0031 | Spent: 7.2 secs | LR: 0.000134
# INFO:tensorflow:Step 19000 | Loss: 5.3298 | Loss_intent: 1.0813 | Loss_slots: 1.0046 | Spent: 7.3 secs | LR: 0.000132
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19050 | Loss: 4.3318 | Loss_intent: 1.0829 | Loss_slots: 0.0002 | Spent: 13.1 secs | LR: 0.000130
# INFO:tensorflow:Step 19100 | Loss: 4.3351 | Loss_intent: 1.0836 | Loss_slots: 0.0008 | Spent: 6.9 secs | LR: 0.000129
# INFO:tensorflow:Step 19150 | Loss: 4.4442 | Loss_intent: 1.0815 | Loss_slots: 0.1180 | Spent: 6.7 secs | LR: 0.000127
# INFO:tensorflow:Step 19200 | Loss: 4.3230 | Loss_intent: 1.0807 | Loss_slots: 0.0002 | Spent: 6.9 secs | LR: 0.000125
# INFO:tensorflow:Step 19250 | Loss: 4.3266 | Loss_intent: 1.0812 | Loss_slots: 0.0020 | Spent: 6.8 secs | LR: 0.000123
# INFO:tensorflow:Step 19300 | Loss: 4.3320 | Loss_intent: 1.0830 | Loss_slots: 0.0000 | Spent: 6.8 secs | LR: 0.000122
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19350 | Loss: 4.3370 | Loss_intent: 1.0842 | Loss_slots: 0.0003 | Spent: 13.1 secs | LR: 0.000120
# INFO:tensorflow:Step 19400 | Loss: 4.3248 | Loss_intent: 1.0812 | Loss_slots: 0.0001 | Spent: 7.1 secs | LR: 0.000118
# INFO:tensorflow:Step 19450 | Loss: 4.3218 | Loss_intent: 1.0804 | Loss_slots: 0.0003 | Spent: 6.9 secs | LR: 0.000116
# INFO:tensorflow:Step 19500 | Loss: 4.3510 | Loss_intent: 1.0877 | Loss_slots: -0.0000 | Spent: 7.1 secs | LR: 0.000114
# INFO:tensorflow:Step 19550 | Loss: 4.3296 | Loss_intent: 1.0824 | Loss_slots: 0.0000 | Spent: 7.3 secs | LR: 0.000113
# INFO:tensorflow:Step 19600 | Loss: 4.3248 | Loss_intent: 1.0809 | Loss_slots: 0.0011 | Spent: 7.0 secs | LR: 0.000111
# INFO:tensorflow:Step 19650 | Loss: 4.3379 | Loss_intent: 1.0845 | Loss_slots: 0.0000 | Spent: 7.0 secs | LR: 0.000109
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19700 | Loss: 4.3252 | Loss_intent: 1.0813 | Loss_slots: 0.0002 | Spent: 13.3 secs | LR: 0.000107
# INFO:tensorflow:Step 19750 | Loss: 4.3212 | Loss_intent: 1.0803 | Loss_slots: 0.0000 | Spent: 7.4 secs | LR: 0.000106
# INFO:tensorflow:Step 19800 | Loss: 4.3245 | Loss_intent: 1.0811 | Loss_slots: -0.0000 | Spent: 7.2 secs | LR: 0.000104
# INFO:tensorflow:Step 19850 | Loss: 4.3262 | Loss_intent: 1.0815 | Loss_slots: 0.0001 | Spent: 7.1 secs | LR: 0.000102
# INFO:tensorflow:Step 19900 | Loss: 4.3926 | Loss_intent: 1.0843 | Loss_slots: 0.0555 | Spent: 7.2 secs | LR: 0.000100
# INFO:tensorflow:Step 19950 | Loss: 4.3281 | Loss_intent: 1.0820 | Loss_slots: 0.0002 | Spent: 7.1 secs | LR: 0.000101
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.972
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.977     0.992     0.984       632
#                             atis_airfare      0.959     0.979     0.969        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     0.889     0.941         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.800     0.333     0.471        12
#                             atis_airport      0.941     0.889     0.914        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.800     0.667     0.727         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.972     0.977     0.975       888
#                                macro avg      0.672     0.663     0.657       888
#                             weighted avg      0.973     0.977     0.973       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.973     0.993     0.983     716.0
#          B-fromloc.city_name      0.987     0.997     0.992     704.0
#            I-toloc.city_name      0.952     0.981     0.967     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     0.990     0.995     101.0
#          I-fromloc.city_name      0.972     0.994     0.983     177.0
#  B-depart_time.period_of_day      1.000     0.931     0.964     130.0
#               I-airline_name      0.985     1.000     0.992      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.838     1.000     0.912      57.0
#                 B-round_trip      1.000     0.973     0.986      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      1.000     1.000     1.000      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.981     1.000     0.990      52.0
#          B-stoploc.city_name      1.000     1.000     1.000      20.0
#                  B-city_name      0.912     0.544     0.681      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.943     0.971     0.957      34.0
#  B-arrive_time.time_relative      0.967     0.935     0.951      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      0.971     0.971     0.971      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.429     1.000     0.600      15.0
#       B-fromloc.airport_name      0.429     1.000     0.600      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.611     1.000     0.759      11.0
#  B-depart_date.date_relative      0.944     1.000     0.971      17.0
#           B-toloc.state_name      0.893     0.893     0.893      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.800     0.414     0.545      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.929     0.433     0.591      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     1.000     1.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.800     0.381     0.516      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      0.800     0.848     0.824      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.000     0.000     0.000       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     1.000     1.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      0.444     1.000     0.615       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-arrive_time.end_time      0.875     0.875     0.875       8.0
#       I-depart_time.end_time      1.000     0.667     0.800       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      1.000     1.000     1.000       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     1.000     1.000       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.250     0.400       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      1.000     0.500     0.667       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.500     0.111     0.182       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.952     0.954     0.953    3657.0
#                    macro avg      0.682     0.652     0.651    3657.0
#                 weighted avg      0.959     0.954     0.951    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.957, Intent Acc: 0.969
