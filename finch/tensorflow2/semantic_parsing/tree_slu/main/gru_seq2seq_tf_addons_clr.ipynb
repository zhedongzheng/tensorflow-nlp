# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/semantic_parsing/tree_slu/main')

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate

import tensorflow as tf
import tensorflow_addons as tfa

import numpy as np
import pprint
import logging
import time
import nltk

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-19e7c5f51f68>:13: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      text_raw, text_tokenized, label = line.split('\t')
      text_tokenized = text_tokenized.lower().split()
      label = label.replace('[', '[ ').lower().split()
      source = [params['tgt2idx'].get(w, len(params['tgt2idx'])) for w in text_tokenized]
      target = [params['tgt2idx'].get(w, len(params['tgt2idx'])) for w in label]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, target_in, target_out)

# %%
def dataset(is_training, params):
  _shapes = ([None], [None], [None])
  _types = (tf.int32, tf.int32, tf.int32)
  _pads = (0, 0, 0)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['train_batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['eval_batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class Embed(tf.keras.Model):
  def __init__(self):
    super().__init__()
    self.embedding = tf.Variable(np.load('../vocab/word.npy'),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
  
  def call(self, inputs):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    return x

# %%
class Encoder(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.bilstm = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
      params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    self.state_fc = tf.keras.layers.Dense(params['rnn_units'], params['activation'], name='state_fc')
  
  def call(self, inputs, mask, training):
    if mask.dtype != tf.bool:
      mask = tf.cast(mask, tf.bool)
    x = self.dropout(inputs, training=training)
    
    encoder_o, state_fw, state_bw = self.bilstm(x, mask=mask)
    encoder_s = self.state_fc(tf.concat((state_fw, state_bw), -1))
    
    return encoder_o, tuple([encoder_s])

# %%
class TiedDense(tf.keras.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
class Model(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.embed = Embed()

    self.encoder = Encoder(params)

    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])

    self.attn = tfa.seq2seq.BahdanauAttention(params['rnn_units'])

    self.decoder_cell = tfa.seq2seq.AttentionWrapper(
      tf.keras.layers.StackedRNNCells([tf.keras.layers.GRUCell(params['rnn_units'])]),
      self.attn,
      attention_layer_size=params['rnn_units'])
    
    self.proj_layer = TiedDense(self.embed.embedding, len(params['tgt2idx'])+1)

    self.teach_forcing = tfa.seq2seq.BasicDecoder(
      self.decoder_cell,
      tfa.seq2seq.sampler.TrainingSampler(),
      output_layer = self.proj_layer)

    self.beam_search = tfa.seq2seq.BeamSearchDecoder(
      self.decoder_cell,
      beam_width = params['beam_width'],
      embedding_fn = lambda x: self.embed(x),
      output_layer = self.proj_layer,
      maximum_iterations = 80,)

  
  def call(self, inputs, training=True):
    if training:
      source, target_in = inputs
    else:
      source = inputs
    batch_sz = tf.shape(source)[0]

    encoder_o, encoder_s = self.encoder(self.embed(source), mask=tf.sign(source), training=training)

    if training:
      self.attn([encoder_o, tf.math.count_nonzero(source, 1)], setup_memory=True)
      attn_state = self.decoder_cell.get_initial_state(batch_size=batch_sz, dtype=tf.float32)
      attn_state = attn_state.clone(cell_state=encoder_s)

      decoder_o, _, _ = self.teach_forcing(
        inputs = self.dropout(self.embed(target_in), training=training),
        initial_state = attn_state,
        sequence_length = tf.math.count_nonzero(target_in, 1, dtype=tf.int32))

      logits_or_ids = decoder_o.rnn_output
    else:
      encoder_o_t = tfa.seq2seq.tile_batch(encoder_o, params['beam_width'])
      encoder_len_t = tfa.seq2seq.tile_batch(tf.math.count_nonzero(source, 1), params['beam_width'])
      encoder_s_t = tfa.seq2seq.tile_batch(encoder_s, params['beam_width'])

      self.attn([encoder_o_t, encoder_len_t], setup_memory=True)
      attn_state = self.decoder_cell.get_initial_state(batch_size=batch_sz*params['beam_width'], dtype=tf.float32)
      attn_state = attn_state.clone(cell_state=encoder_s_t)

      decoder_o, _, _ = self.beam_search(
        None,
        start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
        end_token = 2,
        initial_state = attn_state,)

      logits_or_ids = decoder_o.predicted_ids[:, :, 0]

    return logits_or_ids

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
params = {
    'train_path': '../data/train.tsv',
    'test_path': '../data/test.tsv',
    'vocab_src_path': '../vocab/source.txt',
    'vocab_tgt_path': '../vocab/target.txt',
    'model_path': '../model/',
    'dropout_rate': .2,
    'rnn_units': 300,
    'embed_dim': 300,
    'activation': tf.nn.elu,
    'beam_width': 10,
    'init_lr': 1e-4,
    'max_lr': 8e-4,
    'clip_norm': .1,
    'buffer_size': 31279,
    'train_batch_size': 32,
    'eval_batch_size': 128,
    'num_patience': 10,
}

# %%
params['tgt2idx'] = get_vocab(params['vocab_tgt_path'])
params['idx2tgt'] = {idx: tgt for tgt, idx in params['tgt2idx'].items()}

# %%
model = Model(params)
model.build(input_shape=[[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])
# Out:
# [('pretrained_embedding:0', TensorShape([8692, 300])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/bias:0',
#   TensorShape([2, 900])),
#  ('encoder/state_fc/kernel:0', TensorShape([600, 300])),
#  ('encoder/state_fc/bias:0', TensorShape([300])),
#  ('BahdanauAttention/attention_v:0', TensorShape([300])),
#  ('attention_wrapper/BahdanauAttention/kernel:0', TensorShape([300, 300])),
#  ('BahdanauAttention/kernel:0', TensorShape([600, 300])),
#  ('attention_wrapper/attention_layer/kernel:0', TensorShape([900, 300])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/kernel:0',
#   TensorShape([600, 900])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/bias:0',
#   TensorShape([2, 900])),
#  ('tied_dense/bias:0', TensorShape([8692]))]

# %%
decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = params['init_lr'],
  maximal_learning_rate = params['max_lr'],
  step_size = 4*params['buffer_size']//params['train_batch_size'],)
optim = tf.optimizers.Adam(params['init_lr'])
global_step = 0

# %%
best_acc = .0
count = 0

# %%
t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.propagate = False
logger.setLevel(logging.INFO)

# %%
def minimal_test(model, params):
  test_str = ['what', 'times', 'are', 'the', 'nutcracker', 'show', 'playing', 'near', 'me']
  test_arr = tf.convert_to_tensor([[params['tgt2idx'][w] for w in test_str]])
  generated = model(inputs=test_arr, training=False)

  print('-'*12)
  print('minimal test')
  print('utterance:', ' '.join(test_str))
  parsed = ' '.join([params['idx2tgt'][idx] for idx in generated[0].numpy() if (idx != 0 and idx != 2)])
  print('parsed:', parsed)
  print()
  try:
    nltk.tree.Tree.fromstring(parsed.replace('[ ', '(').replace(' ]', ')')).pretty_print()
  except:
    pass
  print('-'*12)

# %%
while True:
  # TRAINING
  is_training = True
  for i, (source, target_in, target_out) in enumerate(dataset(is_training=is_training, params=params)):
    with tf.GradientTape() as tape:
      logits_or_ids = model((source, target_in), training=is_training)
      
      loss = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(target_out, len(params['tgt2idx'])+1),
        logits = logits_or_ids,
        weights = tf.cast(tf.sign(target_out), tf.float32),
        label_smoothing = .2)  

    variables = model.trainable_variables
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, variables))
    
    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
        global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    
    global_step += 1

  # EVALUATION
  is_training = False
  minimal_test(model, params)
  m = tf.keras.metrics.Mean()
  
  parse_fn = lambda x: [e for e in x if (e != 0 and e != 2)]

  for i, (source, target_in, target_out) in enumerate(dataset(is_training=is_training, params=params)):
    generated = model(inputs=source, training=is_training)
    for pred, tgt in zip(generated.numpy(), target_out.numpy()):
      matched = np.array_equal(parse_fn(pred), parse_fn(tgt))
      m.update_state(int(matched))
  
  acc = m.result().numpy()
  logger.info("Evaluation: Testing EM: {:.3f}".format(acc))

  if acc > best_acc:
    best_acc = acc
    count = 0
    model.save_weights('../model/gru_seq2seq_clr')
  else:
    count += 1
  logger.info("Best EM: {:.3f}".format(best_acc))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# Reading ../data/train.tsv
# INFO:tensorflow:Step 0 | Loss: 10.0613 | Spent: 25.4 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 6.1059 | Spent: 24.3 secs | LR: 0.000109
# INFO:tensorflow:Step 100 | Loss: 5.1683 | Spent: 24.2 secs | LR: 0.000118
# INFO:tensorflow:Step 150 | Loss: 5.0629 | Spent: 24.8 secs | LR: 0.000127
# INFO:tensorflow:Step 200 | Loss: 4.5041 | Spent: 25.0 secs | LR: 0.000136
# INFO:tensorflow:Step 250 | Loss: 4.4831 | Spent: 23.6 secs | LR: 0.000145
# INFO:tensorflow:Step 300 | Loss: 4.2703 | Spent: 24.2 secs | LR: 0.000154
# INFO:tensorflow:Step 350 | Loss: 4.2365 | Spent: 23.5 secs | LR: 0.000163
# INFO:tensorflow:Step 400 | Loss: 3.8806 | Spent: 23.2 secs | LR: 0.000172
# INFO:tensorflow:Step 450 | Loss: 3.7415 | Spent: 23.7 secs | LR: 0.000181
# INFO:tensorflow:Step 500 | Loss: 3.6758 | Spent: 23.6 secs | LR: 0.000190
# INFO:tensorflow:Step 550 | Loss: 3.5014 | Spent: 23.9 secs | LR: 0.000198
# INFO:tensorflow:Step 600 | Loss: 3.4392 | Spent: 24.5 secs | LR: 0.000207
# INFO:tensorflow:Step 650 | Loss: 3.4188 | Spent: 23.0 secs | LR: 0.000216
# INFO:tensorflow:Step 700 | Loss: 3.5338 | Spent: 22.4 secs | LR: 0.000225
# INFO:tensorflow:Step 750 | Loss: 3.2620 | Spent: 22.8 secs | LR: 0.000234
# INFO:tensorflow:Step 800 | Loss: 3.4408 | Spent: 22.4 secs | LR: 0.000243
# INFO:tensorflow:Step 850 | Loss: 3.1395 | Spent: 24.3 secs | LR: 0.000252
# INFO:tensorflow:Step 900 | Loss: 3.1629 | Spent: 23.2 secs | LR: 0.000261
# INFO:tensorflow:Step 950 | Loss: 3.0494 | Spent: 23.3 secs | LR: 0.000270
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_info_traffic what times are the [ sl:location [ in:get_location [ sl:category_location the nutcracker shows ] ] [ sl:date_time playing ] [ sl:date_time near ] [ sl:date_time me ] ]
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.042
# INFO:tensorflow:Best EM: 0.042
# Reading ../data/train.tsv
# INFO:tensorflow:Step 1000 | Loss: 2.9760 | Spent: 182.7 secs | LR: 0.000279
# INFO:tensorflow:Step 1050 | Loss: 3.0049 | Spent: 22.8 secs | LR: 0.000288
# INFO:tensorflow:Step 1100 | Loss: 2.9369 | Spent: 21.7 secs | LR: 0.000297
# INFO:tensorflow:Step 1150 | Loss: 2.8868 | Spent: 23.1 secs | LR: 0.000306
# INFO:tensorflow:Step 1200 | Loss: 2.9814 | Spent: 22.9 secs | LR: 0.000315
# INFO:tensorflow:Step 1250 | Loss: 2.8343 | Spent: 22.6 secs | LR: 0.000324
# INFO:tensorflow:Step 1300 | Loss: 2.8790 | Spent: 22.2 secs | LR: 0.000333
# INFO:tensorflow:Step 1350 | Loss: 2.8476 | Spent: 22.5 secs | LR: 0.000342
# INFO:tensorflow:Step 1400 | Loss: 2.7654 | Spent: 23.2 secs | LR: 0.000351
# INFO:tensorflow:Step 1450 | Loss: 2.8507 | Spent: 22.9 secs | LR: 0.000360
# INFO:tensorflow:Step 1500 | Loss: 2.7835 | Spent: 23.2 secs | LR: 0.000369
# INFO:tensorflow:Step 1550 | Loss: 2.7807 | Spent: 21.8 secs | LR: 0.000378
# INFO:tensorflow:Step 1600 | Loss: 2.7767 | Spent: 23.0 secs | LR: 0.000387
# INFO:tensorflow:Step 1650 | Loss: 2.7165 | Spent: 23.1 secs | LR: 0.000395
# INFO:tensorflow:Step 1700 | Loss: 2.6453 | Spent: 23.3 secs | LR: 0.000404
# INFO:tensorflow:Step 1750 | Loss: 2.7951 | Spent: 22.6 secs | LR: 0.000413
# INFO:tensorflow:Step 1800 | Loss: 2.7392 | Spent: 23.1 secs | LR: 0.000422
# INFO:tensorflow:Step 1850 | Loss: 2.6726 | Spent: 23.3 secs | LR: 0.000431
# INFO:tensorflow:Step 1900 | Loss: 2.6651 | Spent: 21.9 secs | LR: 0.000440
# INFO:tensorflow:Step 1950 | Loss: 2.7880 | Spent: 22.8 secs | LR: 0.000449
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show playing ] [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                      in:get_event
#   ________________________|______________________________________________
#  |     |    |             |                                         sl:location
#  |     |    |             |                                              |
#  |     |    |             |                                       in:get_location
#  |     |    |             |                              ________________|_______________
#  |     |    |      sl:category_even              sl:search_radius                 sl:location_user
#  |     |    |             t                             |                                |
#  |     |    |    _________|_________________            |                                |
# what times are the    nutcracker    show playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.488
# INFO:tensorflow:Best EM: 0.488
# Reading ../data/train.tsv
# INFO:tensorflow:Step 2000 | Loss: 2.7479 | Spent: 165.9 secs | LR: 0.000458
# INFO:tensorflow:Step 2050 | Loss: 2.7254 | Spent: 22.6 secs | LR: 0.000467
# INFO:tensorflow:Step 2100 | Loss: 2.6201 | Spent: 23.2 secs | LR: 0.000476
# INFO:tensorflow:Step 2150 | Loss: 2.6099 | Spent: 22.5 secs | LR: 0.000485
# INFO:tensorflow:Step 2200 | Loss: 2.5808 | Spent: 22.5 secs | LR: 0.000494
# INFO:tensorflow:Step 2250 | Loss: 2.6369 | Spent: 22.9 secs | LR: 0.000503
# INFO:tensorflow:Step 2300 | Loss: 2.5386 | Spent: 22.2 secs | LR: 0.000512
# INFO:tensorflow:Step 2350 | Loss: 2.5416 | Spent: 22.1 secs | LR: 0.000521
# INFO:tensorflow:Step 2400 | Loss: 2.5435 | Spent: 23.1 secs | LR: 0.000530
# INFO:tensorflow:Step 2450 | Loss: 2.5766 | Spent: 22.2 secs | LR: 0.000539
# INFO:tensorflow:Step 2500 | Loss: 2.5538 | Spent: 22.1 secs | LR: 0.000548
# INFO:tensorflow:Step 2550 | Loss: 2.5096 | Spent: 21.8 secs | LR: 0.000557
# INFO:tensorflow:Step 2600 | Loss: 2.5607 | Spent: 22.9 secs | LR: 0.000566
# INFO:tensorflow:Step 2650 | Loss: 2.5117 | Spent: 22.1 secs | LR: 0.000575
# INFO:tensorflow:Step 2700 | Loss: 2.5098 | Spent: 23.1 secs | LR: 0.000583
# INFO:tensorflow:Step 2750 | Loss: 2.5488 | Spent: 23.0 secs | LR: 0.000592
# INFO:tensorflow:Step 2800 | Loss: 2.6060 | Spent: 22.3 secs | LR: 0.000601
# INFO:tensorflow:Step 2850 | Loss: 2.4824 | Spent: 21.6 secs | LR: 0.000610
# INFO:tensorflow:Step 2900 | Loss: 2.5411 | Spent: 22.6 secs | LR: 0.000619
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:unsupported what times are the nutcracker show playing near me ]
#
#                    in:unsupported
#   _______________________|___________________________
# what times are the   nutcracker   show playing near  me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0
# INFO:tensorflow:Step 7200 | Loss: 2.3794 | Spent: 22.9 secs | LR: 0.000211
# INFO:tensorflow:Step 7250 | Loss: 2.3878 | Spent: 22.4 secs | LR: 0.000202
# INFO:tensorflow:Step 7300 | Loss: 2.3756 | Spent: 22.3 secs | LR: 0.000193
# INFO:tensorflow:Step 7350 | Loss: 2.3694 | Spent: 22.3 secs | LR: 0.000184
# INFO:tensorflow:Step 7400 | Loss: 2.3743 | Spent: 23.1 secs | LR: 0.000175
# INFO:tensorflow:Step 7450 | Loss: 2.3689 | Spent: 22.9 secs | LR: 0.000166
# INFO:tensorflow:Step 7500 | Loss: 2.3684 | Spent: 22.7 secs | LR: 0.000157
# INFO:tensorflow:Step 7550 | Loss: 2.3769 | Spent: 22.0 secs | LR: 0.000148
# INFO:tensorflow:Step 7600 | Loss: 2.3689 | Spent: 22.4 secs | LR: 0.000139
# INFO:tensorflow:Step 7650 | Loss: 2.3812 | Spent: 22.6 secs | LR: 0.000130
# INFO:tensorflow:Step 7700 | Loss: 2.4268 | Spent: 22.2 secs | LR: 0.000121
# INFO:tensorflow:Step 7750 | Loss: 2.3742 | Spent: 22.3 secs | LR: 0.000112
# INFO:tensorflow:Step 7800 | Loss: 2.3772 | Spent: 21.9 secs | LR: 0.000103
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show playing ] [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                      in:get_event
#   ________________________|______________________________________________
#  |     |    |             |                                         sl:location
#  |     |    |             |                                              |
#  |     |    |             |                                       in:get_location
#  |     |    |             |                              ________________|_______________
#  |     |    |      sl:category_even              sl:search_radius                 sl:location_user
#  |     |    |             t                             |                                |
#  |     |    |    _________|_________________            |                                |
# what times are the    nutcracker    show playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.712
# INFO:tensorflow:Best EM: 0.713
# Reading ../data/train.tsv
# INFO:tensorflow:Step 7850 | Loss: 2.3600 | Spent: 153.5 secs | LR: 0.000103
# INFO:tensorflow:Step 7900 | Loss: 2.3642 | Spent: 22.5 secs | LR: 0.000107
# INFO:tensorflow:Step 7950 | Loss: 2.3739 | Spent: 22.7 secs | LR: 0.000112
# INFO:tensorflow:Step 8000 | Loss: 2.3733 | Spent: 22.0 secs | LR: 0.000116
# INFO:tensorflow:Step 8050 | Loss: 2.3676 | Spent: 22.2 secs | LR: 0.000121
# INFO:tensorflow:Step 8100 | Loss: 2.3736 | Spent: 22.9 secs | LR: 0.000125
# INFO:tensorflow:Step 8150 | Loss: 2.3586 | Spent: 21.5 secs | LR: 0.000130
# INFO:tensorflow:Step 8200 | Loss: 2.3788 | Spent: 21.0 secs | LR: 0.000134
# INFO:tensorflow:Step 8250 | Loss: 2.3659 | Spent: 22.4 secs | LR: 0.000139
# INFO:tensorflow:Step 8300 | Loss: 2.3693 | Spent: 22.1 secs | LR: 0.000143
# INFO:tensorflow:Step 8350 | Loss: 2.3736 | Spent: 23.0 secs | LR: 0.000148
# INFO:tensorflow:Step 8400 | Loss: 2.3722 | Spent: 22.6 secs | LR: 0.000152
# INFO:tensorflow:Step 8450 | Loss: 2.3666 | Spent: 22.1 secs | LR: 0.000157
# INFO:tensorflow:Step 8500 | Loss: 2.3608 | Spent: 23.6 secs | LR: 0.000161
# INFO:tensorflow:Step 8550 | Loss: 2.3605 | Spent: 22.3 secs | LR: 0.000166
# INFO:tensorflow:Step 8600 | Loss: 2.3687 | Spent: 21.5 secs | LR: 0.000170
# INFO:tensorflow:Step 8650 | Loss: 2.3687 | Spent: 23.1 secs | LR: 0.000174
# INFO:tensorflow:Step 8700 | Loss: 2.3656 | Spent: 22.9 secs | LR: 0.000179
# INFO:tensorflow:Step 8750 | Loss: 2.3743 | Spent: 23.4 secs | LR: 0.000183
# INFO:tensorflow:Step 8800 | Loss: 2.3723 | Spent: 22.9 secs | LR: 0.000188
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.723
# INFO:tensorflow:Best EM: 0.723
# Reading ../data/train.tsv
# INFO:tensorflow:Step 8850 | Loss: 2.3717 | Spent: 156.9 secs | LR: 0.000192
# INFO:tensorflow:Step 8900 | Loss: 2.3797 | Spent: 23.6 secs | LR: 0.000197
# INFO:tensorflow:Step 8950 | Loss: 2.3690 | Spent: 23.0 secs | LR: 0.000201
# INFO:tensorflow:Step 9000 | Loss: 2.3650 | Spent: 21.5 secs | LR: 0.000206
# INFO:tensorflow:Step 9050 | Loss: 2.3694 | Spent: 23.3 secs | LR: 0.000210
# INFO:tensorflow:Step 9100 | Loss: 2.3960 | Spent: 23.0 secs | LR: 0.000215
# INFO:tensorflow:Step 9150 | Loss: 2.3655 | Spent: 22.3 secs | LR: 0.000219
# INFO:tensorflow:Step 9200 | Loss: 2.3703 | Spent: 22.2 secs | LR: 0.000224
# INFO:tensorflow:Step 9250 | Loss: 2.3713 | Spent: 23.3 secs | LR: 0.000228
# INFO:tensorflow:Step 9300 | Loss: 2.3615 | Spent: 22.0 secs | LR: 0.000233
# INFO:tensorflow:Step 9350 | Loss: 2.3706 | Spent: 23.3 secs | LR: 0.000237
# INFO:tensorflow:Step 9400 | Loss: 2.3736 | Spent: 22.8 secs | LR: 0.000242
# INFO:tensorflow:Step 9450 | Loss: 2.3618 | Spent: 21.5 secs | LR: 0.000246
# INFO:tensorflow:Step 9500 | Loss: 2.3806 | Spent: 23.0 secs | LR: 0.000251
# INFO:tensorflow:Step 9550 | Loss: 2.3764 | Spent: 22.5 secs | LR: 0.000255
# INFO:tensorflow:Step 9600 | Loss: 2.3872 | Spent: 23.9 secs | LR: 0.000260
# INFO:tensorflow:Step 9650 | Loss: 2.3771 | Spent: 22.3 secs | LR: 0.000264
# INFO:tensorflow:Step 9700 | Loss: 2.3616 | Spent: 21.8 secs | LR: 0.000269
# INFO:tensorflow:Step 9750 | Loss: 2.3665 | Spent: 22.9 secs | LR: 0.000273
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show playing ] [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                      in:get_event
#   ________________________|______________________________________________
#  |     |    |             |                                         sl:location
#  |     |    |             |                                              |
#  |     |    |             |                                       in:get_location
#  |     |    |             |                              ________________|_______________
#  |     |    |      sl:category_even              sl:search_radius                 sl:location_user
#  |     |    |             t                             |                                |
#  |     |    |    _________|_________________            |                                |
# what times are the    nutcracker    show playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.719
# INFO:tensorflow:Best EM: 0.723
# Reading ../data/train.tsv
# INFO:tensorflow:Step 9800 | Loss: 2.3749 | Spent: 150.6 secs | LR: 0.000277
# INFO:tensorflow:Step 9850 | Loss: 2.3589 | Spent: 23.4 secs | LR: 0.000282
# INFO:tensorflow:Step 9900 | Loss: 2.3623 | Spent: 23.4 secs | LR: 0.000286
# INFO:tensorflow:Step 9950 | Loss: 2.3635 | Spent: 23.5 secs | LR: 0.000291
# INFO:tensorflow:Step 10000 | Loss: 2.3600 | Spent: 23.8 secs | LR: 0.000295
# INFO:tensorflow:Step 10050 | Loss: 2.3821 | Spent: 23.0 secs | LR: 0.000300
# INFO:tensorflow:Step 10100 | Loss: 2.3820 | Spent: 22.8 secs | LR: 0.000304
# INFO:tensorflow:Step 10150 | Loss: 2.3551 | Spent: 23.1 secs | LR: 0.000309
# INFO:tensorflow:Step 10200 | Loss: 2.3638 | Spent: 23.1 secs | LR: 0.000313
# INFO:tensorflow:Step 10250 | Loss: 2.3822 | Spent: 22.0 secs | LR: 0.000318
# INFO:tensorflow:Step 10300 | Loss: 2.3634 | Spent: 22.8 secs | LR: 0.000322
# INFO:tensorflow:Step 10350 | Loss: 2.3750 | Spent: 22.9 secs | LR: 0.000327
# INFO:tensorflow:Step 10400 | Loss: 2.3758 | Spent: 22.4 secs | LR: 0.000331
# INFO:tensorflow:Step 10450 | Loss: 2.3756 | Spent: 23.0 secs | LR: 0.000336
# INFO:tensorflow:Step 10500 | Loss: 2.3790 | Spent: 22.1 secs | LR: 0.000340
# INFO:tensorflow:Step 10550 | Loss: 2.3780 | Spent: 22.9 secs | LR: 0.000345
# INFO:tensorflow:Step 10600 | Loss: 2.3673 | Spent: 23.4 secs | LR: 0.000349
# INFO:tensorflow:Step 10650 | Loss: 2.3657 | Spent: 23.4 secs | LR: 0.000354
# INFO:tensorflow:Step 10700 | Loss: 2.3685 | Spent: 22.6 secs | LR: 0.000358
# INFO:tensorflow:Step 10750 | Loss: 2.3724 | Spent: 23.1 secs | LR: 0.000363
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show playing ] [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                      in:get_event
#   ________________________|______________________________________________
#  |     |    |             |                                         sl:location
#  |     |    |             |                                              |
#  |     |    |             |                                       in:get_location
#  |     |    |             |                              ________________|_______________
#  |     |    |      sl:category_even              sl:search_radius                 sl:location_user
#  |     |    |             t                             |                                |
#  |     |    |    _________|_________________            |                                |
# what times are the    nutcracker    show playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.729
# INFO:tensorflow:Best EM: 0.729
# Reading ../data/train.tsv
# INFO:tensorflow:Step 10800 | Loss: 2.3863 | Spent: 153.7 secs | LR: 0.000367
# INFO:tensorflow:Step 10850 | Loss: 2.3577 | Spent: 22.7 secs | LR: 0.000371
# INFO:tensorflow:Step 10900 | Loss: 2.3744 | Spent: 22.5 secs | LR: 0.000376
# INFO:tensorflow:Step 10950 | Loss: 2.3800 | Spent: 23.0 secs | LR: 0.000380
# INFO:tensorflow:Step 13900 | Loss: 2.3516 | Spent: 23.6 secs | LR: 0.000255
# INFO:tensorflow:Step 13950 | Loss: 2.3604 | Spent: 23.5 secs | LR: 0.000251
# INFO:tensorflow:Step 14000 | Loss: 2.3682 | Spent: 23.7 secs | LR: 0.000246
# INFO:tensorflow:Step 14050 | Loss: 2.3532 | Spent: 23.1 secs | LR: 0.000242
# INFO:tensorflow:Step 14100 | Loss: 2.3513 | Spent: 22.4 secs | LR: 0.000238
# INFO:tensorflow:Step 14150 | Loss: 2.3558 | Spent: 23.3 secs | LR: 0.000233
# INFO:tensorflow:Step 14200 | Loss: 2.3490 | Spent: 23.4 secs | LR: 0.000229
# INFO:tensorflow:Step 14250 | Loss: 2.3590 | Spent: 23.9 secs | LR: 0.000224
# INFO:tensorflow:Step 14300 | Loss: 2.3443 | Spent: 23.9 secs | LR: 0.000220
# INFO:tensorflow:Step 14350 | Loss: 2.3551 | Spent: 24.0 secs | LR: 0.000215
# INFO:tensorflow:Step 14400 | Loss: 2.3600 | Spent: 23.2 secs | LR: 0.000211
# INFO:tensorflow:Step 14450 | Loss: 2.3611 | Spent: 23.5 secs | LR: 0.000206
# INFO:tensorflow:Step 14500 | Loss: 2.3488 | Spent: 23.3 secs | LR: 0.000202
# INFO:tensorflow:Step 14550 | Loss: 2.3512 | Spent: 23.3 secs | LR: 0.000197
# INFO:tensorflow:Step 14600 | Loss: 2.3645 | Spent: 22.7 secs | LR: 0.000193
# INFO:tensorflow:Step 14650 | Loss: 2.3660 | Spent: 23.1 secs | LR: 0.000188
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.734
# INFO:tensorflow:Best EM: 0.735
# Reading ../data/train.tsv
# INFO:tensorflow:Step 14700 | Loss: 2.3582 | Spent: 149.6 secs | LR: 0.000184
# INFO:tensorflow:Step 14750 | Loss: 2.3504 | Spent: 22.4 secs | LR: 0.000179
# INFO:tensorflow:Step 14800 | Loss: 2.3456 | Spent: 23.1 secs | LR: 0.000175
# INFO:tensorflow:Step 14850 | Loss: 2.3459 | Spent: 23.1 secs | LR: 0.000170
# INFO:tensorflow:Step 14900 | Loss: 2.3696 | Spent: 23.7 secs | LR: 0.000166
# INFO:tensorflow:Step 14950 | Loss: 2.3619 | Spent: 22.4 secs | LR: 0.000161
# INFO:tensorflow:Step 15000 | Loss: 2.3474 | Spent: 22.5 secs | LR: 0.000157
# INFO:tensorflow:Step 15050 | Loss: 2.3586 | Spent: 23.7 secs | LR: 0.000152
# INFO:tensorflow:Step 15100 | Loss: 2.3582 | Spent: 23.2 secs | LR: 0.000148
# INFO:tensorflow:Step 15150 | Loss: 2.3532 | Spent: 23.8 secs | LR: 0.000144
# INFO:tensorflow:Step 15200 | Loss: 2.3580 | Spent: 22.2 secs | LR: 0.000139
# INFO:tensorflow:Step 15250 | Loss: 2.3569 | Spent: 23.9 secs | LR: 0.000135
# INFO:tensorflow:Step 15300 | Loss: 2.3425 | Spent: 23.9 secs | LR: 0.000130
# INFO:tensorflow:Step 15350 | Loss: 2.3457 | Spent: 23.5 secs | LR: 0.000126
# INFO:tensorflow:Step 15400 | Loss: 2.3595 | Spent: 24.5 secs | LR: 0.000121
# INFO:tensorflow:Step 15450 | Loss: 2.3746 | Spent: 22.8 secs | LR: 0.000117
# INFO:tensorflow:Step 15500 | Loss: 2.3596 | Spent: 23.1 secs | LR: 0.000112
# INFO:tensorflow:Step 15550 | Loss: 2.3557 | Spent: 23.2 secs | LR: 0.000108
# INFO:tensorflow:Step 15600 | Loss: 2.3489 | Spent: 23.8 secs | LR: 0.000103
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.738
# INFO:tensorflow:Best EM: 0.738
# Reading ../data/train.tsv
# INFO:tensorflow:Step 15650 | Loss: 2.3549 | Spent: 151.2 secs | LR: 0.000101
# INFO:tensorflow:Step 15700 | Loss: 2.3496 | Spent: 23.4 secs | LR: 0.000103
# INFO:tensorflow:Step 15750 | Loss: 2.3511 | Spent: 23.9 secs | LR: 0.000105
# INFO:tensorflow:Step 15800 | Loss: 2.3489 | Spent: 24.0 secs | LR: 0.000107
# INFO:tensorflow:Step 15850 | Loss: 2.3541 | Spent: 23.2 secs | LR: 0.000110
# INFO:tensorflow:Step 15900 | Loss: 2.3569 | Spent: 23.3 secs | LR: 0.000112
# INFO:tensorflow:Step 15950 | Loss: 2.3539 | Spent: 22.5 secs | LR: 0.000114
# INFO:tensorflow:Step 16000 | Loss: 2.3622 | Spent: 23.9 secs | LR: 0.000116
# INFO:tensorflow:Step 16050 | Loss: 2.3580 | Spent: 22.8 secs | LR: 0.000119
# INFO:tensorflow:Step 16100 | Loss: 2.3589 | Spent: 23.1 secs | LR: 0.000121
# INFO:tensorflow:Step 16150 | Loss: 2.3461 | Spent: 24.8 secs | LR: 0.000123
# INFO:tensorflow:Step 16200 | Loss: 2.3503 | Spent: 23.2 secs | LR: 0.000125
# INFO:tensorflow:Step 16250 | Loss: 2.3487 | Spent: 23.2 secs | LR: 0.000127
# INFO:tensorflow:Step 16300 | Loss: 2.3526 | Spent: 22.8 secs | LR: 0.000130
# INFO:tensorflow:Step 16350 | Loss: 2.3507 | Spent: 24.4 secs | LR: 0.000132
# INFO:tensorflow:Step 16400 | Loss: 2.3407 | Spent: 23.9 secs | LR: 0.000134
# INFO:tensorflow:Step 16450 | Loss: 2.3577 | Spent: 24.8 secs | LR: 0.000136
# INFO:tensorflow:Step 16500 | Loss: 2.3734 | Spent: 24.0 secs | LR: 0.000139
# INFO:tensorflow:Step 16550 | Loss: 2.3444 | Spent: 23.5 secs | LR: 0.000141
# INFO:tensorflow:Step 16600 | Loss: 2.3658 | Spent: 23.6 secs | LR: 0.000143
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.734
# INFO:tensorflow:Best EM: 0.741
# Reading ../data/train.tsv
# INFO:tensorflow:Step 32300 | Loss: 2.3391 | Spent: 151.2 secs | LR: 0.000112
# INFO:tensorflow:Step 32350 | Loss: 2.3409 | Spent: 23.9 secs | LR: 0.000112
# INFO:tensorflow:Step 32400 | Loss: 2.3386 | Spent: 26.1 secs | LR: 0.000113
# INFO:tensorflow:Step 32450 | Loss: 2.3384 | Spent: 24.9 secs | LR: 0.000113
# INFO:tensorflow:Step 32500 | Loss: 2.3353 | Spent: 24.8 secs | LR: 0.000114
# INFO:tensorflow:Step 32550 | Loss: 2.3397 | Spent: 24.1 secs | LR: 0.000114
# INFO:tensorflow:Step 32600 | Loss: 2.3397 | Spent: 24.8 secs | LR: 0.000115
# INFO:tensorflow:Step 32650 | Loss: 2.3393 | Spent: 25.3 secs | LR: 0.000115
# INFO:tensorflow:Step 32700 | Loss: 2.3357 | Spent: 24.2 secs | LR: 0.000116
# INFO:tensorflow:Step 32750 | Loss: 2.3417 | Spent: 24.0 secs | LR: 0.000117
# INFO:tensorflow:Step 32800 | Loss: 2.3369 | Spent: 24.4 secs | LR: 0.000117
# INFO:tensorflow:Step 32850 | Loss: 2.3351 | Spent: 24.6 secs | LR: 0.000118
# INFO:tensorflow:Step 32900 | Loss: 2.3379 | Spent: 24.1 secs | LR: 0.000118
# INFO:tensorflow:Step 32950 | Loss: 2.3323 | Spent: 23.9 secs | LR: 0.000119
# INFO:tensorflow:Step 33000 | Loss: 2.3464 | Spent: 23.8 secs | LR: 0.000119
# INFO:tensorflow:Step 33050 | Loss: 2.3401 | Spent: 23.8 secs | LR: 0.000120
# INFO:tensorflow:Step 33100 | Loss: 2.3364 | Spent: 24.6 secs | LR: 0.000120
# INFO:tensorflow:Step 33150 | Loss: 2.3382 | Spent: 24.6 secs | LR: 0.000121
# INFO:tensorflow:Step 33200 | Loss: 2.3402 | Spent: 25.7 secs | LR: 0.000122
# INFO:tensorflow:Step 33250 | Loss: 2.3343 | Spent: 24.9 secs | LR: 0.000122
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show playing ] [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                      in:get_event
#   ________________________|______________________________________________
#  |     |    |             |                                         sl:location
#  |     |    |             |                                              |
#  |     |    |             |                                       in:get_location
#  |     |    |             |                              ________________|_______________
#  |     |    |      sl:category_even              sl:search_radius                 sl:location_user
#  |     |    |             t                             |                                |
#  |     |    |    _________|_________________            |                                |
# what times are the    nutcracker    show playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.739
# INFO:tensorflow:Best EM: 0.741
# Reading ../data/train.tsv
# INFO:tensorflow:Step 33300 | Loss: 2.3371 | Spent: 151.7 secs | LR: 0.000123
# INFO:tensorflow:Step 33350 | Loss: 2.3458 | Spent: 24.9 secs | LR: 0.000123
# INFO:tensorflow:Step 33400 | Loss: 2.3402 | Spent: 25.2 secs | LR: 0.000124
# INFO:tensorflow:Step 33450 | Loss: 2.3369 | Spent: 25.4 secs | LR: 0.000124
# INFO:tensorflow:Step 33500 | Loss: 2.3385 | Spent: 24.7 secs | LR: 0.000125
# INFO:tensorflow:Step 33550 | Loss: 2.3371 | Spent: 24.4 secs | LR: 0.000125
# INFO:tensorflow:Step 33600 | Loss: 2.3386 | Spent: 25.4 secs | LR: 0.000126
# INFO:tensorflow:Step 33650 | Loss: 2.3379 | Spent: 25.2 secs | LR: 0.000127
# INFO:tensorflow:Step 33700 | Loss: 2.3374 | Spent: 24.7 secs | LR: 0.000127
# INFO:tensorflow:Step 33750 | Loss: 2.3409 | Spent: 23.8 secs | LR: 0.000128
# INFO:tensorflow:Step 33800 | Loss: 2.3356 | Spent: 25.4 secs | LR: 0.000128
# INFO:tensorflow:Step 33850 | Loss: 2.3338 | Spent: 24.5 secs | LR: 0.000129
# INFO:tensorflow:Step 33900 | Loss: 2.3378 | Spent: 24.8 secs | LR: 0.000129
# INFO:tensorflow:Step 33950 | Loss: 2.3378 | Spent: 24.3 secs | LR: 0.000130
# INFO:tensorflow:Step 34000 | Loss: 2.3423 | Spent: 25.7 secs | LR: 0.000131
# INFO:tensorflow:Step 34050 | Loss: 2.3406 | Spent: 25.7 secs | LR: 0.000131
# INFO:tensorflow:Step 34100 | Loss: 2.3401 | Spent: 23.7 secs | LR: 0.000132
# INFO:tensorflow:Step 34150 | Loss: 2.3385 | Spent: 24.5 secs | LR: 0.000132
# INFO:tensorflow:Step 34200 | Loss: 2.3463 | Spent: 25.7 secs | LR: 0.000133
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.736
# INFO:tensorflow:Best EM: 0.741
# Reading ../data/train.tsv
# INFO:tensorflow:Step 34250 | Loss: 2.3335 | Spent: 151.7 secs | LR: 0.000133
# INFO:tensorflow:Step 34300 | Loss: 2.3363 | Spent: 25.1 secs | LR: 0.000134
# INFO:tensorflow:Step 34350 | Loss: 2.3413 | Spent: 24.3 secs | LR: 0.000134
# INFO:tensorflow:Step 34400 | Loss: 2.3483 | Spent: 24.6 secs | LR: 0.000135
# INFO:tensorflow:Step 34450 | Loss: 2.3379 | Spent: 24.5 secs | LR: 0.000136
# INFO:tensorflow:Step 34500 | Loss: 2.3368 | Spent: 24.8 secs | LR: 0.000136
# INFO:tensorflow:Step 34550 | Loss: 2.3453 | Spent: 24.7 secs | LR: 0.000137
# INFO:tensorflow:Step 34600 | Loss: 2.3364 | Spent: 26.2 secs | LR: 0.000137
# INFO:tensorflow:Step 34650 | Loss: 2.3367 | Spent: 25.2 secs | LR: 0.000138
# INFO:tensorflow:Step 34700 | Loss: 2.3392 | Spent: 26.3 secs | LR: 0.000138
# INFO:tensorflow:Step 34750 | Loss: 2.3361 | Spent: 24.8 secs | LR: 0.000139
# INFO:tensorflow:Step 34800 | Loss: 2.3377 | Spent: 24.6 secs | LR: 0.000139
# INFO:tensorflow:Step 34850 | Loss: 2.3417 | Spent: 24.6 secs | LR: 0.000140
# INFO:tensorflow:Step 34900 | Loss: 2.3373 | Spent: 25.0 secs | LR: 0.000141
# INFO:tensorflow:Step 34950 | Loss: 2.3337 | Spent: 24.6 secs | LR: 0.000141
# INFO:tensorflow:Step 35000 | Loss: 2.3385 | Spent: 25.0 secs | LR: 0.000142
# INFO:tensorflow:Step 35050 | Loss: 2.3353 | Spent: 24.3 secs | LR: 0.000142
# INFO:tensorflow:Step 35100 | Loss: 2.3379 | Spent: 24.4 secs | LR: 0.000143
# INFO:tensorflow:Step 35150 | Loss: 2.3412 | Spent: 25.2 secs | LR: 0.000143
# INFO:tensorflow:Step 35200 | Loss: 2.3405 | Spent: 24.4 secs | LR: 0.000144
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.735
# INFO:tensorflow:Best EM: 0.741
# Reading ../data/train.tsv
# INFO:tensorflow:Step 35250 | Loss: 2.3407 | Spent: 152.3 secs | LR: 0.000143
# INFO:tensorflow:Step 35300 | Loss: 2.3411 | Spent: 24.4 secs | LR: 0.000142
# INFO:tensorflow:Step 35350 | Loss: 2.3364 | Spent: 24.7 secs | LR: 0.000142
# INFO:tensorflow:Step 35400 | Loss: 2.3370 | Spent: 26.3 secs | LR: 0.000141
# INFO:tensorflow:Step 35450 | Loss: 2.3406 | Spent: 24.8 secs | LR: 0.000141
# INFO:tensorflow:Step 35500 | Loss: 2.3411 | Spent: 25.0 secs | LR: 0.000140
# INFO:tensorflow:Step 35550 | Loss: 2.3352 | Spent: 23.9 secs | LR: 0.000140
# INFO:tensorflow:Step 35600 | Loss: 2.3363 | Spent: 25.5 secs | LR: 0.000139
# INFO:tensorflow:Step 35650 | Loss: 2.3403 | Spent: 24.8 secs | LR: 0.000139
# INFO:tensorflow:Step 35700 | Loss: 2.3387 | Spent: 25.2 secs | LR: 0.000138
# INFO:tensorflow:Step 35750 | Loss: 2.3394 | Spent: 25.2 secs | LR: 0.000137
# INFO:tensorflow:Step 35800 | Loss: 2.3338 | Spent: 24.6 secs | LR: 0.000137
# INFO:tensorflow:Step 35850 | Loss: 2.3383 | Spent: 25.1 secs | LR: 0.000136
# INFO:tensorflow:Step 35900 | Loss: 2.3375 | Spent: 24.6 secs | LR: 0.000136
# INFO:tensorflow:Step 35950 | Loss: 2.3403 | Spent: 24.3 secs | LR: 0.000135
# INFO:tensorflow:Step 36000 | Loss: 2.3436 | Spent: 24.9 secs | LR: 0.000135
# INFO:tensorflow:Step 36050 | Loss: 2.3399 | Spent: 25.0 secs | LR: 0.000134
# INFO:tensorflow:Step 36100 | Loss: 2.3396 | Spent: 24.9 secs | LR: 0.000133
# INFO:tensorflow:Step 36150 | Loss: 2.3360 | Spent: 24.1 secs | LR: 0.000133
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.738
# INFO:tensorflow:Best EM: 0.741
# Reading ../data/train.tsv
# INFO:tensorflow:Step 36200 | Loss: 2.3364 | Spent: 152.4 secs | LR: 0.000132
# INFO:tensorflow:Step 36250 | Loss: 2.3371 | Spent: 25.3 secs | LR: 0.000132
# INFO:tensorflow:Step 36300 | Loss: 2.3357 | Spent: 24.7 secs | LR: 0.000131
# INFO:tensorflow:Step 36350 | Loss: 2.3391 | Spent: 24.4 secs | LR: 0.000131
