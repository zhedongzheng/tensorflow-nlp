# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/text_matching/chinese/main')

# %%
# %tensorflow_version 2.x

# %%
import csv
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
import math

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0-rc2
# WARNING:tensorflow:From <ipython-input-3-21cf261602fd>:10: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(f_path):
  k2v = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      k2v[line] = i
  return k2v

# %%
# stream data from text files
def data_generator(f_path, char2idx):
  with open(f_path) as f:
    print('Reading', f_path)
    for i, line in enumerate(csv.reader(f, delimiter=',')):
      if i == 0:
        continue
      text1, text2, label = line
      text1 = [char2idx.get(c, len(char2idx)) for c in list(text1)]
      text2 = [char2idx.get(c, len(char2idx)) for c in list(text2)]
      yield ((text1, text2), int(label))


def dataset(is_training, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.int32, tf.int32), tf.int32)
  _pads = ((0, 0), -1)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
class RE2(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    
    self.pretrained_embedding = tf.Variable(np.load(params['embedding_path']), name='pretrained_embedding', dtype=tf.float32)
    self.embed_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.birnn = [tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['hidden_size'], return_sequences=True), name='birnn_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.enc_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.align_t = self.add_weight(name='temperature',
                                   shape=(),
                                   trainable=True,
                                   initializer=tf.initializers.constant(math.sqrt(1/params['hidden_size'])))
    self.align_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.align_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.align_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
      
    self.fusion_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc3 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc3_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc4 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc4_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.out_drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_fc = tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='out_fc')
    self.out_drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(1, name='out_linear')
    
  
  
  def call(self, inputs, training=False):
    x1, x2 = inputs
    
    if x1.dtype != tf.int32:
      x1 = tf.cast(x1, tf.int32)
    if x2.dtype != tf.int32:
      x2 = tf.cast(x2, tf.int32)
    
    batch_sz = tf.shape(x1)[0]
    
    mask1 = tf.sign(x1)
    mask2 = tf.sign(x2)
    
    x1 = self.embedding(x1, training=training)
    x2 = self.embedding(x2, training=training)
    
    res_x1, res_x2 = x1, x2
    
    for i in range(params['num_blocks']):
      
      if i > 0:
        x1 = self.connection(x1, res_x1, i)
        x2 = self.connection(x2, res_x2, i)
        res_x1, res_x2 = x1, x2
    
      x1_enc = self.encoding(x1, mask1, i, training=training)
      x2_enc = self.encoding(x2, mask2, i, training=training)
    
      x1 = tf.concat((x1, x1_enc), -1)
      x2 = tf.concat((x2, x2_enc), -1)
      
      align_1, align_2 = self.alignment(x1, x2, mask1, mask2, i, training=training)
      
      x1 = self.fusion(x1, align_1, i, training=training)
      x2 = self.fusion(x2, align_2, i, training=training)
    
    x1 = self.pooling(x1, mask1)
    x2 = self.pooling(x2, mask2)
    
    x = self.prediction(x1, x2, training=training)
    
    return x
  
  
  def embedding(self, x, training):
    x = tf.nn.embedding_lookup(self.pretrained_embedding, x)
    x = self.embed_dropout(x, training=training)
    return x
  
  
  def connection(self, x, res, i):
    if i == 1:
      x = tf.concat((res, x), -1)
    elif i > 1:
      hidden_size = x.shape[-1]
      x = (res[:, :, -hidden_size:] + x) * tf.math.sqrt(0.5)
      x = tf.concat((res[:, :, :-hidden_size], x), -1)
    return x
    
    
  def encoding(self, x, mask, i, training):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    x *= mask
    x = self.birnn[i](x)
    x = self.enc_dropout(x, training=training)
    return x
  
  
  def alignment(self, x1, x2, mask1, mask2, i, training):
    mask1 = tf.cast(tf.expand_dims(mask1, -1), tf.float32)
    mask2 = tf.cast(tf.expand_dims(mask2, -1), tf.float32)
    
    x1_ = self.align_fc1[i](self.align_dropout(x1, training=training))
    x2_ = self.align_fc2[i](self.align_dropout(x2, training=training))
    align = tf.matmul(x1_, x2_, transpose_b=True) * self.align_t
    mask = tf.matmul(mask1, mask2, transpose_b=True)
    align = mask * align + (1 - mask) * tf.float32.min
    align_1 = tf.nn.softmax(align, 1)
    align_2 = tf.nn.softmax(align, 2)
    
    x2 = tf.matmul(align_1, x1, transpose_a=True)
    x1 = tf.matmul(align_2, x2)
    return x1, x2
  
  
  def fusion(self, x, align, i, training):
    x = tf.concat([self.fusion_fc1[i](tf.concat((x, align), -1)),
                   self.fusion_fc2[i](tf.concat((x, x - align), -1)),
                   self.fusion_fc3[i](tf.concat((x, x * align), -1))], -1)
    x = self.fusion_dropout(x, training=training)
    x = self.fusion_fc4[i](x)
    return x
  
  
  def pooling(self, x, mask):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    return tf.reduce_max(x * mask, 1)
  
  
  def prediction(self, x1, x2, training):
    x = tf.concat((x1, x2, x1 * x2, x1 - x2), -1)
    x = self.out_drop1(x, training=training)
    x = self.out_fc(x)
    x = self.out_drop2(x, training=training)
    x = self.out_linear(x)
    x = tf.squeeze(x, 1)
    return x

# %%
params = {
  'train_path': '../data/train.csv',
  'test_path': '../data/test.csv',
  'vocab_path': '../vocab/char.txt',
  'embedding_path': '../vocab/char.npy',
  'batch_size': 32,
  'buffer_size': 100000,
  'num_blocks': 2,
  'dropout_rate': 0.2,
  'hidden_size': 300,
  'activation': tf.nn.relu,
  'lr': 4e-4,
  'clip_norm': 5.,
  'num_patience': 5,
}

# %%
def is_descending(history):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] <= history[i]:
      return False
  return True

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['vocab_size'] = len(params['char2idx']) + 1

model = RE2(params)
model.build([[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = tf.optimizers.schedules.ExponentialDecay(params['lr'], 1000, 0.99)
optim = tf.optimizers.Adam(params['lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

while True:
  # TRAINING
  for ((text1, text2), labels) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      logits = model((text1, text2), training=True)
      loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.cast(labels, tf.float32), logits=logits)
      loss = tf.reduce_mean(loss)
      
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))
    
    if global_step % 100 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
  
  # EVALUATION
  m = tf.keras.metrics.Accuracy()

  for ((text1, text2), labels) in dataset(is_training=False, params=params):
    logits = tf.sigmoid(model((text1, text2), training=False))
    y_pred = tf.cast(tf.math.greater_equal(logits, .5), tf.int32)
    m.update_state(y_true=labels, y_pred=y_pred)

  acc = m.result().numpy()
  logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
  history_acc.append(acc)

  if acc > best_acc:
    best_acc = acc
    # you can save model here
  logger.info("Best Accuracy: {:.3f}".format(best_acc))

  if len(history_acc) > params['num_patience'] and is_descending(history_acc):
    logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# [('birnn_1/forward_lstm/lstm_cell_1/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm/lstm_cell_1/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm/lstm_cell_1/bias:0', TensorShape([1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/bias:0', TensorShape([1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/bias:0', TensorShape([1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/bias:0', TensorShape([1200])),
#  ('align_fc1_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc1_1/bias:0', TensorShape([300])),
#  ('align_fc1_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc1_2/bias:0', TensorShape([300])),
#  ('align_fc2_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc2_1/bias:0', TensorShape([300])),
#  ('align_fc2_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc1_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc1_1/bias:0', TensorShape([300])),
#  ('fusion_fc1_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc1_2/bias:0', TensorShape([300])),
#  ('fusion_fc2_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc2_1/bias:0', TensorShape([300])),
#  ('fusion_fc2_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc3_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc3_1/bias:0', TensorShape([300])),
#  ('fusion_fc3_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc3_2/bias:0', TensorShape([300])),
#  ('fusion_fc4_1/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_1/bias:0', TensorShape([300])),
#  ('fusion_fc4_2/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_2/bias:0', TensorShape([300])),
#  ('out_fc/kernel:0', TensorShape([1200, 300])),
#  ('out_fc/bias:0', TensorShape([300])),
#  ('out_linear/kernel:0', TensorShape([300, 1])),
#  ('out_linear/bias:0', TensorShape([1])),
#  ('pretrained_embedding:0', TensorShape([1507, 300])),
#  ('temperature:0', TensorShape([]))]
# Reading ../data/train.csv
# INFO:tensorflow:Step 0 | Loss: 0.6763 | Spent: 23.6 secs | LR: 0.000400
# INFO:tensorflow:Step 100 | Loss: 0.6030 | Spent: 10.9 secs | LR: 0.000400
# INFO:tensorflow:Step 200 | Loss: 0.6542 | Spent: 10.8 secs | LR: 0.000399
# INFO:tensorflow:Step 300 | Loss: 0.6848 | Spent: 10.7 secs | LR: 0.000399
# INFO:tensorflow:Step 400 | Loss: 0.6185 | Spent: 10.5 secs | LR: 0.000398
# INFO:tensorflow:Step 500 | Loss: 0.4714 | Spent: 10.5 secs | LR: 0.000398
# INFO:tensorflow:Step 600 | Loss: 0.6942 | Spent: 10.5 secs | LR: 0.000398
# INFO:tensorflow:Step 700 | Loss: 0.6108 | Spent: 10.5 secs | LR: 0.000397
# INFO:tensorflow:Step 800 | Loss: 0.5382 | Spent: 10.8 secs | LR: 0.000397
# INFO:tensorflow:Step 900 | Loss: 0.5778 | Spent: 10.7 secs | LR: 0.000396
# INFO:tensorflow:Step 1000 | Loss: 0.5159 | Spent: 10.6 secs | LR: 0.000396
# INFO:tensorflow:Step 1100 | Loss: 0.5485 | Spent: 10.3 secs | LR: 0.000396
# INFO:tensorflow:Step 1200 | Loss: 0.7098 | Spent: 10.3 secs | LR: 0.000395
# INFO:tensorflow:Step 1300 | Loss: 0.5960 | Spent: 10.4 secs | LR: 0.000395
# INFO:tensorflow:Step 1400 | Loss: 0.4307 | Spent: 10.5 secs | LR: 0.000394
# INFO:tensorflow:Step 1500 | Loss: 0.4825 | Spent: 10.6 secs | LR: 0.000394
# INFO:tensorflow:Step 1600 | Loss: 0.3821 | Spent: 10.5 secs | LR: 0.000394
# INFO:tensorflow:Step 1700 | Loss: 0.4029 | Spent: 10.6 secs | LR: 0.000393
# INFO:tensorflow:Step 1800 | Loss: 0.5261 | Spent: 10.4 secs | LR: 0.000393
# INFO:tensorflow:Step 1900 | Loss: 0.3745 | Spent: 10.4 secs | LR: 0.000392
# INFO:tensorflow:Step 2000 | Loss: 0.5739 | Spent: 10.2 secs | LR: 0.000392
# INFO:tensorflow:Step 2100 | Loss: 0.4246 | Spent: 10.3 secs | LR: 0.000392
# INFO:tensorflow:Step 2200 | Loss: 0.3892 | Spent: 10.5 secs | LR: 0.000391
# INFO:tensorflow:Step 2300 | Loss: 0.3533 | Spent: 10.5 secs | LR: 0.000391
# INFO:tensorflow:Step 2400 | Loss: 0.4083 | Spent: 10.3 secs | LR: 0.000390
# INFO:tensorflow:Step 2500 | Loss: 0.3269 | Spent: 10.4 secs | LR: 0.000390
# INFO:tensorflow:Step 2600 | Loss: 0.5425 | Spent: 10.2 secs | LR: 0.000390
# INFO:tensorflow:Step 2700 | Loss: 0.4406 | Spent: 10.4 secs | LR: 0.000389
# INFO:tensorflow:Step 2800 | Loss: 0.3099 | Spent: 10.5 secs | LR: 0.000389
# INFO:tensorflow:Step 2900 | Loss: 0.6196 | Spent: 10.3 secs | LR: 0.000389
# INFO:tensorflow:Step 3000 | Loss: 0.2948 | Spent: 10.5 secs | LR: 0.000388
# INFO:tensorflow:Step 3100 | Loss: 0.4196 | Spent: 10.5 secs | LR: 0.000388
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.785
# INFO:tensorflow:Best Accuracy: 0.785
# Reading ../data/train.csv
# INFO:tensorflow:Step 3200 | Loss: 0.3336 | Spent: 42.1 secs | LR: 0.000387
# INFO:tensorflow:Step 3300 | Loss: 0.4638 | Spent: 10.4 secs | LR: 0.000387
# INFO:tensorflow:Step 3400 | Loss: 0.3219 | Spent: 10.2 secs | LR: 0.000387
# INFO:tensorflow:Step 3500 | Loss: 0.6232 | Spent: 10.3 secs | LR: 0.000386
# INFO:tensorflow:Step 3600 | Loss: 0.4669 | Spent: 10.2 secs | LR: 0.000386
# INFO:tensorflow:Step 3700 | Loss: 0.2951 | Spent: 10.4 secs | LR: 0.000385
# INFO:tensorflow:Step 3800 | Loss: 0.2973 | Spent: 10.5 secs | LR: 0.000385
# INFO:tensorflow:Step 3900 | Loss: 0.3625 | Spent: 10.4 secs | LR: 0.000385
# INFO:tensorflow:Step 4000 | Loss: 0.3064 | Spent: 10.2 secs | LR: 0.000384
# INFO:tensorflow:Step 4100 | Loss: 0.4429 | Spent: 10.4 secs | LR: 0.000384
# INFO:tensorflow:Step 4200 | Loss: 0.2854 | Spent: 10.3 secs | LR: 0.000383
# INFO:tensorflow:Step 4300 | Loss: 0.3410 | Spent: 10.2 secs | LR: 0.000383
# INFO:tensorflow:Step 4400 | Loss: 0.3711 | Spent: 10.2 secs | LR: 0.000383
# INFO:tensorflow:Step 4500 | Loss: 0.3148 | Spent: 10.4 secs | LR: 0.000382
# INFO:tensorflow:Step 4600 | Loss: 0.4159 | Spent: 10.4 secs | LR: 0.000382
# INFO:tensorflow:Step 4700 | Loss: 0.2592 | Spent: 10.2 secs | LR: 0.000382
# INFO:tensorflow:Step 4800 | Loss: 0.4348 | Spent: 10.3 secs | LR: 0.000381
# INFO:tensorflow:Step 4900 | Loss: 0.4271 | Spent: 10.3 secs | LR: 0.000381
# INFO:tensorflow:Step 5000 | Loss: 0.2277 | Spent: 10.2 secs | LR: 0.000380
# INFO:tensorflow:Step 5100 | Loss: 0.4130 | Spent: 10.2 secs | LR: 0.000380
# INFO:tensorflow:Step 5200 | Loss: 0.3781 | Spent: 10.2 secs | LR: 0.000380
# INFO:tensorflow:Step 5300 | Loss: 0.2932 | Spent: 10.4 secs | LR: 0.000379
# INFO:tensorflow:Step 5400 | Loss: 0.5365 | Spent: 10.4 secs | LR: 0.000379
# INFO:tensorflow:Step 5500 | Loss: 0.2089 | Spent: 10.5 secs | LR: 0.000378
# INFO:tensorflow:Step 5600 | Loss: 0.2069 | Spent: 10.5 secs | LR: 0.000378
# INFO:tensorflow:Step 5700 | Loss: 0.3200 | Spent: 10.4 secs | LR: 0.000378
# INFO:tensorflow:Step 5800 | Loss: 0.2433 | Spent: 10.3 secs | LR: 0.000377
# INFO:tensorflow:Step 5900 | Loss: 0.2871 | Spent: 10.4 secs | LR: 0.000377
# INFO:tensorflow:Step 6000 | Loss: 0.2921 | Spent: 10.2 secs | LR: 0.000377
# INFO:tensorflow:Step 6100 | Loss: 0.5559 | Spent: 10.3 secs | LR: 0.000376
# INFO:tensorflow:Step 6200 | Loss: 0.3292 | Spent: 10.3 secs | LR: 0.000376
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.811
# INFO:tensorflow:Best Accuracy: 0.811
# Reading ../data/train.csv
# INFO:tensorflow:Step 6300 | Loss: 0.4163 | Spent: 41.6 secs | LR: 0.000375
# INFO:tensorflow:Step 6400 | Loss: 0.4068 | Spent: 10.1 secs | LR: 0.000375
# INFO:tensorflow:Step 6500 | Loss: 0.4184 | Spent: 10.4 secs | LR: 0.000375
# INFO:tensorflow:Step 6600 | Loss: 0.1488 | Spent: 10.4 secs | LR: 0.000374
# INFO:tensorflow:Step 6700 | Loss: 0.4568 | Spent: 10.2 secs | LR: 0.000374
# INFO:tensorflow:Step 6800 | Loss: 0.1940 | Spent: 10.4 secs | LR: 0.000374
# INFO:tensorflow:Step 6900 | Loss: 0.2574 | Spent: 10.3 secs | LR: 0.000373
# INFO:tensorflow:Step 7000 | Loss: 0.4477 | Spent: 10.3 secs | LR: 0.000373
# INFO:tensorflow:Step 7100 | Loss: 0.3805 | Spent: 10.4 secs | LR: 0.000372
# INFO:tensorflow:Step 7200 | Loss: 0.2233 | Spent: 10.3 secs | LR: 0.000372
# INFO:tensorflow:Step 7300 | Loss: 0.3092 | Spent: 10.4 secs | LR: 0.000372
# INFO:tensorflow:Step 7400 | Loss: 0.2522 | Spent: 10.4 secs | LR: 0.000371
# INFO:tensorflow:Step 7500 | Loss: 0.3921 | Spent: 10.3 secs | LR: 0.000371
# INFO:tensorflow:Step 7600 | Loss: 0.1874 | Spent: 10.4 secs | LR: 0.000371
# INFO:tensorflow:Step 7700 | Loss: 0.2932 | Spent: 10.2 secs | LR: 0.000370
# INFO:tensorflow:Step 7800 | Loss: 0.4309 | Spent: 10.1 secs | LR: 0.000370
# INFO:tensorflow:Step 7900 | Loss: 0.3241 | Spent: 10.3 secs | LR: 0.000369
# INFO:tensorflow:Step 8000 | Loss: 0.1911 | Spent: 10.1 secs | LR: 0.000369
# INFO:tensorflow:Step 8100 | Loss: 0.3438 | Spent: 10.3 secs | LR: 0.000369
# INFO:tensorflow:Step 8200 | Loss: 0.2996 | Spent: 10.3 secs | LR: 0.000368
# INFO:tensorflow:Step 8300 | Loss: 0.5653 | Spent: 10.4 secs | LR: 0.000368
# INFO:tensorflow:Step 8400 | Loss: 0.3282 | Spent: 10.4 secs | LR: 0.000368
# INFO:tensorflow:Step 8500 | Loss: 0.4724 | Spent: 10.5 secs | LR: 0.000367
# INFO:tensorflow:Step 8600 | Loss: 0.3632 | Spent: 10.2 secs | LR: 0.000367
# INFO:tensorflow:Step 8700 | Loss: 0.1955 | Spent: 10.5 secs | LR: 0.000367
# INFO:tensorflow:Step 8800 | Loss: 0.7162 | Spent: 10.2 secs | LR: 0.000366
# INFO:tensorflow:Step 8900 | Loss: 0.2256 | Spent: 10.3 secs | LR: 0.000366
# INFO:tensorflow:Step 9000 | Loss: 0.1916 | Spent: 10.3 secs | LR: 0.000365
# INFO:tensorflow:Step 9100 | Loss: 0.1035 | Spent: 10.3 secs | LR: 0.000365
# INFO:tensorflow:Step 9200 | Loss: 0.4971 | Spent: 10.2 secs | LR: 0.000365
# INFO:tensorflow:Step 9300 | Loss: 0.3008 | Spent: 10.2 secs | LR: 0.000364
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.819
# INFO:tensorflow:Best Accuracy: 0.819
# Reading ../data/train.csv
# INFO:tensorflow:Step 9400 | Loss: 0.3422 | Spent: 41.6 secs | LR: 0.000364
# INFO:tensorflow:Step 9500 | Loss: 0.2959 | Spent: 10.2 secs | LR: 0.000364
# INFO:tensorflow:Step 9600 | Loss: 0.1520 | Spent: 10.3 secs | LR: 0.000363
# INFO:tensorflow:Step 9700 | Loss: 0.2585 | Spent: 10.4 secs | LR: 0.000363
# INFO:tensorflow:Step 9800 | Loss: 0.2008 | Spent: 10.2 secs | LR: 0.000362
# INFO:tensorflow:Step 9900 | Loss: 0.4408 | Spent: 10.5 secs | LR: 0.000362
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.821
# INFO:tensorflow:Best Accuracy: 0.821
# Reading ../data/train.csv
# INFO:tensorflow:Step 18800 | Loss: 0.1886 | Spent: 41.3 secs | LR: 0.000331
# INFO:tensorflow:Step 18900 | Loss: 0.1038 | Spent: 10.4 secs | LR: 0.000331
# INFO:tensorflow:Step 19000 | Loss: 0.1464 | Spent: 10.2 secs | LR: 0.000330
# INFO:tensorflow:Step 19100 | Loss: 0.1438 | Spent: 10.5 secs | LR: 0.000330
# INFO:tensorflow:Step 19200 | Loss: 0.0546 | Spent: 10.4 secs | LR: 0.000330
# INFO:tensorflow:Step 19300 | Loss: 0.1838 | Spent: 10.2 secs | LR: 0.000329
# INFO:tensorflow:Step 19400 | Loss: 0.0852 | Spent: 10.3 secs | LR: 0.000329
# INFO:tensorflow:Step 19500 | Loss: 0.4445 | Spent: 10.3 secs | LR: 0.000329
# INFO:tensorflow:Step 19600 | Loss: 0.0618 | Spent: 10.2 secs | LR: 0.000328
# INFO:tensorflow:Step 19700 | Loss: 0.1121 | Spent: 10.3 secs | LR: 0.000328
# INFO:tensorflow:Step 19800 | Loss: 0.1000 | Spent: 10.2 secs | LR: 0.000328
# INFO:tensorflow:Step 19900 | Loss: 0.1022 | Spent: 10.1 secs | LR: 0.000327
# INFO:tensorflow:Step 20000 | Loss: 0.1344 | Spent: 10.2 secs | LR: 0.000327
# INFO:tensorflow:Step 20100 | Loss: 0.0871 | Spent: 10.1 secs | LR: 0.000327
# INFO:tensorflow:Step 20200 | Loss: 0.1153 | Spent: 10.4 secs | LR: 0.000327
# INFO:tensorflow:Step 20300 | Loss: 0.1179 | Spent: 10.4 secs | LR: 0.000326
# INFO:tensorflow:Step 20400 | Loss: 0.0602 | Spent: 10.4 secs | LR: 0.000326
# INFO:tensorflow:Step 20500 | Loss: 0.0600 | Spent: 10.2 secs | LR: 0.000326
# INFO:tensorflow:Step 20600 | Loss: 0.2660 | Spent: 10.3 secs | LR: 0.000325
# INFO:tensorflow:Step 20700 | Loss: 0.1374 | Spent: 10.3 secs | LR: 0.000325
# INFO:tensorflow:Step 20800 | Loss: 0.1607 | Spent: 10.2 secs | LR: 0.000325
# INFO:tensorflow:Step 20900 | Loss: 0.1324 | Spent: 10.2 secs | LR: 0.000324
# INFO:tensorflow:Step 21000 | Loss: 0.1424 | Spent: 10.2 secs | LR: 0.000324
# INFO:tensorflow:Step 21100 | Loss: 0.2656 | Spent: 10.2 secs | LR: 0.000324
# INFO:tensorflow:Step 21200 | Loss: 0.1717 | Spent: 10.4 secs | LR: 0.000323
# INFO:tensorflow:Step 21300 | Loss: 0.1436 | Spent: 10.2 secs | LR: 0.000323
# INFO:tensorflow:Step 21400 | Loss: 0.0954 | Spent: 10.4 secs | LR: 0.000323
# INFO:tensorflow:Step 21500 | Loss: 0.1321 | Spent: 10.2 secs | LR: 0.000322
# INFO:tensorflow:Step 21600 | Loss: 0.0774 | Spent: 10.2 secs | LR: 0.000322
# INFO:tensorflow:Step 21700 | Loss: 0.1528 | Spent: 10.1 secs | LR: 0.000322
# INFO:tensorflow:Step 21800 | Loss: 0.0391 | Spent: 10.3 secs | LR: 0.000321
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.815
# INFO:tensorflow:Best Accuracy: 0.828
# Reading ../data/train.csv
# INFO:tensorflow:Step 37500 | Loss: 0.0820 | Spent: 41.3 secs | LR: 0.000274
# INFO:tensorflow:Step 37600 | Loss: 0.1515 | Spent: 10.2 secs | LR: 0.000274
# INFO:tensorflow:Step 37700 | Loss: 0.0231 | Spent: 10.5 secs | LR: 0.000274
# INFO:tensorflow:Step 37800 | Loss: 0.0158 | Spent: 10.3 secs | LR: 0.000274
# INFO:tensorflow:Step 37900 | Loss: 0.0148 | Spent: 10.2 secs | LR: 0.000273
# INFO:tensorflow:Step 38000 | Loss: 0.0095 | Spent: 10.3 secs | LR: 0.000273
# INFO:tensorflow:Step 38100 | Loss: 0.0006 | Spent: 10.3 secs | LR: 0.000273
# INFO:tensorflow:Step 38200 | Loss: 0.0490 | Spent: 10.5 secs | LR: 0.000272
# INFO:tensorflow:Step 38300 | Loss: 0.1552 | Spent: 10.2 secs | LR: 0.000272
# INFO:tensorflow:Step 38400 | Loss: 0.0694 | Spent: 10.5 secs | LR: 0.000272
# INFO:tensorflow:Step 38500 | Loss: 0.0882 | Spent: 10.2 secs | LR: 0.000272
# INFO:tensorflow:Step 38600 | Loss: 0.0247 | Spent: 10.3 secs | LR: 0.000271
# INFO:tensorflow:Step 38700 | Loss: 0.0144 | Spent: 10.3 secs | LR: 0.000271
# INFO:tensorflow:Step 38800 | Loss: 0.0025 | Spent: 10.2 secs | LR: 0.000271
# INFO:tensorflow:Step 38900 | Loss: 0.0465 | Spent: 10.1 secs | LR: 0.000271
# INFO:tensorflow:Step 39000 | Loss: 0.0521 | Spent: 10.3 secs | LR: 0.000270
# INFO:tensorflow:Step 39100 | Loss: 0.0291 | Spent: 10.4 secs | LR: 0.000270
# INFO:tensorflow:Step 39200 | Loss: 0.0036 | Spent: 10.1 secs | LR: 0.000270
# INFO:tensorflow:Step 39300 | Loss: 0.0224 | Spent: 10.4 secs | LR: 0.000269
# INFO:tensorflow:Step 39400 | Loss: 0.0239 | Spent: 10.4 secs | LR: 0.000269
# INFO:tensorflow:Step 39500 | Loss: 0.0881 | Spent: 10.3 secs | LR: 0.000269
# INFO:tensorflow:Step 39600 | Loss: 0.0854 | Spent: 10.2 secs | LR: 0.000269
# INFO:tensorflow:Step 39700 | Loss: 0.0203 | Spent: 10.4 secs | LR: 0.000268
# INFO:tensorflow:Step 39800 | Loss: 0.0352 | Spent: 10.3 secs | LR: 0.000268
# INFO:tensorflow:Step 39900 | Loss: 0.0213 | Spent: 10.3 secs | LR: 0.000268
# INFO:tensorflow:Step 40000 | Loss: 0.0166 | Spent: 10.4 secs | LR: 0.000268
# INFO:tensorflow:Step 40100 | Loss: 0.0916 | Spent: 10.3 secs | LR: 0.000267
# INFO:tensorflow:Step 43300 | Loss: 0.1552 | Spent: 10.6 secs | LR: 0.000259
# INFO:tensorflow:Step 43400 | Loss: 0.0911 | Spent: 10.5 secs | LR: 0.000259
# INFO:tensorflow:Step 43500 | Loss: 0.1016 | Spent: 10.6 secs | LR: 0.000258
# INFO:tensorflow:Step 43600 | Loss: 0.0470 | Spent: 10.5 secs | LR: 0.000258
# INFO:tensorflow:Step 43700 | Loss: 0.0083 | Spent: 10.5 secs | LR: 0.000258
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.823
# INFO:tensorflow:Best Accuracy: 0.828
# Reading ../data/train.csv
# INFO:tensorflow:Step 43800 | Loss: 0.1179 | Spent: 43.5 secs | LR: 0.000258
# INFO:tensorflow:Step 43900 | Loss: 0.0054 | Spent: 10.5 secs | LR: 0.000257
# INFO:tensorflow:Step 44000 | Loss: 0.0351 | Spent: 10.3 secs | LR: 0.000257
# INFO:tensorflow:Step 44100 | Loss: 0.0091 | Spent: 10.5 secs | LR: 0.000257
# INFO:tensorflow:Step 44200 | Loss: 0.0060 | Spent: 10.5 secs | LR: 0.000257
# INFO:tensorflow:Step 44300 | Loss: 0.0405 | Spent: 10.5 secs | LR: 0.000256
# INFO:tensorflow:Step 44400 | Loss: 0.0034 | Spent: 10.2 secs | LR: 0.000256
# INFO:tensorflow:Step 44500 | Loss: 0.1496 | Spent: 10.5 secs | LR: 0.000256
# INFO:tensorflow:Step 44600 | Loss: 0.0059 | Spent: 10.6 secs | LR: 0.000255
# INFO:tensorflow:Step 44700 | Loss: 0.0174 | Spent: 10.3 secs | LR: 0.000255
# INFO:tensorflow:Step 44800 | Loss: 0.1636 | Spent: 10.4 secs | LR: 0.000255
# INFO:tensorflow:Step 44900 | Loss: 0.0944 | Spent: 10.5 secs | LR: 0.000255
# INFO:tensorflow:Step 45000 | Loss: 0.0099 | Spent: 10.5 secs | LR: 0.000254
# INFO:tensorflow:Step 45100 | Loss: 0.0147 | Spent: 10.5 secs | LR: 0.000254
# INFO:tensorflow:Step 45200 | Loss: 0.0645 | Spent: 10.5 secs | LR: 0.000254
# INFO:tensorflow:Step 45300 | Loss: 0.0233 | Spent: 10.5 secs | LR: 0.000254
# INFO:tensorflow:Step 45400 | Loss: 0.0542 | Spent: 10.5 secs | LR: 0.000253
# INFO:tensorflow:Step 45500 | Loss: 0.0649 | Spent: 10.4 secs | LR: 0.000253
# INFO:tensorflow:Step 45600 | Loss: 0.0823 | Spent: 10.2 secs | LR: 0.000253
# INFO:tensorflow:Step 45700 | Loss: 0.0138 | Spent: 10.3 secs | LR: 0.000253
# INFO:tensorflow:Step 45800 | Loss: 0.4480 | Spent: 10.3 secs | LR: 0.000252
# INFO:tensorflow:Step 45900 | Loss: 0.0404 | Spent: 10.5 secs | LR: 0.000252
# INFO:tensorflow:Step 46000 | Loss: 0.0025 | Spent: 10.6 secs | LR: 0.000252
# INFO:tensorflow:Step 46100 | Loss: 0.0041 | Spent: 10.5 secs | LR: 0.000252
# INFO:tensorflow:Step 46200 | Loss: 0.0156 | Spent: 10.4 secs | LR: 0.000251
# INFO:tensorflow:Step 46300 | Loss: 0.0479 | Spent: 10.4 secs | LR: 0.000251
# INFO:tensorflow:Step 55500 | Loss: 0.0139 | Spent: 10.4 secs | LR: 0.000229
# INFO:tensorflow:Step 55600 | Loss: 0.0616 | Spent: 10.4 secs | LR: 0.000229
# INFO:tensorflow:Step 55700 | Loss: 0.0087 | Spent: 10.4 secs | LR: 0.000229
# INFO:tensorflow:Step 55800 | Loss: 0.0088 | Spent: 10.9 secs | LR: 0.000228
# INFO:tensorflow:Step 55900 | Loss: 0.0005 | Spent: 10.6 secs | LR: 0.000228
# INFO:tensorflow:Step 56000 | Loss: 0.0063 | Spent: 10.6 secs | LR: 0.000228
# INFO:tensorflow:Step 56100 | Loss: 0.0860 | Spent: 10.7 secs | LR: 0.000228
# INFO:tensorflow:Step 56200 | Loss: 0.0493 | Spent: 10.3 secs | LR: 0.000227
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.829
# INFO:tensorflow:Best Accuracy: 0.829
# Reading ../data/train.csv
# INFO:tensorflow:Step 56300 | Loss: 0.0026 | Spent: 42.2 secs | LR: 0.000227
# INFO:tensorflow:Step 56400 | Loss: 0.0080 | Spent: 10.5 secs | LR: 0.000227
# INFO:tensorflow:Step 56500 | Loss: 0.0005 | Spent: 10.6 secs | LR: 0.000227
# INFO:tensorflow:Step 56600 | Loss: 0.0014 | Spent: 10.5 secs | LR: 0.000226
# INFO:tensorflow:Step 56700 | Loss: 0.0713 | Spent: 10.6 secs | LR: 0.000226
# ...
# INFO:tensorflow:Step 90900 | Loss: 0.0071 | Spent: 10.8 secs | LR: 0.000160
# INFO:tensorflow:Step 91000 | Loss: 0.0013 | Spent: 10.8 secs | LR: 0.000160
# INFO:tensorflow:Step 91100 | Loss: 0.0003 | Spent: 11.0 secs | LR: 0.000160
# INFO:tensorflow:Step 91200 | Loss: 0.0066 | Spent: 10.9 secs | LR: 0.000160
# INFO:tensorflow:Step 91300 | Loss: 0.0003 | Spent: 10.9 secs | LR: 0.000160
# INFO:tensorflow:Step 91400 | Loss: 0.0017 | Spent: 11.1 secs | LR: 0.000160
# INFO:tensorflow:Step 91500 | Loss: 0.0056 | Spent: 11.1 secs | LR: 0.000159
# INFO:tensorflow:Step 91600 | Loss: 0.0216 | Spent: 11.2 secs | LR: 0.000159
# INFO:tensorflow:Step 91700 | Loss: 0.0405 | Spent: 11.1 secs | LR: 0.000159
# INFO:tensorflow:Step 91800 | Loss: 0.0020 | Spent: 10.7 secs | LR: 0.000159
# INFO:tensorflow:Step 91900 | Loss: 0.0036 | Spent: 10.9 secs | LR: 0.000159
# INFO:tensorflow:Step 92000 | Loss: 0.0076 | Spent: 10.7 secs | LR: 0.000159
# INFO:tensorflow:Step 92100 | Loss: 0.0135 | Spent: 10.9 secs | LR: 0.000159
# INFO:tensorflow:Step 92200 | Loss: 0.0007 | Spent: 10.8 secs | LR: 0.000158
# INFO:tensorflow:Step 92300 | Loss: 0.0015 | Spent: 10.8 secs | LR: 0.000158
# INFO:tensorflow:Step 92400 | Loss: 0.0001 | Spent: 10.8 secs | LR: 0.000158
| Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000148
# INFO:tensorflow:Step 98900 | Loss: 0.1060 | Spent: 10.2 secs | LR: 0.000148
# INFO:tensorflow:Step 99000 | Loss: 0.0127 | Spent: 10.3 secs | LR: 0.000148
# INFO:tensorflow:Step 99100 | Loss: 0.0006 | Spent: 10.3 secs | LR: 0.000148
# INFO:tensorflow:Step 99200 | Loss: 0.0004 | Spent: 10.3 secs | LR: 0.000148
# INFO:tensorflow:Step 99300 | Loss: 0.0002 | Spent: 10.5 secs | LR: 0.000147
# INFO:tensorflow:Step 99400 | Loss: 0.0001 | Spent: 10.3 secs | LR: 0.000147
# INFO:tensorflow:Step 99500 | Loss: 0.0001 | Spent: 10.4 secs | LR: 0.000147
# INFO:tensorflow:Step 99600 | Loss: 0.0005 | Spent: 10.6 secs | LR: 0.000147
# INFO:tensorflow:Step 99700 | Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000147
# INFO:tensorflow:Step 99800 | Loss: 0.0001 | Spent: 10.4 secs | LR: 0.000147
# INFO:tensorflow:Step 99900 | Loss: 0.0009 | Spent: 10.3 secs | LR: 0.000147
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.821
# INFO:tensorflow:Best Accuracy: 0.829
# Reading ../data/train.csv
# INFO:tensorflow:Step 100000 | Loss: 0.0028 | Spent: 41.6 secs | LR: 0.000146
# INFO:tensorflow:Step 100100 | Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000146
# INFO:tensorflow:Step 100200 | Loss: 0.0066 | Spent: 10.4 secs | LR: 0.000146
# INFO:tensorflow:Step 100300 | Loss: 0.0012 | Spent: 10.2 secs | LR: 0.000146
# INFO:tensorflow:Step 100400 | Loss: 0.0226 | Spent: 10.4 secs | LR: 0.000146
# INFO:tensorflow:Step 100500 | Loss: 0.0015 | Spent: 10.4 secs | LR: 0.000146
# INFO:tensorflow:Step 100600 | Loss: 0.0028 | Spent: 10.5 secs | LR: 0.000146
# INFO:tensorflow:Step 100700 | Loss: 0.0150 | Spent: 10.2 secs | LR: 0.000145
# INFO:tensorflow:Step 100800 | Loss: 0.0052 | Spent: 10.4 secs | LR: 0.000145
# INFO:tensorflow:Step 100900 | Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000145
# INFO:tensorflow:Step 101000 | Loss: 0.0003 | Spent: 10.2 secs | LR: 0.000145
# INFO:tensorflow:Step 101100 | Loss: 0.0001 | Spent: 10.3 secs | LR: 0.000145
# INFO:tensorflow:Step 101200 | Loss: 0.0004 | Spent: 10.2 secs | LR: 0.000145
# INFO:tensorflow:Step 101300 | Loss: 0.0136 | Spent: 10.5 secs | LR: 0.000145
# INFO:tensorflow:Step 101400 | Loss: 0.0006 | Spent: 10.4 secs | LR: 0.000144
# INFO:tensorflow:Step 101500 | Loss: 0.0051 | Spent: 10.2 secs | LR: 0.000144
# INFO:tensorflow:Step 101600 | Loss: 0.0008 | Spent: 10.5 secs | LR: 0.000144
# INFO:tensorflow:Step 101700 | Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000144
# INFO:tensorflow:Step 101800 | Loss: 0.0032 | Spent: 10.2 secs | LR: 0.000144
# INFO:tensorflow:Step 101900 | Loss: 0.0006 | Spent: 10.4 secs | LR: 0.000144
# INFO:tensorflow:Step 102000 | Loss: 0.0869 | Spent: 10.3 secs | LR: 0.000143
# INFO:tensorflow:Step 102100 | Loss: 0.0000 | Spent: 10.2 secs | LR: 0.000143
# INFO:tensorflow:Step 102200 | Loss: 0.0600 | Spent: 10.3 secs | LR: 0.000143
# INFO:tensorflow:Step 102300 | Loss: 0.0000 | Spent: 10.6 secs | LR: 0.000143
# INFO:tensorflow:Step 102400 | Loss: 0.0000 | Spent: 10.4 secs | LR: 0.000143
# INFO:tensorflow:Step 102500 | Loss: 0.0015 | Spent: 10.2 secs | LR: 0.000143
# INFO:tensorflow:Step 102600 | Loss: 0.0004 | Spent: 10.3 secs | LR: 0.000143
# INFO:tensorflow:Step 102700 | Loss: 0.0017 | Spent: 10.3 secs | LR: 0.000142
# INFO:tensorflow:Step 102800 | Loss: 0.0003 | Spent: 10.2 secs | LR: 0.000142
# INFO:tensorflow:Step 102900 | Loss: 0.0030 | Spent: 10.4 secs | LR: 0.000142
# INFO:tensorflow:Step 103000 | Loss: 0.0003 | Spent: 10.2 secs | LR: 0.000142
# INFO:tensorflow:Step 103100 | Loss: 0.0361 | Spent: 10.6 secs | LR: 0.000142
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.825
# INFO:tensorflow:Best Accuracy: 0.829
# Reading ../data/train.csv
# INFO:tensorflow:Step 103200 | Loss: 0.0057 | Spent: 41.3 secs | LR: 0.000142
# INFO:tensorflow:Step 103300 | Loss: 0.0176 | Spent: 10.3 secs | LR: 0.000142
# INFO:tensorflow:Step 103400 | Loss: 0.0008 | Spent: 10.3 secs | LR: 0.000141
# INFO:tensorflow:Step 103500 | Loss: 0.0013 | Spent: 10.2 secs | LR: 0.000141
# INFO:tensorflow:Step 103600 | Loss: 0.0002 | Spent: 10.4 secs | LR: 0.000141
# INFO:tensorflow:Step 103700 | Loss: 0.0003 | Spent: 10.4 secs | LR: 0.000141
# INFO:tensorflow:Step 103800 | Loss: 0.0045 | Spent: 10.5 secs | LR: 0.000141
# INFO:tensorflow:Step 103900 | Loss: 0.0012 | Spent: 10.3 secs | LR: 0.000141
# INFO:tensorflow:Step 104000 | Loss: 0.0004 | Spent: 10.5 secs | LR: 0.000141
# INFO:tensorflow:Step 104100 | Loss: 0.0236 | Spent: 10.4 secs | LR: 0.000141
# INFO:tensorflow:Step 104200 | Loss: 0.0074 | Spent: 10.3 secs | LR: 0.000140
# INFO:tensorflow:Step 104300 | Loss: 0.0259 | Spent: 10.5 secs | LR: 0.000140
# INFO:tensorflow:Step 104400 | Loss: 0.0097 | Spent: 10.5 secs | LR: 0.000140
# INFO:tensorflow:Step 104500 | Loss: 0.0004 | Spent: 10.3 secs | LR: 0.000140
# INFO:tensorflow:Step 104600 | Loss: 0.1502 | Spent: 10.4 secs | LR: 0.000140
# INFO:tensorflow:Step 104700 | Loss: 0.0002 | Spent: 10.3 secs | LR: 0.000140
# INFO:tensorflow:Step 104800 | Loss: 0.0024 | Spent: 10.0 secs | LR: 0.000140
# INFO:tensorflow:Step 104900 | Loss: 0.0002 | Spent: 10.2 secs | LR: 0.000139
# INFO:tensorflow:Step 105000 | Loss: 0.0000 | Spent: 10.5 secs | LR: 0.000139
# INFO:tensorflow:Step 105100 | Loss: 0.0000 | Spent: 10.2 secs | LR: 0.000139
# INFO:tensorflow:Step 105200 | Loss: 0.0002 | Spent: 10.3 secs | LR: 0.000139
# INFO:tensorflow:Step 105300 | Loss: 0.0000 | Spent: 10.5 secs | LR: 0.000139
# INFO:tensorflow:Step 105400 | Loss: 0.0026 | Spent: 10.4 secs | LR: 0.000139
# INFO:tensorflow:Step 105500 | Loss: 0.0001 | Spent: 10.2 secs | LR: 0.000139
# INFO:tensorflow:Step 105600 | Loss: 0.0001 | Spent: 10.3 secs | LR: 0.000138
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8074         _ctx._context_handle, tld.device_name, "Reshape", name,
# -> 8075         tld.op_callbacks, tensor, shape)
#    8076       return _result
#
# _FallbackException: This function does not handle the case of the path where all inputs are not already EagerTensors.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3b182965ddf9> in <module>()
#      21   for ((text1, text2), labels) in dataset(is_training=True, params=params):
#      22     with tf.GradientTape() as tape:
# ---> 23       logits = model((text1, text2), training=True)
#      24       loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.cast(labels, tf.float32), logits=logits)
#      25       loss = tf.reduce_mean(loss)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-6-09060435180e> in call(self, inputs, training)
#      62       x2 = tf.concat((x2, x2_enc), -1)
#      63
# ---> 64       align_1, align_2 = self.alignment(x1, x2, mask1, mask2, i, training=training)
#      65
#      66       x1 = self.fusion(x1, align_1, i, training=training)
#
# <ipython-input-6-09060435180e> in alignment(self, x1, x2, mask1, mask2, i, training)
#     104
#     105     x1_ = self.align_fc1[i](self.align_dropout(x1, training=training))
# --> 106     x2_ = self.align_fc2[i](self.align_dropout(x2, training=training))
#     107     align = tf.matmul(x1_, x2_, transpose_b=True) * self.align_t
#     108     mask = tf.matmul(mask1, mask2, transpose_b=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py in call(self, inputs)
#    1181     if rank is not None and rank > 2:
#    1182       # Broadcasting is required for the inputs.
# -> 1183       outputs = standard_ops.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#    1184       # Reshape the output back to the original ndim of the input.
#    1185       if not context.executing_eagerly():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in tensordot(a, b, axes, name)
#    4351       else:
#    4352         return array_ops.reshape(
# -> 4353             ab_matmul, a_free_dims + b_free_dims, name=name)
#    4354     else:
#    4355       a_free_dims = ops.convert_to_tensor(a_free_dims, dtype=dtypes.int32)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in reshape(tensor, shape, name)
#     191     A `Tensor`. Has the same type as `tensor`.
#     192   """
# --> 193   result = gen_array_ops.reshape(tensor, shape, name)
#     194   tensor_util.maybe_set_static_shape(result, shape)
#     195   return result
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8073       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    8074         _ctx._context_handle, tld.device_name, "Reshape", name,
# -> 8075         tld.op_callbacks, tensor, shape)
#    8076       return _result
#    8077     except _core._FallbackException:
#
# KeyboardInterrupt:
