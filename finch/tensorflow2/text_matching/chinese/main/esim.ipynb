# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/text_matching/chinese/main')

# %%
# %tensorflow_version 2.x

# %%
import csv
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
import math

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0-rc2
# WARNING:tensorflow:From <ipython-input-3-21cf261602fd>:10: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(f_path):
  k2v = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      k2v[line] = i
  return k2v

# %%
# stream data from text files
def data_generator(f_path, char2idx):
  with open(f_path) as f:
    print('Reading', f_path)
    for i, line in enumerate(csv.reader(f, delimiter=',')):
      if i == 0:
        continue
      text1, text2, label = line
      text1 = [char2idx.get(c, len(char2idx)) for c in list(text1)]
      text2 = [char2idx.get(c, len(char2idx)) for c in list(text2)]
      yield ((text1, text2), int(label))


def dataset(is_training, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.int32, tf.int32), tf.int32)
  _pads = ((0, 0), -1)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
def masked_attention(x, align, mask, tile_len):
  pad = tf.fill(tf.shape(align), float('-inf'))
  mask = tf.tile(tf.expand_dims(mask, 1), [1, tile_len, 1])
  align = tf.where(tf.equal(mask, 0), pad, align)
  align = tf.nn.softmax(align)
  return tf.matmul(align, x)


def soft_align_attention(x1, x2, mask1, mask2):
  align12 = tf.matmul(x1, x2, transpose_b=True)
  align21 = tf.transpose(align12, [0,2,1])
  x1_ = masked_attention(x2, align12, mask2, tf.shape(x1)[1])
  x2_ = masked_attention(x1, align21, mask1, tf.shape(x2)[1])
  return x1_, x2_


class AttentivePooling(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dropout = tf.keras.layers.Dropout(.2)
    self.kernel = tf.keras.layers.Dense(units=1,
                                        activation=tf.tanh,
                                        use_bias=False)

  
  def call(self, inputs, training=False):
    x, masks = inputs
    # alignment
    align = tf.squeeze(self.kernel(self.dropout(x, training=training)), -1)
    # masking
    paddings = tf.fill(tf.shape(align), float('-inf'))
    align = tf.where(tf.equal(masks, 0), paddings, align)
    # probability
    align = tf.nn.softmax(align)
    align = tf.expand_dims(align, -1)
    # weighted sum
    return tf.squeeze(tf.matmul(x, align, transpose_a=True), -1)

# %%
class ESIM(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['embedding_path']), name='pretrained_embedding', dtype=tf.float32)
    
    self.input_dropout = tf.keras.layers.Dropout(.2)
    self.input_encoder = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['rnn_units'], return_sequences=True), name='input_encoder')
    
    self.feature_dropout = tf.keras.layers.Dropout(.5)
    self.feature_fc = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='feature_fc')
    
    self.revise_dropout = tf.keras.layers.Dropout(.2)
    self.revise_encoder = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['rnn_units'], return_sequences=True), name='revise_encoder')
    
    self.attentive_pooling = AttentivePooling(params)
    
    self.fc1_dropout = tf.keras.layers.Dropout(.5)
    self.fc1 = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='final_fc1')
    self.fc2_dropout = tf.keras.layers.Dropout(.2)
    self.fc2 = tf.keras.layers.Dense(params['rnn_units'], tf.nn.elu, name='final_fc2')
    
    self.out_linear = tf.keras.layers.Dense(1, name='out_linear')
  
  
  def call(self, inputs, training=False):
    x1, x2 = inputs
    
    if x1.dtype != tf.int32:
      x1 = tf.cast(x1, tf.int32)
    if x2.dtype != tf.int32:
      x2 = tf.cast(x2, tf.int32)
    
    batch_sz = tf.shape(x1)[0]
    
    mask1 = tf.sign(x1)
    mask2 = tf.sign(x2)
    
    x1 = tf.nn.embedding_lookup(self.embedding, x1)
    x2 = tf.nn.embedding_lookup(self.embedding, x2)
    
    self.input_dropout.noise_shape = (batch_sz, 1, 300)
    x1 = self.input_dropout(x1, training=training)
    x2 = self.input_dropout(x2, training=training)
    
    x1 = self.input_encoder(x1, mask=None)
    x2 = self.input_encoder(x2, mask=None)
    
    x1_, x2_ = soft_align_attention(x1, x2, mask1, mask2)
    aggregate_fn = lambda x, x_: tf.concat((x,
                                            x_,
                                           (x - x_),
                                           (x * x_),), -1)
    x1 = aggregate_fn(x1, x1_)
    x2 = aggregate_fn(x2, x2_)
    
    self.feature_dropout.noise_shape = (batch_sz, 1, params['rnn_units']*8)
    x1 = self.feature_dropout(x1, training=training)
    x2 = self.feature_dropout(x2, training=training)
    
    x1 = self.feature_fc(x1)
    x2 = self.feature_fc(x2)
    
    self.revise_dropout.noise_shape = (batch_sz, 1, params['rnn_units'])
    x1 = self.revise_dropout(x1, training=training)
    x2 = self.revise_dropout(x2, training=training)
    
    x1 = self.revise_encoder(x1, mask=None)
    x2 = self.revise_encoder(x2, mask=None)
    
    features = []
    features.append(tf.reduce_max(x1, axis=1))
    features.append(tf.reduce_max(x2, axis=1))
    features.append(self.attentive_pooling((x1, mask1), training=training))
    features.append(self.attentive_pooling((x2, mask2), training=training))
    x = tf.concat(features, axis=-1)
    
    x = self.fc1_dropout(x, training=training)
    x = self.fc1(x)
    
    x = self.fc2_dropout(x, training=training)
    x = self.fc2(x)
    
    x = self.out_linear(x)
    x = tf.squeeze(x, 1)
    
    return x

# %%
params = {
  'train_path': '../data/train.csv',
  'test_path': '../data/test.csv',
  'vocab_path': '../vocab/char.txt',
  'embedding_path': '../vocab/char.npy',
  'batch_size': 32,
  'buffer_size': 100000,
  'num_blocks': 2,
  'dropout_rate': 0.2,
  'rnn_units': 300,
  'lr': 4e-4,
  'clip_norm': 5.,
  'num_patience': 5,
}

# %%
def is_descending(history):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] <= history[i]:
      return False
  return True

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['vocab_size'] = len(params['char2idx']) + 1

model = ESIM(params)
model.build([[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = tf.optimizers.schedules.ExponentialDecay(params['lr'], 1000, 0.99)
optim = tf.optimizers.Adam(params['lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

while True:
  # TRAINING
  for ((text1, text2), labels) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      logits = model((text1, text2), training=True)
      loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.cast(labels, tf.float32), logits=logits)
      loss = tf.reduce_mean(loss)
      
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))
    
    if global_step % 100 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
  
  # EVALUATION
  m = tf.keras.metrics.Accuracy()

  for ((text1, text2), labels) in dataset(is_training=False, params=params):
    logits = tf.sigmoid(model((text1, text2), training=False))
    y_pred = tf.cast(tf.math.greater_equal(logits, .5), tf.int32)
    m.update_state(y_true=labels, y_pred=y_pred)

  acc = m.result().numpy()
  logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
  history_acc.append(acc)

  if acc > best_acc:
    best_acc = acc
    # you can save model here
  logger.info("Best Accuracy: {:.3f}".format(best_acc))

  if len(history_acc) > params['num_patience'] and is_descending(history_acc):
    logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# [('input_encoder/forward_lstm/lstm_cell_1/kernel:0', TensorShape([300, 1200])),
#  ('input_encoder/forward_lstm/lstm_cell_1/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('input_encoder/forward_lstm/lstm_cell_1/bias:0', TensorShape([1200])),
#  ('input_encoder/backward_lstm/lstm_cell_2/kernel:0', TensorShape([300, 1200])),
#  ('input_encoder/backward_lstm/lstm_cell_2/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('input_encoder/backward_lstm/lstm_cell_2/bias:0', TensorShape([1200])),
#  ('feature_fc/kernel:0', TensorShape([2400, 300])),
#  ('feature_fc/bias:0', TensorShape([300])),
#  ('revise_encoder/forward_lstm_1/lstm_cell_4/kernel:0',
#   TensorShape([300, 1200])),
#  ('revise_encoder/forward_lstm_1/lstm_cell_4/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('revise_encoder/forward_lstm_1/lstm_cell_4/bias:0', TensorShape([1200])),
#  ('revise_encoder/backward_lstm_1/lstm_cell_5/kernel:0',
#   TensorShape([300, 1200])),
#  ('revise_encoder/backward_lstm_1/lstm_cell_5/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('revise_encoder/backward_lstm_1/lstm_cell_5/bias:0', TensorShape([1200])),
#  ('attentive_pooling/dense/kernel:0', TensorShape([600, 1])),
#  ('final_fc1/kernel:0', TensorShape([2400, 300])),
#  ('final_fc1/bias:0', TensorShape([300])),
#  ('final_fc2/kernel:0', TensorShape([300, 300])),
#  ('final_fc2/bias:0', TensorShape([300])),
#  ('out_linear/kernel:0', TensorShape([300, 1])),
#  ('out_linear/bias:0', TensorShape([1])),
#  ('pretrained_embedding:0', TensorShape([1507, 300]))]
# Reading ../data/train.csv
# INFO:tensorflow:Step 0 | Loss: 0.6841 | Spent: 24.8 secs | LR: 0.000400
# INFO:tensorflow:Step 100 | Loss: 0.7320 | Spent: 9.3 secs | LR: 0.000400
# INFO:tensorflow:Step 200 | Loss: 0.6401 | Spent: 9.5 secs | LR: 0.000399
# INFO:tensorflow:Step 300 | Loss: 0.6755 | Spent: 9.3 secs | LR: 0.000399
# INFO:tensorflow:Step 400 | Loss: 0.6212 | Spent: 9.4 secs | LR: 0.000398
# INFO:tensorflow:Step 500 | Loss: 0.6340 | Spent: 9.2 secs | LR: 0.000398
# INFO:tensorflow:Step 600 | Loss: 0.5881 | Spent: 9.2 secs | LR: 0.000398
# INFO:tensorflow:Step 700 | Loss: 0.6741 | Spent: 9.4 secs | LR: 0.000397
# INFO:tensorflow:Step 800 | Loss: 0.5959 | Spent: 9.4 secs | LR: 0.000397
# INFO:tensorflow:Step 900 | Loss: 0.5975 | Spent: 9.2 secs | LR: 0.000396
# INFO:tensorflow:Step 1000 | Loss: 0.5643 | Spent: 9.3 secs | LR: 0.000396
# INFO:tensorflow:Step 1100 | Loss: 0.4190 | Spent: 9.2 secs | LR: 0.000396
# INFO:tensorflow:Step 1200 | Loss: 0.4824 | Spent: 9.5 secs | LR: 0.000395
# INFO:tensorflow:Step 1300 | Loss: 0.4583 | Spent: 9.5 secs | LR: 0.000395
# INFO:tensorflow:Step 1400 | Loss: 0.4552 | Spent: 9.3 secs | LR: 0.000394
# INFO:tensorflow:Step 1500 | Loss: 0.6604 | Spent: 9.4 secs | LR: 0.000394
# INFO:tensorflow:Step 1600 | Loss: 0.5551 | Spent: 9.7 secs | LR: 0.000394
# INFO:tensorflow:Step 1700 | Loss: 0.4134 | Spent: 9.3 secs | LR: 0.000393
# INFO:tensorflow:Step 1800 | Loss: 0.6244 | Spent: 9.4 secs | LR: 0.000393
# INFO:tensorflow:Step 1900 | Loss: 0.4830 | Spent: 9.2 secs | LR: 0.000392
# INFO:tensorflow:Step 2000 | Loss: 0.3524 | Spent: 9.1 secs | LR: 0.000392
# INFO:tensorflow:Step 2100 | Loss: 0.5051 | Spent: 9.2 secs | LR: 0.000392
# INFO:tensorflow:Step 2200 | Loss: 0.5199 | Spent: 9.1 secs | LR: 0.000391
# INFO:tensorflow:Step 2300 | Loss: 0.4495 | Spent: 9.5 secs | LR: 0.000391
# INFO:tensorflow:Step 2400 | Loss: 0.3090 | Spent: 9.4 secs | LR: 0.000390
# INFO:tensorflow:Step 2500 | Loss: 0.3472 | Spent: 9.0 secs | LR: 0.000390
# INFO:tensorflow:Step 2600 | Loss: 0.4881 | Spent: 9.1 secs | LR: 0.000390
# INFO:tensorflow:Step 2700 | Loss: 0.5600 | Spent: 9.2 secs | LR: 0.000389
# INFO:tensorflow:Step 2800 | Loss: 0.4023 | Spent: 9.1 secs | LR: 0.000389
# INFO:tensorflow:Step 2900 | Loss: 0.5817 | Spent: 9.4 secs | LR: 0.000389
# INFO:tensorflow:Step 3000 | Loss: 0.4903 | Spent: 9.0 secs | LR: 0.000388
# INFO:tensorflow:Step 3100 | Loss: 0.5683 | Spent: 9.2 secs | LR: 0.000388
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.780
# INFO:tensorflow:Best Accuracy: 0.780
# Reading ../data/train.csv
# INFO:tensorflow:Step 3200 | Loss: 0.3659 | Spent: 40.2 secs | LR: 0.000387
# INFO:tensorflow:Step 3300 | Loss: 0.4041 | Spent: 8.8 secs | LR: 0.000387
# INFO:tensorflow:Step 3400 | Loss: 0.4407 | Spent: 8.8 secs | LR: 0.000387
# INFO:tensorflow:Step 3500 | Loss: 0.5475 | Spent: 8.9 secs | LR: 0.000386
# INFO:tensorflow:Step 3600 | Loss: 0.4248 | Spent: 9.0 secs | LR: 0.000386
# INFO:tensorflow:Step 3700 | Loss: 0.2836 | Spent: 8.6 secs | LR: 0.000385
# INFO:tensorflow:Step 3800 | Loss: 0.4810 | Spent: 9.0 secs | LR: 0.000385
# INFO:tensorflow:Step 3900 | Loss: 0.5372 | Spent: 9.1 secs | LR: 0.000385
# INFO:tensorflow:Step 4000 | Loss: 0.4897 | Spent: 8.6 secs | LR: 0.000384
# INFO:tensorflow:Step 4100 | Loss: 0.3732 | Spent: 8.9 secs | LR: 0.000384
# INFO:tensorflow:Step 4200 | Loss: 0.3227 | Spent: 8.9 secs | LR: 0.000383
# INFO:tensorflow:Step 4300 | Loss: 0.2903 | Spent: 8.7 secs | LR: 0.000383
# INFO:tensorflow:Step 4400 | Loss: 0.4616 | Spent: 9.0 secs | LR: 0.000383
# INFO:tensorflow:Step 4500 | Loss: 0.3089 | Spent: 9.1 secs | LR: 0.000382
# INFO:tensorflow:Step 4600 | Loss: 0.3412 | Spent: 9.2 secs | LR: 0.000382
# INFO:tensorflow:Step 4700 | Loss: 0.3846 | Spent: 8.7 secs | LR: 0.000382
# INFO:tensorflow:Step 4800 | Loss: 0.3115 | Spent: 8.9 secs | LR: 0.000381
# INFO:tensorflow:Step 4900 | Loss: 0.3886 | Spent: 9.0 secs | LR: 0.000381
# INFO:tensorflow:Step 5000 | Loss: 0.4474 | Spent: 8.8 secs | LR: 0.000380
# INFO:tensorflow:Step 5100 | Loss: 0.4834 | Spent: 9.2 secs | LR: 0.000380
# INFO:tensorflow:Step 5200 | Loss: 0.3132 | Spent: 8.8 secs | LR: 0.000380
# INFO:tensorflow:Step 5300 | Loss: 0.3833 | Spent: 9.1 secs | LR: 0.000379
# INFO:tensorflow:Step 5400 | Loss: 0.5503 | Spent: 9.0 secs | LR: 0.000379
# INFO:tensorflow:Step 5500 | Loss: 0.4177 | Spent: 9.1 secs | LR: 0.000378
# INFO:tensorflow:Step 5600 | Loss: 0.3546 | Spent: 8.8 secs | LR: 0.000378
# INFO:tensorflow:Step 5700 | Loss: 0.5184 | Spent: 9.0 secs | LR: 0.000378
# INFO:tensorflow:Step 5800 | Loss: 0.3253 | Spent: 9.1 secs | LR: 0.000377
# INFO:tensorflow:Step 5900 | Loss: 0.4551 | Spent: 9.3 secs | LR: 0.000377
# INFO:tensorflow:Step 6000 | Loss: 0.4636 | Spent: 9.1 secs | LR: 0.000377
# INFO:tensorflow:Step 6100 | Loss: 0.4508 | Spent: 8.8 secs | LR: 0.000376
# INFO:tensorflow:Step 6200 | Loss: 0.2698 | Spent: 9.0 secs | LR: 0.000376
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.804
# INFO:tensorflow:Best Accuracy: 0.804
# Reading ../data/train.csv
# INFO:tensorflow:Step 6300 | Loss: 0.2677 | Spent: 40.1 secs | LR: 0.000375
# INFO:tensorflow:Step 6400 | Loss: 0.4421 | Spent: 9.1 secs | LR: 0.000375
# INFO:tensorflow:Step 6500 | Loss: 0.7539 | Spent: 9.0 secs | LR: 0.000375
# INFO:tensorflow:Step 6600 | Loss: 0.4459 | Spent: 9.3 secs | LR: 0.000374
# INFO:tensorflow:Step 6700 | Loss: 0.2990 | Spent: 9.1 secs | LR: 0.000374
# INFO:tensorflow:Step 6800 | Loss: 0.4059 | Spent: 9.1 secs | LR: 0.000374
# INFO:tensorflow:Step 6900 | Loss: 0.3484 | Spent: 9.1 secs | LR: 0.000373
# INFO:tensorflow:Step 7000 | Loss: 0.2294 | Spent: 9.0 secs | LR: 0.000373
# INFO:tensorflow:Step 7100 | Loss: 0.4104 | Spent: 9.0 secs | LR: 0.000372
# INFO:tensorflow:Step 7200 | Loss: 0.2434 | Spent: 9.2 secs | LR: 0.000372
# INFO:tensorflow:Step 7300 | Loss: 0.4909 | Spent: 9.1 secs | LR: 0.000372
# INFO:tensorflow:Step 7400 | Loss: 0.5091 | Spent: 9.1 secs | LR: 0.000371
# INFO:tensorflow:Step 7500 | Loss: 0.6222 | Spent: 9.0 secs | LR: 0.000371
# INFO:tensorflow:Step 7600 | Loss: 0.2672 | Spent: 8.9 secs | LR: 0.000371
# INFO:tensorflow:Step 7700 | Loss: 0.4611 | Spent: 8.8 secs | LR: 0.000370
# INFO:tensorflow:Step 7800 | Loss: 0.2574 | Spent: 8.9 secs | LR: 0.000370
# INFO:tensorflow:Step 7900 | Loss: 0.6709 | Spent: 9.2 secs | LR: 0.000369
# INFO:tensorflow:Step 8000 | Loss: 0.3562 | Spent: 9.3 secs | LR: 0.000369
# INFO:tensorflow:Step 8100 | Loss: 0.2554 | Spent: 9.5 secs | LR: 0.000369
# INFO:tensorflow:Step 8200 | Loss: 0.2461 | Spent: 9.8 secs | LR: 0.000368
# INFO:tensorflow:Step 8300 | Loss: 0.4612 | Spent: 9.2 secs | LR: 0.000368
# INFO:tensorflow:Step 17500 | Loss: 0.1970 | Spent: 9.0 secs | LR: 0.000335
# INFO:tensorflow:Step 17600 | Loss: 0.1614 | Spent: 9.1 secs | LR: 0.000335
# INFO:tensorflow:Step 17700 | Loss: 0.2044 | Spent: 9.3 secs | LR: 0.000335
# INFO:tensorflow:Step 17800 | Loss: 0.2805 | Spent: 9.1 secs | LR: 0.000334
# INFO:tensorflow:Step 17900 | Loss: 0.4554 | Spent: 8.8 secs | LR: 0.000334
# INFO:tensorflow:Step 18000 | Loss: 0.1851 | Spent: 8.8 secs | LR: 0.000334
# INFO:tensorflow:Step 18100 | Loss: 0.1534 | Spent: 8.8 secs | LR: 0.000333
# INFO:tensorflow:Step 18200 | Loss: 0.2754 | Spent: 8.9 secs | LR: 0.000333
# INFO:tensorflow:Step 18300 | Loss: 0.0899 | Spent: 8.9 secs | LR: 0.000333
# INFO:tensorflow:Step 18400 | Loss: 0.1418 | Spent: 9.2 secs | LR: 0.000332
# INFO:tensorflow:Step 18500 | Loss: 0.2178 | Spent: 8.8 secs | LR: 0.000332
# INFO:tensorflow:Step 18600 | Loss: 0.1270 | Spent: 9.0 secs | LR: 0.000332
# INFO:tensorflow:Step 18700 | Loss: 0.2388 | Spent: 8.6 secs | LR: 0.000331
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.820
# INFO:tensorflow:Best Accuracy: 0.820
# Reading ../data/train.csv
# INFO:tensorflow:Step 18800 | Loss: 0.3505 | Spent: 39.3 secs | LR: 0.000331
# INFO:tensorflow:Step 18900 | Loss: 0.0594 | Spent: 8.9 secs | LR: 0.000331
# INFO:tensorflow:Step 19000 | Loss: 0.1571 | Spent: 8.9 secs | LR: 0.000330
# INFO:tensorflow:Step 19100 | Loss: 0.2780 | Spent: 9.1 secs | LR: 0.000330
# INFO:tensorflow:Step 19200 | Loss: 0.3990 | Spent: 8.9 secs | LR: 0.000330
# INFO:tensorflow:Step 19300 | Loss: 0.1924 | Spent: 9.1 secs | LR: 0.000329
# INFO:tensorflow:Step 19400 | Loss: 0.1587 | Spent: 9.2 secs | LR: 0.000329
# INFO:tensorflow:Step 19500 | Loss: 0.1796 | Spent: 8.9 secs | LR: 0.000329
# INFO:tensorflow:Step 19600 | Loss: 0.0844 | Spent: 9.0 secs | LR: 0.000328
# INFO:tensorflow:Step 19700 | Loss: 0.1665 | Spent: 8.8 secs | LR: 0.000328
# INFO:tensorflow:Step 19800 | Loss: 0.0629 | Spent: 9.0 secs | LR: 0.000328
# INFO:tensorflow:Step 19900 | Loss: 0.1209 | Spent: 9.2 secs | LR: 0.000327
# INFO:tensorflow:Step 20000 | Loss: 0.2404 | Spent: 8.7 secs | LR: 0.000327
# INFO:tensorflow:Step 20100 | Loss: 0.3060 | Spent: 9.3 secs | LR: 0.000327
# INFO:tensorflow:Step 20200 | Loss: 0.2368 | Spent: 9.0 secs | LR: 0.000327
# INFO:tensorflow:Step 20300 | Loss: 0.1224 | Spent: 8.8 secs | LR: 0.000326
# INFO:tensorflow:Step 20400 | Loss: 0.0578 | Spent: 9.0 secs | LR: 0.000326
# INFO:tensorflow:Step 20500 | Loss: 0.1921 | Spent: 8.8 secs | LR: 0.000326
# INFO:tensorflow:Step 55000 | Loss: 0.0329 | Spent: 9.5 secs | LR: 0.000230
# INFO:tensorflow:Step 55100 | Loss: 0.0141 | Spent: 9.1 secs | LR: 0.000230
# INFO:tensorflow:Step 55200 | Loss: 0.0097 | Spent: 9.3 secs | LR: 0.000230
# INFO:tensorflow:Step 55300 | Loss: 0.0159 | Spent: 9.1 secs | LR: 0.000229
# INFO:tensorflow:Step 55400 | Loss: 0.0110 | Spent: 9.1 secs | LR: 0.000229
# INFO:tensorflow:Step 55500 | Loss: 0.0068 | Spent: 9.0 secs | LR: 0.000229
# INFO:tensorflow:Step 55600 | Loss: 0.0207 | Spent: 9.4 secs | LR: 0.000229
# INFO:tensorflow:Step 55700 | Loss: 0.0077 | Spent: 9.3 secs | LR: 0.000229
# INFO:tensorflow:Step 55800 | Loss: 0.0135 | Spent: 9.3 secs | LR: 0.000228
# INFO:tensorflow:Step 55900 | Loss: 0.0125 | Spent: 9.2 secs | LR: 0.000228
# INFO:tensorflow:Step 56000 | Loss: 0.0322 | Spent: 9.6 secs | LR: 0.000228
# INFO:tensorflow:Step 56100 | Loss: 0.0172 | Spent: 9.3 secs | LR: 0.000228
# INFO:tensorflow:Step 56200 | Loss: 0.0286 | Spent: 9.3 secs | LR: 0.000227
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.819
# INFO:tensorflow:Best Accuracy: 0.825
# Reading ../data/train.csv
# INFO:tensorflow:Step 56300 | Loss: 0.0805 | Spent: 41.4 secs | LR: 0.000227
# INFO:tensorflow:Step 56400 | Loss: 0.0328 | Spent: 9.4 secs | LR: 0.000227
# INFO:tensorflow:Step 56500 | Loss: 0.0451 | Spent: 9.4 secs | LR: 0.000227
# INFO:tensorflow:Step 56600 | Loss: 0.0038 | Spent: 9.2 secs | LR: 0.000226
# INFO:tensorflow:Step 56700 | Loss: 0.0178 | Spent: 9.6 secs | LR: 0.000226
# INFO:tensorflow:Step 56800 | Loss: 0.0033 | Spent: 9.0 secs | LR: 0.000226
# INFO:tensorflow:Step 56900 | Loss: 0.0682 | Spent: 9.4 secs | LR: 0.000226
# INFO:tensorflow:Step 57000 | Loss: 0.0028 | Spent: 9.5 secs | LR: 0.000226
# INFO:tensorflow:Step 57100 | Loss: 0.0161 | Spent: 9.4 secs | LR: 0.000225
# INFO:tensorflow:Step 57200 | Loss: 0.0033 | Spent: 9.8 secs | LR: 0.000225
# INFO:tensorflow:Step 57300 | Loss: 0.0146 | Spent: 9.4 secs | LR: 0.000225
# INFO:tensorflow:Step 57400 | Loss: 0.1091 | Spent: 9.6 secs | LR: 0.000225
# INFO:tensorflow:Step 57500 | Loss: 0.0303 | Spent: 9.8 secs | LR: 0.000224
# INFO:tensorflow:Step 57600 | Loss: 0.0184 | Spent: 9.7 secs | LR: 0.000224
# INFO:tensorflow:Step 57700 | Loss: 0.0702 | Spent: 9.5 secs | LR: 0.000224
# INFO:tensorflow:Step 57800 | Loss: 0.0662 | Spent: 9.3 secs | LR: 0.000224
# INFO:tensorflow:Step 57900 | Loss: 0.0056 | Spent: 9.8 secs | LR: 0.000224
# INFO:tensorflow:Step 58000 | Loss: 0.0284 | Spent: 9.4 secs | LR: 0.000223
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.821
# INFO:tensorflow:Best Accuracy: 0.825
# Reading ../data/train.csv
# INFO:tensorflow:Step 90700 | Loss: 0.0017 | Spent: 41.4 secs | LR: 0.000161
# INFO:tensorflow:Step 90800 | Loss: 0.0011 | Spent: 9.2 secs | LR: 0.000161
# INFO:tensorflow:Step 90900 | Loss: 0.0007 | Spent: 9.4 secs | LR: 0.000160
# INFO:tensorflow:Step 91000 | Loss: 0.0012 | Spent: 9.5 secs | LR: 0.000160
# INFO:tensorflow:Step 91100 | Loss: 0.0001 | Spent: 9.2 secs | LR: 0.000160
# INFO:tensorflow:Step 91200 | Loss: 0.0003 | Spent: 9.3 secs | LR: 0.000160
# INFO:tensorflow:Step 91300 | Loss: 0.0174 | Spent: 9.6 secs | LR: 0.000160
# INFO:tensorflow:Step 91400 | Loss: 0.0045 | Spent: 9.1 secs | LR: 0.000160
# INFO:tensorflow:Step 91500 | Loss: 0.0036 | Spent: 9.2 secs | LR: 0.000159
# INFO:tensorflow:Step 91600 | Loss: 0.0008 | Spent: 9.2 secs | LR: 0.000159
# INFO:tensorflow:Step 91700 | Loss: 0.1255 | Spent: 9.3 secs | LR: 0.000159
# INFO:tensorflow:Step 91800 | Loss: 0.0359 | Spent: 9.0 secs | LR: 0.000159
# INFO:tensorflow:Step 91900 | Loss: 0.0207 | Spent: 9.4 secs | LR: 0.000159
# INFO:tensorflow:Step 92000 | Loss: 0.0001 | Spent: 9.3 secs | LR: 0.000159
# INFO:tensorflow:Step 92100 | Loss: 0.0002 | Spent: 9.4 secs | LR: 0.000159
# INFO:tensorflow:Step 92200 | Loss: 0.0036 | Spent: 9.2 secs | LR: 0.000158
# INFO:tensorflow:Step 92300 | Loss: 0.0005 | Spent: 9.2 secs | LR: 0.000158
# INFO:tensorflow:Step 92400 | Loss: 0.0008 | Spent: 9.3 secs | LR: 0.000158
# INFO:tensorflow:Step 92500 | Loss: 0.0020 | Spent: 9.2 secs | LR: 0.000158
# INFO:tensorflow:Step 92600 | Loss: 0.0001 | Spent: 9.2 secs | LR: 0.000158
# INFO:tensorflow:Step 92700 | Loss: 0.0254 | Spent: 9.4 secs | LR: 0.000158
# INFO:tensorflow:Step 92800 | Loss: 0.0015 | Spent: 9.3 secs | LR: 0.000157
# INFO:tensorflow:Step 92900 | Loss: 0.0064 | Spent: 9.2 secs | LR: 0.000157
# INFO:tensorflow:Step 93000 | Loss: 0.0049 | Spent: 9.1 secs | LR: 0.000157
# INFO:tensorflow:Step 93100 | Loss: 0.0253 | Spent: 9.1 secs | LR: 0.000157
# INFO:tensorflow:Step 93200 | Loss: 0.0039 | Spent: 9.2 secs | LR: 0.000157
# INFO:tensorflow:Step 93300 | Loss: 0.0011 | Spent: 9.5 secs | LR: 0.000157
# INFO:tensorflow:Step 93400 | Loss: 0.0007 | Spent: 9.4 secs | LR: 0.000156
# INFO:tensorflow:Step 93500 | Loss: 0.0278 | Spent: 9.8 secs | LR: 0.000156
# INFO:tensorflow:Step 93600 | Loss: 0.0006 | Spent: 9.3 secs | LR: 0.000156
# INFO:tensorflow:Step 93700 | Loss: 0.0101 | Spent: 9.4 secs | LR: 0.000156
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.822
# INFO:tensorflow:Best Accuracy: 0.825
# Reading ../data/train.csv
# INFO:tensorflow:Step 93800 | Loss: 0.0006 | Spent: 41.4 secs | LR: 0.000156
# INFO:tensorflow:Step 93900 | Loss: 0.0032 | Spent: 9.2 secs | LR: 0.000156
# INFO:tensorflow:Step 94000 | Loss: 0.0058 | Spent: 9.4 secs | LR: 0.000156
# INFO:tensorflow:Step 94100 | Loss: 0.0004 | Spent: 9.5 secs | LR: 0.000155
# INFO:tensorflow:Step 94200 | Loss: 0.0040 | Spent: 9.4 secs | LR: 0.000155
# INFO:tensorflow:Step 94300 | Loss: 0.0009 | Spent: 9.5 secs | LR: 0.000155
# INFO:tensorflow:Step 94400 | Loss: 0.0125 | Spent: 9.6 secs | LR: 0.000155
# INFO:tensorflow:Step 94500 | Loss: 0.0012 | Spent: 9.3 secs | LR: 0.000155
# INFO:tensorflow:Step 94600 | Loss: 0.0407 | Spent: 9.2 secs | LR: 0.000155
# INFO:tensorflow:Step 94700 | Loss: 0.0002 | Spent: 9.3 secs | LR: 0.000154
# INFO:tensorflow:Step 94800 | Loss: 0.0001 | Spent: 9.6 secs | LR: 0.000154
# INFO:tensorflow:Step 94900 | Loss: 0.1763 | Spent: 9.3 secs | LR: 0.000154
# INFO:tensorflow:Step 95000 | Loss: 0.0640 | Spent: 9.3 secs | LR: 0.000154
# INFO:tensorflow:Step 95100 | Loss: 0.0013 | Spent: 9.4 secs | LR: 0.000154
# INFO:tensorflow:Step 95200 | Loss: 0.0034 | Spent: 9.3 secs | LR: 0.000154
# INFO:tensorflow:Step 95300 | Loss: 0.0387 | Spent: 9.3 secs | LR: 0.000153
# INFO:tensorflow:Step 95400 | Loss: 0.0447 | Spent: 9.3 secs | LR: 0.000153
# INFO:tensorflow:Step 95500 | Loss: 0.0309 | Spent: 9.2 secs | LR: 0.000153
# INFO:tensorflow:Step 95600 | Loss: 0.0032 | Spent: 9.4 secs | LR: 0.000153
# INFO:tensorflow:Step 95700 | Loss: 0.0037 | Spent: 9.5 secs | LR: 0.000153
# INFO:tensorflow:Step 95800 | Loss: 0.0007 | Spent: 9.4 secs | LR: 0.000153
# INFO:tensorflow:Step 95900 | Loss: 0.0012 | Spent: 9.5 secs | LR: 0.000153
# INFO:tensorflow:Step 96000 | Loss: 0.0204 | Spent: 9.5 secs | LR: 0.000152
# INFO:tensorflow:Step 96100 | Loss: 0.0035 | Spent: 9.3 secs | LR: 0.000152
# INFO:tensorflow:Step 96200 | Loss: 0.0059 | Spent: 9.3 secs | LR: 0.000152
# INFO:tensorflow:Step 96300 | Loss: 0.0272 | Spent: 9.3 secs | LR: 0.000152
# INFO:tensorflow:Step 96400 | Loss: 0.0004 | Spent: 9.7 secs | LR: 0.000152
# INFO:tensorflow:Step 96500 | Loss: 0.0005 | Spent: 9.5 secs | LR: 0.000152
# INFO:tensorflow:Step 96600 | Loss: 0.0178 | Spent: 9.4 secs | LR: 0.000152
# INFO:tensorflow:Step 96700 | Loss: 0.0196 | Spent: 9.5 secs | LR: 0.000151
# INFO:tensorflow:Step 96800 | Loss: 0.0013 | Spent: 9.4 secs | LR: 0.000151
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.817
# INFO:tensorflow:Best Accuracy: 0.825
# Reading ../data/train.csv
# INFO:tensorflow:Step
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.821
# INFO:tensorflow:Best Accuracy: 0.825
# Reading ../data/train.csv
# INFO:tensorflow:Step 100000 | Loss: 0.0037 | Spent: 40.7 secs | LR: 0.000146
# INFO:tensorflow:Step 100100 | Loss: 0.0005 | Spent: 9.3 secs | LR: 0.000146
# INFO:tensorflow:Step 100200 | Loss: 0.0002 | Spent: 9.6 secs | LR: 0.000146
# INFO:tensorflow:Step 100300 | Loss: 0.0003 | Spent: 9.3 secs | LR: 0.000146
# INFO:tensorflow:Step 100400 | Loss: 0.0005 | Spent: 9.5 secs | LR: 0.000146
# INFO:tensorflow:Step 100500 | Loss: 0.0089 | Spent: 9.6 secs | LR: 0.000146
# INFO:tensorflow:Step 100600 | Loss: 0.0045 | Spent: 9.4 secs | LR: 0.000146
# INFO:tensorflow:Step 100700 | Loss: 0.0030 | Spent: 9.3 secs | LR: 0.000145
# INFO:tensorflow:Step 100800 | Loss: 0.0939 | Spent: 9.3 secs | LR: 0.000145
# INFO:tensorflow:Step 100900 | Loss: 0.0010 | Spent: 9.5 secs | LR: 0.000145
# INFO:tensorflow:Step 101000 | Loss: 0.0035 | Spent: 9.6 secs | LR: 0.000145
# INFO:tensorflow:Step 101100 | Loss: 0.0376 | Spent: 9.4 secs | LR: 0.000145
# INFO:tensorflow:Step 101200 | Loss: 0.0226 | Spent: 9.8 secs | LR: 0.000145
# INFO:tensorflow:Step 101300 | Loss: 0.0689 | Spent: 9.3 secs | LR: 0.000145
# INFO:tensorflow:Step 101400 | Loss: 0.0281 | Spent: 9.3 secs | LR: 0.000144
# INFO:tensorflow:Step 101500 | Loss: 0.0063 | Spent: 9.6 secs | LR: 0.000144
# INFO:tensorflow:Step 101600 | Loss: 0.0345 | Spent: 9.3 secs | LR: 0.000144
# INFO:tensorflow:Step 101700 | Loss: 0.0005 | Spent: 9.5 secs | LR: 0.000144
# INFO:tensorflow:Step 101800 | Loss: 0.0008 | Spent: 9.3 secs | LR: 0.000144
# INFO:tensorflow:Step 101900 | Loss: 0.0021 | Spent: 9.3 secs | LR: 0.000144
# INFO:tensorflow:Step 102000 | Loss: 0.0081 | Spent: 9.2 secs | LR: 0.000143
# INFO:tensorflow:Step 102100 | Loss: 0.0007 | Spent: 9.0 secs | LR: 0.000143
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b3611aad071d> in <module>()
#      26
#      27     optim.lr.assign(decay_lr(global_step))
# ---> 28     grads = tape.gradient(loss, model.trainable_variables)
#      29     grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
#      30     optim.apply_gradients(zip(grads, model.trainable_variables))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1046         output_gradients=output_gradients,
#    1047         sources_raw=flat_sources_raw,
# -> 1048         unconnected_gradients=unconnected_gradients)
#    1049
#    1050     if not self._persistent:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155       gradient_name_scope = "gradient_tape/"
#     156     with ops.name_scope(gradient_name_scope):
# --> 157       return grad_fn(mock_op, *out_grads)
#     158   else:
#     159     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py in _TransposeGrad(op, grad)
#     783   """Returns unshuffle(grad)."""
#     784   p = op.inputs[1]
# --> 785   return [array_ops.transpose(grad, array_ops.invert_permutation(p)), None]
#     786
#     787
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in transpose(a, perm, name, conjugate)
#    2120
#    2121     if perm is not None:
# -> 2122       return transpose_fn(a, perm, name=name)
#    2123
#    2124     rank = a.shape.rank
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_array_ops.py in transpose(x, perm, name)
#   11167       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   11168         _ctx._context_handle, tld.device_name, "Transpose", name,
# > 11169         tld.op_callbacks, x, perm)
#   11170       return _result
#   11171     except _core._FallbackException:
#
# KeyboardInterrupt:
