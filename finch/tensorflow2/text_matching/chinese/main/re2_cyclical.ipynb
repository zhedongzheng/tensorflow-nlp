# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/text_matching/chinese/main')

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
import csv
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
import math

from tensorflow_addons.optimizers.cyclical_learning_rate import CyclicalLearningRate

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0-rc2
# WARNING:tensorflow:From <ipython-input-3-24f82ec5174c>:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(f_path):
  k2v = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      k2v[line] = i
  return k2v

# %%
# stream data from text files
def data_generator(f_path, char2idx):
  with open(f_path) as f:
    print('Reading', f_path)
    for i, line in enumerate(csv.reader(f, delimiter=',')):
      if i == 0:
        continue
      text1, text2, label = line
      text1 = [char2idx.get(c, len(char2idx)) for c in list(text1)]
      text2 = [char2idx.get(c, len(char2idx)) for c in list(text2)]
      yield ((text1, text2), int(label))


def dataset(is_training, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.int32, tf.int32), tf.int32)
  _pads = ((0, 0), -1)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
class RE2(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    
    self.pretrained_embedding = tf.Variable(np.load(params['embedding_path']), name='pretrained_embedding', dtype=tf.float32)
    self.embed_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.birnn = [tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['hidden_size'], return_sequences=True), name='birnn_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.enc_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.align_t = self.add_weight(name='temperature',
                                   shape=(),
                                   trainable=True,
                                   initializer=tf.initializers.constant(math.sqrt(1/params['hidden_size'])))
    self.align_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.align_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.align_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
      
    self.fusion_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc3 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc3_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc4 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc4_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.out_drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_fc = tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='out_fc')
    self.out_drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(1, name='out_linear')
    
  
  
  def call(self, inputs, training=False):
    x1, x2 = inputs
    
    if x1.dtype != tf.int32:
      x1 = tf.cast(x1, tf.int32)
    if x2.dtype != tf.int32:
      x2 = tf.cast(x2, tf.int32)
    
    batch_sz = tf.shape(x1)[0]
    
    mask1 = tf.sign(x1)
    mask2 = tf.sign(x2)
    
    x1 = self.embedding(x1, training=training)
    x2 = self.embedding(x2, training=training)
    
    res_x1, res_x2 = x1, x2
    
    for i in range(params['num_blocks']):
      
      if i > 0:
        x1 = self.connection(x1, res_x1, i)
        x2 = self.connection(x2, res_x2, i)
        res_x1, res_x2 = x1, x2
    
      x1_enc = self.encoding(x1, mask1, i, training=training)
      x2_enc = self.encoding(x2, mask2, i, training=training)
    
      x1 = tf.concat((x1, x1_enc), -1)
      x2 = tf.concat((x2, x2_enc), -1)
      
      align_1, align_2 = self.alignment(x1, x2, mask1, mask2, i, training=training)
      
      x1 = self.fusion(x1, align_1, i, training=training)
      x2 = self.fusion(x2, align_2, i, training=training)
    
    x1 = self.pooling(x1, mask1)
    x2 = self.pooling(x2, mask2)
    
    x = self.prediction(x1, x2, training=training)
    
    return x
  
  
  def embedding(self, x, training):
    x = tf.nn.embedding_lookup(self.pretrained_embedding, x)
    x = self.embed_dropout(x, training=training)
    return x
  
  
  def connection(self, x, res, i):
    if i == 1:
      x = tf.concat((res, x), -1)
    elif i > 1:
      hidden_size = x.shape[-1]
      x = (res[:, :, -hidden_size:] + x) * tf.math.sqrt(0.5)
      x = tf.concat((res[:, :, :-hidden_size], x), -1)
    return x
    
    
  def encoding(self, x, mask, i, training):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    x *= mask
    x = self.birnn[i](x)
    x = self.enc_dropout(x, training=training)
    return x
  
  
  def alignment(self, x1, x2, mask1, mask2, i, training):
    mask1 = tf.cast(tf.expand_dims(mask1, -1), tf.float32)
    mask2 = tf.cast(tf.expand_dims(mask2, -1), tf.float32)
    
    x1_ = self.align_fc1[i](self.align_dropout(x1, training=training))
    x2_ = self.align_fc2[i](self.align_dropout(x2, training=training))
    align = tf.matmul(x1_, x2_, transpose_b=True) * self.align_t
    mask = tf.matmul(mask1, mask2, transpose_b=True)
    align = mask * align + (1 - mask) * tf.float32.min
    align_1 = tf.nn.softmax(align, 1)
    align_2 = tf.nn.softmax(align, 2)
    
    x2 = tf.matmul(align_1, x1, transpose_a=True)
    x1 = tf.matmul(align_2, x2)
    return x1, x2
  
  
  def fusion(self, x, align, i, training):
    x = tf.concat([self.fusion_fc1[i](tf.concat((x, align), -1)),
                   self.fusion_fc2[i](tf.concat((x, x - align), -1)),
                   self.fusion_fc3[i](tf.concat((x, x * align), -1))], -1)
    x = self.fusion_dropout(x, training=training)
    x = self.fusion_fc4[i](x)
    return x
  
  
  def pooling(self, x, mask):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    return tf.reduce_max(x * mask, 1)
  
  
  def prediction(self, x1, x2, training):
    x = tf.concat((x1, x2, x1 * x2, x1 - x2), -1)
    x = self.out_drop1(x, training=training)
    x = self.out_fc(x)
    x = self.out_drop2(x, training=training)
    x = self.out_linear(x)
    x = tf.squeeze(x, 1)
    return x

# %%
params = {
  'train_path': '../data/train.csv',
  'test_path': '../data/test.csv',
  'vocab_path': '../vocab/char.txt',
  'embedding_path': '../vocab/char.npy',
  'batch_size': 32,
  'buffer_size': 100000,
  'num_blocks': 2,
  'dropout_rate': 0.2,
  'hidden_size': 300,
  'activation': tf.nn.relu,
  'init_lr': 1e-4,
  'max_lr': 1e-3,
  'clip_norm': 5.,
  'num_patience': 5,
}

# %%
def is_descending(history):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] <= history[i]:
      return False
  return True

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['vocab_size'] = len(params['char2idx']) + 1

model = RE2(params)
model.build([[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = CyclicalLearningRate(
  initial_learning_rate=params['init_lr'],
  maximal_learning_rate=params['max_lr'],
  step_size=6000,
  scale_fn=lambda x: 1.,
  scale_mode='cycle',)
optim = tf.optimizers.Adam(params['init_lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

while True:
  # TRAINING
  for ((text1, text2), labels) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      logits = model((text1, text2), training=True)
      loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.cast(labels, tf.float32), logits=logits)
      loss = tf.reduce_mean(loss)
      
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))
    
    if global_step % 100 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
  
  # EVALUATION
  m = tf.keras.metrics.Accuracy()

  for ((text1, text2), labels) in dataset(is_training=False, params=params):
    logits = tf.sigmoid(model((text1, text2), training=False))
    y_pred = tf.cast(tf.math.greater_equal(logits, .5), tf.int32)
    m.update_state(y_true=labels, y_pred=y_pred)

  acc = m.result().numpy()
  logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
  history_acc.append(acc)

  if acc > best_acc:
    best_acc = acc
    # you can save model here
  logger.info("Best Accuracy: {:.3f}".format(best_acc))

  if len(history_acc) > params['num_patience'] and is_descending(history_acc):
    logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# [('birnn_1/forward_lstm_4/lstm_cell_13/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm_4/lstm_cell_13/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm_4/lstm_cell_13/bias:0', TensorShape([1200])),
#  ('birnn_1/backward_lstm_4/lstm_cell_14/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm_4/lstm_cell_14/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm_4/lstm_cell_14/bias:0', TensorShape([1200])),
#  ('birnn_2/forward_lstm_5/lstm_cell_16/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/forward_lstm_5/lstm_cell_16/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/forward_lstm_5/lstm_cell_16/bias:0', TensorShape([1200])),
#  ('birnn_2/backward_lstm_5/lstm_cell_17/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/backward_lstm_5/lstm_cell_17/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/backward_lstm_5/lstm_cell_17/bias:0', TensorShape([1200])),
#  ('align_fc1_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc1_1/bias:0', TensorShape([300])),
#  ('align_fc1_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc1_2/bias:0', TensorShape([300])),
#  ('align_fc2_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc2_1/bias:0', TensorShape([300])),
#  ('align_fc2_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc1_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc1_1/bias:0', TensorShape([300])),
#  ('fusion_fc1_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc1_2/bias:0', TensorShape([300])),
#  ('fusion_fc2_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc2_1/bias:0', TensorShape([300])),
#  ('fusion_fc2_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc3_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc3_1/bias:0', TensorShape([300])),
#  ('fusion_fc3_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc3_2/bias:0', TensorShape([300])),
#  ('fusion_fc4_1/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_1/bias:0', TensorShape([300])),
#  ('fusion_fc4_2/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_2/bias:0', TensorShape([300])),
#  ('out_fc/kernel:0', TensorShape([1200, 300])),
#  ('out_fc/bias:0', TensorShape([300])),
#  ('out_linear/kernel:0', TensorShape([300, 1])),
#  ('out_linear/bias:0', TensorShape([1])),
#  ('pretrained_embedding:0', TensorShape([1507, 300])),
#  ('temperature:0', TensorShape([]))]
# Reading ../data/train.csv
# INFO:tensorflow:Step 0 | Loss: 0.7036 | Spent: 15.7 secs | LR: 0.000100
# INFO:tensorflow:Step 100 | Loss: 0.7125 | Spent: 13.4 secs | LR: 0.000115
# INFO:tensorflow:Step 200 | Loss: 0.7233 | Spent: 13.6 secs | LR: 0.000130
# INFO:tensorflow:Step 300 | Loss: 0.6924 | Spent: 13.4 secs | LR: 0.000145
# INFO:tensorflow:Step 400 | Loss: 0.6303 | Spent: 13.6 secs | LR: 0.000160
# INFO:tensorflow:Step 500 | Loss: 0.7363 | Spent: 13.8 secs | LR: 0.000175
# INFO:tensorflow:Step 600 | Loss: 0.7124 | Spent: 13.1 secs | LR: 0.000190
# INFO:tensorflow:Step 700 | Loss: 0.5433 | Spent: 13.5 secs | LR: 0.000205
# INFO:tensorflow:Step 800 | Loss: 0.5671 | Spent: 13.3 secs | LR: 0.000220
# INFO:tensorflow:Step 900 | Loss: 0.8083 | Spent: 13.2 secs | LR: 0.000235
# INFO:tensorflow:Step 1000 | Loss: 0.5063 | Spent: 13.2 secs | LR: 0.000250
# INFO:tensorflow:Step 1100 | Loss: 0.5949 | Spent: 13.4 secs | LR: 0.000265
# INFO:tensorflow:Step 1200 | Loss: 0.5327 | Spent: 13.5 secs | LR: 0.000280
# INFO:tensorflow:Step 1300 | Loss: 0.5779 | Spent: 13.9 secs | LR: 0.000295
# INFO:tensorflow:Step 7400 | Loss: 0.3294 | Spent: 14.1 secs | LR: 0.000790
# INFO:tensorflow:Step 7500 | Loss: 0.2680 | Spent: 14.0 secs | LR: 0.000775
# INFO:tensorflow:Step 7600 | Loss: 0.2871 | Spent: 14.1 secs | LR: 0.000760
# INFO:tensorflow:Step 7700 | Loss: 0.3871 | Spent: 14.3 secs | LR: 0.000745
# INFO:tensorflow:Step 7800 | Loss: 0.3279 | Spent: 14.4 secs | LR: 0.000730
# INFO:tensorflow:Step 7900 | Loss: 0.5410 | Spent: 14.1 secs | LR: 0.000715
# INFO:tensorflow:Step 8000 | Loss: 0.1932 | Spent: 14.2 secs | LR: 0.000700
# INFO:tensorflow:Step 8100 | Loss: 0.5198 | Spent: 14.2 secs | LR: 0.000685
# INFO:tensorflow:Step 8200 | Loss: 0.3777 | Spent: 14.2 secs | LR: 0.000670
# INFO:tensorflow:Step 8300 | Loss: 0.1648 | Spent: 13.8 secs | LR: 0.000655
# INFO:tensorflow:Step 8400 | Loss: 0.2203 | Spent: 13.9 secs | LR: 0.000640
# INFO:tensorflow:Step 8500 | Loss: 0.2600 | Spent: 13.8 secs | LR: 0.000625
# INFO:tensorflow:Step 8600 | Loss: 0.3013 | Spent: 14.1 secs | LR: 0.000610
# INFO:tensorflow:Step 8700 | Loss: 0.3209 | Spent: 14.1 secs | LR: 0.000595
# INFO:tensorflow:Step 8800 | Loss: 0.2757 | Spent: 14.0 secs | LR: 0.000580
# INFO:tensorflow:Step 8900 | Loss: 0.3068 | Spent: 13.8 secs | LR: 0.000565
# INFO:tensorflow:Step 9000 | Loss: 0.1855 | Spent: 14.0 secs | LR: 0.000550
# INFO:tensorflow:Step 9100 | Loss: 0.1053 | Spent: 13.8 secs | LR: 0.000535
# INFO:tensorflow:Step 9200 | Loss: 0.3966 | Spent: 13.9 secs | LR: 0.000520
# INFO:tensorflow:Step 9300 | Loss: 0.2204 | Spent: 14.4 secs | LR: 0.000505
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.824
# INFO:tensorflow:Best Accuracy: 0.824
# Reading ../data/train.csv
# INFO:tensorflow:Step 9400 | Loss: 0.1823 | Spent: 50.0 secs | LR: 0.000490
# INFO:tensorflow:Step 9500 | Loss: 0.2293 | Spent: 14.0 secs | LR: 0.000475
# INFO:tensorflow:Step 9600 | Loss: 0.2589 | Spent: 14.4 secs | LR: 0.000460
# INFO:tensorflow:Step 9700 | Loss: 0.1807 | Spent: 14.4 secs | LR: 0.000445
# INFO:tensorflow:Step 9800 | Loss: 0.1594 | Spent: 13.9 secs | LR: 0.000430
# INFO:tensorflow:Step 9900 | Loss: 0.1979 | Spent: 14.1 secs | LR: 0.000415
# INFO:tensorflow:Step 10000 | Loss: 0.1711 | Spent: 14.2 secs | LR: 0.000400
# INFO:tensorflow:Step 10100 | Loss: 0.2431 | Spent: 14.2 secs | LR: 0.000385
# INFO:tensorflow:Step 10200 | Loss: 0.2157 | Spent: 14.2 secs | LR: 0.000370
# INFO:tensorflow:Step 10300 | Loss: 0.1646 | Spent: 14.1 secs | LR: 0.000355
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.822
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 46900 | Loss: 0.0396 | Spent: 50.7 secs | LR: 0.000265
# INFO:tensorflow:Step 47000 | Loss: 0.0107 | Spent: 14.0 secs | LR: 0.000250
# INFO:tensorflow:Step 47100 | Loss: 0.0087 | Spent: 14.2 secs | LR: 0.000235
# INFO:tensorflow:Step 47200 | Loss: 0.0009 | Spent: 14.2 secs | LR: 0.000220
# INFO:tensorflow:Step 47300 | Loss: 0.0894 | Spent: 14.3 secs | LR: 0.000205
# INFO:tensorflow:Step 47400 | Loss: 0.0235 | Spent: 14.4 secs | LR: 0.000190
# INFO:tensorflow:Step 47500 | Loss: 0.0087 | Spent: 14.4 secs | LR: 0.000175
# INFO:tensorflow:Step 47600 | Loss: 0.0040 | Spent: 14.2 secs | LR: 0.000160
# INFO:tensorflow:Step 47700 | Loss: 0.1102 | Spent: 14.1 secs | LR: 0.000145
# INFO:tensorflow:Step 47800 | Loss: 0.0631 | Spent: 14.5 secs | LR: 0.000130
# INFO:tensorflow:Step 47900 | Loss: 0.0709 | Spent: 14.7 secs | LR: 0.000115
# INFO:tensorflow:Step 48000 | Loss: 0.0235 | Spent: 14.3 secs | LR: 0.000100
# INFO:tensorflow:Step 48100 | Loss: 0.0252 | Spent: 14.1 secs | LR: 0.000115
# INFO:tensorflow:Step 48200 | Loss: 0.0044 | Spent: 14.4 secs | LR: 0.000130
# INFO:tensorflow:Step 48300 | Loss: 0.0245 | Spent: 14.6 secs | LR: 0.000145
# INFO:tensorflow:Step 48400 | Loss: 0.0134 | Spent: 14.5 secs | LR: 0.000160
# INFO:tensorflow:Step 48500 | Loss: 0.0112 | Spent: 14.0 secs | LR: 0.000175
# INFO:tensorflow:Step 48600 | Loss: 0.0019 | Spent: 14.5 secs | LR: 0.000190
# INFO:tensorflow:Step 48700 | Loss: 0.1101 | Spent: 14.5 secs | LR: 0.000205
# INFO:tensorflow:Step 48800 | Loss: 0.0005 | Spent: 14.2 secs | LR: 0.000220
# INFO:tensorflow:Step 48900 | Loss: 0.0632 | Spent: 14.4 secs | LR: 0.000235
# INFO:tensorflow:Step 49000 | Loss: 0.0098 | Spent: 14.5 secs | LR: 0.000250
# INFO:tensorflow:Step 49100 | Loss: 0.1700 | Spent: 14.4 secs | LR: 0.000265
# INFO:tensorflow:Step 49200 | Loss: 0.0545 | Spent: 14.1 secs | LR: 0.000280
# INFO:tensorflow:Step 49300 | Loss: 0.0191 | Spent: 14.4 secs | LR: 0.000295
# INFO:tensorflow:Step 49400 | Loss: 0.0552 | Spent: 14.3 secs | LR: 0.000310
# INFO:tensorflow:Step 49500 | Loss: 0.0675 | Spent: 14.1 secs | LR: 0.000325
# INFO:tensorflow:Step 49600 | Loss: 0.0011 | Spent: 14.3 secs | LR: 0.000340
# INFO:tensorflow:Step 49700 | Loss: 0.0192 | Spent: 14.4 secs | LR: 0.000355
# INFO:tensorflow:Step 49800 | Loss: 0.0217 | Spent: 14.5 secs | LR: 0.000370
# INFO:tensorflow:Step 49900 | Loss: 0.1268 | Spent: 14.1 secs | LR: 0.000385
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.824
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 50000 | Loss: 0.0773 | Spent: 51.4 secs | LR: 0.000400
# INFO:tensorflow:Step 50100 | Loss: 0.0070 | Spent: 14.1 secs | LR: 0.000415
# INFO:tensorflow:Step 50200 | Loss: 0.0078 | Spent: 14.4 secs | LR: 0.000430
# INFO:tensorflow:Step 50300 | Loss: 0.1110 | Spent: 14.4 secs | LR: 0.000445
# INFO:tensorflow:Step 50400 | Loss: 0.0047 | Spent: 14.1 secs | LR: 0.000460
# INFO:tensorflow:Step 50500 | Loss: 0.1622 | Spent: 14.4 secs | LR: 0.000475
# INFO:tensorflow:Step 50600 | Loss: 0.0294 | Spent: 14.4 secs | LR: 0.000490
# INFO:tensorflow:Step 50700 | Loss: 0.0062 | Spent: 14.3 secs | LR: 0.000505
# INFO:tensorflow:Step 50800 | Loss: 0.0003 | Spent: 14.2 secs | LR: 0.000520
# INFO:tensorflow:Step 50900 | Loss: 0.0006 | Spent: 14.5 secs | LR: 0.000535
# INFO:tensorflow:Step 51000 | Loss: 0.0375 | Spent: 14.2 secs | LR: 0.000550
# INFO:tensorflow:Step 51100 | Loss: 0.0071 | Spent: 14.4 secs | LR: 0.000565
# INFO:tensorflow:Step 51200 | Loss: 0.0446 | Spent: 14.5 secs | LR: 0.000580
# INFO:tensorflow:Step 51300 | Loss: 0.0414 | Spent: 14.1 secs | LR: 0.000595
# INFO:tensorflow:Step 51400 | Loss: 0.0146 | Spent: 14.4 secs | LR: 0.000610
# INFO:tensorflow:Step 51500 | Loss: 0.0058 | Spent: 14.4 secs | LR: 0.000625
# INFO:tensorflow:Step 51600 | Loss: 0.0072 | Spent: 14.1 secs | LR: 0.000640
# INFO:tensorflow:Step 51700 | Loss: 0.0102 | Spent: 14.3 secs | LR: 0.000655
# INFO:tensorflow:Step 51800 | Loss: 0.0220 | Spent: 14.2 secs | LR: 0.000670
# INFO:tensorflow:Step 51900 | Loss: 0.0035 | Spent: 14.4 secs | LR: 0.000685
# INFO:tensorflow:Step 52000 | Loss: 0.0088 | Spent: 14.6 secs | LR: 0.000700
# INFO:tensorflow:Step 52100 | Loss: 0.2520 | Spent: 14.7 secs | LR: 0.000715
# INFO:tensorflow:Step 52200 | Loss: 0.0116 | Spent: 14.1 secs | LR: 0.000730
# INFO:tensorflow:Step 52300 | Loss: 0.0347 | Spent: 14.5 secs | LR: 0.000745
# INFO:tensorflow:Step 52400 | Loss: 0.0880 | Spent: 15.0 secs | LR: 0.000760
# INFO:tensorflow:Step 52500 | Loss: 0.3102 | Spent: 15.0 secs | LR: 0.000775
# INFO:tensorflow:Step 52600 | Loss: 0.0401 | Spent: 14.6 secs | LR: 0.000790
# INFO:tensorflow:Step 52700 | Loss: 0.0193 | Spent: 14.3 secs | LR: 0.000805
# INFO:tensorflow:Step 52800 | Loss: 0.0665 | Spent: 14.3 secs | LR: 0.000820
# INFO:tensorflow:Step 52900 | Loss: 0.0732 | Spent: 14.2 secs | LR: 0.000835
# INFO:tensorflow:Step 53000 | Loss: 0.0923 | Spent: 14.6 secs | LR: 0.000850
# INFO:tensorflow:Step 53100 | Loss: 0.0151 | Spent: 14.4 secs | LR: 0.000865
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.811
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 53200 | Loss: 0.0029 | Spent: 51.1 secs | LR: 0.000880
# INFO:tensorflow:Step 53300 | Loss: 0.0036 | Spent: 14.8 secs | LR: 0.000895
# INFO:tensorflow:Step 53400 | Loss: 0.0675 | Spent: 14.2 secs | LR: 0.000910
# INFO:tensorflow:Step 53500 | Loss: 0.0433 | Spent: 14.4 secs | LR: 0.000925
# INFO:tensorflow:Step 53600 | Loss: 0.0202 | Spent: 14.4 secs | LR: 0.000940
# INFO:tensorflow:Step 53700 | Loss: 0.0541 | Spent: 14.4 secs | LR: 0.000955
# INFO:tensorflow:Step 53800 | Loss: 0.0130 | Spent: 14.5 secs | LR: 0.000970
# INFO:tensorflow:Step 53900 | Loss: 0.1852 | Spent: 14.7 secs | LR: 0.000985
# INFO:tensorflow:Step 54000 | Loss: 0.1205 | Spent: 14.2 secs | LR: 0.001000
# INFO:tensorflow:Step 54100 | Loss: 0.0292 | Spent: 14.5 secs | LR: 0.000985
# INFO:tensorflow:Step 54200 | Loss: 0.0441 | Spent: 14.7 secs | LR: 0.000970
# INFO:tensorflow:Step 54300 | Loss: 0.0074 | Spent: 14.0 secs | LR: 0.000955
# INFO:tensorflow:Step 54400 | Loss: 0.1216 | Spent: 14.5 secs | LR: 0.000940
# INFO:tensorflow:Step 54500 | Loss: 0.0209 | Spent: 14.2 secs | LR: 0.000925
# INFO:tensorflow:Step 54600 | Loss: 0.1489 | Spent: 14.2 secs | LR: 0.000910
# INFO:tensorflow:Step 54700 | Loss: 0.1935 | Spent: 14.3 secs | LR: 0.000895
# INFO:tensorflow:Step 54800 | Loss: 0.0455 | Spent: 14.6 secs | LR: 0.000880
# INFO:tensorflow:Step 54900 | Loss: 0.0729 | Spent: 14.5 secs | LR: 0.000865
# INFO:tensorflow:Step 55000 | Loss: 0.0784 | Spent: 14.3 secs | LR: 0.000850
# INFO:tensorflow:Step 55100 | Loss: 0.0320 | Spent: 14.4 secs | LR: 0.000835
# INFO:tensorflow:Step 55200 | Loss: 0.0511 | Spent: 14.5 secs | LR: 0.000820
# INFO:tensorflow:Step 55300 | Loss: 0.1580 | Spent: 14.5 secs | LR: 0.000805
# INFO:tensorflow:Step 55400 | Loss: 0.0784 | Spent: 14.5 secs | LR: 0.000790
# INFO:tensorflow:Step 55500 | Loss: 0.0181 | Spent: 14.1 secs | LR: 0.000775
# INFO:tensorflow:Step 55600 | Loss: 0.0660 | Spent: 14.0 secs | LR: 0.000760
# INFO:tensorflow:Step 55700 | Loss: 0.0361 | Spent: 14.3 secs | LR: 0.000745
# INFO:tensorflow:Step 55800 | Loss: 0.0615 | Spent: 14.0 secs | LR: 0.000730
# INFO:tensorflow:Step 55900 | Loss: 0.0235 | Spent: 14.2 secs | LR: 0.000715
# INFO:tensorflow:Step 56000 | Loss: 0.0613 | Spent: 14.6 secs | LR: 0.000700
# INFO:tensorflow:Step 56100 | Loss: 0.0353 | Spent: 14.3 secs | LR: 0.000685
# INFO:tensorflow:Step 56200 | Loss: 0.2250 | Spent: 14.2 secs | LR: 0.000670
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.822
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 56300 | Loss: 0.0782 | Spent: 51.4 secs | LR: 0.000655
# INFO:tensorflow:Step 56400 | Loss: 0.0930 | Spent: 14.3 secs | LR: 0.000640
# INFO:tensorflow:Step 56500 | Loss: 0.0206 | Spent: 13.9 secs | LR: 0.000625
# INFO:tensorflow:Step 56600 | Loss: 0.0009 | Spent: 14.2 secs | LR: 0.000610
# INFO:tensorflow:Step 56700 | Loss: 0.0312 | Spent: 14.6 secs | LR: 0.000595
# INFO:tensorflow:Step 56800 | Loss: 0.0485 | Spent: 14.4 secs | LR: 0.000580
# INFO:tensorflow:Step 56900 | Loss: 0.0563 | Spent: 14.5 secs | LR: 0.000565
# INFO:tensorflow:Step 57000 | Loss: 0.0170 | Spent: 13.9 secs | LR: 0.000550
# INFO:tensorflow:Step 57100 | Loss: 0.0055 | Spent: 14.3 secs | LR: 0.000535
# INFO:tensorflow:Step 57200 | Loss: 0.0051 | Spent: 14.7 secs | LR: 0.000520
# INFO:tensorflow:Step 57300 | Loss: 0.0656 | Spent: 14.3 secs | LR: 0.000505
# INFO:tensorflow:Step 57400 | Loss: 0.0083 | Spent: 14.2 secs | LR: 0.000490
# INFO:tensorflow:Step 57500 | Loss: 0.0164 | Spent: 14.1 secs | LR: 0.000475
# INFO:tensorflow:Step 57600 | Loss: 0.0099 | Spent: 14.4 secs | LR: 0.000460
# INFO:tensorflow:Step 57700 | Loss: 0.0061 | Spent: 14.4 secs | LR: 0.000445
# INFO:tensorflow:Step 57800 | Loss: 0.0027 | Spent: 14.3 secs | LR: 0.000430
# INFO:tensorflow:Step 57900 | Loss: 0.0495 | Spent: 14.5 secs | LR: 0.000415
# INFO:tensorflow:Step 58000 | Loss: 0.0302 | Spent: 14.6 secs | LR: 0.000400
# INFO:tensorflow:Step 58100 | Loss: 0.0903 | Spent: 14.3 secs | LR: 0.000385
# INFO:tensorflow:Step 58200 | Loss: 0.0031 | Spent: 14.4 secs | LR: 0.000370
# INFO:tensorflow:Step 58300 | Loss: 0.0970 | Spent: 14.0 secs | LR: 0.000355
# INFO:tensorflow:Step 58400 | Loss: 0.0012 | Spent: 14.4 secs | LR: 0.000340
# INFO:tensorflow:Step 58500 | Loss: 0.0310 | Spent: 14.5 secs | LR: 0.000325
# INFO:tensorflow:Step 58600 | Loss: 0.0044 | Spent: 14.1 secs | LR: 0.000310
# INFO:tensorflow:Step 58700 | Loss: 0.0010 | Spent: 14.2 secs | LR: 0.000295
# INFO:tensorflow:Step 58800 | Loss: 0.0057 | Spent: 14.0 secs | LR: 0.000280
# INFO:tensorflow:Step 58900 | Loss: 0.0415 | Spent: 14.6 secs | LR: 0.000265
# INFO:tensorflow:Step 59000 | Loss: 0.0716 | Spent: 14.4 secs | LR: 0.000250
# INFO:tensorflow:Step 59100 | Loss: 0.0185 | Spent: 14.5 secs | LR: 0.000235
# INFO:tensorflow:Step 59200 | Loss: 0.0077 | Spent: 14.1 secs | LR: 0.000220
# INFO:tensorflow:Step 59300 | Loss: 0.0036 | Spent: 14.1 secs | LR: 0.000205
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.825
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 59400 | Loss: 0.0111 | Spent: 50.8 secs | LR: 0.000190
# INFO:tensorflow:Step 59500 | Loss: 0.0002 | Spent: 14.2 secs | LR: 0.000175
# INFO:tensorflow:Step 59600 | Loss: 0.0021 | Spent: 14.6 secs | LR: 0.000160
# INFO:tensorflow:Step 59700 | Loss: 0.0142 | Spent: 14.3 secs | LR: 0.000145
# INFO:tensorflow:Step 59800 | Loss: 0.0081 | Spent: 14.5 secs | LR: 0.000130
# INFO:tensorflow:Step 59900 | Loss: 0.0185 | Spent: 14.3 secs | LR: 0.000115
# INFO:tensorflow:Step 60000 | Loss: 0.0277 | Spent: 14.4 secs | LR: 0.000100
# INFO:tensorflow:Step 60100 | Loss: 0.0245 | Spent: 14.3 secs | LR: 0.000115
# INFO:tensorflow:Step 60200 | Loss: 0.0093 | Spent: 14.5 secs | LR: 0.000130
# INFO:tensorflow:Step 60300 | Loss: 0.0645 | Spent: 14.5 secs | LR: 0.000145
# INFO:tensorflow:Step 60400 | Loss: 0.0359 | Spent: 14.3 secs | LR: 0.000160
# INFO:tensorflow:Step 60500 | Loss: 0.0025 | Spent: 14.4 secs | LR: 0.000175
# INFO:tensorflow:Step 60600 | Loss: 0.0002 | Spent: 14.3 secs | LR: 0.000190
# INFO:tensorflow:Step 60700 | Loss: 0.0027 | Spent: 14.0 secs | LR: 0.000205
# INFO:tensorflow:Step 60800 | Loss: 0.0361 | Spent: 14.3 secs | LR: 0.000220
# INFO:tensorflow:Step 60900 | Loss: 0.0163 | Spent: 14.3 secs | LR: 0.000235
# INFO:tensorflow:Step 61000 | Loss: 0.1507 | Spent: 14.3 secs | LR: 0.000250
# INFO:tensorflow:Step 61100 | Loss: 0.0151 | Spent: 14.2 secs | LR: 0.000265
# INFO:tensorflow:Step 61200 | Loss: 0.0003 | Spent: 14.6 secs | LR: 0.000280
# INFO:tensorflow:Step 61300 | Loss: 0.0285 | Spent: 13.8 secs | LR: 0.000295
# INFO:tensorflow:Step 61400 | Loss: 0.0020 | Spent: 14.4 secs | LR: 0.000310
# INFO:tensorflow:Step 61500 | Loss: 0.0065 | Spent: 14.1 secs | LR: 0.000325
# INFO:tensorflow:Step 61600 | Loss: 0.0020 | Spent: 14.3 secs | LR: 0.000340
# INFO:tensorflow:Step 61700 | Loss: 0.0011 | Spent: 14.5 secs | LR: 0.000355
# INFO:tensorflow:Step 61800 | Loss: 0.0004 | Spent: 14.2 secs | LR: 0.000370
# INFO:tensorflow:Step 61900 | Loss: 0.0623 | Spent: 14.6 secs | LR: 0.000385
# INFO:tensorflow:Step 62000 | Loss: 0.0103 | Spent: 14.1 secs | LR: 0.000400
# INFO:tensorflow:Step 62100 | Loss: 0.0052 | Spent: 14.6 secs | LR: 0.000415
# INFO:tensorflow:Step 62200 | Loss: 0.0048 | Spent: 14.7 secs | LR: 0.000430
# INFO:tensorflow:Step 62300 | Loss: 0.0763 | Spent: 14.4 secs | LR: 0.000445
# INFO:tensorflow:Step 62400 | Loss: 0.0215 | Spent: 14.4 secs | LR: 0.000460
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.821
# INFO:tensorflow:Best Accuracy: 0.831
# Reading ../data/train.csv
# INFO:tensorflow:Step 62500 | Loss: 0.0027 | Spent: 51.2 secs | LR: 0.000475
