# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/text_matching/chinese/main')

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
import csv
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
import math

from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-894cb78b85fa>:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(f_path):
  k2v = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      k2v[line] = i
  return k2v

# %%
# stream data from text files
def data_generator(f_path, char2idx):
  with open(f_path) as f:
    print('Reading', f_path)
    for i, line in enumerate(csv.reader(f, delimiter=',')):
      if i == 0:
        continue
      text1, text2, label = line
      text1 = [char2idx.get(c, len(char2idx)) for c in list(text1)]
      text2 = [char2idx.get(c, len(char2idx)) for c in list(text2)]
      yield ((text1, text2), int(label))


def dataset(is_training, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.int32, tf.int32), tf.int32)
  _pads = ((0, 0), -1)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
class RE2(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    
    self.pretrained_embedding = tf.Variable(np.load(params['embedding_path']), name='pretrained_embedding', dtype=tf.float32)
    self.embed_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.birnn = [tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['hidden_size'], return_sequences=True), name='birnn_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.enc_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.align_t = self.add_weight(name='temperature',
                                   shape=(),
                                   trainable=True,
                                   initializer=tf.initializers.constant(math.sqrt(1/params['hidden_size'])))
    self.align_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.align_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.align_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
      
    self.fusion_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc3 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc3_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc4 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc4_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.out_drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_fc = tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='out_fc')
    self.out_drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(1, name='out_linear')
    
  
  
  def call(self, inputs, training=False):
    x1, x2 = inputs
    
    if x1.dtype != tf.int32:
      x1 = tf.cast(x1, tf.int32)
    if x2.dtype != tf.int32:
      x2 = tf.cast(x2, tf.int32)
    
    batch_sz = tf.shape(x1)[0]
    
    mask1 = tf.sign(x1)
    mask2 = tf.sign(x2)
    
    x1 = self.embedding(x1, training=training)
    x2 = self.embedding(x2, training=training)
    
    res_x1, res_x2 = x1, x2
    
    for i in range(params['num_blocks']):
      
      if i > 0:
        x1 = self.connection(x1, res_x1, i)
        x2 = self.connection(x2, res_x2, i)
        res_x1, res_x2 = x1, x2
    
      x1_enc = self.encoding(x1, mask1, i, training=training)
      x2_enc = self.encoding(x2, mask2, i, training=training)
    
      x1 = tf.concat((x1, x1_enc), -1)
      x2 = tf.concat((x2, x2_enc), -1)
      
      align_1, align_2 = self.alignment(x1, x2, mask1, mask2, i, training=training)
      
      x1 = self.fusion(x1, align_1, i, training=training)
      x2 = self.fusion(x2, align_2, i, training=training)
    
    x1 = self.pooling(x1, mask1)
    x2 = self.pooling(x2, mask2)
    
    x = self.prediction(x1, x2, training=training)
    
    return x
  
  
  def embedding(self, x, training):
    x = tf.nn.embedding_lookup(self.pretrained_embedding, x)
    x = self.embed_dropout(x, training=training)
    return x
  
  
  def connection(self, x, res, i):
    if i == 1:
      x = tf.concat((res, x), -1)
    elif i > 1:
      hidden_size = x.shape[-1]
      x = (res[:, :, -hidden_size:] + x) * tf.math.sqrt(0.5)
      x = tf.concat((res[:, :, :-hidden_size], x), -1)
    return x
    
    
  def encoding(self, x, mask, i, training):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    x *= mask
    x = self.birnn[i](x)
    x = self.enc_dropout(x, training=training)
    return x
  
  
  def alignment(self, x1, x2, mask1, mask2, i, training):
    mask1 = tf.cast(tf.expand_dims(mask1, -1), tf.float32)
    mask2 = tf.cast(tf.expand_dims(mask2, -1), tf.float32)
    
    x1_ = self.align_fc1[i](self.align_dropout(x1, training=training))
    x2_ = self.align_fc2[i](self.align_dropout(x2, training=training))
    align = tf.matmul(x1_, x2_, transpose_b=True) * self.align_t
    mask = tf.matmul(mask1, mask2, transpose_b=True)
    align = mask * align + (1 - mask) * tf.float32.min
    align_1 = tf.nn.softmax(align, 1)
    align_2 = tf.nn.softmax(align, 2)
    
    x2 = tf.matmul(align_1, x1, transpose_a=True)
    x1 = tf.matmul(align_2, x2)
    return x1, x2
  
  
  def fusion(self, x, align, i, training):
    x = tf.concat([self.fusion_fc1[i](tf.concat((x, align), -1)),
                   self.fusion_fc2[i](tf.concat((x, x - align), -1)),
                   self.fusion_fc3[i](tf.concat((x, x * align), -1))], -1)
    x = self.fusion_dropout(x, training=training)
    x = self.fusion_fc4[i](x)
    return x
  
  
  def pooling(self, x, mask):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    return tf.reduce_max(x * mask, 1)
  
  
  def prediction(self, x1, x2, training):
    x = tf.concat((x1, x2, x1 * x2, x1 - x2), -1)
    x = self.out_drop1(x, training=training)
    x = self.out_fc(x)
    x = self.out_drop2(x, training=training)
    x = self.out_linear(x)
    x = tf.squeeze(x, 1)
    return x

# %%
params = {
  'train_path': '../data/train.csv',
  'test_path': '../data/test.csv',
  'vocab_path': '../vocab/char.txt',
  'embedding_path': '../vocab/char.npy',
  'batch_size': 32,
  'buffer_size': 100000,
  'num_blocks': 2,
  'dropout_rate': 0.2,
  'hidden_size': 300,
  'activation': tf.nn.relu,
  'init_lr': 1e-4,
  'max_lr': 8e-4,
  'label_smooth': .2,
  'clip_norm': 5.,
  'num_patience': 10,
}

# %%
def label_smoothing(inputs, epsilon):
  V = inputs.get_shape().as_list()[-1]
  return ((1-epsilon) * inputs) + (epsilon / V)

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['vocab_size'] = len(params['char2idx']) + 1

model = RE2(params)
model.build([[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = params['init_lr'],
  maximal_learning_rate = params['max_lr'],
  step_size = 4 * params['buffer_size'] // params['batch_size'],)
optim = tf.optimizers.Adam(params['init_lr'])
global_step = 0

best_acc = .0
count = 0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

while True:
  # TRAINING
  for ((text1, text2), labels) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      logits = model((text1, text2), training=True)
      loss = tf.nn.sigmoid_cross_entropy_with_logits(
        labels=label_smoothing(tf.cast(labels, tf.float32), params['label_smooth']),
        logits=logits)
      loss = tf.reduce_mean(loss)
      
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))
    
    if global_step % 100 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
  
  # EVALUATION
  m = tf.keras.metrics.Accuracy()

  for ((text1, text2), labels) in dataset(is_training=False, params=params):
    logits = tf.sigmoid(model((text1, text2), training=False))
    y_pred = tf.cast(tf.math.greater_equal(logits, .5), tf.int32)
    m.update_state(y_true=labels, y_pred=y_pred)

  acc = m.result().numpy()
  logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))

  if acc > best_acc:
    best_acc = acc
    # you can save model here
    count = 0
  else:
    count += 1
  logger.info("Best Accuracy: {:.3f}".format(best_acc))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# [('birnn_1/forward_lstm/lstm_cell_1/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm/lstm_cell_1/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm/lstm_cell_1/bias:0', TensorShape([1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm/lstm_cell_2/bias:0', TensorShape([1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/forward_lstm_1/lstm_cell_4/bias:0', TensorShape([1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/backward_lstm_1/lstm_cell_5/bias:0', TensorShape([1200])),
#  ('align_fc1_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc1_1/bias:0', TensorShape([300])),
#  ('align_fc1_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc1_2/bias:0', TensorShape([300])),
#  ('align_fc2_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc2_1/bias:0', TensorShape([300])),
#  ('align_fc2_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc1_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc1_1/bias:0', TensorShape([300])),
#  ('fusion_fc1_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc1_2/bias:0', TensorShape([300])),
#  ('fusion_fc2_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc2_1/bias:0', TensorShape([300])),
#  ('fusion_fc2_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc3_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc3_1/bias:0', TensorShape([300])),
#  ('fusion_fc3_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc3_2/bias:0', TensorShape([300])),
#  ('fusion_fc4_1/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_1/bias:0', TensorShape([300])),
#  ('fusion_fc4_2/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_2/bias:0', TensorShape([300])),
#  ('out_fc/kernel:0', TensorShape([1200, 300])),
#  ('out_fc/bias:0', TensorShape([300])),
#  ('out_linear/kernel:0', TensorShape([300, 1])),
#  ('out_linear/bias:0', TensorShape([1])),
#  ('pretrained_embedding:0', TensorShape([1507, 300])),
#  ('temperature:0', TensorShape([]))]
# Reading ../data/train.csv
# INFO:tensorflow:Step 0 | Loss: 0.7002 | Spent: 23.6 secs | LR: 0.000100
# INFO:tensorflow:Step 100 | Loss: 0.6505 | Spent: 10.9 secs | LR: 0.000106
# INFO:tensorflow:Step 200 | Loss: 0.6448 | Spent: 10.6 secs | LR: 0.000111
# INFO:tensorflow:Step 300 | Loss: 0.7073 | Spent: 11.0 secs | LR: 0.000117
# INFO:tensorflow:Step 400 | Loss: 0.5947 | Spent: 10.9 secs | LR: 0.000122
# INFO:tensorflow:Step 500 | Loss: 0.6872 | Spent: 11.0 secs | LR: 0.000128
# INFO:tensorflow:Step 600 | Loss: 0.6071 | Spent: 11.1 secs | LR: 0.000134
# INFO:tensorflow:Step 700 | Loss: 0.6134 | Spent: 10.9 secs | LR: 0.000139
# INFO:tensorflow:Step 800 | Loss: 0.6199 | Spent: 10.9 secs | LR: 0.000145
# INFO:tensorflow:Step 900 | Loss: 0.6022 | Spent: 10.8 secs | LR: 0.000150
# INFO:tensorflow:Step 1000 | Loss: 0.5365 | Spent: 10.9 secs | LR: 0.000156
# INFO:tensorflow:Step 1100 | Loss: 0.5337 | Spent: 10.7 secs | LR: 0.000162
# INFO:tensorflow:Step 1200 | Loss: 0.6021 | Spent: 10.8 secs | LR: 0.000167
# INFO:tensorflow:Step 1300 | Loss: 0.7197 | Spent: 10.9 secs | LR: 0.000173
# INFO:tensorflow:Step 1400 | Loss: 0.5750 | Spent: 10.7 secs | LR: 0.000178
# INFO:tensorflow:Step 55500 | Loss: 0.2687 | Spent: 10.9 secs | LR: 0.000177
# INFO:tensorflow:Step 55600 | Loss: 0.3004 | Spent: 10.9 secs | LR: 0.000178
# INFO:tensorflow:Step 55700 | Loss: 0.2534 | Spent: 10.9 secs | LR: 0.000180
# INFO:tensorflow:Step 55800 | Loss: 0.2809 | Spent: 10.8 secs | LR: 0.000181
# INFO:tensorflow:Step 55900 | Loss: 0.2712 | Spent: 10.9 secs | LR: 0.000183
# INFO:tensorflow:Step 56000 | Loss: 0.3106 | Spent: 11.1 secs | LR: 0.000184
# INFO:tensorflow:Step 56100 | Loss: 0.2534 | Spent: 11.1 secs | LR: 0.000185
# INFO:tensorflow:Step 56200 | Loss: 0.3017 | Spent: 10.9 secs | LR: 0.000187
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.835
# INFO:tensorflow:Best Accuracy: 0.835
# Reading ../data/train.csv
# INFO:tensorflow:Step 56300 | Loss: 0.2393 | Spent: 44.1 secs | LR: 0.000188
# INFO:tensorflow:Step 56400 | Loss: 0.2571 | Spent: 10.9 secs | LR: 0.000190
# INFO:tensorflow:Step 56500 | Loss: 0.2706 | Spent: 11.1 secs | LR: 0.000191
# INFO:tensorflow:Step 56600 | Loss: 0.3360 | Spent: 10.8 secs | LR: 0.000192
# INFO:tensorflow:Step 56700 | Loss: 0.2391 | Spent: 11.0 secs | LR: 0.000194
# ...
# INFO:tensorflow:Step 93000 | Loss: 0.2521 | Spent: 10.8 secs | LR: 0.000149
# INFO:tensorflow:Step 93100 | Loss: 0.2822 | Spent: 10.9 secs | LR: 0.000148
# INFO:tensorflow:Step 93200 | Loss: 0.2954 | Spent: 10.9 secs | LR: 0.000148
# INFO:tensorflow:Step 93300 | Loss: 0.2665 | Spent: 10.9 secs | LR: 0.000147
# INFO:tensorflow:Step 93400 | Loss: 0.2257 | Spent: 10.9 secs | LR: 0.000146
# INFO:tensorflow:Step 93500 | Loss: 0.2666 | Spent: 11.2 secs | LR: 0.000146
# INFO:tensorflow:Step 93600 | Loss: 0.2395 | Spent: 10.9 secs | LR: 0.000145
# INFO:tensorflow:Step 93700 | Loss: 0.2242 | Spent: 10.9 secs | LR: 0.000144
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.836
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ../data/train.csv
# INFO:tensorflow:Step 93800 | Loss: 0.2248 | Spent: 44.0 secs | LR: 0.000143
# INFO:tensorflow:Step 93900 | Loss: 0.2684 | Spent: 10.9 secs | LR: 0.000143
# INFO:tensorflow:Step 94000 | Loss: 0.3087 | Spent: 10.8 secs | LR: 0.000142
# INFO:tensorflow:Step 94100 | Loss: 0.2656 | Spent: 10.6 secs | LR: 0.000141
# INFO:tensorflow:Step 94200 | Loss: 0.2525 | Spent: 11.0 secs | LR: 0.000141
# INFO:tensorflow:Step 94300 | Loss: 0.3088 | Spent: 11.1 secs | LR: 0.000140
# INFO:tensorflow:Step 94400 | Loss: 0.2532 | Spent: 11.0 secs | LR: 0.000139
# INFO:tensorflow:Step 94500 | Loss: 0.2948 | Spent: 11.0 secs | LR: 0.000139
# INFO:tensorflow:Step 94600 | Loss: 0.2952 | Spent: 10.9 secs | LR: 0.000138
# INFO:tensorflow:Step 94700 | Loss: 0.2231 | Spent: 10.9 secs | LR: 0.000137
# INFO:tensorflow:Step 94800 | Loss: 0.2396 | Spent: 10.8 secs | LR: 0.000136
# INFO:tensorflow:Step 94900 | Loss: 0.2948 | Spent: 10.9 secs | LR: 0.000136
# INFO:tensorflow:Step 95000 | Loss: 0.3512 | Spent: 10.9 secs | LR: 0.000135
# INFO:tensorflow:Step 95100 | Loss: 0.3259 | Spent: 11.0 secs | LR: 0.000134
# INFO:tensorflow:Step 95200 | Loss: 0.2514 | Spent: 10.8 secs | LR: 0.000134
# INFO:tensorflow:Step 95300 | Loss: 0.1955 | Spent: 10.9 secs | LR: 0.000133
# INFO:tensorflow:Step 95400 | Loss: 0.2315 | Spent: 10.7 secs | LR: 0.000132
# INFO:tensorflow:Step 95500 | Loss: 0.2244 | Spent: 10.7 secs | LR: 0.000132
# INFO:tensorflow:Step 95600 | Loss: 0.2380 | Spent: 11.0 secs | LR: 0.000131
# INFO:tensorflow:Step 95700 | Loss: 0.3096 | Spent: 10.8 secs | LR: 0.000130
# INFO:tensorflow:Step 95800 | Loss: 0.2537 | Spent: 10.7 secs | LR: 0.000129
# INFO:tensorflow:Step 95900 | Loss: 0.2839 | Spent: 10.9 secs | LR: 0.000129
# INFO:tensorflow:Step 96000 | Loss: 0.2945 | Spent: 11.1 secs | LR: 0.000128
# INFO:tensorflow:Step 96100 | Loss: 0.2372 | Spent: 11.0 secs | LR: 0.000127
# INFO:tensorflow:Step 96200 | Loss: 0.3178 | Spent: 10.9 secs | LR: 0.000127
# INFO:tensorflow:Step 96300 | Loss: 0.3685 | Spent: 10.7 secs | LR: 0.000126
# INFO:tensorflow:Step 96400 | Loss: 0.2236 | Spent: 10.9 secs | LR: 0.000125
# INFO:tensorflow:Step 96500 | Loss: 0.2809 | Spent: 10.7 secs | LR: 0.000125
# INFO:tensorflow:Step 96600 | Loss: 0.3367 | Spent: 10.8 secs | LR: 0.000124
# INFO:tensorflow:Step 96700 | Loss: 0.2666 | Spent: 10.9 secs | LR: 0.000123
# INFO:tensorflow:Step 96800 | Loss: 0.3683 | Spent: 10.9 secs | LR: 0.000122
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.835
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ../data/train.csv
# INFO:tensorflow:Step 96900 | Loss: 0.3285 | Spent: 43.8 secs | LR: 0.000122
# INFO:tensorflow:Step 97000 | Loss: 0.2237 | Spent: 10.8 secs | LR: 0.000121
# INFO:tensorflow:Step 97100 | Loss: 0.2516 | Spent: 10.9 secs | LR: 0.000120
# INFO:tensorflow:Step 97200 | Loss: 0.2820 | Spent: 10.9 secs | LR: 0.000120
# INFO:tensorflow:Step 97300 | Loss: 0.2101 | Spent: 10.9 secs | LR: 0.000119
# INFO:tensorflow:Step 97400 | Loss: 0.2806 | Spent: 10.9 secs | LR: 0.000118
# INFO:tensorflow:Step 97500 | Loss: 0.3514 | Spent: 10.7 secs | LR: 0.000117
# INFO:tensorflow:Step 103600 | Loss: 0.2521 | Spent: 10.7 secs | LR: 0.000113
# INFO:tensorflow:Step 103700 | Loss: 0.1821 | Spent: 10.5 secs | LR: 0.000113
# INFO:tensorflow:Step 103800 | Loss: 0.2808 | Spent: 10.9 secs | LR: 0.000113
# INFO:tensorflow:Step 103900 | Loss: 0.3082 | Spent: 10.6 secs | LR: 0.000114
# INFO:tensorflow:Step 104000 | Loss: 0.1672 | Spent: 10.9 secs | LR: 0.000114
# INFO:tensorflow:Step 104100 | Loss: 0.3363 | Spent: 10.9 secs | LR: 0.000114
# INFO:tensorflow:Step 104200 | Loss: 0.3510 | Spent: 10.4 secs | LR: 0.000115
# INFO:tensorflow:Step 104300 | Loss: 0.3225 | Spent: 10.8 secs | LR: 0.000115
# INFO:tensorflow:Step 104400 | Loss: 0.2944 | Spent: 10.5 secs | LR: 0.000115
# INFO:tensorflow:Step 104500 | Loss: 0.2807 | Spent: 10.4 secs | LR: 0.000116
# INFO:tensorflow:Step 104600 | Loss: 0.3366 | Spent: 10.8 secs | LR: 0.000116
# INFO:tensorflow:Step 104700 | Loss: 0.2373 | Spent: 10.8 secs | LR: 0.000116
# INFO:tensorflow:Step 104800 | Loss: 0.2527 | Spent: 10.8 secs | LR: 0.000117
# INFO:tensorflow:Step 104900 | Loss: 0.3084 | Spent: 10.6 secs | LR: 0.000117
# INFO:tensorflow:Step 105000 | Loss: 0.1975 | Spent: 10.7 secs | LR: 0.000117
# INFO:tensorflow:Step 105100 | Loss: 0.2901 | Spent: 10.5 secs | LR: 0.000118
# INFO:tensorflow:Step 105200 | Loss: 0.2939 | Spent: 10.6 secs | LR: 0.000118
# INFO:tensorflow:Step 105300 | Loss: 0.2848 | Spent: 10.6 secs | LR: 0.000119
# INFO:tensorflow:Step 105400 | Loss: 0.3223 | Spent: 10.8 secs | LR: 0.000119
# INFO:tensorflow:Step 105500 | Loss: 0.2381 | Spent: 10.7 secs | LR: 0.000119
# INFO:tensorflow:Step 105600 | Loss: 0.3095 | Spent: 10.7 secs | LR: 0.000120
# INFO:tensorflow:Step 105700 | Loss: 0.2383 | Spent: 10.7 secs | LR: 0.000120
# INFO:tensorflow:Step 105800 | Loss: 0.2658 | Spent: 10.5 secs | LR: 0.000120
# INFO:tensorflow:Step 105900 | Loss: 0.2957 | Spent: 10.6 secs | LR: 0.000121
# INFO:tensorflow:Step 106000 | Loss: 0.3225 | Spent: 10.7 secs | LR: 0.000121
# INFO:tensorflow:Step 106100 | Loss: 0.3223 | Spent: 10.6 secs | LR: 0.000121
# INFO:tensorflow:Step 106200 | Loss: 0.2100 | Spent: 10.7 secs | LR: 0.000122
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.835
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ../data/train.csv
# INFO:tensorflow:Step 106300 | Loss: 0.2662 | Spent: 42.8 secs | LR: 0.000122
# INFO:tensorflow:Step 106400 | Loss: 0.3232 | Spent: 11.1 secs | LR: 0.000122
# INFO:tensorflow:Step 106500 | Loss: 0.2100 | Spent: 10.7 secs | LR: 0.000123
# INFO:tensorflow:Step 106600 | Loss: 0.2806 | Spent: 10.7 secs | LR: 0.000123
# INFO:tensorflow:Step 106700 | Loss: 0.2533 | Spent: 10.7 secs | LR: 0.000123
# INFO:tensorflow:Step 106800 | Loss: 0.3363 | Spent: 10.6 secs | LR: 0.000124
# INFO:tensorflow:Step 106900 | Loss: 0.2940 | Spent: 10.6 secs | LR: 0.000124
# INFO:tensorflow:Step 107000 | Loss: 0.2094 | Spent: 10.9 secs | LR: 0.000125
# INFO:tensorflow:Step 107100 | Loss: 0.2153 | Spent: 10.6 secs | LR: 0.000125
# INFO:tensorflow:Step 107200 | Loss: 0.2093 | Spent: 10.6 secs | LR: 0.000125
# INFO:tensorflow:Step 107300 | Loss: 0.2521 | Spent: 10.8 secs | LR: 0.000126
# INFO:tensorflow:Step 107400 | Loss: 0.4372 | Spent: 10.7 secs | LR: 0.000126
# INFO:tensorflow:Step 107500 | Loss: 0.2671 | Spent: 10.7 secs | LR: 0.000126
# INFO:tensorflow:Step 107600 | Loss: 0.2520 | Spent: 10.5 secs | LR: 0.000127
# INFO:tensorflow:Step 107700 | Loss: 0.2371 | Spent: 10.7 secs | LR: 0.000127
# INFO:tensorflow:Step 107800 | Loss: 0.2518 | Spent: 10.5 secs | LR: 0.000127
# INFO:tensorflow:Step 107900 | Loss: 0.3113 | Spent: 10.7 secs | LR: 0.000128
# INFO:tensorflow:Step 108000 | Loss: 0.2512 | Spent: 10.6 secs | LR: 0.000128
# INFO:tensorflow:Step 108100 | Loss: 0.3332 | Spent: 10.5 secs | LR: 0.000128
# INFO:tensorflow:Step 108200 | Loss: 0.2110 | Spent: 10.7 secs | LR: 0.000129
# INFO:tensorflow:Step 108300 | Loss: 0.2944 | Spent: 10.6 secs | LR: 0.000129
# INFO:tensorflow:Step 108400 | Loss: 0.2373 | Spent: 10.7 secs | LR: 0.000129
# INFO:tensorflow:Step 108500 | Loss: 0.2305 | Spent: 10.5 secs | LR: 0.000130
# INFO:tensorflow:Step 108600 | Loss: 0.2574 | Spent: 10.7 secs | LR: 0.000130
# INFO:tensorflow:Step 108700 | Loss: 0.2823 | Spent: 10.7 secs | LR: 0.000130
# INFO:tensorflow:Step 108800 | Loss: 0.2515 | Spent: 10.8 secs | LR: 0.000131
# INFO:tensorflow:Step 108900 | Loss: 0.3431 | Spent: 10.6 secs | LR: 0.000131
# INFO:tensorflow:Step 109000 | Loss: 0.2664 | Spent: 10.7 secs | LR: 0.000132
# INFO:tensorflow:Step 109100 | Loss: 0.3311 | Spent: 10.6 secs | LR: 0.000132
# INFO:tensorflow:Step 109200 | Loss: 0.3365 | Spent: 10.7 secs | LR: 0.000132
# INFO:tensorflow:Step 109300 | Loss: 0.2724 | Spent: 10.8 secs | LR: 0.000133
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.835
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ../data/train.csv
# INFO:tensorflow:Step 109400 | Loss: 0.2938 | Spent: 42.7 secs | LR: 0.000133
# INFO:tensorflow:Step 109500 | Loss: 0.3951 | Spent: 10.6 secs | LR: 0.000133
# INFO:tensorflow:Step 109600 | Loss: 0.2954 | Spent: 10.8 secs | LR: 0.000134
# INFO:tensorflow:Step 109700 | Loss: 0.3192 | Spent: 10.6 secs | LR: 0.000134
# INFO:tensorflow:Step 109800 | Loss: 0.3006 | Spent: 10.8 secs | LR: 0.000134
# INFO:tensorflow:Step 109900 | Loss: 0.2514 | Spent: 10.7 secs | LR: 0.000135
# INFO:tensorflow:Step 110000 | Loss: 0.2518 | Spent: 10.7 secs | LR: 0.000135
# INFO:tensorflow:Step 110100 | Loss: 0.2535 | Spent: 10.5 secs | LR: 0.000135
# INFO:tensorflow:Step 110200 | Loss: 0.2517 | Spent: 10.8 secs | LR: 0.000136
# INFO:tensorflow:Step 110300 | Loss: 0.2377 | Spent: 10.6 secs | LR: 0.000136
# INFO:tensorflow:Step 110400 | Loss: 0.1821 | Spent: 10.7 secs | LR: 0.000136
# INFO:tensorflow:Step 110500 | Loss: 0.2092 | Spent: 10.6 secs | LR: 0.000137
# INFO:tensorflow:Step 110600 | Loss: 0.2945 | Spent: 10.7 secs | LR: 0.000137
# INFO:tensorflow:Step 110700 | Loss: 0.2946 | Spent: 10.8 secs | LR: 0.000137
# INFO:tensorflow:Step 110800 | Loss: 0.2236 | Spent: 10.5 secs | LR: 0.000138
# INFO:tensorflow:Step 110900 | Loss: 0.2095 | Spent: 10.6 secs | LR: 0.000138
# INFO:tensorflow:Step 111000 | Loss: 0.2651 | Spent: 10.6 secs | LR: 0.000139
# INFO:tensorflow:Step 111100 | Loss: 0.2536 | Spent: 10.5 secs | LR: 0.000139
# INFO:tensorflow:Step 111200 | Loss: 0.2801 | Spent: 10.7 secs | LR: 0.000139
# INFO:tensorflow:Step 111300 | Loss: 0.3083 | Spent: 10.9 secs | LR: 0.000140
# INFO:tensorflow:Step 111400 | Loss: 0.2802 | Spent: 10.4 secs | LR: 0.000140
# INFO:tensorflow:Step 111500 | Loss: 0.2098 | Spent: 10.7 secs | LR: 0.000140
# INFO:tensorflow:Step 111600 | Loss: 0.2519 | Spent: 10.6 secs | LR: 0.000141
# INFO:tensorflow:Step 111700 | Loss: 0.2400 | Spent: 10.6 secs | LR: 0.000141
# INFO:tensorflow:Step 111800 | Loss: 0.1968 | Spent: 10.6 secs | LR: 0.000141
# INFO:tensorflow:Step 111900 | Loss: 0.2520 | Spent: 10.9 secs | LR: 0.000142
# INFO:tensorflow:Step 112000 | Loss: 0.2798 | Spent: 10.7 secs | LR: 0.000142
# INFO:tensorflow:Step 112100 | Loss: 0.2657 | Spent: 10.5 secs | LR: 0.000142
# INFO:tensorflow:Step 112200 | Loss: 0.1948 | Spent: 10.6 secs | LR: 0.000143
# INFO:tensorflow:Step 112300 | Loss: 0.2513 | Spent: 10.5 secs | LR: 0.000143
# INFO:tensorflow:Step 112400 | Loss: 0.2093 | Spent: 10.8 secs | LR: 0.000143
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.831
# INFO:tensorflow:Best Accuracy: 0.838
# 10 times not improve the best result, therefore stop training
